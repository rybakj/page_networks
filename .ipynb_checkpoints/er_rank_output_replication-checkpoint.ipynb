# %% [markdown]
# ## Ranking output

# %% [markdown]
# **Replication of `rank_output.ipynb`**
#
# **This notebook produces ranking of economic recovery pages based on the tfdf_max metric**

# %% [markdown]
# Currently, the output of the random walks is a single set of pages. End users will prefer a ranked list of pages. This ranking should have a tendency to rank pages from the target WUJ higher than pages not in that WUJ.

# %% [markdown]
# ### Ranking by page frequency-random walk frequency
#
# #### An example
#
# The most successful random walk method has been to perform multiple random walks and combine the pages visited by each one into a single set of pages.
#
# Each random walk traverses a path of pages. Since we perform multiple random walks, we have multiple paths. Some pages will appear on more paths than others. Some pages will appear more frequently per path.
#
# For example: suppose you perform two random walks and each one traverses the following path:
#
# - [A, C, D, C, X, Y, Z]
# - [A, C, B, D, Q, P, M]
#
# Pages A, C and D are common to both paths. However, C occurs twice on the first path, which no other page does. Hence, C should be ranked first, followed by A and D in joint second. The remaining pages are equally ranked at the bottom.
#
# #### Page frequency-path frequency
#
# Inspired by the tf-idf ("term frequency-inverse document frequency") metric from NLP, we create the tf-df metric, "term frequency-document frequency". Translated into random walk parlance, this is "page frequency-path frequency". Where "page frequency" is the number of occurences of a given page on a given path taken by a random walk, and, "path frequency" is the number of random walk paths on which a given page occurs at least once.
#
# Mathematically,
#
# $pf(r,p)$ is the frequency of page $p$ on a single random walk $r$,
#
# $$\text{pf}(r,p) = f_{r,p}$$
#
# Where $f_{r,p}$ is the count of a page on a random walk path.
#
# The path frequency is a measure of how common a given page is to all random walks performed, i.e. if it's common or rare across all random walks,
#
# $$\text{rwf}(p,R) = |\{r \in R : p \in r\}|$$
#
# Where $R$ is the set of paths taken by all random walks and $|\{r \in R : p \in r\}|$ is the number of random walks on which the page $p$ occurs. For instance, in the above example, page C occurs on two random walk paths.

# %% [markdown]
# From here, we can compute the page frequency-path frequency metric. We start by constructing an $n\times m$ matrix, $A$, where $n$ is the number of random walks performed and $m$ is the number of unique pages visited across all random walks.
#
# Hence, $A_{r,p}=f_{r,p}$, i.e. the value on the $p$-th column of the $r$-th row is the the number of occurrences of page $p$ on random walk $r$.
#
# Then, for each page, we compute the path frequency score $\text{rwf}(p,R)$. Doing this for each page gives a vector of length $m$, called $v$, and we convert this into a diagonal matrix: $V=\text{diag}(v)$, where the elements of $v$ occupy the main diagonal.
#
# Once we have this, we simply calculate $AV$. This means each $(AV)_{r,p}=f_{r,p} \text{rwf}(p,R)$.
#
# There are multiple ways to proceed from here, but somehow we need to compress $AV$ down into a vector, where we have a score for each page. We could average each column, we could take the max, the min, and so on.
#
# In our implementation, each page is ranked by the maximum score for its column in $AV$.

# %% [markdown]
# Below, a demo is shown of this ranking system.

# %%
import random_walk.utils.randomwalks as rw
import numpy as np
import pandas as pd
import networkx as nx

# %%
# er_pages is a list of pages known to be within the economic recovery WUJ
# this will be used to help evaluate the ranking system

er_pages = pd.read_excel('./data/inputs/2021-11-12 - Economic recovery pages.xlsx', sheet_name='Top pages').pagePathv2.to_list()

# get networkx graph
G = nx.read_gpickle("./data/inputs/functional_session_hit_directed_graph_er.gpickle").to_undirected()

# reformat the graph to make it compliant with existing random walk functions
# i.e. add the path to a name property and set the index to be a number

for index,data in G.nodes(data=True):
    data['properties'] = dict()
    data['properties']['name'] = index


G = nx.convert_node_labels_to_integers(G, first_label=0, ordering='default', label_attribute=None)

# get adjacency matrix of G
A = nx.adj_matrix(G, weight=None)

# %%
# set the seeds from where random walks will be initialised
seeds = (
    '/find-a-job',
    '/universal-credit',
    '/government/collections/financial-support-for-businesses-during-coronavirus-covid-19'
)

# %%
results = rw.repeat_random_walks(steps=100, repeats=100, T=A, G=G, seed_pages=seeds, proba=False, combine='union', level=1, n_jobs=1)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=3.0), HTML(value='')))

# %%
len(results["paths_taken"])
# Out:
# 3

# %%
len(results["seeds"])
# Out:
# 3

# %%
page_scores = rw.page_freq_path_freq_ranking(results)

# %%
paths = [path for paths in results['paths_taken'] for path in paths]


pages_visited = {page: i for i, page in zip(range(len(results['pages_visited'])), results['pages_visited'])}

tf = np.zeros((len(paths), len(pages_visited)))

# %%
results["pages_visited"]
# Out:
# {'/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals',
#  '/claim-asylum/help-you-can-get',
#  '/check-university-award-degree/recognised-awards',
#  '/government/organisations/uk-export-finance',
#  '/complain-about-hmrc',
#  '/return-home-voluntarily',
#  '/government/publications/transferring-a-visa-to-a-new-passport-ecb17/transferring-a-visa-ecb17',
#  '/winter-fuel-payment/print',
#  '/government/statistics/funded-occupational-pension-schemes-in-the-uk-october-2020-to-december-2020',
#  '/expenses-and-benefits-bonuses/what-to-report-and-pay',
#  '/government/publications/easy-read-support-for-mortgage-interest-smi',
#  '/tax-appeals',
#  '/motorcycle-helmet-law',
#  '/government/publications/higher-and-degree-apprenticeships',
#  '/change-your-charitys-details',
#  '/government/publications/universal-credit-and-your-family-quick-guide/universal-credit-further-information-for-families',
#  '/government/organisations/department-for-education',
#  '/foreign-travel-advice/spain/entry-requirements',
#  '/view-right-to-work',
#  '/government/organisations/disclosure-and-barring-service/about',
#  '/benefit-overpayments/repayments-when-someone-has-died',
#  '/guidance/childminders-and-childcare-providers-register-with-ofsted/the-registration-visit',
#  '/world/yemen',
#  '/child-tax-credit/responsibility-for-child',
#  '/government/publications/exempt-exm',
#  '/set-up-self-employed',
#  '/repaying-your-student-loan/when-you-start-repaying',
#  '/government/statistics/apprenticeship-and-traineeships-november-2020',
#  '/government/publications/apply-to-extend-stay-in-the-uk-as-a-partner-or-dependent-child-form-flrm/apply-online-form-flr-m',
#  '/government/organisations/defence-science-and-technology-laboratory',
#  '/government/organisations/treasure-valuation-committee',
#  '/definition-of-disability-under-equality-act-2010',
#  '/access-to-work/report-a-change-of-circumstances',
#  '/government/collections/travelling-to-the-eu-switzerland-norway-iceland-or-liechtenstein-for-work',
#  '/employers-maternity-pay-leave',
#  '/set-up-a-charity',
#  '/browse/driving/businesses',
#  '/vat-returns',
#  '/government/publications/initial-teacher-training-itt-bursary-funding-manual/initial-teacher-training-bursaries-funding-manual-2020-to-2021-academic-year',
#  '/government/statistics/further-education-and-skills-open-data-csv-files',
#  '/research-family-history',
#  '/solve-workplace-dispute/formal-procedures',
#  '/government/publications/capability-for-work-questionnaire',
#  '/right-to-buy-buying-your-council-home/help-and-advice',
#  '/find-someones-attorney-deputy-or-guardian',
#  '/control-dog-public',
#  '/government/collections/self-employment-forms-and-helpsheets',
#  '/government/organisations/hm-revenue-customs/contact/couriers',
#  '/coronavirus/education-and-childcare',
#  '/countersigning-passport-applications',
#  '/get-vehicle-information-from-dvla',
#  '/government/publications/early-years-teachers-standards',
#  '/self-employed-records/how-long-to-keep-your-records',
#  '/sure-start-maternity-grant/print',
#  '/criminal-record-checks-apply-role',
#  '/guidance/16-to-19-funding-how-it-works',
#  '/paye-forms-p45-p60-p11d/p60',
#  '/employment/finding-job',
#  '/government/publications/asylum-applicants-rights-and-responsibilities',
#  '/government/publications/individuals-rights-policy/polisi-hawliau-unigolyn',
#  '/guidance/how-to-reportself-isolation-support-payments',
#  '/browse/working/armed-forces',
#  '/plan-retirement-income/working-past-state-pension-age',
#  '/government/publications/conditions-of-acceptance-for-apprenticeship-training-providers',
#  '/tax-foreign-income',
#  '/support-for-mortgage-interest/eligibility',
#  '/vehicle-registration-schemes-for-the-motor-trade',
#  '/moving-from-benefits-to-work',
#  '/child-tax-credit/how-to-claim',
#  '/government/publications/english-language-requirements-for-immigration-applicants',
#  '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes',
#  '/government/publications/requests-for-personal-data-uk-visas-and-immigration',
#  '/government/publications/pension-schemes-newsletter-131-july-2021/pension-schemes-newsletter-131-july-2021',
#  '/find-an-immigration-adviser/what-advisers-can-do',
#  '/moving-from-benefits-to-work/help-for-parents-and-carers',
#  '/guidance/using-personal-data-in-your-business-or-other-organisation',
#  '/uk-family-visa/proof-income',
#  '/browse/benefits/unable-to-work',
#  '/guidance/help-and-support-for-agents',
#  '/browse/working/redundancies-dismissals',
#  '/park-mobile-homes/charges',
#  '/government/publications/child-maintenance-a-guide-to-statements-for-receiving-and-paying-parents/understanding-your-child-maintenance-statement-a-guide-for-receiving-parents',
#  '/government/collections/public-bodies',
#  '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do.ar',
#  '/pay-self-assessment-tax-bill/check-payment-received',
#  '/government/publications/state-pension-age-independent-review-final-report',
#  '/government/collections/pension-scheme-administration-hmrc-manuals',
#  '/short-term-benefit-advance/how-to-apply',
#  '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships',
#  '/shared-parental-leave-and-pay/when-you-can-start',
#  '/employee-tax-codes/numbers',
#  '/government/publications/staying-covid-19-secure-in-2020-notice',
#  '/government/publications/esa-outcomes-of-work-capability-assessment-policies-and-statements',
#  '/government/publications/sfa-creating-an-inclusive-apprenticeship-offer',
#  '/tax-credits-if-moving-country-or-travelling/moving-to-the-uk',
#  '/what-different-qualification-levels-mean',
#  '/government/collections/sustainable-farming-incentive-pilot-guidance',
#  '/skilled-worker-visa/your-partner-and-children',
#  '/find-motorcycle-training',
#  '/manage-child-maintenance-case/making-and-getting-payments',
#  '/government/publications/work-and-health-programme-covid-19-provider-guidance/chapter-16-performance-management-and-compliance-monitoring--2',
#  '/apply-direct-payments',
#  '/apply-tax-free-interest-on-savings',
#  '/guidance/send-your-aggregates-levy-return-online',
#  '/government/publications/supporting-documents-for-sponsor-applications-appendix-a',
#  '/government/publications/personal-independence-payment-fact-sheets',
#  '/government/publications/universal-credit-and-homeless-people',
#  '/junior-individual-savings-accounts',
#  '/illness-child-education',
#  '/government/groups/joint-biosecurity-centre',
#  '/buy-sell-your-home/energy-performance-certificates',
#  '/jobseekers-allowance/report-a-change-of-circumstances',
#  '/overseas-domestic-worker-visa/eligibility',
#  '/government/publications/state-pension-fact-sheets/contracting-out-and-why-we-may-have-included-a-contracted-out-pension-equivalent-cope-amount-when-you-used-the-online-service',
#  '/checks-when-buying-a-used-car',
#  '/government/publications/coping-with-death-abroad/death-abroad-initial-steps',
#  '/foreign-travel-advice/usa/entry-requirements',
#  '/manage-child-maintenance-case/contact',
#  '/capital-allowances/how-to-claim',
#  '/government/publications/postgraduate-teaching-apprenticeships-funding-manual',
#  '/guidance/notarial-and-documentary-services-guide-for-egypt',
#  '/government/publications/return-of-allotment-of-shares-sh01',
#  '/business-finance-support/inclusive-enterprise-programme',
#  '/advanced-learner-loan/how-to-apply',
#  '/marriages-civil-partnerships',
#  '/guidance/dbs-and-coronavirus-covid-19-frequently-asked-questions',
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes',
#  '/employment-contracts-and-conditions/contract-terms',
#  '/parental-bereavement-pay-leave/how-to-claim',
#  '/guidance/civil-service-secondments-and-loans-how-to-apply',
#  '/hmrc-internal-manuals/capital-gains-manual/cg71262',
#  '/government-authorised-exchange/documents-you-must-provide',
#  '/courts-tribunals/upper-tribunal-immigration-and-asylum-chamber',
#  '/browse/visas-immigration/student-visas',
#  '/government/publications/egypt-list-of-lawyers',
#  '/guidance/deferral-of-vat-payments-due-to-coronavirus-covid-19',
#  '/government/publications/redundancy-payments-form-hr1-advance-notification-of-redundancies',
#  '/motorcycle-cbt/prepare-cbt-course',
#  '/business-and-industry',
#  '/children-with-special-educational-needs',
#  '/send-fit-note',
#  '/parking-tickets/challenging-a-ticket',
#  '/start-up-visa/knowledge-of-english',
#  '/guidance/annual-tax-summary',
#  '/browse/disabilities/carers',
#  '/browse/business/premises-rates',
#  '/vehicle-log-book',
#  '/capital-gains-tax/work-out-need-to-pay',
#  '/guidance/contact-the-department-for-work-and-pensions-about-its-policies',
#  '/housing-association-homes/standard-of-your-home',
#  '/government/publications/organisation-testing-registration-record-of-users',
#  '/scrapped-and-written-off-vehicles',
#  '/government/publications/how-to-register-for-an-idams-account',
#  '/guidance/qualification-funding-approval/changes-to-principles-and-processes',
#  '/adult-dependants-grant/how-to-claim',
#  '/gwneud-cais-am-rif-yswiriant-gwladol',
#  '/guidance/national-insurance-number-applying-for-a-number-for-a-looked-after-child',
#  '/foreign-travel-advice/turkey/money',
#  '/government/publications/best-management-practice-portfolio',
#  '/government/organisations/pensions-ombudsman',
#  '/find-covid-19-lateral-flow-test-site',
#  '/topic/competition/competition-act-cartels',
#  '/health-care-worker-visa/documents-you-must-provide',
#  '/guidance/land-compensation-manual-section-16-estimates-negotiations-reports-and-advance-payments/part-4-advance-payments',
#  '/employment-contracts-and-conditions/collective-agreements',
#  '/lay-offs-short-timeworking',
#  '/types-of-british-nationality/british-overseas-territories-citizen',
#  '/topic/climate-change-energy/energy-efficiency',
#  '/support-military-bereaved-children',
#  '/adi-part-1-test/what-to-take',
#  '/government/publications/biometric-residence-permit-and-leave-to-remain-ecb14',
#  '/government/publications/understanding-the-possession-action-process-guidance-for-landlords-and-tenants/understanding-the-possession-action-process-a-guide-for-private-landlords-in-england-and-wales',
#  '/guidance/get-a-certificate-of-residence',
#  '/travel-grants-students-england',
#  '/claim-employment-allowance',
#  '/government/publications/disclosure-and-barring-service-dbs-check-guidance',
#  '/government/collections/fees-and-help-with-fees-forms',
#  '/guidance/coronavirus-covid-19-testing-for-people-travelling-to-england',
#  '/browse/environment-countryside/treasure-wrecks',
#  '/government/collections/esfa-update',
#  '/government/organisations/probation-service',
#  '/government/publications/civil-service-pay-remit-guidance-202122/civil-service-pay-remit-guidance-202122',
#  '/rent-room-in-your-home',
#  '/divorce',
#  '/business-and-industry/running-a-business',
#  '/guidance/visit-a-prisoner-using-a-video-call',
#  '/driving-lessons-learning-to-drive',
#  '/topic/benefits-credits',
#  '/masters-loan/eligibility',
#  '/guidance/adjusted-net-income',
#  '/licence-finder',
#  '/tax-relief-for-employees/vehicles-you-use-for-work',
#  '/government/collections/dbs-checking-service-guidance--2',
#  '/stopped-by-police-while-driving-your-rights',
#  '/government/publications/missing-children',
#  '/ask-for-a-visa-administrative-review/if-youre-in-the-uk',
#  '/guidance/working-level-for-delivery-managers-course-description',
#  '/government/publications/film-tv-production-restart-scheme',
#  '/tell-employer-or-college-about-criminal-record/cautions',
#  '/transferring-your-pension',
#  '/report-pothole',
#  '/criminal-record-checks-apply-role/application-process',
#  '/guidance/statutory-sick-pay-how-different-employment-types-affect-what-you-pay',
#  '/taking-vehicles-out-of-uk/for-less-than-12-months',
#  '/government/publications/apprenticeship-funding-legal-agreement-for-training-providers',
#  '/ancestry-visa/eligibility',
#  '/hmrc-internal-manuals/capital-gains-manual/cg22202',
#  '/government/publications/dbs-home-based-positions-guide/home-based-position-definition-and-guidance',
#  '/employment-support-allowance/your-esa-claim',
#  '/hmrc-internal-manuals/residence-domicile-and-remittance-basis/rdrm11300',
#  '/government/publications/immigration-health-surcharge-applying-for-a-refund',
#  '/employment/working-state-pension',
#  '/guidance/apprenticeship-funding-rules-for-training-providers/annex-a-eligibility-criteria-who-we-fund',
#  '/individual-savings-accounts',
#  '/track-passport-application',
#  '/apply-medal-or-veterans-badge/replace-a-medal-or-badge',
#  '/contracted-out/check-if-you-were-contracted-out',
#  '/guidance/national-planning-policy-framework/16-conserving-and-enhancing-the-historic-environment',
#  '/government/publications/veterans-world',
#  '/nhs-bursaries',
#  '/government/publications/travel-documents-no-time-limit',
#  '/manage-your-tax-credits',
#  '/driving-lessons-learning-to-drive/practising-with-family-or-friends',
#  '/corporation-tax-accounting-period',
#  '/government/publications/employment-allowance-more-detailed-guidance',
#  '/industrial-injuries-disablement-benefit/how-to-claim',
#  '/set-up-limited-company',
#  '/dismiss-staff',
#  '/take-practice-theory-test',
#  '/health-conditions-and-driving',
#  '/foreign-travel-advice/portugal',
#  '/further-education-courses/find-a-course',
#  '/apply-to-come-to-the-uk/getting-a-decision-on-your-application',
#  '/check-a-passport-travel-europe',
#  '/government/publications/appeal-a-social-security-benefits-decision-form-sscs1',
#  '/recover-statutory-payments/if-you-cant-afford-to-make-payments',
#  '/government/publications/screening-tests-for-you-and-your-baby',
#  '/options-for-paying-off-your-debts/debt-management-plans',
#  '/pay-dartford-crossing-charge/charges-fines',
#  '/browse/visas-immigration',
#  '/government/publications/employers-could-you-offer-work-experience/work-experience-employer-guide',
#  '/jobsearch-rights',
#  '/government/publications/universal-credit-different-earning-patterns-and-your-payments/universal-credit-different-earning-patterns-and-your-payments-payment-cycles',
#  '/guidance/universal-credit-toolkit-for-partner-organisations',
#  '/guidance/immigration-rules/immigration-rules-part-12-procedure-and-rights-of-appeal',
#  '/guidance/traineeship-information-for-training-providers',
#  '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees',
#  '/self-assessment-tax-returns/penalties',
#  '/staying-in-touch-with-someone-in-prison/visiting-someone-in-prison',
#  '/child-trust-funds/managing-the-account',
#  '/guidance/living-in-spain',
#  '/income-tax/check-youre-paying-the-right-amount',
#  '/government/collections/apprenticeship-end-point-assessments',
#  '/government/collections/new-rules-for-legal-practice-guidance-for-legal-professionals',
#  '/undeclared-income',
#  '/browse/housing-local-services/planning-permission',
#  '/government/publications/application-registration-card-arc',
#  '/foreign-travel-advice/india',
#  '/guidance/report-changes-to-your-disability-confident-details',
#  '/dla-disability-living-allowance-benefit/your-dla-claim',
#  '/guidance/new-style-jobseekers-allowance',
#  '/change-name-deed-poll',
#  '/maternity-allowance/how-to-claim',
#  '/claim-benefits-abroad/maternity-and-childcare-benefits',
#  '/government/collections/apprenticeship-vacancies',
#  '/driving-medical-conditions',
#  '/government/publications/accrued-income-scheme-hs343-self-assessment-helpsheet',
#  '/government/organisations/animal-and-plant-health-agency',
#  '/apply-for-elderly-person-bus-pass',
#  '/government/organisations/government-digital-service/about',
#  '/pip',
#  '/help-with-childcare-costs/free-childcare-and-education-for-2-to-4-year-olds',
#  '/government/organisations/department-for-education/about/complaints-procedure',
#  '/government/collections/coronavirus-job-retention-scheme',
#  '/government/publications/careers-guidance-provision-for-young-people-in-schools',
#  '/private-renting',
#  '/tax-national-insurance-after-state-pension-age/agerelated-tax-allowances',
#  '/government/publications/income-tax-transferring-the-married-couples-allowance-18',
#  '/get-ready-to-employ-someone',
#  '/guidance/learning-aim-reference-service-lars',
#  '/how-to-register-a-trade-mark',
#  '/government/publications/register-of-licensed-sponsors-workers',
#  '/guidance/qualification-funding-approval',
#  '/education/funding-and-finance-for-students',
#  '/keeping-your-pay-tax-records/savings-investments-and-pensions',
#  '/apply-for-business-rate-relief/rural-rate-relief',
#  '/government/organisations/high-speed-two-limited',
#  '/government/publications/fit-note-guidance-for-employers-and-line-managers/getting-the-most-out-of-the-fit-note-guidance-for-employers-and-line-managers',
#  '/guidance/check-if-your-nursery-is-eligible-for-business-rates-relief-due-to-coronavirus-covid-19',
#  '/government/publications/decision-makers-guide-vol-12-widows-benefit-and-retirement-pension-staff-guide',
#  '/subsidised-college-transport-16-19',
#  '/government/organisations/department-for-environment-food-rural-affairs',
#  '/government/publications/public-funds--2/public-funds',
#  '/guidance/united-kingdom-security-vetting-existing-clearance-holders',
#  '/over-80-pension/print',
#  '/business-finance-support/construction-industry-training-board-citb-grants-scheme-england',
#  '/child-trust-funds',
#  '/guidance/household-waste-bins-when-and-how-councils-may-issue-fixed-penalties',
#  '/guidance/new-style-employment-and-support-allowance',
#  '/government/publications/strategic-transport-apprenticeship-taskforce-skills-forecasting-baseline-study',
#  '/foreign-travel-advice/honduras',
#  '/uk-residence-card/report-a-lost-or-stolen-card',
#  '/staff-redundant',
#  '/liquidate-your-company/access-to-your-bank-account',
#  '/tax-codes',
#  '/penalty-points-endorsements/how-to-check-your-endorsement-details',
#  '/government/organisations/hm-courts-and-tribunals-service',
#  '/guidance/social-research-scheme-2021',
#  '/personalised-vehicle-registration-numbers/take-private-number-off',
#  '/visit-uk-research',
#  '/liquidate-your-company/what-happens-to-directors',
#  '/drug-driving-law',
#  '/government/publications/universal-credit-and-childcare',
#  '/winter-fuel-payment',
#  '/guidance/how-to-access-department-for-education-dfe-data-extracts',
#  '/government/publications/coronavirus-covid-19-testing-privacy-information',
#  '/taking-your-pet-abroad',
#  '/guidance/welsh-partial-loan-cancellation',
#  '/employment-tribunals/after-you-make-a-claim',
#  '/renew-driving-licence-at-70',
#  '/government/collections/keeping-children-safe-in-out-of-school-settings',
#  '/education/further-and-higher-education-courses-and-qualifications',
#  '/british-passport-eligibility',
#  '/intensive-personalised-employment-support',
#  '/help-if-you-are-arrested-abroad',
#  '/government/collections/lrs-batch-toolkit-for-aos-and-lrbs',
#  '/browse/business/waste-environment',
#  '/government/organisations/uk-council-for-internet-safety',
#  '/turkish-worker-business-person-settlement/eligibility',
#  '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries',
#  '/guidance/miscellaneous-conditions-assessing-fitness-to-drive',
#  '/government/publications/disqualification-under-the-childcare-act-2006/disqualification-under-the-childcare-act-2006',
#  '/taking-sick-leave',
#  '/claim-tax-credits/backdate-a-claim',
#  '/government/statistics/coronavirus-and-clinically-extremely-vulnerable-people-in-england-21-june-to-26-june-2021',
#  '/vat-businesses',
#  '/guidance/new-style-employment-and-support-allowance-detailed-guide',
#  '/government/publications/hm-revenue-and-customs-disclosure-service',
#  '/employing-an-apprentice/print',
#  '/government/organisations/hm-treasury/about/recruitment',
#  '/government/statistics/benefit-claimants-with-alcohol-or-drugs-as-a-disabling-condition',
#  '/government/publications/birth-certificates-and-the-full-birth-certificate-policy/birth-certificates-and-the-full-birth-certificate-policy',
#  '/disabled-facilities-grants/what-youll-get',
#  '/tax-return-uk',
#  '/government/organisations/uk-debt-management-office',
#  '/employer-preventing-discrimination',
#  '/government/publications/reciprocal-agreements',
#  '/disciplinary-procedures-and-action-at-work/suspension-from-work',
#  '/employment-contracts-and-conditions',
#  '/change-address-v5c',
#  '/transfers-takeovers',
#  '/government/publications/national-security-vetting-advice-for-people-who-are-being-vetted',
#  '/pip/when-your-pip-claim-is-reviewed',
#  '/biometric-residence-permits/lost-stolen-damaged',
#  '/employer-reporting-expenses-benefits',
#  '/government/publications/disability-confident-guidance-for-levels-1-2-and-3/level-2-disability-confident-employer',
#  '/if-your-business-faces-industrial-action',
#  '/disability-living-allowance-children/eligibility',
#  '/additional-state-pension/print',
#  '/government/publications/tier-2-and-5-priority-service-request-form',
#  '/government/collections/fit-note',
#  '/government/publications/adaptation-action-coalition-an-overview/adaptation-action-coalition-an-overview',
#  '/make-a-freedom-of-information-request/organisations-you-can-ask-for-information',
#  '/next-steps-for-your-business',
#  '/entering-staying-uk/right-to-rent-in-the-uk',
#  '/market-stall-licence',
#  '/self-employed-records',
#  '/government/publications/sector-based-work-academies-and-work-experience-trials-for-older-claimants-combined-quantitative-and-qualitative-findings',
#  '/government/publications/sfa-european-social-fund-esf-funding-rates-and-formula',
#  '/government/collections/uk-points-based-immigration-system-further-details',
#  '/government/publications/ministry-of-justice-single-departmental-plan/ministry-of-justice-single-departmental-plan--2',
#  '/employers-paternity-pay-leave/notice-period',
#  '/guidance/regulating-medical-devices-in-the-uk',
#  '/limited-company-formation',
#  '/change-name-deed-poll/enrol-a-deed-poll-with-the-courts',
#  '/government/publications/national-insurance-widows-reduced-rate-contributions-cf9a',
#  '/council-tax/who-has-to-pay',
#  '/government/publications/eea-residence-card-applications-certificates-of-application',
#  '/county-court-judgments-ccj-for-debt/pay-the-judgment-if-you-do-owe-the-money',
#  '/government/organisations/hm-revenue-customs/contact',
#  '/statutory-sick-pay',
#  '/claim-national-insurance-refund',
#  '/government/publications/disability-confident-employers-that-have-signed-up',
#  '/topic/further-education-skills/vocational-qualifications',
#  '/prepare-file-annual-accounts-for-limited-company/file-your-accounts-and-company-tax-return',
#  '/renew-adult-passport/renew',
#  '/foreign-travel-advice/romania/coronavirus',
#  '/appeal-housing-benefit-decision',
#  '/government/publications/covid-19-grant-schemes-privacy-notice',
#  '/government/publications/what-personal-independence-payment-means-for-carers',
#  '/government/statistics/esa-underpayments-progress-on-checking-june-2021/june-2021-esa-underpayments-numbers-affected-expenditure-and-final-update-on-checking',
#  '/government/organisations/immigration-enforcement',
#  '/topic/benefits-credits/child-benefit',
#  '/temporary-worker-creative-and-sporting-visa',
#  '/national-minimum-wage/employers-and-the-minimum-wage',
#  '/check-state-pension',
#  '/guidance/e10-petrol-explained',
#  '/guidance/immigration-rules/immigration-rules-appendix-v-visitor',
#  '/employment-status/director',
#  '/immigration-asylum-tribunal/appeal-from-outside-the-uk',
#  '/check-job-applicant-right-to-work',
#  '/divorce/file-for-divorce',
#  '/paternity-pay-leave/leave',
#  '/uk-visa-sponsorship-employers',
#  '/government/publications/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19',
#  '/search-bankruptcy-insolvency-register',
#  '/guidance/customer-service',
#  '/government/organisations/hm-revenue-customs/contact/employer-enquiries',
#  '/government/publications/calculating-holiday-pay-for-workers-without-fixed-hours-or-pay/calculating-holiday-pay-for-workers-without-fixed-hours-or-pay--2',
#  '/government/consultations/call-for-evidence-modernisation-of-the-stamp-taxes-on-shares-framework/outcome/modernisation-of-the-stamp-taxes-on-shares-framework-summary-of-responses',
#  '/government/publications/electrical-safety-approved-document-p',
#  '/government/publications/uk-digital-identity-attributes-trust-framework-updated-version/uk-digital-identity-and-attributes-trust-framework-delegated-authority-guidance',
#  '/apply-citizenship-eea',
#  '/government/publications/protection-of-freedoms-act-2012-dna-and-fingerprint-provisions/protection-of-freedoms-act-2012-how-dna-and-fingerprint-evidence-is-protected-in-law',
#  '/government/publications/esa214-a-guide-to-employment-and-support-allowance-the-work-capability-assessment',
#  '/make-court-claim-for-money/court-fees',
#  '/guidance/eu-settlement-scheme-applying-from-outside-the-uk',
#  '/settlement-refugee-or-humanitarian-protection/eligibility',
#  '/government/publications/apply-for-a-duplicate-citizenship-certificate-form-nc',
#  '/government/publications/workers-and-temporary-workers-guidance-for-sponsors-part-1-apply-for-a-licence',
#  '/guidance/immigration-rules/immigration-rules-part-9-grounds-for-refusal',
#  '/government/publications/pension-schemes-newsletter-131-july-2021',
#  '/council-tax-appeals',
#  '/uk-family-visa/after-you-apply',
#  '/browse/housing-local-services/council-housing-association',
#  '/government/publications/children-nationality-policy-guidance',
#  '/hmrc-internal-manuals/employment-status-manual/esm4022',
#  '/courts-tribunals/companies-list',
#  '/government/publications/incorporation-and-names',
#  '/working-tax-credit',
#  '/dismiss-staff/unfair-dismissals',
#  '/government/publications/fe-commissioner-intervention-nottingham-college',
#  '/government/organisations/hm-passport-office',
#  '/redundancy-your-rights/redundancy-pay',
#  '/personal-tax-account/sign-in/prove-identity',
#  '/guidance/how-to-complete-the-educational-setting-status-form',
#  '/government/publications/nda-value-framework-how-we-make-decisions/explaining-the-value-framework',
#  '/guidance/frontier-workers-in-eu-and-efta-countries',
#  '/government/publications/employing-disabled-people-and-people-with-health-conditions/employing-disabled-people-and-people-with-health-conditions',
#  '/disciplinary-procedures-and-action-at-work/help-and-advice-with-disciplinary-issues',
#  '/adi-part-3-test/what-happens-during-test',
#  '/government/publications/travelling-to-the-uk',
#  '/government/publications/statutory-maternity-pay-employee-not-entitled-form-for-employers',
#  '/foreign-travel-advice/singapore',
#  '/graduate-visa/your-partner-and-children',
#  '/government/publications/5-million-loneliness-covid-19-grant-fund',
#  '/guidance/qualifications-learning',
#  '/government/publications/agreements-reached-between-the-united-kingdom-of-great-britain-and-northern-ireland-and-the-european-union/summary-explainer',
#  '/government/organisations/department-for-digital-culture-media-sport',
#  '/government/publications/universal-credit-and-your-claimant-commitment-quick-guide/universal-credit-and-your-claimant-commitment',
#  '/browse/housing-local-services/owning-renting-property',
#  '/claim-employment-allowance/eligibility',
#  '/government/publications/grade-and-salary-bands',
#  '/government/organisations/advisory-committee-on-business-appointments',
#  '/government/publications/application-to-extend-stay-in-the-uk-flrgt',
#  '/british-national-overseas-bno-visa',
#  '/guidance/apply-to-join-a-nursery-or-other-daycare-organisation-ey2',
#  '/government/collections/alcohol-licensing-personal-licences',
#  '/guidance/mot-inspection-manual-for-private-passenger-and-light-commercial-vehicles/3-visibility',
#  '/money',
#  '/government/publications/good-work-plan/good-work-plan',
#  '/government/collections/gcse-subject-content',
#  '/disabled-facilities-grants/eligibility',
#  '/guidance/the-uks-points-based-immigration-system-information-for-eu-citizens.pt',
#  '/world/coming-to-the-uk-south-africa',
#  '/government/publications/teachers-standards',
#  '/standard-visitor-visa/what-you-can-do-in-the-uk',
#  '/hmrc-internal-manuals/international-manual/intm120185',
#  '/renew-adult-passport',
#  '/government/organisations/department-for-environment-food-rural-affairs/services-information',
#  '/register-with-the-police/where-to-register',
#  '/blind-persons-allowance',
#  '/find-driving-instructor-training',
#  '/skilled-worker-visa/your-job',
#  '/government/publications/subcontracting-funding-rules-for-esfa-funded-post-16-funding-excluding-apprenticeships',
#  '/jury-service/what-you-can-claim-if-youre-an-employee',
#  '/child-trust-funds/find-a-child-trust-fund',
#  '/browse/employing-people/time-off',
#  '/government/publications/work-and-health-programme-provider-guidance/chapter-1-introduction-and-overview',
#  '/find-an-energy-assessor',
#  '/pay-voluntary-class-3-national-insurance/bank-details',
#  '/fixed-term-contracts',
#  '/government/publications/pre-release-access-list-for-eu-settlement-scheme-statistics-headline-monthly-figures',
#  '/government/organisations/civil-service-government-finance-profession',
#  '/identitycards',
#  '/government/collections/reptile-licences',
#  '/government/publications/how-to-take-a-complaint-to-the-independent-case-examiner',
#  '/support-for-mortgage-interest/other-financial-help-housing',
#  '/guidance/applying-to-the-court-as-a-creditor-of-a-debt-in-a-breathing-space',
#  '/government/publications/calculating-holiday-entitlement-for-workers/how-to-calculate-holiday-entitlement-for-workers-on-different-types-of-contract',
#  '/government/publications/additional-statutory-paternity-pay-non-payment-explanation-aspp1',
#  '/company-tax-returns',
#  '/eu-eea',
#  '/cymraeg',
#  '/guidance/salary-sacrifice-and-the-effects-on-paye',
#  '/working-with-trade-unions',
#  '/government/publications/further-education-and-skills-inspection-handbook-eif',
#  '/after-school-holiday-club',
#  '/getting-parole/parole-board-hearing',
#  '/topic/housing/tenancies-leases',
#  '/tax-codes/tell-hmrc-about-a-change-tax-code',
#  '/family-permit/eea-family-permit',
#  '/browse/education/student-finance',
#  '/blind-persons-allowance/eligibility',
#  '/government/publications/filtering-rules-for-criminal-record-check-certificates',
#  '/check-mot-status',
#  '/claim-for-injury-received-while-serving/how-to-claim',
#  '/government/publications/employment-and-support-allowance-notes-about-your-claim',
#  '/school-attendance-absence/help-with-getting-your-child-to-go-to-school',
#  '/government/publications/intellectual-property-for-business',
#  '/settled-status-eu-citizens-families/if-you-have-permanent-residence-or-indefinite-leave-to-remain',
#  '/government/publications/compensation-for-poor-service-a-guide-for-dwp-staff',
#  '/vat-rates',
#  '/government/collections/applications-for-continued-registration',
#  '/government/publications/redundancy-support-for-employers/redundancy-factsheet-for-employers',
#  '/contact-hmrc',
#  '/asylum-support/further-information',
#  '/guidance/how-to-buy-printed-copies-of-official-documents',
#  '/global-talent/apply-from-outside-the-uk',
#  '/expenses-benefits-items-for-disabled-employees',
#  '/register-book-driving-tests-for-pupils',
#  '/browse/benefits/families',
#  '/contact-student-finance-england',
#  '/apply-home-equipment-for-disabled',
#  '/guidance/mot-modernisation-slot-payments',
#  '/foreign-travel-advice/canada/entry-requirements',
#  '/guardians-allowance/further-information',
#  '/government/publications/new-enterprise-allowance-phase-2-provider-guidance/new-enterprise-allowance-phase-2-provider-guidance',
#  '/armed-forces-pension-calculator',
#  '/government/publications/dance-and-drama-awards-income-scales',
#  '/government/publications/disability-confident-guidance-for-levels-1-2-and-3',
#  '/uk-family-visa/adult-dependent-relative',
#  '/government/collections/housing-benefit-recoveries-and-fraud-data',
#  '/government/publications/best-management-practice-portfolio/about-the-office-of-government-commerce',
#  '/browse/driving/highway-code-road-safety',
#  '/work-health-programme',
#  '/government/publications/civil-service-code/the-civil-service-code',
#  '/agricultural-sick-pay/eligibility',
#  '/government/collections/self-assessment-helpsheets-main-self-assessment-tax-return',
#  '/government/collections/apprenticeship-end-point-assessments-rules-and-guidance',
#  '/new-state-pension/how-its-calculated',
#  '/government/publications/dwp-factual-medical-reports-guidance-for-healthcare-professionals/dwp-forms',
#  '/student-visa/family-members',
#  '/guidance/industry-placements',
#  '/international-agreement-worker-visa/switch-to-this-visa',
#  '/government/collections/self-assessment-helpsheets-capital-gains',
#  '/government/organisations/home-office/about/access-and-opening',
#  '/guidance/teacher-misconduct-attend-a-professional-conduct-panel-hearing-or-meeting',
#  '/world/hong-kong',
#  '/government/organisations/disclosure-and-barring-service',
#  '/topic/personal-tax',
#  '/universal-credit/how-youre-paid',
#  '/government/publications/actions-for-schools-during-the-coronavirus-outbreak',
#  '/national-insurance',
#  '/residential-support-scheme/residential-bursary-fund',
#  '/browse/driving/penalty-points-fines-bans',
#  '/guidance/search-for-apprenticeship-standards',
#  '/access-to-elected-office-fund',
#  '/support-for-mortgage-interest',
#  '/guidance/the-uks-points-based-immigration-system-information-for-eu-citizens.lt',
#  '/government/publications/home-office-structure-and-salaries-2021',
#  '/join-trade-union/role-of-your-trade-union-rep',
#  '/deposit-protection-schemes-and-landlords',
#  '/government/publications/dfid-technical-competency-frameworks',
#  '/inheritance-tax',
#  '/hmrc-internal-manuals/national-minimum-wage-manual/nmwm04100',
#  '/long-residence',
#  '/what-is-the-construction-industry-scheme',
#  '/turkish-worker-business-person-settlement/family-members',
#  '/guidance/apprenticeship-funding-rules-for-training-providers/changes-in-circumstances',
#  '/driving-test/using-your-own-car',
#  '/government/statistics/universal-credit-and-severe-disability-premium-claims',
#  '/government/publications/covid-19-vaccination-and-blood-clotting/covid-19-vaccination-and-blood-clotting',
#  '/government/collections/commercial-medicines-unit-cmu',
#  '/employment-tribunal-decisions',
#  '/government/publications/support-your-child-or-partners-student-finance-application-2021-to-2022',
#  '/guidance/safeguarding-duties-for-charity-trustees',
#  '/volunteer-to-check-standards-in-prison',
#  '/claim-asylum/eligibility',
#  '/hmrc-internal-manuals/residence-domicile-and-remittance-basis/rdrm11500',
#  '/government/publications/eu-settlement-scheme-update/eu-settlement-scheme-update',
#  '/government/publications/register-of-merged-charities',
#  '/employment-status/employee-shareholders',
#  '/guidance/how-to-revalidate-a-uk-certificate-of-competency',
#  '/foreign-travel-advice/australia/coronavirus',
#  '/foreign-travel-advice/italy',
#  '/guidance/homelessness-code-of-guidance-for-local-authorities/chapter-18-applications-decisions-and-notifications',
#  '/government/organisations/hm-revenue-customs/contact/change-your-personal-details',
#  '/government/organisations/civil-service-government-economic-service/about',
#  '/global-entry-usa',
#  '/government/organisations/atomic-weapons-establishment',
#  '/claim-tax-refund',
#  '/request-cctv-footage-of-yourself',
#  '/guidance/what-payroll-information-to-report-to-hmrc',
#  '/youth-mobility/eligibility',
#  '/vehicle-tax-rate-tables',
#  '/parental-rights-responsibilities/apply-for-parental-responsibility',
#  '/government/publications/restart-scheme/how-the-restart-scheme-will-work',
#  '/browse/justice/courts-sentencing-tribunals',
#  '/government/publications/apply-for-a-postal-vote',
#  '/government/publications/financial-sanctions-consolidated-list-of-targets/consolidated-list-of-targets',
#  '/government/publications/how-jobcentre-plus-can-help-employers/jobcentre-plus-working-together-with-employers',
#  '/education/further-and-higher-education-skills-and-vocational-training',
#  '/government/publications/adult-education-budget-funding-rules-2018-to-2019',
#  '/government/collections/visa-decision-waiting-times',
#  '/government/publications/the-universal-credit-coronavirus-restoration-of-the-minimum-income-floor-regulations-2021/minister-for-employment-response-to-ssac-the-universal-credit-coronavirus-restoration-of-the-minimum-income-floor-regulations-2021',
#  '/student-visa/money',
#  '/employing-an-apprentice/pay-and-conditions-for-apprentices',
#  '/guidance/pension-administrators-check-your-members-protection-status',
#  '/plan-adoption-leave',
#  '/settled-status-eu-citizens-families/settled-status-less-than-5-years',
#  '/government/publications/ways-in-which-people-can-be-lawfully-resident-in-the-uk/ways-in-which-people-can-be-lawfully-resident-in-the-uk',
#  '/guidance/homelessness-code-of-guidance-for-local-authorities/chapter-6-homeless-or-threatened-with-homelessness',
#  '/government/organisations/government-actuarys-department',
#  '/government/publications/working-together-to-safeguard-children--2',
#  '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide',
#  '/topic/immigration-operational-guidance/entry-clearance-guidance',
#  '/guidance/refunds-of-uk-vat-for-non-uk-businesses-or-eu-vat-for-uk-businesses',
#  '/maternity-pay-leave',
#  '/early-retirement-pension/benefits',
#  '/government/publications/armed-forces-pensions-and-national-insurance-modification',
#  '/end-civil-partnership',
#  '/transport/driving-and-motorcycle-tests',
#  '/government/collections/self-assessment-helpsheets-employment',
#  '/world/russia',
#  '/government/publications/the-national-minimum-wage-in-2021',
#  '/view-lasting-power-of-attorney',
#  '/trading-hours-for-retailers-the-law',
#  '/guidance/the-highway-code/updates',
#  '/financial-help-disabled/on-a-low-salary',
#  '/government/publications/dbs-unusual-addresses-guidance/dbs-unusual-addresses-guide',
#  '/entering-staying-uk/visas-entry-clearance',
#  '/export-health-certificates/export-processed-pet-food-other-than-canned-pet-food-to-or-transit-through-the-european-union-certificate-8305',
#  '/exempt-vignette',
#  '/state-pension/inheritance',
#  '/vehicle-registration/new-and-used-vehicles',
#  '/repaying-your-student-loan/update-your-employment-details',
#  '/government/publications/eu-settlement-scheme-introduction-for-community-groups',
#  '/topic/business-tax/ir35',
#  '/guidance/living-in-france',
#  '/pay-corporation-tax',
#  '/government/organisations/hm-revenue-customs/contact/report-fraud-to-hmrc',
#  '/apply-for-student-finance',
#  '/government/publications/compensation-for-poor-service-a-guide-for-dwp-staff/financial-redress-for-maladministration-staff-guide',
#  '/government/organisations/department-for-education/about/recruitment',
#  '/uk-residence-card/card-hasnt-arrived',
#  '/hmrc-internal-manuals/savings-and-investment-manual',
#  '/driving-licence-fees',
#  '/adoption-pay-leave/leave',
#  '/running-a-limited-company/company-annual-return',
#  '/government/publications/fit-notes-the-collection-of-anonymous-data-in-england',
#  '/government/history',
#  '/appeal-call-up-reserve-forces',
#  '/introduction-to-business-rates',
#  '/government/publications/hr-career-frameworks',
#  '/after-a-death/death-abroad',
#  '/driving-medical-conditions/what-happens-after-you-tell-dvla',
#  '/guidance/record-a-grade-api',
#  '/government/publications/apprenticeship-commitment-statement-template',
#  '/council-housing/buying-your-council-home',
#  '/statutory-sick-pay/print',
#  '/data-protection-register-notify-ico-personal-data',
#  '/nurse-agency-registration-scotland',
#  '/reapply-licence-revoked',
#  '/browse/citizenship/voting',
#  '/power-of-attorney/end',
#  '/payroll-software/free-software',
#  '/guidance/apply-for-a-discretionary-grant-where-the-dissolved-company-can-be-restored-cb2',
#  '/guidance/steps-to-take-before-calculating-your-claim-using-the-coronavirus-job-retention-scheme',
#  '/government/publications/contact-details-for-immigration-compliance-and-enforcement-teams/contact-details-for-immigration-compliance-and-enforcement-teams',
#  '/guidance/the-uks-points-based-immigration-system-information-for-eu-citizens.ro',
#  '/government/publications/finding-new-trustees-cc30/finding-new-trustees',
#  '/trusts-taxes/parental-trusts-for-children',
#  '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions',
#  '/repair-council-property',
#  '/government/publications/child-benefit-apply-for-extension-ch299',
#  '/free-school-transport',
#  '/debt-payments-from-your-wages',
#  '/carers-allowance/further-information',
#  '/government/publications/basic-passport-checks',
#  '/winter-fuel-payment/how-much-youll-get',
#  '/business-finance-support/business-growth-calderdale',
#  '/browse/justice/rights',
#  '/whistleblowing/who-to-tell-what-to-expect',
#  '/foreign-travel-advice/barbados',
#  '/marriage-allowance/how-to-apply',
#  '/topic/business-tax/corporation-tax',
#  '/guidance/universal-credit-and-families-with-more-than-2-children-information-for-claimants',
#  '/guidance/employment-status-employment-intermediaries',
#  '/apply-citizenship-born-uk/uk-until-10',
#  '/budgeting-help-benefits/repayments',
#  '/pension-credit/change-of-circumstances',
#  '/government/publications/train-to-teach-in-england-non-uk-applicants/train-to-teach-in-england-non-uk-applicants',
#  '/dual-citizenship',
#  '/stop-forced-marriage',
#  '/pass-plus',
#  '/government/publications/traffic-commissioners-transport-managers-november-2018/statutory-document-3-transport-managers',
#  '/government/publications/income-support-claim-form',
#  '/working-tax-credit/how-to-claim',
#  '/parental-bereavement-pay-leave/what-you-can-get',
#  '/benefit-cap/when-youre-not-affected',
#  '/guidance/immigration-rules/immigration-rules-appendix-skilled-worker',
#  '/guidance/secure-tenancy-forms',
#  '/government/publications/adoption-of-rooftop-solar-photovoltaic-panels-in-the-uk',
#  '/settled-status-eu-citizens-families',
#  '/workplace-temperatures',
#  '/apply-medal-or-veterans-badge',
#  '/payroll-annual-reporting/send-your-final-payroll-report',
#  '/expenses-and-benefits-clothing/technical-guidance',
#  '/transfer-visa/transfer-to-brp',
#  '/government/publications/application-for-uk-visa-to-visit-or-for-short-term-stay-form-vaf1a',
#  '/asylum-support/what-youll-get',
#  '/government/publications/pension-credit-claim-form--2',
#  '/government/publications/nhs-holiday-pay-for-voluntary-overtime-equalities-impact-assessment/equality-considerations-under-the-equality-act-2010-including-fulfilment-of-the-psed-for-the-collective-agreed-framework-in-relation-to-annual-leave',
#  '/work-reference',
#  '/blue-badge-scheme-information-council',
#  '/government/organisations/civil-service',
#  '/expenses-and-benefits-company-cars/whats-exempt',
#  '/government/publications/change-to-the-entrepreneurs-relief-lifetime-limit-for-capital-gains-tax/capital-gains-tax-entrepreneurs-relief-reduction-in-the-lifetime-limit--2',
#  '/returning-resident-visa',
#  '/appeal-parking-fine',
#  '/refugee-integration-loan/eligibility',
#  '/driving-disqualifications/apply-to-reduce-your-disqualification-period',
#  '/drivers-hours/rules-for-employers',
#  '/government/publications/dbs-application-forms-guide-for-applicants',
#  '/workplace-pensions/get-help',
#  '/expenses-if-youre-self-employed/office-property',
#  '/dwp-visit',
#  '/government/publications/form-bota-guidance',
#  '/government/publications/institutes-of-technology--2/institutes-of-technology',
#  '/government/publications/claim-for-loss-of-notice-factsheet-rp2/claim-for-loss-of-notice-pay-rp2',
#  '/get-a-child-passport/replace-a-damaged-child-passport',
#  '/capital-allowances',
#  '/log-in-file-self-assessment-tax-return',
#  '/penalty-points-endorsements',
#  '/start-up-visa',
#  '/employee-tax-codes',
#  '/government/publications/preventing-illegal-working-guidance-for-employers-october-2013',
#  '/business-finance-support/bcrs-business-loans-west-midlands',
#  '/government/organisations/disclosure-and-barring-service/about/social-media-use',
#  '/guidance/importing-or-moving-live-animals-animal-products-and-high-risk-food-and-feed-not-of-animal-origin',
#  '/vehicle-tax-direct-debit/renewing',
#  '/tax-buy-shares',
#  '/paye-forms-p45-p60-p11d/p11d',
#  '/government/collections/ofsted-inspections-of-maintained-schools',
#  '/financial-help-disabled',
#  '/taking-disciplinary-action/appeals',
#  '/government/publications/complaints-about-dwp-financial-year-2020-to-2021/complaints-about-dwp-financial-year-2020-to-2021',
#  '/payroll-errors/correcting-your-fps-or-eps',
#  '/death-spouse-benefits-tax-pension/benefits',
#  '/glaucoma-and-driving',
#  '/foreign-travel-advice/netherlands/coronavirus',
#  '/renew-photo-driving-licence',
#  '/settled-status-eu-citizens-families/family-member-eligible-person-from-northern-ireland',
#  '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403.cy',
#  '/guidance/brexit-guidance-for-individuals-and-families',
#  '/come-uk-married',
#  '/government/publications/national-insurance-credits-for-adults-who-care-for-a-child-under-12-fact-sheet/specified-adult-childcare-credits-fact-sheet',
#  '/government/collections/dwp-leaflets-and-how-to-order-them',
#  '/government/publications/open-standards-for-government/viewing-government-documents',
#  '/national-insurance/help-if-youre-not-working',
#  '/guidance/settled-status-for-eu-citizens-and-their-families-translations.ro',
#  '/foreign-travel-advice/germany/entry-requirements',
#  '/government/collections/drivers-hours-rules-and-guidance',
#  '/government/publications/commonwealth-marine-economies-cme-programme-caribbean-region',
#  '/browse/births-deaths-marriages',
#  '/world/organisations',
#  '/guidance/assured-tenancy-forms',
#  '/government/publications/home-office-travel-documents',
#  '/world/pakistan',
#  '/uk-family-visa',
#  '/dla-disability-living-allowance-benefit',
#  '/expenses-if-youre-self-employed/how-to-claim',
#  '/guidance/eu-settlement-scheme-apply-for-an-administrative-review',
#  '/dismiss-staff/eligibility-to-claim-unfair-dismissal',
#  '/seat-belts-law',
#  '/browse/citizenship/government',
#  '/government/organisations/student-loans-company/about/statistics',
#  '/calculate-statutory-sick-pay',
#  '/individual-savings-accounts/how-to-open-an-isa',
#  '/government/publications/benefit-and-pension-rates-2019-to-2020/proposed-benefit-and-pension-rates-2019-to-2020',
#  '/guidance/state-pension-if-youve-lived-in-australia-canada-or-new-zealand',
#  '/foreign-travel-advice/lithuania/entry-requirements',
#  '/foreign-travel-advice/france/entry-requirements',
#  '/over-80-pension',
#  '/foreign-travel-advice/belgium',
#  '/government/publications/uk-points-based-immigration-system-employer-information/the-uks-points-based-immigration-system-an-introduction-for-employers',
#  '/government/publications/universal-credit-and-self-employment-quick-guide',
#  '/deferring-state-pension/extra-state-pension-and-lump-sum-payments',
#  '/workplace-bullying-and-harassment',
#  '/guidance/energy-catalyst-what-it-is-and-how-to-apply-for-funding',
#  '/guidance/coronavirus-covid-19-safer-air-travel-guidance-for-passengers',
#  '/government/organisations/teaching-regulation-agency',
#  '/contact-dfe',
#  '/foreign-travel-advice/ukraine',
#  '/raise-grievance-at-work',
#  '/government/collections/treasury-minutes',
#  '/government/organisations/natural-england/about/recruitment',
#  '/getting-help-with-your-tax-credits-claim/appointees',
#  '/maximum-weekly-working-hours/calculating-your-working-hours',
#  '/send-prisoner-money',
#  '/cognitive-problems-and-driving',
#  '/solve-workplace-dispute/help-and-advice',
#  '/guidance/local-housing-allowance',
#  '/government/publications/the-government-economic-service-degree-level-apprenticeship',
#  '/government/publications/maternity-allowance-claim-form',
#  '/write-business-plan',
#  '/government/publications/covid-19-vaccination-what-to-expect-after-vaccination/what-to-expect-after-your-covid-19-vaccination',
#  '/tell-employer-or-college-about-criminal-record/what-information-you-need-to-give',
#  '/types-of-british-nationality/british-national-overseas',
#  '/government/collections/income-tax-forms',
#  '/check-state-pension/sign-in/create-account',
#  '/government/publications/registering-to-vote-easy-read-guide',
#  '/income-tax/taxfree-and-taxable-state-benefits',
#  '/renting-business-property-tenant-responsibilities',
#  '/government/organisations/the-coal-authority',
#  '/control-dog-public/banned-dogs',
#  '/foreign-travel-advice/iceland/entry-requirements',
#  '/grant-bursary-adult-learners',
#  '/topic/running-charity/staff-volunteers',
#  '/drivers-hours',
#  '/make-money-claim',
#  '/ancestry-visa/extend-your-visa',
#  '/motorcycle-cbt/car-driving-licence',
#  '/government/publications/employing-disabled-people-and-people-with-health-conditions',
#  '/looking-for-work-if-disabled/applying-for-a-job',
#  '/government/statistics/child-tax-credit-and-universal-credit-claimants-statistics-related-to-the-policy-to-provide-support-for-a-maximum-of-2-children-april-2020',
#  '/government/publications/inclusive-communication/accessible-communication-formats',
#  '/browse/births-deaths-marriages/child-adoption',
#  '/guidance/pension-administrators-reporting-to-hmrc',
#  '/guidance/cyber-security-cni-apprenticeships',
#  '/government/publications/child-tax-credit-and-working-tax-credit-leaflet-wtc2',
#  '/government/publications/dbs-subject-access-request',
#  '/government/publications/lrs-maintenance-schedule',
#  '/browse/business',
#  '/plan-retirement-income/get-financial-advice',
#  '/government/publications/travelling-to-the-uk/travelling-to-the-uk',
#  '/browse/working/contract-working-hours',
#  '/apply-for-student-finance/when',
#  '/rights-disabled-person',
#  '/government/publications/kents-national-nature-reserves/kents-national-nature-reserves',
#  '/government/publications/ins216-how-to-apply-for-free-disabled-tax',
#  '/sure-start-maternity-grant/eligibility',
#  '/government/publications/rdpe-growth-programme',
#  '/innovator-visa/eligibility',
#  '/right-to-acquire-buying-housing-association-home/applying',
#  '/self-employment-and-universal-credit',
#  '/become-apprentice/apply-for-an-apprenticeship',
#  '/handling-employee-grievance',
#  '/trusts-taxes/trustees-tax-responsibilities',
#  '/government/publications/visas-and-citizenship-data-q1-2021',
#  '/government/collections/further-education-and-sixth-form-college-governors',
#  '/find-an-immigration-adviser',
#  '/government/publications/gcse-mathematics-subject-content-and-assessment-objectives',
#  '/capital-gains-tax/report-and-pay-capital-gains-tax',
#  '/asylum-support',
#  '/guidance/pupil-premium-effective-use-and-accountability',
#  '/tax-national-insurance-after-state-pension-age',
#  '/government/publications/landlords-guide-to-right-to-rent-checks',
#  '/browse/employing-people',
#  '/simple-assessment',
#  '/government/publications/application-to-register-child-under-18-as-british-overseas-citizen',
#  '/statutory-sick-pay/how-to-claim',
#  '/reapply-driving-licence-medical-condition',
#  '/guidance/income-tax-when-you-rent-out-a-property-working-out-your-rental-income',
#  '/guidance/apply-for-a-kickstart-scheme-grant',
#  '/check-british-citizenship/born-in-the-uk-on-30-april-2006-onwards',
#  '/government/publications/pension-schemes-application-for-a-certificate-of-residence-apss-146e',
#  '/travel-abroad',
#  '/right-to-acquire-buying-housing-association-home/your-landlords-offer',
#  '/1619-bursary-fund/what-youll-get',
#  '/find-postgraduate-teacher-training-courses',
#  '/government/publications/screening-tests-for-you-and-your-baby.ro',
#  '/guidance/carry-out-daily-heavy-goods-vehicle-hgv-walkaround-checks',
#  '/guide-to-probation/ask-to-be-released-again-on-probation',
#  '/how-to-vote/postal-voting',
#  '/foreign-travel-advice/afghanistan',
#  '/the-warm-home-discount-scheme/guarantee-pension-credit',
#  '/hmrc-internal-manuals/employment-income-manual/eim76222',
#  '/government/publications/register-a-private-or-public-company-in01',
#  '/welfare/welfare-reform',
#  '/tax-employee-share-schemes/employee-shareholder-shares',
#  '/national-insurance-credits',
#  '/right-to-reside',
#  '/government/statistics/personal-pensions-including-stakeholder-pensions-for-individuals-scheme-members-annual-contributions',
#  '/visas-partner-dies',
#  '/browse/births-deaths-marriages/register-offices',
#  '/driver-cpc-training/finding-training-courses',
#  '/student-visa/course',
#  '/government/collections/state-pension-toolkit',
#  '/make-will',
#  '/turkish-business-person',
#  '/government/publications/16-to-19-study-programmes-guide-for-providers',
#  '/growing-your-business',
#  '/learning-to-drive-a-tractor-or-specialist-vehicle',
#  '/hmrc-internal-manuals/tax-credits-technical-manual/tctm05300',
#  '/guidance/schools-admissions-applications-from-overseas-children',
#  '/dismissal/what-to-do-if-youre-dismissed',
#  '/government/collections/warning-misleading-invoices',
#  '/rest-breaks-work/compensatory-rest',
#  '/become-childminder-nanny',
#  '/government/organisations/veterinary-medicines-directorate',
#  '/check-job-applicant-right-to-work/prove',
#  '/government/publications/form-rs1-guidance',
#  '/government/publications/provider-guide-to-delivering-high-quality-apprenticeships/ofsted-inspection-and-esfa-intervention',
#  '/stopped-by-police-while-driving-your-rights/breath-tests',
#  '/government/collections/non-resident-landlords-forms',
#  '/provide-journey-contact-details-before-travel-uk',
#  '/government/publications/redundancy-payments-rp1-fact-sheet/what-to-do-when-youve-been-made-redundant',
#  '/government/collections/tax-credits-forms-notes-worksheets-and-checklists',
#  '/government/publications/redundancy-payments-from-the-insolvency-service',
#  '/government/organisations/government-digital-service',
#  '/foreign-travel-advice/russia/entry-requirements',
#  '/parking-tickets',
#  '/government/publications/dbs-application-forms-guide-for-applicants/cyfarwyddyd-ir-ymgeisydd-ar-gwblhaur-ffurflen-gais-dbs',
#  '/guidance/civil-service-fast-track-apprenticeship-who-can-apply',
#  '/becoming-foster-parent',
#  '/self-assessment-ready-reckoner',
#  '/reduced-rate-election-payroll',
#  '/guidance/free-courses-for-jobs',
#  '/government/publications/work-and-health-programme-provider-guidance/chapter-2-participant-identification-eligibility-and-referral',
#  '/private-renting/your-landlords-safety-responsibilities',
#  '/become-lorry-bus-driver',
#  '/government/organisations/ministry-of-defence/about',
#  '/guidance/apprenticeship-funding-rules-for-employer-providers/paying-for-an-apprenticeship',
#  '/tax-appeals/delay-payment',
#  '/guidance/apply-to-register-as-a-nanny',
#  '/standard-visitor-visa',
#  '/company-tax-returns/making-changes',
#  '/intracompany-transfer-worker-visa/eligibility',
#  '/guidance/electricity-meters-high-bills-or-meter-readings',
#  '/disabled-students-allowance-dsa/eligibility',
#  '/government/organisations/department-for-education-and-skills',
#  '/government/publications/applying-for-an-sia-licence-help-and-guidance',
#  '/world/saudi-arabia',
#  '/healthcare-immigration-application/how-much-pay',
#  '/get-help-hmrc-extra-support/information-in-another-language',
#  '/change-name-driving-licence',
#  '/self-employed-national-insurance-rates',
#  '/food-business-registration',
#  '/government/publications/budget-2021-documents/budget-2021-html',
#  '/government/publications/sector-based-work-academies-employer-guide',
#  '/tax-foreign-income/foreign-income-thats-taxed-differently',
#  '/change-driving-test',
#  '/government/collections/esa-underpayments-progress-on-checking',
#  '/government/publications/application-to-extend-stay-in-the-uk-flrhro',
#  '/government/publications/make-a-lasting-power-of-attorney/lp12-make-and-register-your-lasting-power-of-attorney-a-guide-web-version',
#  '/how-to-annul-marriage',
#  '/control-dog-public/report-a-dog',
#  '/discrimination-your-rights/discrimination-at-work',
#  '/exchange-foreign-driving-licence',
#  '/guidance/how-hmrc-works-out-total-income-and-trading-profits-for-the-self-employment-income-support-scheme',
#  '/browse/driving/driving-enforcing-the-law',
#  '/hmrc-internal-manuals/international-manual/intm162000',
#  '/browse/driving/vehicle-tax-mot-insurance',
#  '/housing-benefit',
#  '/entering-staying-uk/visa-sponsorship',
#  '/government/publications/guidance-on-claiming-a-state-pension-if-you-retire-abroad',
#  '/guidance/extended-civil-restraint-orders-in-force',
#  '/help-eu-settlement-scheme',
#  '/government/publications/document-collection-authorisation-letter',
#  '/solve-workplace-dispute/appeals',
#  '/getting-parole/represent-yourself-at-the-hearing',
#  '/guidance/apprenticeship-training-provider-accountability-framework-20212022',
#  '/business-finance-support/enterprise-agency-durham',
#  '/government/publications/list-of-ukvi-international-application-points-and-decision-making-centres',
#  '/mortgage-interest-run-on',
#  '/government/publications/support-for-british-nationals-abroad-a-guide',
#  '/health-care-worker-visa/knowledge-of-english',
#  '/guidance/eu-settlement-scheme-how-we-use-your-personal-information.pl',
#  '/browse/housing-local-services',
#  '/government/publications/employment-allowance-more-detailed-guidance/connected-companies-and-employment-allowance-further-guidance-for-employers-and-their-agents',
#  '/guidance/what-to-do-if-your-employee-has-more-than-1-job',
#  '/agency-workers-your-rights',
#  '/government/publications/universal-credit-and-couples-an-introduction/universal-credit-further-information-for-couples',
#  '/organise-citizenship-ceremony-council',
#  '/guidance/employing-bno-citizens-in-the-uk',
#  '/guidance/working-through-an-umbrella-company',
#  '/hmrc-internal-manuals/national-minimum-wage-manual/nmwm04010',
#  '/guidance/regulating-gcses-as-and-a-levels-guide-for-schools-and-colleges/reasonable-adjustments',
#  '/government/statistics/fit-notes-issued-by-gp-practices-england-december-2014-march-2017',
#  '/shared-parental-leave-and-pay',
#  '/government/publications/tax-credits-check-your-award-notice-tc602sn',
#  '/guidance/how-t-levels-are-funded',
#  '/guidance/renew-your-sia-licence',
#  '/government/collections/hm-revenue-and-customs-service-availability-and-issues',
#  '/government/publications/classification-of-public-bodies-information-and-guidance',
#  '/government/publications/access-to-work-guide-for-employers/access-to-work-factsheet-for-employers',
#  '/squatting-law/squatters-rights-to-property',
#  '/guidance/check-if-a-new-charity-is-the-best-option',
#  '/appeal-benefit-decision/at-the-hearing',
#  '/government/publications/form-d8-application-for-a-divorce-dissolution-or-to-apply-for-a-judicial-separation-order',
#  '/government/organisations/hm-revenue-customs/contact/repayments-where-to-send-claim-forms',
#  '/corporation-tax-rates/allowances-and-reliefs',
#  '/guidance/apprenticeship-funding-rules-for-training-providers/what-is-an-apprenticeship',
#  '/guidance/apply-to-have-your-qualifications-regulated',
#  '/driving-disqualifications',
#  '/guidance/housing-costs-for-18-to-21-year-olds',
#  '/apply-for-business-rate-relief/small-business-rate-relief',
#  '/government/publications/form-an-guidance',
#  ...}

# %%
len(results["pages_visited"])
# Out:
# 5629

# %%
len(results['paths_taken'])
# Out:
# 3

# %%
page_scores['ER'] = page_scores.pagePath.isin(er_pages)
colour = (page_scores.ER == True).map({True: 'background-color: black', False: ''})
# Comment out so that later cells run ok
# otherwise "Styling" causes errors
# page_scores = page_scores.style.apply(lambda s: colour)

# %% [markdown]
# ## Add columns to output
#
# Add additional information to csv output:
# - document type
# - document super type
# - number of sessions that visit this page
# - number of sessions where this page is an entrance hit
# - number of sessions where this page is an exit hit
# - number of sessions where this page is both an entrance and exit hit
# - how frequent the page occurs in the whole user journey

# %%
# create a df with `pagePath`: `documentType`, `sessionHitsAll`, `entranceHit`, `exitHit`, `entranceAndExitHit`
df_dict = {info['properties']['name']: [info['documentType'], info['sessionHitsAll'], info['entranceHit'], info['exitHit'], info['entranceAndExitHit']] for node, info in G.nodes(data=True)}
df_dict = {k:v for (k,v) in df_dict.items() if k in page_scores['pagePath'].tolist()}
df_info = pd.DataFrame.from_dict(df_dict, orient='index', columns=['documentType', 'sessionHitsAll', 'entranceHit', 'exitHit', 'entranceAndExitHit']).rename_axis('pagePath').reset_index()

# %%
# create a df with document supertypes
news_and_comms_doctypes = {'medical_safety_alert', 'drug_safety_update', 'news_article', 
                           'news_story', 'press_release', 'world_location_news_article', 
                           'world_news_story', 'fatality_notice', 'fatality_notice', 
                           'tax_tribunal_decision', 'utaac_decision', 'asylum_support_decision', 
                           'employment_appeal_tribunal_decision', 'employment_tribunal_decision', 
                           'employment_tribunal_decision', 'service_standard_report', 'cma_case', 
                           'decision', 'oral_statement', 'written_statement', 'authored_article', 
                           'correspondence', 'speech', 'government_response', 'case_study' 
}

service_doctypes = {'completed_transaction', 'local_transaction', 'form', 'calculator',
                    'smart_answer', 'simple_smart_answer', 'place', 'licence', 'step_by_step_nav', 
                    'transaction', 'answer', 'guide'
}

guidance_and_reg_doctypes = {'regulation', 'detailed_guide', 'manual', 'manual_section',
                             'guidance', 'map', 'calendar', 'statutory_guidance', 'notice',
                             'international_treaty', 'travel_advice', 'promotional', 
                             'international_development_fund', 'countryside_stewardship_grant',
                             'esi_fund', 'business_finance_support_scheme', 'statutory_instrument',
                             'hmrc_manual', 'standard'
}

policy_and_engage_doctypes = {'impact_assessment', 'policy_paper', 'open_consultation',
                              'policy_paper', 'closed_consultation', 'consultation_outcome',
                              'policy_and_engagement'  
}

research_and_stats_doctypes = {'dfid_research_output', 'independent_report', 'research', 
                               'statistics', 'national_statistics', 'statistics_announcement',
                               'national_statistics_announcement', 'official_statistics_announcement',
                               'statistical_data_set', 'official_statistics'
}

transparency_doctypes = {'transparency', 'corporate_report', 'foi_release', 'aaib_report',
                         'raib_report', 'maib_report'
}

document_type_dict = dict.fromkeys(list(set(df_info['documentType'])))

for docType, docSupertype in document_type_dict.items():
    if docType in news_and_comms_doctypes: 
        document_type_dict[docType] = 'news and communication'
    
    elif docType in service_doctypes:
        document_type_dict[docType] = 'services'
    
    elif docType in guidance_and_reg_doctypes:
        document_type_dict[docType] = 'guidance and regulation'
 
    elif docType in policy_and_engage_doctypes:
        document_type_dict[docType] = 'policy and engagement'
    
    elif docType in research_and_stats_doctypes:
        document_type_dict[docType] = 'research and statistics'
    
    elif docType in transparency_doctypes:
        document_type_dict[docType] = 'transparency'
    
    else: 
        document_type_dict[docType] = 'other' 

df_docSuper = pd.DataFrame(document_type_dict.items(), columns=['documentType', 'documentSupertype'])

# %%
# merge dfs 
df_merged = pd.merge(page_scores, df_info, on='pagePath')
df_merged = pd.merge(df_merged, df_docSuper, how='left')

# %%
# reoder and rename df columns 
df_merged = df_merged[['pagePath', 'documentType', 'documentSupertype', 'sessionHitsAll', 'entranceHit', 'exitHit', 'entranceAndExitHit', 'tfdf_max']]
# df_merged = df_merged.rename(columns={'pagePath': 'page path', 'documentType': 'document type', 'documentSupertype': 'document supertype', 'sessionHitsAll': 'number of sessions that visit this page', 'entranceHit': 'number of sessions where this page is an entrance hit', 'exitHit': 'number of sessions where this page is an exit hit', 'entranceAndExitHit': 'number of sessions where this page is both an entrance and exit hit', 'tfdf_max': 'how frequent the page occurs in the whole user journey'})
# DO NOT RENAME THE TDX_MAX COLUMN
df_merged = df_merged.rename(columns={'pagePath': 'page path', 'documentType': 'document type', 'documentSupertype': 'document supertype', 'sessionHitsAll': 'number of sessions that visit this page', 'entranceHit': 'number of sessions where this page is an entrance hit', 'exitHit': 'number of sessions where this page is an exit hit', 'entranceAndExitHit': 'number of sessions where this page is both an entrance and exit hit'})


# save df
df_merged.to_csv('./data/outputs/pages_ranked_with_data_replication.csv', index=False)
