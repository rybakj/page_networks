# %% [markdown]
# **Replication of** `page_view_approach_economic_recovery.ipynb`
#
# **Produces ranking based on the shortest path to (two) seed pages and degree centrality**

# %% [markdown]
# # Exploring the economic recovery whole user journey subgraph

# %% [markdown]
# This approach does not rely on the existing knowledge graph. It uses a functional graph based on page hit session data, to find a list of pages related to the economic recovery whole user journey (WUJ).
#
# ASSUMPTIONS:
# - A set of pre-defined pages have been removed from the economic recovery WUJ subgraph
# - Any pages with less than 10 session hits are removed from the economic recovery WUJ subgraph
# - Any pages with a shortest page path length equal to or greater than 3 from both `seed0` pages are removed from the economic recovery WUJ subgraph
# - Any pages where accumulated edge weight is equal to or lower than 20 are removed from the economic recovery WUJ subgraph
# - Any browse pages not related to the economic recovery WUJ are manually removed from the economic recovery WUJ subgraph
#
# OUTPUT:
# - A csv containing a list of pages related to the economic recovery WUJ. Sorted in ascending order in relation to a composite metric made up of: shortest page path from both `seed0` pages, and degree centrality.
#   - Additional columns to filter on are included: `document type`, `document supertype`, `number of sessions that visit this page`, `number of sessions where this page is an entrance hit`, `number of sessions where this page is an exit hit`, `distance from /browse/working/finding-job`, `distance from /topic/further-education-skills/apprenticeships`, `the number of pages a user moves to/from between this page and another page in the list`
#
# REQUIREMENTS:
# - Create the functional network by running `page_detector.ipynb`. Save `G` as a pickle file in `../../data/processed/functional_session_hit_directed_graph_er.gpickle`

# %% [markdown]
# ## Import statements

# %%
import os
from collections import Counter, defaultdict
from operator import itemgetter

# import gspread
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
from neo4j import GraphDatabase
from oauth2client.service_account import ServiceAccountCredentials
from tqdm.notebook import tqdm

# %% [markdown]
# ## Functions for coercing knowledge graph into NetworkX

# %%
def getSubgraph(q, parameters=None):

    '''
    Given a Cypher query q, this function queries the knowledge graph,
    returns the nodes and edges from this query, and uses them to construct
    a networkx graph.

    E.g. getSubgraph(r'MATCH (u:Cid)-[r:HYPERLINKS_TO]->(v:Cid) RETURN *')
         returns the structural graph.

    Optionally, can add in parameters (dictionary), allowing Python variables
    to be integrated into the Cypher query q.

    E.g.
        parameters = {}
        parameters['pages'] = ['a','list','of','stuff']
        q7 = f"""
        MATCH (u:Cid)-[r]-(v:Cid)
        WHERE u.name IN $pages AND v.name in $pages
        RETURN *
        """

        g7 = getSubgraph(q7, parameters)
    '''

    # get credentials
    # add to .secrets: export KG_PWD="<PASSWORD>"
    KG_PWD = os.getenv("KG_PWD")

    # create connection to knowledge graph
    driver = GraphDatabase.driver(
        "bolt+s://knowledge-graph.integration.govuk.digital:7687",
        auth=("neo4j", KG_PWD),
    )

    # run query on knowledge graph
    results = driver.session().run(q, parameters)

    # create networkx graph object
    G = nx.MultiDiGraph()

    # add nodes into networkx graph object
    nodes = list(results.graph()._nodes.values())
    print("Adding nodes\n")
    for node in tqdm(nodes):
        G.add_node(node.id, labels=node._labels, properties=node._properties)

    # add edges into networkx graph object
    rels = list(results.graph()._relationships.values())
    print("Adding edges\n")
    for rel in tqdm(rels):
        G.add_edge(
            rel.start_node.id,
            rel.end_node.id,
            key=rel.id,
            type=rel.type,
            properties=rel._properties,
        )

    return G


def showGraph(g):
    """
    Given a networkx graph g, this function visualises the graph.
    Do not use for a large g.
    """
    print(nx.info(g))
    nx.draw(g)

# %%
def getNoOfTruePages(g, economic_pages):
    """
    Calculate a proxy recall metric for the list of pages identified in a
    subgraph (when compared to the ground truth for the economic recovery pages).
    The output is the number of pages in the subgraph list that are present in
    the ground truth list.
    """

    # convert nodeIds to page path slug for the subgraph list
    subgraph_list = [node[0] for node in g.nodes(data=True)]

    # set up the ground truth list
    true_list = list(economic_pages)

    # how many pages are in the subgraph list that are also in the ground truth list
    return (len(true_list)) - (
        len([node for node in true_list if node not in subgraph_list])
    )

# %%
def getPagesNotInSubGraph(g):
    """
    Return a set of pages which are in the economic recovery pre-defined list
    (41 in total), but are not in the filtered subgraph list.
    """

    # list of pages manually defined in the economic recovery whole user journey
    true_list = list(economic_pages)

    # list of pages in the filtered subgraph list
    subgraph_list = [node[0] for node in g.nodes(data=True)]

    # the list of pages in the manually defined list not in the subgraph list
    return [node for node in true_list if node not in subgraph_list]

# %% [markdown]
# ## Pre-defined economic recovery subgraph

# %% [markdown]
# The pages (nodes) in the manually defined list for economic recovery (41 pages in total)

# %%
# Load worksheet of seed pages
er_seed_pages_ws = pd.read_excel("./2021-11-12 - Economic recovery pages.xlsx", sheet_name="Top pages")
er_seed_pages_ws.shape
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 # Load worksheet of seed pages
# ----> 2 er_seed_pages_ws = pd.read_excel("./2021-11-12 - Economic recovery pages.xlsx", sheet_name="Top pages")
#       3 er_seed_pages_ws.shape
#
# File ~\virual_envs_python\nlp_env\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\virual_envs_python\nlp_env\lib\site-packages\pandas\io\excel\_base.py:364, in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
#     362 if not isinstance(io, ExcelFile):
#     363     should_close = True
# --> 364     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#     365 elif engine and engine != io.engine:
#     366     raise ValueError(
#     367         "Engine should not be specified when passing "
#     368         "an ExcelFile - ExcelFile already has the engine set"
#     369     )
#
# File ~\virual_envs_python\nlp_env\lib\site-packages\pandas\io\excel\_base.py:1191, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options)
#    1189     ext = "xls"
#    1190 else:
# -> 1191     ext = inspect_excel_format(
#    1192         content_or_path=path_or_buffer, storage_options=storage_options
#    1193     )
#    1194     if ext is None:
#    1195         raise ValueError(
#    1196             "Excel file format cannot be determined, you must specify "
#    1197             "an engine manually."
#    1198         )
#
# File ~\virual_envs_python\nlp_env\lib\site-packages\pandas\io\excel\_base.py:1070, in inspect_excel_format(content_or_path, storage_options)
#    1067 if isinstance(content_or_path, bytes):
#    1068     content_or_path = BytesIO(content_or_path)
# -> 1070 with get_handle(
#    1071     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1072 ) as handle:
#    1073     stream = handle.handle
#    1074     stream.seek(0)
#
# File ~\virual_envs_python\nlp_env\lib\site-packages\pandas\io\common.py:711, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     702         handle = open(
#     703             handle,
#     704             ioargs.mode,
#    (...)
#     707             newline="",
#     708         )
#     709     else:
#     710         # Binary mode
# --> 711         handle = open(handle, ioargs.mode)
#     712     handles.append(handle)
#     714 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: './2021-11-12 - Economic recovery pages.xlsx'

# %%
er_seed_pages_table = er_seed_pages_ws.values.reshape(-1, 1)
er_seed_pages_table.shape

# %%
economics_pages_df = pd.DataFrame(er_seed_pages_table).dropna()

# %% [markdown]
# ## Exploring the economic recovery functional network

# %% [markdown]
# - 10631 nodes and 79985 edges
# - The page `/guidance/international-trade-products-and-schemes` which is in the manually defined graph, is **not** in this subgraph. This seems to be an old page (updated 2013) related to exporting agricultural products to the EU
# - The distribution of session hit data demonstrates that only 25% of the page paths have session hits over 8. The maximum number of session hit for a page path is 71667:
#     - Min: 1
#     - Max: 71667
#     - 25th percentile: 1
#     - 50th percentile: 2
#     - 75th percentile: 8

# %%
# import the NetworkX graph object
g = nx.read_gpickle(
#     "../../data/processed/functional_session_hit_directed_graph_er.gpickle"
    "./functional_session_hit_directed_graph_er.gpickle"
)

# number of nodes, number of edges
nx.info(g)
# Out:
# C:\Users\jbryb\AppData\Local\Temp\ipykernel_13104\3461170152.py:8: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(g)
# 'DiGraph with 10631 nodes and 79985 edges'

# %%
# how many of the 'true' economic recovery pages are in the functional graph?
economic_pages = economics_pages_df.values.reshape(-1,).tolist()

getNoOfTruePages(g, economic_pages)
# Out:
# 88

# %%
# which pages are in the economic recovery list but not in the subgraph list?
true_list = list(economic_pages)
subgraph_list = [node[0] for node in g.nodes(data=True)]
[node for node in true_list if node not in subgraph_list]
# Out:
# ['/guidance/international-trade-products-and-schemes',
#  '/guidance/international-trade-products-and-schemes',
#  '/campaigns/internationalisation-fund-for-english-businesses/']

# %%
# list of nodes
nodes_list = list(g.nodes(data=True))

# %% [markdown]
# ### Remove pages where edge weight is <= 20

# %% [markdown]
# Edge weight increases by 1 each time a user session visits page A to page B. Therefore, if edge weight is small, we assume the two pages are likely to not be associated with one another. This is because we assume that user's will visit similar pages in the same WUJ during the same session.
#
# Edge weight is equal to or less than 10:
# - 1473 nodes
# - 37/41
# - Pages not in the subgraph list: [`/guidance/recovery-loan-scheme`,
# `/find-driving-instructor-training`,
# `/guidance/international-trade-products-and-schemes`,
# `/how-to-claim-universal-credit`]
#
# Edge weight is equal to or less than 20:
# - 1253 nodes
# - 34/41
# - Pages not in the subgraph list: [`/guidance/international-trade-products-and-schemes`,
#  `/guidance/recovery-loan-scheme`,
#  `/find-driving-instructor-training`,
#  `/how-to-claim-universal-credit`,
#  `/government/collections/financial-support-for-businesses-during-coronavirus-covid-19`,
#  `/agricultural-skills-and-training`,
#  `/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19`]
#
# Edge weight is equal to or less than 30:
# - 1042 nodes
# - 32/41
# - Pages not in the subgraph list: [`/guidance/international-trade-products-and-schemes`,
#  `/guidance/recovery-loan-scheme`,
#  `/find-driving-instructor-training`,
#  `/how-to-claim-universal-credit`,
#  `/government/collections/financial-support-for-businesses-during-coronavirus-covid-19`,
#  `/agricultural-skills-and-training`,
#  `/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19`]

# %% [markdown]
# ### Save the subgraph list of pages that are related to the economic recovery whole user journey

# %% [markdown]
# From the above exploration, run this code to get a final subgraph related to the economic recovery whole user journey

# %%
# import the NetworkX graph object
g = nx.read_gpickle(
    "./functional_session_hit_directed_graph_er.gpickle"
)

# %%
nx.info(g)
# Out:
# C:\Users\jbryb\AppData\Local\Temp\ipykernel_13104\3034883828.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(g)
# 'DiGraph with 10631 nodes and 79985 edges'

# %%
# remove irrelevant nodes
g.remove_nodes_from(
    [
        "/prove-right-to-work",
        "/",
        "/request-copy-criminal-record",
        "/browse/working/state-pension",
        "/search/all",
        "/search",
        "/brexit",
        "/coronavirus",
        "/report-covid19-result",
    ]
)

# %%
nx.info(g)
# Out:
# C:\Users\jbryb\AppData\Local\Temp\ipykernel_13104\3034883828.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(g)
# 'DiGraph with 10622 nodes and 67524 edges'

# %%
# remove pages with equal or less than 10 session hits
remove = [
    node for node, session in g.nodes(data=True) if session["sessionHitsAll"] <= 10
]
g.remove_nodes_from(remove)

# %%
# remove pages where they have a shortest page path length on >= 3 from both `seed0` pages
shortest_paths_seed0_1 = nx.shortest_path_length(
    g, source="/browse/working/finding-job"
)
shortest_paths_seed0_2 = nx.shortest_path_length(
    g, source="/topic/further-education-skills/apprenticeships"
)

finding_job = {
    k: v
    for k, v in sorted(
        shortest_paths_seed0_1.items(), key=lambda item: item[1], reverse=True
    )
}
apprentice = {
    k: v
    for k, v in sorted(
        shortest_paths_seed0_2.items(), key=lambda item: item[1], reverse=True
    )
}

finding_job_filtered = [node for node, length in finding_job.items() if length >= 3]
apprentice_filtered = [node for node, length in apprentice.items() if length >= 3]

remove = [node for node in finding_job_filtered if node not in apprentice_filtered]
g.remove_nodes_from(remove)

# %%
# remove pages where accumulated edge weight is equal to or lower than 20
user_movement_weights = []
for node1, node2, edgeWeight in g.edges(data=True):
    case = {"node1": node1, "node2": node2, "edgeWeight": edgeWeight["edgeWeight"]}
    user_movement_weights.append(case)

user_movements_sum = defaultdict(float)

for info in user_movement_weights:
    user_movements_sum[info["node1"]] += info["edgeWeight"]

user_movements_sum = [
    {"node1": node1, "edgeWeight": user_movements_sum[node1]}
    for node1 in user_movements_sum
]

remove = [node["node1"] for node in user_movements_sum if node["edgeWeight"] <= 20]
g.remove_nodes_from(remove)

# %%
# remove certain browse pages. Browse pages seem to score highly (when ranking, below),
# regardless of whether they are relevant to the WUJ or not
browse_pages_remove = (
    "/browse/employing-people",
    "/browse/births-deaths-marriages",
    "/browse/citizenship",
    "/browse/driving",
    "/browse/education",
    "/browse/business",
    "/browse/childcare-parenting",
    "/browse/justice",
    "/browse/abroad",
    "/browse/tax",
    "/browse/visas-immigration",
    "/browse/disabilities",
    "/browse/environment-countryside",
    "/browse/housing-local-services",
    "/browse/employing-people",
    "/browse/births-deaths-marriages",
    "/browse/citizenship",
    "/browse/driving",
    "/browse/business",
    "/browse/abroad",
    "/browse/environment-countryside",
    "/browse/housing-local-services",
    "/browse/benefits",
)

g.remove_nodes_from(browse_pages_remove)

# %%
nx.info(g)
# Out:
# C:\Users\jbryb\AppData\Local\Temp\ipykernel_13104\3034883828.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(g)
# 'DiGraph with 1338 nodes and 31143 edges'

# %%
# how many of economic recovery pages are in the functional graph?
getNoOfTruePages(g, economic_pages)
# Out:
# 77

# %%
# which pages are in the economic recovery list but not in the subgraph list?
getPagesNotInSubGraph(g)
# Out:
# ['/guidance/international-trade-products-and-schemes',
#  '/guidance/international-trade-products-and-schemes',
#  '/campaigns/internationalisation-fund-for-english-businesses/',
#  '/guidance/recovery-loan-scheme',
#  '/guidance/recovery-loan-scheme',
#  '/how-to-claim-universal-credit',
#  '/how-to-claim-universal-credit',
#  '/browse/education',
#  '/browse/education',
#  '/agricultural-skills-and-training',
#  '/education/further-and-higher-education-courses-and-qualifications',
#  '/agricultural-skills-and-training',
#  '/find-driving-instructor-training',
#  '/find-driving-instructor-training']

# %%
# final subgraph list related to the economic recovery whole user journey
economic_recovery_subgraph = list(g.nodes(data=True))

# %%
# save subgraph to file
# nx.write_gpickle(
#     g, "../../data/processed/functional_session_hit_directed_graph_er_final.gpickle"
# )

# %% [markdown]
# ### Explore communities of the subgraph

# %% [markdown]
# Look at adjacent neighbours, to identify communities within the WUJ. While there seems to be relevant pages within a community (e.g. `/find-a-job` and `/contact-jobcentre-plus`), other pages seem to be irrelevant (e.g. `/find-a-job` and `/check-mot-status`)

# %%
# create a dict of all nodes and it's edges
dict_of_nodes_and_edges = dict()
for node in g.nodes():
    dict_of_nodes_and_edges[node] = list(nx.neighbors(g, node))

    # sort dict based on the length of its' values (i.e. top result is the largest number of neighbours)
sorted(dict_of_nodes_and_edges.items(), key=lambda x: len(x[1]), reverse=True)
# Out:
# [('/find-a-job',
#   ['/sign-in-universal-credit',
#    '/browse/working/finding-job',
#    '/advertise-job',
#    '/contact-jobcentre-plus',
#    '/universal-credit',
#    '/apply-apprenticeship',
#    '/jobseekers-allowance',
#    '/browse/working',
#    '/browse/benefits/looking-for-work',
#    '/coronavirus/worker-support',
#    '/government/organisations/department-for-work-pensions',
#    '/government/organisations/department-for-work-pensions/about/recruitment',
#    '/find-internship',
#    '/chwilio-am-swydd',
#    '/national-minimum-wage-rates',
#    '/guidance/free-courses-for-jobs',
#    '/personal-tax-account',
#    '/log-in-register-hmrc-online-services',
#    '/skilled-worker-visa',
#    '/government/organisations/hm-revenue-customs/about/recruitment',
#    '/find-traineeship',
#    '/government/collections/kickstart-scheme',
#    '/benefits-calculators',
#    '/find-coronavirus-support',
#    '/check-mot-history',
#    '/government/organisations/hm-revenue-customs',
#    '/government/organisations',
#    '/employment/finding-job',
#    '/jobseekers-allowance/eligibility',
#    '/jobseekers-allowance/your-jsa-claim',
#    '/government/publications/register-of-licensed-sponsors-workers',
#    '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes',
#    '/government/organisations/companies-house',
#    '/estimate-income-tax',
#    '/book-theory-test',
#    '/guidance/red-amber-and-green-list-rules-for-entering-england',
#    '/help',
#    '/travel-abroad',
#    '/topic/further-education-skills/apprenticeships',
#    '/student-finance-register-login',
#    '/universal-credit/what-youll-get',
#    '/government/organisations/civil-service/about/recruitment',
#    '/government/publications/the-national-minimum-wage-in-2021',
#    '/jobseekers-allowance/report-a-change-of-circumstances',
#    '/guidance/apply-for-a-kickstart-scheme-grant',
#    '/browse/visas-immigration/work-visas',
#    '/guidance/universal-credit-advances',
#    '/apply-first-provisional-driving-licence',
#    '/moving-from-benefits-to-work',
#    '/become-apprentice',
#    '/career-skills-and-training',
#    '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers',
#    '/guidance/immigration-rules',
#    '/contact-jobcentre-plus/new-benefit-claims',
#    '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations',
#    '/jobcentre-plus-help-for-recruiters',
#    '/order-coronavirus-rapid-lateral-flow-tests',
#    '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do',
#    '/check-mot-status',
#    '/change-driving-test',
#    '/jobseekers-allowance/apply-new-style-jsa',
#    '/government/organisations/uk-visas-and-immigration',
#    '/apply-national-insurance-number',
#    '/check-uk-visa',
#    '/view-driving-licence',
#    '/provide-journey-contact-details-before-travel-uk',
#    '/check-vehicle-tax',
#    '/apply-universal-credit',
#    '/universal-credit/how-your-earnings-affect-your-payments',
#    '/vehicle-tax',
#    '/find-local-council',
#    '/dbs-update-service',
#    '/view-prove-immigration-status',
#    '/manage-your-tax-credits',
#    '/pip',
#    '/guidance/redundancy-help-finding-work-and-claiming-benefits',
#    '/looking-for-work-if-disabled',
#    '/intensive-personalised-employment-support',
#    '/book-driving-test',
#    '/topic/work-careers/government-graduate-schemes',
#    '/lost-national-insurance-number',
#    '/government/publications/skilled-worker-visa-shortage-occupations',
#    '/employment-support-allowance',
#    '/universal-credit/other-financial-support',
#    '/council-tax-bands',
#    '/government/organisations/home-office',
#    '/benefit-cap',
#    '/carers-allowance',
#    '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme',
#    '/contact-jobcentre-plus/existing-benefit-claims',
#    '/register-to-vote',
#    '/search/services',
#    '/government/organisations/home-office/about/recruitment',
#    '/government/organisations/foreign-commonwealth-development-office',
#    '/contact-jobcentre-plus/change-cancel-appointment',
#    '/government/organisations/driver-and-vehicle-licensing-agency',
#    '/get-coronavirus-test',
#    '/universal-credit/contact-universal-credit',
#    '/government/organisations/disclosure-and-barring-service',
#    '/become-lorry-bus-driver',
#    '/tax-credits-calculator',
#    '/apply-renew-passport',
#    '/check-state-pension',
#    '/work-health-programme',
#    '/pension-credit',
#    '/pip/how-to-claim',
#    '/uk-visa-sponsorship-employers',
#    '/income-tax-rates',
#    '/government/publications/higher-and-degree-apprenticeships',
#    '/government/get-involved/take-part/volunteer',
#    '/contact-ukvi-inside-outside-uk',
#    '/minimum-wage-different-types-work/paid-an-annual-salary',
#    '/check-income-tax-current-year',
#    '/30-hours-free-childcare',
#    '/employment-support-allowance/how-to-claim',
#    '/apply-to-come-to-the-uk',
#    '/government/organisations/department-for-education',
#    '/mature-student-university-funding',
#    '/child-employment',
#    '/contact-the-dvla',
#    '/settled-status-eu-citizens-families',
#    '/health-care-worker-visa',
#    '/further-education-courses/financial-help',
#    '/government/publications/united-kingdom-security-vetting-clearance-levels/national-security-vetting-clearance-levels',
#    '/government/publications/test-and-trace-support-payment-scheme-claiming-financial-support/claiming-financial-support-under-the-test-and-trace-support-payment-scheme',
#    '/universal-credit/eligibility',
#    '/government/organisations/hm-revenue-customs/contact/national-insurance-numbers',
#    '/state-pension-age',
#    '/exchange-foreign-driving-licence',
#    '/council-housing',
#    '/access-to-work',
#    '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means',
#    '/british-national-overseas-bno-visa',
#    '/government/collections/helping-young-people-into-work',
#    '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers',
#    '/foreign-travel-advice',
#    '/log-in-hmrc-excise-import-export',
#    '/bank-holidays',
#    '/government/topical-events/plan-for-jobs',
#    '/renew-adult-passport',
#    '/find-postgraduate-teacher-training-courses',
#    '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees',
#    '/skilled-worker-visa/your-job',
#    '/budgeting-help-benefits/how-to-apply',
#    '/housing-benefit/what-youll-get',
#    '/access-to-work/eligibility',
#    '/guidance/immigration-rules/immigration-rules-appendix-shortage-occupation-list',
#    '/universal-credit/how-to-claim',
#    '/moving-from-benefits-to-work/job-search-programmes',
#    '/browse/abroad/passports',
#    '/working-for-yourself',
#    '/set-up-sole-trader',
#    '/government/publications/jobseekers-allowance-sanctions-leaflet/jobseekers-allowance-sanctions-how-to-keep-your-benefit-payment',
#    '/how-to-claim-new-style-jsa',
#    '/government/organisations/student-loans-company',
#    '/moving-from-benefits-to-work/starting-your-own-business',
#    '/contact-hmrc',
#    '/guidance/new-immigration-system-what-you-need-to-know',
#    '/further-education-courses/find-a-course',
#    '/get-information-about-a-company',
#    '/carers-allowance/effect-on-other-benefits',
#    '/get-help-savings-low-income',
#    '/uk-border-control',
#    '/report-benefits-change-circumstances',
#    '/search/research-and-statistics',
#    '/government/collections/new-enterprise-allowance-campaign',
#    '/government/organisations/foreign-commonwealth-office',
#    '/guidance/academic-technology-approval-scheme',
#    '/browse/working/contract-working-hours',
#    '/advanced-learner-loan',
#    '/apply-for-council-housing',
#    '/browse/employing-people/contracts',
#    '/browse/benefits/manage-your-benefit',
#    '/student-jobs-paying-tax',
#    '/order-copy-birth-death-marriage-certificate',
#    '/guidance/track-a-dbs-application',
#    '/guidance/national-skills-fund',
#    '/browse/business/setting-up',
#    '/carers-allowance/how-to-claim',
#    '/standard-visitor-visa/apply',
#    '/income-tax',
#    '/pip/what-youll-get',
#    '/housing-and-universal-credit/renting-from-private-landlord',
#    '/personal-tax-account/sign-in/prove-identity',
#    '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults',
#    '/sign-in-help-to-save',
#    '/search/news-and-communications',
#    '/rest-breaks-work',
#    '/claim-tax-refund',
#    '/settle-in-the-uk',
#    '/government/collections/traineeships--2',
#    '/browse/employing-people/recruiting-hiring',
#    '/student-finance',
#    '/employee-immigration-employment-status',
#    '/set-up-business',
#    '/log-in-register-hmrc-online-services/register',
#    '/self-employment-and-universal-credit',
#    '/pip/change-of-circumstances',
#    '/skilled-worker-visa/how-much-it-costs',
#    '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403',
#    '/calculate-your-redundancy-pay',
#    '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022',
#    '/new-state-pension/what-youll-get',
#    '/sign-in-childcare-account',
#    '/government/publications/find-a-free-level-3-qualification/list-of-colleges-and-training-providers-able-to-offer-free-places-for-level-3-qualifications',
#    '/employment-rights-for-interns',
#    '/employment-support-allowance/eligibility',
#    '/government/organisations/hm-revenue-customs/contact',
#    '/renew-driving-licence',
#    '/national-minimum-wage',
#    '/government/publications/universal-credit-work-allowances/universal-credit-work-allowances',
#    '/check-job-applicant-right-to-work',
#    '/higher-education-courses-find-and-apply',
#    '/working-tax-credit',
#    '/bills-benefits',
#    '/am-i-getting-minimum-wage',
#    '/uk-visa-sponsorship-employers/certificates-of-sponsorship',
#    '/job-offers-your-rights',
#    '/courses-qualifications',
#    '/budgeting-help-benefits/eligibility',
#    '/paye-forms-p45-p60-p11d/p60',
#    '/sunday-working',
#    '/government/publications/skilled-worker-visa-eligible-healthcare-and-education-jobs',
#    '/your-employment-contract-how-it-can-be-changed/dealing-with-problems',
#    '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant',
#    '/skilled-worker-visa/when-you-can-be-paid-less',
#    '/guidance/how-to-quarantine-when-you-arrive-in-england',
#    '/government/collections/desg-graduate-scheme',
#    '/find-pension-centre',
#    '/employment-support-allowance/working-while-you-claim',
#    '/biometric-residence-permits/report-problem',
#    '/guidance/dvla-coronavirus-covid-19-update',
#    '/browse/visas-immigration/commonwealth-british-nationals-overseas',
#    '/uk-visa-sponsorship-employers/eligibility',
#    '/disability-living-allowance-children/rates',
#    '/recruit-apprentice',
#    '/dla-disability-living-allowance-benefit',
#    '/browse/education/universities-higher-education',
#    '/government/organisations/hm-revenue-customs/contact/child-benefit',
#    '/student-finance/who-qualifies',
#    '/repaying-your-student-loan',
#    '/find-lost-utr-number',
#    '/guidance/contact-the-department-for-work-and-pensions-about-its-policies',
#    '/national-insurance-credits/eligibility',
#    '/carers-credit/eligibility',
#    '/health-care-worker-visa/your-job',
#    '/moving-or-retiring-abroad',
#    '/paye-forms-p45-p60-p11d',
#    '/id-for-driving-licence',
#    '/national-insurance/how-much-you-pay',
#    '/uk-family-visa/partner-spouse',
#    '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member',
#    '/uk-family-visa',
#    '/guidance/recruiting-people-from-outside-the-uk',
#    '/budgeting-help-benefits',
#    '/start-up-visa',
#    '/international-agreement-worker-visa',
#    '/national-insurance',
#    '/fixed-term-contracts',
#    '/what-different-qualification-levels-mean/list-of-qualification-levels',
#    '/guidance/new-style-jobseekers-allowance',
#    '/browse/disabilities/work',
#    '/employment-support-allowance/your-esa-claim',
#    '/government/publications/qualifications-in-new-funded-offers',
#    '/when-is-your-next-tax-credits-payment',
#    '/childcare-calculator',
#    '/guidance/nhs-covid-pass',
#    '/night-working-hours',
#    '/report-benefit-fraud',
#    '/cold-weather-payment/eligibility',
#    '/business-finance-support',
#    '/government/publications/dbs-application-forms-guide-for-applicants',
#    '/find-a-regulated-qualification',
#    '/apply-blue-badge',
#    '/child-benefit',
#    '/child-tax-credit',
#    '/dismissal',
#    '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide',
#    '/frontier-worker-permit',
#    '/carers-allowance/eligibility',
#    '/topic/personal-tax/national-insurance',
#    '/self-assessment-tax-returns',
#    '/part-time-worker-rights',
#    '/new-state-pension',
#    '/government/publications/paye-starter-checklist',
#    '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships',
#    '/browse/driving/driving-licences',
#    '/browse/working/tax-minimum-wage',
#    '/student-visa/extend-your-visa',
#    '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens',
#    '/redundancy-your-rights/consultation',
#    '/statutory-sick-pay',
#    '/settled-status-eu-citizens-families/applying-for-settled-status',
#    '/looking-for-work-if-disabled/applying-for-a-job',
#    '/browse/visas-immigration/tourist-short-stay-visas',
#    '/search/guidance-and-regulation',
#    '/topic/work-careers/secondments-with-government',
#    '/government/publications/right-to-work-checklist',
#    '/what-is-the-construction-industry-scheme',
#    '/register-for-self-assessment/self-employed',
#    '/right-to-reside',
#    '/browse/visas-immigration/family-visas',
#    '/foreign-travel-advice/france',
#    '/track-your-driving-licence-application',
#    '/browse/disabilities/equipment',
#    '/guidance/national-minimum-wage-work-experience-and-internships',
#    '/guidance/return-to-your-claim-for-the-self-employment-income-support-scheme',
#    '/business-support-helpline',
#    '/temporary-worker-charity-worker-visa',
#    '/work-reference',
#    '/guidance/temporary-jobcentres-during-the-coronavirus-covid-19-pandemic',
#    '/improve-english-maths-it-skills',
#    '/skilled-worker-visa/apply-from-outside-the-uk',
#    '/what-different-qualification-levels-mean',
#    '/government/organisations/department-of-health-and-social-care',
#    '/apply-council-tax-reduction',
#    '/guidance/coronavirus-covid-19-advice-for-uk-visa-applicants-and-temporary-uk-residents',
#    '/statutory-sick-pay/how-to-claim',
#    '/national-insurance/your-national-insurance-number',
#    '/employment-contracts-and-conditions',
#    '/government/publications/traineeship-providers',
#    '/sure-start-maternity-grant',
#    '/calculate-employee-redundancy-pay',
#    '/government/organisations/hm-revenue-customs/services-information',
#    '/guidance/coronavirus-covid-19-what-to-do-if-youre-employed-and-cannot-work',
#    '/government/publications/your-new-state-pension-explained/your-state-pension-explained',
#    '/employing-staff',
#    '/check-national-insurance-record',
#    '/browse/visas-immigration/eu-eea-swiss',
#    '/become-magistrate',
#    '/tax-free-childcare',
#    '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa',
#    '/browse/childcare-parenting/financial-help-children',
#    '/housing-benefit/how-to-claim',
#    '/view-right-to-work',
#    '/guidance/working-safely-during-covid-19',
#    '/government/organisations/hm-revenue-customs/contact/get-help-with-the-self-employment-income-support-scheme',
#    '/running-payroll',
#    '/browse/education/find-course',
#    '/driving-lessons-learning-to-drive',
#    '/driving-nongb-licence',
#    '/guidance/plan-for-jobs-skills-and-employment-programmes-information-for-employers',
#    '/guidance/help-employers-apply-for-a-kickstart-scheme-grant-kickstart-gateway',
#    '/government/publications/eu-settlement-scheme-application-processing-times',
#    '/driving-medical-conditions',
#    '/government-authorised-exchange',
#    '/grant-bursary-adult-learners',
#    '/the-warm-home-discount-scheme',
#    '/employers-checks-job-applicants',
#    '/government/organisations/hm-revenue-customs/contact/self-assessment',
#    '/coronavirus/business-support',
#    '/help-with-childcare-costs',
#    '/find-pension-contact-details',
#    '/become-apprentice/pay-and-conditions',
#    '/standard-visitor-visa/eligibility',
#    '/employment-status/selfemployed-contractor',
#    '/learner-support',
#    '/flexible-working',
#    '/apply-start-up-loan',
#    '/income-support',
#    '/youth-mobility',
#    '/guidance/rehabilitation-periods',
#    '/how-to-have-your-benefits-paid',
#    '/further-education-courses',
#    '/pip/when-your-pip-claim-is-reviewed',
#    '/student-visa/money',
#    '/guidance/booking-and-staying-in-a-quarantine-hotel-when-you-arrive-in-england',
#    '/claim-tax-credits',
#    '/foreign-travel-advice/spain',
#    '/definition-of-disability-under-equality-act-2010',
#    '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments',
#    '/apply-online-to-replace-a-driving-licence',
#    '/disability-living-allowance-children',
#    '/help/terms-conditions',
#    '/claim-redundancy',
#    '/browse/working/time-off',
#    '/browse/visas-immigration/arriving-in-the-uk',
#    '/volunteering',
#    '/national-insurance-credits',
#    '/get-a-passport-urgently',
#    '/jobsearch-rights',
#    '/government/publications/employment-and-support-allowance-permitted-work-form/permitted-work-factsheet',
#    '/employment-status/worker',
#    '/tell-dvla-changed-address',
#    '/employer-relocation-your-rights',
#    '/employment-support-allowance/what-youll-get',
#    '/passport-fees',
#    '/housing-benefit',
#    '/know-when-you-can-leave-school',
#    '/browse/driving/learning-to-drive',
#    '/redundancy-your-rights',
#    '/maternity-allowance/how-to-claim',
#    '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes',
#    '/uk-residence-card',
#    '/child-employment/restrictions-on-child-employment',
#    '/browse/citizenship/citizenship',
#    '/find-travel-test-provider',
#    '/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work',
#    '/flexible-working/applying-for-flexible-working',
#    '/child-trust-funds',
#    '/benefit-overpayments/how-to-make-a-repayment',
#    '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions',
#    '/government/organisations/department-for-work-pensions/about',
#    '/guidance/visa-decision-waiting-times-applications-inside-the-uk']),
#  ('/contact-jobcentre-plus',
#   ['/find-a-job',
#    '/contact-jobcentre-plus/new-benefit-claims',
#    '/contact-jobcentre-plus/existing-benefit-claims',
#    '/advertise-job',
#    '/contact-jobcentre-plus/change-cancel-appointment',
#    '/universal-credit',
#    '/browse/working/finding-job',
#    '/sign-in-universal-credit',
#    '/government/organisations/department-for-work-pensions',
#    '/apply-national-insurance-number',
#    '/employment-support-allowance',
#    '/jobcentre-plus-help-for-recruiters',
#    '/lost-national-insurance-number',
#    '/government/organisations/department-for-work-pensions/about/complaints-procedure',
#    '/national-insurance-credits/eligibility',
#    '/jobseekers-allowance',
#    '/universal-credit/contact-universal-credit',
#    '/moving-from-benefits-to-work/starting-your-own-business',
#    '/become-appointee-for-someone-claiming-benefits',
#    '/disability-premiums/how-to-claim',
#    '/jobseekers-allowance/eligibility',
#    '/browse/working',
#    '/sure-start-maternity-grant/how-to-claim',
#    '/budgeting-help-benefits/other-help-you-can-get',
#    '/budgeting-help-benefits/how-to-apply',
#    '/bills-benefits',
#    '/guidance/universal-credit-advances',
#    '/jobseekers-allowance/report-a-change-of-circumstances',
#    '/employment-support-allowance/change-of-circumstances',
#    '/universal-credit/eligibility',
#    '/contact-pension-service',
#    '/jobseekers-allowance/your-jsa-claim',
#    '/reasonable-adjustments-for-disabled-workers',
#    '/guidance/temporary-jobcentres-during-the-coronavirus-covid-19-pandemic',
#    '/government/organisations',
#    '/work-health-programme',
#    '/government/organisations/hm-revenue-customs/contact/national-insurance-numbers',
#    '/over-80-pension/how-to-claim',
#    '/access-to-work',
#    '/government/organisations/hm-revenue-customs/contact',
#    '/budgeting-help-benefits',
#    '/claim-benefits-abroad',
#    '/intensive-personalised-employment-support',
#    '/benefits-calculators',
#    '/apply-universal-credit',
#    '/jobseekers-allowance/apply-new-style-jsa',
#    '/carers-allowance/if-youre-working-',
#    '/government/organisations/hm-revenue-customs',
#    '/help',
#    '/guidance/free-courses-for-jobs',
#    '/employment-support-allowance/how-to-claim',
#    '/contact-ukvi-inside-outside-uk',
#    '/universal-credit/what-youll-get',
#    '/find-local-council',
#    '/guidance/get-help-with-benefits-and-pensions-if-you-have-accessibility-needs',
#    '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals',
#    '/contact-the-dvla',
#    '/government/organisations/department-for-work-pensions/about/recruitment',
#    '/apply-start-up-loan',
#    '/apply-apprenticeship',
#    '/search/services',
#    '/income-support',
#    '/benefit-overpayments',
#    '/universal-credit/other-financial-support',
#    '/government/collections/kickstart-scheme',
#    '/government/publications/dwp-jobcentre-register',
#    '/incapacity-benefit',
#    '/report-benefit-fraud',
#    '/maternity-allowance',
#    '/moving-from-benefits-to-work',
#    '/government/organisations/companies-house',
#    '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions',
#    '/benefit-overpayments/when-repayments-have-to-be-made',
#    '/budgeting-help-benefits/eligibility',
#    '/tax-right-retire-abroad-return-to-uk',
#    '/pip/how-to-claim',
#    '/browse/benefits/looking-for-work',
#    '/benefit-overpayments/how-to-make-a-repayment',
#    '/carers-allowance-unit',
#    '/contact-hmrc',
#    '/register-birth',
#    '/career-skills-and-training',
#    '/universal-credit/how-to-claim',
#    '/government/collections/new-enterprise-allowance-campaign',
#    '/employment-support-allowance/eligibility',
#    '/guidance/new-style-jobseekers-allowance',
#    '/maternity-allowance/eligibility',
#    '/check-national-insurance-record',
#    '/moving-from-benefits-to-work/support-when-you-start-working',
#    '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers',
#    '/log-in-register-hmrc-online-services',
#    '/view-prove-immigration-status',
#    '/guidance/contact-the-department-for-work-and-pensions-about-its-policies',
#    '/jobsearch-rights',
#    '/government/organisations/department-for-work-pensions/about',
#    '/report-benefits-change-circumstances',
#    '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries',
#    '/cold-weather-payment/how-to-claim',
#    '/employment-support-allowance/your-esa-claim',
#    '/statutory-sick-pay',
#    '/moving-from-benefits-to-work/work-experience-and-volunteering',
#    '/government/collections/helping-young-people-into-work',
#    '/disability-benefits-helpline',
#    '/find-traineeship',
#    '/looking-for-work-if-disabled',
#    '/pip/change-of-circumstances',
#    '/become-lorry-bus-driver',
#    '/national-insurance-credits',
#    '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403',
#    '/working-tax-credit',
#    '/government/publications/budgeting-loan-claim-form',
#    '/maternity-allowance/how-to-claim',
#    '/how-to-claim-new-style-jsa',
#    '/access-to-work/apply',
#    '/statutory-sick-pay/how-to-claim',
#    '/support-visit-benefit-claim',
#    '/carers-allowance',
#    '/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance',
#    '/send-fit-note',
#    '/pension-credit',
#    '/voluntary-national-insurance-contributions',
#    '/fraud-error-prevention-centres',
#    '/check-state-pension',
#    '/government/publications/maternity-allowance-claim-form',
#    '/disability-premiums',
#    '/budgeting-help-benefits/after-you-apply',
#    '/government/publications/statutory-sick-pay-employee-not-entitled-form-for-employers',
#    '/dla-disability-living-allowance-benefit',
#    '/grant-bursary-adult-learners',
#    '/how-to-have-your-benefits-paid',
#    '/pip',
#    '/national-insurance/your-national-insurance-number',
#    '/30-hours-free-childcare',
#    '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme',
#    '/payment-exception-service',
#    '/housing-and-universal-credit/renting-from-private-landlord',
#    '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers',
#    '/help/terms-conditions',
#    '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees',
#    '/housing-benefit',
#    '/over-80-pension',
#    '/further-education-courses/financial-help',
#    '/browse/benefits/low-income',
#    '/job-offers-your-rights',
#    '/pension-credit-calculator',
#    '/student-finance-register-login',
#    '/moving-from-benefits-to-work/help-for-parents-and-carers',
#    '/carers-allowance/further-information',
#    '/skilled-worker-visa',
#    '/guidance/apply-for-a-kickstart-scheme-grant',
#    '/employment-support-allowance/what-youll-get',
#    '/government/publications/sure-start-maternity-grant-claim-form',
#    '/the-warm-home-discount-scheme',
#    '/check-mot-status',
#    '/bereavement-support-payment/how-to-claim',
#    '/find-pension-centre',
#    '/working-for-yourself',
#    '/apply-for-council-housing',
#    '/carers-credit',
#    '/government/publications/employing-disabled-people-and-people-with-health-conditions/employing-disabled-people-and-people-with-health-conditions',
#    '/bank-holidays',
#    '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments',
#    '/apply-blue-badge',
#    '/government/publications/test-and-trace-support-payment-scheme-claiming-financial-support/claiming-financial-support-under-the-test-and-trace-support-payment-scheme',
#    '/renew-driving-licence',
#    '/national-minimum-wage-rates',
#    '/carers-allowance/eligibility',
#    '/universal-credit/changes-of-circumstances',
#    '/government/organisations/hm-revenue-customs/contact/change-your-personal-details',
#    '/disability-premiums/eligibility',
#    '/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2',
#    '/carers-credit/how-to-claim',
#    '/income-support/report-a-change-of-circumstances',
#    '/universal-credit/get-an-advance-first-payment',
#    '/government/publications/qualifications-in-new-funded-offers',
#    '/browse/abroad/passports',
#    '/tax-credits-overpayments',
#    '/budgeting-help-benefits/repayments',
#    '/call-charges',
#    '/guidance/new-style-employment-and-support-allowance',
#    '/mature-student-university-funding',
#    '/browse/benefits/manage-your-benefit',
#    '/maternity-pay-leave',
#    '/housing-and-universal-credit',
#    '/government/publications/attendance-allowance-claim-form',
#    '/childcare-grant',
#    '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships',
#    '/benefit-fraud',
#    '/child-benefit-tax-calculator',
#    '/deferring-state-pension/what-you-get',
#    '/guidance/statutory-sick-pay-employee-fitness-to-work',
#    '/income-support/income-support-rates',
#    '/book-driving-test',
#    '/marriage-allowance',
#    '/employer-preventing-discrimination',
#    '/get-information-about-a-company',
#    '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults',
#    '/settled-status-eu-citizens-families/applying-for-settled-status',
#    '/guidance/claim-a-grant-through-the-self-employment-income-support-scheme',
#    '/get-help-hmrc-extra-support',
#    '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations',
#    '/search/research-and-statistics',
#    '/claim-benefits-abroad/jobseekers-allowance',
#    '/guidance/using-the-uk-immigration-id-check-app',
#    '/mandatory-reconsideration',
#    '/sure-start-maternity-grant/what-youll-get',
#    '/guidance/benefits-and-pensions-for-uk-nationals-in-the-eea-or-switzerland',
#    '/check-vehicle-tax',
#    '/order-coronavirus-rapid-lateral-flow-tests',
#    '/apply-housing-benefit-from-council',
#    '/work-reference',
#    '/browse/employing-people/trade-unions',
#    '/disability-premiums/what-youll-get',
#    '/check-income-tax-current-year',
#    '/get-proof-employment-history',
#    '/browse/benefits/help-for-carers',
#    '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed',
#    '/employers-sick-pay',
#    '/cold-weather-payment/eligibility',
#    '/government/publications/public-funds--2',
#    '/guidance/red-amber-and-green-list-rules-for-entering-england',
#    '/government/organisations/foreign-commonwealth-development-office',
#    '/sure-start-maternity-grant/eligibility',
#    '/government/publications/child-benefit-claim-form-ch2',
#    '/set-up-sole-trader',
#    '/search/guidance-and-regulation',
#    '/browse/employing-people/recruiting-hiring',
#    '/additional-state-pension',
#    '/severe-disablement-allowance',
#    '/self-employed-records/what-records-to-keep',
#    '/set-up-self-employed',
#    '/sure-start-maternity-grant',
#    '/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19',
#    '/over-80-pension/further-information',
#    '/tell-dvla-changed-address',
#    '/financial-help-disabled/disability-and-sickness-benefits',
#    '/employment-support-allowance/working-while-you-claim',
#    '/bereavement-support-payment',
#    '/working-tax-credit/how-to-claim',
#    '/apply-marriage-allowance',
#    '/jobcentre-plus-help-for-recruiters/work-trials',
#    '/improve-english-maths-it-skills',
#    '/employment-rights-for-interns',
#    '/manage-your-tax-credits',
#    '/employing-an-apprentice',
#    '/attendance-allowance/eligibility',
#    '/foreign-travel-advice',
#    '/student-finance',
#    '/financial-help-disabled',
#    '/after-a-death/organisations-you-need-to-contact-and-tell-us-once',
#    '/government/organisations/hm-revenue-customs/contact/online-services-helpdesk',
#    '/access-to-work/eligibility',
#    '/carers-allowance/effect-on-other-benefits',
#    '/moving-from-benefits-to-work/job-search-programmes',
#    '/biometric-residence-permits',
#    '/new-state-pension/your-national-insurance-record-and-your-state-pension',
#    '/claim-tax-refund',
#    '/new-state-pension/what-youll-get',
#    '/set-up-business',
#    '/pip/what-youll-get',
#    '/check-income-tax-last-year',
#    '/voluntary-national-insurance-contributions/deadlines',
#    '/budgeting-help-benefits/what-youll-get',
#    '/government/organisations/department-of-social-security',
#    '/council-housing',
#    '/national-insurance/help-if-youre-not-working',
#    '/browse/tax/national-insurance',
#    '/guidance/visa-decision-waiting-times-applications-inside-the-uk',
#    '/coronavirus/worker-support',
#    '/book-theory-test',
#    '/settled-status-eu-citizens-families/eligibility',
#    '/government/publications/capability-for-work-questionnaire',
#    '/order-copy-birth-death-marriage-certificate',
#    '/government/organisations/department-for-education',
#    '/early-retirement-pension/personal-and-workplace-pensions',
#    '/business-finance-support',
#    '/child-employment',
#    '/get-tax-free-childcare',
#    '/tax-credits-calculator',
#    '/change-address-driving-licence',
#    '/child-benefit/what-youll-get',
#    '/deferring-state-pension/how-to-claim-a-deferred-state-pension',
#    '/employment-status/worker',
#    '/jobcentre-plus-help-for-recruiters/other-employment-schemes',
#    '/find-travel-test-provider',
#    '/government/publications/the-official-hmrc-app',
#    '/employers-checks-job-applicants',
#    '/paternity-pay-leave/pay',
#    '/redundancy-your-rights/get-help-finding-a-new-job',
#    '/government/publications/income-tax-leaving-the-uk-getting-your-tax-right-p85',
#    '/browse/childcare-parenting/childcare',
#    '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022',
#    '/employers-sick-pay/eligibility-and-form-ssp1',
#    '/national-insurance',
#    '/government/publications/the-national-minimum-wage-in-2021',
#    '/education/apprenticeships-traineeships-and-internships',
#    '/guidance/indefinite-leave-to-remain-in-the-uk',
#    '/maternity-pay-leave/how-to-claim',
#    '/browse/benefits/unable-to-work',
#    '/cold-weather-payment',
#    '/dismissal',
#    '/government/publications/right-to-work-checks-employers-guide',
#    '/child-benefit-move-to-uk',
#    '/childcare-calculator',
#    '/universal-credit/how-youre-paid',
#    '/how-to-claim-new-style-esa',
#    '/browse/visas-immigration/settle-in-the-uk',
#    '/the-warm-home-discount-scheme/energy-suppliers',
#    '/state-pension',
#    '/state-pension/circumstances-change',
#    '/guidance/travel-abroad-from-england-during-coronavirus-covid-19',
#    '/government/publications/rates-and-allowances-national-insurance-contributions/rates-and-allowances-national-insurance-contributions',
#    '/browse/disabilities/work',
#    '/test-and-trace-support-payment']),
#  ('/browse/working',
#   ['/browse/working/finding-job',
#    '/browse/working/workplace-personal-pensions',
#    '/browse/working/tax-minimum-wage',
#    '/browse/working/time-off',
#    '/browse/working/contract-working-hours',
#    '/browse/working/rights-trade-unions',
#    '/browse/working/redundancies-dismissals',
#    '/browse/working/armed-forces',
#    '/find-a-job',
#    '/contact-jobcentre-plus',
#    '/view-prove-immigration-status',
#    '/government/organisations',
#    '/state-pension-age',
#    '/sign-in-universal-credit',
#    '/browse/visas-immigration/work-visas',
#    '/government/organisations/department-for-work-pensions',
#    '/help',
#    '/contact-pension-service',
#    '/log-in-register-hmrc-online-services',
#    '/check-job-applicant-right-to-work',
#    '/government/organisations/disclosure-and-barring-service',
#    '/new-state-pension',
#    '/guidance/red-amber-and-green-list-rules-for-entering-england',
#    '/personal-tax-account',
#    '/get-state-pension',
#    '/check-state-pension',
#    '/check-uk-visa',
#    '/new-state-pension/what-youll-get',
#    '/view-right-to-work',
#    '/jobseekers-allowance',
#    '/apply-apprenticeship',
#    '/check-state-pension/sign-in/prove-identity',
#    '/find-local-council',
#    '/browse/visas-immigration/what-you-need-to-do',
#    '/log-in-register-hmrc-online-services/register',
#    '/search/services',
#    '/state-pension/what-youll-get',
#    '/future-pension-centre',
#    '/browse/benefits/families',
#    '/plan-for-retirement',
#    '/browse/tax/national-insurance',
#    '/browse/citizenship/citizenship',
#    '/universal-credit/eligibility',
#    '/browse/visas-immigration/student-visas',
#    '/browse/visas-immigration/eu-eea-swiss',
#    '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do',
#    '/government/publications/register-of-licensed-sponsors-workers',
#    '/apply-to-come-to-the-uk',
#    '/national-insurance',
#    '/check-national-insurance-record',
#    '/contact-hmrc',
#    '/calculate-your-redundancy-pay',
#    '/government/organisations/hm-revenue-customs',
#    '/student-finance-register-login',
#    '/topic/further-education-skills/apprenticeships',
#    '/search/guidance-and-regulation',
#    '/guidance/contact-the-department-for-work-and-pensions-about-its-policies',
#    '/pension-credit/what-youll-get',
#    '/contact-ukvi-inside-outside-uk',
#    '/check-income-tax-current-year',
#    '/national-minimum-wage-rates',
#    '/browse/visas-immigration/family-visas',
#    '/universal-credit/contact-universal-credit',
#    '/browse/education/student-finance',
#    '/browse/childcare-parenting/schools-education',
#    '/career-skills-and-training',
#    '/guidance/universal-credit-advances',
#    '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations',
#    '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees',
#    '/government/organisations/hm-revenue-customs/contact/change-your-personal-details',
#    '/how-to-have-your-benefits-paid',
#    '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means',
#    '/right-to-reside',
#    '/log-in-file-self-assessment-tax-return/sign-in/prove-identity',
#    '/browse/citizenship/government',
#    '/staff-redundant',
#    '/apply-national-insurance-number',
#    '/guidance/brexit-guidance-for-individuals-and-families',
#    '/additional-state-pension',
#    '/calculate-your-holiday-entitlement',
#    '/topic/immigration-operational-guidance',
#    '/advertise-job',
#    '/guidance/immigration-rules',
#    '/statutory-sick-pay',
#    '/employment-contracts-and-conditions',
#    '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme',
#    '/additional-state-pension/inheriting',
#    '/government/publications/the-basic-state-pension',
#    '/browse/benefits/low-income',
#    '/dbs-update-service',
#    '/new-state-pension/youve-been-in-a-workplace-personal-or-stakeholder-pension',
#    '/coronavirus/worker-support',
#    '/criminal-record-checks-apply-role',
#    '/check-state-pension/sign-in/create-account',
#    '/topic/immigration-operational-guidance/immigration-rules',
#    '/browse/disabilities/work',
#    '/become-appointee-for-someone-claiming-benefits',
#    '/state-pension-through-partner',
#    '/sold-bought-vehicle',
#    '/claim-asylum',
#    '/pension-credit',
#    '/contracted-out/check-if-you-were-contracted-out',
#    '/employers-workplace-pensions-rules',
#    '/skilled-worker-visa/your-job',
#    '/find-coronavirus-support',
#    '/browse/visas-immigration/arriving-in-the-uk',
#    '/personal-pensions-your-rights/how-you-can-take-pension',
#    '/benefits-calculators',
#    '/contracted-out',
#    '/vehicles-can-drive',
#    '/browse/education/universities-higher-education',
#    '/check-vehicle-tax',
#    '/uk-visa-sponsorship-employers',
#    '/government/publications/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens-accessible-version',
#    '/government/organisations/hm-revenue-customs/contact/child-benefit',
#    '/browse/benefits/disability',
#    '/early-retirement-pension/benefits',
#    '/uk-family-visa',
#    '/redundancy-your-rights/notice-periods',
#    '/right-of-abode/commonwealth-citizens',
#    '/apply-standard-visitor-visa',
#    '/browse/visas-immigration/settle-in-the-uk',
#    '/tax-come-to-uk',
#    '/government/publications/skilled-worker-visa-shortage-occupations',
#    '/topic/work-careers/government-graduate-schemes',
#    '/the-warm-home-discount-scheme',
#    '/claim-benefits-abroad',
#    '/plan-retirement-income/get-financial-advice',
#    '/browse/education/school-admissions-transport',
#    '/employment-support-allowance',
#    '/visa-fees',
#    '/guidance/immigration-rules/immigration-rules-appendix-shortage-occupation-list',
#    '/employers-checks-job-applicants',
#    '/calculate-agricultural-holiday-entitlement',
#    '/contact-jobcentre-plus/existing-benefit-claims',
#    '/manage-your-tax-credits',
#    '/pension-types',
#    '/settled-status-eu-citizens-families/after-youve-applied',
#    '/government/publications/dwp-jobcentre-register',
#    '/skilled-worker-visa/when-you-can-be-paid-less',
#    '/english-language',
#    '/deferring-state-pension/what-you-get',
#    '/guidance/using-the-eu-exit-id-document-check-app',
#    '/check-income-tax-current-year/sign-in/create-account',
#    '/pension-credit-calculator',
#    '/register-to-vote',
#    '/am-i-getting-minimum-wage',
#    '/report-benefits-change-circumstances',
#    '/night-working-hours',
#    '/guidance/brexit-guidance-for-businesses',
#    '/browse/benefits/unable-to-work',
#    '/youth-mobility',
#    '/browse/citizenship/voting',
#    '/guidance/immigration-rules/immigration-rules-part-5-working-in-the-uk',
#    '/workplace-bullying-and-harassment',
#    '/access-to-work',
#    '/estimate-income-tax',
#    '/check-income-tax-last-year',
#    '/guidance/new-immigration-system-what-you-need-to-know',
#    '/legal-right-work-uk',
#    '/renew-adult-passport',
#    '/new-state-pension/living-and-working-overseas',
#    '/moving-from-benefits-to-work/starting-your-own-business',
#    '/government/organisations/hm-revenue-customs/contact',
#    '/guidance/free-courses-for-jobs',
#    '/dla-disability-living-allowance-benefit',
#    '/pension-credit/change-of-circumstances',
#    '/tax-on-pension/tax-free',
#    '/government/publications/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19',
#    '/tax-help',
#    '/transferring-your-pension',
#    '/workplace-pensions',
#    '/student-visa/family-members',
#    '/check-mot-history',
#    '/pensions-advisory-service',
#    '/get-paye-forms-p45-p60',
#    '/check-income-tax-current-year/sign-in/prove-identity',
#    '/employment-rights-for-interns',
#    '/browse/disabilities/equipment',
#    '/graduate-visa/documents-youll-need-to-apply',
#    '/passport-advice-line',
#    '/government/organisations/foreign-commonwealth-development-office',
#    '/holiday-entitlement-rights',
#    '/renew-driving-licence-at-70',
#    '/pension-credit/how-to-claim',
#    '/find-traineeship',
#    '/universal-credit/how-to-claim',
#    '/jobseekers-allowance/eligibility',
#    '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults',
#    '/topic/higher-education/scholarships-for-overseas-students',
#    '/new-state-pension/how-to-claim',
#    '/contracted-out/new-state-pension',
#    '/apply-online-to-replace-a-driving-licence',
#    '/standard-visitor-visa',
#    '/browse/benefits/manage-your-benefit',
#    '/browse/visas-immigration/asylum',
#    '/apply-housing-benefit-from-council',
#    '/uk-border-control/before-you-leave-for-the-uk',
#    '/foreign-travel-advice/spain',
#    '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member',
#    '/government/publications/eu-settlement-scheme-application-processing-times/eu-settlement-scheme-pilot-current-expected-processing-times-for-applications',
#    '/browse/benefits/looking-for-work',
#    '/government/publications/register-of-licensed-sponsors-students',
#    '/skilled-worker-visa',
#    '/benefit-cap',
#    '/holiday-entitlement-rights/holiday-pay-the-basics',
#    '/income-tax',
#    '/find-pension-contact-details',
#    '/government/organisations/foreign-commonwealth-office',
#    '/government/organisations/home-office',
#    '/guidance/booking-and-staying-in-a-quarantine-hotel-when-you-arrive-in-england',
#    '/topic/business-tax/self-employed',
#    '/government/organisations/department-for-work-pensions/about',
#    '/government/organisations/uk-visas-and-immigration',
#    '/self-employed-national-insurance-rates',
#    '/handing-in-your-notice/gardening-leave',
#    '/understanding-your-pay/deductions-from-your-pay',
#    '/pay-and-work-rights',
#    '/browse/employing-people/recruiting-hiring',
#    '/government/get-involved/take-part/volunteer',
#    '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens',
#    '/universal-credit',
#    '/biometric-residence-permits',
#    '/government/publications/test-and-trace-support-payment-scheme-claiming-financial-support/claiming-financial-support-under-the-test-and-trace-support-payment-scheme',
#    '/browse/education/find-course',
#    '/taking-sick-leave',
#    '/topic/personal-tax/national-insurance',
#    '/moving-from-benefits-to-work/support-when-you-start-working',
#    '/get-help-hmrc-extra-support',
#    '/new-state-pension/how-its-calculated',
#    '/state-pension',
#    '/find-internship',
#    '/contact-jobcentre-plus/new-benefit-claims',
#    '/pip',
#    '/pension-credit/eligibility',
#    '/tell-hmrc-change-address',
#    '/guidance/visa-decision-waiting-times-applications-outside-the-uk',
#    '/browse/tax/self-assessment',
#    '/state-pension-if-you-retire-abroad',
#    '/government/organisations/department-of-health-and-social-care',
#    '/personal-tax-account/sign-in/prove-identity',
#    '/contact-student-finance-england',
#    '/search/news-and-communications',
#    '/claim-tax-credits',
#    '/short-term-benefit-advance/how-to-apply',
#    '/new-state-pension/inheriting-or-increasing-state-pension-from-a-spouse-or-civil-partner',
#    '/council-tax-bands',
#    '/uk-visa-sponsorship-employers/types-of-licence',
#    '/coronavirus/business-support',
#    '/student-visa/money',
#    '/after-a-death/organisations-you-need-to-contact-and-tell-us-once',
#    '/contracted-out/old-state-pension',
#    '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022',
#    '/government/publications/right-to-work-checklist',
#    '/pip/change-of-circumstances',
#    '/find-lost-utr-number',
#    '/universal-credit/other-financial-support',
#    '/tax-on-pension',
#    '/guidance/recruiting-people-from-outside-the-uk',
#    '/apply-for-elderly-person-bus-pass',
#    '/government/organisations/hm-revenue-customs/services-information',
#    '/student-finance/extra-help',
#    '/employment-status/worker',
#    '/death-spouse-benefits-tax-pension/pensions',
#    '/job-offers-your-rights',
#    '/find-travel-test-provider',
#    '/government/organisations/department-for-work-pensions/about/complaints-procedure',
#    '/pay-voluntary-class-3-national-insurance',
#    '/agency-workers-your-rights/basic-information-you-should-receive',
#    '/get-tax-free-childcare',
#    '/learn-to-drive-a-car',
#    '/browse/employing-people/contracts',
#    '/early-retirement-pension/personal-and-workplace-pensions',
#    '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus',
#    '/criminal-record-checks-apply-role/application-process']),
#  ('/jobseekers-allowance',
#   ['/jobseekers-allowance/eligibility',
#    '/jobseekers-allowance/apply-new-style-jsa',
#    '/benefits-calculators',
#    '/jobseekers-allowance/your-jsa-claim',
#    '/universal-credit/eligibility',
#    '/browse/benefits/looking-for-work',
#    '/jobseekers-allowance/report-a-change-of-circumstances',
#    '/universal-credit',
#    '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa',
#    '/contact-jobcentre-plus',
#    '/find-a-job',
#    '/employment-support-allowance',
#    '/sign-in-universal-credit',
#    '/how-to-claim-new-style-jsa',
#    '/how-to-have-your-benefits-paid',
#    '/employment-support-allowance/eligibility',
#    '/apply-universal-credit',
#    '/browse/working/finding-job',
#    '/contact-jobcentre-plus/new-benefit-claims',
#    '/universal-credit/contact-universal-credit',
#    '/guidance/redundancy-help-finding-work-and-claiming-benefits',
#    '/guidance/new-style-jobseekers-allowance',
#    '/contact-jobcentre-plus/existing-benefit-claims',
#    '/employment-support-allowance/what-youll-get',
#    '/universal-credit/how-to-claim',
#    '/employment-support-allowance/how-to-claim',
#    '/universal-credit/what-youll-get',
#    '/income-support',
#    '/pension-credit',
#    '/housing-benefit',
#    '/incapacity-benefit',
#    '/government/organisations/department-for-work-pensions',
#    '/browse/working',
#    '/statutory-sick-pay',
#    '/pip',
#    '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022',
#    '/short-term-benefit-advance',
#    '/employment-support-allowance/working-while-you-claim',
#    '/disability-premiums',
#    '/guidance/new-style-employment-and-support-allowance',
#    '/child-benefit',
#    '/further-education-courses/financial-help',
#    '/apply-apprenticeship',
#    '/log-in-register-hmrc-online-services',
#    '/budgeting-help-benefits',
#    '/carers-allowance',
#    '/moving-from-benefits-to-work/support-when-you-start-working',
#    '/working-tax-credit',
#    '/guidance/get-help-with-benefits-and-pensions-if-you-have-accessibility-needs',
#    '/grant-bursary-adult-learners',
#    '/state-pension-age',
#    '/browse/benefits/manage-your-benefit',
#    '/national-insurance/help-if-youre-not-working',
#    '/universal-credit/how-your-earnings-affect-your-payments',
#    '/universal-credit/other-financial-support',
#    '/guidance/universal-credit-advances',
#    '/employment-support-allowance/your-esa-claim',
#    '/housing-benefit/what-youll-get',
#    '/government/collections/kickstart-scheme',
# ...
#    '/settled-status-eu-citizens-families/applying-for-settled-status',
#    '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens']),
#  ('/help/terms-conditions',
#   ['/contact-jobcentre-plus',
#    '/help',
#    '/government/publications/introducing-govuk-verify/introducing-govuk-verify',
#    '/register-to-vote',
#    '/apply-apprenticeship',
#    '/national-insurance/your-national-insurance-number',
#    '/search/guidance-and-regulation',
#    '/contact-ukvi-inside-outside-uk',
#    '/get-copy-military-service-records',
#    '/government/organisations/hm-revenue-customs/contact',
#    '/get-coronavirus-test']),
#  ('/government/collections/financial-support-for-businesses-during-coronavirus-covid-19',
#   ['/coronavirus/business-support',
#    '/moving-from-benefits-to-work/starting-your-own-business',
#    '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme',
#    '/guidance/coronavirus-covid-19-what-to-do-if-youre-self-employed-and-getting-less-work-or-no-work',
#    '/contact-jobcentre-plus',
#    '/apply-start-up-loan',
#    '/coronavirus/worker-support',
#    '/grant-bursary-adult-learners',
#    '/government/collections/new-enterprise-allowance-campaign',
#    '/business-finance-support',
#    '/statutory-sick-pay']),
#  ('/help-for-disabled-child',
#   ['/browse/benefits/families',
#    '/browse/benefits/disability',
#    '/find-local-council',
#    '/browse/disabilities/carers',
#    '/browse/births-deaths-marriages/child-adoption',
#    '/disability-living-allowance-children',
#    '/employment-support-allowance',
#    '/apply-needs-assessment-social-services',
#    '/child-tax-credit',
#    '/discrimination-your-rights',
#    '/apply-direct-payments']),
#  ('/government/organisations/companies-house',
#   ['/get-information-about-a-company',
#    '/check-state-pension',
#    '/jobseekers-allowance',
#    '/criminal-record-checks-apply-role',
#    '/access-to-work',
#    '/employers-checks-job-applicants',
#    '/apply-apprenticeship',
#    '/guidance/how-to-take-on-an-apprentice',
#    '/get-coronavirus-test',
#    '/find-a-job']),
#  ('/government/get-involved/take-part/volunteer',
#   ['/volunteering',
#    '/find-a-job',
#    '/browse/working/finding-job',
#    '/contact-student-finance-england',
#    '/government/organisations/disclosure-and-barring-service',
#    '/topic/further-education-skills/apprenticeships',
#    '/guidance/government-legal-service-gls-legal-trainee-scheme-how-to-apply',
#    '/become-apprentice',
#    '/browse/working',
#    '/volunteering/volunteers-rights']),
#  ('/budgeting-help-benefits/what-youll-get',
#   ['/budgeting-help-benefits/repayments',
#    '/budgeting-help-benefits/eligibility',
#    '/budgeting-help-benefits/how-to-apply',
#    '/budgeting-help-benefits/other-help-you-can-get',
#    '/budgeting-help-benefits',
#    '/budgeting-help-benefits/after-you-apply',
#    '/browse/benefits/looking-for-work',
#    '/guidance/get-help-with-benefits-and-pensions-if-you-have-accessibility-needs',
#    '/find-a-job',
#    '/apply-universal-credit']),
#  ('/volunteering/volunteers-rights',
#   ['/volunteering',
#    '/volunteering/when-you-can-volunteer',
#    '/volunteering/pay-and-expenses',
#    '/employment-status',
#    '/browse/citizenship/charities-honours',
#    '/employment-rights-for-interns',
#    '/temporary-worker-charity-worker-visa',
#    '/government/get-involved/take-part/volunteer',
#    '/browse/working/finding-job',
#    '/check-job-applicant-right-to-work']),
#  ('/government/publications/apprenticeship-recruitment-employers-and-training-organisations',
#   ['/government/collections/apprenticeship-vacancies',
#    '/topic/further-education-skills/apprenticeships',
#    '/government/organisations/education-and-skills-funding-agency',
#    '/apply-apprenticeship',
#    '/guidance/how-to-take-on-an-apprentice',
#    '/employing-an-apprentice/pay-and-conditions-for-apprentices',
#    '/guidance/manage-apprenticeship-funds',
#    '/guidance/search-for-apprenticeship-standards',
#    '/recruit-apprentice',
#    '/government/collections/kickstart-scheme']),
#  ('/browse/abroad/travel-abroad',
#   ['/foreign-travel-advice',
#    '/travel-abroad',
#    '/uk-border-control',
#    '/provide-journey-contact-details-before-travel-uk',
#    '/browse/working',
#    '/browse/abroad/living-abroad',
#    '/browse/abroad/passports',
#    '/uk-border-control/before-you-leave-for-the-uk',
#    '/claim-benefits-abroad',
#    '/get-document-legalised']),
#  ('/health-care-worker-visa/your-job',
#   ['/health-care-worker-visa',
#    '/browse/visas-immigration/work-visas',
#    '/uk-visa-sponsorship-employers',
#    '/apply-to-come-to-the-uk',
#    '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes',
#    '/find-a-job',
#    '/guidance/immigration-rules',
#    '/check-uk-visa',
#    '/government/publications/skilled-worker-visa-shortage-occupations',
#    '/government/publications/register-of-licensed-sponsors-workers']),
#  ('/carers-credit/eligibility',
#   ['/carers-credit/how-to-claim',
#    '/carers-credit/what-youll-get',
#    '/carers-allowance',
#    '/browse/benefits/help-for-carers',
#    '/state-pension-age',
#    '/carers-credit',
#    '/contact-jobcentre-plus',
#    '/pip',
#    '/check-state-pension',
#    '/constant-attendance-allowance']),
#  ('/benefit-cap/when-youre-not-affected',
#   ['/benefit-cap/how-earnings-affect-when-benefit-cap-starts',
#    '/benefit-cap',
#    '/benefit-cap/benefit-cap-amounts',
#    '/benefit-cap/help-with-the-benefit-cap',
#    '/browse/benefits/manage-your-benefit',
#    '/housing-benefit',
#    '/sign-in-universal-credit',
#    '/council-housing',
#    '/universal-credit',
#    '/dbs-update-service']),
#  ('/your-employment-contract-how-it-can-be-changed/making-changes',
#   ['/your-employment-contract-how-it-can-be-changed/dealing-with-problems',
#    '/your-employment-contract-how-it-can-be-changed',
#    '/browse/working/contract-working-hours',
#    '/employment-contracts-and-conditions/written-statement-of-employment-particulars',
#    '/flexible-working/applying-for-flexible-working',
#    '/maximum-weekly-working-hours/calculating-your-working-hours',
#    '/employment-contracts-and-conditions/collective-agreements',
#    '/employment-contracts-and-conditions',
#    '/maximum-weekly-working-hours',
#    '/browse/working']),
#  ('/browse/tax/capital-gains',
#   ['/capital-gains-tax',
#    '/applying-for-probate',
#    '/browse/tax/income-tax',
#    '/browse/tax/court-claims-debt-bankruptcy',
#    '/browse/tax/national-insurance',
#    '/pay-self-assessment-tax-bill',
#    '/browse/working',
#    '/government/organisations',
#    '/browse/tax/self-assessment',
#    '/browse/tax/dealing-with-hmrc']),
#  ('/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers',
#   ['/find-a-job',
#    '/find-traineeship',
#    '/contact-jobcentre-plus',
#    '/government/topical-events/plan-for-jobs',
#    '/guidance/free-courses-for-jobs',
#    '/what-different-qualification-levels-mean/list-of-qualification-levels',
#    '/government/collections/kickstart-scheme',
#    '/apply-apprenticeship',
#    '/guidance/plan-for-jobs-skills-and-employment-programmes-information-for-employers',
#    '/career-skills-and-training']),
#  ('/get-paye-forms-p45-p60',
#   ['/paye-forms-p45-p60-p11d',
#    '/browse/employing-people/payroll',
#    '/government/publications/paye-starter-checklist',
#    '/paye-forms-p45-p60-p11d/p60',
#    '/browse/working',
#    '/log-in-register-hmrc-online-services',
#    '/apply-national-insurance-number',
#    '/contact-hmrc',
#    '/tax-right-retire-abroad-return-to-uk',
#    '/running-payroll']),
#  ('/register-for-self-assessment',
#   ['/register-for-self-assessment/self-employed',
#    '/register-for-self-assessment/not-self-employed',
#    '/log-in-file-self-assessment-tax-return/sign-in/prove-identity',
#    '/browse/tax/self-assessment',
#    '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed',
#    '/log-in-file-self-assessment-tax-return',
#    '/self-employed-records',
#    '/self-assessment-forms-and-helpsheets',
#    '/pay-self-assessment-tax-bill',
#    '/working-for-yourself']),
#  ('/visit-uk-holiday-family-friends',
#   ['/check-uk-visa',
#    '/browse/visas-immigration/tourist-short-stay-visas',
#    '/apply-standard-visitor-visa',
#    '/uk-family-visa',
#    '/browse/visas-immigration/family-visas',
#    '/family-permit',
#    '/browse/working',
#    '/browse/visas-immigration/work-visas',
#    '/standard-visitor-visa',
#    '/browse/visas-immigration/student-visas']),
#  ('/national-insurance-rates-letters/category-letters',
#   ['/national-insurance-rates-letters',
#    '/contracted-out/check-if-you-were-contracted-out',
#    '/contracted-out/new-state-pension',
#    '/new-state-pension/how-to-claim',
#    '/contracted-out/old-state-pension',
#    '/additional-state-pension',
#    '/find-pension-contact-details',
#    '/state-pension-age',
#    '/child-benefit-16-19',
#    '/government/organisations/department-for-work-pensions']),
#  ('/paternity-pay-leave/how-to-claim',
#   ['/paternity-pay-leave/eligibility',
#    '/browse/working/time-off',
#    '/paternity-pay-leave',
#    '/maternity-paternity-pay-leave',
#    '/paternity-pay-leave/pay',
#    '/browse/working',
#    '/browse/benefits/families',
#    '/maternity-pay-leave',
#    '/maternity-pay-leave/how-to-claim',
#    '/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19']),
#  ('/apply-to-come-to-the-uk/prove-your-identity',
#   ['/biometric-residence-permits',
#    '/find-a-visa-application-centre',
#    '/apply-to-come-to-the-uk',
#    '/apply-national-insurance-number',
#    '/apply-to-come-to-the-uk/prepare-your-application',
#    '/view-prove-immigration-status',
#    '/check-uk-visa',
#    '/biometric-residence-permits/replace-expired-brp',
#    '/private-renting',
#    '/biometric-residence-permits/collect']),
#  ('/government/publications/easy-read-get-help-at-work-if-youre-disabled-or-have-a-health-condition-access-to-work',
#   ['/access-to-work',
#    '/access-to-work/eligibility',
#    '/access-to-work/apply',
#    '/access-to-work/what-youll-get',
#    '/government/organisations/department-for-work-pensions',
#    '/browse/benefits/disability',
#    '/rights-disabled-person',
#    '/access-to-work/after-you-have-applied',
#    '/government/publications/access-to-work-factsheet/access-to-work-factsheet-for-customers',
#    '/access-to-work/report-a-change-of-circumstances']),
#  ('/government/publications/biometric-residence-permits-applicant-and-sponsor-information',
#   ['/biometric-residence-permits',
#    '/transfer-visa',
#    '/biometric-residence-permits/personal-data',
#    '/national-insurance',
#    '/contact-ukvi-inside-outside-uk',
#    '/browse/working',
#    '/biometric-residence-permits/collect',
#    '/biometric-residence-permits/replace-visa-brp',
#    '/browse/visas-immigration/settle-in-the-uk',
#    '/view-prove-immigration-status']),
#  ('/tax-national-insurance-after-state-pension-age/stopping-paying-national-insurance',
#   ['/tax-national-insurance-after-state-pension-age',
#    '/national-insurance',
#    '/claim-national-insurance-refund',
#    '/state-pension-age',
#    '/national-insurance/national-insurance-classes',
#    '/state-pension',
#    '/additional-state-pension',
#    '/new-state-pension/how-its-calculated',
#    '/tax-on-pension',
#    '/check-national-insurance-record']),
#  ('/redundancy-payments-helpline',
#   ['/browse/working/redundancies-dismissals',
#    '/redundancy-your-rights',
#    '/calculate-your-redundancy-pay',
#    '/your-rights-if-your-employer-is-insolvent',
#    '/claim-redundancy',
#    '/redundancy-your-rights/notice-periods',
#    '/jobseekers-allowance',
#    '/browse/working',
#    '/call-charges',
#    '/jobseekers-allowance/eligibility']),
#  ('/child-tax-credit/new-claim',
#   ['/child-tax-credit',
#    '/tax-credits-calculator',
#    '/child-tax-credit/how-to-claim',
#    '/working-tax-credit',
#    '/pip',
#    '/browse/childcare-parenting/financial-help-children',
#    '/claim-tax-credits',
#    '/child-benefit/eligibility',
#    '/working-tax-credit/what-youll-get',
#    '/browse/working']),
#  ('/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide',
#   ['/dbs-check-applicant-criminal-record',
#    '/dbs-update-service',
#    '/government/publications/dbs-certificate-reprint-guide',
#    '/guidance/track-a-dbs-application',
#    '/government/organisations/disclosure-and-barring-service',
#    '/guidance/digital-and-online-services',
#    '/government/publications/dbs-update-service-applicant-guide/dbs-update-service-applicant-guide',
#    '/find-out-dbs-check',
#    '/government/publications/dbs-application-forms-guide-for-applicants',
#    '/guidance/dbs-check-requests-guidance-for-employers']),
#  ('/personal-pensions-your-rights/get-help',
#   ['/personal-pensions-your-rights/how-you-can-take-pension',
#    '/contact-pension-service',
#    '/browse/working/workplace-personal-pensions',
#    '/browse/working',
#    '/personal-pensions-your-rights',
#    '/new-state-pension',
#    '/council-tax-bands',
#    '/topic/business-tax/pension-scheme-administration',
#    '/state-pension',
#    '/vehicle-tax']),
#  ('/tax-on-your-private-pension/annual-allowance',
#   ['/tax-on-your-private-pension/pension-tax-relief',
#    '/tax-on-your-private-pension/lifetime-allowance',
#    '/browse/working/workplace-personal-pensions',
#    '/personal-pensions-your-rights/how-you-can-take-pension',
#    '/tax-on-your-private-pension',
#    '/pension-types',
#    '/browse/tax/income-tax',
#    '/workplace-pensions/if-you-want-to-leave-your-workplace-pension-scheme',
#    '/government/organisations/the-pensions-advisory-service',
#    '/plan-retirement-income']),
#  ('/browse/citizenship/charities-honours',
#   ['/volunteering',
#    '/browse/citizenship/citizenship',
#    '/browse/citizenship/government',
#    '/apply-medal-or-veterans-badge',
#    '/volunteering/when-you-can-volunteer',
#    '/sign-in-universal-credit',
#    '/become-magistrate',
#    '/search/policy-papers-and-consultations',
#    '/browse/citizenship/voting',
#    '/volunteering/pay-and-expenses']),
#  ('/tax-company-benefits',
#   ['/browse/working/tax-minimum-wage',
#    '/check-income-tax-current-year',
#    '/national-minimum-wage-accommodation',
#    '/am-i-getting-minimum-wage',
#    '/browse/tax/income-tax',
#    '/keeping-your-pay-tax-records',
#    '/national-minimum-wage',
#    '/paye-for-employers',
#    '/browse/working',
#    '/tax-codes']),
#  ('/contract-types-and-employer-responsibilities',
#   ['/contract-types-and-employer-responsibilities/fulltime-and-parttime-contracts',
#    '/browse/employing-people/contracts',
#    '/employer-relocation-your-rights',
#    '/employment-status',
#    '/pension-types',
#    '/uk-visa-sponsorship-employers/certificates-of-sponsorship',
#    '/self-employment-and-universal-credit',
#    '/redundancy-your-rights/notice-periods',
#    '/au-pairs-employment-law',
#    '/employing-staff']),
#  ('/recruitment-disabled-people',
#   ['/recruitment-disabled-people/encouraging-applications',
#    '/browse/disabilities/work',
#    '/browse/employing-people/recruiting-hiring',
#    '/access-to-work',
#    '/definition-of-disability-under-equality-act-2010',
#    '/browse/employing-people/health-safety',
#    '/access-to-work/eligibility',
#    '/employer-preventing-discrimination',
#    '/access-to-work/apply',
#    '/reasonable-adjustments-for-disabled-workers']),
#  ('/guidance/how-your-trading-conditions-affect-your-eligibility-for-the-self-employment-income-support-scheme',
#   ['/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme',
#    '/coronavirus/business-support',
#    '/government/organisations/hm-revenue-customs',
#    '/topic/further-education-skills/apprenticeships',
#    '/guidance/check-if-you-could-be-covered-by-the-coronavirus-job-retention-scheme',
#    '/find-coronavirus-support',
#    '/browse/working',
#    '/coronavirus/worker-support',
#    '/set-up-self-employed',
#    '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant']),
#  ('/independent-livingfund',
#   ['/browse/disabilities/benefits',
#    '/find-local-council',
#    '/financial-help-disabled',
#    '/disability-premiums',
#    '/pip',
#    '/reduced-earnings-allowance',
#    '/incapacity-benefit',
#    '/severe-disablement-allowance',
#    '/browse/disabilities/work',
#    '/browse/working']),
#  ...]

# %% [markdown]
# ## Ranking the subgraph

# %% [markdown]
# We now have a subgraph of 1384 nodes. How do we rank these pages so that the most 'relevant' pages to a WUJ are at the top, while the most 'irrelevant' pages to a WUJ are at the bottom?
#
# Explored:
# - session hits
# - shortest page path lengths
# - sum of the shortest page path lengths
# - between centrality
# - degree centrality
# - closeness centrality
#
# An average (non-weighted) rank for each page path was created using:
# - shortest page path length from seed0.1: `shortest_seed0_1`
# - shortest page path length from seed0.2: `shortest_seed0_2`
# - degree centrality: `g_degree`
#
# These four metrics were chosen as the assumption is that nodes close to seed0 nodes, are more likely to be associated with the same topic, and therefore the same WUJ. In addition, nodes which are more highly connected (e.g. more outgoing/incoming relationships) should be included in the WUJ, as it is expected the majority of the pages in the subgraph are mostly relevant.
#
# The others metrics were not chosen, because:
# - session hits: pages with low session hits may be relevant to a WUJ
# - sum of the shortest page path lengths: pages may be closer to one seed0 node, but far away from the other seed0 node
# - between centrality: pages relevant to a WUJ may not neccessarily have many paths that pass through. It is likely that more 'popular' pages will (i.e. ones with higher session hits)
#
#
# Caveat: browse pages are likely to be ranked highly, as these are common pages which may be highly connected to other nodes. Therefore, irrelevant browse pages are removed.

# %% [markdown]
# ### Order by session hits

# %%
sessions = list(
    sorted(
        economic_recovery_subgraph, key=lambda x: x[1]["sessionHitsAll"], reverse=True
    )
)

# %% [markdown]
# ### Order by shortest page path lengths

# %%
# calculate the paths of the shortest page path

# for two seed pages caluclat eshortest path of all pages to the seed page
shortest_paths_seed0 = nx.shortest_path_length(g, source="/browse/working/finding-job")
shortest_paths_seed1 = nx.shortest_path_length(
    g, source="/topic/further-education-skills/apprenticeships"
)

# %%
shortest_paths_seed0
# Out:
# {'/browse/working/finding-job': 0,
#  '/dbs-update-service': 1,
#  '/government/collections/sponsorship-information-for-employers-and-educators': 1,
#  '/view-right-to-work': 1,
#  '/access-to-work/after-you-have-applied': 1,
#  '/employment-status': 1,
#  '/guidance/dbs-check-requests-guidance-for-employers': 1,
#  '/what-different-qualification-levels-mean': 1,
#  '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers': 1,
#  '/become-apprentice/apply-for-an-apprenticeship': 1,
#  '/browse/working/redundancies-dismissals': 1,
#  '/improve-english-maths-it-skills': 1,
#  '/find-internship': 1,
#  '/contact-ukvi-inside-outside-uk': 1,
#  '/coronavirus/worker-support': 1,
#  '/access-to-work': 1,
#  '/apply-universal-credit': 1,
#  '/work-reference': 1,
#  '/job-offers-your-rights': 1,
#  '/jobseekers-allowance': 1,
#  '/find-a-job': 1,
#  '/browse/working/time-off': 1,
#  '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations': 1,
#  '/topic/work-careers/secondments-with-government': 1,
#  '/manage-your-tax-credits': 1,
#  '/browse/benefits/looking-for-work': 1,
#  '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme': 1,
#  '/government/organisations/disclosure-and-barring-service': 1,
#  '/skilled-worker-visa/knowledge-of-english': 1,
#  '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide/universal-credit-if-you-have-a-disability-or-health-condition': 1,
#  '/government/organisations/department-for-work-pensions/about/recruitment': 1,
#  '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do': 1,
#  '/jobseekers-allowance/eligibility': 1,
#  '/intracompany-transfer-worker-visa': 1,
#  '/sign-in-universal-credit': 1,
#  '/volunteering/when-you-can-volunteer': 1,
#  '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes': 1,
#  '/employee-immigration-employment-status': 1,
#  '/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2': 1,
#  '/guidance/red-amber-and-green-list-rules-for-entering-england': 1,
#  '/jobsearch-rights': 1,
#  '/advertise-job': 1,
#  '/get-information-about-a-company': 1,
#  '/tell-employer-or-college-about-criminal-record': 1,
#  '/get-copy-military-service-records': 1,
#  '/report-problem-criminal-record-certificate': 1,
#  '/universal-credit': 1,
#  '/british-citizenship': 1,
#  '/check-job-applicant-right-to-work': 1,
#  '/pip/eligibility': 1,
#  '/employment-rights-for-interns': 1,
#  '/government/get-involved/take-part/volunteer': 1,
#  '/register-to-vote': 1,
#  '/death-spouse-benefits-tax-pension/pensions': 1,
#  '/check-uk-visa': 1,
#  '/work-health-programme': 1,
#  '/government/organisations': 1,
#  '/government/organisations/home-office': 1,
#  '/settled-status-eu-citizens-families/apply-settled-status-for-child': 1,
#  '/seasonal-worker-visa': 1,
#  '/jobseekers-allowance/report-a-change-of-circumstances': 1,
#  '/browse/working/armed-forces': 1,
#  '/guidance/immigration-rules': 1,
#  '/browse/working/rights-trade-unions': 1,
#  '/tell-employer-or-college-about-criminal-record/driving-convictions': 1,
#  '/government/publications/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens-accessible-version': 1,
#  '/browse/visas-immigration/work-visas': 1,
#  '/career-skills-and-training': 1,
#  '/topic/further-education-skills/apprenticeships': 1,
#  '/government/organisations/department-for-work-pensions/about': 1,
#  '/browse/employing-people/trade-unions': 1,
#  '/browse/working/tax-minimum-wage': 1,
#  '/skilled-worker-visa/documents-you-must-provide': 1,
#  '/apply-apprenticeship': 1,
#  '/volunteering': 1,
#  '/jobcentre-plus-help-for-recruiters': 1,
#  '/contact-jobcentre-plus': 1,
#  '/criminal-record-checks-apply-role': 1,
#  '/contact-the-dvla': 1,
#  '/find-traineeship': 1,
#  '/moving-from-benefits-to-work/support-when-you-start-working': 1,
#  '/tell-employer-or-college-about-criminal-record/prison-sentences': 1,
#  '/exchange-foreign-driving-licence': 1,
#  '/dbs-check-applicant-criminal-record': 1,
#  '/government/publications/skilled-worker-visa-shortage-occupations': 1,
#  '/browse/working/workplace-personal-pensions': 1,
#  '/browse/working/contract-working-hours': 1,
#  '/topic/defence-armed-forces/military-recruitment-training-operations': 1,
#  '/help-with-childcare-costs': 1,
#  '/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work': 1,
#  '/student-finance/who-qualifies': 1,
#  '/child-employment/paying': 1,
#  '/national-insurance/national-insurance-classes': 1,
#  '/government/publications/standard-and-enhanced-dbs-check-privacy-policy/standard-and-enhanced-dbs-check-privacy-policy': 1,
#  '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers': 1,
#  '/government/organisations/hm-revenue-customs/about/recruitment': 1,
#  '/tax-credits-calculator': 1,
#  '/pip/when-your-pip-claim-is-reviewed': 1,
#  '/log-in-register-hmrc-online-services': 1,
#  '/moving-from-benefits-to-work': 1,
#  '/looking-for-work-if-disabled': 1,
#  '/browse/working': 1,
#  '/benefits-calculators': 1,
#  '/uk-visa-sponsorship-employers': 1,
#  '/criminal-record-check-documents': 1,
#  '/guidance/immigration-rules/immigration-rules-appendix-shortage-occupation-list': 1,
#  '/contact-jobcentre-plus/change-cancel-appointment': 1,
#  '/become-apprentice': 1,
#  '/government/publications/register-of-licensed-sponsors-workers': 1,
#  '/contact-jobcentre-plus/new-benefit-claims': 1,
#  '/topic/work-careers/government-graduate-schemes': 1,
#  '/employers-checks-job-applicants': 1,
#  '/browse/education/find-course': 1,
#  '/search/services': 1,
#  '/national-insurance': 1,
#  '/guidance/free-courses-for-jobs': 1,
#  '/legal-right-work-uk': 1,
#  '/graduate-visa/documents-youll-need-to-apply': 2,
#  '/government/collections/dbs-filtering-guidance': 2,
#  '/government/organisations/hm-revenue-customs/contact/online-services-helpdesk': 2,
#  '/guidance/dvla-coronavirus-covid-19-update': 2,
#  '/apply-sponsor-licence': 2,
#  '/child-benefit-16-19': 2,
#  '/carers-allowance-report-change': 2,
#  '/guidance/search-for-apprenticeship-standards': 2,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations': 2,
#  '/apply-direct-payments': 2,
#  '/government/publications/filtering-rules-for-criminal-record-check-certificates': 2,
#  '/browse/visas-immigration/student-visas': 2,
#  '/log-in-hmrc-excise-import-export': 2,
#  '/student-visa/money': 2,
#  '/government/publications/access-to-work-factsheet/access-to-work-factsheet-for-customers': 2,
#  '/id-for-driving-licence': 2,
#  '/biometric-residence-permits/replace-expired-brp': 2,
#  '/employing-an-apprentice/apprenticeship-agreement': 2,
#  '/volunteering/volunteers-rights': 2,
#  '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus': 2,
#  '/graduate-visa/course-you-studied': 2,
#  '/browse/childcare-parenting/schools-education': 2,
#  '/overtime-your-rights/compulsory-overtime': 2,
#  '/financial-help-disabled/home-and-housing': 2,
#  '/moving-from-benefits-to-work/work-experience-and-volunteering': 2,
#  '/browse/childcare-parenting/financial-help-children': 2,
#  '/understanding-your-pay/deductions-from-your-pay': 2,
#  '/government/organisations/hm-revenue-customs/contact': 2,
#  '/government/publications/redundancy-payments-rp1-fact-sheet/what-to-do-when-youve-been-made-redundant': 2,
#  '/mandatory-reconsideration/how-to-ask-for-mandatory-reconsideration': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants': 2,
#  '/bank-holidays': 2,
#  '/settled-status-eu-citizens-families/what-youll-need-to-apply': 2,
#  '/passport-fees': 2,
#  '/budgeting-help-benefits': 2,
#  '/government/publications/basic-check-guidance-and-policies': 2,
#  '/statutory-sick-pay': 2,
#  '/housing-benefit/other-help-with-housing-costs': 2,
#  '/dual-citizenship': 2,
#  '/fraud-error-prevention-centres': 2,
#  '/self-employment-and-universal-credit': 2,
#  '/criminal-record-checks-apply-role/application-process': 2,
#  '/register-for-self-assessment/self-employed': 2,
#  '/disability-living-allowance-children/rates': 2,
#  '/browse/abroad/travel-abroad': 2,
#  '/check-british-citizenship': 2,
#  '/government/publications/dbs-update-service-applicant-guide': 2,
#  '/time-off-for-dependants': 2,
#  '/guidance/how-to-take-on-an-apprentice': 2,
#  '/estimate-income-tax': 2,
#  '/recruitment-disabled-people': 2,
#  '/advanced-learner-loan': 2,
#  '/government/collections/financial-support-for-businesses-during-coronavirus-covid-19': 2,
#  '/uk-residence-card': 2,
#  '/government/organisations/skills-funding-agency': 2,
#  '/national-insurance-rates-letters/category-letters': 2,
#  '/foreign-travel-advice/france': 2,
#  '/council-tax': 2,
#  '/help': 2,
#  '/apply-disabled-facilities-grant': 2,
#  '/browse/tax/dealing-with-hmrc': 2,
#  '/driving-lessons-learning-to-drive': 2,
#  '/changes-affect-tax-credits': 2,
#  '/guidance/using-your-uk-visas-and-immigration-account': 2,
#  '/further-education-courses': 2,
#  '/tax-on-pension/tax-free': 2,
#  '/right-to-reside': 2,
#  '/student-finance': 2,
#  '/get-copy-military-service-records/apply-for-someone-elses-records': 2,
#  '/guidance/new-immigration-system-what-you-need-to-know': 2,
#  '/national-minimum-wage-accommodation': 2,
#  '/government/publications/dbs-application-forms-guide-for-applicants/dbs-application-form-guide-for-applicants': 2,
#  '/cold-weather-payment/eligibility': 2,
#  '/guidance/contact-the-department-for-work-and-pensions-about-its-policies': 2,
#  '/what-is-the-construction-industry-scheme': 2,
#  '/workplace-pensions/what-you-your-employer-and-the-government-pay': 2,
#  '/government/publications/apprenticeship-funding-bands': 2,
#  '/tax-on-pension': 2,
#  '/taking-sick-leave': 2,
#  '/rest-breaks-work/disputes': 2,
#  '/paye-forms-p45-p60-p11d/p60': 2,
#  '/carers-allowance/if-youre-working-': 2,
#  '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide': 2,
#  '/browse/visas-immigration/settle-in-the-uk': 2,
#  '/claim-benefits-abroad/jobseekers-allowance': 2,
#  '/financial-help-disabled/disability-and-sickness-benefits': 2,
#  '/dvlaforms': 2,
#  '/looking-for-work-if-disabled/applying-for-a-job': 2,
#  '/student-visa/extend-your-visa': 2,
#  '/dla-disability-living-allowance-benefit': 2,
#  '/dbs-check-applicant-criminal-record/get-a-standard-or-enhanced-dbs-check-for-an-employee': 2,
#  '/graduate-visa': 2,
#  '/benefit-fraud': 2,
#  '/browse/births-deaths-marriages/child': 2,
#  '/benefit-overpayments': 2,
#  '/maternity-pay-leave/leave': 2,
#  '/guidance/statutory-sick-pay-employee-fitness-to-work': 2,
#  '/join-trade-union/trade-union-membership-your-employment-rights': 2,
#  '/child-employment': 2,
#  '/carers-allowance': 2,
#  '/education/apprenticeships-traineeships-and-internships': 2,
#  '/deferring-state-pension': 2,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes': 2,
#  '/state-pension-if-you-retire-abroad/report-a-change-in-your-circumstances': 2,
#  '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa': 2,
#  '/government/collections/traineeships--2': 2,
#  '/parental-leave/notice-period': 2,
#  '/income-tax/check-youre-paying-the-right-amount': 2,
#  '/topic/personal-tax/national-insurance': 2,
#  '/dismissal': 2,
#  '/employment-support-allowance/what-youll-get': 2,
#  '/renew-adult-passport': 2,
#  '/employment/finding-job': 2,
#  '/monitoring-work-workers-rights': 2,
#  '/topic/business-tax/pension-scheme-administration': 2,
#  '/new-state-pension/inheriting-or-increasing-state-pension-from-a-spouse-or-civil-partner': 2,
#  '/log-in-file-self-assessment-tax-return/sign-in/prove-identity': 2,
#  '/student-finance/extra-help': 2,
#  '/calculate-employee-redundancy-pay': 2,
#  '/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19': 2,
#  '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022': 2,
#  '/universal-credit/how-your-earnings-affect-your-payments': 2,
#  '/employment-tribunals/make-a-claim': 2,
#  '/universal-credit/get-an-advance-first-payment': 2,
#  '/get-undergraduate-student-loan': 2,
#  '/apply-to-come-to-the-uk': 2,
#  '/topic/crime-policing/criminal-record-disclosure': 2,
#  '/standard-visitor-visa/apply': 2,
#  '/government/publications/apprenticeship-recruitment-employers-and-training-organisations': 2,
#  '/foreign-travel-advice/spain': 2,
#  '/guidance/government-legal-service-gls-legal-trainee-scheme-how-to-apply': 2,
#  '/life-in-the-uk-test': 2,
#  '/browse/employing-people/recruiting-hiring': 2,
#  '/dismissal/unfair-and-constructive-dismissal': 2,
#  '/disability-premiums/what-youll-get': 2,
#  '/national-insurance/change-of-circumstance': 2,
#  '/browse/employing-people/time-off': 2,
#  '/browse/disabilities/benefits': 2,
#  '/government/publications/new-enterprise-allowance-phase-2-provider-guidance/new-enterprise-allowance-phase-2-provider-guidance': 2,
#  '/types-of-british-nationality': 2,
#  '/disabled-students-allowance-dsa': 2,
#  '/tax-on-your-private-pension/annual-allowance': 2,
#  '/redundancy-your-rights/being-selected-for-redundancy': 2,
#  '/government/publications/find-a-free-level-3-qualification': 2,
#  '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments': 2,
#  '/agricultural-workers-rights': 2,
#  '/government/collections/desg-graduate-scheme': 2,
#  '/benefit-cap/benefit-cap-amounts': 2,
#  '/incapacity-benefit': 2,
#  '/tax-on-your-private-pension/pension-tax-relief': 2,
#  '/recruitment-disabled-people/encouraging-applications': 2,
#  '/government/publications/disclosure-application-process-for-volunteers': 2,
#  '/national-insurance/help-if-youre-not-working': 2,
#  '/statutory-sick-pay/how-to-claim': 2,
#  '/biometric-residence-permits/personal-data': 2,
#  '/government/organisations/education-and-skills-funding-agency': 2,
#  '/apply-for-student-finance': 2,
#  '/view-right-to-rent': 2,
#  '/contract-types-and-employer-responsibilities': 2,
#  '/payment-exception-service': 2,
#  '/child-benefit-move-to-uk': 2,
#  '/tax-help': 2,
#  '/continuous-employment-what-it-is': 2,
#  '/government/organisations/hm-revenue-customs/contact/child-benefit': 2,
#  '/training-study-work-your-rights': 2,
#  '/biometric-residence-permits/not-arrived': 2,
#  '/1619-bursary-fund/eligibility': 2,
#  '/early-retirement-pension': 2,
#  '/track-passport-application': 2,
#  '/start-up-visa': 2,
#  '/send-fit-note': 2,
#  '/browse/benefits/disability': 2,
#  '/budgeting-help-benefits/repayments': 2,
#  '/government/publications/budgeting-loan-claim-form': 2,
#  '/international-pension-centre': 2,
#  '/join-trade-union': 2,
#  '/travel-abroad': 2,
#  '/government/publications/dbs-update-service-applicant-guide/dbs-update-service-applicant-guide': 2,
#  '/council-housing': 2,
#  '/skilled-worker-visa/when-you-can-be-paid-less': 2,
#  '/guidance/plan-for-jobs-skills-and-employment-programmes-information-for-employers': 2,
#  '/government/publications/united-kingdom-security-vetting-clearance-levels/national-security-vetting-clearance-levels': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/guidance-on-the-application-process-for-criminal-records-checks-overseas': 2,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals': 2,
#  '/british-passport-eligibility': 2,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship': 2,
#  '/search/news-and-communications': 2,
#  '/attendance-allowance/how-to-claim': 2,
#  '/apply-home-equipment-for-disabled': 2,
#  '/find-a-visa-application-centre': 2,
#  '/voluntary-national-insurance-contributions/deadlines': 2,
#  '/marriage-visa': 2,
#  '/childcare-grant': 2,
#  '/personal-pensions-your-rights/choosing-personal-pension': 2,
#  '/fixed-term-contracts/employees-rights': 2,
#  '/government/collections/hm-revenue-and-customs-service-availability-and-issues': 2,
#  '/employment-tribunals': 2,
#  '/paternity-pay-leave/eligibility': 2,
#  '/carers-allowance/further-information': 2,
#  '/shared-parental-leave-and-pay/eligibility-for-birth-parents': 2,
#  '/apply-for-elderly-person-bus-pass': 2,
#  '/get-a-passport-urgently/1-week-fast-track-service': 2,
#  '/check-university-award-degree': 2,
#  '/guidance/traineeship-information-for-trainees': 2,
#  '/employer-relocation-your-rights': 2,
#  '/your-employment-contract-how-it-can-be-changed/dealing-with-problems': 2,
#  '/pension-credit': 2,
#  '/calculate-your-holiday-entitlement': 2,
#  '/contact-student-finance-england': 2,
#  '/guidance/apply-for-a-kickstart-scheme-grant': 2,
#  '/become-lorry-bus-driver': 2,
#  '/call-charges': 2,
#  '/uk-visa-sponsorship-employers/sponsorship-management-roles': 2,
#  '/universal-credit/changes-of-circumstances': 2,
#  '/working-tax-credit': 2,
#  '/advanced-learner-loan/what-youll-get': 2,
#  '/after-a-death/organisations-you-need-to-contact-and-tell-us-once': 2,
#  '/government/publications/find-a-skills-bootcamp/list-of-skills-bootcamps': 2,
#  '/check-immigration-status': 2,
#  '/government/publications/your-new-state-pension-explained/your-state-pension-explained': 2,
#  '/personal-tax-account/sign-in/create-account': 2,
#  '/claim-loss-notice': 2,
#  '/rest-breaks-work/taking-breaks': 2,
#  '/employ-someone': 2,
#  '/night-working-hours': 2,
#  '/jobseekers-allowance/apply-new-style-jsa': 2,
#  '/guidance/redundancy-help-finding-work-and-claiming-benefits': 2,
#  '/handing-in-your-notice': 2,
#  '/browse/education/student-finance': 2,
#  '/government/organisations/disclosure-and-barring-service/about': 2,
#  '/what-different-qualification-levels-mean/list-of-qualification-levels': 2,
#  '/jobseekers-allowance/your-jsa-claim': 2,
#  '/employment-support-allowance/working-while-you-claim': 2,
#  '/browse/births-deaths-marriages/register-offices': 2,
#  '/shared-parental-leave-and-pay': 2,
#  '/uk-visa-sponsorship-employers/job-suitability': 2,
#  '/further-education-courses/if-youre-16-or-17': 2,
#  '/guidance/coronavirus-covid-19-what-to-do-if-youre-employed-and-cannot-work': 2,
#  '/government/organisations/pension-service': 2,
#  '/get-a-passport-urgently/online-premium-service': 2,
#  '/1619-bursary-fund': 2,
#  '/eu-eea': 2,
#  '/apply-medal-or-veterans-badge': 2,
#  '/guidance/claim-for-wage-costs-through-the-coronavirus-job-retention-scheme': 2,
#  '/test-and-trace-support-payment': 2,
#  '/constant-attendance-allowance': 2,
#  '/pension-credit/what-youll-get': 2,
#  '/guidance/how-your-trading-conditions-affect-your-eligibility-for-the-self-employment-income-support-scheme': 2,
#  '/log-in-file-self-assessment-tax-return': 2,
#  '/guidance/claim-for-wages-through-the-coronavirus-job-retention-scheme': 2,
#  '/contracted-out/old-state-pension': 2,
#  '/browse/business/finance-support': 2,
#  '/universal-credit/what-youll-get': 2,
#  '/apply-start-up-loan': 2,
#  '/government/publications/employment-and-support-allowance-permitted-work-form/permitted-work-factsheet': 2,
#  '/government/publications/attendance-allowance-claim-form': 2,
#  '/state-pension/circumstances-change': 2,
#  '/fixed-term-contracts/renewing-or-ending-a-fixedterm-contract': 2,
#  '/maximum-weekly-working-hours/calculating-your-working-hours': 2,
#  '/tax-national-insurance-after-state-pension-age/stopping-paying-national-insurance': 2,
#  '/tell-hmrc-change-of-details/income-changes': 2,
#  '/browse/driving/driving-licences': 2,
#  '/government/publications/apprenticeship-technical-funding-guide': 2,
#  '/settled-status-eu-citizens-families/family-member-eligible-person-from-northern-ireland': 2,
#  '/statutory-sick-pay/what-youll-get': 2,
#  '/housing-and-universal-credit': 2,
#  '/redundancy-your-rights/suitable-alternative-employment': 2,
#  '/browse/citizenship/voting': 2,
#  '/handing-in-your-notice/gardening-leave': 2,
#  '/government/publications/traineeship-providers': 2,
#  '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means': 2,
#  '/guidance/new-style-jobseekers-allowance': 2,
#  '/report-unfit-work-children-vulnerable-adults': 2,
#  '/handing-in-your-notice/payment-during-your-notice-period': 2,
#  '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member': 2,
#  '/state-pension-if-you-retire-abroad': 2,
#  '/student-finance/new-fulltime-students': 2,
#  '/plan-retirement-income': 2,
#  '/overseas-domestic-worker-visa': 2,
#  '/the-warm-home-discount-scheme/low-income': 2,
#  '/access-to-work/apply': 2,
#  '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults': 2,
#  '/find-pension-centre': 2,
#  '/government/organisations/hm-revenue-customs/services-information': 2,
#  '/maternity-pay-leave/extra-help': 2,
#  '/time-off-for-dependants/whats-an-emergency': 2,
#  '/government/publications/disclosure-application-process-for-volunteers/disclosure-application-process-for-volunteers': 2,
#  '/new-state-pension/what-youll-get': 2,
#  '/budgeting-help-benefits/after-you-apply': 2,
#  '/copy-of-police-records': 2,
#  '/check-state-pension': 2,
#  '/voluntary-national-insurance-contributions': 2,
#  '/parental-leave': 2,
#  '/national-minimum-wage/employers-and-the-minimum-wage': 2,
#  '/visa-documents-returned': 2,
#  '/government/organisations/hm-revenue-customs/contact/change-your-personal-details': 2,
#  '/get-document-legalised': 2,
#  '/apply-council-tax-reduction': 2,
#  '/guidance/barring-referrals': 2,
#  '/find-postgraduate-teacher-training-courses': 2,
#  '/pension-credit-calculator': 2,
#  '/access-to-work/renew': 2,
#  '/claim-benefits-abroad': 2,
#  '/new-state-pension/how-to-claim': 2,
#  '/youth-mobility': 2,
#  '/funeral-payments': 2,
#  '/register-employer': 2,
#  '/holiday-entitlement-rights/workers-furlough-coronavirus': 2,
#  '/government/organisations/civil-service/about/recruitment': 2,
#  '/income-support/report-a-change-of-circumstances': 2,
#  '/browse/employing-people/dismissals-redundancies': 2,
#  '/government/organisations/hm-revenue-customs': 2,
#  '/topic/benefits-credits/tax-credits': 2,
#  '/calculate-statutory-sick-pay': 2,
#  '/healthcare-immigration-application': 2,
#  '/guidance/return-to-your-claim-for-the-self-employment-income-support-scheme': 2,
#  '/tell-employer-or-college-about-criminal-record/fines-and-compensation': 2,
#  '/government/collections/statutory-pay-forms': 2,
#  '/employment-status/employee': 2,
#  '/topic/dealing-with-hmrc/paying-hmrc': 2,
#  '/child-employment/restrictions-on-child-employment': 2,
#  '/financial-help-disabled/vehicles-and-transport': 2,
#  '/moving-from-benefits-to-work/help-for-specific-problems': 2,
#  '/state-pension/what-youll-get': 2,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-standardenhanced-dbs-check-applications-from-1-july-2021': 2,
#  '/get-coronavirus-test': 2,
#  '/carers-allowance-unit': 2,
#  '/industrial-injuries-disablement-benefit/eligibility': 2,
#  '/30-hours-free-childcare': 2,
#  '/tax-codes/tell-hmrc-about-a-change-tax-code': 2,
#  '/jobcentre-plus-help-for-recruiters/recruitment-advice-and-support': 2,
#  '/government/collections/apprenticeship-vacancies': 2,
#  '/tell-employer-or-college-about-criminal-record/what-information-you-need-to-give': 2,
#  '/government/publications/employment-and-support-allowance-permitted-work-form': 2,
#  '/id-scan-eu-settlement-scheme': 2,
#  '/guidance/visa-decision-waiting-times-applications-inside-the-uk': 2,
#  '/standard-visitor-visa': 2,
#  '/guidance/register-of-apprenticeship-training-providers': 2,
#  '/payslips': 2,
#  '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant': 2,
#  '/moving-or-retiring-abroad': 2,
#  '/learn-to-drive-a-car': 2,
#  '/personal-pensions-your-rights': 2,
#  '/browse/driving/vehicle-tax-mot-insurance': 2,
#  '/income-tax': 2,
#  '/employers-sick-pay/entitlement': 2,
#  '/agency-workers-your-rights/basic-information-you-should-receive': 2,
#  '/sign-in-help-to-save': 2,
#  '/employing-an-apprentice/get-funding': 2,
#  '/browse/visas-immigration/eu-eea-swiss': 2,
#  '/government/publications/child-benefit-claim-form-ch2': 2,
#  '/guidance/pensions-and-compensation-for-veterans': 2,
#  '/residence-documents-foreign-nationals-uk': 2,
#  '/sure-start-maternity-grant/how-to-claim': 2,
#  '/education-maintenance-allowance-ema': 2,
#  '/advanced-learner-loan/how-to-apply': 2,
#  '/working-tax-credit/what-youll-get': 2,
#  '/government/collections/citizenship-application-forms': 2,
#  '/set-up-sole-trader': 2,
#  '/guidance/national-minimum-wage-work-experience-and-internships': 2,
#  '/jobseekers-allowance/apply-new-style-jsa/eligibility': 2,
#  '/british-national-overseas-bno-visa': 2,
#  '/child-trust-funds/managing-the-account': 2,
#  '/government/publications/apprenticeship-levy-how-it-will-work/apprenticeship-levy-how-it-will-work': 2,
#  '/get-proof-employment-history': 2,
#  '/guidance/brexit-guidance-for-individuals-and-families': 2,
#  '/tax-on-pension/how-your-tax-is-paid': 2,
#  '/driving-medical-conditions': 2,
#  '/tips-at-work': 2,
#  '/plan-for-retirement': 2,
#  '/skilled-worker-visa/switch-to-this-visa': 2,
#  '/government/publications/register-of-licensed-sponsors-students': 2,
#  '/order-coronavirus-rapid-lateral-flow-tests': 2,
#  '/government/publications/dbs-continuation-sheet': 2,
#  '/view-driving-licence': 2,
#  '/sponsor-management-system': 2,
#  '/vehicles-can-drive': 2,
#  '/disciplinary-procedures-and-action-at-work/how-disciplinary-procedures-work': 2,
#  '/right-of-abode/commonwealth-citizens': 2,
#  '/find-an-immigration-adviser': 2,
#  '/career-breaks': 2,
#  '/handing-in-your-notice/giving-notice': 2,
#  '/careers-helpline-for-teenagers': 2,
#  '/income-support/if-you-already-get-income-support': 2,
#  '/topic/immigration-operational-guidance/immigration-rules': 2,
#  '/tell-hmrc-change-address': 2,
#  '/plan-retirement-income/private-pensions': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-a-to-f-applying-for-a-criminal-records-check-for-someone-from-overseas': 2,
#  '/universal-credit/contact-universal-credit': 2,
#  '/sure-start-maternity-grant/what-youll-get': 2,
#  '/government/publications/universal-credit-work-allowances/universal-credit-work-allowances': 2,
#  '/guidance/track-a-dbs-application': 2,
#  '/learner-support': 2,
#  '/student-finance-register-login': 2,
#  '/welfare/jobseekers-allowance': 2,
#  '/uk-visa-sponsorship-employers/eligibility': 2,
#  '/visa-to-study-english': 2,
#  '/get-help-savings-low-income': 2,
#  '/vehicle-tax': 2,
#  '/statutory-sick-pay/eligibility': 2,
#  '/bereavement-support-payment/how-to-claim': 2,
#  '/government/collections/statutory-sick-pay-and-leave': 2,
#  '/search/policy-papers-and-consultations': 2,
#  '/report-cash-in-hand-pay': 2,
#  '/government/publications/application-for-a-state-pension-statement': 2,
#  '/browse/tax/income-tax': 2,
#  '/guidance/using-the-uk-immigration-id-check-app': 2,
#  '/holiday-entitlement-rights/holiday-pay-the-basics': 2,
#  '/government/publications/apprenticeships-off-the-job-training': 2,
#  '/topic/further-education-skills/administration': 2,
#  '/government/publications/basic-check-guidance-and-policies/basic-check-id-checking-guidelines-from-1-july-2021': 2,
#  '/claim-tax-credits': 2,
#  '/student-visa/family-members': 2,
#  '/workplace-temperatures': 2,
#  '/employment-support-allowance': 2,
#  '/settled-status-eu-citizens-families/applying-for-settled-status': 2,
#  '/transferring-your-pension': 2,
#  '/housing-benefit/what-youll-get': 2,
#  '/state-pension-age': 2,
#  '/government/publications/dbs-identity-checking-guidelines': 2,
#  '/check-vehicle-tax': 2,
#  '/support-visit-benefit-claim': 2,
#  '/uk-border-control/before-you-leave-for-the-uk': 2,
#  '/government/organisations/the-pensions-advisory-service': 2,
#  '/plan-shared-parental-leave-pay': 2,
#  '/repaying-your-student-loan': 2,
#  '/check-income-tax-current-year/sign-in/create-account': 2,
#  '/early-retirement-pension/benefits': 2,
#  '/government/organisations/companies-house': 2,
#  '/paye-forms-p45-p60-p11d/lost-paye-forms': 2,
#  '/universal-credit/how-to-claim': 2,
#  '/government/publications/employing-disabled-people-and-people-with-health-conditions/employing-disabled-people-and-people-with-health-conditions': 2,
#  '/government/collections/illegal-working-penalties-codes-of-practice-for-employers': 2,
#  '/update-uk-visas-immigration-account-details': 2,
#  '/apply-housing-benefit-from-council': 2,
#  '/guidance/how-to-quarantine-when-you-arrive-in-england': 2,
#  '/government/publications/access-to-work-guide-for-employers': 2,
#  '/skilled-worker-visa/if-you-work-in-healthcare-or-education': 2,
#  '/contracted-out': 2,
#  '/topic/further-education-skills/vocational-qualifications': 2,
#  '/am-i-getting-minimum-wage': 2,
#  '/government/publications/dbs-workforce-guidance': 2,
#  '/tell-employer-or-college-about-criminal-record/cautions': 2,
#  '/guidance/national-skills-fund': 2,
#  '/dismissal/what-to-do-if-youre-dismissed': 2,
#  '/report-benefit-fraud': 2,
#  '/skilled-worker-visa/your-partner-and-children': 2,
#  '/browse/driving/number-plate': 2,
#  '/moving-from-benefits-to-work/job-search-programmes': 2,
#  '/raise-grievance-at-work': 2,
#  '/find-lost-utr-number': 2,
#  '/government/publications/introducing-govuk-verify/introducing-govuk-verify': 2,
#  '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education': 2,
#  '/government/publications/national-insurance-employment-history-request': 2,
#  '/financial-help-disabled/television-licence-discount': 2,
#  '/national-insurance-rates-letters': 2,
#  '/skilled-worker-visa/your-job': 2,
#  '/contact-hmrc': 2,
#  '/dismiss-staff': 2,
#  '/agency-workers-your-rights': 2,
#  '/guidance/new-style-employment-and-support-allowance': 2,
#  '/government/collections/helping-young-people-into-work': 2,
#  '/biometric-residence-permits': 2,
#  '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed': 2,
#  '/government/publications/maternity-allowance-claim-form': 2,
#  '/apply-first-provisional-driving-licence': 2,
#  '/carers-credit': 2,
#  '/how-tax-credits-affect-other-benefits': 2,
#  '/armed-forces-pension-calculator': 2,
#  '/redundancy-your-rights/get-help-finding-a-new-job': 2,
#  '/driving-nongb-licence': 2,
#  '/sign-in-childcare-account': 2,
#  '/if-you-become-disabled/if-youre-in-employment-and-become-disabled': 2,
#  '/child-benefit/how-to-claim': 2,
#  '/your-employment-contract-how-it-can-be-changed': 2,
#  '/find-out-dbs-check': 2,
#  '/housing-benefit/how-to-claim': 2,
#  '/coronavirus/business-support': 2,
#  '/self-employed-records': 2,
#  '/log-in-register-hmrc-online-services/register': 2,
#  '/child-benefit-payment-dates': 2,
#  '/winter-fuel-payment/eligibility': 2,
#  '/employers-sick-pay/eligibility-and-form-ssp1': 2,
#  '/uk-border-control': 2,
#  '/how-to-claim-new-style-esa': 2,
#  '/guidance/basic-dbs-checks-guidance': 2,
#  '/new-employee/employee-information': 2,
#  '/support-for-mortgage-interest/eligibility': 2,
#  '/pip/how-to-claim': 2,
#  '/guidance/working-safely-during-covid-19': 2,
#  '/national-concessionary-fuel-scheme': 2,
#  '/personal-tax-account': 2,
#  '/grant-bursary-adult-learners': 2,
#  '/renewing-your-tax-credits-claim': 2,
#  '/additional-state-pension': 2,
#  '/voluntary-national-insurance-contributions/who-can-pay-voluntary-contributions': 2,
#  '/government/topical-events/plan-for-jobs': 2,
#  '/browse/visas-immigration/what-you-need-to-do': 2,
#  '/reasonable-adjustments-for-disabled-workers': 2,
#  '/government/collections/dbs-checking-service-guidance--2': 2,
#  '/uk-benefits-abroad': 2,
#  '/financial-help-disabled/on-a-low-salary': 2,
#  '/death-spouse-benefits-tax-pension/benefits': 2,
#  '/guidance/eu-settlement-scheme-evidence-of-uk-residence': 2,
#  '/government/publications/easy-read-get-help-at-work-if-youre-disabled-or-have-a-health-condition-access-to-work': 2,
#  '/help/terms-conditions': 2,
#  '/check-national-insurance-record': 2,
#  '/financial-help-disabled': 2,
#  '/guidance/rehabilitation-periods': 2,
#  '/tax-free-childcare': 2,
#  '/government/publications/the-basic-state-pension': 2,
#  '/settle-in-the-uk': 2,
#  '/set-up-business': 2,
#  '/renew-driving-licence-at-70': 2,
#  '/moving-from-benefits-to-work/help-for-parents-and-carers': 2,
#  '/tax-relief-for-employees': 2,
#  '/browse/disabilities/rights': 2,
#  '/advanced-learner-loan/bursary-fund': 2,
#  '/government/publications/dbs-update-service-employer-guide': 2,
#  '/national-insurance-credits/eligibility': 2,
#  '/visa-fees': 2,
#  '/browse/visas-immigration/asylum': 2,
#  '/voluntary-national-insurance-contributions/rates': 2,
#  '/browse/tax/self-assessment': 2,
#  '/working-retirement-pension-age': 2,
#  '/check-tenant-right-to-rent-documents': 2,
#  '/english-language': 2,
#  '/update-uk-visas-immigration-account-details/update-your-ukvi-account': 2,
#  '/minimum-wage-different-types-work/paid-an-annual-salary': 2,
#  '/change-circumstances-visa-brp': 2,
#  '/employing-an-apprentice/pay-and-conditions-for-apprentices': 2,
#  '/income-support/income-support-rates': 2,
#  '/tax-come-to-uk': 2,
#  '/government/publications/dbs-update-service-employer-guide/dbs-update-service-employer-guide': 2,
#  '/whistleblowing': 2,
#  '/government/publications/paye-starter-checklist': 2,
#  '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403': 2,
#  '/workplace-pensions': 2,
#  '/paternity-pay-leave': 2,
#  '/employment-contracts-and-conditions': 2,
#  '/disabled-facilities-grants': 2,
#  '/further-education-skills/apprenticeships': 2,
#  '/faster-decision-visa-settlement': 2,
#  '/find-pension-contact-details': 2,
#  '/health-conditions-disability-universal-credit': 2,
#  '/keeping-your-pay-tax-records': 2,
#  '/when-someone-dies': 2,
#  '/tax-credits-overpayments': 2,
#  '/check-tenant-right-to-rent-documents/how-to-check': 2,
#  '/browse/education/school-life': 2,
#  '/working-abroad': 2,
#  '/view-prove-immigration-status': 2,
#  '/overtime-your-rights': 2,
#  '/government/publications/qualifications-in-new-funded-offers': 2,
#  '/agency-workers-your-rights/your-rights-as-a-temporary-agency-worker': 2,
#  '/redundancy-your-rights': 2,
#  '/government/organisations/home-office/about/recruitment': 2,
#  '/childcare-calculator': 2,
#  '/maternity-pay-leave/pay': 2,
#  '/housing-and-universal-credit/property-you-own': 2,
#  '/child-employment/local-council-rules-for-child-employment-permits': 2,
#  '/housing-and-universal-credit/renting-from-private-landlord': 2,
#  '/contract-types-and-employer-responsibilities/fulltime-and-parttime-contracts': 2,
#  '/government/publications/dbs-list-of-offences-that-will-never-be-filtered-from-a-criminal-record-check': 2,
#  '/guidance/coronavirus-covid-19-what-to-do-if-youre-self-employed-and-getting-less-work-or-no-work': 2,
#  '/severe-disablement-allowance': 2,
#  '/government/publications/dbs-filtering-guidance/dbs-filtering-guide': 2,
#  '/ancestry-visa': 2,
#  '/minimum-wage-different-types-work/paid-by-the-hour': 2,
#  '/seasonal-worker-visa/eligibility': 2,
#  '/government/publications/sector-based-work-academies-employer-guide': 2,
#  '/become-appointee-for-someone-claiming-benefits': 2,
#  '/dla-disability-living-allowance-benefit/dla-rates': 2,
#  '/government/publications/dbs-application-forms-guide-for-applicants': 2,
#  '/maternity-pay-leave': 2,
#  '/claim-tax-refund': 2,
#  '/budgeting-help-benefits/what-youll-get': 2,
#  '/change-address-driving-licence': 2,
#  '/book-theory-test': 2,
#  '/check-mot-history': 2,
#  '/guidance/coronavirus-covid-19-testing-for-people-travelling-to-england': 2,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship/borders-immigration-and-citizenship-privacy-information-notice': 2,
#  '/benefit-cap/how-earnings-affect-when-benefit-cap-starts': 2,
#  '/paye-forms-p45-p60-p11d/p11d': 2,
#  '/when-mental-health-condition-becomes-disability': 2,
#  '/employer-preventing-discrimination': 2,
#  '/standard-visitor-visa/documents-you-will-need': 2,
#  '/check-income-tax-current-year/sign-in/prove-identity': 2,
#  '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide': 2,
#  '/disability-living-allowance-children': 2,
#  '/government/publications/the-official-hmrc-app': 2,
#  '/working-for-yourself': 2,
#  '/national-minimum-wage': 2,
#  '/benefit-cap': 2,
#  '/employee-rights-when-on-leave': 2,
#  '/change-name-deed-poll': 2,
#  '/assisted-digital-help-online-applications': 2,
#  '/government/publications/eu-settlement-scheme-application-processing-times/eu-settlement-scheme-pilot-current-expected-processing-times-for-applications': 2,
#  '/entering-staying-uk': 2,
#  '/education': 2,
#  '/rest-breaks-work/compensatory-rest': 2,
#  '/browse/visas-immigration/commonwealth-british-nationals-overseas': 2,
#  '/working-tax-credit/how-to-claim': 2,
#  '/get-copy-military-service-records/apply-for-your-own-records': 2,
#  '/maternity-allowance': 2,
#  '/topic/benefits-credits/child-benefit': 2,
#  '/self-employed-national-insurance-rates': 2,
#  '/government/organisations/department-for-education/services-information': 2,
#  '/national-insurance-credits': 2,
#  '/volunteering/pay-and-expenses': 2,
#  '/government/organisations/hm-revenue-customs/contact/self-assessment': 2,
#  '/1619-bursary-fund/how-to-claim': 2,
#  '/income-tax/how-you-pay-income-tax': 2,
#  '/guidance/recruiting-people-from-outside-the-uk': 2,
#  '/book-driving-test': 2,
#  '/tax-on-your-private-pension': 2,
#  '/tell-hmrc-change-of-details': 2,
#  '/self-assessment-forms-and-helpsheets': 2,
#  '/national-minimum-wage-rates': 2,
#  '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions': 2,
#  '/guidance/nhs-covid-pass': 2,
#  '/what-different-qualification-levels-mean/compare-different-qualification-levels': 2,
#  '/order-copy-birth-death-marriage-certificate': 2,
#  '/higher-education-courses-find-and-apply': 2,
#  '/guidance/check-if-you-could-be-covered-by-the-coronavirus-job-retention-scheme': 2,
#  '/child-benefit/what-youll-get': 2,
#  '/income-tax/taxfree-and-taxable-state-benefits': 2,
#  '/criminal-record-check-become-driving-instructor': 2,
#  '/claim-redundancy': 2,
#  '/business-support-helpline': 2,
#  '/personal-pensions-your-rights/how-you-can-take-pension': 2,
#  '/register-birth': 2,
#  '/government/publications/acceptable-right-to-work-documents-an-employers-guide': 2,
#  '/overtime-your-rights/parttime-workers': 2,
#  '/education/further-and-higher-education-skills-and-vocational-training': 2,
#  '/browse/visas-immigration/tourist-short-stay-visas': 2,
#  '/browse/education/universities-higher-education': 2,
#  '/government/organisations/department-of-health-and-social-care': 2,
#  '/agricultural-sick-pay': 2,
#  '/business-finance-support': 2,
#  '/maximum-weekly-working-hours': 2,
#  '/government/organisations/foreign-commonwealth-office': 2,
#  '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships': 2,
#  '/guidance/criminal-record-checks-for-childminders-and-childcare-workers': 2,
#  '/agency-workers-your-rights/pay': 2,
#  '/work/pensions-and-ageing-society': 2,
#  '/benefit-cap/when-youre-not-affected': 2,
#  '/topic/personal-tax/self-assessment': 2,
#  '/government/publications/skilled-worker-visa-eligible-healthcare-and-education-jobs': 2,
#  '/government/publications/rates-and-allowances-national-insurance-contributions/rates-and-allowances-national-insurance-contributions': 2,
#  '/caution-warning-penalty': 2,
#  '/business-coronavirus-support-finder': 2,
#  '/workplace-pensions/managing-your-pension': 2,
#  '/tax-codes/emergency-tax-codes': 2,
#  '/how-to-have-your-benefits-paid': 2,
#  '/staff-redundant': 2,
#  '/additional-state-pension/inheriting': 2,
#  '/check-driving-information': 2,
#  '/browse/citizenship/charities-honours': 2,
#  '/income-tax/find-out-if-you-need-to-pay-income-tax': 2,
#  '/settled-status-eu-citizens-families/after-youve-applied': 2,
#  '/get-state-pension': 2,
#  '/mandatory-reconsideration': 2,
#  '/browse/benefits/bereavement': 2,
#  '/check-income-tax-last-year': 2,
#  '/reduced-national-insurance-married-women': 2,
#  '/browse/childcare-parenting/pregnancy-birth': 2,
#  '/guidance/incentive-payments-for-hiring-a-new-apprentice': 2,
#  '/chwilio-am-swydd': 2,
#  '/browse/childcare-parenting/childcare': 2,
#  '/settled-status-eu-citizens-families': 2,
#  '/browse/visas-immigration/immigration-appeals': 2,
#  '/new-state-pension/youve-been-in-a-workplace-personal-or-stakeholder-pension': 2,
#  '/support-for-mortgage-interest': 2,
#  '/redundancy-your-rights/redundancy-pay': 2,
#  '/pip/claiming-pip-if-youre-terminally-ill': 2,
#  '/employment-contracts-and-conditions/written-statement-of-employment-particulars': 2,
#  '/carers-allowance/how-to-claim': 2,
#  '/government/publications/the-national-minimum-wage-in-2021': 2,
#  '/your-rights-if-your-employer-is-insolvent': 2,
#  '/student-jobs-paying-tax': 2,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-numbers': 2,
#  '/skilled-worker-visa/apply-from-outside-the-uk': 2,
#  '/pip/what-youll-get': 2,
#  '/recruit-apprentice': 2,
#  '/guidance/settled-status-for-eu-citizens-and-their-families-translations': 2,
#  '/report-problem-criminal-record-certificate/appeal-against-a-new-barring-decision': 2,
#  '/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance': 2,
#  '/government/publications/income-tax-leaving-the-uk-getting-your-tax-right-p85': 2,
#  '/transferring-your-pension/transferring-to-a-uk-pension-scheme': 2,
#  '/moving-from-benefits-to-work/starting-your-own-business': 2,
#  '/national-insurance/your-national-insurance-number': 2,
#  '/state-pension-through-partner': 2,
#  '/rest-breaks-work': 2,
#  '/disability-premiums/eligibility': 2,
#  '/uk-family-visa/partner-spouse': 2,
#  '/identitycards': 2,
#  '/guidance/responsible-organisations': 2,
#  '/right-of-abode': 2,
#  '/workplace-pensions/if-you-want-to-leave-your-workplace-pension-scheme': 2,
#  '/apply-standard-visitor-visa': 2,
#  '/paternity-pay-leave/pay': 2,
#  '/dbs-check-applicant-criminal-record/get-a-basic-dbs-check-for-an-employee': 2,
#  '/plan-retirement-income/get-financial-advice': 2,
#  '/income-tax-rates': 2,
#  '/private-renting': 2,
#  '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service': 2,
#  '/independent-livingfund': 2,
#  '/browse/disabilities/work': 2,
#  '/national-insurance/how-much-you-pay': 2,
#  '/search/research-and-statistics': 2,
#  '/running-payroll': 2,
#  '/maximum-weekly-working-hours/weekly-maximum-working-hours-and-opting-out': 2,
#  '/biometric-residence-permits/collect': 2,
#  '/guidance/prove-your-english-language-abilities-with-a-secure-english-language-test-selt': 2,
#  '/future-pension-centre': 2,
#  '/become-magistrate': 2,
#  '/child-tax-credit/new-claim': 2,
#  '/redundancy-your-rights/consultation': 2,
#  '/tax-on-pension-death-benefits': 2,
#  '/pay-self-assessment-tax-bill': 2,
#  '/welfare/entitlement': 2,
#  '/paternity-pay-leave/how-to-claim': 2,
#  '/parents-learning-allowance': 2,
#  '/solve-workplace-dispute': 2,
#  '/government/publications/skilled-worker-visa-eligible-occupations': 2,
#  '/government/publications/sure-start-maternity-grant-claim-form': 2,
#  '/self-employed-records/what-records-to-keep': 2,
#  '/government/publications/view-and-prove-your-immigration-status-evisa': 2,
#  '/guidance/pay-apprenticeship-levy': 2,
#  '/eusettledstatus': 2,
#  '/rights-disabled-person': 2,
#  '/standard-visitor-visa/what-you-can-do-in-the-uk': 2,
#  '/council-tax-bands': 2,
#  '/apply-to-come-to-the-uk/prepare-your-application': 2,
#  '/appeal-benefit-decision': 2,
#  '/government/publications/apprenticeship-agreement-template': 2,
#  '/carers-credit/eligibility': 2,
#  '/renew-adult-passport/renew': 2,
#  '/limited-company-formation': 2,
#  '/employment-support-allowance/change-of-circumstances': 2,
#  '/reduced-earnings-allowance': 2,
#  '/pay-and-work-rights': 2,
#  '/maternity-allowance/how-to-claim': 2,
#  '/guidance/get-help-with-benefits-and-pensions-if-you-have-accessibility-needs': 2,
#  '/state-pension/inheritance': 2,
#  '/holiday-entitlement-rights/calculate-leave-entitlement': 2,
#  '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries': 2,
#  '/workplace-bullying-and-harassment': 2,
#  '/disability-benefits-helpline': 2,
#  '/government/publications/find-a-skills-bootcamp': 2,
#  '/time-off-for-dependants/taking-time-off': 2,
#  '/uk-visa-sponsorship-employers/types-of-licence': 2,
#  '/guidance/apprenticeship-funding-rules': 2,
#  '/guidance/benefits-and-pensions-for-uk-nationals-in-the-eea-or-switzerland': 2,
#  '/housing-benefit/report-a-change-of-circumstances': 2,
#  '/government/publications/view-and-prove-your-immigration-status-evisa/your-immigration-status-an-introduction-for-eu-eea-and-swiss-citizens-accessible-version': 2,
#  '/tax-national-insurance-after-state-pension-age': 2,
#  '/skilled-worker-visa/second-job': 2,
#  '/temporary-worker-charity-worker-visa': 2,
#  '/settled-status-eu-citizens-families/eligibility': 2,
#  '/claim-national-insurance-refund': 2,
#  '/government/publications/right-to-work-checklist': 2,
#  '/pensions-advisory-service': 2,
#  '/benefit-overpayments/how-to-make-a-repayment': 2,
#  '/your-employment-contract-how-it-can-be-changed/making-changes': 2,
#  '/government/publications/dbs-filtering-guidance': 2,
#  '/apply-for-council-housing': 2,
#  '/entering-staying-uk/foreign-nationals-working-in-uk': 2,
#  '/uk-family-visa': 2,
#  '/disability-premiums': 2,
#  '/government/organisations/hm-revenue-customs/contact/get-help-with-the-self-employment-income-support-scheme': 2,
#  '/government/publications/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19': 2,
#  '/apply-online-for-student-finance': 2,
#  '/holiday-entitlement-rights/taking-holiday-before-leaving-a-job': 2,
#  '/child-benefit-tax-calculator': 2,
#  '/new-state-pension/how-its-calculated': 2,
#  '/get-ready-to-employ-someone': 2,
#  '/holiday-entitlement-rights/booking-time-off-': 2,
#  '/sure-start-maternity-grant/eligibility': 2,
#  '/report-benefits-change-circumstances': 2,
#  '/pip/change-of-circumstances': 2,
#  '/time-off-for-dependants/problems-when-you-take-time-off': 2,
#  '/claim-tax-credits/what-counts-as-income': 2,
#  '/government/organisations/department-of-social-security': 2,
#  '/guidance/immigration-rules/immigration-rules-part-5-working-in-the-uk': 2,
#  '/when-is-your-next-tax-credits-payment': 2,
#  '/get-paye-forms-p45-p60': 2,
#  '/topic/higher-education/scholarships-for-overseas-students': 2,
#  '/guidance/manage-apprenticeship-funds': 2,
#  '/au-pairs-employment-law': 2,
#  '/browse/citizenship/citizenship': 2,
#  '/guidance/help-employers-apply-for-a-kickstart-scheme-grant-kickstart-gateway': 2,
#  '/penalty-points-endorsements/how-to-check-your-endorsement-details': 2,
#  '/biometric-residence-permits/report-problem': 2,
#  '/guidance/using-the-eu-exit-id-document-check-app': 2,
#  '/government/publications/dbs-check-eligible-positions-guidance': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-q-z': 2,
#  '/bereavement-support-payment': 2,
#  '/tell-employer-or-college-about-criminal-record/check-your-conviction-caution': 2,
#  '/further-education-courses/find-a-course': 2,
#  '/national-insurance-if-you-go-abroad': 2,
#  '/personal-tax-account/sign-in/prove-identity': 2,
#  '/find-coronavirus-support': 2,
#  '/disciplinary-procedures-and-action-at-work': 2,
#  '/universal-credit/other-financial-support': 2,
#  '/help/accessibility-statement': 2,
#  '/tell-employer-or-college-about-criminal-record/discharges': 2,
#  '/get-tax-free-childcare': 2,
#  '/rest-breaks-work/exceptions': 2,
#  '/dismissal/reasons-you-can-be-dismissed': 2,
#  '/employing-an-apprentice': 2,
#  '/government/publications/jobseekers-allowance-sanctions-leaflet/jobseekers-allowance-sanctions-how-to-keep-your-benefit-payment': 2,
#  '/government/organisations/foreign-commonwealth-development-office': 2,
#  '/government/publications/eu-settlement-scheme-application-processing-times': 2,
#  '/definition-of-disability-under-equality-act-2010': 2,
#  '/early-retirement-pension/personal-and-workplace-pensions': 2,
#  '/winter-fuel-payment/how-much-youll-get': 2,
#  '/international-agreement-worker-visa': 2,
#  '/discrimination-your-rights/discrimination-at-work': 2,
#  '/budgeting-help-benefits/how-to-apply': 2,
#  '/employer-preventing-discrimination/recruitment': 2,
#  '/track-your-driving-licence-application': 2,
#  '/government-authorised-exchange': 2,
#  '/government/organisations/uk-visas-and-immigration': 2,
#  '/check-state-pension/sign-in/create-account': 2,
#  '/carers-allowance/eligibility': 2,
#  '/topic/personal-tax/income-tax': 2,
#  '/paye-forms-p45-p60-p11d': 2,
#  '/lost-national-insurance-number': 2,
#  '/employment-support-allowance/your-esa-claim': 2,
#  '/further-education-courses/financial-help': 2,
#  '/terminal-illness-benefits': 2,
#  '/maternity-pay-leave/how-to-claim': 2,
#  '/frontier-worker-permit': 2,
#  '/guidance/visa-decision-waiting-times-applications-outside-the-uk': 2,
#  '/windrush-prove-your-right-to-be-in-the-uk': 2,
#  '/overtime-your-rights/time-off-and-paid-leave': 2,
#  '/employers-sick-pay': 2,
#  '/child-benefit/eligibility': 2,
#  '/maternity-allowance/what-youll-get': 2,
#  '/government/organisations/department-for-work-pensions/about/complaints-procedure': 2,
#  '/topic/immigration-operational-guidance': 2,
#  '/calculate-your-redundancy-pay': 2,
#  '/adoption-pay-leave': 2,
#  '/uk-visa-sponsorship-employers/certificates-of-sponsorship': 2,
#  '/industrial-injuries-disablement-benefit': 2,
#  '/guidance/eu-settlement-scheme-how-we-use-your-personal-information': 2,
#  '/guidance/covid-19-how-dbs-is-supporting-the-fight-against-coronavirus': 2,
#  '/career-development-loans': 2,
#  '/report-problem-criminal-record-certificate/dispute-a-mistake': 2,
#  '/workplace-pensions-employers': 2,
#  '/pension-credit/how-to-claim': 2,
#  '/minimum-wage-different-types-work': 2,
#  '/deferring-state-pension/what-you-get': 2,
#  '/employment-support-allowance/eligibility': 2,
#  '/graduate-visa/apply': 2,
#  '/death-spouse-benefits-tax-pension': 2,
#  '/lay-offs-short-timeworking': 2,
#  '/government/collections/dbs-eligibility-guidance': 2,
#  '/workplace-pensions/joining-a-workplace-pension': 2,
#  '/income-support': 2,
#  '/how-to-claim-new-style-jsa': 2,
#  '/browse/benefits/help-for-carers': 2,
#  '/tell-dvla-changed-address': 2,
#  '/standard-visitor-visa/eligibility': 2,
#  '/government/collections/apprenticeship-changes': 2,
#  '/pension-credit/eligibility': 2,
#  '/family-permit': 2,
#  '/keeping-your-pay-tax-records/how-long-to-keep-your-records': 2,
#  '/understanding-your-pay': 2,
#  '/guidance/coronavirus-covid-19-test-to-release-for-international-travel': 2,
#  '/housing-benefit': 2,
#  '/guidance/traineeship-information-for-employers': 2,
#  '/skilled-worker-visa/how-much-it-costs': 2,
#  '/government/collections/dbs-update-service-promotional-material': 2,
#  '/contact-pension-service': 2,
#  '/attendance-allowance/eligibility': 2,
#  '/guidance/travel-abroad-from-england-during-coronavirus-covid-19': 2,
#  '/topic/business-tax/paye': 2,
#  '/attendance-allowance': 2,
#  '/government/organisations/driver-and-vehicle-licensing-agency': 2,
#  '/guidance/coronavirus-covid-19-right-to-work-checks': 2,
#  ...}

# %%
# seeed0.1: shortest_paths_seed0.1: '/browse/working/finding-job'
shortest_seed0_1 = {
    k: v
    for k, v in sorted(
        shortest_paths_seed0.items(), key=lambda item: item[1], reverse=False
    )
}

# %%
shortest_seed0_1
# Out:
# {'/browse/working/finding-job': 0,
#  '/dbs-update-service': 1,
#  '/government/collections/sponsorship-information-for-employers-and-educators': 1,
#  '/view-right-to-work': 1,
#  '/access-to-work/after-you-have-applied': 1,
#  '/employment-status': 1,
#  '/guidance/dbs-check-requests-guidance-for-employers': 1,
#  '/what-different-qualification-levels-mean': 1,
#  '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers': 1,
#  '/become-apprentice/apply-for-an-apprenticeship': 1,
#  '/browse/working/redundancies-dismissals': 1,
#  '/improve-english-maths-it-skills': 1,
#  '/find-internship': 1,
#  '/contact-ukvi-inside-outside-uk': 1,
#  '/coronavirus/worker-support': 1,
#  '/access-to-work': 1,
#  '/apply-universal-credit': 1,
#  '/work-reference': 1,
#  '/job-offers-your-rights': 1,
#  '/jobseekers-allowance': 1,
#  '/find-a-job': 1,
#  '/browse/working/time-off': 1,
#  '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations': 1,
#  '/topic/work-careers/secondments-with-government': 1,
#  '/manage-your-tax-credits': 1,
#  '/browse/benefits/looking-for-work': 1,
#  '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme': 1,
#  '/government/organisations/disclosure-and-barring-service': 1,
#  '/skilled-worker-visa/knowledge-of-english': 1,
#  '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide/universal-credit-if-you-have-a-disability-or-health-condition': 1,
#  '/government/organisations/department-for-work-pensions/about/recruitment': 1,
#  '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do': 1,
#  '/jobseekers-allowance/eligibility': 1,
#  '/intracompany-transfer-worker-visa': 1,
#  '/sign-in-universal-credit': 1,
#  '/volunteering/when-you-can-volunteer': 1,
#  '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes': 1,
#  '/employee-immigration-employment-status': 1,
#  '/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2': 1,
#  '/guidance/red-amber-and-green-list-rules-for-entering-england': 1,
#  '/jobsearch-rights': 1,
#  '/advertise-job': 1,
#  '/get-information-about-a-company': 1,
#  '/tell-employer-or-college-about-criminal-record': 1,
#  '/get-copy-military-service-records': 1,
#  '/report-problem-criminal-record-certificate': 1,
#  '/universal-credit': 1,
#  '/british-citizenship': 1,
#  '/check-job-applicant-right-to-work': 1,
#  '/pip/eligibility': 1,
#  '/employment-rights-for-interns': 1,
#  '/government/get-involved/take-part/volunteer': 1,
#  '/register-to-vote': 1,
#  '/death-spouse-benefits-tax-pension/pensions': 1,
#  '/check-uk-visa': 1,
#  '/work-health-programme': 1,
#  '/government/organisations': 1,
#  '/government/organisations/home-office': 1,
#  '/settled-status-eu-citizens-families/apply-settled-status-for-child': 1,
#  '/seasonal-worker-visa': 1,
#  '/jobseekers-allowance/report-a-change-of-circumstances': 1,
#  '/browse/working/armed-forces': 1,
#  '/guidance/immigration-rules': 1,
#  '/browse/working/rights-trade-unions': 1,
#  '/tell-employer-or-college-about-criminal-record/driving-convictions': 1,
#  '/government/publications/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens-accessible-version': 1,
#  '/browse/visas-immigration/work-visas': 1,
#  '/career-skills-and-training': 1,
#  '/topic/further-education-skills/apprenticeships': 1,
#  '/government/organisations/department-for-work-pensions/about': 1,
#  '/browse/employing-people/trade-unions': 1,
#  '/browse/working/tax-minimum-wage': 1,
#  '/skilled-worker-visa/documents-you-must-provide': 1,
#  '/apply-apprenticeship': 1,
#  '/volunteering': 1,
#  '/jobcentre-plus-help-for-recruiters': 1,
#  '/contact-jobcentre-plus': 1,
#  '/criminal-record-checks-apply-role': 1,
#  '/contact-the-dvla': 1,
#  '/find-traineeship': 1,
#  '/moving-from-benefits-to-work/support-when-you-start-working': 1,
#  '/tell-employer-or-college-about-criminal-record/prison-sentences': 1,
#  '/exchange-foreign-driving-licence': 1,
#  '/dbs-check-applicant-criminal-record': 1,
#  '/government/publications/skilled-worker-visa-shortage-occupations': 1,
#  '/browse/working/workplace-personal-pensions': 1,
#  '/browse/working/contract-working-hours': 1,
#  '/topic/defence-armed-forces/military-recruitment-training-operations': 1,
#  '/help-with-childcare-costs': 1,
#  '/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work': 1,
#  '/student-finance/who-qualifies': 1,
#  '/child-employment/paying': 1,
#  '/national-insurance/national-insurance-classes': 1,
#  '/government/publications/standard-and-enhanced-dbs-check-privacy-policy/standard-and-enhanced-dbs-check-privacy-policy': 1,
#  '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers': 1,
#  '/government/organisations/hm-revenue-customs/about/recruitment': 1,
#  '/tax-credits-calculator': 1,
#  '/pip/when-your-pip-claim-is-reviewed': 1,
#  '/log-in-register-hmrc-online-services': 1,
#  '/moving-from-benefits-to-work': 1,
#  '/looking-for-work-if-disabled': 1,
#  '/browse/working': 1,
#  '/benefits-calculators': 1,
#  '/uk-visa-sponsorship-employers': 1,
#  '/criminal-record-check-documents': 1,
#  '/guidance/immigration-rules/immigration-rules-appendix-shortage-occupation-list': 1,
#  '/contact-jobcentre-plus/change-cancel-appointment': 1,
#  '/become-apprentice': 1,
#  '/government/publications/register-of-licensed-sponsors-workers': 1,
#  '/contact-jobcentre-plus/new-benefit-claims': 1,
#  '/topic/work-careers/government-graduate-schemes': 1,
#  '/employers-checks-job-applicants': 1,
#  '/browse/education/find-course': 1,
#  '/search/services': 1,
#  '/national-insurance': 1,
#  '/guidance/free-courses-for-jobs': 1,
#  '/legal-right-work-uk': 1,
#  '/graduate-visa/documents-youll-need-to-apply': 2,
#  '/government/collections/dbs-filtering-guidance': 2,
#  '/government/organisations/hm-revenue-customs/contact/online-services-helpdesk': 2,
#  '/guidance/dvla-coronavirus-covid-19-update': 2,
#  '/apply-sponsor-licence': 2,
#  '/child-benefit-16-19': 2,
#  '/carers-allowance-report-change': 2,
#  '/guidance/search-for-apprenticeship-standards': 2,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations': 2,
#  '/apply-direct-payments': 2,
#  '/government/publications/filtering-rules-for-criminal-record-check-certificates': 2,
#  '/browse/visas-immigration/student-visas': 2,
#  '/log-in-hmrc-excise-import-export': 2,
#  '/student-visa/money': 2,
#  '/government/publications/access-to-work-factsheet/access-to-work-factsheet-for-customers': 2,
#  '/id-for-driving-licence': 2,
#  '/biometric-residence-permits/replace-expired-brp': 2,
#  '/employing-an-apprentice/apprenticeship-agreement': 2,
#  '/volunteering/volunteers-rights': 2,
#  '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus': 2,
#  '/graduate-visa/course-you-studied': 2,
#  '/browse/childcare-parenting/schools-education': 2,
#  '/overtime-your-rights/compulsory-overtime': 2,
#  '/financial-help-disabled/home-and-housing': 2,
#  '/moving-from-benefits-to-work/work-experience-and-volunteering': 2,
#  '/browse/childcare-parenting/financial-help-children': 2,
#  '/understanding-your-pay/deductions-from-your-pay': 2,
#  '/government/organisations/hm-revenue-customs/contact': 2,
#  '/government/publications/redundancy-payments-rp1-fact-sheet/what-to-do-when-youve-been-made-redundant': 2,
#  '/mandatory-reconsideration/how-to-ask-for-mandatory-reconsideration': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants': 2,
#  '/bank-holidays': 2,
#  '/settled-status-eu-citizens-families/what-youll-need-to-apply': 2,
#  '/passport-fees': 2,
#  '/budgeting-help-benefits': 2,
#  '/government/publications/basic-check-guidance-and-policies': 2,
#  '/statutory-sick-pay': 2,
#  '/housing-benefit/other-help-with-housing-costs': 2,
#  '/dual-citizenship': 2,
#  '/fraud-error-prevention-centres': 2,
#  '/self-employment-and-universal-credit': 2,
#  '/criminal-record-checks-apply-role/application-process': 2,
#  '/register-for-self-assessment/self-employed': 2,
#  '/disability-living-allowance-children/rates': 2,
#  '/browse/abroad/travel-abroad': 2,
#  '/check-british-citizenship': 2,
#  '/government/publications/dbs-update-service-applicant-guide': 2,
#  '/time-off-for-dependants': 2,
#  '/guidance/how-to-take-on-an-apprentice': 2,
#  '/estimate-income-tax': 2,
#  '/recruitment-disabled-people': 2,
#  '/advanced-learner-loan': 2,
#  '/government/collections/financial-support-for-businesses-during-coronavirus-covid-19': 2,
#  '/uk-residence-card': 2,
#  '/government/organisations/skills-funding-agency': 2,
#  '/national-insurance-rates-letters/category-letters': 2,
#  '/foreign-travel-advice/france': 2,
#  '/council-tax': 2,
#  '/help': 2,
#  '/apply-disabled-facilities-grant': 2,
#  '/browse/tax/dealing-with-hmrc': 2,
#  '/driving-lessons-learning-to-drive': 2,
#  '/changes-affect-tax-credits': 2,
#  '/guidance/using-your-uk-visas-and-immigration-account': 2,
#  '/further-education-courses': 2,
#  '/tax-on-pension/tax-free': 2,
#  '/right-to-reside': 2,
#  '/student-finance': 2,
#  '/get-copy-military-service-records/apply-for-someone-elses-records': 2,
#  '/guidance/new-immigration-system-what-you-need-to-know': 2,
#  '/national-minimum-wage-accommodation': 2,
#  '/government/publications/dbs-application-forms-guide-for-applicants/dbs-application-form-guide-for-applicants': 2,
#  '/cold-weather-payment/eligibility': 2,
#  '/guidance/contact-the-department-for-work-and-pensions-about-its-policies': 2,
#  '/what-is-the-construction-industry-scheme': 2,
#  '/workplace-pensions/what-you-your-employer-and-the-government-pay': 2,
#  '/government/publications/apprenticeship-funding-bands': 2,
#  '/tax-on-pension': 2,
#  '/taking-sick-leave': 2,
#  '/rest-breaks-work/disputes': 2,
#  '/paye-forms-p45-p60-p11d/p60': 2,
#  '/carers-allowance/if-youre-working-': 2,
#  '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide': 2,
#  '/browse/visas-immigration/settle-in-the-uk': 2,
#  '/claim-benefits-abroad/jobseekers-allowance': 2,
#  '/financial-help-disabled/disability-and-sickness-benefits': 2,
#  '/dvlaforms': 2,
#  '/looking-for-work-if-disabled/applying-for-a-job': 2,
#  '/student-visa/extend-your-visa': 2,
#  '/dla-disability-living-allowance-benefit': 2,
#  '/dbs-check-applicant-criminal-record/get-a-standard-or-enhanced-dbs-check-for-an-employee': 2,
#  '/graduate-visa': 2,
#  '/benefit-fraud': 2,
#  '/browse/births-deaths-marriages/child': 2,
#  '/benefit-overpayments': 2,
#  '/maternity-pay-leave/leave': 2,
#  '/guidance/statutory-sick-pay-employee-fitness-to-work': 2,
#  '/join-trade-union/trade-union-membership-your-employment-rights': 2,
#  '/child-employment': 2,
#  '/carers-allowance': 2,
#  '/education/apprenticeships-traineeships-and-internships': 2,
#  '/deferring-state-pension': 2,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes': 2,
#  '/state-pension-if-you-retire-abroad/report-a-change-in-your-circumstances': 2,
#  '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa': 2,
#  '/government/collections/traineeships--2': 2,
#  '/parental-leave/notice-period': 2,
#  '/income-tax/check-youre-paying-the-right-amount': 2,
#  '/topic/personal-tax/national-insurance': 2,
#  '/dismissal': 2,
#  '/employment-support-allowance/what-youll-get': 2,
#  '/renew-adult-passport': 2,
#  '/employment/finding-job': 2,
#  '/monitoring-work-workers-rights': 2,
#  '/topic/business-tax/pension-scheme-administration': 2,
#  '/new-state-pension/inheriting-or-increasing-state-pension-from-a-spouse-or-civil-partner': 2,
#  '/log-in-file-self-assessment-tax-return/sign-in/prove-identity': 2,
#  '/student-finance/extra-help': 2,
#  '/calculate-employee-redundancy-pay': 2,
#  '/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19': 2,
#  '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022': 2,
#  '/universal-credit/how-your-earnings-affect-your-payments': 2,
#  '/employment-tribunals/make-a-claim': 2,
#  '/universal-credit/get-an-advance-first-payment': 2,
#  '/get-undergraduate-student-loan': 2,
#  '/apply-to-come-to-the-uk': 2,
#  '/topic/crime-policing/criminal-record-disclosure': 2,
#  '/standard-visitor-visa/apply': 2,
#  '/government/publications/apprenticeship-recruitment-employers-and-training-organisations': 2,
#  '/foreign-travel-advice/spain': 2,
#  '/guidance/government-legal-service-gls-legal-trainee-scheme-how-to-apply': 2,
#  '/life-in-the-uk-test': 2,
#  '/browse/employing-people/recruiting-hiring': 2,
#  '/dismissal/unfair-and-constructive-dismissal': 2,
#  '/disability-premiums/what-youll-get': 2,
#  '/national-insurance/change-of-circumstance': 2,
#  '/browse/employing-people/time-off': 2,
#  '/browse/disabilities/benefits': 2,
#  '/government/publications/new-enterprise-allowance-phase-2-provider-guidance/new-enterprise-allowance-phase-2-provider-guidance': 2,
#  '/types-of-british-nationality': 2,
#  '/disabled-students-allowance-dsa': 2,
#  '/tax-on-your-private-pension/annual-allowance': 2,
#  '/redundancy-your-rights/being-selected-for-redundancy': 2,
#  '/government/publications/find-a-free-level-3-qualification': 2,
#  '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments': 2,
#  '/agricultural-workers-rights': 2,
#  '/government/collections/desg-graduate-scheme': 2,
#  '/benefit-cap/benefit-cap-amounts': 2,
#  '/incapacity-benefit': 2,
#  '/tax-on-your-private-pension/pension-tax-relief': 2,
#  '/recruitment-disabled-people/encouraging-applications': 2,
#  '/government/publications/disclosure-application-process-for-volunteers': 2,
#  '/national-insurance/help-if-youre-not-working': 2,
#  '/statutory-sick-pay/how-to-claim': 2,
#  '/biometric-residence-permits/personal-data': 2,
#  '/government/organisations/education-and-skills-funding-agency': 2,
#  '/apply-for-student-finance': 2,
#  '/view-right-to-rent': 2,
#  '/contract-types-and-employer-responsibilities': 2,
#  '/payment-exception-service': 2,
#  '/child-benefit-move-to-uk': 2,
#  '/tax-help': 2,
#  '/continuous-employment-what-it-is': 2,
#  '/government/organisations/hm-revenue-customs/contact/child-benefit': 2,
#  '/training-study-work-your-rights': 2,
#  '/biometric-residence-permits/not-arrived': 2,
#  '/1619-bursary-fund/eligibility': 2,
#  '/early-retirement-pension': 2,
#  '/track-passport-application': 2,
#  '/start-up-visa': 2,
#  '/send-fit-note': 2,
#  '/browse/benefits/disability': 2,
#  '/budgeting-help-benefits/repayments': 2,
#  '/government/publications/budgeting-loan-claim-form': 2,
#  '/international-pension-centre': 2,
#  '/join-trade-union': 2,
#  '/travel-abroad': 2,
#  '/government/publications/dbs-update-service-applicant-guide/dbs-update-service-applicant-guide': 2,
#  '/council-housing': 2,
#  '/skilled-worker-visa/when-you-can-be-paid-less': 2,
#  '/guidance/plan-for-jobs-skills-and-employment-programmes-information-for-employers': 2,
#  '/government/publications/united-kingdom-security-vetting-clearance-levels/national-security-vetting-clearance-levels': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/guidance-on-the-application-process-for-criminal-records-checks-overseas': 2,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals': 2,
#  '/british-passport-eligibility': 2,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship': 2,
#  '/search/news-and-communications': 2,
#  '/attendance-allowance/how-to-claim': 2,
#  '/apply-home-equipment-for-disabled': 2,
#  '/find-a-visa-application-centre': 2,
#  '/voluntary-national-insurance-contributions/deadlines': 2,
#  '/marriage-visa': 2,
#  '/childcare-grant': 2,
#  '/personal-pensions-your-rights/choosing-personal-pension': 2,
#  '/fixed-term-contracts/employees-rights': 2,
#  '/government/collections/hm-revenue-and-customs-service-availability-and-issues': 2,
#  '/employment-tribunals': 2,
#  '/paternity-pay-leave/eligibility': 2,
#  '/carers-allowance/further-information': 2,
#  '/shared-parental-leave-and-pay/eligibility-for-birth-parents': 2,
#  '/apply-for-elderly-person-bus-pass': 2,
#  '/get-a-passport-urgently/1-week-fast-track-service': 2,
#  '/check-university-award-degree': 2,
#  '/guidance/traineeship-information-for-trainees': 2,
#  '/employer-relocation-your-rights': 2,
#  '/your-employment-contract-how-it-can-be-changed/dealing-with-problems': 2,
#  '/pension-credit': 2,
#  '/calculate-your-holiday-entitlement': 2,
#  '/contact-student-finance-england': 2,
#  '/guidance/apply-for-a-kickstart-scheme-grant': 2,
#  '/become-lorry-bus-driver': 2,
#  '/call-charges': 2,
#  '/uk-visa-sponsorship-employers/sponsorship-management-roles': 2,
#  '/universal-credit/changes-of-circumstances': 2,
#  '/working-tax-credit': 2,
#  '/advanced-learner-loan/what-youll-get': 2,
#  '/after-a-death/organisations-you-need-to-contact-and-tell-us-once': 2,
#  '/government/publications/find-a-skills-bootcamp/list-of-skills-bootcamps': 2,
#  '/check-immigration-status': 2,
#  '/government/publications/your-new-state-pension-explained/your-state-pension-explained': 2,
#  '/personal-tax-account/sign-in/create-account': 2,
#  '/claim-loss-notice': 2,
#  '/rest-breaks-work/taking-breaks': 2,
#  '/employ-someone': 2,
#  '/night-working-hours': 2,
#  '/jobseekers-allowance/apply-new-style-jsa': 2,
#  '/guidance/redundancy-help-finding-work-and-claiming-benefits': 2,
#  '/handing-in-your-notice': 2,
#  '/browse/education/student-finance': 2,
#  '/government/organisations/disclosure-and-barring-service/about': 2,
#  '/what-different-qualification-levels-mean/list-of-qualification-levels': 2,
#  '/jobseekers-allowance/your-jsa-claim': 2,
#  '/employment-support-allowance/working-while-you-claim': 2,
#  '/browse/births-deaths-marriages/register-offices': 2,
#  '/shared-parental-leave-and-pay': 2,
#  '/uk-visa-sponsorship-employers/job-suitability': 2,
#  '/further-education-courses/if-youre-16-or-17': 2,
#  '/guidance/coronavirus-covid-19-what-to-do-if-youre-employed-and-cannot-work': 2,
#  '/government/organisations/pension-service': 2,
#  '/get-a-passport-urgently/online-premium-service': 2,
#  '/1619-bursary-fund': 2,
#  '/eu-eea': 2,
#  '/apply-medal-or-veterans-badge': 2,
#  '/guidance/claim-for-wage-costs-through-the-coronavirus-job-retention-scheme': 2,
#  '/test-and-trace-support-payment': 2,
#  '/constant-attendance-allowance': 2,
#  '/pension-credit/what-youll-get': 2,
#  '/guidance/how-your-trading-conditions-affect-your-eligibility-for-the-self-employment-income-support-scheme': 2,
#  '/log-in-file-self-assessment-tax-return': 2,
#  '/guidance/claim-for-wages-through-the-coronavirus-job-retention-scheme': 2,
#  '/contracted-out/old-state-pension': 2,
#  '/browse/business/finance-support': 2,
#  '/universal-credit/what-youll-get': 2,
#  '/apply-start-up-loan': 2,
#  '/government/publications/employment-and-support-allowance-permitted-work-form/permitted-work-factsheet': 2,
#  '/government/publications/attendance-allowance-claim-form': 2,
#  '/state-pension/circumstances-change': 2,
#  '/fixed-term-contracts/renewing-or-ending-a-fixedterm-contract': 2,
#  '/maximum-weekly-working-hours/calculating-your-working-hours': 2,
#  '/tax-national-insurance-after-state-pension-age/stopping-paying-national-insurance': 2,
#  '/tell-hmrc-change-of-details/income-changes': 2,
#  '/browse/driving/driving-licences': 2,
#  '/government/publications/apprenticeship-technical-funding-guide': 2,
#  '/settled-status-eu-citizens-families/family-member-eligible-person-from-northern-ireland': 2,
#  '/statutory-sick-pay/what-youll-get': 2,
#  '/housing-and-universal-credit': 2,
#  '/redundancy-your-rights/suitable-alternative-employment': 2,
#  '/browse/citizenship/voting': 2,
#  '/handing-in-your-notice/gardening-leave': 2,
#  '/government/publications/traineeship-providers': 2,
#  '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means': 2,
#  '/guidance/new-style-jobseekers-allowance': 2,
#  '/report-unfit-work-children-vulnerable-adults': 2,
#  '/handing-in-your-notice/payment-during-your-notice-period': 2,
#  '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member': 2,
#  '/state-pension-if-you-retire-abroad': 2,
#  '/student-finance/new-fulltime-students': 2,
#  '/plan-retirement-income': 2,
#  '/overseas-domestic-worker-visa': 2,
#  '/the-warm-home-discount-scheme/low-income': 2,
#  '/access-to-work/apply': 2,
#  '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults': 2,
#  '/find-pension-centre': 2,
#  '/government/organisations/hm-revenue-customs/services-information': 2,
#  '/maternity-pay-leave/extra-help': 2,
#  '/time-off-for-dependants/whats-an-emergency': 2,
#  '/government/publications/disclosure-application-process-for-volunteers/disclosure-application-process-for-volunteers': 2,
#  '/new-state-pension/what-youll-get': 2,
#  '/budgeting-help-benefits/after-you-apply': 2,
#  '/copy-of-police-records': 2,
#  '/check-state-pension': 2,
#  '/voluntary-national-insurance-contributions': 2,
#  '/parental-leave': 2,
#  '/national-minimum-wage/employers-and-the-minimum-wage': 2,
#  '/visa-documents-returned': 2,
#  '/government/organisations/hm-revenue-customs/contact/change-your-personal-details': 2,
#  '/get-document-legalised': 2,
#  '/apply-council-tax-reduction': 2,
#  '/guidance/barring-referrals': 2,
#  '/find-postgraduate-teacher-training-courses': 2,
#  '/pension-credit-calculator': 2,
#  '/access-to-work/renew': 2,
#  '/claim-benefits-abroad': 2,
#  '/new-state-pension/how-to-claim': 2,
#  '/youth-mobility': 2,
#  '/funeral-payments': 2,
#  '/register-employer': 2,
#  '/holiday-entitlement-rights/workers-furlough-coronavirus': 2,
#  '/government/organisations/civil-service/about/recruitment': 2,
#  '/income-support/report-a-change-of-circumstances': 2,
#  '/browse/employing-people/dismissals-redundancies': 2,
#  '/government/organisations/hm-revenue-customs': 2,
#  '/topic/benefits-credits/tax-credits': 2,
#  '/calculate-statutory-sick-pay': 2,
#  '/healthcare-immigration-application': 2,
#  '/guidance/return-to-your-claim-for-the-self-employment-income-support-scheme': 2,
#  '/tell-employer-or-college-about-criminal-record/fines-and-compensation': 2,
#  '/government/collections/statutory-pay-forms': 2,
#  '/employment-status/employee': 2,
#  '/topic/dealing-with-hmrc/paying-hmrc': 2,
#  '/child-employment/restrictions-on-child-employment': 2,
#  '/financial-help-disabled/vehicles-and-transport': 2,
#  '/moving-from-benefits-to-work/help-for-specific-problems': 2,
#  '/state-pension/what-youll-get': 2,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-standardenhanced-dbs-check-applications-from-1-july-2021': 2,
#  '/get-coronavirus-test': 2,
#  '/carers-allowance-unit': 2,
#  '/industrial-injuries-disablement-benefit/eligibility': 2,
#  '/30-hours-free-childcare': 2,
#  '/tax-codes/tell-hmrc-about-a-change-tax-code': 2,
#  '/jobcentre-plus-help-for-recruiters/recruitment-advice-and-support': 2,
#  '/government/collections/apprenticeship-vacancies': 2,
#  '/tell-employer-or-college-about-criminal-record/what-information-you-need-to-give': 2,
#  '/government/publications/employment-and-support-allowance-permitted-work-form': 2,
#  '/id-scan-eu-settlement-scheme': 2,
#  '/guidance/visa-decision-waiting-times-applications-inside-the-uk': 2,
#  '/standard-visitor-visa': 2,
#  '/guidance/register-of-apprenticeship-training-providers': 2,
#  '/payslips': 2,
#  '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant': 2,
#  '/moving-or-retiring-abroad': 2,
#  '/learn-to-drive-a-car': 2,
#  '/personal-pensions-your-rights': 2,
#  '/browse/driving/vehicle-tax-mot-insurance': 2,
#  '/income-tax': 2,
#  '/employers-sick-pay/entitlement': 2,
#  '/agency-workers-your-rights/basic-information-you-should-receive': 2,
#  '/sign-in-help-to-save': 2,
#  '/employing-an-apprentice/get-funding': 2,
#  '/browse/visas-immigration/eu-eea-swiss': 2,
#  '/government/publications/child-benefit-claim-form-ch2': 2,
#  '/guidance/pensions-and-compensation-for-veterans': 2,
#  '/residence-documents-foreign-nationals-uk': 2,
#  '/sure-start-maternity-grant/how-to-claim': 2,
#  '/education-maintenance-allowance-ema': 2,
#  '/advanced-learner-loan/how-to-apply': 2,
#  '/working-tax-credit/what-youll-get': 2,
#  '/government/collections/citizenship-application-forms': 2,
#  '/set-up-sole-trader': 2,
#  '/guidance/national-minimum-wage-work-experience-and-internships': 2,
#  '/jobseekers-allowance/apply-new-style-jsa/eligibility': 2,
#  '/british-national-overseas-bno-visa': 2,
#  '/child-trust-funds/managing-the-account': 2,
#  '/government/publications/apprenticeship-levy-how-it-will-work/apprenticeship-levy-how-it-will-work': 2,
#  '/get-proof-employment-history': 2,
#  '/guidance/brexit-guidance-for-individuals-and-families': 2,
#  '/tax-on-pension/how-your-tax-is-paid': 2,
#  '/driving-medical-conditions': 2,
#  '/tips-at-work': 2,
#  '/plan-for-retirement': 2,
#  '/skilled-worker-visa/switch-to-this-visa': 2,
#  '/government/publications/register-of-licensed-sponsors-students': 2,
#  '/order-coronavirus-rapid-lateral-flow-tests': 2,
#  '/government/publications/dbs-continuation-sheet': 2,
#  '/view-driving-licence': 2,
#  '/sponsor-management-system': 2,
#  '/vehicles-can-drive': 2,
#  '/disciplinary-procedures-and-action-at-work/how-disciplinary-procedures-work': 2,
#  '/right-of-abode/commonwealth-citizens': 2,
#  '/find-an-immigration-adviser': 2,
#  '/career-breaks': 2,
#  '/handing-in-your-notice/giving-notice': 2,
#  '/careers-helpline-for-teenagers': 2,
#  '/income-support/if-you-already-get-income-support': 2,
#  '/topic/immigration-operational-guidance/immigration-rules': 2,
#  '/tell-hmrc-change-address': 2,
#  '/plan-retirement-income/private-pensions': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-a-to-f-applying-for-a-criminal-records-check-for-someone-from-overseas': 2,
#  '/universal-credit/contact-universal-credit': 2,
#  '/sure-start-maternity-grant/what-youll-get': 2,
#  '/government/publications/universal-credit-work-allowances/universal-credit-work-allowances': 2,
#  '/guidance/track-a-dbs-application': 2,
#  '/learner-support': 2,
#  '/student-finance-register-login': 2,
#  '/welfare/jobseekers-allowance': 2,
#  '/uk-visa-sponsorship-employers/eligibility': 2,
#  '/visa-to-study-english': 2,
#  '/get-help-savings-low-income': 2,
#  '/vehicle-tax': 2,
#  '/statutory-sick-pay/eligibility': 2,
#  '/bereavement-support-payment/how-to-claim': 2,
#  '/government/collections/statutory-sick-pay-and-leave': 2,
#  '/search/policy-papers-and-consultations': 2,
#  '/report-cash-in-hand-pay': 2,
#  '/government/publications/application-for-a-state-pension-statement': 2,
#  '/browse/tax/income-tax': 2,
#  '/guidance/using-the-uk-immigration-id-check-app': 2,
#  '/holiday-entitlement-rights/holiday-pay-the-basics': 2,
#  '/government/publications/apprenticeships-off-the-job-training': 2,
#  '/topic/further-education-skills/administration': 2,
#  '/government/publications/basic-check-guidance-and-policies/basic-check-id-checking-guidelines-from-1-july-2021': 2,
#  '/claim-tax-credits': 2,
#  '/student-visa/family-members': 2,
#  '/workplace-temperatures': 2,
#  '/employment-support-allowance': 2,
#  '/settled-status-eu-citizens-families/applying-for-settled-status': 2,
#  '/transferring-your-pension': 2,
#  '/housing-benefit/what-youll-get': 2,
#  '/state-pension-age': 2,
#  '/government/publications/dbs-identity-checking-guidelines': 2,
#  '/check-vehicle-tax': 2,
#  '/support-visit-benefit-claim': 2,
#  '/uk-border-control/before-you-leave-for-the-uk': 2,
#  '/government/organisations/the-pensions-advisory-service': 2,
#  '/plan-shared-parental-leave-pay': 2,
#  '/repaying-your-student-loan': 2,
#  '/check-income-tax-current-year/sign-in/create-account': 2,
#  '/early-retirement-pension/benefits': 2,
#  '/government/organisations/companies-house': 2,
#  '/paye-forms-p45-p60-p11d/lost-paye-forms': 2,
#  '/universal-credit/how-to-claim': 2,
#  '/government/publications/employing-disabled-people-and-people-with-health-conditions/employing-disabled-people-and-people-with-health-conditions': 2,
#  '/government/collections/illegal-working-penalties-codes-of-practice-for-employers': 2,
#  '/update-uk-visas-immigration-account-details': 2,
#  '/apply-housing-benefit-from-council': 2,
#  '/guidance/how-to-quarantine-when-you-arrive-in-england': 2,
#  '/government/publications/access-to-work-guide-for-employers': 2,
#  '/skilled-worker-visa/if-you-work-in-healthcare-or-education': 2,
#  '/contracted-out': 2,
#  '/topic/further-education-skills/vocational-qualifications': 2,
#  '/am-i-getting-minimum-wage': 2,
#  '/government/publications/dbs-workforce-guidance': 2,
#  '/tell-employer-or-college-about-criminal-record/cautions': 2,
#  '/guidance/national-skills-fund': 2,
#  '/dismissal/what-to-do-if-youre-dismissed': 2,
#  '/report-benefit-fraud': 2,
#  '/skilled-worker-visa/your-partner-and-children': 2,
#  '/browse/driving/number-plate': 2,
#  '/moving-from-benefits-to-work/job-search-programmes': 2,
#  '/raise-grievance-at-work': 2,
#  '/find-lost-utr-number': 2,
#  '/government/publications/introducing-govuk-verify/introducing-govuk-verify': 2,
#  '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education': 2,
#  '/government/publications/national-insurance-employment-history-request': 2,
#  '/financial-help-disabled/television-licence-discount': 2,
#  '/national-insurance-rates-letters': 2,
#  '/skilled-worker-visa/your-job': 2,
#  '/contact-hmrc': 2,
#  '/dismiss-staff': 2,
#  '/agency-workers-your-rights': 2,
#  '/guidance/new-style-employment-and-support-allowance': 2,
#  '/government/collections/helping-young-people-into-work': 2,
#  '/biometric-residence-permits': 2,
#  '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed': 2,
#  '/government/publications/maternity-allowance-claim-form': 2,
#  '/apply-first-provisional-driving-licence': 2,
#  '/carers-credit': 2,
#  '/how-tax-credits-affect-other-benefits': 2,
#  '/armed-forces-pension-calculator': 2,
#  '/redundancy-your-rights/get-help-finding-a-new-job': 2,
#  '/driving-nongb-licence': 2,
#  '/sign-in-childcare-account': 2,
#  '/if-you-become-disabled/if-youre-in-employment-and-become-disabled': 2,
#  '/child-benefit/how-to-claim': 2,
#  '/your-employment-contract-how-it-can-be-changed': 2,
#  '/find-out-dbs-check': 2,
#  '/housing-benefit/how-to-claim': 2,
#  '/coronavirus/business-support': 2,
#  '/self-employed-records': 2,
#  '/log-in-register-hmrc-online-services/register': 2,
#  '/child-benefit-payment-dates': 2,
#  '/winter-fuel-payment/eligibility': 2,
#  '/employers-sick-pay/eligibility-and-form-ssp1': 2,
#  '/uk-border-control': 2,
#  '/how-to-claim-new-style-esa': 2,
#  '/guidance/basic-dbs-checks-guidance': 2,
#  '/new-employee/employee-information': 2,
#  '/support-for-mortgage-interest/eligibility': 2,
#  '/pip/how-to-claim': 2,
#  '/guidance/working-safely-during-covid-19': 2,
#  '/national-concessionary-fuel-scheme': 2,
#  '/personal-tax-account': 2,
#  '/grant-bursary-adult-learners': 2,
#  '/renewing-your-tax-credits-claim': 2,
#  '/additional-state-pension': 2,
#  '/voluntary-national-insurance-contributions/who-can-pay-voluntary-contributions': 2,
#  '/government/topical-events/plan-for-jobs': 2,
#  '/browse/visas-immigration/what-you-need-to-do': 2,
#  '/reasonable-adjustments-for-disabled-workers': 2,
#  '/government/collections/dbs-checking-service-guidance--2': 2,
#  '/uk-benefits-abroad': 2,
#  '/financial-help-disabled/on-a-low-salary': 2,
#  '/death-spouse-benefits-tax-pension/benefits': 2,
#  '/guidance/eu-settlement-scheme-evidence-of-uk-residence': 2,
#  '/government/publications/easy-read-get-help-at-work-if-youre-disabled-or-have-a-health-condition-access-to-work': 2,
#  '/help/terms-conditions': 2,
#  '/check-national-insurance-record': 2,
#  '/financial-help-disabled': 2,
#  '/guidance/rehabilitation-periods': 2,
#  '/tax-free-childcare': 2,
#  '/government/publications/the-basic-state-pension': 2,
#  '/settle-in-the-uk': 2,
#  '/set-up-business': 2,
#  '/renew-driving-licence-at-70': 2,
#  '/moving-from-benefits-to-work/help-for-parents-and-carers': 2,
#  '/tax-relief-for-employees': 2,
#  '/browse/disabilities/rights': 2,
#  '/advanced-learner-loan/bursary-fund': 2,
#  '/government/publications/dbs-update-service-employer-guide': 2,
#  '/national-insurance-credits/eligibility': 2,
#  '/visa-fees': 2,
#  '/browse/visas-immigration/asylum': 2,
#  '/voluntary-national-insurance-contributions/rates': 2,
#  '/browse/tax/self-assessment': 2,
#  '/working-retirement-pension-age': 2,
#  '/check-tenant-right-to-rent-documents': 2,
#  '/english-language': 2,
#  '/update-uk-visas-immigration-account-details/update-your-ukvi-account': 2,
#  '/minimum-wage-different-types-work/paid-an-annual-salary': 2,
#  '/change-circumstances-visa-brp': 2,
#  '/employing-an-apprentice/pay-and-conditions-for-apprentices': 2,
#  '/income-support/income-support-rates': 2,
#  '/tax-come-to-uk': 2,
#  '/government/publications/dbs-update-service-employer-guide/dbs-update-service-employer-guide': 2,
#  '/whistleblowing': 2,
#  '/government/publications/paye-starter-checklist': 2,
#  '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403': 2,
#  '/workplace-pensions': 2,
#  '/paternity-pay-leave': 2,
#  '/employment-contracts-and-conditions': 2,
#  '/disabled-facilities-grants': 2,
#  '/further-education-skills/apprenticeships': 2,
#  '/faster-decision-visa-settlement': 2,
#  '/find-pension-contact-details': 2,
#  '/health-conditions-disability-universal-credit': 2,
#  '/keeping-your-pay-tax-records': 2,
#  '/when-someone-dies': 2,
#  '/tax-credits-overpayments': 2,
#  '/check-tenant-right-to-rent-documents/how-to-check': 2,
#  '/browse/education/school-life': 2,
#  '/working-abroad': 2,
#  '/view-prove-immigration-status': 2,
#  '/overtime-your-rights': 2,
#  '/government/publications/qualifications-in-new-funded-offers': 2,
#  '/agency-workers-your-rights/your-rights-as-a-temporary-agency-worker': 2,
#  '/redundancy-your-rights': 2,
#  '/government/organisations/home-office/about/recruitment': 2,
#  '/childcare-calculator': 2,
#  '/maternity-pay-leave/pay': 2,
#  '/housing-and-universal-credit/property-you-own': 2,
#  '/child-employment/local-council-rules-for-child-employment-permits': 2,
#  '/housing-and-universal-credit/renting-from-private-landlord': 2,
#  '/contract-types-and-employer-responsibilities/fulltime-and-parttime-contracts': 2,
#  '/government/publications/dbs-list-of-offences-that-will-never-be-filtered-from-a-criminal-record-check': 2,
#  '/guidance/coronavirus-covid-19-what-to-do-if-youre-self-employed-and-getting-less-work-or-no-work': 2,
#  '/severe-disablement-allowance': 2,
#  '/government/publications/dbs-filtering-guidance/dbs-filtering-guide': 2,
#  '/ancestry-visa': 2,
#  '/minimum-wage-different-types-work/paid-by-the-hour': 2,
#  '/seasonal-worker-visa/eligibility': 2,
#  '/government/publications/sector-based-work-academies-employer-guide': 2,
#  '/become-appointee-for-someone-claiming-benefits': 2,
#  '/dla-disability-living-allowance-benefit/dla-rates': 2,
#  '/government/publications/dbs-application-forms-guide-for-applicants': 2,
#  '/maternity-pay-leave': 2,
#  '/claim-tax-refund': 2,
#  '/budgeting-help-benefits/what-youll-get': 2,
#  '/change-address-driving-licence': 2,
#  '/book-theory-test': 2,
#  '/check-mot-history': 2,
#  '/guidance/coronavirus-covid-19-testing-for-people-travelling-to-england': 2,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship/borders-immigration-and-citizenship-privacy-information-notice': 2,
#  '/benefit-cap/how-earnings-affect-when-benefit-cap-starts': 2,
#  '/paye-forms-p45-p60-p11d/p11d': 2,
#  '/when-mental-health-condition-becomes-disability': 2,
#  '/employer-preventing-discrimination': 2,
#  '/standard-visitor-visa/documents-you-will-need': 2,
#  '/check-income-tax-current-year/sign-in/prove-identity': 2,
#  '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide': 2,
#  '/disability-living-allowance-children': 2,
#  '/government/publications/the-official-hmrc-app': 2,
#  '/working-for-yourself': 2,
#  '/national-minimum-wage': 2,
#  '/benefit-cap': 2,
#  '/employee-rights-when-on-leave': 2,
#  '/change-name-deed-poll': 2,
#  '/assisted-digital-help-online-applications': 2,
#  '/government/publications/eu-settlement-scheme-application-processing-times/eu-settlement-scheme-pilot-current-expected-processing-times-for-applications': 2,
#  '/entering-staying-uk': 2,
#  '/education': 2,
#  '/rest-breaks-work/compensatory-rest': 2,
#  '/browse/visas-immigration/commonwealth-british-nationals-overseas': 2,
#  '/working-tax-credit/how-to-claim': 2,
#  '/get-copy-military-service-records/apply-for-your-own-records': 2,
#  '/maternity-allowance': 2,
#  '/topic/benefits-credits/child-benefit': 2,
#  '/self-employed-national-insurance-rates': 2,
#  '/government/organisations/department-for-education/services-information': 2,
#  '/national-insurance-credits': 2,
#  '/volunteering/pay-and-expenses': 2,
#  '/government/organisations/hm-revenue-customs/contact/self-assessment': 2,
#  '/1619-bursary-fund/how-to-claim': 2,
#  '/income-tax/how-you-pay-income-tax': 2,
#  '/guidance/recruiting-people-from-outside-the-uk': 2,
#  '/book-driving-test': 2,
#  '/tax-on-your-private-pension': 2,
#  '/tell-hmrc-change-of-details': 2,
#  '/self-assessment-forms-and-helpsheets': 2,
#  '/national-minimum-wage-rates': 2,
#  '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions': 2,
#  '/guidance/nhs-covid-pass': 2,
#  '/what-different-qualification-levels-mean/compare-different-qualification-levels': 2,
#  '/order-copy-birth-death-marriage-certificate': 2,
#  '/higher-education-courses-find-and-apply': 2,
#  '/guidance/check-if-you-could-be-covered-by-the-coronavirus-job-retention-scheme': 2,
#  '/child-benefit/what-youll-get': 2,
#  '/income-tax/taxfree-and-taxable-state-benefits': 2,
#  '/criminal-record-check-become-driving-instructor': 2,
#  '/claim-redundancy': 2,
#  '/business-support-helpline': 2,
#  '/personal-pensions-your-rights/how-you-can-take-pension': 2,
#  '/register-birth': 2,
#  '/government/publications/acceptable-right-to-work-documents-an-employers-guide': 2,
#  '/overtime-your-rights/parttime-workers': 2,
#  '/education/further-and-higher-education-skills-and-vocational-training': 2,
#  '/browse/visas-immigration/tourist-short-stay-visas': 2,
#  '/browse/education/universities-higher-education': 2,
#  '/government/organisations/department-of-health-and-social-care': 2,
#  '/agricultural-sick-pay': 2,
#  '/business-finance-support': 2,
#  '/maximum-weekly-working-hours': 2,
#  '/government/organisations/foreign-commonwealth-office': 2,
#  '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships': 2,
#  '/guidance/criminal-record-checks-for-childminders-and-childcare-workers': 2,
#  '/agency-workers-your-rights/pay': 2,
#  '/work/pensions-and-ageing-society': 2,
#  '/benefit-cap/when-youre-not-affected': 2,
#  '/topic/personal-tax/self-assessment': 2,
#  '/government/publications/skilled-worker-visa-eligible-healthcare-and-education-jobs': 2,
#  '/government/publications/rates-and-allowances-national-insurance-contributions/rates-and-allowances-national-insurance-contributions': 2,
#  '/caution-warning-penalty': 2,
#  '/business-coronavirus-support-finder': 2,
#  '/workplace-pensions/managing-your-pension': 2,
#  '/tax-codes/emergency-tax-codes': 2,
#  '/how-to-have-your-benefits-paid': 2,
#  '/staff-redundant': 2,
#  '/additional-state-pension/inheriting': 2,
#  '/check-driving-information': 2,
#  '/browse/citizenship/charities-honours': 2,
#  '/income-tax/find-out-if-you-need-to-pay-income-tax': 2,
#  '/settled-status-eu-citizens-families/after-youve-applied': 2,
#  '/get-state-pension': 2,
#  '/mandatory-reconsideration': 2,
#  '/browse/benefits/bereavement': 2,
#  '/check-income-tax-last-year': 2,
#  '/reduced-national-insurance-married-women': 2,
#  '/browse/childcare-parenting/pregnancy-birth': 2,
#  '/guidance/incentive-payments-for-hiring-a-new-apprentice': 2,
#  '/chwilio-am-swydd': 2,
#  '/browse/childcare-parenting/childcare': 2,
#  '/settled-status-eu-citizens-families': 2,
#  '/browse/visas-immigration/immigration-appeals': 2,
#  '/new-state-pension/youve-been-in-a-workplace-personal-or-stakeholder-pension': 2,
#  '/support-for-mortgage-interest': 2,
#  '/redundancy-your-rights/redundancy-pay': 2,
#  '/pip/claiming-pip-if-youre-terminally-ill': 2,
#  '/employment-contracts-and-conditions/written-statement-of-employment-particulars': 2,
#  '/carers-allowance/how-to-claim': 2,
#  '/government/publications/the-national-minimum-wage-in-2021': 2,
#  '/your-rights-if-your-employer-is-insolvent': 2,
#  '/student-jobs-paying-tax': 2,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-numbers': 2,
#  '/skilled-worker-visa/apply-from-outside-the-uk': 2,
#  '/pip/what-youll-get': 2,
#  '/recruit-apprentice': 2,
#  '/guidance/settled-status-for-eu-citizens-and-their-families-translations': 2,
#  '/report-problem-criminal-record-certificate/appeal-against-a-new-barring-decision': 2,
#  '/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance': 2,
#  '/government/publications/income-tax-leaving-the-uk-getting-your-tax-right-p85': 2,
#  '/transferring-your-pension/transferring-to-a-uk-pension-scheme': 2,
#  '/moving-from-benefits-to-work/starting-your-own-business': 2,
#  '/national-insurance/your-national-insurance-number': 2,
#  '/state-pension-through-partner': 2,
#  '/rest-breaks-work': 2,
#  '/disability-premiums/eligibility': 2,
#  '/uk-family-visa/partner-spouse': 2,
#  '/identitycards': 2,
#  '/guidance/responsible-organisations': 2,
#  '/right-of-abode': 2,
#  '/workplace-pensions/if-you-want-to-leave-your-workplace-pension-scheme': 2,
#  '/apply-standard-visitor-visa': 2,
#  '/paternity-pay-leave/pay': 2,
#  '/dbs-check-applicant-criminal-record/get-a-basic-dbs-check-for-an-employee': 2,
#  '/plan-retirement-income/get-financial-advice': 2,
#  '/income-tax-rates': 2,
#  '/private-renting': 2,
#  '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service': 2,
#  '/independent-livingfund': 2,
#  '/browse/disabilities/work': 2,
#  '/national-insurance/how-much-you-pay': 2,
#  '/search/research-and-statistics': 2,
#  '/running-payroll': 2,
#  '/maximum-weekly-working-hours/weekly-maximum-working-hours-and-opting-out': 2,
#  '/biometric-residence-permits/collect': 2,
#  '/guidance/prove-your-english-language-abilities-with-a-secure-english-language-test-selt': 2,
#  '/future-pension-centre': 2,
#  '/become-magistrate': 2,
#  '/child-tax-credit/new-claim': 2,
#  '/redundancy-your-rights/consultation': 2,
#  '/tax-on-pension-death-benefits': 2,
#  '/pay-self-assessment-tax-bill': 2,
#  '/welfare/entitlement': 2,
#  '/paternity-pay-leave/how-to-claim': 2,
#  '/parents-learning-allowance': 2,
#  '/solve-workplace-dispute': 2,
#  '/government/publications/skilled-worker-visa-eligible-occupations': 2,
#  '/government/publications/sure-start-maternity-grant-claim-form': 2,
#  '/self-employed-records/what-records-to-keep': 2,
#  '/government/publications/view-and-prove-your-immigration-status-evisa': 2,
#  '/guidance/pay-apprenticeship-levy': 2,
#  '/eusettledstatus': 2,
#  '/rights-disabled-person': 2,
#  '/standard-visitor-visa/what-you-can-do-in-the-uk': 2,
#  '/council-tax-bands': 2,
#  '/apply-to-come-to-the-uk/prepare-your-application': 2,
#  '/appeal-benefit-decision': 2,
#  '/government/publications/apprenticeship-agreement-template': 2,
#  '/carers-credit/eligibility': 2,
#  '/renew-adult-passport/renew': 2,
#  '/limited-company-formation': 2,
#  '/employment-support-allowance/change-of-circumstances': 2,
#  '/reduced-earnings-allowance': 2,
#  '/pay-and-work-rights': 2,
#  '/maternity-allowance/how-to-claim': 2,
#  '/guidance/get-help-with-benefits-and-pensions-if-you-have-accessibility-needs': 2,
#  '/state-pension/inheritance': 2,
#  '/holiday-entitlement-rights/calculate-leave-entitlement': 2,
#  '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries': 2,
#  '/workplace-bullying-and-harassment': 2,
#  '/disability-benefits-helpline': 2,
#  '/government/publications/find-a-skills-bootcamp': 2,
#  '/time-off-for-dependants/taking-time-off': 2,
#  '/uk-visa-sponsorship-employers/types-of-licence': 2,
#  '/guidance/apprenticeship-funding-rules': 2,
#  '/guidance/benefits-and-pensions-for-uk-nationals-in-the-eea-or-switzerland': 2,
#  '/housing-benefit/report-a-change-of-circumstances': 2,
#  '/government/publications/view-and-prove-your-immigration-status-evisa/your-immigration-status-an-introduction-for-eu-eea-and-swiss-citizens-accessible-version': 2,
#  '/tax-national-insurance-after-state-pension-age': 2,
#  '/skilled-worker-visa/second-job': 2,
#  '/temporary-worker-charity-worker-visa': 2,
#  '/settled-status-eu-citizens-families/eligibility': 2,
#  '/claim-national-insurance-refund': 2,
#  '/government/publications/right-to-work-checklist': 2,
#  '/pensions-advisory-service': 2,
#  '/benefit-overpayments/how-to-make-a-repayment': 2,
#  '/your-employment-contract-how-it-can-be-changed/making-changes': 2,
#  '/government/publications/dbs-filtering-guidance': 2,
#  '/apply-for-council-housing': 2,
#  '/entering-staying-uk/foreign-nationals-working-in-uk': 2,
#  '/uk-family-visa': 2,
#  '/disability-premiums': 2,
#  '/government/organisations/hm-revenue-customs/contact/get-help-with-the-self-employment-income-support-scheme': 2,
#  '/government/publications/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19': 2,
#  '/apply-online-for-student-finance': 2,
#  '/holiday-entitlement-rights/taking-holiday-before-leaving-a-job': 2,
#  '/child-benefit-tax-calculator': 2,
#  '/new-state-pension/how-its-calculated': 2,
#  '/get-ready-to-employ-someone': 2,
#  '/holiday-entitlement-rights/booking-time-off-': 2,
#  '/sure-start-maternity-grant/eligibility': 2,
#  '/report-benefits-change-circumstances': 2,
#  '/pip/change-of-circumstances': 2,
#  '/time-off-for-dependants/problems-when-you-take-time-off': 2,
#  '/claim-tax-credits/what-counts-as-income': 2,
#  '/government/organisations/department-of-social-security': 2,
#  '/guidance/immigration-rules/immigration-rules-part-5-working-in-the-uk': 2,
#  '/when-is-your-next-tax-credits-payment': 2,
#  '/get-paye-forms-p45-p60': 2,
#  '/topic/higher-education/scholarships-for-overseas-students': 2,
#  '/guidance/manage-apprenticeship-funds': 2,
#  '/au-pairs-employment-law': 2,
#  '/browse/citizenship/citizenship': 2,
#  '/guidance/help-employers-apply-for-a-kickstart-scheme-grant-kickstart-gateway': 2,
#  '/penalty-points-endorsements/how-to-check-your-endorsement-details': 2,
#  '/biometric-residence-permits/report-problem': 2,
#  '/guidance/using-the-eu-exit-id-document-check-app': 2,
#  '/government/publications/dbs-check-eligible-positions-guidance': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-q-z': 2,
#  '/bereavement-support-payment': 2,
#  '/tell-employer-or-college-about-criminal-record/check-your-conviction-caution': 2,
#  '/further-education-courses/find-a-course': 2,
#  '/national-insurance-if-you-go-abroad': 2,
#  '/personal-tax-account/sign-in/prove-identity': 2,
#  '/find-coronavirus-support': 2,
#  '/disciplinary-procedures-and-action-at-work': 2,
#  '/universal-credit/other-financial-support': 2,
#  '/help/accessibility-statement': 2,
#  '/tell-employer-or-college-about-criminal-record/discharges': 2,
#  '/get-tax-free-childcare': 2,
#  '/rest-breaks-work/exceptions': 2,
#  '/dismissal/reasons-you-can-be-dismissed': 2,
#  '/employing-an-apprentice': 2,
#  '/government/publications/jobseekers-allowance-sanctions-leaflet/jobseekers-allowance-sanctions-how-to-keep-your-benefit-payment': 2,
#  '/government/organisations/foreign-commonwealth-development-office': 2,
#  '/government/publications/eu-settlement-scheme-application-processing-times': 2,
#  '/definition-of-disability-under-equality-act-2010': 2,
#  '/early-retirement-pension/personal-and-workplace-pensions': 2,
#  '/winter-fuel-payment/how-much-youll-get': 2,
#  '/international-agreement-worker-visa': 2,
#  '/discrimination-your-rights/discrimination-at-work': 2,
#  '/budgeting-help-benefits/how-to-apply': 2,
#  '/employer-preventing-discrimination/recruitment': 2,
#  '/track-your-driving-licence-application': 2,
#  '/government-authorised-exchange': 2,
#  '/government/organisations/uk-visas-and-immigration': 2,
#  '/check-state-pension/sign-in/create-account': 2,
#  '/carers-allowance/eligibility': 2,
#  '/topic/personal-tax/income-tax': 2,
#  '/paye-forms-p45-p60-p11d': 2,
#  '/lost-national-insurance-number': 2,
#  '/employment-support-allowance/your-esa-claim': 2,
#  '/further-education-courses/financial-help': 2,
#  '/terminal-illness-benefits': 2,
#  '/maternity-pay-leave/how-to-claim': 2,
#  '/frontier-worker-permit': 2,
#  '/guidance/visa-decision-waiting-times-applications-outside-the-uk': 2,
#  '/windrush-prove-your-right-to-be-in-the-uk': 2,
#  '/overtime-your-rights/time-off-and-paid-leave': 2,
#  '/employers-sick-pay': 2,
#  '/child-benefit/eligibility': 2,
#  '/maternity-allowance/what-youll-get': 2,
#  '/government/organisations/department-for-work-pensions/about/complaints-procedure': 2,
#  '/topic/immigration-operational-guidance': 2,
#  '/calculate-your-redundancy-pay': 2,
#  '/adoption-pay-leave': 2,
#  '/uk-visa-sponsorship-employers/certificates-of-sponsorship': 2,
#  '/industrial-injuries-disablement-benefit': 2,
#  '/guidance/eu-settlement-scheme-how-we-use-your-personal-information': 2,
#  '/guidance/covid-19-how-dbs-is-supporting-the-fight-against-coronavirus': 2,
#  '/career-development-loans': 2,
#  '/report-problem-criminal-record-certificate/dispute-a-mistake': 2,
#  '/workplace-pensions-employers': 2,
#  '/pension-credit/how-to-claim': 2,
#  '/minimum-wage-different-types-work': 2,
#  '/deferring-state-pension/what-you-get': 2,
#  '/employment-support-allowance/eligibility': 2,
#  '/graduate-visa/apply': 2,
#  '/death-spouse-benefits-tax-pension': 2,
#  '/lay-offs-short-timeworking': 2,
#  '/government/collections/dbs-eligibility-guidance': 2,
#  '/workplace-pensions/joining-a-workplace-pension': 2,
#  '/income-support': 2,
#  '/how-to-claim-new-style-jsa': 2,
#  '/browse/benefits/help-for-carers': 2,
#  '/tell-dvla-changed-address': 2,
#  '/standard-visitor-visa/eligibility': 2,
#  '/government/collections/apprenticeship-changes': 2,
#  '/pension-credit/eligibility': 2,
#  '/family-permit': 2,
#  '/keeping-your-pay-tax-records/how-long-to-keep-your-records': 2,
#  '/understanding-your-pay': 2,
#  '/guidance/coronavirus-covid-19-test-to-release-for-international-travel': 2,
#  '/housing-benefit': 2,
#  '/guidance/traineeship-information-for-employers': 2,
#  '/skilled-worker-visa/how-much-it-costs': 2,
#  '/government/collections/dbs-update-service-promotional-material': 2,
#  '/contact-pension-service': 2,
#  '/attendance-allowance/eligibility': 2,
#  '/guidance/travel-abroad-from-england-during-coronavirus-covid-19': 2,
#  '/topic/business-tax/paye': 2,
#  '/attendance-allowance': 2,
#  '/government/organisations/driver-and-vehicle-licensing-agency': 2,
#  '/guidance/coronavirus-covid-19-right-to-work-checks': 2,
#  ...}

# %%
# seed0.2: shortest_paths_seed0.2: '/topic/further-education-skills/apprenticeships'
shortest_seed0_2 = {
    k: v
    for k, v in sorted(
        shortest_paths_seed1.items(), key=lambda item: item[1], reverse=False
    )
}

# %% [markdown]
# ### Order by the sum of the shortest page path lengths

# %%
combined_paths = {
    k: finding_job[k] + apprentice[k] for k in set(finding_job) & set(apprentice)
}
combined_paths = {
    k: v
    for k, v in sorted(combined_paths.items(), key=lambda item: item[1], reverse=True)
}
combined_paths
# Out:
# {'/government/publications/lrs-help-and-support/lrs-help-and-support': 8,
#  '/employment-tribunals/going-to-a-tribunal-hearing': 8,
#  '/government/publications/self-assessment-register-for-self-assessment-and-get-a-tax-return-sa1': 8,
#  '/adoption-pay-leave/leave': 7,
#  '/adoption-pay-leave/how-to-claim': 7,
#  '/government/publications/ordinary-statutory-paternity-pay-and-leave-becoming-a-birth-parent-sc3': 7,
#  '/employment-tribunals/after-you-make-a-claim': 7,
#  '/trusts-taxes': 7,
#  '/government/publications/filtering-rules-for-criminal-record-check-certificates/filtering-rules-for-dbs-certificates-criminal-record-checks': 7,
#  '/government/publications/lrs-maintenance-schedule': 7,
#  '/raise-grievance-at-work/grievance-procedure': 7,
#  '/government/publications/dbs-certificate-disputes-and-fingerprint-consent-forms-and-guidance-af14-af15/dbs-certificate-disputes-and-fingerprint-consent-guidance': 7,
#  '/guidance/veterans-uk-armed-forces-pensions-forms': 7,
#  '/buy-sell-your-home': 7,
#  '/funeral-payments/eligibility': 7,
#  '/paternity-pay-leave/adoption': 7,
#  '/government/publications/notification-of-change-of-circumstances-form-mcc': 7,
#  '/tax-uk-income-live-abroad/taxed-twice': 7,
#  '/national-curriculum/key-stage-3-and-4': 7,
#  '/rights-disabled-person/police': 6,
#  '/staff-redundant/avoiding-redundancies': 6,
#  '/government/publications/maternity-benefits-technical-guidance': 6,
#  '/foreign-travel-advice/ireland': 6,
#  '/government/publications/government-baseline-personnel-security-standard': 6,
#  '/government/publications/biometric-residence-permits-overseas-applicant-and-sponsor-information': 6,
#  '/settlement-refugee-or-humanitarian-protection/eligibility': 6,
#  '/christmas-bonus': 6,
#  '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service/supplementary-guidance-on-eligible-roles': 6,
#  '/applying-for-probate': 6,
#  '/working-tax-credit/further-information': 6,
#  '/employee-tax-codes/numbers': 6,
#  '/government/publications/child-benefit-general-enquiry': 6,
#  '/government/collections/state-pension-age-review': 6,
#  '/disciplinary-procedures-and-action-at-work/disciplinary-appeals': 6,
#  '/government/publications/unique-pupil-numbers': 6,
#  '/become-magistrate/apply-to-be-a-magistrate': 6,
#  '/rights-disabled-person/education-rights': 6,
#  '/the-warm-home-discount-scheme/guarantee-pension-credit': 6,
#  '/government/publications/social-security-abroad-ni38': 6,
#  '/government/publications/form-an-guidance': 6,
#  '/employers-sick-pay/notice-and-fit-notes': 6,
#  '/settlement-refugee-or-humanitarian-protection': 6,
#  '/free-discount-tv-licence': 6,
#  '/running-payroll/reporting-to-hmrc': 6,
#  '/additional-state-pension/you-get-divorced': 6,
#  '/government/organisations/hm-revenue-customs/contact/pension-scheme-enquiries': 6,
#  '/driving-lessons-learning-to-drive/taking-driving-lessons': 6,
#  '/child-benefit/get-help-with-your-claim': 6,
#  '/government/publications/disability-living-allowance-for-children-claim-form': 6,
#  '/data-protection/find-out-what-data-an-organisation-has-about-you': 6,
#  '/employment-tribunals/refund-tribunal-fees': 6,
#  '/start-up-visa/eligibility': 6,
#  '/options-for-paying-off-your-debts': 6,
#  '/indefinite-leave-to-remain-innovator-visa': 6,
#  '/constant-attendance-allowance/what-youll-get': 6,
#  '/government/publications/carers-allowance-claim-form': 6,
#  '/tax-credits-if-moving-country-or-travelling': 6,
#  '/become-magistrate/can-you-be-a-magistrate': 6,
#  '/uk-family-visa/private-life': 6,
#  '/government/publications/identity-proofing-and-verification-of-an-individual/how-to-prove-and-verify-someones-identity': 6,
#  '/paternity-pay-leave/leave': 6,
#  '/healthy-start/eligibility': 6,
#  '/government/publications/accredited-personal-licence-qualification-providers': 6,
#  '/check-university-award-degree/recognised-bodies': 6,
#  '/child-trust-funds/find-a-child-trust-fund': 6,
#  '/workplace-pensions/get-help': 6,
#  '/register-for-self-assessment/not-self-employed': 6,
#  '/register-birth/who-can-register-a-birth': 6,
#  '/learner-support/eligibility': 6,
#  '/guidance/statutory-sick-pay-manually-calculate-your-employees-payments': 6,
#  '/capital-gains-tax': 6,
#  '/simpler-income-tax-simplified-expenses': 6,
#  '/claim-tax-credits/joint-claims': 6,
#  '/uk-family-visa/adult-dependent-relative': 6,
#  '/government/collections/state-pension-toolkit': 6,
#  '/appeal-housing-benefit-decision': 6,
#  '/staff-redundant/redundancy-pay': 6,
#  '/guidance/help-and-support-for-self-assessment': 6,
#  '/garden-maintenance-council-tenants': 6,
#  '/government/publications/funeral-payment-claim-form': 6,
#  '/tax-overpayments-and-underpayments': 6,
#  '/government/publications/blue-badge-can-i-get-one': 6,
#  '/guidance/manage-a-registered-pension-scheme': 6,
#  '/after-a-death': 6,
#  '/staff-redundant/noncompulsory-redundancy': 6,
#  '/get-help-savings-low-income/how-to-apply': 6,
#  '/personal-pensions-your-rights/get-help': 6,
#  '/child-trust-funds/add-money-to-the-account': 6,
#  '/tax-codes/what-your-tax-code-means': 6,
#  '/apply-needs-assessment-social-services': 6,
#  '/disabled-facilities-grants/what-youll-get': 6,
#  '/get-a-child-passport/first-child-passport': 6,
#  '/valuing-estate-of-someone-who-died': 6,
#  '/claim-tax-credits/when-to-claim': 6,
#  '/government/publications/application-to-settle-in-the-uk-form-setm': 6,
#  '/shared-parental-leave-and-pay/what-youll-get': 6,
#  '/healthy-start': 6,
#  '/government-authorised-exchange/eligibility': 6,
#  '/parents-learning-allowance/eligibility': 6,
#  '/guidance/national-insurance-for-workers-from-the-uk-working-in-the-eea-or-switzerland': 6,
#  '/pay-off-debts': 6,
#  '/tax-national-insurance-after-state-pension-age/agerelated-tax-allowances': 6,
#  '/help-home-school-transport': 6,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-g-to-p-applying-for-a-criminal-records-check-for-someone-from-overseas': 6,
#  '/access-to-elected-office-fund': 6,
#  '/set-up-business-partnership': 6,
#  '/employer-preventing-discrimination/discrimination-during-employment': 6,
#  '/renew-adult-passport/replace': 6,
#  '/british-national-overseas-bno-visa/apply-in-the-uk': 6,
#  '/become-car-driving-instructor': 6,
#  '/get-help-savings-low-income/how-it-will-affect-your-benefits': 6,
#  '/after-a-death/death-abroad': 6,
#  '/government/publications/eu-settlement-scheme-frontier-workers-and-their-family-members': 6,
#  '/government/publications/biometric-residence-permits-applicant-and-sponsor-information': 6,
#  '/taxi-driver-licence': 6,
#  '/government/publications/carers-credit-application-form': 6,
#  '/plan-retirement-income/your-pension-options': 6,
#  '/private-renting/document-checks': 6,
#  '/tell-hmrc-changed-business-details': 6,
#  '/nominate-someone-to-collect-state-pension': 6,
#  '/types-of-british-nationality/british-overseas-citizen': 6,
#  '/plan-retirement-income/pensions-from-the-government': 6,
#  '/carers-credit/what-youll-get': 6,
#  '/cold-weather-payment/what-youll-get': 6,
#  '/government/publications/dbs-update-service-application-form-checklist': 6,
#  '/government/collections/statutory-pay': 6,
#  '/check-income-tax': 6,
#  '/workplace-pensions-employers/how-to-enrol-staff': 6,
#  '/arrested-your-rights': 6,
#  '/agency-workers-your-rights/fees': 6,
#  '/running-payroll/payments': 6,
#  '/government/publications/eu-settlement-scheme-communications-information-for-applicants/eu-settlement-scheme-information-for-eu-settlement-scheme-applicants-accessible-version': 6,
#  '/government/publications/dbs-guidance-leaflets': 6,
#  '/self-assessment-tax-returns/deadlines': 6,
#  '/check-your-driver-cpc-periodic-training-hours': 6,
#  '/night-working-hours/exceptions-to-night-work-limits': 6,
#  '/employers-maternity-pay-leave/refuse-pay-form-smp1': 6,
#  '/government/publications/introducing-govuk-verify': 6,
#  '/keeping-your-pay-tax-records/employees-and-limited-company-directors': 6,
#  '/graduate-visa/how-much-it-costs': 6,
#  '/get-help-savings-low-income/eligibility': 6,
#  '/savings-for-children': 6,
#  '/check-if-you-need-tax-return': 6,
#  '/become-a-driving-instructor': 6,
#  '/government/publications/common-travel-area-guidance': 6,
#  '/register-birth/birth-certificates': 6,
#  '/apply-free-school-meals': 6,
#  '/employment-tribunals/if-you-lose-your-case': 6,
#  '/claim-benefits-abroad/where-you-can-claim-benefits': 6,
#  '/government/publications/dbs-certificate-reprint-guide': 6,
#  '/disabled-students-allowance-dsa/eligibility': 6,
#  '/disabled-facilities-grants/eligibility': 6,
#  '/tax-foreign-income/non-domiciled-residents': 6,
#  '/agency-workers-your-rights/maternity-rights-for-agency-workers': 6,
#  '/government/publications/new-state-pension-if-youve-been-contracted-out-of-additional-state-pension': 6,
#  '/topic/personal-tax/coming-to-uk': 6,
#  '/inheritance-tax': 6,
#  '/immigration-asylum-tribunal': 6,
#  '/employers-sick-pay/help-with-sick-pay': 6,
#  '/guidance/alcohol-licensing': 6,
#  '/apply-first-adult-passport/what-documents-you-need-to-apply': 6,
#  '/transport-disabled': 6,
#  '/appeal-benefit-decision/submit-appeal': 6,
#  '/government/collections/employers-illegal-working-penalties': 6,
#  '/government/publications/exempt-exm/exempt-exm': 6,
#  '/plan-retirement-income/working-past-state-pension-age': 6,
#  '/expenses-if-youre-self-employed': 6,
#  '/shared-parental-leave-and-pay/applying-for-leave-and-pay': 6,
#  '/marriages-civil-partnerships': 6,
#  '/guidance/statutory-sick-pay-employee-circumstances-that-affect-payment': 6,
#  '/rights-disabled-person/employment': 6,
#  '/government/publications/armed-forces-veterans-badge-application-form': 6,
#  '/add-driving-licence-check-code': 6,
#  '/register-a-death': 6,
#  '/employee-tax-codes/letters': 6,
#  '/english-language/exemptions': 6,
#  '/benefit-cap/help-with-the-benefit-cap': 6,
#  '/government/publications/dbs-referrals-form-and-guidance': 6,
#  '/visas-when-you-separate-or-divorce': 6,
#  '/government/publications/right-to-rent-document-checks-a-user-guide': 6,
#  '/government/collections/alcohol-licensing-personal-licences': 6,
#  '/capital-gains-tax/what-you-pay-it-on': 6,
#  '/over-80-pension/eligibility': 6,
#  '/child-benefit/make-a-change-to-your-claim': 6,
#  '/overseas-domestic-worker-visa/eligibility': 6,
#  '/disabled-facilities-grants/how-to-claim': 6,
#  '/long-residence/eligibility': 6,
#  '/disciplinary-procedures-and-action-at-work/suspension-from-work': 6,
#  '/ask-for-a-visa-administrative-review/if-youre-in-the-uk': 6,
#  '/individual-savings-accounts': 6,
#  '/solve-workplace-dispute/appeals': 6,
#  '/government/publications/basic-check-guidance-and-policies/basic-check-identity-guidance-from-3-september-2018': 6,
#  '/additional-state-pension/eligibility': 6,
#  '/check-additional-income-tax': 6,
#  '/tb-test-visa': 6,
#  '/income-tax-reliefs': 6,
#  '/financial-help-disabled/injuries-illness-caused-at-work': 6,
#  '/run-business-from-home': 6,
#  '/study-uk-student-visa': 6,
#  '/government/publications/challenge-a-decision-made-by-the-department-for-work-and-pensions-dwp': 6,
#  '/self-assessment-tax-returns/sending-return': 6,
#  '/pay-voluntary-class-3-national-insurance/bank-details': 6,
#  '/entering-staying-uk/rights-eu-eea-citizens': 6,
#  '/landlord-immigration-check': 6,
#  '/government/organisations/hm-revenue-customs/contact/report-fraud-to-hmrc': 6,
#  '/learner-support/how-to-claim': 6,
#  '/temporary-worker-charity-worker-visa/eligibility': 6,
#  '/government/collections/national-insurance-forms': 6,
#  '/government/publications/universal-credit-changes-to-limited-capability-for-work-payments': 6,
#  '/dismiss-staff/unfair-dismissals': 6,
#  '/british-national-overseas-bno-visa/living-permanently-in-the-uk': 6,
#  '/rent-room-in-your-home/the-rent-a-room-scheme': 6,
#  '/government/publications/eu-settlement-scheme-introduction-for-employers': 6,
#  '/guidance/immigration-rules/immigration-rules-appendix-n-authorised-exchange-schemes': 6,
#  '/bringing-cash-into-uk': 6,
#  '/guidance/the-hardship-fund-a-guide': 6,
#  '/national-minimum-wage/worker-disputes-over-minimum-wage': 6,
#  '/tax-on-pension/tax-when-you-live-abroad': 6,
#  '/claim-asylum/documents': 6,
#  '/government/publications/national-insurance-credits-for-adults-who-care-for-a-child-under-12-fact-sheet': 6,
#  '/rights-disabled-person/the-equality-act-2010-and-un-convention': 6,
#  '/marriage-abroad': 6,
#  '/running-payroll/deductions': 6,
#  '/adult-dependants-grant': 6,
#  '/tax-overpayments-and-underpayments/if-youre-due-a-refund': 6,
#  '/parental-leave/eligibility': 6,
#  '/government/publications/application-for-mot-authorisation-vt01/how-to-apply-to-open-run-or-change-an-mot-testing-station': 6,
#  '/taking-disciplinary-action': 6,
#  '/self-employed-records/how-long-to-keep-your-records': 6,
#  '/apply-30-hours-free-tax-free-childcare': 6,
#  '/register-a-birth': 6,
#  '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service/fast-track-service-eligible-roles': 6,
#  '/industrial-injuries-disablement-benefit/how-to-claim': 6,
#  '/over-80-pension/what-youll-get': 6,
#  '/disciplinary-procedures-and-action-at-work/help-and-advice-with-disciplinary-issues': 6,
#  '/dismiss-staff/how-to-dismiss-someone': 6,
#  '/housing-and-universal-credit/renting-from-local-authority-or-housing-association': 6,
#  '/pay-voluntary-class-3-national-insurance/direct-debit': 6,
#  '/1619-bursary-fund/what-youll-get': 6,
#  '/benefit-overpayments/repayments-when-someone-has-died': 6,
#  '/tax-relief-for-employees/vehicles-you-use-for-work': 6,
#  '/personal-licence-to-sell-alcohol': 6,
#  '/inheritance-tax/passing-on-home': 6,
#  '/child-benefit-proof': 6,
#  '/track-your-driving-licence-application/provisional-licences-new': 6,
#  '/council-housing/types-of-tenancy': 6,
#  '/health-care-worker-visa/apply-from-outside-the-uk': 6,
#  '/employers-maternity-pay-leave/notice-period': 6,
#  '/student-visa/switch-to-this-visa': 6,
#  '/vaccine-damage-payment': 6,
#  '/guidance/checking-the-status-of-your-student-finance-application': 6,
#  '/government/publications/national-insurance-application-to-pay-voluntary-national-insurance-contributions-ca5603': 6,
#  '/uk-residence-card/card-hasnt-arrived': 6,
#  '/guidance/new-employee-coming-to-work-from-abroad': 6,
#  '/income-tax-rates/previous-tax-years': 6,
#  '/claim-asylum/screening': 6,
#  '/update-company-car-details': 6,
#  '/government/publications/rates-and-allowances-national-insurance-contributions': 6,
#  '/smoking-at-work-the-law': 6,
#  '/simpler-income-tax-cash-basis': 6,
#  '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education/skilled-worker-visa-shortage-occupations-for-healthcare-and-education': 6,
#  '/asylum-support': 6,
#  '/pay-class-2-national-insurance/bank-details': 6,
#  '/school-performance-tables': 6,
#  '/government/publications/application-to-settle-in-the-uk-form-seto': 6,
#  '/government/publications/pension-credit-claim-form--2': 6,
#  '/employment-contracts-and-conditions/problems-with-a-written-statement': 6,
#  '/staff-redundant/redundancy-consultations': 6,
#  '/simple-assessment': 6,
#  '/sa302-tax-calculation': 6,
#  '/income-tax-rates/income-over-100000': 6,
#  '/industrial-injuries-disablement-benefit/what-youll-get': 6,
#  '/get-help-savings-low-income/what-youll-get': 6,
#  '/dla-disability-living-allowance-benefit/your-dla-claim': 6,
#  '/find-a-community-support-group-or-organisation': 6,
#  '/tax-foreign-income': 6,
#  '/keeping-your-pay-tax-records/savings-investments-and-pensions': 6,
#  '/state-pension-if-you-retire-abroad/tax-on-your-state-pension': 6,
#  '/tax-on-pension/higher-tax-on-unauthorised-payments': 6,
#  '/rights-disabled-person/further-help-and-advice': 6,
#  '/uk-family-visa/provide-information': 6,
#  '/contract-types-and-employer-responsibilities/fixedterm-contracts': 6,
#  '/apply-for-primary-school-place': 6,
#  '/child-benefit-abroad': 6,
#  '/deferring-state-pension/extra-state-pension-and-lump-sum-payments': 6,
#  '/shared-parental-leave-and-pay/eligibility-for-adopters': 6,
#  '/employment-tribunals/if-you-win-your-case': 6,
#  '/government/publications/lrs-help-and-support': 6,
#  '/deferring-state-pension/tax-and-inheritance': 6,
#  '/employers-maternity-pay-leave/eligibility-and-proof-of-pregnancy': 6,
#  '/tax-company-benefits/tax-on-company-cars': 6,
#  '/change-circumstances-visa-brp/youre-in-the-uk-and-dont-have-a-brp': 6,
#  '/guidance/living-in-spain': 6,
#  '/uk-border-control/layovers-and-transiting': 6,
#  '/inherits-someone-dies-without-will': 6,
#  '/government/collections/tax-treaties': 6,
#  '/permanent-residence-document-eu-eea': 6,
#  '/solve-workplace-dispute/formal-procedures': 6,
#  '/apply-for-secondary-school-place': 6,
#  '/guidance/living-in-the-uk-applying-from-overseas': 6,
#  '/affordable-home-ownership-schemes': 6,
#  '/vaccine-damage-payment/eligibility': 6,
#  '/healthcare-immigration-application/how-much-pay': 6,
#  '/calculate-married-couples-allowance': 6,
#  '/rent-room-in-your-home': 6,
#  '/how-to-register-a-trade-mark': 6,
#  '/tax-national-insurance-after-state-pension-age/claiming-back-tax-or-national-insurance': 6,
#  '/workplace-pensions/protection-for-your-pension': 6,
#  '/stay-in-uk-stateless': 6,
#  '/winter-fuel-payment/report-change-circumstances': 6,
#  '/send-vat-return': 6,
#  '/student-visa/apply': 6,
#  '/apply-first-adult-passport/apply-online': 6,
#  '/government/publications/lrs-organisation-portal': 6,
#  '/payroll-software': 6,
#  '/government/collections/universal-credit-detailed-information-for-claimants': 6,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-the-self-employed': 6,
#  '/topic/immigration-operational-guidance/fees-forms': 6,
#  '/your-rights-if-your-employer-is-insolvent/your-rights': 6,
#  '/bringing-goods-into-uk-personal-use': 6,
#  '/apply-medal-or-veterans-badge/apply-for-a-medal': 6,
#  '/applying-for-probate/who-can-apply': 6,
#  '/help-for-disabled-child': 6,
#  '/junior-individual-savings-accounts': 6,
#  '/employment-contracts-and-conditions/collective-agreements': 6,
#  '/guardians-allowance': 6,
#  '/staff-redundant/compulsory-redundancy': 6,
#  '/student-visa/knowledge-of-english': 6,
#  '/disciplinary-procedures-and-action-at-work/disciplinary-hearings': 6,
#  '/understand-self-assessment-bill/payments-on-account': 6,
#  '/parental-leave/delaying-leave': 6,
#  '/government/publications/dbs-update-service-applicant-guide': 5,
#  '/guidance/using-your-uk-visas-and-immigration-account': 5,
#  '/mandatory-reconsideration/if-you-disagree-with-the-outcome': 5,
#  '/workplace-pensions/what-you-your-employer-and-the-government-pay': 5,
#  '/browse/tax/inheritance-tax': 5,
#  '/guidance/visiting-the-uk-as-an-eu-eea-or-swiss-citizen': 5,
#  '/funeral-payments/how-to-claim': 5,
#  '/join-trade-union/trade-union-membership-your-employment-rights': 5,
#  '/employment-status/legal-decisions-on-employment-status': 5,
#  '/state-pension-if-you-retire-abroad/report-a-change-in-your-circumstances': 5,
#  '/income-tax/check-youre-paying-the-right-amount': 5,
#  '/government/organisations/hm-revenue-customs/contact/statutory-payment-dispute-team': 5,
#  '/national-insurance/change-of-circumstance': 5,
#  '/blind-persons-allowance': 5,
#  '/student-finance-forms': 5,
#  '/government/publications/find-a-free-level-3-qualification': 5,
#  '/how-the-post-office-check-and-send-service-works': 5,
#  '/personal-pensions-your-rights/choosing-personal-pension': 5,
#  '/fixed-term-contracts/employees-rights': 5,
#  '/government/publications/access-to-work-staff-guide/access-to-work-staff-guide': 5,
#  '/uk-visa-sponsorship-employers/sponsorship-management-roles': 5,
#  '/coronavirus/education-and-childcare': 5,
#  '/government/publications/lrs-registration-documents': 5,
#  '/pay-class-2-national-insurance': 5,
#  '/driving-eyesight-rules': 5,
#  '/handing-in-your-notice/payment-during-your-notice-period': 5,
#  '/family-permit/after-family-permit': 5,
#  '/uk-visa-sponsorship-employers/your-licence-rating': 5,
#  '/employer-reporting-expenses-benefits': 5,
#  '/government/publications/apply-to-the-eu-settlement-scheme-by-post-or-email': 5,
#  '/guidance/barring-referrals': 5,
#  '/funeral-payments': 5,
#  '/industrial-injuries-disablement-benefit/eligibility': 5,
#  '/government/publications/calculating-holiday-pay-for-workers-without-fixed-hours-or-pay': 5,
#  '/long-residence': 5,
#  '/government/collections/dbs-referrals-guidance--2': 5,
#  '/handing-in-your-notice/giving-notice': 5,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-a-to-f-applying-for-a-criminal-records-check-for-someone-from-overseas': 5,
#  '/bereavement-support-payment/how-to-claim': 5,
#  '/state-pension-if-you-retire-abroad/rates-of-state-pension': 5,
#  '/browse/tax/income-tax': 5,
#  '/workplace-temperatures': 5,
#  '/healthcare-immigration-application/refunds': 5,
#  '/support-visit-benefit-claim': 5,
#  '/government/collections/illegal-working-penalties-codes-of-practice-for-employers': 5,
#  '/additional-state-pension/contracting-out': 5,
#  '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education': 5,
#  '/carers-credit': 5,
#  '/redundancy-your-rights/get-help-finding-a-new-job': 5,
#  '/claim-tax-credits/working-hours': 5,
#  '/guidance/government-legal-service-gls-legal-trainee-scheme-how-to-apply--2': 5,
#  '/driving-lessons-learning-to-drive/practising-with-family-or-friends': 5,
#  '/financial-help-disabled/on-a-low-salary': 5,
#  '/browse/housing-local-services/owning-renting-property': 5,
#  '/change-address-driving-licence/apply-by-post': 5,
#  '/government/publications/dbs-update-service-employer-guide': 5,
#  '/working-retirement-pension-age': 5,
#  '/change-circumstances-visa-brp': 5,
#  '/dismiss-staff/fair-dismissals': 5,
#  '/guidance/adult-education-budget-aeb-funding-rules-2020-to-2021': 5,
#  '/check-tenant-right-to-rent-documents/how-to-check': 5,
#  '/government/publications/state-pension-fact-sheets/contracting-out-and-why-we-may-have-included-a-contracted-out-pension-equivalent-cope-amount-when-you-used-the-online-service': 5,
#  '/contract-types-and-employer-responsibilities/fulltime-and-parttime-contracts': 5,
#  '/vat-registration': 5,
#  '/budgeting-help-benefits/what-youll-get': 5,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship/borders-immigration-and-citizenship-privacy-information-notice': 5,
#  '/paye-forms-p45-p60-p11d/p11d': 5,
#  '/uk-family-visa/knowledge-of-english': 5,
#  '/register-birth': 5,
#  '/criminal-record-check-become-driving-instructor': 5,
#  '/government/publications/acceptable-right-to-work-documents-an-employers-guide': 5,
#  '/agency-workers-your-rights/pay': 5,
#  '/housing-benefit/supporting-your-claim': 5,
#  '/tax-codes/emergency-tax-codes': 5,
#  '/reduced-national-insurance-married-women': 5,
#  '/browse/visas-immigration/immigration-appeals': 5,
#  '/support-for-mortgage-interest': 5,
#  '/government/publications/income-tax-leaving-the-uk-getting-your-tax-right-p85': 5,
#  '/workplace-pensions/if-you-want-to-leave-your-workplace-pension-scheme': 5,
#  '/flexible-working/after-the-application': 5,
#  '/tax-on-pension-death-benefits': 5,
#  '/apply-first-adult-passport': 5,
#  '/standard-visitor-visa/what-you-can-do-in-the-uk': 5,
#  '/time-off-for-dependants/taking-time-off': 5,
#  '/employment-status/director': 5,
#  '/government/publications/the-fit-note-a-guide-for-patients-and-employees': 5,
#  '/guidance/national-insurance-number-applying-for-a-number-for-a-looked-after-child': 5,
#  '/repaying-your-student-loan/when-you-start-repaying': 5,
#  '/government/organisations/immigration-enforcement': 5,
#  '/government/publications/dbs-unusual-addresses-guidance/dbs-unusual-addresses-guide': 5,
#  '/lay-offs-short-timeworking': 5,
#  '/keeping-your-pay-tax-records/how-long-to-keep-your-records': 5,
#  '/recruitment-disabled-people/reasonable-adjustments': 5,
#  '/financial-help-disabled/vat-relief': 5,
#  '/child-tax-credit/how-to-claim': 5,
#  '/discrimination-your-rights/how-you-can-be-discriminated-against': 5,
#  '/get-replacement-citizenship-certificate': 5,
#  '/health-care-worker-visa/documents-you-must-provide': 5,
#  '/government/publications/disclosure-of-convictions-and-declaration': 5,
#  '/school-term-holiday-dates': 5,
#  '/guidance/dbs-online-account-guidance': 5,
#  '/help-with-childcare-costs/free-childcare-and-education-for-2-to-4-year-olds': 5,
#  '/tax-right-retire-abroad-return-to-uk': 5,
#  '/government/publications/handling-applications-for-permission-to-take-employment-instruction': 5,
#  '/child-employment/performance-licences-for-children': 5,
#  '/government/publications/foreign-embassies-in-the-uk': 5,
#  '/disability-living-allowance-children/eligibility': 5,
#  '/jobcentre-plus-help-for-recruiters/work-trials': 5,
#  '/maternity-pay-leave/eligibility': 5,
#  '/education/further-education-funding': 5,
#  '/workplace-pensions/changing-jobs-and-taking-leave': 5,
#  '/healthcare-immigration-application/pay': 5,
#  '/english-language/approved-english-language-qualifications': 5,
#  '/government/publications/maternity-certificate-mat-b1-guidance-for-health-professionals/benefits-available-during-pregnancy-background-information': 5,
#  '/access-to-work/report-a-change-of-circumstances': 5,
#  '/government/publications/access-to-work-factsheet/access-to-work-factsheet-for-customers': 5,
#  '/graduate-visa/course-you-studied': 5,
#  '/government/publications/redundancy-payments-rp1-fact-sheet/what-to-do-when-youve-been-made-redundant': 5,
#  '/mortgage-interest-run-on': 5,
#  '/government/publications/united-kingdom-security-vetting-clearance-levels': 5,
#  '/industrial-injuries-disablement-benefit/further-information': 5,
#  '/topic/further-education-skills/learning-records-service': 5,
#  '/guidance/information-for-individuals-that-have-been-referred-to-dbs': 5,
#  '/becoming-foster-parent': 5,
#  '/government/publications/pay-and-work-rights-complaints': 5,
#  '/apply-disabled-facilities-grant': 5,
#  '/government/publications/health-and-care-visa-guidance-for-applicants': 5,
#  '/power-of-attorney': 5,
#  '/get-childcare': 5,
#  '/rest-breaks-work/disputes': 5,
#  '/sportsperson-visa': 5,
#  '/report-problem-criminal-record-certificate/appeal-against-an-existing-barring-decision': 5,
#  '/agency-workers-your-rights/entertainment-and-modelling-agencies': 5,
#  '/national-curriculum': 5,
#  '/dismissal/unfair-and-constructive-dismissal': 5,
#  '/browse/tax/court-claims-debt-bankruptcy': 5,
#  '/view-right-to-rent': 5,
#  '/child-benefit-move-to-uk': 5,
#  '/help-with-childcare-costs/free-childcare-2-year-olds': 5,
#  '/browse/housing-local-services/recycling-rubbish': 5,
#  '/certifying-a-document': 5,
#  '/passport-services-disabled': 5,
#  '/check-university-award-degree/recognised-awards': 5,
#  '/guidance/immigration-rules/immigration-rules-part-1-leave-to-enter-or-stay-in-the-uk': 5,
#  '/child-benefit-tax-charge': 5,
#  '/guidance/pension-schemes-and-unauthorised-payments': 5,
#  '/get-a-child-passport': 5,
#  '/uk-visa-sponsorship-employers/job-suitability': 5,
#  '/government/publications/uk-points-based-immigration-system-employer-information': 5,
#  '/make-money-claim': 5,
#  '/fixed-term-contracts/renewing-or-ending-a-fixedterm-contract': 5,
#  '/tax-national-insurance-after-state-pension-age/stopping-paying-national-insurance': 5,
#  '/manage-child-maintenance-case/contact': 5,
#  '/welfare/disability': 5,
#  '/time-off-for-dependants/whats-an-emergency': 5,
#  '/guidance/making-barring-referrals-to-the-dbs': 5,
#  '/government/publications/employing-disabled-people-and-people-with-health-conditions': 5,
#  '/access-to-work/renew': 5,
#  '/tell-employer-or-college-about-criminal-record/what-information-you-need-to-give': 5,
#  '/electoral-register': 5,
#  '/government/publications/employment-and-support-allowance-permitted-work-form': 5,
#  '/right-of-abode/apply-for-a-certificate-of-entitlement': 5,
#  '/widowed-parents-allowance': 5,
#  '/dismiss-staff/dismissals-on-capability-or-conduct-grounds': 5,
#  '/government/publications/child-benefit-claim-form-ch2': 5,
#  '/government/collections/citizenship-application-forms': 5,
#  '/get-proof-employment-history': 5,
#  '/guidance/immigration-rules/updates': 5,
#  '/guidance/claim-back-statutory-sick-pay-paid-to-your-employees-due-to-coronavirus-covid-19': 5,
#  '/government/publications/dbs-continuation-sheet': 5,
#  '/sure-start-maternity-grant/what-youll-get': 5,
#  '/going-to-hospital-benefits': 5,
#  '/family-permit/apply-joining-family-member-eu-switzerland-norway-iceland-liechtenstein': 5,
#  '/theory-test/revision-and-practice': 5,
#  '/recover-statutory-payments': 5,
#  '/government/publications/child-benefit-child-left-approved-education-or-training-ch459': 5,
#  '/topic/work-careers/trade-unions': 5,
#  '/employers-paternity-pay-leave': 5,
#  '/employers-maternity-pay-leave': 5,
#  '/browse/tax/vat': 5,
#  '/armed-forces-pension-calculator': 5,
#  '/becoming-foster-parent/applying-to-become-foster-parent': 5,
#  '/your-employment-contract-how-it-can-be-changed': 5,
#  '/death-spouse-benefits-tax-pension/benefits': 5,
#  '/tax-relief-for-employees': 5,
#  '/returning-resident-visa': 5,
#  '/government/publications/statutory-maternity-pay-employee-not-entitled-form-for-employers': 5,
#  '/check-tenant-right-to-rent-documents': 5,
#  '/subsidised-college-transport-16-19': 5,
#  '/guidance/help-and-support-if-youre-self-employed': 5,
#  '/council-tax/paying-your-bill': 5,
#  '/government/publications/dbs-list-of-offences-that-will-never-be-filtered-from-a-criminal-record-check': 5,
#  '/find-ofsted-inspection-report': 5,
#  '/government/publications/dbs-sample-policy-on-the-recruitment-of-ex-offenders/sample-policy-on-the-recruitment-of-ex-offenders': 5,
#  '/temporary-worker-creative-and-sporting-visa': 5,
#  '/standard-visitor-visa/documents-you-will-need': 5,
#  '/health-and-safety-executive': 5,
#  '/rest-breaks-work/compensatory-rest': 5,
#  '/get-copy-military-service-records/apply-for-your-own-records': 5,
#  '/government/publications/supporting-documents-for-sponsor-applications-appendix-a': 5,
#  '/tax-on-your-private-pension': 5,
#  '/tell-hmrc-change-of-details/relationship-or-family-changes': 5,
#  '/overtime-your-rights/parttime-workers': 5,
#  '/guidance/the-highway-code': 5,
#  '/health-care-worker-visa/how-much-it-costs': 5,
#  '/government/publications/national-security-vetting-advice-for-people-who-are-being-vetted': 5,
#  '/child-tax-credit/responsibility-for-child': 5,
#  '/guidance/universal-credit-and-families-with-more-than-2-children-information-for-claimants': 5,
#  '/government/publications/access-to-work-factsheet': 5,
#  '/access-to-work/print': 5,
#  '/report-problem-criminal-record-certificate/appeal-against-a-new-barring-decision': 5,
#  '/government/publications/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19': 5,
#  '/government/publications/skilled-worker-visa-eligible-occupations': 5,
#  '/guidance/managing-candidates-through-pre-employment-checks-vx': 5,
#  '/self-employed-records/what-records-to-keep': 5,
#  '/coronavirus-health-worker-visa-extension': 5,
#  '/benefits-and-prison': 5,
#  '/search-armed-forces-memorial-roll-of-honour': 5,
#  '/tb-test-visa/countries-where-you-need-a-tb-test-to-enter-the-uk': 5,
#  '/skilled-worker-visa/second-job': 5,
#  '/government/publications/dbs-filtering-guidance': 5,
#  '/government/publications/identity-proofing-and-verification-of-an-individual': 5,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-q-z': 5,
#  '/government/publications/dbs-check-eligible-positions-guidance': 5,
#  '/national-insurance-if-you-go-abroad': 5,
#  '/government/organisations/hm-revenue-customs/contact/get-help-from-hmrc-s-extra-support-team': 5,
#  '/apply-to-come-to-the-uk/getting-a-decision-on-your-application': 5,
#  '/time-off-work-public-duties': 5,
#  '/maternity-allowance/what-youll-get': 5,
#  '/government/publications/dwp-registered-twitter-accounts': 5,
#  '/report-problem-criminal-record-certificate/dispute-a-mistake': 5,
#  '/workplace-pensions-employers': 5,
#  '/guidance/pension-schemes-protect-your-lifetime-allowance': 5,
#  '/graduate-visa/apply': 5,
#  '/government/organisations/united-kingdom-security-vetting': 5,
#  '/uk-residence-card/replace': 5,
#  '/government/publications/kickstart-scheme-employer-resources': 5,
#  '/health-care-worker-visa/your-partner-and-children': 5,
#  '/innovator-visa': 5,
#  '/government/publications/easy-read-get-help-at-work-if-youre-disabled-or-have-a-health-condition-access-to-work/get-help-from-access-to-work-easy-read': 5,
#  '/government/publications/your-new-state-pension-explained': 5,
#  '/government/publications/unlock-opportunity-employer-information-pack-and-case-studies': 5,
#  '/employment-status/employee-shareholders': 5,
#  '/health-care-worker-visa/different-salary-requirements': 5,
#  '/guidance/eu-settlement-scheme-evidence-of-relationship-to-an-eu-citizen': 5,
#  '/your-rights-if-your-employer-is-insolvent/apply-money-owed': 5,
#  '/government/publications/accredited-personal-licence-qualification-providers/accredited-personal-licence-qualification-providers': 5,
#  '/ukvcas': 5,
#  '/refugee-integration-loan': 5,
#  '/short-term-benefit-advance': 5,
#  '/flexible-working/types-of-flexible-working': 5,
#  '/browse/housing-local-services/household-energy': 5,
#  '/join-trade-union/role-of-your-trade-union-rep': 5,
#  '/guidance/digital-and-online-services': 5,
#  '/government/publications/public-funds--2': 5,
#  '/redundancy-payments-helpline': 5,
#  '/guidance/eu-settlement-scheme-uk-tax-and-benefits-records-automated-check': 5,
#  '/disability-premiums/how-to-claim': 5,
#  '/government/publications/how-to-become-a-regulated-immigration-adviser/how-to-become-a-regulated-immigration-adviser': 5,
#  '/additional-state-pension/what-youll-get': 5,
#  '/data-protection': 5,
#  '/government/publications/new-guidance-on-the-rehabilitation-of-offenders-act-1974': 5,
#  '/maternity-allowance/eligibility': 5,
#  '/government/publications/public-funds--2/public-funds': 5,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-dbs-check-applications-from-3-september-2018': 5,
#  '/government/publications/become-a-british-citizen-by-naturalisation-form-an': 5,
#  '/government/publications/disclosure-and-barring-service-dbs-checks-for-childcare-providers-who-register-with-ofsted': 5,
#  '/adi-criminal-record-disclosure': 5,
#  '/government/collections/dbs-filtering-guidance': 5,
#  '/browse/abroad/living-abroad': 5,
#  '/apply-direct-payments': 5,
#  '/jobseekers-allowance/print': 5,
#  '/browse/housing-local-services/local-councils': 5,
#  '/government/publications/universal-credit-and-rented-housing--2/universal-credit-and-rented-housing-guide-for-landlords': 5,
#  '/staff-redundant/layoffs-and-shorttime-working': 5,
#  '/guidance/using-open-document-formats-odf-in-your-organisation': 5,
#  '/get-copy-military-service-records/apply-for-someone-elses-records': 5,
#  '/parental-leave/notice-period': 5,
#  '/capital-gains-tax/report-and-pay-capital-gains-tax': 5,
#  '/minimum-wage-calculator-employers': 5,
#  '/employment-tribunals/make-a-claim': 5,
#  '/guidance/passport-rules-for-travel-to-europe': 5,
#  '/government/collections/requests-for-personal-data-and-service-records': 5,
#  '/life-in-the-uk-test': 5,
#  '/tax-on-your-private-pension/annual-allowance': 5,
#  '/biometric-residence-permits/not-arrived': 5,
#  '/if-youre-homeless-at-risk-of-homelessness': 5,
#  '/government/publications/statutory-sick-pay-record-sheet-ssp2': 5,
#  '/get-a-passport-urgently/1-week-fast-track-service': 5,
#  '/health-care-worker-visa/knowledge-of-english': 5,
#  '/government/publications/criminal-record-certificate-requirement': 5,
#  '/government/collections/citizenship-guidance': 5,
#  '/guidance/immigration-rules/immigration-rules-part-6a-the-points-based-system': 5,
#  '/government/collections/complaints-about-the-department-for-work-and-pensions': 5,
#  '/overseas-domestic-worker-visa': 5,
#  '/the-warm-home-discount-scheme/low-income': 5,
#  '/update-property-records-someone-dies': 5,
#  '/visa-documents-returned': 5,
#  '/guidance/immigration-rules/immigration-rules-appendix-skilled-occupations': 5,
#  '/holiday-entitlement-rights/workers-furlough-coronavirus': 5,
#  '/tell-employer-or-college-about-criminal-record/fines-and-compensation': 5,
#  '/skilled-worker-visa/switch-to-this-visa': 5,
#  '/government/publications/covid-19-stay-at-home-guidance': 5,
#  '/claim-benefits-abroad/illness-injury-benefits': 5,
#  '/government/publications/guidance-on-claiming-a-state-pension-if-you-retire-abroad': 5,
#  '/parents-learning-allowance/what-youll-get': 5,
#  '/government/publications/basic-check-guidance-and-policies/basic-check-id-checking-guidelines-from-1-july-2021': 5,
#  '/set-up-limited-company': 5,
#  '/government/publications/access-to-work-guide-for-employers': 5,
#  '/government/publications/dbs-workforce-guidance': 5,
#  '/council-tax/who-has-to-pay': 5,
#  '/carers-uk': 5,
#  '/government/collections/archive-immigration-rules': 5,
#  '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed': 5,
#  '/government/publications/operational-low-flying-training-timetable': 5,
#  '/being-taken-to-employment-tribunal-by-employee': 5,
#  '/rights-of-trade-union-reps': 5,
#  '/driving-disqualifications': 5,
#  '/data-protection-your-business': 5,
#  '/update-uk-visas-immigration-account-details/update-your-ukvi-account': 5,
#  '/whistleblowing': 5,
#  '/government/publications/dbs-update-service-employer-guide/dbs-update-service-employer-guide': 5,
#  '/disabled-facilities-grants': 5,
#  '/guidance/military-low-flying': 5,
#  '/government/publications/skilled-worker-visa-eligible-salary-if-youre-under-26-studying-training-or-in-a-postdoctoral-role': 5,
#  '/government/publications/dbs-filtering-guidance/dbs-filtering-guide': 5,
#  '/government/collections/individualised-learner-record-ilr': 5,
#  '/guidance/local-housing-allowance': 5,
#  '/settled-status-eu-citizens-families/settled-status-less-than-5-years': 5,
#  '/become-an-mot-tester/eligibility': 5,
#  '/government/publications/equality-act-guidance': 5,
#  '/crime-justice-and-law': 5,
#  '/government/collections/check-a-list-of-genuine-hmrc-contacts': 5,
#  '/defer-national-insurance': 5,
#  '/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance': 5,
#  '/change-name-driving-licence': 5,
#  '/guidance/responsible-organisations': 5,
#  '/types-of-british-nationality/british-overseas-territories-citizen': 5,
#  '/lay-offs-short-timeworking/guarantee-pay': 5,
#  '/limited-company-formation': 5,
#  '/reduced-earnings-allowance': 5,
#  '/state-pension/inheritance': 5,
#  '/guidance/welcome-a-guide-for-hong-kong-british-national-overseas-visa-holders-in-the-uk': 5,
#  '/your-employment-contract-how-it-can-be-changed/making-changes': 5,
#  '/government/publications/basic-dbs-check-privacy-policy/basic-dbs-check-privacy-policy': 5,
#  '/au-pairs-employment-law/au-pairs': 5,
#  '/personal-data-my-employer-can-keep-about-me': 5,
#  '/penalty-points-endorsements': 5,
#  '/tell-employer-or-college-about-criminal-record/discharges': 5,
#  '/discrimination-your-rights/discrimination-at-work': 5,
#  '/adoption-pay-leave': 5,
#  '/government/publications/redundancy-payments-from-the-insolvency-service/explaining-your-redundancy-payment': 5,
#  '/government/publications/calculating-holiday-entitlement-for-workers': 5,
#  '/guidance/check-which-employees-you-can-put-on-furlough-to-use-the-coronavirus-job-retention-scheme': 5,
#  '/guidance/how-hmrc-works-out-total-income-and-trading-profits-for-the-self-employment-income-support-scheme': 5,
#  '/employers-liability-insurance': 5,
#  '/budgeting-help-benefits/other-help-you-can-get': 5,
#  '/uk-visa-sponsorship-employers/apply-for-your-licence': 5,
#  '/uk-border-control/at-border-control': 5,
#  '/additional-state-pension/how-to-claim': 5,
#  '/becoming-foster-parent/help-with-the-cost-of-fostering': 5,
#  '/government/collections/fit-note': 5,
#  '/government/collections/coronavirus-job-retention-scheme': 5,
#  '/access-to-work/what-youll-get': 5,
#  '/government/publications/the-graduate-route-information-for-international-students': 5,
#  '/cold-weather-payment': 5,
#  '/tax-codes': 5,
#  '/uk-family-visa/parent': 5,
#  '/claim-for-injury-received-while-serving': 5,
#  '/the-warm-home-discount-scheme/energy-suppliers': 5,
#  '/government/publications/dbs-certificate-disputes-and-fingerprint-consent-forms-and-guidance-af14-af15': 5,
#  '/biometric-residence-permits/lost-stolen-damaged': 5,
#  '/get-help-hmrc-extra-support/cannot-use-telephone-different-way-to-contact': 5,
#  '/uk-family-visa/proof-income': 5,
#  '/agricultural-skills-and-training': 5,
#  '/family-permit/eea-family-permit': 5,
#  '/motorcycle-cbt': 5,
#  '/register-with-the-police': 5,
#  '/make-a-freedom-of-information-request': 5,
#  '/over-80-pension/further-information': 5,
#  '/apply-30-hours-free-childcare': 5,
#  '/government/publications/illegal-working-penalties-codes-of-practice-for-employers-2018': 5,
#  '/parental-leave/entitlement': 5,
#  '/renounce-british-nationality/resume-your-british-nationality': 5,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations': 5,
#  '/government/publications/filtering-rules-for-criminal-record-check-certificates': 5,
#  '/overtime-your-rights/compulsory-overtime': 5,
#  '/armed-forces-redundancy-calculator': 5,
#  '/government/publications/basic-check-guidance-and-policies': 5,
#  '/browse/abroad/travel-abroad': 5,
#  '/guidance/the-uks-points-based-immigration-system-information-for-eu-citizens': 5,
#  '/government/publications/filtering-rules-for-criminal-record-check-certificates/new-filtering-rules-for-dbs-certificates-from-28-november-2020-onwards': 5,
#  '/browse/tax/capital-gains': 5,
#  '/your-rights-if-your-employer-is-insolvent/what-you-can-get': 5,
#  '/claim-benefits-abroad/maternity-and-childcare-benefits': 5,
#  '/recruitment-disabled-people/encouraging-applications': 5,
#  '/biometric-residence-permits/personal-data': 5,
#  '/continuous-employment-what-it-is': 5,
#  '/gwneud-cais-copi-cofnod-troseddol': 5,
#  '/work': 5,
#  '/carers-allowance/further-information': 5,
#  '/shared-parental-leave-and-pay/eligibility-for-birth-parents': 5,
#  '/legal-aid': 5,
#  '/claim-loss-notice': 5,
#  '/rest-breaks-work/taking-breaks': 5,
#  '/constant-attendance-allowance': 5,
#  '/redundancy-your-rights/suitable-alternative-employment': 5,
#  '/war-pension-armed-forces-compensation-tribunal': 5,
#  '/visit-eu-switzerland-norway-iceland-liechtenstein': 5,
#  '/access-to-work/apply': 5,
#  '/government/publications/disclosure-application-process-for-volunteers/disclosure-application-process-for-volunteers': 5,
#  '/find-regional-passport-office': 5,
#  '/government/publications/right-to-work-checks-code-of-practice-on-avoiding-discrimination': 5,
#  '/guidance/immigration-rules/immigration-rules-index': 5,
#  '/government/publications/state-pensions-annual-increases-if-you-live-abroad/countries-where-we-pay-an-annual-increase-in-the-state-pension': 5,
#  '/topic/benefits-credits/tax-credits': 5,
#  '/tax-codes/tell-hmrc-about-a-change-tax-code': 5,
#  '/government/publications/calculating-holiday-entitlement-for-workers/how-to-calculate-holiday-entitlement-for-workers-on-different-types-of-contract': 5,
#  '/government/publications/dbs-national-security-vetting-solution-guidance-for-subjects': 5,
#  '/sure-start-maternity-grant/how-to-claim': 5,
#  '/guidance/pensions-and-compensation-for-veterans': 5,
#  '/residence-documents-foreign-nationals-uk': 5,
#  '/government/publications/kickstart-scheme-employer-contacts': 5,
#  '/disciplinary-procedures-and-action-at-work/how-disciplinary-procedures-work': 5,
#  '/plan-retirement-income/private-pensions': 5,
#  '/skilled-worker-visa/extend-your-visa': 5,
#  '/driving-licence-codes': 5,
#  '/guidance/disclosure-and-barring-service-guidance-for-childrens-social-care-providers-and-managers': 5,
#  '/guidance/using-the-uk-immigration-id-check-app': 5,
#  '/turkish-business-person': 5,
#  '/plan-shared-parental-leave-pay': 5,
#  '/mobility-scooters-and-powered-wheelchairs-rules': 5,
#  '/tell-employer-or-college-about-criminal-record/cautions': 5,
#  '/dismissal/what-to-do-if-youre-dismissed': 5,
#  '/skilled-worker-visa/your-partner-and-children': 5,
#  '/raise-grievance-at-work': 5,
#  '/government/publications/national-insurance-employment-history-request': 5,
#  '/dismiss-staff': 5,
#  '/disability-living-allowance-children/how-to-claim': 5,
#  '/after-a-death/tax-benefits-vehicles': 5,
#  '/renewing-your-tax-credits-claim': 5,
#  '/government/collections/dbs-checking-service-guidance--2': 5,
#  '/working-abroad': 5,
#  '/agency-workers-your-rights/your-rights-as-a-temporary-agency-worker': 5,
#  '/minister-of-religion-visa': 5,
#  '/housing-and-universal-credit/property-you-own': 5,
#  '/child-employment/local-council-rules-for-child-employment-permits': 5,
#  '/seasonal-worker-visa/eligibility': 5,
#  '/visas-and-immigration-service-and-support-centres': 5,
#  '/dla-disability-living-allowance-benefit/dla-rates': 5,
#  '/ancestry-visa/eligibility': 5,
#  '/driving-licence-fees': 5,
#  '/become-childminder-nanny': 5,
#  '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide': 5,
#  '/guidance/dbs-and-coronavirus-covid-19-frequently-asked-questions': 5,
#  '/marriage-allowance/how-to-apply': 5,
#  '/transferring-your-pension/transferring-to-an-overseas-pension-scheme': 5,
#  '/deferring-state-pension/how-to-claim-a-deferred-state-pension': 5,
#  '/guidance/criminal-record-checks-for-childminders-and-childcare-workers': 5,
#  '/self-assessment-tax-returns/who-must-send-a-tax-return': 5,
#  '/caution-warning-penalty': 5,
#  '/check-driving-information': 5,
#  '/guidance/coronavirus-covid-19-eu-settlement-scheme-guidance-for-applicants': 5,
#  '/employment-contracts-and-conditions/written-statement-of-employment-particulars': 5,
#  '/apply-citizenship-spouse': 5,
#  '/travel-disruption-your-rights-at-work': 5,
#  '/guidance/immigration-rules/immigration-rules-appendix-skilled-worker': 5,
#  '/transferring-your-pension/transferring-to-a-uk-pension-scheme': 5,
#  '/paternity-pay-leave/pay': 5,
#  '/government/publications/british-forces-air-strikes-in-iraq-monthly-list': 5,
#  '/maximum-weekly-working-hours/weekly-maximum-working-hours-and-opting-out': 5,
#  '/biometric-residence-permits/collect': 5,
#  '/government/publications/compensation-for-poor-service-a-guide-for-dwp-staff': 5,
#  '/browse/housing-local-services/repossessions-evictions': 5,
#  '/paternity-pay-leave/how-to-claim': 5,
#  '/confirm-identity-online-for-passport-application': 5,
#  '/topic/company-registration-filing/starting-company': 5,
#  '/government/publications/find-a-skills-bootcamp': 5,
#  '/tax-national-insurance-after-state-pension-age': 5,
#  '/housing-benefit/report-a-change-of-circumstances': 5,
#  '/claim-national-insurance-refund': 5,
#  '/entering-staying-uk/foreign-nationals-working-in-uk': 5,
#  '/child-benefit-tax-calculator': 5,
#  '/get-electronic-visa-waiver': 5,
#  '/time-off-for-dependants/problems-when-you-take-time-off': 5,
#  '/penalty-points-endorsements/how-to-check-your-endorsement-details': 5,
#  '/tell-employer-or-college-about-criminal-record/check-your-conviction-caution': 5,
#  '/employment/state-pension-age': 5,
#  '/rest-breaks-work/exceptions': 5,
#  '/cancel-visa': 5,
#  '/government/publications/kickstart-scheme-terms-and-conditions/kickstart-scheme-grant-funding-agreement-terms-and-conditions-for-employers-effective-from-21-june-2021': 5,
#  '/employer-preventing-discrimination/recruitment': 5,
#  '/entering-staying-uk/rights-foreign-nationals-uk': 5,
#  '/countersigning-passport-applications': 5,
#  '/tell-employer-or-college-about-criminal-record/community-service': 5,
#  '/maternity-pay-leave/how-to-claim': 5,
#  '/self-assessment-tax-returns/get-help': 5,
#  '/guidance/covid-19-how-dbs-is-supporting-the-fight-against-coronavirus': 5,
#  '/visas-and-immigration-service-and-support-centres/locations': 5,
#  '/workplace-pensions/joining-a-workplace-pension': 5,
#  '/guidance/eu-settlement-scheme-apply-for-an-administrative-review': 5,
#  '/winter-fuel-payment/how-to-claim': 5,
#  '/maternity-paternity-pay-leave': 5,
#  '/handing-in-your-notice/restrictive-covenants': 5,
#  '/government/publications/lrs-organisation-portal/learning-records-service-release-210302': 5,
#  '/support-child-or-partners-student-finance-application': 5,
#  '/transfer-visa': 5,
#  '/types-of-british-nationality/british-national-overseas': 5,
#  '/bereavement-support-payment/what-youll-get': 5,
#  '/exempt-vignette': 5,
#  '/probate-estate': 5,
#  '/apply-citizenship-british-parent': 5,
#  '/government/publications/redundancy-payments-rp1-fact-sheet': 5,
#  '/apply-marriage-allowance': 5,
#  '/government/publications/coronavirus-covid-19-apprenticeship-programme-response': 5,
#  '/check-british-citizenship/your-parents-immigration-status-when-you-were-born': 5,
#  '/uk-visa-sponsorship-employers/immigration-skills-charge': 5,
#  '/apply-home-office-travel-document': 5,
#  '/government/publications/application-registration-card-arc/application-registration-card-arc': 5,
#  '/cold-weather-payment/how-to-claim': 5,
#  '/tax-on-your-private-pension/lifetime-allowance': 5,
#  '/government/collections/uk-visa-forms': 5,
#  '/appeal-call-up-reserve-forces': 5,
#  '/tax-uk-income-live-abroad': 5,
#  '/apply-for-council-tax-discount': 5,
#  '/nhs-bursaries': 5,
#  '/self-assessment-ready-reckoner': 5,
#  '/courts': 5,
#  '/employment/work': 5,
#  '/youth-mobility/eligibility': 5,
#  '/graduate-visa/documents-youll-need-to-apply': 4,
#  '/carers-allowance-report-change': 4,
#  '/browse/visas-immigration/student-visas': 4,
#  '/child-study-visa': 4,
#  '/child-benefit-payment-dates/bank-holidays': 4,
#  '/government/organisations/hm-passport-office': 4,
#  '/id-for-driving-licence': 4,
#  '/biometric-residence-permits/replace-expired-brp': 4,
#  '/financial-help-disabled/home-and-housing': 4,
#  '/bank-holidays': 4,
#  '/housing-benefit/other-help-with-housing-costs': 4,
#  '/fraud-error-prevention-centres': 4,
#  '/time-off-for-dependants': 4,
#  '/recruitment-disabled-people': 4,
#  '/foreign-travel-advice/france': 4,
#  '/cold-weather-payment/eligibility': 4,
#  '/government/publications/dbs-application-forms-guide-for-applicants/dbs-application-form-guide-for-applicants': 4,
#  '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide': 4,
#  '/guidance/apprenticeship-opportunities-in-the-ministry-of-defence': 4,
#  '/financial-help-disabled/disability-and-sickness-benefits': 4,
#  '/dvlaforms': 4,
#  '/public-appointments': 4,
#  '/benefit-fraud': 4,
#  '/maternity-pay-leave/leave': 4,
#  '/apply-driver-digital-tachograph-card': 4,
#  '/deferring-state-pension': 4,
#  '/guidance/understanding-off-payroll-working-ir35': 4,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes': 4,
#  '/government/publications/dwp-debt-management-performance-data/dwp-debt-management-customer-service-standards': 4,
#  '/employment-support-allowance/what-youll-get': 4,
#  '/guidance/volunteering-and-claiming-benefits': 4,
#  '/employment/finding-job': 4,
#  '/monitoring-work-workers-rights': 4,
#  '/government/publications/income-tax-repayment-claim-when-small-pension-taken-as-a-lump-sum-p53': 4,
#  '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022': 4,
#  '/government/publications/employers-who-have-claimed-through-the-coronavirus-job-retention-scheme': 4,
#  '/get-undergraduate-student-loan': 4,
#  '/standard-visitor-visa/apply': 4,
#  '/browse/employing-people/pensions': 4,
#  '/browse/employing-people/time-off': 4,
#  '/browse/disabilities/benefits': 4,
#  '/redundancy-your-rights/being-selected-for-redundancy': 4,
#  '/government/collections/desg-graduate-scheme': 4,
#  '/national-insurance/help-if-youre-not-working': 4,
#  '/statutory-sick-pay/how-to-claim': 4,
#  '/government/organisations/hm-revenue-customs/contact/employer-enquiries': 4,
#  '/apply-for-student-finance': 4,
#  '/tax-help': 4,
#  '/guidance/living-in-the-uk-applying-from-within-the-uk': 4,
#  '/training-study-work-your-rights': 4,
#  '/track-passport-application': 4,
#  '/married-couples-allowance': 4,
#  '/international-pension-centre': 4,
#  '/stop-being-self-employed': 4,
#  '/join-trade-union': 4,
#  '/council-housing': 4,
#  '/apply-home-equipment-for-disabled': 4,
#  '/your-rights-to-housing-if-youre-under-18': 4,
#  '/guidance/disability-confident-how-to-sign-up-to-the-employer-scheme': 4,
#  '/probate-search': 4,
#  '/employment-tribunals': 4,
#  '/employer-relocation-your-rights': 4,
#  '/call-charges': 4,
#  '/after-a-death/organisations-you-need-to-contact-and-tell-us-once': 4,
#  '/uk-visa-sponsorship-employers/your-responsibilities': 4,
#  '/check-immigration-status': 4,
#  '/dismiss-staff/dismissals-due-to-illness': 4,
#  '/browse/education/student-finance': 4,
#  '/browse/births-deaths-marriages/register-offices': 4,
#  '/government/collections/how-to-manually-check-your-payroll-calculations': 4,
#  '/capital-gains-tax/allowances': 4,
#  '/log-in-file-self-assessment-tax-return': 4,
#  '/browse/business/finance-support': 4,
#  '/universal-credit/what-youll-get': 4,
#  '/government/organisations/border-force/about/recruitment': 4,
#  '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member': 4,
#  '/moving-to-uk': 4,
#  '/report-unfit-work-children-vulnerable-adults': 4,
#  '/state-pension-if-you-retire-abroad': 4,
#  '/new-state-pension/what-youll-get': 4,
#  '/copy-of-police-records': 4,
#  '/pension-credit-calculator': 4,
#  '/youth-mobility': 4,
#  '/guidance/returning-to-the-uk': 4,
#  '/topic/dealing-with-hmrc/paying-hmrc': 4,
#  '/government/collections/statutory-pay-forms': 4,
#  '/employment-status/employee': 4,
#  '/child-employment/restrictions-on-child-employment': 4,
#  '/get-coronavirus-test': 4,
#  '/state-pension/what-youll-get': 4,
#  '/carers-allowance-unit': 4,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-standardenhanced-dbs-check-applications-from-1-july-2021': 4,
#  '/standard-visitor-visa': 4,
#  '/payslips': 4,
#  '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant': 4,
#  '/guidance/hmrc-tools-and-calculators': 4,
#  '/browse/visas-immigration/eu-eea-swiss': 4,
#  '/education-maintenance-allowance-ema': 4,
#  '/jobseekers-allowance/apply-new-style-jsa/eligibility': 4,
#  '/housing-and-universal-credit/how-to-claim': 4,
#  '/guidance/brexit-guidance-for-individuals-and-families': 4,
#  '/vehicles-can-drive': 4,
#  '/tell-hmrc-change-address': 4,
#  '/income-support/if-you-already-get-income-support': 4,
#  '/government/publications/income-tax-claiming-tax-back-when-you-have-stopped-working-p50': 4,
#  '/foreign-travel-advice/portugal/entry-requirements': 4,
#  '/government/organisations/ministry-of-justice': 4,
#  '/guidance/track-a-dbs-application': 4,
#  '/student-finance-register-login': 4,
#  '/statutory-sick-pay/eligibility': 4,
#  '/vehicle-tax': 4,
#  '/social-work-bursaries': 4,
#  '/government/publications/disability-confident-employers-that-have-signed-up': 4,
#  '/guidance/the-uks-points-based-immigration-system-information-for-eu-citizens.ro': 4,
#  '/government/organisations/department-for-education/about/recruitment': 4,
#  '/contracted-out': 4,
#  '/change-theory-test': 4,
#  '/guidance/national-skills-fund': 4,
#  '/extra-money-pay-university/university-and-college-hardship-funds': 4,
#  '/government/publications/new-dwp-postal-addresses': 4,
#  '/government/publications/guidance-for-contacts-of-people-with-possible-or-confirmed-coronavirus-covid-19-infection-who-do-not-live-with-the-person/guidance-for-contacts-of-people-with-possible-or-confirmed-coronavirus-covid-19-infection-who-do-not-live-with-the-person': 4,
#  '/agency-workers-your-rights': 4,
#  '/foreign-travel-advice/spain/entry-requirements': 4,
#  '/government/publications/maternity-allowance-claim-form': 4,
#  '/how-tax-credits-affect-other-benefits': 4,
#  '/browse/business/limited-company': 4,
#  '/government/organisations/environment-agency': 4,
#  '/volunteer-as-a-coastguard/what-to-expect-as-a-volunteer': 4,
#  '/sign-in-childcare-account': 4,
#  '/child-benefit/how-to-claim': 4,
#  '/guidance/redundancy-support-for-apprentices': 4,
#  '/government/organisations/department-for-business-energy-and-industrial-strategy': 4,
#  '/housing-benefit/how-to-claim': 4,
#  '/guidance/civil-service-secondments-and-loans-how-to-apply': 4,
#  '/browse/housing-local-services/landlords': 4,
#  '/guidance/rates-and-thresholds-for-employers-2021-to-2022': 4,
#  '/pip/how-to-claim': 4,
#  '/national-concessionary-fuel-scheme': 4,
#  '/schools-admissions/school-starting-age': 4,
#  ...}

# %% [markdown]
# ### Order by centrality metrics

# %%
# degree centrality: counts the number of incoming and outgoing relationships from a node - 'most connected'
# the higher the degree, the more central the node is
g_degree = nx.degree_centrality(g)
g_degree = dict(sorted(g_degree.items(), key=itemgetter(1), reverse=True))
g_degree
# Out:
# {'/browse/working': 0.6694091249065071,
#  '/find-a-job': 0.5916230366492147,
#  '/contact-jobcentre-plus': 0.531787584143605,
#  '/jobseekers-allowance': 0.4599850411368736,
#  '/apply-apprenticeship': 0.3807030665669409,
#  '/sign-in-universal-credit': 0.3096484667165295,
#  '/view-prove-immigration-status': 0.3006731488406881,
#  '/government/organisations/department-for-work-pensions': 0.3006731488406881,
#  '/benefits-calculators': 0.2655198204936425,
#  '/universal-credit': 0.262528047868362,
#  '/log-in-register-hmrc-online-services': 0.25280478683620045,
#  '/state-pension-age': 0.2281226626776365,
#  '/access-to-work': 0.2131637995512341,
#  '/apply-national-insurance-number': 0.19371727748691098,
#  '/search/services': 0.1869857890800299,
#  '/national-minimum-wage-rates': 0.18548990276738966,
#  '/contact-pension-service': 0.18399401645474944,
#  '/browse/working/finding-job': 0.17726252804786835,
#  '/contact-ukvi-inside-outside-uk': 0.17651458489154823,
#  '/government/organisations': 0.17352281226626776,
#  '/check-state-pension': 0.16454749439042632,
#  '/employment-support-allowance': 0.16454749439042632,
#  '/government/organisations/hm-revenue-customs': 0.1637995512341062,
#  '/topic/further-education-skills/apprenticeships': 0.1630516080777861,
#  '/jobseekers-allowance/apply-new-style-jsa': 0.15856394913986538,
#  '/become-apprentice': 0.15557217651458488,
#  '/jobseekers-allowance/eligibility': 0.15033657442034404,
#  '/contact-jobcentre-plus/existing-benefit-claims': 0.15033657442034404,
#  '/browse/working/time-off': 0.14958863126402394,
#  '/pension-credit': 0.14734480179506357,
#  '/view-right-to-work': 0.14659685863874344,
#  '/settled-status-eu-citizens-families': 0.1443530291697831,
#  '/check-uk-visa': 0.14285714285714285,
#  '/call-charges': 0.14210919970082272,
#  '/check-job-applicant-right-to-work': 0.1406133133881825,
#  '/browse/working/tax-minimum-wage': 0.13986537023186238,
#  '/check-state-pension/sign-in/prove-identity': 0.137621540762902,
#  '/government/organisations/disclosure-and-barring-service': 0.137621540762902,
#  '/universal-credit/eligibility': 0.137621540762902,
#  '/state-pension': 0.1368735976065819,
#  '/check-national-insurance-record': 0.13537771129394166,
#  '/criminal-record-checks-apply-role': 0.1331338818249813,
#  '/new-state-pension': 0.12864622288706057,
#  '/statutory-sick-pay': 0.1219147344801795,
#  '/dbs-update-service': 0.12041884816753927,
#  '/browse/visas-immigration/work-visas': 0.12041884816753927,
#  '/browse/benefits/manage-your-benefit': 0.11967090501121914,
#  '/browse/benefits/looking-for-work': 0.11892296185489902,
#  '/national-insurance': 0.11892296185489902,
#  '/browse/working/contract-working-hours': 0.11667913238593866,
#  '/career-skills-and-training': 0.11593118922961855,
#  '/government/organisations/uk-visas-and-immigration': 0.11518324607329843,
#  '/pip': 0.1144353029169783,
#  '/financial-help-disabled': 0.11293941660433807,
#  '/get-state-pension': 0.10845175766641735,
#  '/browse/working/workplace-personal-pensions': 0.10545998504113688,
#  '/browse/benefits/disability': 0.10545998504113688,
#  '/contact-jobcentre-plus/new-benefit-claims': 0.10396409872849663,
#  '/legal-right-work-uk': 0.10321615557217652,
#  '/employment-contracts-and-conditions': 0.1024682124158564,
#  '/carers-allowance': 0.10172026925953627,
#  '/housing-benefit': 0.10172026925953627,
#  '/new-state-pension/what-youll-get': 0.10022438294689603,
#  '/universal-credit/how-to-claim': 0.10022438294689603,
#  '/how-to-have-your-benefits-paid': 0.09947643979057591,
#  '/dbs-check-applicant-criminal-record': 0.0987284966342558,
#  '/employment-rights-for-interns': 0.0987284966342558,
#  '/guidance/red-amber-and-green-list-rules-for-entering-england': 0.09798055347793568,
#  '/personal-tax-account': 0.09723261032161555,
#  '/guidance/redundancy-help-finding-work-and-claiming-benefits': 0.09723261032161555,
#  '/biometric-residence-permits': 0.09723261032161555,
#  '/lost-national-insurance-number': 0.09573672400897532,
#  '/employment-support-allowance/how-to-claim': 0.09498878085265519,
#  '/personal-tax-account/sign-in/prove-identity': 0.09424083769633508,
#  '/skilled-worker-visa': 0.09349289454001496,
#  '/income-tax-rates': 0.09349289454001496,
#  '/national-insurance-credits': 0.09274495138369483,
#  '/browse/education/find-course': 0.09199700822737472,
#  '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-sche

#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship': 0.054599850411368736,
#  '/apply-first-provisional-driving-licence': 0.054599850411368736,
#  '/find-coronavirus-support': 0.054599850411368736,
#  '/new-state-pension/how-to-claim': 0.05385190725504861,
#  '/new-state-pension/how-its-calculated': 0.05385190725504861,
#  '/guidance/claim-a-grant-through-the-self-employment-income-support-scheme': 0.05385190725504861,
#  '/employment-status/worker': 0.05385190725504861,
#  '/tax-codes': 0.05385190725504861,
#  '/government/publications/introducing-govuk-verify/introducing-govuk-verify': 0.05385190725504861,
#  '/child-tax-credit': 0.05385190725504861,
#  '/pension-credit/eligibility': 0.053103964098728494,
#  '/winter-fuel-payment': 0.053103964098728494,
#  '/browse/visas-immigration/settle-in-the-uk': 0.053103964098728494,
#  '/employment-support-allowance/your-esa-claim': 0.053103964098728494,
#  '/grant-bursary-adult-learners': 0.053103964098728494,
#  '/maternity-allowance': 0.053103964098728494,
#  '/job-offers-your-rights': 0.053103964098728494,
#  '/settle-in-the-uk': 0.053103964098728494,
#  '/government/publications/right-to-work-checks-employers-guide': 0.05235602094240838,
#  '/government/publications/register-of-licensed-sponsors-workers': 0.05235602094240838,
#  '/uk-visa-sponsorship-employers': 0.05235602094240838,
#  '/tax-credits-calculator': 0.05235602094240838,
#  '/apply-for-elderly-person-bus-pass': 0.05160807778608826,
#  '/government/organisations/education-and-skills-funding-agency': 0.05160807778608826,
#  '/am-i-getting-minimum-wage': 0.05160807778608826,
#  '/voluntary-national-insurance-contributions': 0.05160807778608826,
#  '/topic/personal-tax/national-insurance': 0.05160807778608826,
#  '/benefit-cap': 0.05160807778608826,
#  '/guidance/basic-dbs-checks-guidance': 0.050860134629768135,
#  '/pension-credit-calculator': 0.05011219147344802,
#  '/what-different-qualification-levels-mean/list-of-qualification-levels': 0.05011219147344802,
#  '/student-visa': 0.05011219147344802,
#  '/browse/benefits/unable-to-work': 0.0493642483171279,
#  '/statutory-sick-pay/eligibility': 0.0493642483171279,
#  '/skilled-worker-visa/your-job': 0.0493642483171279,
#  '/carers-allowance/eligibility': 0.0493642483171279,
#  '/financial-help-disabled/disability-and-sickness-benefits': 0.0493642483171279,
#  '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens': 0.0493642483171279,
#  '/redundancy-your-rights': 0.0493642483171279,
#  '/mandatory-reconsideration': 0.0493642483171279,
#  '/uk-border-control': 0.0493642483171279,
#  '/uk-residence-card': 0.0493642483171279,
#  '/disability-benefits-helpline': 0.0493642483171279,
#  '/access-to-work/what-youll-get': 0.048616305160807775,
#  '/advertise-job': 0.048616305160807775,
#  '/pip/what-youll-get': 0.048616305160807775,
#  '/employment-status/employee': 0.048616305160807775,
#  '/housing-and-universal-credit': 0.048616305160807775,
#  '/working-for-yourself': 0.048616305160807775,
#  '/estimate-income-tax': 0.048616305160807775,
#  '/contact-jobcentre-plus/change-cancel-appointment': 0.04786836200448766,
#  '/know-when-you-can-leave-school': 0.04786836200448766,
#  '/budgeting-help-benefits': 0.04786836200448766,
#  '/bank-holidays': 0.04786836200448766,
#  '/work-health-programme': 0.04786836200448766,
#  '/universal-credit/how-your-earnings-affect-your-payments': 0.04712041884816754,
#  '/guidance/apply-for-a-kickstart-scheme-grant': 0.04712041884816754,
#  '/tax-national-insurance-after-state-pension-age': 0.04712041884816754,
#  '/settled-status-eu-citizens-families/eligibility': 0.046372475691847416,
/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults': 0.033657442034405384,
#  '/browse/disabilities/equipment': 0.033657442034405384,
#  '/settled-status-eu-citizens-families/switch-from-presettled-status-to-settled-status': 0.033657442034405384,
#  '/how-to-claim-new-style-esa': 0.033657442034405384,
#  '/find-travel-test-provider': 0.033657442034405384,
#  '/government/publications/eu-settlement-scheme-application-processing-times': 0.033657442034405384,
#  '/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2': 0.033657442034405384,
#  '/bereavement-support-payment': 0.033657442034405384,
#  '/the-warm-home-discount-scheme': 0.033657442034405384,
#  '/government/publications/test-and-trace-support-payment-scheme-claiming-financial-support/claiming-financial-support-under-the-test-and-trace-support-payment-scheme': 0.033657442034405384,
#  '/biometric-residence-permits/replace-visa-brp': 0.033657442034405384,
#  '/over-80-pension': 0.032909498878085267,
#  '/browse/visas-immigration/family-visas': 0.032909498878085267,
#  '/state-pension/how-to-claim': 0.032909498878085267,
#  '/keeping-your-pay-tax-records': 0.032909498878085267,
#  '/browse/tax/self-assessment': 0.032909498878085267,
#  '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes': 0.032909498878085267,
#  '/browse/abroad/living-abroad': 0.032909498878085267,
#  '/browse/benefits/bereavement': 0.032909498878085267,
#  '/browse/childcare-parenting/pregnancy-birth': 0.032909498878085267,
#  '/topic/work-careers/government-graduate-schemes': 0.032909498878085267,
#  '/definition-of-disability-under-equality-act-2010': 0.032909498878085267,
#  '/skilled-worker-visa/documents-you-must-provide': 0.032909498878085267,
#  '/employing-an-apprentice/pay-and-conditions-for-apprentices': 0.032909498878085267,
#  '/book-theory-test': 0.032909498878085267,
#  '/learner-support': 0.032909498878085267,
#  '/order-copy-birth-death-marriage-certificate': 0.032909498878085267,
#  '/register-employer': 0.032909498878085267,
#  '/child-benefit-16-19': 0.032909498878085267,
#  '/government/collections/apprenticeship-changes': 0.03216155572176514,
#  '/government/publications/apprenticeship-funding-bands': 0.03216155572176514,
#  '/report-problem-criminal-record-certificate': 0.03216155572176514,
#  '/state-pension/increase-the-amount-youll-get': 0.03216155572176514,
#  '/paye-forms-p45-p60-p11d/p60': 0.03216155572176514,
#  '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers': 0.03216155572176514,
#  '/topic/business-tax/pension-scheme-administration': 0.03216155572176514,
#  '/plan-retirement-income': 0.03216155572176514,
#  '/government/publications/statutory-sick-pay-employee-not-entitled-form-for-employers': 0.03216155572176514,
#  '/uk-family-visa/partner-spouse': 0.03216155572176514,
#  '/maternity-allowance/how-to-claim': 0.03216155572176514,
#  '/guidance/how-to-take-on-an-apprentice': 0.03216155572176514,
#  '/government/organisations/department-for-work-pensions/about': 0.03216155572176514,
#  '/guidance/contact-the-department-for-work-and-pensions-about-its-policies': 0.03216155572176514,
#  '/employers-sick-pay/eligibility-and-form-ssp1': 0.03216155572176514,
#  '/seasonal-worker-visa': 0.02019446522064323,
#  '/attendance-allowance/how-to-claim': 0.02019446522064323,
#  '/redundancy-your-rights/get-help-finding-a-new-job': 0.02019446522064323,
# ...
#  '/identitycards': 0.01944652206432311,
#  '/severe-disablement-allowance': 0.01944652206432311,
#  '/driving-medical-conditions': 0.01944652206432311,
#  '/biometric-residence-permits/report-problem': 0.01944652206432311,
#  '/jobsearch-rights': 0.01944652206432311,
#  '/guidance/national-skills-fund': 0.01944652206432311,
#  '/guidance/academic-technology-approval-scheme': 0.01944652206432311,
#  '/healthy-start': 0.01944652206432311,
#  '/government/publications/universal-credit-work-allowances/universal-credit-work-allowances': 0.01944652206432311,
#  '/government/publications/acceptable-right-to-work-documents-an-employers-guide': 0.018698578908002993,
#  '/budgeting-help-benefits/what-youll-get': 0.018698578908002993,
#  '/advanced-learner-loan/eligibility': 0.018698578908002993,
#  '/contracted-out/check-if-you-were-contracted-out': 0.018698578908002993,
#  '/national-minimum-wage/employers-and-the-minimum-wage': 0.018698578908002993,
#  '/government/publications/dbs-update-service-employer-guide': 0.018698578908002993,
#  '/check-driving-information': 0.018698578908002993,
#  '/financial-help-disabled/television-licence-discount': 0.018698578908002993,
#  '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education': 0.018698578908002993,
#  '/passport-fees': 0.018698578908002993,
#  '/government/publications/dbs-workforce-guidance': 0.018698578908002993,
#  '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed': 0.018698578908002993,
#  '/browse/births-deaths-marriages/child': 0.018698578908002993,
#  '/join-trade-union': 0.018698578908002993,
#  '/learn-to-drive-a-car': 0.018698578908002993,
#  '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments': 0.018698578908002993,
#  '/international-agreement-worker-visa': 0.018698578908002993,
#  '/overseas-domestic-worker-visa': 0.018698578908002993,
#  '/what-is-the-construction-industry-scheme': 0.018698578908002993,
#  '/raise-grievance-at-work': 0.018698578908002993,
#  '/government/publications/dbs-list-of-offences-that-will-never-be-filtered-from-a-criminal-record-check': 0.018698578908002993,
#  '/log-in-hmrc-excise-import-export': 0.018698578908002993,
#  '/support-for-mortgage-interest': 0.018698578908002993,
#  '/apply-for-council-tax-discount': 0.018698578908002993,
#  '/uk-border-control/at-border-control': 0.018698578908002993,
#  '/report-changes-child-benefit': 0.018698578908002993,
#  '/government/organisations/hm-revenue-customs/contact/get-help-with-the-self-employment-income-support-scheme': 0.018698578908002993,
#  '/guidance/claim-for-wages-through-the-coronavirus-job-retention-scheme': 0.018698578908002993,
#  '/apply-needs-assessment-social-services': 0.018698578908002993,
#  '/government/get-involved/take-part/volunteer': 0.01795063575168287,
#  '/access-to-work/renew': 0.01795063575168287,
#  '/tell-employer-or-college-about-criminal-record/check-your-conviction-caution': 0.01795063575168287,
#  '/dismissal/what-to-do-if-youre-dismissed': 0.01795063575168287,
#  '/apply-citizenship-indefinite-leave-to-remain': 0.01795063575168287,
#  '/browse/driving/learning-to-drive': 0.01795063575168287,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations': 0.01795063575168287,
#  '/handing-in-your-notice/giving-notice': 0.01795063575168287,
#  '/agricultural-sick-pay': 0.01795063575168287,
#  '/employers-sick-pay/entitlement': 0.01795063575168287,
#  '/tell-dvla-changed-address': 0.01795063575168287,
#  '/benefit-overpayments/when-repayments-have-to-be-made': 0.01795063575168287,
#  '/guidance/eu-settlement-scheme-uk-tax-and-benefits-records-automated-check': 0.01795063575168287,
#  '/workplace-pensions/protection-for-your-pension': 0.01795063575168287,
#  '/apply-for-council-housing': 0.01795063575168287,
#  '/your-rights-if-your-employer-is-insolvent': 0.01795063575168287,
#  '/financial-help-disabled/vat-relief': 0.01795063575168287,
#  '/government/publications/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens-accessible-version': 0.01795063575168287,
#  '/working-tax-credit/how-to-claim': 0.01795063575168287,
#  '/get-document-legalised': 0.01795063575168287,
#  '/get-help-hmrc-extra-support': 0.01795063575168287,
#  '/tax-uk-income-live-abroad': 0.01795063575168287,
#  '/guidance/rehabilitation-periods': 0.01795063575168287,
#  '/income-tax/check-youre-paying-the-right-amount': 0.01795063575168287,
#  '/self-employed-records': 0.01795063575168287,
#  '/apply-marriage-allowance': 0.01795063575168287,
#  '/find-postgraduate-teacher-training-courses': 0.01795063575168287,
#  '/financial-help-disabled/on-a-low-salary': 0.01795063575168287,
#  '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus': 0.01795063575168287,
#  '/plan-retirement-income/pensions-from-the-government': 0.01795063575168287,
#  '/visa-fees': 0.01795063575168287,
#  '/when-is-your-next-tax-credits-payment': 0.01795063575168287,
#  '/apply-for-disabled-bus-pass': 0.01795063575168287,
#  '/skilled-worker-visa/switch-to-this-visa': 0.01795063575168287,
#  '/childcare-calculator': 0.01795063575168287,
#  '/tax-free-childcare': 0.01795063575168287,
#  '/track-passport-application': 0.01795063575168287,
#  '/browse/visas-immigration/immigration-appeals': 0.01720269259536275,
#  '/redundancy-your-rights/suitable-alternative-employment': 0.01720269259536275,
#  '/browse/driving/vehicle-tax-mot-insurance': 0.01720269259536275,
#  '/browse/disabilities/rights': 0.01720269259536275,
#  '/browse/employing-people/dismissals-redundancies': 0.01720269259536275,
#  '/government/publications/find-a-skills-bootcamp/list-of-skills-bootcamps': 0.01720269259536275,
#  '/paternity-pay-leave/pay': 0.01720269259536275,
#  '/apply-to-come-to-the-uk/prepare-your-application': 0.01720269259536275,
#  '/higher-education-courses-find-and-apply': 0.01720269259536275,
#  '/recruitment-disabled-people': 0.01720269259536275,
#  '/view-right-to-rent': 0.01720269259536275,
#  '/budgeting-help-benefits/after-you-apply': 0.01720269259536275,
#  '/government/publications/the-official-hmrc-app': 0.01720269259536275,
#  '/council-housing': 0.01720269259536275,
#  '/government/publications/dbs-filtering-guidance/dbs-filtering-guide': 0.01720269259536275,
#  '/guidance/search-for-apprenticeship-standards': 0.01720269259536275,
#  '/whistleblowing': 0.01720269259536275,
#  '/biometric-residence-permits/lost-stolen-damaged': 0.01720269259536275,
#  '/renewing-your-tax-credits-claim': 0.01720269259536275,
#  '/work/pensions-and-ageing-society': 0.01720269259536275,
#  '/browse/working/finding-job': 0.17726252804786835,
#  '/jobseekers-allowance/apply-new-style-jsa': 0.15856394913986538,
#  '/dbs-update-service': 0.12041884816753927,
#  '/criminal-record-checks-apply-role': 0.1331338818249813,
#  '/new-state-pension': 0.12864622288706057,
#  '/government/organisations/department-for-work-pensions': 0.3006731488406881,
#  '/apply-national-insurance-number': 0.19371727748691098,
#  '/state-pension-age': 0.2281226626776365,
#  '/contact-pension-service': 0.18399401645474944,
#  '/new-state-pension/what-youll-get': 0.10022438294689603,
#  '/check-job-applicant-right-to-work': 0.1406133133881825,
#  '/contact-jobcentre-plus/new-benefit-claims': 0.10396409872849663,
#  '/become-apprentice/apply-for-an-apprenticeship': 0.04038893044128646,
#  '/contact-jobcentre-plus/existing-benefit-claims': 0.15033657442034404,
#  '/get-state-pension': 0.10845175766641735,
#  '/sign-in-universal-credit': 0.3096484667165295,
#  '/check-state-pension/sign-in/create-account': 0.041884816753926704,
#  '/become-apprentice': 0.15557217651458488,
#  '/universal-credit': 0.262528047868362,
#  '/find-out-dbs-check': 0.07479431563201197,
#  '/access-to-work': 0.2131637995512341,
#  '/access-to-work/eligibility': 0.05983545250560957,
#  '/browse/working/workplace-personal-pensions': 0.10545998504113688,
#  '/legal-right-work-uk': 0.10321615557217652,
#  '/browse/benefits/looking-for-work': 0.11892296185489902,
#  '/universal-credit/eligibility': 0.137621540762902,
#  '/state-pension': 0.1368735976065819,
#  '/access-to-work/what-youll-get': 0.048616305160807775,
#  '/browse/working/tax-minimum-wage': 0.13986537023186238,
#  '/contact-ukvi-inside-outside-uk': 0.17651458489154823,
#  '/criminal-record-checks-apply-role/application-process': 0.03889304412864622,
#  '/become-apprentice/pay-and-conditions': 0.06207928197456993,
#  '/universal-credit/what-youll-get': 0.08900523560209424,
#  '/personal-tax-account': 0.09723261032161555,
#  '/personal-tax-account/sign-in/prove-identity': 0.09424083769633508,
#  '/browse/benefits/manage-your-benefit': 0.11967090501121914,
#  '/benefits-calculators': 0.2655198204936425,
#  '/advertise-job': 0.048616305160807775,
#  '/browse/education/find-course': 0.09199700822737472,
#  '/employment-support-allowance': 0.16454749439042632,
#  '/employment-support-allowance/eligibility': 0.08825729244577411,
#  '/access-to-work/apply': 0.05833956619296933,
#  '/guidance/track-a-dbs-application': 0.07180254300673149,
#  '/government/publications/higher-and-degree-apprenticeships': 0.031413612565445025,
#  '/dbs-check-applicant-criminal-record': 0.0987284966342558,
#  '/browse/working/time-off': 0.14958863126402394,
#  '/jobseekers-allowance/your-jsa-claim': 0.07030665669409125,
#  '/pension-credit': 0.14734480179506357,
#  '/pension-credit/eligibility': 0.053103964098728494,
#  '/guidance/responsible-organisations': 0.04338070306656694,
#  '/browse/working/contract-working-hours': 0.11667913238593866,
#  '/national-minimum-wage-rates': 0.18548990276738966,
#  '/state-pension/eligibility': 0.06731488406881077,
#  '/new-state-pension/your-national-insurance-record-and-your-state-pension': 0.05983545250560957,
#  '/new-state-pension/how-to-claim': 0.05385190725504861,
#  '/browse/visas-immigration/work-visas': 0.12041884816753927,
#  '/browse/disabilities/work': 0.0456245325355273,
#  '/check-income-tax-current-year': 0.0456245325355273,
#  '/check-income-tax-current-year/sign-in/prove-identity': 0.030665669409124907,
#  '/pip': 0.1144353029169783,
#  '/pip/eligibility': 0.04263275991024682,
#  '/browse/citizenship/citizenship': 0.0381451009723261,
#  '/personal-pensions-your-rights': 0.06806282722513089,
#  '/additional-state-pension/what-youll-get': 0.02169035153328347,
#  '/over-80-pension': 0.032909498878085267,
#  '/browse/benefits/low-income': 0.068810770381451,
#  '/apply-for-elderly-person-bus-pass': 0.05160807778608826,
#  '/international-pension-centre': 0.05609573672400897,
#  '/universal-credit/how-youre-paid': 0.041884816753926704,
#  '/browse/disabilities/benefits': 0.06656694091249064,
#  '/workplace-pensions': 0.08975317875841436,
#  '/settled-status-eu-citizens-families': 0.1443530291697831,
#  '/settled-status-eu-citizens-families/eligibility': 0.046372475691847416,
#  '/calculate-your-holiday-entitlement': 0.06357516828721017,
#  '/government/collections/new-enterprise-allowance-campaign': 0.0344053851907255,
#  '/government/publications/the-basic-state-pension': 0.04113687359760658,
#  '/find-internship': 0.04038893044128646,
#  '/browse/visas-immigration/what-you-need-to-do': 0.0456245325355273,
#  '/lost-national-insurance-number': 0.09573672400897532,
#  '/update-uk-visas-immigration-account-details': 0.05609573672400897,
#  '/update-uk-visas-immigration-account-details/update-your-ukvi-account': 0.02393418100224383,
#  '/reasonable-adjustments-for-disabled-workers': 0.05759162303664921,
#  '/government/organisations/education-and-skills-funding-agency': 0.05160807778608826,
#  '/pension-credit/what-youll-get': 0.04263275991024682,
#  '/new-state-pension/how-its-calculated': 0.05385190725504861,
#  '/tell-employer-or-college-about-criminal-record': 0.04487658937920718,
#  '/tell-employer-or-college-about-criminal-record/what-information-you-need-to-give': 0.01944652206432311,
#  '/skilled-worker-visa/your-job': 0.0493642483171279,
#  '/guidance/redundancy-help-finding-work-and-claiming-benefits': 0.09723261032161555,
#  '/early-retirement-pension': 0.04487658937920718,
#  '/statutory-sick-pay/how-to-claim': 0.0456245325355273,
#  '/deferring-state-pension': 0.06207928197456993,
#  '/government/organisations/hm-revenue-customs': 0.1637995512341062,
#  '/check-immigration-status': 0.046372475691847416,
#  '/browse/employing-people/contracts': 0.07703814510097233,
#  '/guidance/coronavirus-covid-19-right-to-work-checks': 0.025430067314884067,
#  '/check-uk-visa': 0.14285714285714285,
#  '/topic/personal-tax/income-tax': 0.056843679880329095,
#  '/government/collections/dbs-checking-service-guidance--2': 0.04338070306656694,
#  '/find-pension-contact-details': 0.06207928197456993,
#  '/future-pension-centre': 0.04412864622288706,
#  '/government/publications/acceptable-right-to-work-documents-an-employers-guide': 0.018698578908002993,
#  '/disability-premiums/how-to-claim': 0.02393418100224383,
#  '/government/organisations': 0.17352281226626776,
#  '/personal-tax-account/sign-in/create-account': 0.023186237845923708,
#  '/government/publications/apprenticeship-funding-bands': 0.03216155572176514,
#  '/know-when-you-can-leave-school': 0.04786836200448766,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance
/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide': 0.008975317875841436,
#  '/income-tax/check-youre-paying-the-right-amount': 0.01795063575168287,
#  '/bereavement-support-payment/how-to-claim': 0.0074794315632011965,
#  '/check-mot-history': 0.030665669409124907,
#  '/vehicle-exempt-from-vehicle-tax': 0.014958863126402393,
#  '/government/organisations/skills-funding-agency': 0.013462976813762153,
#  '/tax-on-your-private-pension/lifetime-allowance': 0.020942408376963352,
#  '/guidance/temporary-jobcentres-during-the-coronavirus-covid-19-pandemic': 0.010471204188481676,
#  '/identitycards': 0.01944652206432311,
#  '/payment-exception-service': 0.016454749439042633,
#  '/overtime-your-rights/parttime-workers': 0.009723261032161555,
#  '/paye-forms-p45-p60-p11d/lost-paye-forms': 0.02019446522064323,
#  '/id-scan-eu-settlement-scheme': 0.011219147344801795,
#  '/register-employer': 0.032909498878085267,
#  '/uk-benefits-abroad': 0.013462976813762153,
#  '/topic/crime-policing/criminal-record-disclosure': 0.037397157816005985,
#  '/jobcentre-plus-help-for-recruiters/other-employment-schemes': 0.011967090501121914,
#  '/residence-documents-foreign-nationals-uk': 0.014210919970082274,
#  '/dismiss-staff': 0.0037397157816005983,
#  '/self-employed-records': 0.01795063575168287,
#  '/self-employed-records/what-records-to-keep': 0.004487658937920718,
#  '/apply-blue-badge': 0.03590127150336574,
#  '/dla-disability-living-allowance-benefit/dla-rates': 0.023186237845923708,
#  '/government/publications/paye-starter-checklist': 0.02169035153328347,
#  '/get-help-savings-low-income/what-youll-get': 0.0067314884068810765,
#  '/probate-estate': 0.023186237845923708,
#  '/guidance/indefinite-leave-to-remain-in-the-uk': 0.02169035153328347,
#  '/faster-decision-visa-settlement': 0.02393418100224383,
#  '/child-benefit/make-a-change-to-your-claim': 0.012715033657442034,
#  '/claim-asylum': 0.008227374719521317,
#  '/financial-help-disabled/home-and-housing': 0.023186237845923708,
#  '/agricultural-workers-rights': 0.008975317875841436,
#  '/government/publications/the-official-hmrc-app': 0.01720269259536275,
#  '/exchange-foreign-driving-licence': 0.016454749439042633,
#  ...}

# %% [markdown]
# ### Overall rank from multiple ranked items
#
# Choose a final ranking method. In this example, `shortest_seed0_1`, `shortest_seed0_2`, `g_degree` have been used.

# %%
# create lists in order
sessions_list = [(index, element[0]) for index, element in enumerate(sessions)]
shortest_seed0_1_list = [
    (index, element) for index, element in enumerate(shortest_seed0_1)
]
shortest_seed0_2_list = [
    (index, element) for index, element in enumerate(shortest_seed0_2)
]
combined_paths_list = [(index, element) for index, element in enumerate(combined_paths)]
# g_between_list = [(index, element) for index, element in enumerate(g_between)]
g_degree_list = [(index, element) for index, element in enumerate(g_degree)]
# g_closeness_list = [(index, element) for index, element in enumerate(g_closeness)]

# %%
shortest_seed0_1_list
# Out:
# [(0, '/browse/working/finding-job'),
#  (1, '/dbs-update-service'),
#  (2,
#   '/government/collections/sponsorship-information-for-employers-and-educators'),
#  (3, '/view-right-to-work'),
#  (4, '/access-to-work/after-you-have-applied'),
#  (5, '/employment-status'),
#  (6, '/guidance/dbs-check-requests-guidance-for-employers'),
#  (7, '/what-different-qualification-levels-mean'),
#  (8,
#   '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers'),
#  (9, '/become-apprentice/apply-for-an-apprenticeship'),
#  (10, '/browse/working/redundancies-dismissals'),
#  (11, '/improve-english-maths-it-skills'),
#  (12, '/find-internship'),
#  (13, '/contact-ukvi-inside-outside-uk'),
#  (14, '/coronavirus/worker-support'),
#  (15, '/access-to-work'),
#  (16, '/apply-universal-credit'),
#  (17, '/work-reference'),
#  (18, '/job-offers-your-rights'),
#  (19, '/jobseekers-allowance'),
#  (20, '/find-a-job'),
#  (21, '/browse/working/time-off'),
#  (22,
#   '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations'),
#  (23, '/topic/work-careers/secondments-with-government'),
#  (24, '/manage-your-tax-credits'),
#  (25, '/browse/benefits/looking-for-work'),
#  (26,
#   '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme'),
#  (27, '/government/organisations/disclosure-and-barring-service'),
#  (28, '/skilled-worker-visa/knowledge-of-english'),
#  (29,
#   '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide/universal-credit-if-you-have-a-disability-or-health-condition'),
#  (30,
#   '/government/organisations/department-for-work-pensions/about/recruitment'),
#  (31,
#   '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do'),
#  (32, '/jobseekers-allowance/eligibility'),
#  (33, '/intracompany-transfer-worker-visa'),
#  (34, '/sign-in-universal-credit'),
#  (35, '/volunteering/when-you-can-volunteer'),
#  (36,
#   '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes'),
#  (37, '/employee-immigration-employment-status'),
#  (38,
#   '/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2'),
#  (39, '/guidance/red-amber-and-green-list-rules-for-entering-england'),
#  (40, '/jobsearch-rights'),
#  (41, '/advertise-job'),
#  (42, '/get-information-about-a-company'),
#  (43, '/tell-employer-or-college-about-criminal-record'),
#  (44, '/get-copy-military-service-records'),
#  (45, '/report-problem-criminal-record-certificate'),
#  (46, '/universal-credit'),
#  (47, '/british-citizenship'),
#  (48, '/check-job-applicant-right-to-work'),
#  (49, '/pip/eligibility'),
#  (50, '/employment-rights-for-interns'),
#  (51, '/government/get-involved/take-part/volunteer'),
#  (52, '/register-to-vote'),
#  (53, '/death-spouse-benefits-tax-pension/pensions'),
#  (54, '/check-uk-visa'),
#  (55, '/work-health-programme'),
#  (56, '/government/organisations'),
#  (57, '/government/organisations/home-office'),
#  (58, '/settled-status-eu-citizens-families/apply-settled-status-for-child'),
#  (59, '/seasonal-worker-visa'),
#  (60, '/jobseekers-allowance/report-a-change-of-circumstances'),
#  (61, '/browse/working/armed-forces'),
#  (62, '/guidance/immigration-rules'),
#  (63, '/browse/working/rights-trade-unions'),
#  (64, '/tell-employer-or-college-about-criminal-record/driving-convictions'),
#  (65,
#   '/government/publications/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens-accessible-version'),
#  (66, '/browse/visas-immigration/work-visas'),
#  (67, '/career-skills-and-training'),
#  (68, '/topic/further-education-skills/apprenticeships'),
#  (69, '/government/organisations/department-for-work-pensions/about'),
#  (70, '/browse/employing-people/trade-unions'),
#  (71, '/browse/working/tax-minimum-wage'),
#  (72, '/skilled-worker-visa/documents-you-must-provide'),
#  (73, '/apply-apprenticeship'),
#  (74, '/volunteering'),
#  (75, '/jobcentre-plus-help-for-recruiters'),
#  (76, '/contact-jobcentre-plus'),
#  (77, '/criminal-record-checks-apply-role'),
#  (78, '/contact-the-dvla'),
#  (79, '/find-traineeship'),
#  (80, '/moving-from-benefits-to-work/support-when-you-start-working'),
#  (81, '/tell-employer-or-college-about-criminal-record/prison-sentences'),
#  (82, '/exchange-foreign-driving-licence'),
#  (83, '/dbs-check-applicant-criminal-record'),
#  (84, '/government/publications/skilled-worker-visa-shortage-occupations'),
#  (85, '/browse/working/workplace-personal-pensions'),
#  (86, '/browse/working/contract-working-hours'),
#  (87, '/topic/defence-armed-forces/military-recruitment-training-operations'),
#  (88, '/help-with-childcare-costs'),
#  (89,
#   '/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work'),
#  (90, '/student-finance/who-qualifies'),
#  (91, '/child-employment/paying'),
#  (92, '/national-insurance/national-insurance-classes'),
#  (93,
#   '/government/publications/standard-and-enhanced-dbs-check-privacy-policy/standard-and-enhanced-dbs-check-privacy-policy'),
#  (94,
#   '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers'),
#  (95, '/government/organisations/hm-revenue-customs/about/recruitment'),
#  (96, '/tax-credits-calculator'),
#  (97, '/pip/when-your-pip-claim-is-reviewed'),
#  (98, '/log-in-register-hmrc-online-services'),
#  (99, '/moving-from-benefits-to-work'),
#  (100, '/looking-for-work-if-disabled'),
#  (101, '/browse/working'),
#  (102, '/benefits-calculators'),
#  (103, '/uk-visa-sponsorship-employers'),
#  (104, '/criminal-record-check-documents'),
#  (105,
#   '/guidance/immigration-rules/immigration-rules-appendix-shortage-occupation-list'),
#  (106, '/contact-jobcentre-plus/change-cancel-appointment'),
#  (107, '/become-apprentice'),
#  (108, '/government/publications/register-of-licensed-sponsors-workers'),
#  (109, '/contact-jobcentre-plus/new-benefit-claims'),
#  (110, '/topic/work-careers/government-graduate-schemes'),
#  (111, '/employers-checks-job-applicants'),
#  (112, '/browse/education/find-course'),
#  (113, '/search/services'),
#  (114, '/national-insurance'),
#  (115, '/guidance/free-courses-for-jobs'),
#  (116, '/legal-right-work-uk'),
#  (117, '/graduate-visa/documents-youll-need-to-apply'),
#  (118, '/government/collections/dbs-filtering-guidance'),
#  (119,
#   '/government/organisations/hm-revenue-customs/contact/online-services-helpdesk'),
#  (120, '/guidance/dvla-coronavirus-covid-19-update'),
#  (121, '/apply-sponsor-licence'),
#  (122, '/child-benefit-16-19'),
#  (123, '/carers-allowance-report-change'),
#  (124, '/guidance/search-for-apprenticeship-standards'),
#  (125,
#   '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations'),
#  (126, '/apply-direct-payments'),
#  (127,
#   '/government/publications/filtering-rules-for-criminal-record-check-certificates'),
#  (128, '/browse/visas-immigration/student-visas'),
#  (129, '/log-in-hmrc-excise-import-export'),
#  (130, '/student-visa/money'),
#  (131,
#   '/government/publications/access-to-work-factsheet/access-to-work-factsheet-for-customers'),
#  (132, '/id-for-driving-licence'),
#  (133, '/biometric-residence-permits/replace-expired-brp'),
#  (134, '/employing-an-apprentice/apprenticeship-agreement'),
#  (135, '/volunteering/volunteers-rights'),
#  (136,
#   '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus'),
#  (137, '/graduate-visa/course-you-studied'),
#  (138, '/browse/childcare-parenting/schools-education'),
#  (139, '/overtime-your-rights/compulsory-overtime'),
#  (140, '/financial-help-disabled/home-and-housing'),
#  (141, '/moving-from-benefits-to-work/work-experience-and-volunteering'),
#  (142, '/browse/childcare-parenting/financial-help-children'),
#  (143, '/understanding-your-pay/deductions-from-your-pay'),
#  (144, '/government/organisations/hm-revenue-customs/contact'),
#  (145,
#   '/government/publications/redundancy-payments-rp1-fact-sheet/what-to-do-when-youve-been-made-redundant'),
#  (146, '/mandatory-reconsideration/how-to-ask-for-mandatory-reconsideration'),
#  (147,
#   '/government/publications/criminal-records-checks-for-overseas-applicants'),
#  (148, '/bank-holidays'),
#  (149, '/settled-status-eu-citizens-families/what-youll-need-to-apply'),
#  (150, '/passport-fees'),
#  (151, '/budgeting-help-benefits'),
#  (152, '/government/publications/basic-check-guidance-and-policies'),
#  (153, '/statutory-sick-pay'),
#  (154, '/housing-benefit/other-help-with-housing-costs'),
#  (155, '/dual-citizenship'),
#  (156, '/fraud-error-prevention-centres'),
#  (157, '/self-employment-and-universal-credit'),
#  (158, '/criminal-record-checks-apply-role/application-process'),
#  (159, '/register-for-self-assessment/self-employed'),
#  (160, '/disability-living-allowance-children/rates'),
#  (161, '/browse/abroad/travel-abroad'),
#  (162, '/check-british-citizenship'),
#  (163, '/government/publications/dbs-update-service-applicant-guide'),
#  (164, '/time-off-for-dependants'),
#  (165, '/guidance/how-to-take-on-an-apprentice'),
#  (166, '/estimate-income-tax'),
#  (167, '/recruitment-disabled-people'),
#  (168, '/advanced-learner-loan'),
#  (169,
#   '/government/collections/financial-support-for-businesses-during-coronavirus-covid-19'),
#  (170, '/uk-residence-card'),
#  (171, '/government/organisations/skills-funding-agency'),
#  (172, '/national-insurance-rates-letters/category-letters'),
#  (173, '/foreign-travel-advice/france'),
#  (174, '/council-tax'),
#  (175, '/help'),
#  (176, '/apply-disabled-facilities-grant'),
#  (177, '/browse/tax/dealing-with-hmrc'),
#  (178, '/driving-lessons-learning-to-drive'),
#  (179, '/changes-affect-tax-credits'),
#  (180, '/guidance/using-your-uk-visas-and-immigration-account'),
#  (181, '/further-education-courses'),
#  (182, '/tax-on-pension/tax-free'),
#  (183, '/right-to-reside'),
#  (184, '/student-finance'),
#  (185, '/get-copy-military-service-records/apply-for-someone-elses-records'),
#  (186, '/guidance/new-immigration-system-what-you-need-to-know'),
#  (187, '/national-minimum-wage-accommodation'),
#  (188,
#   '/government/publications/dbs-application-forms-guide-for-applicants/dbs-application-form-guide-for-applicants'),
#  (189, '/cold-weather-payment/eligibility'),
#  (190,
#   '/guidance/contact-the-department-for-work-and-pensions-about-its-policies'),
#  (191, '/what-is-the-construction-industry-scheme'),
#  (192, '/workplace-pensions/what-you-your-employer-and-the-government-pay'),
#  (193, '/government/publications/apprenticeship-funding-bands'),
#  (194, '/tax-on-pension'),
#  (195, '/taking-sick-leave'),
#  (196, '/rest-breaks-work/disputes'),
#  (197, '/paye-forms-p45-p60-p11d/p60'),
#  (198, '/carers-allowance/if-youre-working-'),
#  (199,
#   '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide'),
#  (200, '/browse/visas-immigration/settle-in-the-uk'),
#  (201, '/claim-benefits-abroad/jobseekers-allowance'),
#  (202, '/financial-help-disabled/disability-and-sickness-benefits'),
#  (203, '/dvlaforms'),
#  (204, '/looking-for-work-if-disabled/applying-for-a-job'),
#  (205, '/student-visa/extend-your-visa'),
#  (206, '/dla-disability-living-allowance-benefit'),
#  (207,
#   '/dbs-check-applicant-criminal-record/get-a-standard-or-enhanced-dbs-check-for-an-employee'),
#  (208, '/graduate-visa'),
#  (209, '/benefit-fraud'),
#  (210, '/browse/births-deaths-marriages/child'),
#  (211, '/benefit-overpayments'),
#  (212, '/maternity-pay-leave/leave'),
#  (213, '/guidance/statutory-sick-pay-employee-fitness-to-work'),
#  (214, '/join-trade-union/trade-union-membership-your-employment-rights'),
#  (215, '/child-employment'),
#  (216, '/carers-allowance'),
#  (217, '/education/apprenticeships-traineeships-and-internships'),
#  (218, '/deferring-state-pension'),
#  (219,
#   '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes'),
#  (220,
#   '/state-pension-if-you-retire-abroad/report-a-change-in-your-circumstances'),
#  (221,
#   '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa'),
#  (222, '/government/collections/traineeships--2'),
#  (223, '/parental-leave/notice-period'),
#  (224, '/income-tax/check-youre-paying-the-right-amount'),
#  (225, '/topic/personal-tax/national-insurance'),
#  (226, '/dismissal'),
#  (227, '/employment-support-allowance/what-youll-get'),
#  (228, '/renew-adult-passport'),
#  (229, '/employment/finding-job'),
#  (230, '/monitoring-work-workers-rights'),
#  (231, '/topic/business-tax/pension-scheme-administration'),
#  (232,
#   '/new-state-pension/inheriting-or-increasing-state-pension-from-a-spouse-or-civil-partner'),
#  (233, '/log-in-file-self-assessment-tax-return/sign-in/prove-identity'),
#  (234, '/student-finance/extra-help'),
#  (235, '/calculate-employee-redundancy-pay'),
#  (236,
#   '/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19'),
#  (237,
#   '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022'),
#  (238, '/universal-credit/how-your-earnings-affect-your-payments'),
#  (239, '/employment-tribunals/make-a-claim'),
#  (240, '/universal-credit/get-an-advance-first-payment'),
#  (241, '/get-undergraduate-student-loan'),
#  (242, '/apply-to-come-to-the-uk'),
#  (243, '/topic/crime-policing/criminal-record-disclosure'),
#  (244, '/standard-visitor-visa/apply'),
#  (245,
#   '/government/publications/apprenticeship-recruitment-employers-and-training-organisations'),
#  (246, '/foreign-travel-advice/spain'),
#  (247,
#   '/guidance/government-legal-service-gls-legal-trainee-scheme-how-to-apply'),
#  (248, '/life-in-the-uk-test'),
#  (249, '/browse/employing-people/recruiting-hiring'),
#  (250, '/dismissal/unfair-and-constructive-dismissal'),
#  (251, '/disability-premiums/what-youll-get'),
#  (252, '/national-insurance/change-of-circumstance'),
#  (253, '/browse/employing-people/time-off'),
#  (254, '/browse/disabilities/benefits'),
#  (255,
#   '/government/publications/new-enterprise-allowance-phase-2-provider-guidance/new-enterprise-allowance-phase-2-provider-guidance'),
#  (256, '/types-of-british-nationality'),
#  (257, '/disabled-students-allowance-dsa'),
#  (258, '/tax-on-your-private-pension/annual-allowance'),
#  (259, '/redundancy-your-rights/being-selected-for-redundancy'),
#  (260, '/government/publications/find-a-free-level-3-qualification'),
#  (261,
#   '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments'),
#  (262, '/agricultural-workers-rights'),
#  (263, '/government/collections/desg-graduate-scheme'),
#  (264, '/benefit-cap/benefit-cap-amounts'),
#  (265, '/incapacity-benefit'),
#  (266, '/tax-on-your-private-pension/pension-tax-relief'),
#  (267, '/recruitment-disabled-people/encouraging-applications'),
#  (268,
#   '/government/publications/disclosure-application-process-for-volunteers'),
#  (269, '/national-insurance/help-if-youre-not-working'),
#  (270, '/statutory-sick-pay/how-to-claim'),
#  (271, '/biometric-residence-permits/personal-data'),
#  (272, '/government/organisations/education-and-skills-funding-agency'),
#  (273, '/apply-for-student-finance'),
#  (274, '/view-right-to-rent'),
#  (275, '/contract-types-and-employer-responsibilities'),
#  (276, '/payment-exception-service'),
#  (277, '/child-benefit-move-to-uk'),
#  (278, '/tax-help'),
#  (279, '/continuous-employment-what-it-is'),
#  (280, '/government/organisations/hm-revenue-customs/contact/child-benefit'),
#  (281, '/training-study-work-your-rights'),
#  (282, '/biometric-residence-permits/not-arrived'),
#  (283, '/1619-bursary-fund/eligibility'),
#  (284, '/early-retirement-pension'),
#  (285, '/track-passport-application'),
#  (286, '/start-up-visa'),
#  (287, '/send-fit-note'),
#  (288, '/browse/benefits/disability'),
#  (289, '/budgeting-help-benefits/repayments'),
#  (290, '/government/publications/budgeting-loan-claim-form'),
#  (291, '/international-pension-centre'),
#  (292, '/join-trade-union'),
#  (293, '/travel-abroad'),
#  (294,
#   '/government/publications/dbs-update-service-applicant-guide/dbs-update-service-applicant-guide'),
#  (295, '/council-housing'),
#  (296, '/skilled-worker-visa/when-you-can-be-paid-less'),
#  (297,
#   '/guidance/plan-for-jobs-skills-and-employment-programmes-information-for-employers'),
#  (298,
#   '/government/publications/united-kingdom-security-vetting-clearance-levels/national-security-vetting-clearance-levels'),
#  (299,
#   '/government/publications/criminal-records-checks-for-overseas-applicants/guidance-on-the-application-process-for-criminal-records-checks-overseas'),
#  (300,
#   '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals'),
#  (301, '/british-passport-eligibility'),
#  (302,
#   '/government/publications/personal-information-use-in-borders-immigration-and-citizenship'),
#  (303, '/search/news-and-communications'),
#  (304, '/attendance-allowance/how-to-claim'),
#  (305, '/apply-home-equipment-for-disabled'),
#  (306, '/find-a-visa-application-centre'),
#  (307, '/voluntary-national-insurance-contributions/deadlines'),
#  (308, '/marriage-visa'),
#  (309, '/childcare-grant'),
#  (310, '/personal-pensions-your-rights/choosing-personal-pension'),
#  (311, '/fixed-term-contracts/employees-rights'),
#  (312,
#   '/government/collections/hm-revenue-and-customs-service-availability-and-issues'),
#  (313, '/employment-tribunals'),
#  (314, '/paternity-pay-leave/eligibility'),
#  (315, '/carers-allowance/further-information'),
#  (316, '/shared-parental-leave-and-pay/eligibility-for-birth-parents'),
#  (317, '/apply-for-elderly-person-bus-pass'),
#  (318, '/get-a-passport-urgently/1-week-fast-track-service'),
#  (319, '/check-university-award-degree'),
#  (320, '/guidance/traineeship-information-for-trainees'),
#  (321, '/employer-relocation-your-rights'),
#  (322,
#   '/your-employment-contract-how-it-can-be-changed/dealing-with-problems'),
#  (323, '/pension-credit'),
#  (324, '/calculate-your-holiday-entitlement'),
#  (325, '/contact-student-finance-england'),
#  (326, '/guidance/apply-for-a-kickstart-scheme-grant'),
#  (327, '/become-lorry-bus-driver'),
#  (328, '/call-charges'),
#  (329, '/uk-visa-sponsorship-employers/sponsorship-management-roles'),
#  (330, '/universal-credit/changes-of-circumstances'),
#  (331, '/working-tax-credit'),
#  (332, '/advanced-learner-loan/what-youll-get'),
#  (333, '/after-a-death/organisations-you-need-to-contact-and-tell-us-once'),
#  (334,
#   '/government/publications/find-a-skills-bootcamp/list-of-skills-bootcamps'),
#  (335, '/check-immigration-status'),
#  (336,
#   '/government/publications/your-new-state-pension-explained/your-state-pension-explained'),
#  (337, '/personal-tax-account/sign-in/create-account'),
#  (338, '/claim-loss-notice'),
#  (339, '/rest-breaks-work/taking-breaks'),
#  (340, '/employ-someone'),
#  (341, '/night-working-hours'),
#  (342, '/jobseekers-allowance/apply-new-style-jsa'),
#  (343, '/guidance/redundancy-help-finding-work-and-claiming-benefits'),
#  (344, '/handing-in-your-notice'),
#  (345, '/browse/education/student-finance'),
#  (346, '/government/organisations/disclosure-and-barring-service/about'),
#  (347,
#   '/what-different-qualification-levels-mean/list-of-qualification-levels'),
#  (348, '/jobseekers-allowance/your-jsa-claim'),
#  (349, '/employment-support-allowance/working-while-you-claim'),
#  (350, '/browse/births-deaths-marriages/register-offices'),
#  (351, '/shared-parental-leave-and-pay'),
#  (352, '/uk-visa-sponsorship-employers/job-suitability'),
#  (353, '/further-education-courses/if-youre-16-or-17'),
#  (354,
#   '/guidance/coronavirus-covid-19-what-to-do-if-youre-employed-and-cannot-work'),
#  (355, '/government/organisations/pension-service'),
#  (356, '/get-a-passport-urgently/online-premium-service'),
#  (357, '/1619-bursary-fund'),
#  (358, '/eu-eea'),
#  (359, '/apply-medal-or-veterans-badge'),
#  (360,
#   '/guidance/claim-for-wage-costs-through-the-coronavirus-job-retention-scheme'),
#  (361, '/test-and-trace-support-payment'),
#  (362, '/constant-attendance-allowance'),
#  (363, '/pension-credit/what-youll-get'),
#  (364,
#   '/guidance/how-your-trading-conditions-affect-your-eligibility-for-the-self-employment-income-support-scheme'),
#  (365, '/log-in-file-self-assessment-tax-return'),
#  (366,
#   '/guidance/claim-for-wages-through-the-coronavirus-job-retention-scheme'),
#  (367, '/contracted-out/old-state-pension'),
#  (368, '/browse/business/finance-support'),
#  (369, '/universal-credit/what-youll-get'),
#  (370, '/apply-start-up-loan'),
#  (371,
#   '/government/publications/employment-and-support-allowance-permitted-work-form/permitted-work-factsheet'),
#  (372, '/government/publications/attendance-allowance-claim-form'),
#  (373, '/state-pension/circumstances-change'),
#  (374, '/fixed-term-contracts/renewing-or-ending-a-fixedterm-contract'),
#  (375, '/maximum-weekly-working-hours/calculating-your-working-hours'),
#  (376,
#   '/tax-national-insurance-after-state-pension-age/stopping-paying-national-insurance'),
#  (377, '/tell-hmrc-change-of-details/income-changes'),
#  (378, '/browse/driving/driving-licences'),
#  (379, '/government/publications/apprenticeship-technical-funding-guide'),
#  (380,
#   '/settled-status-eu-citizens-families/family-member-eligible-person-from-northern-ireland'),
#  (381, '/statutory-sick-pay/what-youll-get'),
#  (382, '/housing-and-universal-credit'),
#  (383, '/redundancy-your-rights/suitable-alternative-employment'),
#  (384, '/browse/citizenship/voting'),
#  (385, '/handing-in-your-notice/gardening-leave'),
#  (386, '/government/publications/traineeship-providers'),
#  (387,
#   '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means'),
#  (388, '/guidance/new-style-jobseekers-allowance'),
#  (389, '/report-unfit-work-children-vulnerable-adults'),
#  (390, '/handing-in-your-notice/payment-during-your-notice-period'),
#  (391, '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member'),
#  (392, '/state-pension-if-you-retire-abroad'),
#  (393, '/student-finance/new-fulltime-students'),
#  (394, '/plan-retirement-income'),
#  (395, '/overseas-domestic-worker-visa'),
#  (396, '/the-warm-home-discount-scheme/low-income'),
#  (397, '/access-to-work/apply'),
#  (398,
#   '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults'),
#  (399, '/find-pension-centre'),
#  (400, '/government/organisations/hm-revenue-customs/services-information'),
#  (401, '/maternity-pay-leave/extra-help'),
#  (402, '/time-off-for-dependants/whats-an-emergency'),
#  (403,
#   '/government/publications/disclosure-application-process-for-volunteers/disclosure-application-process-for-volunteers'),
#  (404, '/new-state-pension/what-youll-get'),
#  (405, '/budgeting-help-benefits/after-you-apply'),
#  (406, '/copy-of-police-records'),
#  (407, '/check-state-pension'),
#  (408, '/voluntary-national-insurance-contributions'),
#  (409, '/parental-leave'),
#  (410, '/national-minimum-wage/employers-and-the-minimum-wage'),
#  (411, '/visa-documents-returned'),
#  (412,
#   '/government/organisations/hm-revenue-customs/contact/change-your-personal-details'),
#  (413, '/get-document-legalised'),
#  (414, '/apply-council-tax-reduction'),
#  (415, '/guidance/barring-referrals'),
#  (416, '/find-postgraduate-teacher-training-courses'),
#  (417, '/pension-credit-calculator'),
#  (418, '/access-to-work/renew'),
#  (419, '/claim-benefits-abroad'),
#  (420, '/new-state-pension/how-to-claim'),
#  (421, '/youth-mobility'),
#  (422, '/funeral-payments'),
#  (423, '/register-employer'),
#  (424, '/holiday-entitlement-rights/workers-furlough-coronavirus'),
#  (425, '/government/organisations/civil-service/about/recruitment'),
#  (426, '/income-support/report-a-change-of-circumstances'),
#  (427, '/browse/employing-people/dismissals-redundancies'),
#  (428, '/government/organisations/hm-revenue-customs'),
#  (429, '/topic/benefits-credits/tax-credits'),
#  (430, '/calculate-statutory-sick-pay'),
#  (431, '/healthcare-immigration-application'),
#  (432,
#   '/guidance/return-to-your-claim-for-the-self-employment-income-support-scheme'),
#  (433,
#   '/tell-employer-or-college-about-criminal-record/fines-and-compensation'),
#  (434, '/government/collections/statutory-pay-forms'),
#  (435, '/employment-status/employee'),
#  (436, '/topic/dealing-with-hmrc/paying-hmrc'),
#  (437, '/child-employment/restrictions-on-child-employment'),
#  (438, '/financial-help-disabled/vehicles-and-transport'),
#  (439, '/moving-from-benefits-to-work/help-for-specific-problems'),
#  (440, '/state-pension/what-youll-get'),
#  (441,
#   '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-standardenhanced-dbs-check-applications-from-1-july-2021'),
#  (442, '/get-coronavirus-test'),
#  (443, '/carers-allowance-unit'),
#  (444, '/industrial-injuries-disablement-benefit/eligibility'),
#  (445, '/30-hours-free-childcare'),
#  (446, '/tax-codes/tell-hmrc-about-a-change-tax-code'),
#  (447, '/jobcentre-plus-help-for-recruiters/recruitment-advice-and-support'),
#  (448, '/government/collections/apprenticeship-vacancies'),
#  (449,
#   '/tell-employer-or-college-about-criminal-record/what-information-you-need-to-give'),
#  (450,
#   '/government/publications/employment-and-support-allowance-permitted-work-form'),
#  (451, '/id-scan-eu-settlement-scheme'),
#  (452, '/guidance/visa-decision-waiting-times-applications-inside-the-uk'),
#  (453, '/standard-visitor-visa'),
#  (454, '/guidance/register-of-apprenticeship-training-providers'),
#  (455, '/payslips'),
#  (456,
#   '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant'),
#  (457, '/moving-or-retiring-abroad'),
#  (458, '/learn-to-drive-a-car'),
#  (459, '/personal-pensions-your-rights'),
#  (460, '/browse/driving/vehicle-tax-mot-insurance'),
#  (461, '/income-tax'),
#  (462, '/employers-sick-pay/entitlement'),
#  (463, '/agency-workers-your-rights/basic-information-you-should-receive'),
#  (464, '/sign-in-help-to-save'),
#  (465, '/employing-an-apprentice/get-funding'),
#  (466, '/browse/visas-immigration/eu-eea-swiss'),
#  (467, '/government/publications/child-benefit-claim-form-ch2'),
#  (468, '/guidance/pensions-and-compensation-for-veterans'),
#  (469, '/residence-documents-foreign-nationals-uk'),
#  (470, '/sure-start-maternity-grant/how-to-claim'),
#  (471, '/education-maintenance-allowance-ema'),
#  (472, '/advanced-learner-loan/how-to-apply'),
#  (473, '/working-tax-credit/what-youll-get'),
#  (474, '/government/collections/citizenship-application-forms'),
#  (475, '/set-up-sole-trader'),
#  (476, '/guidance/national-minimum-wage-work-experience-and-internships'),
#  (477, '/jobseekers-allowance/apply-new-style-jsa/eligibility'),
#  (478, '/british-national-overseas-bno-visa'),
#  (479, '/child-trust-funds/managing-the-account'),
#  (480,
#   '/government/publications/apprenticeship-levy-how-it-will-work/apprenticeship-levy-how-it-will-work'),
#  (481, '/get-proof-employment-history'),
#  (482, '/guidance/brexit-guidance-for-individuals-and-families'),
#  (483, '/tax-on-pension/how-your-tax-is-paid'),
#  (484, '/driving-medical-conditions'),
#  (485, '/tips-at-work'),
#  (486, '/plan-for-retirement'),
#  (487, '/skilled-worker-visa/switch-to-this-visa'),
#  (488, '/government/publications/register-of-licensed-sponsors-students'),
#  (489, '/order-coronavirus-rapid-lateral-flow-tests'),
#  (490, '/government/publications/dbs-continuation-sheet'),
#  (491, '/view-driving-licence'),
#  (492, '/sponsor-management-system'),
#  (493, '/vehicles-can-drive'),
#  (494,
#   '/disciplinary-procedures-and-action-at-work/how-disciplinary-procedures-work'),
#  (495, '/right-of-abode/commonwealth-citizens'),
#  (496, '/find-an-immigration-adviser'),
#  (497, '/career-breaks'),
#  (498, '/handing-in-your-notice/giving-notice'),
#  (499, '/careers-helpline-for-teenagers'),
#  (500, '/income-support/if-you-already-get-income-support'),
#  (501, '/topic/immigration-operational-guidance/immigration-rules'),
#  (502, '/tell-hmrc-change-address'),
#  (503, '/plan-retirement-income/private-pensions'),
#  (504,
#   '/government/publications/criminal-records-checks-for-overseas-applicants/countries-a-to-f-applying-for-a-criminal-records-check-for-someone-from-overseas'),
#  (505, '/universal-credit/contact-universal-credit'),
#  (506, '/sure-start-maternity-grant/what-youll-get'),
#  (507,
#   '/government/publications/universal-credit-work-allowances/universal-credit-work-allowances'),
#  (508, '/guidance/track-a-dbs-application'),
#  (509, '/learner-support'),
#  (510, '/student-finance-register-login'),
#  (511, '/welfare/jobseekers-allowance'),
#  (512, '/uk-visa-sponsorship-employers/eligibility'),
#  (513, '/visa-to-study-english'),
#  (514, '/get-help-savings-low-income'),
#  (515, '/vehicle-tax'),
#  (516, '/statutory-sick-pay/eligibility'),
#  (517, '/bereavement-support-payment/how-to-claim'),
#  (518, '/government/collections/statutory-sick-pay-and-leave'),
#  (519, '/search/policy-papers-and-consultations'),
#  (520, '/report-cash-in-hand-pay'),
#  (521, '/government/publications/application-for-a-state-pension-statement'),
#  (522, '/browse/tax/income-tax'),
#  (523, '/guidance/using-the-uk-immigration-id-check-app'),
#  (524, '/holiday-entitlement-rights/holiday-pay-the-basics'),
#  (525, '/government/publications/apprenticeships-off-the-job-training'),
#  (526, '/topic/further-education-skills/administration'),
#  (527,
#   '/government/publications/basic-check-guidance-and-policies/basic-check-id-checking-guidelines-from-1-july-2021'),
#  (528, '/claim-tax-credits'),
#  (529, '/student-visa/family-members'),
#  (530, '/workplace-temperatures'),
#  (531, '/employment-support-allowance'),
#  (532, '/settled-status-eu-citizens-families/applying-for-settled-status'),
#  (533, '/transferring-your-pension'),
#  (534, '/housing-benefit/what-youll-get'),
#  (535, '/state-pension-age'),
#  (536, '/government/publications/dbs-identity-checking-guidelines'),
#  (537, '/check-vehicle-tax'),
#  (538, '/support-visit-benefit-claim'),
#  (539, '/uk-border-control/before-you-leave-for-the-uk'),
#  (540, '/government/organisations/the-pensions-advisory-service'),
#  (541, '/plan-shared-parental-leave-pay'),
#  (542, '/repaying-your-student-loan'),
#  (543, '/check-income-tax-current-year/sign-in/create-account'),
#  (544, '/early-retirement-pension/benefits'),
#  (545, '/government/organisations/companies-house'),
#  (546, '/paye-forms-p45-p60-p11d/lost-paye-forms'),
#  (547, '/universal-credit/how-to-claim'),
#  (548,
#   '/government/publications/employing-disabled-people-and-people-with-health-conditions/employing-disabled-people-and-people-with-health-conditions'),
#  (549,
#   '/government/collections/illegal-working-penalties-codes-of-practice-for-employers'),
#  (550, '/update-uk-visas-immigration-account-details'),
#  (551, '/apply-housing-benefit-from-council'),
#  (552, '/guidance/how-to-quarantine-when-you-arrive-in-england'),
#  (553, '/government/publications/access-to-work-guide-for-employers'),
#  (554, '/skilled-worker-visa/if-you-work-in-healthcare-or-education'),
#  (555, '/contracted-out'),
#  (556, '/topic/further-education-skills/vocational-qualifications'),
#  (557, '/am-i-getting-minimum-wage'),
#  (558, '/government/publications/dbs-workforce-guidance'),
#  (559, '/tell-employer-or-college-about-criminal-record/cautions'),
#  (560, '/guidance/national-skills-fund'),
#  (561, '/dismissal/what-to-do-if-youre-dismissed'),
#  (562, '/report-benefit-fraud'),
#  (563, '/skilled-worker-visa/your-partner-and-children'),
#  (564, '/browse/driving/number-plate'),
#  (565, '/moving-from-benefits-to-work/job-search-programmes'),
#  (566, '/raise-grievance-at-work'),
#  (567, '/find-lost-utr-number'),
#  (568,
#   '/government/publications/introducing-govuk-verify/introducing-govuk-verify'),
#  (569,
#   '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education'),
#  (570,
#   '/government/publications/national-insurance-employment-history-request'),
#  (571, '/financial-help-disabled/television-licence-discount'),
#  (572, '/national-insurance-rates-letters'),
#  (573, '/skilled-worker-visa/your-job'),
#  (574, '/contact-hmrc'),
#  (575, '/dismiss-staff'),
#  (576, '/agency-workers-your-rights'),
#  (577, '/guidance/new-style-employment-and-support-allowance'),
#  (578, '/government/collections/helping-young-people-into-work'),
#  (579, '/biometric-residence-permits'),
#  (580,
#   '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed'),
#  (581, '/government/publications/maternity-allowance-claim-form'),
#  (582, '/apply-first-provisional-driving-licence'),
#  (583, '/carers-credit'),
#  (584, '/how-tax-credits-affect-other-benefits'),
#  (585, '/armed-forces-pension-calculator'),
#  (586, '/redundancy-your-rights/get-help-finding-a-new-job'),
#  (587, '/driving-nongb-licence'),
#  (588, '/sign-in-childcare-account'),
#  (589, '/if-you-become-disabled/if-youre-in-employment-and-become-disabled'),
#  (590, '/child-benefit/how-to-claim'),
#  (591, '/your-employment-contract-how-it-can-be-changed'),
#  (592, '/find-out-dbs-check'),
#  (593, '/housing-benefit/how-to-claim'),
#  (594, '/coronavirus/business-support'),
#  (595, '/self-employed-records'),
#  (596, '/log-in-register-hmrc-online-services/register'),
#  (597, '/child-benefit-payment-dates'),
#  (598, '/winter-fuel-payment/eligibility'),
#  (599, '/employers-sick-pay/eligibility-and-form-ssp1'),
#  (600, '/uk-border-control'),
#  (601, '/how-to-claim-new-style-esa'),
#  (602, '/guidance/basic-dbs-checks-guidance'),
#  (603, '/new-employee/employee-information'),
#  (604, '/support-for-mortgage-interest/eligibility'),
#  (605, '/pip/how-to-claim'),
#  (606, '/guidance/working-safely-during-covid-19'),
#  (607, '/national-concessionary-fuel-scheme'),
#  (608, '/personal-tax-account'),
#  (609, '/grant-bursary-adult-learners'),
#  (610, '/renewing-your-tax-credits-claim'),
#  (611, '/additional-state-pension'),
#  (612,
#   '/voluntary-national-insurance-contributions/who-can-pay-voluntary-contributions'),
#  (613, '/government/topical-events/plan-for-jobs'),
#  (614, '/browse/visas-immigration/what-you-need-to-do'),
#  (615, '/reasonable-adjustments-for-disabled-workers'),
#  (616, '/government/collections/dbs-checking-service-guidance--2'),
#  (617, '/uk-benefits-abroad'),
#  (618, '/financial-help-disabled/on-a-low-salary'),
#  (619, '/death-spouse-benefits-tax-pension/benefits'),
#  (620, '/guidance/eu-settlement-scheme-evidence-of-uk-residence'),
#  (621,
#   '/government/publications/easy-read-get-help-at-work-if-youre-disabled-or-have-a-health-condition-access-to-work'),
#  (622, '/help/terms-conditions'),
#  (623, '/check-national-insurance-record'),
#  (624, '/financial-help-disabled'),
#  (625, '/guidance/rehabilitation-periods'),
#  (626, '/tax-free-childcare'),
#  (627, '/government/publications/the-basic-state-pension'),
#  (628, '/settle-in-the-uk'),
#  (629, '/set-up-business'),
#  (630, '/renew-driving-licence-at-70'),
#  (631, '/moving-from-benefits-to-work/help-for-parents-and-carers'),
#  (632, '/tax-relief-for-employees'),
#  (633, '/browse/disabilities/rights'),
#  (634, '/advanced-learner-loan/bursary-fund'),
#  (635, '/government/publications/dbs-update-service-employer-guide'),
#  (636, '/national-insurance-credits/eligibility'),
#  (637, '/visa-fees'),
#  (638, '/browse/visas-immigration/asylum'),
#  (639, '/voluntary-national-insurance-contributions/rates'),
#  (640, '/browse/tax/self-assessment'),
#  (641, '/working-retirement-pension-age'),
#  (642, '/check-tenant-right-to-rent-documents'),
#  (643, '/english-language'),
#  (644,
#   '/update-uk-visas-immigration-account-details/update-your-ukvi-account'),
#  (645, '/minimum-wage-different-types-work/paid-an-annual-salary'),
#  (646, '/change-circumstances-visa-brp'),
#  (647, '/employing-an-apprentice/pay-and-conditions-for-apprentices'),
#  (648, '/income-support/income-support-rates'),
#  (649, '/tax-come-to-uk'),
#  (650,
#   '/government/publications/dbs-update-service-employer-guide/dbs-update-service-employer-guide'),
#  (651, '/whistleblowing'),
#  (652, '/government/publications/paye-starter-checklist'),
#  (653,
#   '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403'),
#  (654, '/workplace-pensions'),
#  (655, '/paternity-pay-leave'),
#  (656, '/employment-contracts-and-conditions'),
#  (657, '/disabled-facilities-grants'),
#  (658, '/further-education-skills/apprenticeships'),
#  (659, '/faster-decision-visa-settlement'),
#  (660, '/find-pension-contact-details'),
#  (661, '/health-conditions-disability-universal-credit'),
#  (662, '/keeping-your-pay-tax-records'),
#  (663, '/when-someone-dies'),
#  (664, '/tax-credits-overpayments'),
#  (665, '/check-tenant-right-to-rent-documents/how-to-check'),
#  (666, '/browse/education/school-life'),
#  (667, '/working-abroad'),
#  (668, '/view-prove-immigration-status'),
#  (669, '/overtime-your-rights'),
#  (670, '/government/publications/qualifications-in-new-funded-offers'),
#  (671, '/agency-workers-your-rights/your-rights-as-a-temporary-agency-worker'),
#  (672, '/redundancy-your-rights'),
#  (673, '/government/organisations/home-office/about/recruitment'),
#  (674, '/childcare-calculator'),
#  (675, '/maternity-pay-leave/pay'),
#  (676, '/housing-and-universal-credit/property-you-own'),
#  (677, '/child-employment/local-council-rules-for-child-employment-permits'),
#  (678, '/housing-and-universal-credit/renting-from-private-landlord'),
#  (679,
#   '/contract-types-and-employer-responsibilities/fulltime-and-parttime-contracts'),
#  (680,
#   '/government/publications/dbs-list-of-offences-that-will-never-be-filtered-from-a-criminal-record-check'),
#  (681,
#   '/guidance/coronavirus-covid-19-what-to-do-if-youre-self-employed-and-getting-less-work-or-no-work'),
#  (682, '/severe-disablement-allowance'),
#  (683, '/government/publications/dbs-filtering-guidance/dbs-filtering-guide'),
#  (684, '/ancestry-visa'),
#  (685, '/minimum-wage-different-types-work/paid-by-the-hour'),
#  (686, '/seasonal-worker-visa/eligibility'),
#  (687, '/government/publications/sector-based-work-academies-employer-guide'),
#  (688, '/become-appointee-for-someone-claiming-benefits'),
#  (689, '/dla-disability-living-allowance-benefit/dla-rates'),
#  (690, '/government/publications/dbs-application-forms-guide-for-applicants'),
#  (691, '/maternity-pay-leave'),
#  (692, '/claim-tax-refund'),
#  (693, '/budgeting-help-benefits/what-youll-get'),
#  (694, '/change-address-driving-licence'),
#  (695, '/book-theory-test'),
#  (696, '/check-mot-history'),
#  (697,
#   '/guidance/coronavirus-covid-19-testing-for-people-travelling-to-england'),
#  (698,
#   '/government/publications/personal-information-use-in-borders-immigration-and-citizenship/borders-immigration-and-citizenship-privacy-information-notice'),
#  (699, '/benefit-cap/how-earnings-affect-when-benefit-cap-starts'),
#  (700, '/paye-forms-p45-p60-p11d/p11d'),
#  (701, '/when-mental-health-condition-becomes-disability'),
#  (702, '/employer-preventing-discrimination'),
#  (703, '/standard-visitor-visa/documents-you-will-need'),
#  (704, '/check-income-tax-current-year/sign-in/prove-identity'),
#  (705,
#   '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide'),
#  (706, '/disability-living-allowance-children'),
#  (707, '/government/publications/the-official-hmrc-app'),
#  (708, '/working-for-yourself'),
#  (709, '/national-minimum-wage'),
#  (710, '/benefit-cap'),
#  (711, '/employee-rights-when-on-leave'),
#  (712, '/change-name-deed-poll'),
#  (713, '/assisted-digital-help-online-applications'),
#  (714,
#   '/government/publications/eu-settlement-scheme-application-processing-times/eu-settlement-scheme-pilot-current-expected-processing-times-for-applications'),
#  (715, '/entering-staying-uk'),
#  (716, '/education'),
#  (717, '/rest-breaks-work/compensatory-rest'),
#  (718, '/browse/visas-immigration/commonwealth-british-nationals-overseas'),
#  (719, '/working-tax-credit/how-to-claim'),
#  (720, '/get-copy-military-service-records/apply-for-your-own-records'),
#  (721, '/maternity-allowance'),
#  (722, '/topic/benefits-credits/child-benefit'),
#  (723, '/self-employed-national-insurance-rates'),
#  (724,
#   '/government/organisations/department-for-education/services-information'),
#  (725, '/national-insurance-credits'),
#  (726, '/volunteering/pay-and-expenses'),
#  (727, '/government/organisations/hm-revenue-customs/contact/self-assessment'),
#  (728, '/1619-bursary-fund/how-to-claim'),
#  (729, '/income-tax/how-you-pay-income-tax'),
#  (730, '/guidance/recruiting-people-from-outside-the-uk'),
#  (731, '/book-driving-test'),
#  (732, '/tax-on-your-private-pension'),
#  (733, '/tell-hmrc-change-of-details'),
#  (734, '/self-assessment-forms-and-helpsheets'),
#  (735, '/national-minimum-wage-rates'),
#  (736,
#   '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions'),
#  (737, '/guidance/nhs-covid-pass'),
#  (738,
#   '/what-different-qualification-levels-mean/compare-different-qualification-levels'),
#  (739, '/order-copy-birth-death-marriage-certificate'),
#  (740, '/higher-education-courses-find-and-apply'),
#  (741,
#   '/guidance/check-if-you-could-be-covered-by-the-coronavirus-job-retention-scheme'),
#  (742, '/child-benefit/what-youll-get'),
#  (743, '/income-tax/taxfree-and-taxable-state-benefits'),
#  (744, '/criminal-record-check-become-driving-instructor'),
#  (745, '/claim-redundancy'),
#  (746, '/business-support-helpline'),
#  (747, '/personal-pensions-your-rights/how-you-can-take-pension'),
#  (748, '/register-birth'),
#  (749,
#   '/government/publications/acceptable-right-to-work-documents-an-employers-guide'),
#  (750, '/overtime-your-rights/parttime-workers'),
#  (751,
#   '/education/further-and-higher-education-skills-and-vocational-training'),
#  (752, '/browse/visas-immigration/tourist-short-stay-visas'),
#  (753, '/browse/education/universities-higher-education'),
#  (754, '/government/organisations/department-of-health-and-social-care'),
#  (755, '/agricultural-sick-pay'),
#  (756, '/business-finance-support'),
#  (757, '/maximum-weekly-working-hours'),
#  (758, '/government/organisations/foreign-commonwealth-office'),
#  (759, '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships'),
#  (760,
#   '/guidance/criminal-record-checks-for-childminders-and-childcare-workers'),
#  (761, '/agency-workers-your-rights/pay'),
#  (762, '/work/pensions-and-ageing-society'),
#  (763, '/benefit-cap/when-youre-not-affected'),
#  (764, '/topic/personal-tax/self-assessment'),
#  (765,
#   '/government/publications/skilled-worker-visa-eligible-healthcare-and-education-jobs'),
#  (766,
#   '/government/publications/rates-and-allowances-national-insurance-contributions/rates-and-allowances-national-insurance-contributions'),
#  (767, '/caution-warning-penalty'),
#  (768, '/business-coronavirus-support-finder'),
#  (769, '/workplace-pensions/managing-your-pension'),
#  (770, '/tax-codes/emergency-tax-codes'),
#  (771, '/how-to-have-your-benefits-paid'),
#  (772, '/staff-redundant'),
#  (773, '/additional-state-pension/inheriting'),
#  (774, '/check-driving-information'),
#  (775, '/browse/citizenship/charities-honours'),
#  (776, '/income-tax/find-out-if-you-need-to-pay-income-tax'),
#  (777, '/settled-status-eu-citizens-families/after-youve-applied'),
#  (778, '/get-state-pension'),
#  (779, '/mandatory-reconsideration'),
#  (780, '/browse/benefits/bereavement'),
#  (781, '/check-income-tax-last-year'),
#  (782, '/reduced-national-insurance-married-women'),
#  (783, '/browse/childcare-parenting/pregnancy-birth'),
#  (784, '/guidance/incentive-payments-for-hiring-a-new-apprentice'),
#  (785, '/chwilio-am-swydd'),
#  (786, '/browse/childcare-parenting/childcare'),
#  (787, '/settled-status-eu-citizens-families'),
#  (788, '/browse/visas-immigration/immigration-appeals'),
#  (789,
#   '/new-state-pension/youve-been-in-a-workplace-personal-or-stakeholder-pension'),
#  (790, '/support-for-mortgage-interest'),
#  (791, '/redundancy-your-rights/redundancy-pay'),
#  (792, '/pip/claiming-pip-if-youre-terminally-ill'),
#  (793,
#   '/employment-contracts-and-conditions/written-statement-of-employment-particulars'),
#  (794, '/carers-allowance/how-to-claim'),
#  (795, '/government/publications/the-national-minimum-wage-in-2021'),
#  (796, '/your-rights-if-your-employer-is-insolvent'),
#  (797, '/student-jobs-paying-tax'),
#  (798,
#   '/government/organisations/hm-revenue-customs/contact/national-insurance-numbers'),
#  (799, '/skilled-worker-visa/apply-from-outside-the-uk'),
#  (800, '/pip/what-youll-get'),
#  (801, '/recruit-apprentice'),
#  (802,
#   '/guidance/settled-status-for-eu-citizens-and-their-families-translations'),
#  (803,
#   '/report-problem-criminal-record-certificate/appeal-against-a-new-barring-decision'),
#  (804,
#   '/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance'),
#  (805,
#   '/government/publications/income-tax-leaving-the-uk-getting-your-tax-right-p85'),
#  (806, '/transferring-your-pension/transferring-to-a-uk-pension-scheme'),
#  (807, '/moving-from-benefits-to-work/starting-your-own-business'),
#  (808, '/national-insurance/your-national-insurance-number'),
#  (809, '/state-pension-through-partner'),
#  (810, '/rest-breaks-work'),
#  (811, '/disability-premiums/eligibility'),
#  (812, '/uk-family-visa/partner-spouse'),
#  (813, '/identitycards'),
#  (814, '/guidance/responsible-organisations'),
#  (815, '/right-of-abode'),
#  (816,
#   '/workplace-pensions/if-you-want-to-leave-your-workplace-pension-scheme'),
#  (817, '/apply-standard-visitor-visa'),
#  (818, '/paternity-pay-leave/pay'),
#  (819,
#   '/dbs-check-applicant-criminal-record/get-a-basic-dbs-check-for-an-employee'),
#  (820, '/plan-retirement-income/get-financial-advice'),
#  (821, '/income-tax-rates'),
#  (822, '/private-renting'),
#  (823,
#   '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service'),
#  (824, '/independent-livingfund'),
#  (825, '/browse/disabilities/work'),
#  (826, '/national-insurance/how-much-you-pay'),
#  (827, '/search/research-and-statistics'),
#  (828, '/running-payroll'),
#  (829,
#   '/maximum-weekly-working-hours/weekly-maximum-working-hours-and-opting-out'),
#  (830, '/biometric-residence-permits/collect'),
#  (831,
#   '/guidance/prove-your-english-language-abilities-with-a-secure-english-language-test-selt'),
#  (832, '/future-pension-centre'),
#  (833, '/become-magistrate'),
#  (834, '/child-tax-credit/new-claim'),
#  (835, '/redundancy-your-rights/consultation'),
#  (836, '/tax-on-pension-death-benefits'),
#  (837, '/pay-self-assessment-tax-bill'),
#  (838, '/welfare/entitlement'),
#  (839, '/paternity-pay-leave/how-to-claim'),
#  (840, '/parents-learning-allowance'),
#  (841, '/solve-workplace-dispute'),
#  (842, '/government/publications/skilled-worker-visa-eligible-occupations'),
#  (843, '/government/publications/sure-start-maternity-grant-claim-form'),
#  (844, '/self-employed-records/what-records-to-keep'),
#  (845,
#   '/government/publications/view-and-prove-your-immigration-status-evisa'),
#  (846, '/guidance/pay-apprenticeship-levy'),
#  (847, '/eusettledstatus'),
#  (848, '/rights-disabled-person'),
#  (849, '/standard-visitor-visa/what-you-can-do-in-the-uk'),
#  (850, '/council-tax-bands'),
#  (851, '/apply-to-come-to-the-uk/prepare-your-application'),
#  (852, '/appeal-benefit-decision'),
#  (853, '/government/publications/apprenticeship-agreement-template'),
#  (854, '/carers-credit/eligibility'),
#  (855, '/renew-adult-passport/renew'),
#  (856, '/limited-company-formation'),
#  (857, '/employment-support-allowance/change-of-circumstances'),
#  (858, '/reduced-earnings-allowance'),
#  (859, '/pay-and-work-rights'),
#  (860, '/maternity-allowance/how-to-claim'),
#  (861,
#   '/guidance/get-help-with-benefits-and-pensions-if-you-have-accessibility-needs'),
#  (862, '/state-pension/inheritance'),
#  (863, '/holiday-entitlement-rights/calculate-leave-entitlement'),
#  (864,
#   '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries'),
#  (865, '/workplace-bullying-and-harassment'),
#  (866, '/disability-benefits-helpline'),
#  (867, '/government/publications/find-a-skills-bootcamp'),
#  (868, '/time-off-for-dependants/taking-time-off'),
#  (869, '/uk-visa-sponsorship-employers/types-of-licence'),
#  (870, '/guidance/apprenticeship-funding-rules'),
#  (871,
#   '/guidance/benefits-and-pensions-for-uk-nationals-in-the-eea-or-switzerland'),
#  (872, '/housing-benefit/report-a-change-of-circumstances'),
#  (873,
#   '/government/publications/view-and-prove-your-immigration-status-evisa/your-immigration-status-an-introduction-for-eu-eea-and-swiss-citizens-accessible-version'),
#  (874, '/tax-national-insurance-after-state-pension-age'),
#  (875, '/skilled-worker-visa/second-job'),
#  (876, '/temporary-worker-charity-worker-visa'),
#  (877, '/settled-status-eu-citizens-families/eligibility'),
#  (878, '/claim-national-insurance-refund'),
#  (879, '/government/publications/right-to-work-checklist'),
#  (880, '/pensions-advisory-service'),
#  (881, '/benefit-overpayments/how-to-make-a-repayment'),
#  (882, '/your-employment-contract-how-it-can-be-changed/making-changes'),
#  (883, '/government/publications/dbs-filtering-guidance'),
#  (884, '/apply-for-council-housing'),
#  (885, '/entering-staying-uk/foreign-nationals-working-in-uk'),
#  (886, '/uk-family-visa'),
#  (887, '/disability-premiums'),
#  (888,
#   '/government/organisations/hm-revenue-customs/contact/get-help-with-the-self-employment-income-support-scheme'),
#  (889,
#   '/government/publications/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19'),
#  (890, '/apply-online-for-student-finance'),
#  (891, '/holiday-entitlement-rights/taking-holiday-before-leaving-a-job'),
#  (892, '/child-benefit-tax-calculator'),
#  (893, '/new-state-pension/how-its-calculated'),
#  (894, '/get-ready-to-employ-someone'),
#  (895, '/holiday-entitlement-rights/booking-time-off-'),
#  (896, '/sure-start-maternity-grant/eligibility'),
#  (897, '/report-benefits-change-circumstances'),
#  (898, '/pip/change-of-circumstances'),
#  (899, '/time-off-for-dependants/problems-when-you-take-time-off'),
#  (900, '/claim-tax-credits/what-counts-as-income'),
#  (901, '/government/organisations/department-of-social-security'),
#  (902,
#   '/guidance/immigration-rules/immigration-rules-part-5-working-in-the-uk'),
#  (903, '/when-is-your-next-tax-credits-payment'),
#  (904, '/get-paye-forms-p45-p60'),
#  (905, '/topic/higher-education/scholarships-for-overseas-students'),
#  (906, '/guidance/manage-apprenticeship-funds'),
#  (907, '/au-pairs-employment-law'),
#  (908, '/browse/citizenship/citizenship'),
#  (909,
#   '/guidance/help-employers-apply-for-a-kickstart-scheme-grant-kickstart-gateway'),
#  (910, '/penalty-points-endorsements/how-to-check-your-endorsement-details'),
#  (911, '/biometric-residence-permits/report-problem'),
#  (912, '/guidance/using-the-eu-exit-id-document-check-app'),
#  (913, '/government/publications/dbs-check-eligible-positions-guidance'),
#  (914,
#   '/government/publications/criminal-records-checks-for-overseas-applicants/countries-q-z'),
#  (915, '/bereavement-support-payment'),
#  (916,
#   '/tell-employer-or-college-about-criminal-record/check-your-conviction-caution'),
#  (917, '/further-education-courses/find-a-course'),
#  (918, '/national-insurance-if-you-go-abroad'),
#  (919, '/personal-tax-account/sign-in/prove-identity'),
#  (920, '/find-coronavirus-support'),
#  (921, '/disciplinary-procedures-and-action-at-work'),
#  (922, '/universal-credit/other-financial-support'),
#  (923, '/help/accessibility-statement'),
#  (924, '/tell-employer-or-college-about-criminal-record/discharges'),
#  (925, '/get-tax-free-childcare'),
#  (926, '/rest-breaks-work/exceptions'),
#  (927, '/dismissal/reasons-you-can-be-dismissed'),
#  (928, '/employing-an-apprentice'),
#  (929,
#   '/government/publications/jobseekers-allowance-sanctions-leaflet/jobseekers-allowance-sanctions-how-to-keep-your-benefit-payment'),
#  (930, '/government/organisations/foreign-commonwealth-development-office'),
#  (931,
#   '/government/publications/eu-settlement-scheme-application-processing-times'),
#  (932, '/definition-of-disability-under-equality-act-2010'),
#  (933, '/early-retirement-pension/personal-and-workplace-pensions'),
#  (934, '/winter-fuel-payment/how-much-youll-get'),
#  (935, '/international-agreement-worker-visa'),
#  (936, '/discrimination-your-rights/discrimination-at-work'),
#  (937, '/budgeting-help-benefits/how-to-apply'),
#  (938, '/employer-preventing-discrimination/recruitment'),
#  (939, '/track-your-driving-licence-application'),
#  (940, '/government-authorised-exchange'),
#  (941, '/government/organisations/uk-visas-and-immigration'),
#  (942, '/check-state-pension/sign-in/create-account'),
#  (943, '/carers-allowance/eligibility'),
#  (944, '/topic/personal-tax/income-tax'),
#  (945, '/paye-forms-p45-p60-p11d'),
#  (946, '/lost-national-insurance-number'),
#  (947, '/employment-support-allowance/your-esa-claim'),
#  (948, '/further-education-courses/financial-help'),
#  (949, '/terminal-illness-benefits'),
#  (950, '/maternity-pay-leave/how-to-claim'),
#  (951, '/frontier-worker-permit'),
#  (952, '/guidance/visa-decision-waiting-times-applications-outside-the-uk'),
#  (953, '/windrush-prove-your-right-to-be-in-the-uk'),
#  (954, '/overtime-your-rights/time-off-and-paid-leave'),
#  (955, '/employers-sick-pay'),
#  (956, '/child-benefit/eligibility'),
#  (957, '/maternity-allowance/what-youll-get'),
#  (958,
#   '/government/organisations/department-for-work-pensions/about/complaints-procedure'),
#  (959, '/topic/immigration-operational-guidance'),
#  (960, '/calculate-your-redundancy-pay'),
#  (961, '/adoption-pay-leave'),
#  (962, '/uk-visa-sponsorship-employers/certificates-of-sponsorship'),
#  (963, '/industrial-injuries-disablement-benefit'),
#  (964, '/guidance/eu-settlement-scheme-how-we-use-your-personal-information'),
#  (965,
#   '/guidance/covid-19-how-dbs-is-supporting-the-fight-against-coronavirus'),
#  (966, '/career-development-loans'),
#  (967, '/report-problem-criminal-record-certificate/dispute-a-mistake'),
#  (968, '/workplace-pensions-employers'),
#  (969, '/pension-credit/how-to-claim'),
#  (970, '/minimum-wage-different-types-work'),
#  (971, '/deferring-state-pension/what-you-get'),
#  (972, '/employment-support-allowance/eligibility'),
#  (973, '/graduate-visa/apply'),
#  (974, '/death-spouse-benefits-tax-pension'),
#  (975, '/lay-offs-short-timeworking'),
#  (976, '/government/collections/dbs-eligibility-guidance'),
#  (977, '/workplace-pensions/joining-a-workplace-pension'),
#  (978, '/income-support'),
#  (979, '/how-to-claim-new-style-jsa'),
#  (980, '/browse/benefits/help-for-carers'),
#  (981, '/tell-dvla-changed-address'),
#  (982, '/standard-visitor-visa/eligibility'),
#  (983, '/government/collections/apprenticeship-changes'),
#  (984, '/pension-credit/eligibility'),
#  (985, '/family-permit'),
#  (986, '/keeping-your-pay-tax-records/how-long-to-keep-your-records'),
#  (987, '/understanding-your-pay'),
#  (988,
#   '/guidance/coronavirus-covid-19-test-to-release-for-international-travel'),
#  (989, '/housing-benefit'),
#  (990, '/guidance/traineeship-information-for-employers'),
#  (991, '/skilled-worker-visa/how-much-it-costs'),
#  (992, '/government/collections/dbs-update-service-promotional-material'),
#  (993, '/contact-pension-service'),
#  (994, '/attendance-allowance/eligibility'),
#  (995, '/guidance/travel-abroad-from-england-during-coronavirus-covid-19'),
#  (996, '/topic/business-tax/paye'),
#  (997, '/attendance-allowance'),
#  (998, '/government/organisations/driver-and-vehicle-licensing-agency'),
#  (999, '/guidance/coronavirus-covid-19-right-to-work-checks'),
#  ...]

# %%
len(shortest_seed0_1_list + shortest_seed0_2_list + g_degree_list)
# Out:
# 4010

# %%
pd.DataFrame.from_records(
        shortest_seed0_1_list + shortest_seed0_2_list + g_degree_list
    )
# Out:
#          0                                                  1
# 0        0                        /browse/working/finding-job
# 1        1                                /dbs-update-service
# 2        2  /government/collections/sponsorship-informatio...
# 3        3                                /view-right-to-work
# 4        4             /access-to-work/after-you-have-applied
# ...    ...                                                ...
# 4005  1333                                     /dismiss-staff
# 4006  1334                                 /capital-gains-tax
# 4007  1335   /government/publications/lrs-organisation-portal
# 4008  1336      /government/publications/lrs-help-and-support
# 4009  1337  /government/publications/application-for-mot-a...
#
# [4010 rows x 2 columns]

# %%
# take average of rank for each page path (non-weighted)
ranked_items = (
    pd.DataFrame.from_records(
        shortest_seed0_1_list + shortest_seed0_2_list + g_degree_list # this combines 3 lists into one long list
    )
    .groupby(1) # group by column named "1": i.e. by page path
    .mean()
    .round()
    .reset_index()
)
ranked_items = ranked_items.rename(columns={1: "page", 0: "rank"})
ranked_items = ranked_items.sort_values(by=["rank"])

# %%
ranked_items
# Out:
#                                                    page    rank
# 435                                         /find-a-job    12.0
# 190                         /browse/working/finding-job    15.0
# 1096                          /sign-in-universal-credit    23.0
# 1221    /topic/further-education-skills/apprenticeships    30.0
# 1262                                  /universal-credit    31.0
# ...                                                 ...     ...
# 382                                 /employee-tax-codes  1312.0
# 764   /guidance/veterans-uk-armed-forces-pensions-forms  1312.0
# 351   /disciplinary-procedures-and-action-at-work/di...  1329.0
# 624    /government/publications/lrs-organisation-portal  1335.0
# 623       /government/publications/lrs-help-and-support  1336.0
#
# [1338 rows x 2 columns]

# %%
# download as csv file
# ranked_items.to_csv("../../data/processed/ranked_items.csv", index=False)

# %% [markdown]
# ## Create final output

# %% [markdown]
# ### Add document type and session hit data to final csv file
#
# Document supertypes as per: https://docs.publishing.service.gov.uk/document-types/content_purpose_supergroup.html

# %%
# extract: documentType, sessionHitsAll, entranceHit, exitHit, entranceAndExitHit
df_page = pd.DataFrame([i[0] for i in economic_recovery_subgraph], columns=["page"])
df_info = pd.DataFrame([i[1] for i in economic_recovery_subgraph])
df_all = df_page.join(df_info)

# define a set for news and communication doc types
news_and_comms_doctypes = {
    "medical_safety_alert",
    "drug_safety_update",
    "news_article",
    "news_story",
    "press_release",
    "world_location_news_article",
    "world_news_story",
    "fatality_notice",
    "fatality_notice",
    "tax_tribunal_decision",
    "utaac_decision",
    "asylum_support_decision",
    "employment_appeal_tribunal_decision",
    "employment_tribunal_decision",
    "employment_tribunal_decision",
    "service_standard_report",
    "cma_case",
    "decision",
    "oral_statement",
    "written_statement",
    "authored_article",
    "correspondence",
    "speech",
    "government_response",
    "case_study",
}

# define a set for service doc types
service_doctypes = {
    "completed_transaction",
    "local_transaction",
    "form",
    "calculator",
    "smart_answer",
    "simple_smart_answer",
    "place",
    "licence",
    "step_by_step_nav",
    "transaction",
    "answer",
    "guide",
}

# define a set for guidance and regulation doc types
guidance_and_reg_doctypes = {
    "regulation",
    "detailed_guide",
    "manual",
    "manual_section",
    "guidance",
    "map",
    "calendar",
    "statutory_guidance",
    "notice",
    "international_treaty",
    "travel_advice",
    "promotional",
    "international_development_fund",
    "countryside_stewardship_grant",
    "esi_fund",
    "business_finance_support_scheme",
    "statutory_instrument",
    "hmrc_manual",
    "standard",
}

# define a set for policy and engagement doc types
policy_and_engage_doctypes = {
    "impact_assessment",
    "policy_paper",
    "open_consultation",
    "policy_paper",
    "closed_consultation",
    "consultation_outcome",
    "policy_and_engagement",
}

# define a set for research and statistics doc types
research_and_stats_doctypes = {
    "dfid_research_output",
    "independent_report",
    "research",
    "statistics",
    "national_statistics",
    "statistics_announcement",
    "national_statistics_announcement",
    "official_statistics_announcement",
    "statistical_data_set",
    "official_statistics",
}

# define a set for transparency doc types
transparency_doctypes = {
    "transparency",
    "corporate_report",
    "foi_release",
    "aaib_report",
    "raib_report",
    "maib_report",
}

# loop through document types and create document supertype column
document_type_dict = dict.fromkeys(list(set(df_info["documentType"])))

for docType, docSupertype in document_type_dict.items():
    if docType in news_and_comms_doctypes:
        document_type_dict[docType] = "news and communication"

    elif docType in service_doctypes:
        document_type_dict[docType] = "services"

    elif docType in guidance_and_reg_doctypes:
        document_type_dict[docType] = "guidance and regulation"

    elif docType in policy_and_engage_doctypes:
        document_type_dict[docType] = "policy and engagement"

    elif docType in research_and_stats_doctypes:
        document_type_dict[docType] = "research and statistics"

    elif docType in transparency_doctypes:
        document_type_dict[docType] = "transparency"

    else:
        document_type_dict[docType] = "other"

df_docSuper = pd.DataFrame(
    document_type_dict.items(), columns=["documentType", "documentSupertype"]
)

df_all = pd.merge(df_all, df_docSuper, how="left")

# reoder and rename columns
df_all = df_all[
    [
        "page",
        "documentType",
        "documentSupertype",
        "sessionHitsAll",
        "entranceHit",
        "exitHit",
        "entranceAndExitHit",
    ]
]
df_all = df_all.rename(
    columns={
        "documentType": "document type",
        "documentSupertype": "document supertype",
        "sessionHitsAll": "number of sessions that visit this page",
        "entranceHit": "number of sessions where this page is an entrance hit",
        "exitHit": "number of sessions where this page is an exit hit",
        "entranceAndExitHit": "number of sessions where this page is both an entrance and exit hit",
    }
)

# %% [markdown]
# ### Add ranking to final csv file

# %%
# shortest_seed0_1
df_shortest_seed_0_1 = pd.DataFrame(
    shortest_seed0_1.items(),
    columns=[
        "page",
        "distance from `/browse/working/finding-job` (e.g. the higher the value is, the further away the page is from /browse/working/finding-job)",
    ],
)
df_all = pd.merge(df_all, df_shortest_seed_0_1, how="left")

# shortest_seed0_2
df_shortest_seed_0_2 = pd.DataFrame(
    shortest_seed0_2.items(),
    columns=[
        "page",
        "distance from `/topic/further-education-skills/apprenticeships (e.g. the higher the value is, the further away the page is from /topic/further-education-skills/apprenticeships)",
    ],
)
df_all = pd.merge(df_all, df_shortest_seed_0_2, how="left")

# where NaN, add 'no path' (NaN = no path is present between the source and target nodes)
df_all.fillna("no path", inplace=True)

# g_degree
df_g_degree = pd.DataFrame(
    g_degree.items(),
    columns=[
        "page",
        "the number of pages a user moves to/from between this page and another page in the list (e.g. the higher the value, the more users have moved to/from this page and another page in the list)",
    ],
)
df_all = pd.merge(df_all, df_g_degree, how="left")

# %% [markdown]
# ### Order final csv by rank

# %%
# page path becomes an index:
df_all = df_all.set_index("page")
# order webpages by the ranking (the highe rth better), which is stored in ranked_items dataframe
df_all = df_all.reindex(index=ranked_items["page"]).reset_index()

# %%
df_all
# Out:
#                                                    page  \
# 0                                           /find-a-job
# 1                           /browse/working/finding-job
# 2                             /sign-in-universal-credit
# 3       /topic/further-education-skills/apprenticeships
# 4                                     /universal-credit
# ...                                                 ...
# 1333                                /employee-tax-codes
# 1334  /guidance/veterans-uk-armed-forces-pensions-forms
# 1335  /disciplinary-procedures-and-action-at-work/di...
# 1336   /government/publications/lrs-organisation-portal
# 1337      /government/publications/lrs-help-and-support
#
#                document type       document supertype  \
# 0                transaction                 services
# 1     mainstream_browse_page                    other
# 2                transaction                 services
# 3                      topic                    other
# 4                      guide                 services
# ...                      ...                      ...
# 1333                   guide                 services
# 1334          detailed_guide  guidance and regulation
# 1335                   guide                 services
# 1336                guidance  guidance and regulation
# 1337                guidance  guidance and regulation
#
#       number of sessions that visit this page  \
# 0                                       71667
# 1                                        6709
# 2                                        7527
# 3                                        7488
# 4                                        4140
# ...                                       ...
# 1333                                       31
# 1334                                       45
# 1335                                       26
# 1336                                       58
# 1337                                       49
#
#       number of sessions where this page is an entrance hit  \
# 0                                                 18532
# 1                                                   410
# 2                                                  3403
# 3                                                   415
# 4                                                   217
# ...                                                 ...
# 1333                                                  2
# 1334                                                 18
# 1335                                                  4
# 1336                                                 17
# 1337                                                  5
#
#       number of sessions where this page is an exit hit  \
# 0                                                  4157
# 1                                                   753
# 2                                                  2042
# 3                                                  3189
# 4                                                  1076
# ...                                                 ...
# 1333                                                  2
# 1334                                                  0
# 1335                                                  3
# 1336                                                 16
# 1337                                                  5
#
#       number of sessions where this page is both an entrance and exit hit  \
# 0                                                 44191
# 1                                                   304
# 2                                                   349
# 3                                                  1185
# 4                                                    24
# ...                                                 ...
# 1333                                                  0
# 1334                                                  0
# 1335                                                  0
# 1336                                                  1
# 1337                                                  0
#
#      distance from `/browse/working/finding-job` (e.g. the higher the value is, the further away the page is from /browse/working/finding-job)  \
# 0                                                   1.0
# 1                                                   0.0
# 2                                                   1.0
# 3                                                   1.0
# 4                                                   1.0
# ...                                                 ...
# 1333                                                3.0
# 1334                                                3.0
# 1335                                                3.0
# 1336                                            no path
# 1337                                            no path
#
#      distance from `/topic/further-education-skills/apprenticeships (e.g. the higher the value is, the further away the page is from /topic/further-education-skills/apprenticeships)  \
# 0                                                   1.0
# 1                                                   1.0
# 2                                                   1.0
# 3                                                   0.0
# 4                                                   1.0
# ...                                                 ...
# 1333                                                3.0
# 1334                                                4.0
# 1335                                                3.0
# 1336                                            no path
# 1337                                            no path
#
#       the number of pages a user moves to/from between this page and another page in the list (e.g. the higher the value, the more users have moved to/from this page and another page in the list)
# 0                                              0.591623
# 1                                              0.177263
# 2                                              0.309648
# 3                                              0.163052
# 4                                              0.262528
# ...                                                 ...
# 1333                                           0.008227
# 1334                                           0.005984
# 1335                                           0.005984
# 1336                                           0.002244
# 1337                                           0.001496
#
# [1338 rows x 10 columns]

# %%
df_all.to_csv("../../data/processed/pages_ranked_with_data.csv", index=False)

# %%
df_all.to_clipboard()

# %%
ranked_items
# Out:
#                                                    page    rank
# 435                                         /find-a-job    12.0
# 190                         /browse/working/finding-job    15.0
# 1096                          /sign-in-universal-credit    23.0
# 1221    /topic/further-education-skills/apprenticeships    30.0
# 1262                                  /universal-credit    31.0
# ...                                                 ...     ...
# 382                                 /employee-tax-codes  1312.0
# 764   /guidance/veterans-uk-armed-forces-pensions-forms  1312.0
# 351   /disciplinary-procedures-and-action-at-work/di...  1329.0
# 624    /government/publications/lrs-organisation-portal  1335.0
# 623       /government/publications/lrs-help-and-support  1336.0
#
# [1338 rows x 2 columns]
