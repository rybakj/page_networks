# %% [markdown]
# ## Ranking output

# %% [markdown]
# **Replication of `rank_output.ipynb`**
#
# **This notebook produces ranking of economic recovery pages based on the tfdf_max metric**

# %% [markdown]
# Currently, the output of the random walks is a single set of pages. End users will prefer a ranked list of pages. This ranking should have a tendency to rank pages from the target WUJ higher than pages not in that WUJ.

# %% [markdown]
# ### Ranking by page frequency-random walk frequency
#
# #### An example
#
# The most successful random walk method has been to perform multiple random walks and combine the pages visited by each one into a single set of pages.
#
# Each random walk traverses a path of pages. Since we perform multiple random walks, we have multiple paths. Some pages will appear on more paths than others. Some pages will appear more frequently per path.
#
# For example: suppose you perform two random walks and each one traverses the following path:
#
# - [A, C, D, C, X, Y, Z]
# - [A, C, B, D, Q, P, M]
#
# Pages A, C and D are common to both paths. However, C occurs twice on the first path, which no other page does. Hence, C should be ranked first, followed by A and D in joint second. The remaining pages are equally ranked at the bottom.
#
# #### Page frequency-path frequency
#
# Inspired by the tf-idf ("term frequency-inverse document frequency") metric from NLP, we create the tf-df metric, "term frequency-document frequency". Translated into random walk parlance, this is "page frequency-path frequency". Where "page frequency" is the number of occurences of a given page on a given path taken by a random walk, and, "path frequency" is the number of random walk paths on which a given page occurs at least once.
#
# Mathematically,
#
# $pf(r,p)$ is the frequency of page $p$ on a single random walk $r$,
#
# $$\text{pf}(r,p) = f_{r,p}$$
#
# Where $f_{r,p}$ is the count of a page on a random walk path.
#
# The path frequency is a measure of how common a given page is to all random walks performed, i.e. if it's common or rare across all random walks,
#
# $$\text{rwf}(p,R) = |\{r \in R : p \in r\}|$$
#
# Where $R$ is the set of paths taken by all random walks and $|\{r \in R : p \in r\}|$ is the number of random walks on which the page $p$ occurs. For instance, in the above example, page C occurs on two random walk paths.

# %% [markdown]
# From here, we can compute the page frequency-path frequency metric. We start by constructing an $n\times m$ matrix, $A$, where $n$ is the number of random walks performed and $m$ is the number of unique pages visited across all random walks.
#
# Hence, $A_{r,p}=f_{r,p}$, i.e. the value on the $p$-th column of the $r$-th row is the the number of occurrences of page $p$ on random walk $r$.
#
# Then, for each page, we compute the path frequency score $\text{rwf}(p,R)$. Doing this for each page gives a vector of length $m$, called $v$, and we convert this into a diagonal matrix: $V=\text{diag}(v)$, where the elements of $v$ occupy the main diagonal.
#
# Once we have this, we simply calculate $AV$. This means each $(AV)_{r,p}=f_{r,p} \text{rwf}(p,R)$.
#
# There are multiple ways to proceed from here, but somehow we need to compress $AV$ down into a vector, where we have a score for each page. We could average each column, we could take the max, the min, and so on.
#
# In our implementation, each page is ranked by the maximum score for its column in $AV$.

# %% [markdown]
# Below, a demo is shown of this ranking system.

# %%
import random_walk.utils.randomwalks as rw
import numpy as np
import pandas as pd
import networkx as nx

# %%
import random 
random.seed(4894)
np.random.seed(846)

# %%
# er_pages is a list of pages known to be within the economic recovery WUJ
# this will be used to help evaluate the ranking system

er_pages = pd.read_excel('./data/inputs/2021-11-12 - Economic recovery pages.xlsx', sheet_name='Top pages').pagePathv2.to_list()

# get networkx graph
G = nx.read_gpickle("./data/inputs/functional_session_hit_directed_graph_er.gpickle").to_undirected()

# reformat the graph to make it compliant with existing random walk functions
# i.e. add the path to a name property and set the index to be a number

for index,data in G.nodes(data=True):
    data['properties'] = dict()
    data['properties']['name'] = index


G = nx.convert_node_labels_to_integers(G, first_label=0, ordering='default', label_attribute=None)

# get adjacency matrix of G
A = nx.adj_matrix(G, weight=None)

# %%
# set the seeds from where random walks will be initialised
seeds = (
    '/find-a-job',
    '/universal-credit',
    '/government/collections/financial-support-for-businesses-during-coronavirus-covid-19'
)

# %%
results = rw.repeat_random_walks(steps=100, repeats=100, T=A, G=G, seed_pages=seeds, proba=False, combine='union', level=1, n_jobs=1)
# Out:
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=3.0), HTML(value='')))

# %%
page_scores = rw.page_freq_path_freq_ranking(results)

# %%
paths = [path for paths in results['paths_taken'] for path in paths]


pages_visited = {page: i for i, page in zip(range(len(results['pages_visited'])), results['pages_visited'])}

tf = np.zeros((len(paths), len(pages_visited)))

# %%
results["pages_visited"]
# Out:
# {'/tax-company-benefits/tax-on-company-cars',
#  '/government/publications/covid-19-stay-at-home-guidance/stay-at-home-guidance-for-households-with-possible-coronavirus-covid-19-infection',
#  '/government/publications/paye-starter-checklist',
#  '/renting-out-a-property/paying-tax',
#  '/government/publications/coronavirus-job-retention-scheme-service-availability-and-issues',
#  '/government/publications/basic-passport-checks',
#  '/driving-motorhome',
#  '/apply-to-come-to-the-uk',
#  '/stop-being-self-employed',
#  '/parental-bereavement-pay-leave',
#  '/child-benefit-payment-dates/bank-holidays',
#  '/become-magistrate',
#  '/marriage-allowance',
#  '/employment-status/selfemployed-contractor',
#  '/government/publications/dwp-bereavement-service',
#  '/government/publications/universal-credit-and-your-claimant-commitment-quick-guide',
#  '/capital-allowances',
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship/borders-immigration-and-citizenship-privacy-information-notice',
#  '/driving-lessons-learning-to-drive',
#  '/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2',
#  '/jobseekers-allowance/report-a-change-of-circumstances',
#  '/government/organisations/hm-passport-office/about/complaints-procedure',
#  '/apply-citizenship-indefinite-leave-to-remain',
#  '/browse/employing-people',
#  '/world/morocco',
#  '/become-an-mot-tester/class-3-or-5-mot-tester-training',
#  '/tax-return-uk',
#  '/government/publications/2010-to-2015-government-policy-employment/2010-to-2015-government-policy-employment',
#  '/hmrc-internal-manuals/residence-domicile-and-remittance-basis/rdrm22310',
#  '/school-discipline-exclusions/challenging-exclusion',
#  '/complain-independent-case-examiner',
#  '/rent-council-garage',
#  '/set-up-business-partnership/naming-your-partnership',
#  '/guidance/income-tax-and-national-insurance-contributions',
#  '/repaying-your-student-loan/print',
#  '/guidance/notarial-and-documentary-services-guide-for-russia',
#  '/government/publications/portugal-criminal-record-certificate/request-a-copy-of-your-criminal-record-certificate-in-the-uk-and-in-portugal',
#  '/government/publications/ways-in-which-people-can-be-lawfully-resident-in-the-uk/ways-in-which-people-can-be-lawfully-resident-in-the-uk',
#  '/register-birth/birth-certificates',
#  '/government/organisations/hm-passport-office/contact/hm-passport-office-webchat',
#  '/browse/benefits/disability',
#  '/government/organisations/civil-service-government-legal-service',
#  '/business-finance-support/access-to-finance-advice-north-west-england',
#  '/certifying-a-document',
#  '/government/publications/work-and-health-programme-provider-guidance',
#  '/rights-disabled-person/employment',
#  '/government/publications/migration-and-mobility-partnership/mou-on-migration-and-mobility-partnership-between-india-and-the-united-kingdom',
#  '/biometric-residence-permits/replace-visa-brp',
#  '/transfer-visa',
#  '/guidance/civil-service-fast-track-apprenticeship-list-of-qualifying-stem-subjects',
#  '/book-pupil-driving-test',
#  '/guidance/student-loan-cancellation-permanently-unfit-to-work',
#  '/council-tax-bands',
#  '/guidance/check-if-you-need-a-visa-or-permit-for-europe',
#  '/copyright/print',
#  '/temporary-worker-creative-and-sporting-visa',
#  '/topic/business-tax/aggregates-levy',
#  '/data-protection/print',
#  '/government/publications/apply-to-extend-stay-in-the-uk-as-a-partner-or-dependent-child-form-flrm',
#  '/handing-in-your-notice/payment-during-your-notice-period',
#  '/foreign-travel-advice/ghana/health',
#  '/uk-family-visa/partner-spouse',
#  '/benefit-overpayments',
#  '/visas-when-you-separate-or-divorce/apply-stay-uk',
#  '/driver-cpc-training',
#  '/refugee-integration-loan/what-youll-get',
#  '/disciplinary-procedures-and-action-at-work',
#  '/business-finance-support/business-growth-programme-2-the-marches',
#  '/foreign-travel-advice/malta/travel-advice-help-and-support',
#  '/government/publications/double-taxation-treaties-territory-residents-with-uk-income',
#  '/guidance/assistant-economist-recruitment',
#  '/browse/tax/court-claims-debt-bankruptcy',
#  '/find-court-tribunal',
#  '/government/statistics/uk-house-price-index-england-may-2021/uk-house-price-index-england-may-2021',
#  '/guidance/childminders-report-new-adults-in-the-home',
#  '/government/publications/form-n244-application-notice',
#  '/topic/mot/being-mot-tester',
#  '/government/collections/qualifications-approved-for-public-funding',
#  '/guidance/understanding-your-driving-test-result/car-driving-test',
#  '/paternity-pay-leave/adoption',
#  '/child-benefit-complaints',
#  '/government/publications/armed-forces-veterans-badge-application-form',
#  '/guidance/manage-a-registered-pension-scheme',
#  '/new-state-pension/inheriting-or-increasing-state-pension-from-a-spouse-or-civil-partner',
#  '/check-british-citizenship/born-in-the-uk-between-1-january-1983-and-1-october-2000',
#  '/view-prove-immigration-status',
#  '/intracompany-transfer-worker-visa/your-partner-and-children',
#  '/workplace-pensions/get-help',
#  '/government/publications/english-and-maths-requirements-in-apprenticeship-standards-at-level-2-and-above',
#  '/visas-and-immigration-service-and-support-centres',
#  '/eori/apply-for-eori',
#  '/government/publications/disability-living-allowance-for-children-claim-form',
#  '/guidance/applying-to-set-up-a-border-control-post-at-your-port-or-airport',
#  '/world/sudan',
#  '/foreign-travel-advice/netherlands/entry-requirements',
#  '/government/statistics/disability-living-allowance',
#  '/log-in-file-self-assessment-tax-return/sign-in/prove-identity',
#  '/guidance/international-bus-or-coach-services-and-tours-vehicle-documents',
#  '/government/publications/trusts-and-estates-statement-of-income-from-estates-r185-estate-income',
#  '/biometric-residence-permits/personal-data',
#  '/government/publications/basic-paye-tools-national-insurance-number-verification-requests-only/basic-paye-tools-with-other-software-check-a-national-insurance-number',
#  '/government/publications/responsibility-for-autumn-gcse-as-and-a-level-exam-series/public-health-arrangements-for-autumn-exams',
#  '/search/transparency-and-freedom-of-information-releases',
#  '/universal-credit',
#  '/topic/dealing-with-hmrc/tax-compliance',
#  '/childcare-parenting/register-the-birth-of-a-child',
#  '/foreign-travel-advice/cuba',
#  '/foreign-travel-advice/pakistan/terrorism',
#  '/expenses-if-youre-self-employed/staff',
#  '/government/publications/applying-to-the-register-of-apprenticeship-training-providers-roatp',
#  '/child-tax-credit/already-claiming',
#  '/running-payroll/reporting-to-hmrc',
#  '/get-replacement-citizenship-certificate',
#  '/government/collections/pension-administrators',
#  '/chwilio-am-swydd',
#  '/government/publications/register-of-merged-charities',
#  '/government/organisations/hm-passport-office',
#  '/browse/tax',
#  '/government/organisations/department-for-international-development',
#  '/government/publications/qualified-teacher-status-routes-to-qts-for-teachers-and-those-with-teaching-experience-outside-the-uk',
#  '/guidance/section-96-qualifications',
#  '/government/statistics/social-fund-crisis-loan-multiple-applications-and-awards-2010',
#  '/child-adoption/adopting-a-stepchild',
#  '/capital-gains-tax',
#  '/vehicle-registration-schemes-for-the-motor-trade/secure-registration-scheme',
#  '/government/organisations/uk-council-for-internet-safety',
#  '/browse/environment-countryside/countryside',
#  '/what-is-the-construction-industry-scheme',
#  '/government/publications/eu-settlement-scheme-frontier-workers-and-their-family-members/if-the-uk-leaves-the-eu-with-a-deal',
#  '/guidance/the-uks-points-based-immigration-system-information-for-eu-citizens',
#  '/death-spouse-benefits-tax-pension/pensions',
#  '/guidance/early-years-qualifications-finder',
#  '/young-people-in-custody',
#  '/health-conditions-disability-universal-credit',
#  '/government/publications/covid-19-vaccination-women-of-childbearing-age-currently-pregnant-planning-a-pregnancy-or-breastfeeding',
#  '/foreign-travel-advice/argentina',
#  '/government/organisations/careers-wales',
#  '/setting-up-charity',
#  '/growing-your-business/hire-and-train-staff',
#  '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees',
#  '/government/organisations/department-for-education/services-information',
#  '/guidance/sign-in-to-your-hmrc-business-tax-account',
#  '/staff-redundant/layoffs-and-shorttime-working',
#  '/government/publications/ask-for-a-hearing-to-be-adjourned-london-form-ac001',
#  '/check-immigration-status',
#  '/life-in-prison/prisoner-privileges-and-rights',
#  '/guidance/eu-settlement-scheme-how-we-use-your-personal-information.ro',
#  '/intensive-personalised-employment-support',
#  '/guidance/rehabilitation-periods',
#  '/business-finance-support/business-cash-advance-uk',
#  '/guidance/learn-about-the-sia-licence-conditions-you-must-follow',
#  '/get-court-funds-money-when-you-recover',
#  '/government/publications/sure-start-maternity-grant-restricting-payment-of-the-to-the-first-child',
#  '/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19',
#  '/child-tax-credit/how-to-claim',
#  '/trusts-taxes/trustees-tax-responsibilities',
#  '/house-in-multiple-occupation-licence',
#  '/pip/claiming-pip-if-youre-terminally-ill',
#  '/apply-for-disabled-bus-pass',
#  '/employers-maternity-pay-leave/help-with-statutory-pay',
#  '/employers-parental-bereavement-pay-leave',
#  '/government/publications/hong-kong-bno-visa-policy-statement/hong-kong-british-national-overseas-visa-policy-statement-plain-text-version',
#  '/browse/employing-people/pensions',
#  '/apply-disabled-facilities-grant',
#  '/over-80-pension',
#  '/monitoring-work-workers-rights/email-cctv-and-other-monitoring',
#  '/government/publications/subject-access-requests',
#  '/pensiwn-y-wladwriaeth-newydd',
#  '/dbs-update-service',
#  '/government/collections/national-travel-survey-statistics',
#  '/topic/personal-tax/inheritance-tax',
#  '/government/publications/redundancy-payments-form-hr1-advance-notification-of-redundancies',
#  '/courts-tribunals/upper-tribunal-immigration-and-asylum-chamber',
#  '/marriages-civil-partnerships/give-notice',
#  '/illness-child-education',
#  '/society-and-culture',
#  '/guidance/make-a-freedom-of-information-foi-request-to-dwp',
#  '/recover-statutory-payments/if-you-cant-afford-to-make-payments',
#  '/over-80-pension/print',
#  '/government/organisations/civil-service-government-occupational-psychology-profession/about',
#  '/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work',
#  '/government/publications/academic-technology-approval-scheme-atas-occupation-codes/academic-technology-approval-scheme-atas-occupation-codes',
#  '/skilled-worker-visa/knowledge-of-english',
#  '/government/publications/notice-252-valuation-of-imported-goods-for-customs-purposes-vat-and-trade-statistics',
#  '/apply-to-come-to-the-uk/prepare-your-application',
#  '/government/publications/student-finance-guidance-on-how-to-appeal',
#  '/leaving-prison/support-when-someone-leaves-prison',
#  '/government/publications/tax-credits-renewal-pack-notes',
#  '/employing-an-apprentice/apprenticeship-agreement',
#  '/topic/personal-tax/coming-to-uk',
#  '/foreign-travel-advice/india',
#  '/government/publications/apprenticeship-training-agencies',
#  '/government/collections/check-a-list-of-genuine-hmrc-contacts',
#  '/home-responsibilities-protection-hrp/how-to-claim',
#  '/government/organisations/hm-revenue-customs/contact/bereavement-and-deceased-estate',
#  '/government/publications/an-applicants-introduction-to-the-decision-making-process-for-enhanced-criminal-record-checks',
#  '/night-working-hours',
#  '/calculate-agricultural-holiday-entitlement',
#  '/guidance/apprenticeship-funding-rules-for-training-providers/changes-in-circumstances',
#  '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa',
#  '/government/publications/sector-based-work-academies-employer-guide',
#  '/contact-jobcentre-plus/new-benefit-claims',
#  '/buy-sell-your-home/estate-agents',
#  '/change-address-driving-licence/apply-by-post',
#  '/housing-association-homes/complaints',
#  '/government/collections/further-education-and-skills-statistical-first-release-sfr',
#  '/appeal-right-of-way-decision',
#  '/browse/justice/reporting-crimes-compensation',
#  '/change-address-driving-licence',
#  '/track-your-driving-licence-application/provisional-licences-new',
#  '/how-to-vote/postal-voting',
#  '/guidance/apprenticeship-funding-rules-for-employer-providers/what-is-an-apprenticeship',
#  '/government/publications/nationality-forms-guide',
#  '/government/collections/statutory-maternity-pay-and-leave',
#  '/war-widow-pension',
#  '/pension-credit-calculator',
#  '/government/publications/mod-subject-access-request-form',
#  '/understand-self-assessment-bill',
#  '/tax-credits-appeals-complaints/complaints',
#  '/guidance/guidance-for-buying-property-abroad',
#  '/service-standard-reports/universal-credit-full-service-beta-assessment',
#  '/pip/when-your-pip-claim-is-reviewed',
#  '/government/organisations/disclosure-and-barring-service/about/media-enquiries',
#  '/bills-benefits',
#  '/government/publications/guidance-for-dependants-of-uk-visa-applicants-tiers-1-2-4-5',
#  '/government/publications/ask-for-a-hearing-to-be-adjourned-manchester-form-ac001',
#  '/government/publications/data-protection-act-dpa-information-hm-revenue-and-customs-hold-about-you',
#  '/hmrc-internal-manuals/employment-status-manual/esm10001a',
#  '/rights-disabled-person/the-equality-act-2010-and-un-convention',
#  '/guidance/pension-administrators-reporting-to-hmrc',
#  '/government/publications/self-assessment-commercial-software-suppliers',
#  '/guidance/red-amber-and-green-list-rules-for-entering-england',
#  '/expenses-and-benefits-business-travel-mileage/rules-for-tax',
#  '/government/publications/blue-badge-can-i-get-one',
#  '/world/ireland',
#  '/guidance/help-to-find-work-for-universal-credit-claimants-aged-18-to-24',
#  '/appeal-qualification-result',
#  '/hmrc-internal-manuals/employment-income-manual/eim76224',
#  '/deferring-state-pension/print',
#  '/register-milk-production-holding',
#  '/approved-driving-instructor-adi-fees',
#  '/sponsor-management-system',
#  '/government/publications/premises-licence-application-forms/premises-licence-guidance',
#  '/government/statistics/personal-pensions-tables-7-and-8',
#  '/apply-home-office-travel-document/stateless-persons-travel-document',
#  '/married-couples-allowance',
#  '/government/publications/subject-access-request-form',
#  '/government/publications/data-protection-act-dpa-information-hm-revenue-and-customs-hold-about-you/data-protection-act-dpa-information-hm-revenue-and-customs-hold-about-you',
#  '/wind-up-a-company-that-owes-you-money',
#  '/building-regulations-approval',
#  '/get-paye-forms-p45-p60',
#  '/industrial-action-strikes/your-employment-rights-during-industrial-action',
#  '/government/publications/public-service-pensions-increase-2021/note-by-hm-treasury-2021-pensions-increase-multiplier-tables',
#  '/guidance/foreign-travel-insurance',
#  '/guidance/coronavirus-support-for-business-from-outside-government',
#  '/guidance/drivers-hours-goods-vehicles/updates',
#  '/claim-loss-notice',
#  '/renew-driving-licence-at-70',
#  '/government/collections/hong-kong-uk-welcome-programme',
#  '/government/organisations/department-for-work-pensions/about/research',
#  '/employee-ownership',
#  '/online-and-distance-selling-for-businesses',
#  '/stopped-by-police-while-driving-your-rights',
#  '/government/groups/defence-awarding-organisation',
#  '/guidance/apply-to-enter-a-trade-union-on-the-certification-officers-list',
#  '/buy-sell-your-home/offers',
#  '/international-development-funding',
#  '/government/collections/dart-charge',
#  '/government/collections/ethnicity-facts-and-figures-ethnic-group-summaries',
#  '/government/publications/equality-act-guidance',
#  '/self-employment-and-universal-credit',
#  '/contact-grandchild-parents-divorce-separate',
#  '/child-adoption/early-stages-of-adoption',
#  '/government/publications/additional-statutory-paternity-pay-and-leave-becoming-a-parent-sc7',
#  '/government/publications/application-for-review-when-british-citizenship-is-refused-form-nr',
#  '/guidance/graphic-designer',
#  '/guidance/welsh-partial-loan-cancellation',
#  '/government/organisations/land-registry',
#  '/guidance/countryside-productivity-small-grant-cpsg-scheme-round-3/countryside-productivity-small-grant-cpsg-scheme-how-it-works',
#  '/government/publications/self-assessment-employment-sa102',
#  '/uk-family-visa/private-life',
#  '/health-conditions-and-driving',
#  '/guidance/manage-your-mot-centre',
#  '/government/publications/apply-to-extend-your-stay-in-the-uk-form-flrfp/apply-online-form-flr-fp',
#  '/guidance/check-what-training-you-need-to-get-an-sia-licence',
#  '/government/publications/esfa-update-28-july-2021/esfa-update-further-education-28-july-2021',
#  '/government/publications/insolvency-service-financial-assistance-scheme-details-of-employees-to-receive-redundancy-pay',
#  '/government/collections/applications-for-continued-registration',
#  '/government/publications/basic-paye-tools-what-to-do-when-an-employee-leaves/basic-paye-tools-when-an-employee-leaves',
#  '/changing-passport-information/divorce-or-returning-to-a-previous-surname',
#  '/theory-test/what-to-take',
#  '/pay-voluntary-class-3-national-insurance/by-post',
#  '/government/publications/charity-trustee-welcome-pack',
#  '/government/organisations/hm-revenue-customs/contact/child-trust-fund',
#  '/over-80-pension/further-information',
#  '/foreign-travel-advice/mexico',
#  '/guidance/apprenticeship-funding-rules-for-training-providers/annex-a-eligibility-criteria-who-we-fund',
#  '/government/publications/actions-for-schools-during-the-coronavirus-outbreak',
#  '/council-housing',
#  '/government/publications/form-precedent-h-and-r-costs-budget-precedent-h-and-budget-discussion-report-precedent-r',
#  '/goods-sent-from-abroad/print',
#  '/tax-company-benefits/other-company-benefits-youll-pay-tax-on',
#  '/government/publications/dbs-filtering-guidance/dbs-filtering-guide',
#  '/uk-family-visa/knowledge-of-english',
#  '/government/publications/pension-schemes-transferring-uk-tax-relieved-pension-assets-apss-262',
#  '/government/publications/universal-credit-work-allowances/universal-credit-work-allowances',
#  '/report-suspicious-emails-websites-phishing',
#  '/employee-tax-codes/numbers',
#  '/browse/education/student-finance',
#  '/frontier-worker-permit/who-can-apply',
#  '/government/organisations/civil-service-medical-profession',
#  '/employment-tribunals/make-a-claim',
#  '/contracted-out',
#  '/lasting-power-attorney-duties/property-financial-affairs',
#  '/government/publications/dbs-application-forms-guide-for-applicants/dbs-application-form-guide-for-applicants',
#  '/guidance/immigration-rules/immigration-rules-part-6a-the-points-based-system',
#  '/guidance/changes-to-employment-allowance',
#  '/guidance/childminders-and-childcare-providers-register-with-ofsted/daycare-childcare-on-non-domestic-premises-registration',
#  '/liquidate-your-company/what-happens-to-directors',
#  '/government/publications/child-trust-fund-claim-annual-tax-relief-ctf14',
#  '/vehicle-registration-schemes-for-the-motor-trade',
#  '/disabled-facilities-grants/what-youll-get',
#  '/government/publications/fertility-treatment-a-guide-to-your-consumer-rights',
#  '/set-up-limited-company',
#  '/guidance/report-end-of-year-expenses-and-benefits-online.cy',
#  '/change-address-v5c',
#  '/government/organisations/hm-revenue-customs/contact/complain-about-hmrc-online-services',
#  '/police-community-support-officers-what-they-are',
#  '/government/statistics/coronavirus-job-retention-scheme-statistics-june-2020',
#  '/government/publications/furlough-and-redundancy',
#  '/government/publications/skilled-worker-visa-eligible-occupations',
#  '/hmrc-internal-manuals/business-income-manual/bim54030',
#  '/guidance/qualifications-required-to-work-on-equipment-containing-f-gas',
#  '/hmrc-internal-manuals/residence-domicile-and-remittance-basis/rdrm11000',
#  '/apply-citizenship-british-nationality/lived-in-the-uk-or-worked-for-the-crown-service',
#  '/make-will/make-sure-your-will-is-legal',
#  '/types-of-british-nationality/british-overseas-territories-citizen',
#  '/government/publications/terms-and-conditions-for-dbs-online-services',
#  '/workplace-pensions/what-you-your-employer-and-the-government-pay',
#  '/government/publications/application-to-settle-in-the-uk-form-seto',
#  '/help-for-disabled-child/education',
#  '/when-someone-dies',
#  '/vehicle-tax-rate-tables',
#  '/financial-help-disabled/home-and-housing',
#  '/world/mexico',
#  '/government/publications/national-curriculum-in-england-primary-curriculum',
#  '/historic-vehicles',
#  '/guidance/recruiting-people-from-outside-the-uk',
#  '/browse/housing-local-services/local-councils',
#  '/government/publications/sickness-absence-and-health-in-the-workplace-understanding-employer-behaviour-and-practice',
#  '/claim-tax-credits/joint-claims',
#  '/government/publications/early-years-qualifcations-pre-september-2014-criteria',
#  '/government/collections/eu-settlement-scheme-applicant-information',
#  '/government/publications/documents-list-dl',
#  '/government/collections/other-cross-cutting-guidance-modernised-guidance',
#  '/government/organisations/land-registry/about/recruitment',
#  '/government/publications/skills-funding-agency-business-update/business-update-issue-70-august-2021',
#  '/foreign-travel-advice/poland/money',
#  '/topic/defence-armed-forces/support-services-military-defence-personnel-families',
#  '/government/publications/an-introduction-to-the-hong-kong-british-national-overseas-visa',
#  '/redundancy-your-rights/print',
#  '/government/publications/safeguarding-factsheet-community-volunteers-during-covid-19-outbreak',
#  '/handling-employee-grievance',
#  '/government/publications/application-to-extend-stay-in-the-uk-flrir',
#  '/tax-uk-income-live-abroad/rent',
#  '/national-benefit-fraud-hotline',
#  '/government/organisations/united-kingdom-security-vetting',
#  '/difficulties-paying-hmrc',
#  '/government/publications/pension-schemes-newsletter-131-july-2021',
#  '/staff-redundant/redundancy-consultations',
#  '/ride-motorcycle-moped',
#  '/guidance/the-hardship-fund-a-guide',
#  '/apply-free-school-meals',
#  '/government/publications/excise-notice-2002-alcohol-wholesaler-registration-scheme/excise-notice-2002-alcohol-wholesaler-registration-scheme',
#  '/government/publications/work-and-health-programme-covid-19-provider-guidance',
#  '/guidance/redundancy-help-finding-work-and-claiming-benefits',
#  '/government/publications/lrs-help-and-support',
#  '/dormant-company',
#  '/international-development-funding/uk-aid-connect',
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-the-self-employed',
#  '/government/publications/access-to-work-factsheet',
#  '/paye-for-employers/keeping-records',
#  '/cold-weather-payment/further-information',
#  '/change-name-deed-poll',
#  '/uk-border-control',
#  '/government/publications/civil-service-competency-framework',
#  '/help/beta',
#  '/defence-and-armed-forces/armed-forces-support-for-activities-in-the-uk',
#  '/government/publications/armed-forces-community-covenant',
#  '/world/spain',
#  '/income-tax',
#  '/guidance/mod-safeguarding',
#  '/government/organisations/ofqual',
#  '/report-immigration-crime',
#  '/government/publications/state-pensions-annual-increases-if-you-live-abroad/countries-where-we-pay-an-annual-increase-in-the-state-pension',
#  '/government/statistics/apprenticeship-and-traineeships-april-2020',
#  '/guidance/annual-tax-summary',
#  '/innovator-visa/eligibility',
#  '/foreign-travel-advice/spain',
#  '/state-pension/print',
#  '/tax-on-your-private-pension/lifetime-allowance',
#  '/government/publications/disability-confident-and-cipd-guide-for-line-managers-on-employing-people-with-a-disability-or-health-condition',
#  '/social-work-bursaries/print',
#  '/government/publications/corporate-covenant-pledge',
#  '/foreign-travel-advice/greece',
#  '/settled-status-eu-citizens-families/what-youll-need-to-apply',
#  '/marriage-visa/apply',
#  '/understand-self-assessment-bill/payments-on-account',
#  '/government/publications/employers-quick-start-guide-to-positive-action-in-recruitment-and-promotion',
#  '/government/publications/employment-and-support-allowance-permitted-work-form/permitted-work-factsheet',
#  '/government/publications/kickstart-scheme-promotional-materials',
#  '/government/consultations/shaping-future-support-the-health-and-disability-green-paper',
#  '/photos-for-passports',
#  '/dietitian-registration',
#  '/guidance/universal-credit-how-it-helps-you-into-work',
#  '/government/publications/claim-for-costs-of-a-childs-funeral-childrens-funeral-fund-for-england',
#  '/find-an-immigration-adviser',
#  '/research-for-development-outputs/pymod-a-forecasting-model-for-conifer-plantations-in-the-tropical-highlands-of-eastern-africa',
#  '/guidance/driving-in-the-eu-uk-licence-holders-living-in-the-eu',
#  '/guidance/transgender-applications',
#  '/guidance/public-access-to-military-areas',
#  '/education-attendance-council',
#  '/foreign-travel-advice/bulgaria/entry-requirements',
#  '/government/publications/indefinite-leave-to-remain-calculating-continuous-period-in-uk',
#  '/government/publications/redundancy-payments-from-the-insolvency-service',
#  '/government/organisations/charity-commission',
#  '/tell-dvla-about-bereavement/keeping-the-vehicle',
#  '/guidance/use-the-land-information-search',
#  '/government/publications/qualification-achievement-rates-qar-2020-to-2021',
#  '/housing-and-universal-credit/property-you-own',
#  '/government/collections/dhsc-supplementary-statistical-data',
#  '/government/organisations/hm-revenue-customs/contact/child-benefit',
#  '/criminal-record-checks-apply-role',
#  '/government-authorised-exchange/eligibility',
#  '/government/publications/eu-settlement-scheme-factsheet.pl',
#  '/business/premises-rates',
#  '/nhs-bursaries/how-to-claim',
#  '/business-finance-support',
#  '/help-for-disabled-child/childcare',
#  '/driving-lessons-learning-to-drive/practising-with-family-or-friends',
#  '/government/statistical-data-sets/fe-data-library-apprenticeships',
#  '/dismiss-staff',
#  '/guidance/check-if-youre-eligible-for-the-coronavirus-additional-restrictions-grant',
#  '/disabled-students-allowance-dsa/eligibility',
#  '/change-name-deed-poll/enrol-a-deed-poll-with-the-courts',
#  '/report-a-lost-or-stolen-passport',
#  '/support-for-mortgage-interest/eligibility',
#  '/short-term-benefit-advance/how-to-apply',
#  '/government/publications/right-of-abode-roa',
#  '/shared-parental-leave-and-pay/applying-for-leave-and-pay',
#  '/representative-overseas-business/eligibility',
#  '/government/publications/defence-maritime-regulations',
#  '/agricultural-sick-pay/how-to-claim',
#  '/government/collections/universal-credit-information-for-employers',
#  '/1619-bursary-fund/how-to-claim',
#  '/government/publications/workers-and-temporary-workers-guidance-for-sponsors-sponsor-a-sportsperson-or-sporting-worker/workers-and-temporary-workers-guidance-for-sponsors-sponsor-a-sportsperson-or-sporting-worker-accessible-version',
#  '/child-adoption/applying-for-an-adoption-court-order',
#  '/estimate-income-tax',
#  '/government/collections/pension-schemes-forms',
#  '/tax-appeals',
#  '/home-responsibilities-protection-hrp',
#  '/government/organisations/civil-service-government-legal-profession/about/recruitment',
#  '/government/publications/accredited-personal-licence-qualification-providers/accredited-personal-licence-qualification-providers',
#  '/find-traineeship',
#  '/understand-how-your-council-works/decision-making',
#  '/government/publications/access-to-work-statistics-background-information-and-methodology/access-to-work-statistics-background-information-and-methodology',
#  '/tax-sell-property/businesses',
#  '/government/publications/home-office-eu-settlement-scheme-statistics-user-guide',
#  '/government/publications/budgeting-loan-guide-for-decision-makers-reviewing-officers-and-further-reviewing-officers',
#  '/adi-part-1-test',
#  '/apply-citizenship-born-uk/under-18',
#  '/apply-citizenship-indefinite-leave-to-remain/after-you-get-your-certificate',
#  '/checks-when-buying-a-used-car',
#  '/guidance/government-legal-service-gls-legal-trainee-scheme-how-to-apply--2',
#  '/government/collections/des-engineering-management-advanced-apprenticeship-scheme',
#  '/your-rights-after-crime/if-the-case-goes-to-court',
#  '/topic/personal-tax/national-insurance',
#  '/employee-tax-codes/letters',
#  '/government/collections/hm-revenue-and-customs-employer-bulletin',
#  '/council-tax',
#  '/guidance/check-if-your-retail-hospitality-or-leisure-business-is-eligible-for-business-rates-relief-due-to-coronavirus-covid-19',
#  '/government/publications/germany-residency',
#  '/find-bereavement-services-from-council',
#  '/apply-gender-recognition-certificate',
#  '/government/publications/skilled-worker-visa-jobs-that-qualify-for-a-phd-salary-discount',
#  '/pensions-advisory-service',
#  '/government/organisations/department-for-international-trade',
#  '/guidance/sign-in-to-your-agent-services-account',
#  '/guidance/check-if-you-need-an-sia-licence-to-work-as-an-event-steward',
#  '/government/collections/regulatory-framework-requirements',
#  '/world/living-in-british-virgin-islands',
#  '/valuing-estate-of-someone-who-died/tell-hmrc-estate-value',
#  '/contract-types-and-employer-responsibilities/freelancers-consultants-and-contractors',
#  '/intracompany-transfer-worker-visa',
#  '/government/publications/passport-photo-eye-distance-template',
#  '/government/collections/fcdo-commercial-pipeline-data',
#  '/government/publications/plant-species-by-import-category/import-requirements-for-plants-plant-produce-and-products',
#  '/update-uk-visas-immigration-account-details',
#  '/government/groups/defence-relationship-management',
#  '/employment-rights-for-interns',
#  '/guidance/procedures-for-uk-paediatric-investigation-plan-pips',
#  '/child-benefit/how-to-claim',
#  '/guidance/homelessness-code-of-guidance-for-local-authorities/chapter-18-applications-decisions-and-notifications',
#  '/pay-paye-tax/check-payment-received',
#  '/guidance/check-if-your-nursery-is-eligible-for-business-rates-relief-due-to-coronavirus-covid-19',
#  '/topic/environmental-management/boating',
#  '/stop-employing-staff',
#  '/payroll-software',
#  '/permanent-residence-document-eu-eea',
#  '/limited-company-formation',
#  '/hmrc-internal-manuals/pensions-tax-manual/updates',
#  '/government/publications/workers-and-temporary-workers-sponsor-a-skilled-worker',
#  '/reasonable-force-against-intruders',
#  '/government/publications/application-for-mot-authorisation-vt01',
#  '/government/publications/scotland-firing-times/barry-buddon-training-area-firing-times-july-2021',
#  '/government/collections/guidance-for-recruiters-using-civil-service-jobs-vx',
#  '/foreign-travel-advice/germany/coronavirus',
#  '/hackney-carriage-licence',
#  '/government/collections/citizenship-application-forms',
#  '/government/statistics/esa-underpayments-progress-on-checking-june-2021',
#  '/apply-for-council-tax-discount',
#  '/visit-uk-research',
#  '/how-to-register-a-trade-mark/unregistered-trade-marks',
#  '/expenses-and-benefits-bonuses',
#  '/guidance/war-pension-scheme-mobility-supplement-wpms',
#  '/government/publications/coronavirus-covid-19-testing-privacy-information/testing-for-coronavirus-privacy-information--2',
#  '/browse/childcare-parenting/schools-education',
#  '/english-language/approved-english-language-qualifications',
#  '/stay-in-uk-stateless',
#  '/employer-preventing-discrimination/recruitment',
#  '/browse/abroad',
#  '/guidance/e-exporting',
#  '/government/publications/earnings-adjustment-statement-eas-2017-to-2018',
#  '/disabled-students-allowances-assessment-centre',
#  '/get-help-savings-low-income/how-it-will-affect-your-benefits',
#  '/find-theory-test-centre',
#  '/definition-of-disability-under-equality-act-2010',
#  '/hmrc-internal-manuals/pensions-tax-manual/ptm040000',
#  '/government/publications/compensation-recovery-unit-forms',
#  '/sportsperson-visa',
#  '/guidance/mod-diversity-networks',
#  '/entering-staying-uk/family-visas',
#  '/government/publications/easy-read-get-help-at-work-if-youre-disabled-or-have-a-health-condition-access-to-work/get-help-from-access-to-work-easy-read',
#  '/settlement-refugee-or-humanitarian-protection',
#  '/hgv-levy',
#  '/bank-holidays',
#  '/pay-dartford-crossing-charge/charges-fines',
#  '/chaperone-child-performers',
#  '/government/publications/view-and-prove-your-immigration-status-evisa/your-immigration-status-an-introduction-for-eu-eea-and-swiss-citizens-accessible-version',
#  '/government/publications/visitor-visa-guide-to-supporting-documents',
#  '/get-document-legalised',
#  '/find-postgraduate-teacher-training-courses',
#  '/foreign-travel-advice/singapore/entry-requirements',
#  '/government/publications/your-charter/your-charter',
#  '/government/publications/research-opportunities-on-national-nature-reserves-in-england/suggested-topics-for-dissertation-projects-based-on-national-nature-reserves',
#  '/statutory-sick-pay/eligibility',
#  '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus',
#  '/government/publications/l17-statement-of-earnings',
#  '/browse/business/manufacturing',
#  '/world/south-africa',
#  '/government/publications/fe-choices-about-the-survey',
#  '/government/publications/easy-read-universal-credit',
#  '/universal-credit/what-youll-get',
#  '/government/publications/employment-tribunal-procedure-rules',
#  '/guidance/send-prison',
#  '/after-a-death/tax-benefits-vehicles',
#  '/guidance/coming-to-the-uk-for-seasonal-agricultural-work-on-english-farms.ru',
#  '/government/publications/calculating-holiday-entitlement-for-workers/how-to-calculate-holiday-entitlement-for-workers-on-different-types-of-contract',
#  '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships',
#  '/government/publications/know-your-traffic-signs',
#  '/government/publications/form-n1-claim-form-cpr-part-7',
#  '/find-internship',
#  '/stopped-by-police-while-driving-your-rights/minor-motoring-offences',
#  '/appeal-parking-fine',
#  '/transfers-takeovers/transfers-of-employment-contracts',
#  '/agency-workers-your-rights',
#  '/expenses-and-benefits-travel/technical-guidance',
#  '/government/publications/a-parents-guide-to-apprenticeships',
#  '/government/publications/covid-19-response-spring-2021/covid-19-response-spring-2021-summary',
#  '/government/groups/cycle-proofing-working-group',
#  '/guidance/pension-schemes-protect-your-lifetime-allowance',
#  '/company-director-disqualification',
#  '/capital-gains-tax/work-out-need-to-pay',
#  '/industrial-injuries-disablement-benefit/further-information',
#  '/government/publications/state-pension-age-independent-review-final-report',
#  '/government/publications/police-registration',
#  '/leasehold-property/extending-changing-or-ending-a-lease',
#  '/browse/childcare-parenting/childcare',
#  '/government/publications/human-augmentation-the-dawn-of-a-new-paradigm',
#  '/licence-finder',
#  '/tax-foreign-income/taxed-twice',
#  '/government/publications/funding-initial-teacher-training-itt',
#  '/government/government-spending',
#  '/guidance/provide-information-about-your-banking-and-payments-to-dfe',
#  '/topic/further-education-skills/vocational-qualifications/latest',
#  '/turkish-worker-business-person-settlement',
#  '/christmas-bonus/what-youll-get',
#  '/tax-uk-income-live-abroad',
#  '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide',
#  '/government/publications/child-maintenance-how-a-childs-living-arrangements-can-affect-payments-factsheet/how-your-childs-living-arrangements-affect-child-maintenance',
#  '/browse/tax/income-tax',
#  '/apply-to-come-to-the-uk/getting-a-decision-on-your-application',
#  '/driving-test/what-to-take',
#  '/government/publications/operational-low-flying-training-timetable/operational-low-flying-training-timetable-9-to-13-august-2021',
#  '/government/publications/statutory-sick-pay-employee-not-entitled-form-for-employers',
#  '/government/publications/employer-bulletin-february-2021/employer-bulletin-february-2021',
#  '/housing-benefit/what-youll-get',
#  '/trusts-taxes/trusts-and-income-tax',
#  '/government/publications/national-insurance-application-to-pay-voluntary-national-insurance-contributions-ca5603',
#  '/welfare',
#  '/renew-driving-licence',
#  '/carers-allowance/eligibility',
#  '/guidance/deferral-of-vat-payments-due-to-coronavirus-covid-19',
#  '/masters-loan/eligibility',
#  '/global-talent/documents-youll-need-to-apply',
#  '/register-a-death',
#  '/government/publications/apprenticeship-funding-legal-agreement-for-training-providers',
#  '/after-a-death',
#  '/government/publications/ireland-consular-fees/ireland-consular-fees',
#  '/deferring-state-pension/if-you-move-abroad',
#  '/drivers-hours/exemptions-from-eu-law',
#  '/get-help-with-court-fees',
#  '/government/organisations/disabled-peoples-employment-corporation',
#  '/guidance/check-if-you-could-be-covered-by-the-coronavirus-job-retention-scheme',
#  '/government/publications/universal-credit-changes-to-limited-capability-for-work-payments',
#  '/state-pension/how-to-claim',
#  '/life-in-prison/healthcare-in-prison',
#  '/hmrc-internal-manuals/international-exchange-of-information/ieim402040',
#  '/education/apprenticeships-traineeships-and-internships',
#  '/business-and-industry/science-and-innovation',
#  '/employment-support-allowance',
#  '/education/adult-education-funding',
#  '/tax-overpayments-and-underpayments/if-youre-due-a-refund',
#  '/national-minimum-wage-rates',
#  '/moving-from-benefits-to-work/work-experience-and-volunteering',
#  '/government/publications/challenge-a-decision-made-by-the-department-for-work-and-pensions-dwp',
#  '/credyd-cynhwysol/cysylltu-credyd-cynhwysol',
#  '/guidance/claim-a-waiver-for-duty-on-goods-that-you-bring-to-northern-ireland-from-great-britain',
#  '/browse/visas-immigration/what-you-need-to-do',
#  '/apply-citizenship-eea',
#  '/guidance/request-records-of-deceased-service-personnel',
#  '/government/publications/avoiding-common-mistakes-on-the-dbs-application-form',
#  '/foreign-travel-advice/morocco/coronavirus',
#  '/national-insurance-if-you-go-abroad',
#  '/uk-residence-card/report-a-lost-or-stolen-card',
#  '/government/publications/deferring-your-state-pension',
#  '/register-employer',
#  '/world/italy',
#  '/settled-status-eu-citizens-families/switch-from-presettled-status-to-settled-status',
#  '/get-help-hmrc-extra-support/cannot-use-telephone-different-way-to-contact',
#  '/government/publications/16-to-19-study-programmes-guide-for-providers/16-to-19-study-programmes-guidance-2021-to-2022-academic-year',
#  '/register-stillbirth',
#  '/guidance/how-to-get-ethnic-minority-employment-data',
#  '/driving-disqualifications',
#  '/apply-to-adopt-child-through-council',
#  '/government/publications/new-enterprise-allowance-campaign-promotional-videos/new-enterprise-allowance-campaign-promotional-videos-transcripts',
#  '/government/publications/inf1883-car-or-motorcycle-drivers-who-have-had-a-stroke-or-transient-ischaemic-attack-tia',
#  '/child-employment/paying',
#  '/guidance/report-a-lorry-bus-or-coach-driver-or-company',
#  '/get-information-about-a-company',
#  '/guidance/how-to-take-on-an-apprentice',
#  '/options-for-paying-off-your-debts/debt-management-plans',
#  '/employment-support-allowance/working-while-you-claim',
#  '/vaccine-damage-payment',
#  '/health-care-worker-visa/different-salary-requirements',
#  '/government/publications/send-code-of-practice-0-to-25',
#  '/become-apprentice/apply-for-an-apprenticeship',
#  '/check-british-citizenship/born-in-the-uk-on-30-april-2006-onwards',
#  '/keeping-your-pay-tax-records/how-long-to-keep-your-records',
#  '/coronavirus-volunteering/ways-to-volunteer',
#  '/browse/driving/buy-sell-scrap-vehicle',
#  '/government/publications/make-a-report-on-someones-capacity-to-make-decisions-form-cop3',
#  '/guidance/coronavirus-covid-19-getting-tested',
#  '/government/organisations/hm-revenue-customs/contact/construction-industry-scheme',
#  '/government/publications/using-the-apprenticeship-brand',
#  '/guidance/veterans-uk-armed-forces-pensions-forms',
#  '/redundancy-your-rights/suitable-alternative-employment',
#  '/help/browsers',
#  '/service-manual/design/writing-for-user-interfaces',
#  '/government/publications/the-graduate-route-information-for-international-students',
#  '/government/publications/introduction-of-t-levels',
#  '/guidance/charity-purposes-and-rules',
#  '/penalties-for-employing-illegal-workers',
#  '/government/publications/application-to-change-a-vehicle-tax-v70',
#  '/check-a-private-security-licence',
#  '/student-finance/new-fulltime-students',
#  '/government/organisations/hm-revenue-customs',
#  '/apply-school-transport-for-child-with-special-educational-needs-sen',
#  '/countersigning-passport-applications',
#  '/types-of-prison-sentence/indeterminate-prison-sentences-no-fixed-length-of-time',
#  '/send-prisoner-money',
#  '/war-pension-armed-forces-compensation-tribunal/after-appeal',
#  '/register-for-self-assessment/not-self-employed',
#  '/topic/further-education-skills/learning-records-service',
#  '/guidance/war-pension-scheme-other-allowances-that-may-be-available',
#  '/government/publications/a-step-by-step-guide-on-how-to-use-the-armed-forces-pension-calculator',
#  '/government/collections/state-pension-toolkit',
#  '/view-driving-licence',
#  '/lifetime-isa',
#  '/tax-company-benefits/taxfree-company-benefits',
#  '/world/pakistan',
#  '/research-for-development-outputs/jobs-in-kenya-opportunities-and-challenges',
#  '/tax-on-your-private-pension',
#  '/government/publications/change-to-the-people-on-universal-credit-employment-indicator-from-november-2019-onwards',
#  '/how-to-vote',
#  '/national-insurance/your-national-insurance-number',
#  '/get-tax-free-childcare',
#  '/find-lost-utr-number',
#  '/child-adoption/adopting-a-child-from-overseas',
#  '/guidance/plan-your-relationships-sex-and-health-curriculum',
#  '/guidance/tell-hmrc-youre-registered-for-the-vat-import-one-stop-shop-in-the-eu',
#  '/government/publications/carers-credit-application-form',
#  '/check-additional-income-tax',
#  '/residence-documents-foreign-nationals-uk',
#  '/apply-citizenship-indefinite-leave-to-remain/apply-for-your-children',
#  '/government/publications/universal-credit-and-self-employment-quick-guide',
#  '/apply-driver-digital-tachograph-card',
#  '/government/publications/your-tax-account',
#  '/government/publications/find-a-job-and-other-websites-what-you-need-to-know-about-cookies',
#  '/children-with-special-educational-needs/extra-sen-help',
#  '/advanced-learner-loan/how-to-apply',
#  '/topic/company-registration-filing/starting-company',
#  '/right-to-buy-buying-your-council-home',
#  '/government/publications/introducing-govuk-verify/introducing-govuk-verify',
#  '/moving-from-benefits-to-work/support-when-you-start-working',
#  '/equality-advisory-support-service',
#  '/government/collections/alcohol-licensing-personal-licences',
#  '/money/personal-tax',
#  '/volunteering',
#  '/housing-local-and-community/land-registration',
#  '/government/publications/civil-service-talent-management/civil-service-talent-management',
#  '/hmrc-internal-manuals/paye-manual/paye61030',
#  '/pay-vat',
#  '/british-national-overseas-bno-visa/print',
#  '/independent-livingfund',
#  '/how-to-register-a-trade-mark',
#  '/foreign-travel-advice/united-arab-emirates/entry-requirements',
#  '/how-to-claim-new-style-jsa',
#  '/new-state-pension/print',
#  '/government/publications/eu-settlement-scheme-introduction-for-community-groups',
#  '/government/publications/conditions-of-acceptance-for-apprenticeship-training-providers',
#  '/government/publications/child-benefit-general-enquiry',
#  '/world/hong-kong',
#  '/government/statistics/announcements/apprenticeships-and-traineeships-august-2021',
#  '/government/organisations/driver-and-vehicle-standards-agency/services-information',
#  '/private-renting/document-checks',
#  '/transfers-takeovers',
#  '/guidance/it-service-manager',
#  '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-self-employed',
#  '/government/publications/covid-19-management-of-exposed-healthcare-workers-and-patients-in-hospital-settings/covid-19-management-of-exposed-healthcare-workers-and-patients-in-hospital-settings',
#  '/browse/childcare-parenting/divorce-separation-legal',
#  '/uk-family-visa',
#  '/support-for-mortgage-interest',
#  '/guidance/reliefs-from-vat-for-disabled-and-older-people-notice-7017',
#  '/dismissal/what-to-do-if-youre-dismissed',
#  '/guidance/building-regulations-and-approved-documents-index',
#  '/child-benefit-for-children-in-hospital-or-care',
#  '/government/publications/entry-clearance-vignettes-ecb09/ecb09-entry-clearance-vignettes-types-safeguarding-and-validity',
#  '/student-visa/knowledge-of-english',
#  '/guidance/personal-food-plant-and-animal-product-imports',
#  '/government/organisations/treasure-valuation-committee',
#  '/blind-persons-allowance/what-youll-get',
#  '/adi-standards-check',
#  '/health-care-worker-visa/knowledge-of-english',
#  '/entering-staying-uk/rights-eu-eea-citizens',
#  '/moving-from-benefits-to-work/starting-your-own-business',
#  '/government/statistics/universal-credit-statistics-29-april-2013-to-10-june-2021',
#  '/benefit-overpayments/repayments-when-someone-has-died',
#  '/guidance/controlled-drugs-recording-using-storing-and-disposal',
#  '/government/publications/standards-for-school-food-in-england',
#  '/government/publications/cwg5-class-1a-national-insurance-contributions-on-benefits-in-kind',
#  '/guidance/coronavirus-covid-19-right-to-work-checks',
#  '/asylum-helplines',
#  '/taxi-driver-licence/inside-london',
#  '/government/collections/medical-devices-guidance-for-manufacturers-on-vigilance',
#  '/dismiss-staff/fair-dismissals',
#  '/representative-overseas-business/family-members',
#  '/government/publications/material-and-workmanship-approved-document-7',
#  '/guidance/employment-status-employment-intermediaries',
#  '/child-benefit/make-a-change-to-your-claim',
#  '/hmrc-internal-manuals/capital-gains-manual/cg10260',
#  '/hmrc-internal-manuals/pensions-tax-manual/ptm052100',
#  '/government/publications/supporting-young-people-to-develop-the-skills-for-apprenticeships-and-sustainable-employment-framework-for-delivery/traineeships-framework-for-delivery-2020-to-2021-web-accessible-version',
#  '/topic/defence-armed-forces/military-awards-commemorations',
#  '/carers-allowance/how-to-claim',
#  '/guidance/united-kingdom-security-vettingreferees-hiring-managers-contractors-and-consultants',
#  '/guidance/immigration-rules/immigration-rules-part-1-leave-to-enter-or-stay-in-the-uk',
#  '/bankruptcy/when-bankruptcy-ends',
#  '/get-help-hmrc-extra-support',
#  '/pacemakers-and-driving',
#  '/government/organisations/department-for-education/about/recruitment',
#  '/government/publications/cyprus-consular-fees',
#  '/dla-disability-living-allowance-benefit',
#  '/maximum-weekly-working-hours',
#  '/government/publications/handling-applications-for-permission-to-take-employment-instruction/permission-to-work-and-volunteering-for-asylum-seekers-accessible-version',
#  '/tax-overpayments-and-underpayments/if-you-owe-tax',
#  '/looking-after-children-divorce/apply-for-court-order',
#  '/government/organisations/national-crime-agency',
#  '/register-as-an-overseas-company',
#  '/parental-rights-responsibilities',
#  '/register-jobs-international-organisations',
#  '/government/collections/tax-avoidance-schemes-currently-in-the-spotlight-number-20-onwards',
#  '/30-hours-free-childcare',
#  '/help/get-emails-about-updates-to-govuk',
#  '/government/publications/register-to-vote-if-youre-living-in-the-uk',
#  '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers',
#  '/topic/intellectual-property/trade-marks',
#  '/right-to-reside',
#  '/discrimination-your-rights',
#  '/government/publications/what-to-do-with-a-passport-when-the-passport-holder-has-died',
#  '/expenses-and-benefits-medical-treatment/whats-exempt',
#  '/registered-traveller',
#  '/types-of-school/print',
#  '/work-health-programme',
#  '/support-for-families-friends-of-prisoners',
#  '/browse/benefits/bereavement',
#  '/holiday-entitlement-rights/taking-holiday-before-leaving-a-job',
#  '/browse/benefits/families',
#  '/guidance/neurological-disorders-assessing-fitness-to-drive',
#  '/foreign-travel-advice/usa/coronavirus',
#  '/government/publications/application-for-asylum-support-form-asf1',
#  '/jobcentre-plus-help-for-recruiters/work-trials',
#  '/browse/driving/drivers-lorries-buses',
#  '/guidance/how-different-circumstances-affect-the-self-employment-income-support-scheme',
#  '/government/collections/overseas-living-in-guides',
#  '/apply-citizenship-born-uk/uk-until-10',
#  '/tax-on-dividends',
#  '/government/publications/applying-to-the-register-of-apprenticeship-training-providers-roatp/applying-to-the-register-of-apprenticeship-training-providers-roatp',
#  '/government/publications/apply-to-extend-your-stay-in-the-uk-form-flrfp',
#  '/government/publications/workplace-health-needs-assessment',
#  '/government/publications/fit-notes-the-collection-of-anonymous-data-in-england',
#  '/disabled-students-allowance-dsa/further-information',
#  '/education/further-education-funding-data',
#  '/search-armed-forces-memorial-roll-of-honour',
#  '/trusts-taxes/beneficiaries-paying-and-reclaiming-tax-on-trusts',
#  '/guidance/living-in-india',
#  '/government/publications/redundancy-support-for-employers/redundancy-factsheet-for-employees',
#  '/government/publications/verify-identity-citizen-id1',
#  '/government/publications/intercountry-adoption-exception-requests',
#  '/government/publications/spending-review-2020-documents/spending-review-2020',
#  '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service',
#  '/government/publications/how-to-rent',
#  '/government/organisations/office-for-students',
#  '/time-off-for-dependants/problems-when-you-take-time-off',
#  '/employment-support-allowance/how-to-claim',
#  '/guidance/visiting-the-uk-as-an-eu-eea-or-swiss-citizen',
#  '/government/publications/self-assessment-commercial-software-suppliers/self-assessment-online-commercial-software-suppliers',
#  '/government/publications/help-and-support-for-young-disabled-people-to-find-and-stay-in-work',
#  '/browse/justice',
#  '/guidance/travel-abroad-from-england-during-coronavirus-covid-19',
#  '/employers-paternity-pay-leave/eligibility',
#  '/1619-bursary-fund/further-information',
#  '/guidance/national-standard-for-driving-cars-and-light-vans-category-b/introduction',
#  '/tax-property-money-shares-you-inherit/print',
#  '/exempt-vignette',
#  '/apply-citizenship-british-parent',
#  '/government/groups/insolvency-service-legal-services-directorate',
#  '/government/publications/child-benefit-claim-form-ch2',
#  '/government/organisations/disclosure-and-barring-service/about/equality-and-diversity',
#  '/renting-out-a-property',
#  '/government/publications/eu-settlement-scheme-application-survey-privacy-information-notice',
#  '/intracompany-transfer-worker-visa/apply-from-outside-the-uk',
#  '/delete-historic-conviction',
#  '/replacement-exam-certificate',
#  '/park-mobile-homes',
#  '/transferring-your-pension/transferring-to-an-overseas-pension-scheme',
#  '/get-a-passport-urgently/1-week-fast-track-service',
#  '/volunteer-as-a-coastguard/how-to-apply',
#  '/working-tax-credit',
#  '/penalties-drug-possession-dealing',
#  '/government/organisations/hm-revenue-customs/contact/status-customer-service-team',
#  '/compensation-road-property-value/who-can-claim',
#  '/government/organisations/defence-safety-authority',
#  '/redundancy-your-rights/get-help-finding-a-new-job',
#  '/government/publications/pay-and-work-rights-complaints',
#  '/guidance/dbs-check-requests-guidance-for-employers',
#  '/government/publications/apply-to-the-eu-settlement-scheme-by-post-or-email',
#  '/government/publications/posting-passports-and-documents',
#  '/government/publications/incorporation-and-names/annex-a-sensitive-words-and-expressions-or-words-that-could-imply-a-connection-with-government',
#  '/faster-decision-visa-settlement',
#  '/government/publications/state-pension-age-periodic-review-report-by-the-government-actuary',
#  '/life-in-the-uk-test',
#  '/apply-for-student-finance/household-income',
#  '/education/becoming-an-intern-or-trainee',
#  '/guidance/apprenticeship-funding-rules-for-training-providers/who-can-be-funded',
#  '/guidance/coronavirus-covid-19-test-to-release-for-international-travel',
#  '/verify-apostille',
#  '/guidance/living-in-cuba',
#  '/vat-registration/cancel-registration',
#  '/visa-to-study-english/eligibility',
#  '/benefit-overpayments/when-repayments-have-to-be-made',
#  '/personal-data-my-employer-can-keep-about-me',
#  '/guidance/how-to-access-your-personal-learning-record',
#  '/biometric-residence-permits/replace-expired-brp',
#  '/get-a-dna-test',
#  '/guidance/24-advanced-learning-loans-an-overview',
#  '/guidance/recruit-teachers-from-overseas',
#  '/child-tax-credit',
#  '/law-on-leaving-your-child-home-alone',
#  '/browse/disabilities',
#  '/guidance/miscellaneous-conditions-assessing-fitness-to-drive',
#  '/guidance/content-design/planning-content',
#  '/expenses-and-benefits-business-travel-mileage',
#  '/foreign-travel-advice/albania',
#  '/rights-disabled-person/police',
#  '/handing-in-your-notice/restrictive-covenants',
#  '/government/publications/winter-fuel-payment-claim-form',
#  '/world/travelling-to-saudi-arabia',
#  '/global-entry-usa',
#  '/government/collections/careers-in-nursing',
#  '/appeal-employment-appeal-tribunal',
#  '/guidance/self-isolating-after-returning-to-the-uk-your-employment-rights',
#  '/check-income-tax-last-year',
#  '/employer-preventing-discrimination/discrimination-during-employment',
#  '/uk-border-control/at-border-control',
#  '/government/publications/new-state-pension-if-youve-been-contracted-out-of-additional-state-pension',
#  '/biometric-residence-permits',
#  '/search/services',
#  '/getting-an-mot/mot-test-fees',
#  '/check-university-award-degree/recognised-awards',
#  '/foreign-travel-advice/slovakia',
#  '/guidance/guidance-for-repayment-customers',
#  '/jobsearch',
#  '/government/publications/global-talent-endorsing-bodies/technical-or-business-skills-covered-by-tech-nation',
#  '/deferring-state-pension',
#  '/giving-staff-time-off-jury-service/paying-staff-on-jury-service',
#  '/guidance/pension-schemes-value-your-pension-for-lifetime-allowance-protection',
#  '/voluntary-national-insurance-contributions/who-can-pay-voluntary-contributions',
#  '/government/publications/universal-credit-housing-queries-routeway/universal-credit-housing-queries-routeway',
#  '/guidance/statutory-sick-pay-manually-calculate-your-employees-payments',
#  '/state-pension/eligibility',
#  '/government/organisations/medicines-and-healthcare-products-regulatory-agency/about/recruitment',
#  '/topic/crime-policing/criminal-record-disclosure',
#  '/government/publications/prevent-duty-toolkit-for-local-authorities-and-partner-agencies',
#  '/rest-breaks-work/compensatory-rest',
#  '/skilled-worker-visa/second-job',
#  '/guidance/qualification-funding-approval',
#  '/guidance/fast-track-apprenticeship-policy',
#  '/if-you-dont-pay-your-tax-bill/debt-collection-agencies',
#  '/sure-start-maternity-grant/what-youll-get',
#  '/courts/crown-court',
#  '/come-uk-married',
#  '/financial-help-disabled/vat-relief',
#  '/types-of-british-nationality/british-citizenship',
#  '/guidance/paying-employees-cash-in-hand-or-guaranteed-take-home-pay',
#  '/government/publications/claim-for-loss-of-notice-factsheet-rp2',
#  '/working-tax-credit/further-information',
#  '/voluntary-national-insurance-contributions',
#  '/foreign-travel-advice/taiwan/print',
#  '/guidance/recovery-loan-scheme',
#  '/global-health-insurance-card',
#  '/guidance/check-if-a-new-charity-is-the-best-option',
#  '/government/collections/local-government-pensions',
#  '/dispose-hazardous-waste/carriers',
#  '/government/publications/health-matters-health-and-work/health-matters-health-and-work',
#  '/additional-state-pension/you-get-divorced',
#  '/government/publications/rates-and-allowances-tax-credits-child-benefit-and-guardians-allowance/tax-credits-child-benefit-and-guardians-allowance',
#  '/settlement-refugee-or-humanitarian-protection/family-reunion',
#  '/employment-contracts-and-conditions',
#  '/government/collections/armed-forces-covenant-supporting-information',
#  '/government/publications/national-security-vetting-advice-for-people-who-are-being-vetted',
#  '/foreign-travel-advice/poland/coronavirus',
#  '/education/functional-skills',
#  '/browse/citizenship/citizenship',
#  '/government/publications/advice-individualised-learner-record-ilr-returns',
#  '/government/organisations/maritime-and-coastguard-agency/services-information',
#  '/pay-paye-tax',
#  '/tax-relief-for-employees/buying-other-equipment',
#  '/trusts-taxes',
#  '/foreign-travel-advice/afghanistan',
#  '/biometric-residence-permits/report-problem',
#  '/lay-offs-short-timeworking/extra-work-or-claiming-benefits',
#  '/foreign-travel-advice/romania',
#  '/mandatory-reconsideration/how-to-ask-for-mandatory-reconsideration',
#  '/mental-health-tribunal-victim-representations',
#  '/government/collections/ly2-the-large-yacht-code',
#  '/cymraeg',
#  '/funeral-payments',
#  '/guidance/statutory-recognition-guide-for-the-parties-on-parts-iv-and-v-of-schedule-a1',
#  '/government/publications/apprenticeships-off-the-job-training',
#  '/report-unfit-work-children-vulnerable-adults',
#  '/agricultural-sick-pay/further-information',
#  '/employers-liability-insurance',
#  '/guidance/how-to-make-changes-to-your-charitys-governing-document',
#  '/government/publications/statutory-payments-and-national-insurance-contributions-late-claim-sp32',
#  '/government/publications/fe-funding-initial-teacher-education-ite-academic-year-2020-to-2021',
#  '/foreign-travel-advice',
#  '/claim-tax-refund',
#  '/government/publications/safeguarding-children-and-protecting-professionals-in-early-years-settings-online-safety-considerations',
#  '/government/publications/train-to-teach-in-england-non-uk-applicants/train-to-teach-in-england-non-uk-applicants',
#  '/government/publications/armed-forces-pension-scheme-1975-regulations',
#  '/book-driving-test',
#  '/government/organisations/medicines-and-healthcare-products-regulatory-agency',
#  '/health-and-social-care/disabilities-rights',
#  '/what-different-qualification-levels-mean/print',
#  '/guidance/united-kingdom-security-vetting-existing-clearance-holders',
#  '/jury-service/what-you-can-claim-if-youre-self-employed',
#  '/government/publications/british-forces-post-office-locations',
#  '/employer-reporting-expenses-benefits/dispensations',
#  '/government/publications/non-disclosure-agreements',
#  ...}

# %%
len(results["pages_visited"])
# Out:
# 5702

# %%
len(results['paths_taken'])
# Out:
# 3

# %%
page_scores['ER'] = page_scores.pagePath.isin(er_pages)
colour = (page_scores.ER == True).map({True: 'background-color: black', False: ''})
# Comment out so that later cells run ok
# otherwise "Styling" causes errors
# page_scores = page_scores.style.apply(lambda s: colour)

# %% [markdown]
# ## Add columns to output
#
# Add additional information to csv output:
# - document type
# - document super type
# - number of sessions that visit this page
# - number of sessions where this page is an entrance hit
# - number of sessions where this page is an exit hit
# - number of sessions where this page is both an entrance and exit hit
# - how frequent the page occurs in the whole user journey

# %%
# create a df with `pagePath`: `documentType`, `sessionHitsAll`, `entranceHit`, `exitHit`, `entranceAndExitHit`
df_dict = {info['properties']['name']: [info['documentType'], info['sessionHitsAll'], info['entranceHit'], info['exitHit'], info['entranceAndExitHit']] for node, info in G.nodes(data=True)}
df_dict = {k:v for (k,v) in df_dict.items() if k in page_scores['pagePath'].tolist()}
df_info = pd.DataFrame.from_dict(df_dict, orient='index', columns=['documentType', 'sessionHitsAll', 'entranceHit', 'exitHit', 'entranceAndExitHit']).rename_axis('pagePath').reset_index()

# %%
# create a df with document supertypes
news_and_comms_doctypes = {'medical_safety_alert', 'drug_safety_update', 'news_article', 
                           'news_story', 'press_release', 'world_location_news_article', 
                           'world_news_story', 'fatality_notice', 'fatality_notice', 
                           'tax_tribunal_decision', 'utaac_decision', 'asylum_support_decision', 
                           'employment_appeal_tribunal_decision', 'employment_tribunal_decision', 
                           'employment_tribunal_decision', 'service_standard_report', 'cma_case', 
                           'decision', 'oral_statement', 'written_statement', 'authored_article', 
                           'correspondence', 'speech', 'government_response', 'case_study' 
}

service_doctypes = {'completed_transaction', 'local_transaction', 'form', 'calculator',
                    'smart_answer', 'simple_smart_answer', 'place', 'licence', 'step_by_step_nav', 
                    'transaction', 'answer', 'guide'
}

guidance_and_reg_doctypes = {'regulation', 'detailed_guide', 'manual', 'manual_section',
                             'guidance', 'map', 'calendar', 'statutory_guidance', 'notice',
                             'international_treaty', 'travel_advice', 'promotional', 
                             'international_development_fund', 'countryside_stewardship_grant',
                             'esi_fund', 'business_finance_support_scheme', 'statutory_instrument',
                             'hmrc_manual', 'standard'
}

policy_and_engage_doctypes = {'impact_assessment', 'policy_paper', 'open_consultation',
                              'policy_paper', 'closed_consultation', 'consultation_outcome',
                              'policy_and_engagement'  
}

research_and_stats_doctypes = {'dfid_research_output', 'independent_report', 'research', 
                               'statistics', 'national_statistics', 'statistics_announcement',
                               'national_statistics_announcement', 'official_statistics_announcement',
                               'statistical_data_set', 'official_statistics'
}

transparency_doctypes = {'transparency', 'corporate_report', 'foi_release', 'aaib_report',
                         'raib_report', 'maib_report'
}

document_type_dict = dict.fromkeys(list(set(df_info['documentType'])))

for docType, docSupertype in document_type_dict.items():
    if docType in news_and_comms_doctypes: 
        document_type_dict[docType] = 'news and communication'
    
    elif docType in service_doctypes:
        document_type_dict[docType] = 'services'
    
    elif docType in guidance_and_reg_doctypes:
        document_type_dict[docType] = 'guidance and regulation'
 
    elif docType in policy_and_engage_doctypes:
        document_type_dict[docType] = 'policy and engagement'
    
    elif docType in research_and_stats_doctypes:
        document_type_dict[docType] = 'research and statistics'
    
    elif docType in transparency_doctypes:
        document_type_dict[docType] = 'transparency'
    
    else: 
        document_type_dict[docType] = 'other' 

df_docSuper = pd.DataFrame(document_type_dict.items(), columns=['documentType', 'documentSupertype'])

# %%
# merge dfs 
df_merged = pd.merge(page_scores, df_info, on='pagePath')
df_merged = pd.merge(df_merged, df_docSuper, how='left')

# %%
# reoder and rename df columns 
df_merged = df_merged[['pagePath', 'documentType', 'documentSupertype', 'sessionHitsAll', 'entranceHit', 'exitHit', 'entranceAndExitHit', 'tfdf_max']]
# df_merged = df_merged.rename(columns={'pagePath': 'page path', 'documentType': 'document type', 'documentSupertype': 'document supertype', 'sessionHitsAll': 'number of sessions that visit this page', 'entranceHit': 'number of sessions where this page is an entrance hit', 'exitHit': 'number of sessions where this page is an exit hit', 'entranceAndExitHit': 'number of sessions where this page is both an entrance and exit hit', 'tfdf_max': 'how frequent the page occurs in the whole user journey'})
# DO NOT RENAME THE TDX_MAX COLUMN
df_merged = df_merged.rename(columns={'pagePath': 'page path', 'documentType': 'document type', 'documentSupertype': 'document supertype', 'sessionHitsAll': 'number of sessions that visit this page', 'entranceHit': 'number of sessions where this page is an entrance hit', 'exitHit': 'number of sessions where this page is an exit hit', 'entranceAndExitHit': 'number of sessions where this page is both an entrance and exit hit'})


# save df
df_merged.to_csv('./data/outputs/pages_ranked_with_data_replication.csv', index=False)

# %%
df_merged
# Out:
#                                               page path  \
# 0                                           /search/all
# 1                                                     /
# 2                                           /find-a-job
# 3                                       /browse/working
# 4                                     /universal-credit
# ...                                                 ...
# 5697  /government/collections/des-engineering-manage...
# 5698  /guidance/check-if-a-new-charity-is-the-best-o...
# 5699                   /topic/work-careers/trade-unions
# 5700          /guidance/changes-to-employment-allowance
# 5701                /government/collections/dart-charge
#
#                document type       document supertype  \
# 0                     finder                    other
# 1                   homepage                    other
# 2                transaction                 services
# 3     mainstream_browse_page                    other
# 4                      guide                 services
# ...                      ...                      ...
# 5697     document_collection                    other
# 5698          detailed_guide  guidance and regulation
# 5699                   topic                    other
# 5700          detailed_guide  guidance and regulation
# 5701     document_collection                    other
#
#       number of sessions that visit this page  \
# 0                                       18787
# 1                                       39089
# 2                                       71667
# 3                                       15967
# 4                                        4140
# ...                                       ...
# 5697                                       10
# 5698                                        1
# 5699                                       16
# 5700                                        1
# 5701                                        2
#
#       number of sessions where this page is an entrance hit  \
# 0                                                  1081
# 1                                                  1899
# 2                                                 18532
# 3                                                   312
# 4                                                   217
# ...                                                 ...
# 5697                                                  3
# 5698                                                  0
# 5699                                                  3
# 5700                                                  0
# 5701                                                  0
#
#       number of sessions where this page is an exit hit  \
# 0                                                   572
# 1                                                 25618
# 2                                                  4157
# 3                                                   951
# 4                                                  1076
# ...                                                 ...
# 5697                                                  1
# 5698                                                  0
# 5699                                                  0
# 5700                                                  1
# 5701                                                  1
#
#       number of sessions where this page is both an entrance and exit hit  \
# 0                                                    23
# 1                                                  1580
# 2                                                 44191
# 3                                                    84
# 4                                                    24
# ...                                                 ...
# 5697                                                  0
# 5698                                                  0
# 5699                                                  0
# 5700                                                  0
# 5701                                                  0
#
#       tfdf_max
# 0        263.0
# 1        247.0
# 2        204.0
# 3        179.0
# 4        153.0
# ...        ...
# 5697       1.0
# 5698       1.0
# 5699       1.0
# 5700       1.0
# 5701       1.0
#
# [5702 rows x 8 columns]
