# %% [markdown]
# **Replication of** `page_view_approach_economic_recovery.ipynb`
#
# **Produces ranking based on the shortest path to (two) seed pages and degree centrality**

# %% [markdown]
# # Exploring the economic recovery whole user journey subgraph

# %% [markdown]
# This approach does not rely on the existing knowledge graph. It uses a functional graph based on page hit session data, to find a list of pages related to the economic recovery whole user journey (WUJ).
#
# ASSUMPTIONS:
# - A set of pre-defined pages have been removed from the economic recovery WUJ subgraph
# - Any pages with less than 10 session hits are removed from the economic recovery WUJ subgraph
# - Any pages with a shortest page path length equal to or greater than 3 from both `seed0` pages are removed from the economic recovery WUJ subgraph
# - Any pages where accumulated edge weight is equal to or lower than 20 are removed from the economic recovery WUJ subgraph
# - Any browse pages not related to the economic recovery WUJ are manually removed from the economic recovery WUJ subgraph
#
# OUTPUT:
# - A csv containing a list of pages related to the economic recovery WUJ. Sorted in ascending order in relation to a composite metric made up of: shortest page path from both `seed0` pages, and degree centrality.
#   - Additional columns to filter on are included: `document type`, `document supertype`, `number of sessions that visit this page`, `number of sessions where this page is an entrance hit`, `number of sessions where this page is an exit hit`, `distance from /browse/working/finding-job`, `distance from /topic/further-education-skills/apprenticeships`, `the number of pages a user moves to/from between this page and another page in the list`
#
# REQUIREMENTS:
# - Create the functional network by running `page_detector.ipynb`. Save `G` as a pickle file in `../../data/processed/functional_session_hit_directed_graph_er.gpickle`

# %% [markdown]
# ## Import statements

# %%
import os
from collections import Counter, defaultdict
from operator import itemgetter

# import gspread
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
from neo4j import GraphDatabase
from oauth2client.service_account import ServiceAccountCredentials
from tqdm.notebook import tqdm

# %% [markdown]
# ## Functions for coercing knowledge graph into NetworkX

# %%
def getSubgraph(q, parameters=None):

    '''
    Given a Cypher query q, this function queries the knowledge graph,
    returns the nodes and edges from this query, and uses them to construct
    a networkx graph.

    E.g. getSubgraph(r'MATCH (u:Cid)-[r:HYPERLINKS_TO]->(v:Cid) RETURN *')
         returns the structural graph.

    Optionally, can add in parameters (dictionary), allowing Python variables
    to be integrated into the Cypher query q.

    E.g.
        parameters = {}
        parameters['pages'] = ['a','list','of','stuff']
        q7 = f"""
        MATCH (u:Cid)-[r]-(v:Cid)
        WHERE u.name IN $pages AND v.name in $pages
        RETURN *
        """

        g7 = getSubgraph(q7, parameters)
    '''

    # get credentials
    # add to .secrets: export KG_PWD="<PASSWORD>"
    KG_PWD = os.getenv("KG_PWD")

    # create connection to knowledge graph
    driver = GraphDatabase.driver(
        "bolt+s://knowledge-graph.integration.govuk.digital:7687",
        auth=("neo4j", KG_PWD),
    )

    # run query on knowledge graph
    results = driver.session().run(q, parameters)

    # create networkx graph object
    G = nx.MultiDiGraph()

    # add nodes into networkx graph object
    nodes = list(results.graph()._nodes.values())
    print("Adding nodes\n")
    for node in tqdm(nodes):
        G.add_node(node.id, labels=node._labels, properties=node._properties)

    # add edges into networkx graph object
    rels = list(results.graph()._relationships.values())
    print("Adding edges\n")
    for rel in tqdm(rels):
        G.add_edge(
            rel.start_node.id,
            rel.end_node.id,
            key=rel.id,
            type=rel.type,
            properties=rel._properties,
        )

    return G


def showGraph(g):
    """
    Given a networkx graph g, this function visualises the graph.
    Do not use for a large g.
    """
    print(nx.info(g))
    nx.draw(g)

# %%
def getNoOfTruePages(g, economic_pages):
    """
    Calculate a proxy recall metric for the list of pages identified in a
    subgraph (when compared to the ground truth for the economic recovery pages).
    The output is the number of pages in the subgraph list that are present in
    the ground truth list.
    """

    # convert nodeIds to page path slug for the subgraph list
    subgraph_list = [node[0] for node in g.nodes(data=True)]

    # set up the ground truth list
    true_list = list(economic_pages)

    # how many pages are in the subgraph list that are also in the ground truth list
    return (len(true_list)) - (
        len([node for node in true_list if node not in subgraph_list])
    )

# %%
def getPagesNotInSubGraph(g):
    """
    Return a set of pages which are in the economic recovery pre-defined list
    (41 in total), but are not in the filtered subgraph list.
    """

    # list of pages manually defined in the economic recovery whole user journey
    true_list = list(economic_pages)

    # list of pages in the filtered subgraph list
    subgraph_list = [node[0] for node in g.nodes(data=True)]

    # the list of pages in the manually defined list not in the subgraph list
    return [node for node in true_list if node not in subgraph_list]

# %% [markdown]
# ## Pre-defined economic recovery subgraph

# %% [markdown]
# The pages (nodes) in the manually defined list for economic recovery (41 pages in total)

# %%
# Load worksheet of seed pages
er_seed_pages_ws = pd.read_excel("../data/inputs/2021-11-12 - Economic recovery pages.xlsx", sheet_name="Top pages")
er_seed_pages_ws.shape
# Out:
# (47, 2)

# %%
er_seed_pages_table = er_seed_pages_ws.values.reshape(-1, 1)
er_seed_pages_table.shape
# Out:
# (94, 1)

# %%
economics_pages_df = pd.DataFrame(er_seed_pages_table).dropna()

# %% [markdown]
# ## Exploring the economic recovery functional network

# %% [markdown]
# - 10631 nodes and 79985 edges
# - The page `/guidance/international-trade-products-and-schemes` which is in the manually defined graph, is **not** in this subgraph. This seems to be an old page (updated 2013) related to exporting agricultural products to the EU
# - The distribution of session hit data demonstrates that only 25% of the page paths have session hits over 8. The maximum number of session hit for a page path is 71667:
#     - Min: 1
#     - Max: 71667
#     - 25th percentile: 1
#     - 50th percentile: 2
#     - 75th percentile: 8

# %%
# import the NetworkX graph object
g = nx.read_gpickle(
#     "../../data/processed/functional_session_hit_directed_graph_er.gpickle"
    "../data/inputs/functional_session_hit_directed_graph_er.gpickle"
)

# number of nodes, number of edges
nx.info(g)
# Out:
# C:\Users\jbryb\AppData\Local\Temp\ipykernel_2912\3619587734.py:8: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(g)
# 'DiGraph with 10631 nodes and 79985 edges'

# %%
# how many of the 'true' economic recovery pages are in the functional graph?
economic_pages = economics_pages_df.values.reshape(-1,).tolist()

getNoOfTruePages(g, economic_pages)
# Out:
# 88

# %%
# which pages are in the economic recovery list but not in the subgraph list?
true_list = list(economic_pages)
subgraph_list = [node[0] for node in g.nodes(data=True)]
[node for node in true_list if node not in subgraph_list]
# Out:
# ['/guidance/international-trade-products-and-schemes',
#  '/guidance/international-trade-products-and-schemes',
#  '/campaigns/internationalisation-fund-for-english-businesses/']

# %%
# list of nodes
nodes_list = list(g.nodes(data=True))

# %% [markdown]
# ### Remove pages where edge weight is <= 20

# %% [markdown]
# Edge weight increases by 1 each time a user session visits page A to page B. Therefore, if edge weight is small, we assume the two pages are likely to not be associated with one another. This is because we assume that user's will visit similar pages in the same WUJ during the same session.
#
# Edge weight is equal to or less than 10:
# - 1473 nodes
# - 37/41
# - Pages not in the subgraph list: [`/guidance/recovery-loan-scheme`,
# `/find-driving-instructor-training`,
# `/guidance/international-trade-products-and-schemes`,
# `/how-to-claim-universal-credit`]
#
# Edge weight is equal to or less than 20:
# - 1253 nodes
# - 34/41
# - Pages not in the subgraph list: [`/guidance/international-trade-products-and-schemes`,
#  `/guidance/recovery-loan-scheme`,
#  `/find-driving-instructor-training`,
#  `/how-to-claim-universal-credit`,
#  `/government/collections/financial-support-for-businesses-during-coronavirus-covid-19`,
#  `/agricultural-skills-and-training`,
#  `/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19`]
#
# Edge weight is equal to or less than 30:
# - 1042 nodes
# - 32/41
# - Pages not in the subgraph list: [`/guidance/international-trade-products-and-schemes`,
#  `/guidance/recovery-loan-scheme`,
#  `/find-driving-instructor-training`,
#  `/how-to-claim-universal-credit`,
#  `/government/collections/financial-support-for-businesses-during-coronavirus-covid-19`,
#  `/agricultural-skills-and-training`,
#  `/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19`]

# %% [markdown]
# ### Save the subgraph list of pages that are related to the economic recovery whole user journey

# %% [markdown]
# From the above exploration, run this code to get a final subgraph related to the economic recovery whole user journey

# %%
# import the NetworkX graph object
g = nx.read_gpickle(
    "../data/inputs/functional_session_hit_directed_graph_er.gpickle"
)

# %%
nx.info(g)
# Out:
# C:\Users\jbryb\AppData\Local\Temp\ipykernel_2912\3034883828.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(g)
# 'DiGraph with 10631 nodes and 79985 edges'

# %%
# remove irrelevant nodes
g.remove_nodes_from(
    [
        "/prove-right-to-work",
        "/",
        "/request-copy-criminal-record",
        "/browse/working/state-pension",
        "/search/all",
        "/search",
        "/brexit",
        "/coronavirus",
        "/report-covid19-result",
    ]
)

# %%
nx.info(g)
# Out:
# C:\Users\jbryb\AppData\Local\Temp\ipykernel_2912\3034883828.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(g)
# 'DiGraph with 10622 nodes and 67524 edges'

# %%
# remove pages with equal or less than 10 session hits
remove = [
    node for node, session in g.nodes(data=True) if session["sessionHitsAll"] <= 10
]
g.remove_nodes_from(remove)

# %%
# remove pages where they have a shortest page path length on >= 3 from both `seed0` pages
shortest_paths_seed0_1 = nx.shortest_path_length(
    g, source="/browse/working/finding-job"
)
shortest_paths_seed0_2 = nx.shortest_path_length(
    g, source="/topic/further-education-skills/apprenticeships"
)

finding_job = {
    k: v
    for k, v in sorted(
        shortest_paths_seed0_1.items(), key=lambda item: item[1], reverse=True
    )
}
apprentice = {
    k: v
    for k, v in sorted(
        shortest_paths_seed0_2.items(), key=lambda item: item[1], reverse=True
    )
}

finding_job_filtered = [node for node, length in finding_job.items() if length >= 3]
apprentice_filtered = [node for node, length in apprentice.items() if length >= 3]

remove = [node for node in finding_job_filtered if node not in apprentice_filtered]
g.remove_nodes_from(remove)

# %%
# remove pages where accumulated edge weight is equal to or lower than 20
user_movement_weights = []
for node1, node2, edgeWeight in g.edges(data=True):
    case = {"node1": node1, "node2": node2, "edgeWeight": edgeWeight["edgeWeight"]}
    user_movement_weights.append(case)

user_movements_sum = defaultdict(float)

for info in user_movement_weights:
    user_movements_sum[info["node1"]] += info["edgeWeight"]

user_movements_sum = [
    {"node1": node1, "edgeWeight": user_movements_sum[node1]}
    for node1 in user_movements_sum
]

remove = [node["node1"] for node in user_movements_sum if node["edgeWeight"] <= 20]
g.remove_nodes_from(remove)

# %%
# remove certain browse pages. Browse pages seem to score highly (when ranking, below),
# regardless of whether they are relevant to the WUJ or not
browse_pages_remove = (
    "/browse/employing-people",
    "/browse/births-deaths-marriages",
    "/browse/citizenship",
    "/browse/driving",
    "/browse/education",
    "/browse/business",
    "/browse/childcare-parenting",
    "/browse/justice",
    "/browse/abroad",
    "/browse/tax",
    "/browse/visas-immigration",
    "/browse/disabilities",
    "/browse/environment-countryside",
    "/browse/housing-local-services",
    "/browse/employing-people",
    "/browse/births-deaths-marriages",
    "/browse/citizenship",
    "/browse/driving",
    "/browse/business",
    "/browse/abroad",
    "/browse/environment-countryside",
    "/browse/housing-local-services",
    "/browse/benefits",
)

g.remove_nodes_from(browse_pages_remove)

# %%
nx.info(g)
# Out:
# C:\Users\jbryb\AppData\Local\Temp\ipykernel_2912\3034883828.py:1: DeprecationWarning: info is deprecated and will be removed in version 3.0.
#
#   nx.info(g)
# 'DiGraph with 1184 nodes and 28848 edges'

# %%
# how many of economic recovery pages are in the functional graph?
getNoOfTruePages(g, economic_pages)
# Out:
# 73

# %%
# which pages are in the economic recovery list but not in the subgraph list?
getPagesNotInSubGraph(g)
# Out:
# ['/government/collections/financial-support-for-businesses-during-coronavirus-covid-19',
#  '/government/collections/financial-support-for-businesses-during-coronavirus-covid-19',
#  '/guidance/international-trade-products-and-schemes',
#  '/guidance/international-trade-products-and-schemes',
#  '/campaigns/internationalisation-fund-for-english-businesses/',
#  '/guidance/recovery-loan-scheme',
#  '/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19',
#  '/guidance/recovery-loan-scheme',
#  '/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19',
#  '/how-to-claim-universal-credit',
#  '/how-to-claim-universal-credit',
#  '/browse/education',
#  '/browse/education',
#  '/agricultural-skills-and-training',
#  '/education/further-and-higher-education-courses-and-qualifications',
#  '/agricultural-skills-and-training',
#  '/find-driving-instructor-training',
#  '/find-driving-instructor-training']

# %%
# final subgraph list related to the economic recovery whole user journey
economic_recovery_subgraph = list(g.nodes(data=True))

# %%
# save subgraph to file
# nx.write_gpickle(
#     g, "../../data/processed/functional_session_hit_directed_graph_er_final.gpickle"
# )

# %% [markdown]
# ### Explore communities of the subgraph

# %% [markdown]
# Look at adjacent neighbours, to identify communities within the WUJ. While there seems to be relevant pages within a community (e.g. `/find-a-job` and `/contact-jobcentre-plus`), other pages seem to be irrelevant (e.g. `/find-a-job` and `/check-mot-status`)

# %%
# create a dict of all nodes and it's edges
dict_of_nodes_and_edges = dict()
for node in g.nodes():
    dict_of_nodes_and_edges[node] = list(nx.neighbors(g, node))

    # sort dict based on the length of its' values (i.e. top result is the largest number of neighbours)
sorted(dict_of_nodes_and_edges.items(), key=lambda x: len(x[1]), reverse=True)
# Out:
# [('/find-a-job',
#   ['/sign-in-universal-credit',
#    '/browse/working/finding-job',
#    '/advertise-job',
#    '/contact-jobcentre-plus',
#    '/universal-credit',
#    '/apply-apprenticeship',
#    '/jobseekers-allowance',
#    '/browse/working',
#    '/browse/benefits/looking-for-work',
#    '/coronavirus/worker-support',
#    '/government/organisations/department-for-work-pensions',
#    '/government/organisations/department-for-work-pensions/about/recruitment',
#    '/find-internship',
#    '/chwilio-am-swydd',
#    '/national-minimum-wage-rates',
#    '/guidance/free-courses-for-jobs',
#    '/personal-tax-account',
#    '/log-in-register-hmrc-online-services',
#    '/skilled-worker-visa',
#    '/government/organisations/hm-revenue-customs/about/recruitment',
#    '/find-traineeship',
#    '/government/collections/kickstart-scheme',
#    '/benefits-calculators',
#    '/find-coronavirus-support',
#    '/check-mot-history',
#    '/government/organisations/hm-revenue-customs',
#    '/government/organisations',
#    '/employment/finding-job',
#    '/jobseekers-allowance/eligibility',
#    '/jobseekers-allowance/your-jsa-claim',
#    '/government/publications/register-of-licensed-sponsors-workers',
#    '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes',
#    '/government/organisations/companies-house',
#    '/estimate-income-tax',
#    '/book-theory-test',
#    '/guidance/red-amber-and-green-list-rules-for-entering-england',
#    '/help',
#    '/travel-abroad',
#    '/topic/further-education-skills/apprenticeships',
#    '/student-finance-register-login',
#    '/universal-credit/what-youll-get',
#    '/government/publications/the-national-minimum-wage-in-2021',
#    '/jobseekers-allowance/report-a-change-of-circumstances',
#    '/guidance/apply-for-a-kickstart-scheme-grant',
#    '/browse/visas-immigration/work-visas',
#    '/guidance/universal-credit-advances',
#    '/apply-first-provisional-driving-licence',
#    '/moving-from-benefits-to-work',
#    '/become-apprentice',
#    '/career-skills-and-training',
#    '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers',
#    '/guidance/immigration-rules',
#    '/contact-jobcentre-plus/new-benefit-claims',
#    '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations',
#    '/jobcentre-plus-help-for-recruiters',
#    '/order-coronavirus-rapid-lateral-flow-tests',
#    '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do',
#    '/check-mot-status',
#    '/change-driving-test',
#    '/jobseekers-allowance/apply-new-style-jsa',
#    '/government/organisations/uk-visas-and-immigration',
#    '/apply-national-insurance-number',
#    '/check-uk-visa',
#    '/view-driving-licence',
#    '/provide-journey-contact-details-before-travel-uk',
#    '/check-vehicle-tax',
#    '/apply-universal-credit',
#    '/universal-credit/how-your-earnings-affect-your-payments',
#    '/vehicle-tax',
#    '/find-local-council',
#    '/dbs-update-service',
#    '/view-prove-immigration-status',
#    '/manage-your-tax-credits',
#    '/pip',
#    '/guidance/redundancy-help-finding-work-and-claiming-benefits',
#    '/looking-for-work-if-disabled',
#    '/intensive-personalised-employment-support',
#    '/book-driving-test',
#    '/topic/work-careers/government-graduate-schemes',
#    '/lost-national-insurance-number',
#    '/government/publications/skilled-worker-visa-shortage-occupations',
#    '/employment-support-allowance',
#    '/universal-credit/other-financial-support',
#    '/council-tax-bands',
#    '/government/organisations/home-office',
#    '/benefit-cap',
#    '/carers-allowance',
#    '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme',
#    '/contact-jobcentre-plus/existing-benefit-claims',
#    '/register-to-vote',
#    '/search/services',
#    '/government/organisations/home-office/about/recruitment',
#    '/government/organisations/foreign-commonwealth-development-office',
#    '/contact-jobcentre-plus/change-cancel-appointment',
#    '/government/organisations/driver-and-vehicle-licensing-agency',
#    '/get-coronavirus-test',
#    '/universal-credit/contact-universal-credit',
#    '/government/organisations/disclosure-and-barring-service',
#    '/tax-credits-calculator',
#    '/apply-renew-passport',
#    '/check-state-pension',
#    '/work-health-programme',
#    '/pension-credit',
#    '/pip/how-to-claim',
#    '/uk-visa-sponsorship-employers',
#    '/income-tax-rates',
#    '/government/publications/higher-and-degree-apprenticeships',
#    '/government/get-involved/take-part/volunteer',
#    '/contact-ukvi-inside-outside-uk',
#    '/minimum-wage-different-types-work/paid-an-annual-salary',
#    '/check-income-tax-current-year',
#    '/employment-support-allowance/how-to-claim',
#    '/apply-to-come-to-the-uk',
#    '/government/organisations/department-for-education',
#    '/mature-student-university-funding',
#    '/child-employment',
#    '/contact-the-dvla',
#    '/settled-status-eu-citizens-families',
#    '/health-care-worker-visa',
#    '/further-education-courses/financial-help',
#    '/government/publications/test-and-trace-support-payment-scheme-claiming-financial-support/claiming-financial-support-under-the-test-and-trace-support-payment-scheme',
#    '/universal-credit/eligibility',
#    '/government/organisations/hm-revenue-customs/contact/national-insurance-numbers',
#    '/state-pension-age',
#    '/exchange-foreign-driving-licence',
#    '/council-housing',
#    '/access-to-work',
#    '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means',
#    '/british-national-overseas-bno-visa',
#    '/government/collections/helping-young-people-into-work',
#    '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers',
#    '/foreign-travel-advice',
#    '/log-in-hmrc-excise-import-export',
#    '/bank-holidays',
#    '/government/topical-events/plan-for-jobs',
#    '/renew-adult-passport',
#    '/find-postgraduate-teacher-training-courses',
#    '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees',
#    '/skilled-worker-visa/your-job',
#    '/budgeting-help-benefits/how-to-apply',
#    '/housing-benefit/what-youll-get',
#    '/access-to-work/eligibility',
#    '/guidance/immigration-rules/immigration-rules-appendix-shortage-occupation-list',
#    '/universal-credit/how-to-claim',
#    '/moving-from-benefits-to-work/job-search-programmes',
#    '/browse/abroad/passports',
#    '/working-for-yourself',
#    '/set-up-sole-trader',
#    '/government/publications/jobseekers-allowance-sanctions-leaflet/jobseekers-allowance-sanctions-how-to-keep-your-benefit-payment',
#    '/how-to-claim-new-style-jsa',
#    '/moving-from-benefits-to-work/starting-your-own-business',
#    '/contact-hmrc',
#    '/guidance/new-immigration-system-what-you-need-to-know',
#    '/further-education-courses/find-a-course',
#    '/get-information-about-a-company',
#    '/carers-allowance/effect-on-other-benefits',
#    '/get-help-savings-low-income',
#    '/uk-border-control',
#    '/report-benefits-change-circumstances',
#    '/search/research-and-statistics',
#    '/government/collections/new-enterprise-allowance-campaign',
#    '/government/organisations/foreign-commonwealth-office',
#    '/browse/working/contract-working-hours',
#    '/advanced-learner-loan',
#    '/browse/employing-people/contracts',
#    '/browse/benefits/manage-your-benefit',
#    '/student-jobs-paying-tax',
#    '/order-copy-birth-death-marriage-certificate',
#    '/guidance/track-a-dbs-application',
#    '/guidance/national-skills-fund',
#    '/browse/business/setting-up',
#    '/carers-allowance/how-to-claim',
#    '/standard-visitor-visa/apply',
#    '/income-tax',
#    '/pip/what-youll-get',
#    '/housing-and-universal-credit/renting-from-private-landlord',
#    '/personal-tax-account/sign-in/prove-identity',
#    '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults',
#    '/sign-in-help-to-save',
#    '/search/news-and-communications',
#    '/rest-breaks-work',
#    '/claim-tax-refund',
#    '/settle-in-the-uk',
#    '/government/collections/traineeships--2',
#    '/browse/employing-people/recruiting-hiring',
#    '/student-finance',
#    '/employee-immigration-employment-status',
#    '/set-up-business',
#    '/log-in-register-hmrc-online-services/register',
#    '/self-employment-and-universal-credit',
#    '/pip/change-of-circumstances',
#    '/skilled-worker-visa/how-much-it-costs',
#    '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403',
#    '/calculate-your-redundancy-pay',
#    '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022',
#    '/new-state-pension/what-youll-get',
#    '/sign-in-childcare-account',
#    '/government/publications/find-a-free-level-3-qualification/list-of-colleges-and-training-providers-able-to-offer-free-places-for-level-3-qualifications',
#    '/employment-rights-for-interns',
#    '/employment-support-allowance/eligibility',
#    '/government/organisations/hm-revenue-customs/contact',
#    '/renew-driving-licence',
#    '/national-minimum-wage',
#    '/check-job-applicant-right-to-work',
#    '/higher-education-courses-find-and-apply',
#    '/working-tax-credit',
#    '/bills-benefits',
#    '/am-i-getting-minimum-wage',
#    '/job-offers-your-rights',
#    '/courses-qualifications',
#    '/budgeting-help-benefits/eligibility',
#    '/paye-forms-p45-p60-p11d/p60',
#    '/sunday-working',
#    '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant',
#    '/skilled-worker-visa/when-you-can-be-paid-less',
#    '/guidance/how-to-quarantine-when-you-arrive-in-england',
#    '/government/collections/desg-graduate-scheme',
#    '/find-pension-centre',
#    '/employment-support-allowance/working-while-you-claim',
#    '/biometric-residence-permits/report-problem',
#    '/browse/visas-immigration/commonwealth-british-nationals-overseas',
#    '/uk-visa-sponsorship-employers/eligibility',
#    '/recruit-apprentice',
#    '/dla-disability-living-allowance-benefit',
#    '/browse/education/universities-higher-education',
#    '/government/organisations/hm-revenue-customs/contact/child-benefit',
#    '/student-finance/who-qualifies',
#    '/find-lost-utr-number',
#    '/guidance/contact-the-department-for-work-and-pensions-about-its-policies',
#    '/national-insurance-credits/eligibility',
#    '/carers-credit/eligibility',
#    '/health-care-worker-visa/your-job',
#    '/moving-or-retiring-abroad',
#    '/paye-forms-p45-p60-p11d',
#    '/id-for-driving-licence',
#    '/national-insurance/how-much-you-pay',
#    '/uk-family-visa/partner-spouse',
#    '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member',
#    '/uk-family-visa',
#    '/guidance/recruiting-people-from-outside-the-uk',
#    '/budgeting-help-benefits',
#    '/start-up-visa',
#    '/international-agreement-worker-visa',
#    '/national-insurance',
#    '/fixed-term-contracts',
#    '/what-different-qualification-levels-mean/list-of-qualification-levels',
#    '/guidance/new-style-jobseekers-allowance',
#    '/browse/disabilities/work',
#    '/employment-support-allowance/your-esa-claim',
#    '/government/publications/qualifications-in-new-funded-offers',
#    '/when-is-your-next-tax-credits-payment',
#    '/guidance/nhs-covid-pass',
#    '/night-working-hours',
#    '/cold-weather-payment/eligibility',
#    '/business-finance-support',
#    '/government/publications/dbs-application-forms-guide-for-applicants',
#    '/find-a-regulated-qualification',
#    '/apply-blue-badge',
#    '/child-benefit',
#    '/child-tax-credit',
#    '/dismissal',
#    '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide',
#    '/frontier-worker-permit',
#    '/carers-allowance/eligibility',
#    '/topic/personal-tax/national-insurance',
#    '/self-assessment-tax-returns',
#    '/part-time-worker-rights',
#    '/new-state-pension',
#    '/government/publications/paye-starter-checklist',
#    '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships',
#    '/browse/driving/driving-licences',
#    '/browse/working/tax-minimum-wage',
#    '/student-visa/extend-your-visa',
#    '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens',
#    '/redundancy-your-rights/consultation',
#    '/statutory-sick-pay',
#    '/settled-status-eu-citizens-families/applying-for-settled-status',
#    '/looking-for-work-if-disabled/applying-for-a-job',
#    '/browse/visas-immigration/tourist-short-stay-visas',
#    '/search/guidance-and-regulation',
#    '/government/publications/right-to-work-checklist',
#    '/what-is-the-construction-industry-scheme',
#    '/register-for-self-assessment/self-employed',
#    '/right-to-reside',
#    '/browse/visas-immigration/family-visas',
#    '/track-your-driving-licence-application',
#    '/browse/disabilities/equipment',
#    '/guidance/national-minimum-wage-work-experience-and-internships',
#    '/guidance/return-to-your-claim-for-the-self-employment-income-support-scheme',
#    '/business-support-helpline',
#    '/temporary-worker-charity-worker-visa',
#    '/work-reference',
#    '/guidance/temporary-jobcentres-during-the-coronavirus-covid-19-pandemic',
#    '/improve-english-maths-it-skills',
#    '/skilled-worker-visa/apply-from-outside-the-uk',
#    '/what-different-qualification-levels-mean',
#    '/government/organisations/department-of-health-and-social-care',
#    '/apply-council-tax-reduction',
#    '/guidance/coronavirus-covid-19-advice-for-uk-visa-applicants-and-temporary-uk-residents',
#    '/statutory-sick-pay/how-to-claim',
#    '/national-insurance/your-national-insurance-number',
#    '/employment-contracts-and-conditions',
#    '/government/publications/traineeship-providers',
#    '/sure-start-maternity-grant',
#    '/government/organisations/hm-revenue-customs/services-information',
#    '/guidance/coronavirus-covid-19-what-to-do-if-youre-employed-and-cannot-work',
#    '/government/publications/your-new-state-pension-explained/your-state-pension-explained',
#    '/employing-staff',
#    '/check-national-insurance-record',
#    '/browse/visas-immigration/eu-eea-swiss',
#    '/tax-free-childcare',
#    '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa',
#    '/browse/childcare-parenting/financial-help-children',
#    '/housing-benefit/how-to-claim',
#    '/view-right-to-work',
#    '/guidance/working-safely-during-covid-19',
#    '/government/organisations/hm-revenue-customs/contact/get-help-with-the-self-employment-income-support-scheme',
#    '/browse/education/find-course',
#    '/driving-nongb-licence',
#    '/guidance/plan-for-jobs-skills-and-employment-programmes-information-for-employers',
#    '/guidance/help-employers-apply-for-a-kickstart-scheme-grant-kickstart-gateway',
#    '/government/publications/eu-settlement-scheme-application-processing-times',
#    '/driving-medical-conditions',
#    '/government-authorised-exchange',
#    '/grant-bursary-adult-learners',
#    '/the-warm-home-discount-scheme',
#    '/employers-checks-job-applicants',
#    '/government/organisations/hm-revenue-customs/contact/self-assessment',
#    '/coronavirus/business-support',
#    '/help-with-childcare-costs',
#    '/find-pension-contact-details',
#    '/become-apprentice/pay-and-conditions',
#    '/standard-visitor-visa/eligibility',
#    '/employment-status/selfemployed-contractor',
#    '/learner-support',
#    '/flexible-working',
#    '/apply-start-up-loan',
#    '/income-support',
#    '/youth-mobility',
#    '/guidance/rehabilitation-periods',
#    '/how-to-have-your-benefits-paid',
#    '/further-education-courses',
#    '/pip/when-your-pip-claim-is-reviewed',
#    '/student-visa/money',
#    '/guidance/booking-and-staying-in-a-quarantine-hotel-when-you-arrive-in-england',
#    '/claim-tax-credits',
#    '/definition-of-disability-under-equality-act-2010',
#    '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments',
#    '/apply-online-to-replace-a-driving-licence',
#    '/disability-living-allowance-children',
#    '/claim-redundancy',
#    '/browse/working/time-off',
#    '/browse/visas-immigration/arriving-in-the-uk',
#    '/volunteering',
#    '/national-insurance-credits',
#    '/get-a-passport-urgently',
#    '/jobsearch-rights',
#    '/employment-status/worker',
#    '/tell-dvla-changed-address',
#    '/employer-relocation-your-rights',
#    '/employment-support-allowance/what-youll-get',
#    '/passport-fees',
#    '/housing-benefit',
#    '/know-when-you-can-leave-school',
#    '/browse/driving/learning-to-drive',
#    '/redundancy-your-rights',
#    '/maternity-allowance/how-to-claim',
#    '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes',
#    '/uk-residence-card',
#    '/child-employment/restrictions-on-child-employment',
#    '/browse/citizenship/citizenship',
#    '/find-travel-test-provider',
#    '/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work',
#    '/flexible-working/applying-for-flexible-working',
#    '/child-trust-funds',
#    '/benefit-overpayments/how-to-make-a-repayment',
#    '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions',
#    '/government/organisations/department-for-work-pensions/about',
#    '/guidance/visa-decision-waiting-times-applications-inside-the-uk']),
#  ('/contact-jobcentre-plus',
#   ['/find-a-job',
#    '/contact-jobcentre-plus/new-benefit-claims',
#    '/contact-jobcentre-plus/existing-benefit-claims',
#    '/advertise-job',
#    '/contact-jobcentre-plus/change-cancel-appointment',
#    '/universal-credit',
#    '/browse/working/finding-job',
#    '/sign-in-universal-credit',
#    '/government/organisations/department-for-work-pensions',
#    '/apply-national-insurance-number',
#    '/employment-support-allowance',
#    '/jobcentre-plus-help-for-recruiters',
#    '/lost-national-insurance-number',
#    '/government/organisations/department-for-work-pensions/about/complaints-procedure',
#    '/national-insurance-credits/eligibility',
#    '/jobseekers-allowance',
#    '/universal-credit/contact-universal-credit',
#    '/moving-from-benefits-to-work/starting-your-own-business',
#    '/become-appointee-for-someone-claiming-benefits',
#    '/disability-premiums/how-to-claim',
#    '/jobseekers-allowance/eligibility',
#    '/browse/working',
#    '/sure-start-maternity-grant/how-to-claim',
#    '/budgeting-help-benefits/other-help-you-can-get',
#    '/budgeting-help-benefits/how-to-apply',
#    '/bills-benefits',
#    '/guidance/universal-credit-advances',
#    '/jobseekers-allowance/report-a-change-of-circumstances',
#    '/employment-support-allowance/change-of-circumstances',
#    '/universal-credit/eligibility',
#    '/contact-pension-service',
#    '/jobseekers-allowance/your-jsa-claim',
#    '/reasonable-adjustments-for-disabled-workers',
#    '/guidance/temporary-jobcentres-during-the-coronavirus-covid-19-pandemic',
#    '/government/organisations',
#    '/work-health-programme',
#    '/government/organisations/hm-revenue-customs/contact/national-insurance-numbers',
#    '/over-80-pension/how-to-claim',
#    '/access-to-work',
#    '/government/organisations/hm-revenue-customs/contact',
#    '/budgeting-help-benefits',
#    '/claim-benefits-abroad',
#    '/intensive-personalised-employment-support',
#    '/benefits-calculators',
#    '/apply-universal-credit',
#    '/jobseekers-allowance/apply-new-style-jsa',
#    '/carers-allowance/if-youre-working-',
#    '/government/organisations/hm-revenue-customs',
#    '/help',
#    '/guidance/free-courses-for-jobs',
#    '/employment-support-allowance/how-to-claim',
#    '/contact-ukvi-inside-outside-uk',
#    '/universal-credit/what-youll-get',
#    '/find-local-council',
#    '/guidance/get-help-with-benefits-and-pensions-if-you-have-accessibility-needs',
#    '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals',
#    '/contact-the-dvla',
#    '/government/organisations/department-for-work-pensions/about/recruitment',
#    '/apply-start-up-loan',
#    '/apply-apprenticeship',
#    '/search/services',
#    '/income-support',
#    '/benefit-overpayments',
#    '/universal-credit/other-financial-support',
#    '/government/collections/kickstart-scheme',
#    '/government/publications/dwp-jobcentre-register',
#    '/incapacity-benefit',
#    '/maternity-allowance',
#    '/moving-from-benefits-to-work',
#    '/government/organisations/companies-house',
#    '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions',
#    '/benefit-overpayments/when-repayments-have-to-be-made',
#    '/budgeting-help-benefits/eligibility',
#    '/tax-right-retire-abroad-return-to-uk',
#    '/pip/how-to-claim',
#    '/browse/benefits/looking-for-work',
#    '/benefit-overpayments/how-to-make-a-repayment',
#    '/carers-allowance-unit',
#    '/contact-hmrc',
#    '/register-birth',
#    '/career-skills-and-training',
#    '/universal-credit/how-to-claim',
#    '/government/collections/new-enterprise-allowance-campaign',
#    '/employment-support-allowance/eligibility',
#    '/guidance/new-style-jobseekers-allowance',
#    '/maternity-allowance/eligibility',
#    '/check-national-insurance-record',
#    '/moving-from-benefits-to-work/support-when-you-start-working',
#    '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers',
#    '/log-in-register-hmrc-online-services',
#    '/view-prove-immigration-status',
#    '/guidance/contact-the-department-for-work-and-pensions-about-its-policies',
#    '/jobsearch-rights',
#    '/government/organisations/department-for-work-pensions/about',
#    '/report-benefits-change-circumstances',
#    '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries',
#    '/cold-weather-payment/how-to-claim',
#    '/employment-support-allowance/your-esa-claim',
#    '/statutory-sick-pay',
#    '/moving-from-benefits-to-work/work-experience-and-volunteering',
#    '/government/collections/helping-young-people-into-work',
#    '/disability-benefits-helpline',
#    '/find-traineeship',
#    '/looking-for-work-if-disabled',
#    '/pip/change-of-circumstances',
#    '/national-insurance-credits',
#    '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403',
#    '/working-tax-credit',
#    '/government/publications/budgeting-loan-claim-form',
#    '/maternity-allowance/how-to-claim',
#    '/how-to-claim-new-style-jsa',
#    '/access-to-work/apply',
#    '/statutory-sick-pay/how-to-claim',
#    '/support-visit-benefit-claim',
#    '/carers-allowance',
#    '/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance',
#    '/send-fit-note',
#    '/pension-credit',
#    '/voluntary-national-insurance-contributions',
#    '/fraud-error-prevention-centres',
#    '/check-state-pension',
#    '/government/publications/maternity-allowance-claim-form',
#    '/disability-premiums',
#    '/budgeting-help-benefits/after-you-apply',
#    '/government/publications/statutory-sick-pay-employee-not-entitled-form-for-employers',
#    '/dla-disability-living-allowance-benefit',
#    '/grant-bursary-adult-learners',
#    '/how-to-have-your-benefits-paid',
#    '/pip',
#    '/national-insurance/your-national-insurance-number',
#    '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme',
#    '/payment-exception-service',
#    '/housing-and-universal-credit/renting-from-private-landlord',
#    '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers',
#    '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees',
#    '/housing-benefit',
#    '/over-80-pension',
#    '/further-education-courses/financial-help',
#    '/browse/benefits/low-income',
#    '/job-offers-your-rights',
#    '/pension-credit-calculator',
#    '/student-finance-register-login',
#    '/moving-from-benefits-to-work/help-for-parents-and-carers',
#    '/carers-allowance/further-information',
#    '/skilled-worker-visa',
#    '/guidance/apply-for-a-kickstart-scheme-grant',
#    '/employment-support-allowance/what-youll-get',
#    '/government/publications/sure-start-maternity-grant-claim-form',
#    '/the-warm-home-discount-scheme',
#    '/check-mot-status',
#    '/bereavement-support-payment/how-to-claim',
#    '/find-pension-centre',
#    '/working-for-yourself',
#    '/carers-credit',
#    '/bank-holidays',
#    '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments',
#    '/apply-blue-badge',
#    '/government/publications/test-and-trace-support-payment-scheme-claiming-financial-support/claiming-financial-support-under-the-test-and-trace-support-payment-scheme',
#    '/renew-driving-licence',
#    '/national-minimum-wage-rates',
#    '/carers-allowance/eligibility',
#    '/universal-credit/changes-of-circumstances',
#    '/government/organisations/hm-revenue-customs/contact/change-your-personal-details',
#    '/disability-premiums/eligibility',
#    '/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2',
#    '/carers-credit/how-to-claim',
#    '/income-support/report-a-change-of-circumstances',
#    '/universal-credit/get-an-advance-first-payment',
#    '/government/publications/qualifications-in-new-funded-offers',
#    '/browse/abroad/passports',
#    '/budgeting-help-benefits/repayments',
#    '/call-charges',
#    '/guidance/new-style-employment-and-support-allowance',
#    '/mature-student-university-funding',
#    '/browse/benefits/manage-your-benefit',
#    '/maternity-pay-leave',
#    '/housing-and-universal-credit',
#    '/government/publications/attendance-allowance-claim-form',
#    '/childcare-grant',
#    '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships',
#    '/benefit-fraud',
#    '/child-benefit-tax-calculator',
#    '/deferring-state-pension/what-you-get',
#    '/guidance/statutory-sick-pay-employee-fitness-to-work',
#    '/income-support/income-support-rates',
#    '/book-driving-test',
#    '/marriage-allowance',
#    '/employer-preventing-discrimination',
#    '/get-information-about-a-company',
#    '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults',
#    '/settled-status-eu-citizens-families/applying-for-settled-status',
#    '/guidance/claim-a-grant-through-the-self-employment-income-support-scheme',
#    '/get-help-hmrc-extra-support',
#    '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations',
#    '/search/research-and-statistics',
#    '/claim-benefits-abroad/jobseekers-allowance',
#    '/guidance/using-the-uk-immigration-id-check-app',
#    '/mandatory-reconsideration',
#    '/sure-start-maternity-grant/what-youll-get',
#    '/guidance/benefits-and-pensions-for-uk-nationals-in-the-eea-or-switzerland',
#    '/check-vehicle-tax',
#    '/order-coronavirus-rapid-lateral-flow-tests',
#    '/apply-housing-benefit-from-council',
#    '/work-reference',
#    '/browse/employing-people/trade-unions',
#    '/disability-premiums/what-youll-get',
#    '/check-income-tax-current-year',
#    '/get-proof-employment-history',
#    '/browse/benefits/help-for-carers',
#    '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed',
#    '/employers-sick-pay',
#    '/cold-weather-payment/eligibility',
#    '/guidance/red-amber-and-green-list-rules-for-entering-england',
#    '/government/organisations/foreign-commonwealth-development-office',
#    '/sure-start-maternity-grant/eligibility',
#    '/government/publications/child-benefit-claim-form-ch2',
#    '/set-up-sole-trader',
#    '/search/guidance-and-regulation',
#    '/browse/employing-people/recruiting-hiring',
#    '/additional-state-pension',
#    '/severe-disablement-allowance',
#    '/set-up-self-employed',
#    '/sure-start-maternity-grant',
#    '/over-80-pension/further-information',
#    '/tell-dvla-changed-address',
#    '/financial-help-disabled/disability-and-sickness-benefits',
#    '/employment-support-allowance/working-while-you-claim',
#    '/bereavement-support-payment',
#    '/working-tax-credit/how-to-claim',
#    '/apply-marriage-allowance',
#    '/jobcentre-plus-help-for-recruiters/work-trials',
#    '/improve-english-maths-it-skills',
#    '/employment-rights-for-interns',
#    '/manage-your-tax-credits',
#    '/employing-an-apprentice',
#    '/attendance-allowance/eligibility',
#    '/foreign-travel-advice',
#    '/student-finance',
#    '/financial-help-disabled',
#    '/after-a-death/organisations-you-need-to-contact-and-tell-us-once',
#    '/government/organisations/hm-revenue-customs/contact/online-services-helpdesk',
#    '/access-to-work/eligibility',
#    '/carers-allowance/effect-on-other-benefits',
#    '/moving-from-benefits-to-work/job-search-programmes',
#    '/biometric-residence-permits',
#    '/new-state-pension/your-national-insurance-record-and-your-state-pension',
#    '/claim-tax-refund',
#    '/new-state-pension/what-youll-get',
#    '/set-up-business',
#    '/pip/what-youll-get',
#    '/check-income-tax-last-year',
#    '/voluntary-national-insurance-contributions/deadlines',
#    '/budgeting-help-benefits/what-youll-get',
#    '/government/organisations/department-of-social-security',
#    '/council-housing',
#    '/national-insurance/help-if-youre-not-working',
#    '/browse/tax/national-insurance',
#    '/guidance/visa-decision-waiting-times-applications-inside-the-uk',
#    '/coronavirus/worker-support',
#    '/book-theory-test',
#    '/settled-status-eu-citizens-families/eligibility',
#    '/order-copy-birth-death-marriage-certificate',
#    '/government/organisations/department-for-education',
#    '/early-retirement-pension/personal-and-workplace-pensions',
#    '/business-finance-support',
#    '/child-employment',
#    '/get-tax-free-childcare',
#    '/tax-credits-calculator',
#    '/change-address-driving-licence',
#    '/child-benefit/what-youll-get',
#    '/deferring-state-pension/how-to-claim-a-deferred-state-pension',
#    '/employment-status/worker',
#    '/jobcentre-plus-help-for-recruiters/other-employment-schemes',
#    '/find-travel-test-provider',
#    '/government/publications/the-official-hmrc-app',
#    '/employers-checks-job-applicants',
#    '/paternity-pay-leave/pay',
#    '/redundancy-your-rights/get-help-finding-a-new-job',
#    '/browse/childcare-parenting/childcare',
#    '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022',
#    '/employers-sick-pay/eligibility-and-form-ssp1',
#    '/national-insurance',
#    '/government/publications/the-national-minimum-wage-in-2021',
#    '/education/apprenticeships-traineeships-and-internships',
#    '/guidance/indefinite-leave-to-remain-in-the-uk',
#    '/maternity-pay-leave/how-to-claim',
#    '/browse/benefits/unable-to-work',
#    '/cold-weather-payment',
#    '/dismissal',
#    '/government/publications/right-to-work-checks-employers-guide',
#    '/child-benefit-move-to-uk',
#    '/universal-credit/how-youre-paid',
#    '/how-to-claim-new-style-esa',
#    '/browse/visas-immigration/settle-in-the-uk',
#    '/the-warm-home-discount-scheme/energy-suppliers',
#    '/state-pension',
#    '/state-pension/circumstances-change',
#    '/guidance/travel-abroad-from-england-during-coronavirus-covid-19',
#    '/government/publications/rates-and-allowances-national-insurance-contributions/rates-and-allowances-national-insurance-contributions',
#    '/browse/disabilities/work',
#    '/test-and-trace-support-payment']),
#  ('/browse/working',
#   ['/browse/working/finding-job',
#    '/browse/working/workplace-personal-pensions',
#    '/browse/working/tax-minimum-wage',
#    '/browse/working/time-off',
#    '/browse/working/contract-working-hours',
#    '/browse/working/rights-trade-unions',
#    '/browse/working/redundancies-dismissals',
#    '/browse/working/armed-forces',
#    '/find-a-job',
#    '/contact-jobcentre-plus',
#    '/view-prove-immigration-status',
#    '/government/organisations',
#    '/state-pension-age',
#    '/sign-in-universal-credit',
#    '/browse/visas-immigration/work-visas',
#    '/government/organisations/department-for-work-pensions',
#    '/help',
#    '/contact-pension-service',
#    '/log-in-register-hmrc-online-services',
#    '/check-job-applicant-right-to-work',
#    '/government/organisations/disclosure-and-barring-service',
#    '/new-state-pension',
#    '/guidance/red-amber-and-green-list-rules-for-entering-england',
#    '/personal-tax-account',
#    '/get-state-pension',
#    '/check-state-pension',
#    '/check-uk-visa',
#    '/new-state-pension/what-youll-get',
#    '/view-right-to-work',
#    '/jobseekers-allowance',
#    '/apply-apprenticeship',
#    '/check-state-pension/sign-in/prove-identity',
#    '/find-local-council',
#    '/browse/visas-immigration/what-you-need-to-do',
#    '/log-in-register-hmrc-online-services/register',
#    '/search/services',
#    '/state-pension/what-youll-get',
#    '/future-pension-centre',
#    '/browse/benefits/families',
#    '/plan-for-retirement',
#    '/browse/tax/national-insurance',
#    '/browse/citizenship/citizenship',
#    '/universal-credit/eligibility',
#    '/browse/visas-immigration/student-visas',
#    '/browse/visas-immigration/eu-eea-swiss',
#    '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do',
#    '/government/publications/register-of-licensed-sponsors-workers',
#    '/apply-to-come-to-the-uk',
#    '/national-insurance',
#    '/check-national-insurance-record',
#    '/contact-hmrc',
#    '/calculate-your-redundancy-pay',
#    '/government/organisations/hm-revenue-customs',
#    '/student-finance-register-login',
#    '/topic/further-education-skills/apprenticeships',
#    '/search/guidance-and-regulation',
#    '/guidance/contact-the-department-for-work-and-pensions-about-its-policies',
#    '/pension-credit/what-youll-get',
#    '/contact-ukvi-inside-outside-uk',
#    '/check-income-tax-current-year',
#    '/national-minimum-wage-rates',
#    '/browse/visas-immigration/family-visas',
#    '/universal-credit/contact-universal-credit',
#    '/browse/education/student-finance',
#    '/career-skills-and-training',
#    '/guidance/universal-credit-advances',
#    '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations',
#    '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees',
#    '/government/organisations/hm-revenue-customs/contact/change-your-personal-details',
#    '/how-to-have-your-benefits-paid',
#    '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means',
#    '/right-to-reside',
#    '/log-in-file-self-assessment-tax-return/sign-in/prove-identity',
#    '/browse/citizenship/government',
#    '/apply-national-insurance-number',
#    '/guidance/brexit-guidance-for-individuals-and-families',
#    '/additional-state-pension',
#    '/calculate-your-holiday-entitlement',
#    '/topic/immigration-operational-guidance',
#    '/advertise-job',
#    '/guidance/immigration-rules',
#    '/statutory-sick-pay',
#    '/employment-contracts-and-conditions',
#    '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme',
#    '/additional-state-pension/inheriting',
#    '/government/publications/the-basic-state-pension',
#    '/browse/benefits/low-income',
#    '/dbs-update-service',
#    '/new-state-pension/youve-been-in-a-workplace-personal-or-stakeholder-pension',
#    '/coronavirus/worker-support',
#    '/criminal-record-checks-apply-role',
#    '/check-state-pension/sign-in/create-account',
#    '/topic/immigration-operational-guidance/immigration-rules',
#    '/browse/disabilities/work',
#    '/become-appointee-for-someone-claiming-benefits',
#    '/state-pension-through-partner',
#    '/sold-bought-vehicle',
#    '/pension-credit',
#    '/contracted-out/check-if-you-were-contracted-out',
#    '/employers-workplace-pensions-rules',
#    '/skilled-worker-visa/your-job',
#    '/find-coronavirus-support',
#    '/browse/visas-immigration/arriving-in-the-uk',
#    '/personal-pensions-your-rights/how-you-can-take-pension',
#    '/benefits-calculators',
#    '/contracted-out',
#    '/vehicles-can-drive',
#    '/browse/education/universities-higher-education',
#    '/check-vehicle-tax',
#    '/uk-visa-sponsorship-employers',
#    '/government/publications/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens-accessible-version',
#    '/government/organisations/hm-revenue-customs/contact/child-benefit',
#    '/browse/benefits/disability',
#    '/early-retirement-pension/benefits',
#    '/uk-family-visa',
#    '/redundancy-your-rights/notice-periods',
#    '/apply-standard-visitor-visa',
#    '/browse/visas-immigration/settle-in-the-uk',
#    '/tax-come-to-uk',
#    '/government/publications/skilled-worker-visa-shortage-occupations',
#    '/topic/work-careers/government-graduate-schemes',
#    '/the-warm-home-discount-scheme',
#    '/claim-benefits-abroad',
#    '/plan-retirement-income/get-financial-advice',
#    '/employment-support-allowance',
#    '/guidance/immigration-rules/immigration-rules-appendix-shortage-occupation-list',
#    '/employers-checks-job-applicants',
#    '/calculate-agricultural-holiday-entitlement',
#    '/contact-jobcentre-plus/existing-benefit-claims',
#    '/manage-your-tax-credits',
#    '/pension-types',
#    '/settled-status-eu-citizens-families/after-youve-applied',
#    '/government/publications/dwp-jobcentre-register',
#    '/skilled-worker-visa/when-you-can-be-paid-less',
#    '/english-language',
#    '/deferring-state-pension/what-you-get',
#    '/guidance/using-the-eu-exit-id-document-check-app',
#    '/check-income-tax-current-year/sign-in/create-account',
#    '/pension-credit-calculator',
#    '/register-to-vote',
#    '/am-i-getting-minimum-wage',
#    '/report-benefits-change-circumstances',
#    '/night-working-hours',
#    '/guidance/brexit-guidance-for-businesses',
#    '/browse/benefits/unable-to-work',
#    '/youth-mobility',
#    '/workplace-bullying-and-harassment',
#    '/access-to-work',
#    '/estimate-income-tax',
#    '/check-income-tax-last-year',
#    '/guidance/new-immigration-system-what-you-need-to-know',
#    '/legal-right-work-uk',
#    '/renew-adult-passport',
#    '/new-state-pension/living-and-working-overseas',
#    '/moving-from-benefits-to-work/starting-your-own-business',
#    '/government/organisations/hm-revenue-customs/contact',
#    '/guidance/free-courses-for-jobs',
#    '/dla-disability-living-allowance-benefit',
#    '/pension-credit/change-of-circumstances',
#    '/tax-on-pension/tax-free',
#    '/government/publications/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19',
#    '/tax-help',
#    '/transferring-your-pension',
#    '/workplace-pensions',
#    '/check-mot-history',
#    '/get-paye-forms-p45-p60',
#    '/check-income-tax-current-year/sign-in/prove-identity',
#    '/employment-rights-for-interns',
#    '/browse/disabilities/equipment',
#    '/passport-advice-line',
#    '/government/organisations/foreign-commonwealth-development-office',
#    '/holiday-entitlement-rights',
#    '/pension-credit/how-to-claim',
#    '/find-traineeship',
#    '/universal-credit/how-to-claim',
#    '/jobseekers-allowance/eligibility',
#    '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults',
#    '/new-state-pension/how-to-claim',
#    '/contracted-out/new-state-pension',
#    '/apply-online-to-replace-a-driving-licence',
#    '/standard-visitor-visa',
#    '/browse/benefits/manage-your-benefit',
#    '/browse/visas-immigration/asylum',
#    '/apply-housing-benefit-from-council',
#    '/uk-border-control/before-you-leave-for-the-uk',
#    '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member',
#    '/government/publications/eu-settlement-scheme-application-processing-times/eu-settlement-scheme-pilot-current-expected-processing-times-for-applications',
#    '/browse/benefits/looking-for-work',
#    '/government/publications/register-of-licensed-sponsors-students',
#    '/skilled-worker-visa',
#    '/benefit-cap',
#    '/holiday-entitlement-rights/holiday-pay-the-basics',
#    '/income-tax',
#    '/find-pension-contact-details',
#    '/government/organisations/foreign-commonwealth-office',
#    '/government/organisations/home-office',
#    '/guidance/booking-and-staying-in-a-quarantine-hotel-when-you-arrive-in-england',
#    '/topic/business-tax/self-employed',
#    '/government/organisations/department-for-work-pensions/about',
#    '/government/organisations/uk-visas-and-immigration',
#    '/self-employed-national-insurance-rates',
#    '/handing-in-your-notice/gardening-leave',
#    '/understanding-your-pay/deductions-from-your-pay',
#    '/pay-and-work-rights',
#    '/browse/employing-people/recruiting-hiring',
#    '/government/get-involved/take-part/volunteer',
#    '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens',
#    '/universal-credit',
#    '/biometric-residence-permits',
#    '/government/publications/test-and-trace-support-payment-scheme-claiming-financial-support/claiming-financial-support-under-the-test-and-trace-support-payment-scheme',
#    '/browse/education/find-course',
#    '/taking-sick-leave',
#    '/topic/personal-tax/national-insurance',
#    '/moving-from-benefits-to-work/support-when-you-start-working',
#    '/get-help-hmrc-extra-support',
#    '/new-state-pension/how-its-calculated',
#    '/state-pension',
#    '/find-internship',
#    '/contact-jobcentre-plus/new-benefit-claims',
#    '/pip',
#    '/pension-credit/eligibility',
#    '/tell-hmrc-change-address',
#    '/guidance/visa-decision-waiting-times-applications-outside-the-uk',
#    '/browse/tax/self-assessment',
#    '/state-pension-if-you-retire-abroad',
#    '/government/organisations/department-of-health-and-social-care',
#    '/personal-tax-account/sign-in/prove-identity',
#    '/contact-student-finance-england',
#    '/search/news-and-communications',
#    '/claim-tax-credits',
#    '/short-term-benefit-advance/how-to-apply',
#    '/new-state-pension/inheriting-or-increasing-state-pension-from-a-spouse-or-civil-partner',
#    '/council-tax-bands',
#    '/uk-visa-sponsorship-employers/types-of-licence',
#    '/coronavirus/business-support',
#    '/student-visa/money',
#    '/after-a-death/organisations-you-need-to-contact-and-tell-us-once',
#    '/contracted-out/old-state-pension',
#    '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022',
#    '/government/publications/right-to-work-checklist',
#    '/pip/change-of-circumstances',
#    '/find-lost-utr-number',
#    '/universal-credit/other-financial-support',
#    '/tax-on-pension',
#    '/guidance/recruiting-people-from-outside-the-uk',
#    '/apply-for-elderly-person-bus-pass',
#    '/government/organisations/hm-revenue-customs/services-information',
#    '/student-finance/extra-help',
#    '/employment-status/worker',
#    '/death-spouse-benefits-tax-pension/pensions',
#    '/job-offers-your-rights',
#    '/find-travel-test-provider',
#    '/government/organisations/department-for-work-pensions/about/complaints-procedure',
#    '/pay-voluntary-class-3-national-insurance',
#    '/agency-workers-your-rights/basic-information-you-should-receive',
#    '/get-tax-free-childcare',
#    '/learn-to-drive-a-car',
#    '/browse/employing-people/contracts',
#    '/early-retirement-pension/personal-and-workplace-pensions',
#    '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus',
#    '/criminal-record-checks-apply-role/application-process']),
#  ('/jobseekers-allowance',
#   ['/jobseekers-allowance/eligibility',
#    '/jobseekers-allowance/apply-new-style-jsa',
#    '/benefits-calculators',
#    '/jobseekers-allowance/your-jsa-claim',
#    '/universal-credit/eligibility',
#    '/browse/benefits/looking-for-work',
#    '/jobseekers-allowance/report-a-change-of-circumstances',
#    '/universal-credit',
#    '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa',
#    '/contact-jobcentre-plus',
#    '/find-a-job',
#    '/employment-support-allowance',
#    '/sign-in-universal-credit',
#    '/how-to-claim-new-style-jsa',
#    '/how-to-have-your-benefits-paid',
#    '/employment-support-allowance/eligibility',
#    '/apply-universal-credit',
#    '/browse/working/finding-job',
#    '/contact-jobcentre-plus/new-benefit-claims',
#    '/universal-credit/contact-universal-credit',
#    '/guidance/redundancy-help-finding-work-and-claiming-benefits',
#    '/guidance/new-style-jobseekers-allowance',
#    '/contact-jobcentre-plus/existing-benefit-claims',
#    '/employment-support-allowance/what-youll-get',
#    '/universal-credit/how-to-claim',
#    '/employment-support-allowance/how-to-claim',
#    '/universal-credit/what-youll-get',
#    '/income-support',
#    '/pension-credit',
#    '/housing-benefit',
#    '/incapacity-benefit',
#    '/government/organisations/department-for-work-pensions',
#    '/browse/working',
#    '/statutory-sick-pay',
#    '/pip',
#    '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022',
#    '/short-term-benefit-advance',
#    '/employment-support-allowance/working-while-you-claim',
#    '/disability-premiums',
#    '/guidance/new-style-employment-and-support-allowance',
#    '/child-benefit',
#    '/further-education-courses/financial-help',
#    '/apply-apprenticeship',
#    '/log-in-register-hmrc-online-services',
#    '/budgeting-help-benefits',
#    '/carers-allowance',
#    '/moving-from-benefits-to-work/support-when-you-start-working',
#    '/working-tax-credit',
#    '/guidance/get-help-with-benefits-and-pensions-if-you-have-accessibility-needs',
#    '/grant-bursary-adult-learners',
#    '/state-pension-age',
#    '/browse/benefits/manage-your-benefit',
#    '/national-insurance/help-if-youre-not-working',
#    '/universal-credit/how-your-earnings-affect-your-payments',
#    '/universal-credit/other-financial-support',
#    '/guidance/universal-credit-advances',
#    '/employment-support-allowance/your-esa-claim',
#    '/housing-benefit/what-youll-get',
#    '/government/collections/kickstart-scheme',
#    '/browse/childcare-parenting/financial-help-children',
#    '/manage-your-tax-credits',
#    '/dla-disability-living-allowance-benefit',
#    '/check-national-insurance-record',
#    '/volunteering',
#    '/moving-from-benefits-to-work/starting-your-own-business',
#    '/claim-benefits-abroad/jobseekers-allowance',
#    '/personal-tax-account',
#    '/browse/benefits/unable-to-work',
#    '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions',
#    '/view-prove-immigration-status',
#    '/income-tax/taxfree-and-taxable-state-benefits',
#    '/browse/disabilities/benefits',
#    '/passport-fees',
#    '/cold-weather-payment/eligibility',
#    '/apply-council-tax-reduction',
#    '/child-tax-credit',
#    '/calculate-your-redundancy-pay',
#    '/national-insurance-credits',
#    '/financial-help-disabled/disability-and-sickness-benefits',
#    '/government/publications/jobseekers-allowance-sanctions-leaflet/jobseekers-allowance-sanctions-how-to-keep-your-benefit-payment',
#    '/student-finance-register-login',
#    '/find-local-council',
#    '/national-insurance/how-much-you-pay',
#    '/child-benefit/how-to-claim',
#    '/pip/what-youll-get',
#    '/estimate-income-tax',
#    '/guidance/universal-credit-and-students',
#    '/contact-pension-service',
#    '/welfare/jobseekers-allowance',
#    '/budgeting-help-benefits/how-to-apply',
#    '/national-insurance/national-insurance-classes',
#    '/browse/benefits/disability',
#    '/contact-ukvi-inside-outside-uk',
#    '/sure-start-maternity-grant/eligibility',
#    '/bank-holidays',
#    '/your-rights-if-your-employer-is-insolvent',
#    '/disability-premiums/eligibility',
#    '/right-to-reside',
#    '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide/universal-credit-if-you-have-a-disability-or-health-condition',
#    '/self-employed-national-insurance-rates',
#    '/national-insurance-credits/eligibility',
#    '/search/services',
#    '/work-health-programme',
#    '/how-tax-credits-affect-other-benefits',
#    '/attendance-allowance',
#    '/uk-benefits-abroad',
#    '/how-to-claim-new-style-esa',
#    '/state-pension/what-youll-get',
#    '/sure-start-maternity-grant',
#    '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme',
#    '/moving-from-benefits-to-work/work-experience-and-volunteering',
#    '/budgeting-help-benefits/eligibility',
#    '/topic/personal-tax/self-assessment',
#    '/when-mental-health-condition-becomes-disability',
#    '/government/publications/dwp-jobcentre-register',
#    '/tax-credits-calculator',
#    '/state-pension',
# ...
#  ('/tax-relief-for-employees',
#   ['/browse/tax/income-tax',
#    '/income-tax-reliefs',
#    '/topic/personal-tax/income-tax',
#    '/tax-codes',
#    '/browse/working',
#    '/tax-on-your-private-pension/pension-tax-relief',
#    '/marriage-allowance',
#    '/check-income-tax',
#    '/access-to-work',
#    '/government/organisations/hm-revenue-customs']),
#  ('/government/collections/statutory-sick-pay-and-leave',
#   ['/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2',
#    '/statutory-sick-pay',
#    '/employers-sick-pay',
#    '/guidance/statutory-sick-pay-employee-fitness-to-work',
#    '/topic/business-tax/paye',
#    '/government/publications/statutory-sick-pay-employee-not-entitled-form-for-employers',
#    '/government/collections/statutory-pay-forms',
#    '/browse/working/time-off',
#    '/taking-sick-leave',
#    '/topic/personal-tax/income-tax']),
#  ('/dvlaforms',
#   ['/exchange-foreign-driving-licence',
#    '/apply-first-provisional-driving-licence',
#    '/view-prove-immigration-status',
#    '/guidance/free-courses-for-jobs',
#    '/browse/driving/driving-licences',
#    '/find-a-job',
#    '/tax-help',
#    '/renew-driving-licence',
#    '/learn-to-drive-a-car',
#    '/settled-status-eu-citizens-families/apply-settled-status-for-child']),
#  ('/employ-trainees',
#   ['/browse/education/find-course',
#    '/employing-an-apprentice',
#    '/topic/further-education-skills/administration',
#    '/search/services',
#    '/find-traineeship',
#    '/employment-rights-for-interns',
#    '/apply-apprenticeship',
#    '/topic/further-education-skills/vocational-qualifications',
#    '/government/collections/helping-young-people-into-work',
#    '/become-apprentice/apply-for-an-apprenticeship']),
#  ('/tax-on-pension/tax-when-you-live-abroad',
#   ['/tax-on-pension/higher-tax-on-unauthorised-payments',
#    '/tax-on-pension/how-your-tax-is-paid',
#    '/tax-on-pension/tax-free',
#    '/tax-on-pension',
#    '/check-state-pension',
#    '/state-pension-age',
#    '/check-state-pension/sign-in/prove-identity',
#    '/state-pension/eligibility',
#    '/plan-for-retirement',
#    '/government/organisations/hm-revenue-customs']),
#  ('/frontier-worker-permit',
#   ['/browse/visas-immigration/work-visas',
#    '/browse/visas-immigration/eu-eea-swiss',
#    '/overseas-domestic-worker-visa',
#    '/view-prove-immigration-status',
#    '/settled-status-eu-citizens-families',
#    '/browse/working',
#    '/check-uk-visa',
#    '/employment-status',
#    '/government/publications/view-and-prove-your-immigration-status-evisa',
#    '/settled-status-eu-citizens-families/eligibility']),
#  ('/education/further-and-higher-education-skills-and-vocational-training',
#   ['/apply-apprenticeship',
#    '/guidance/free-courses-for-jobs',
#    '/become-apprentice',
#    '/what-different-qualification-levels-mean',
#    '/topic/further-education-skills/apprenticeships',
#    '/career-skills-and-training',
#    '/employing-an-apprentice',
#    '/government/publications/find-a-skills-bootcamp',
#    '/topic/further-education-skills/vocational-qualifications',
#    '/government/publications/qualifications-in-new-funded-offers']),
#  ('/jobcentre-plus-help-for-recruiters/work-trials',
#   ['/jobcentre-plus-help-for-recruiters/recruitment-advice-and-support',
#    '/jobcentre-plus-help-for-recruiters',
#    '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships',
#    '/jobcentre-plus-help-for-recruiters/other-employment-schemes',
#    '/topic/further-education-skills/apprenticeships',
#    '/find-a-job',
#    '/contact-jobcentre-plus',
#    '/redundancy-your-rights/get-help-finding-a-new-job',
#    '/browse/employing-people/recruiting-hiring',
#    '/employment-rights-for-interns']),
#  ('/child-benefit-move-to-uk',
#   ['/child-benefit/eligibility',
#    '/child-benefit',
#    '/browse/childcare-parenting/financial-help-children',
#    '/browse/births-deaths-marriages/child',
#    '/browse/working',
#    '/child-benefit/how-to-claim',
#    '/topic/benefits-credits/child-benefit',
#    '/child-benefit/make-a-change-to-your-claim',
#    '/browse/births-deaths-marriages/child-adoption',
#    '/right-to-reside']),
#  ('/uk-visa-sponsorship-employers/job-suitability',
#   ['/guidance/immigration-rules',
#    '/uk-visa-sponsorship-employers',
#    '/government/publications/skilled-worker-visa-shortage-occupations',
#    '/uk-visa-sponsorship-employers/sponsorship-management-roles',
#    '/uk-visa-sponsorship-employers/types-of-licence',
#    '/uk-visa-sponsorship-employers/apply-for-your-licence',
#    '/government/collections/sponsorship-information-for-employers-and-educators',
#    '/sponsor-management-system',
#    '/skilled-worker-visa',
#    '/health-care-worker-visa']),
#  ('/income-tax/find-out-if-you-need-to-pay-income-tax',
#   ['/income-tax',
#    '/income-tax/taxfree-and-taxable-state-benefits',
#    '/income-tax/check-youre-paying-the-right-amount',
#    '/income-tax-rates',
#    '/income-tax/how-you-pay-income-tax',
#    '/national-insurance',
#    '/student-jobs-paying-tax',
#    '/national-insurance/how-much-you-pay',
#    '/sign-in-universal-credit',
#    '/government/organisations']),
#  ('/council-tax',
#   ['/apply-council-tax-reduction',
#    '/council-tax-bands',
#    '/sign-in-universal-credit',
#    '/browse/working',
#    '/view-prove-immigration-status',
#    '/student-finance/who-qualifies',
#    '/over-80-pension',
#    '/housing-benefit/what-youll-get',
#    '/jobseekers-allowance',
#    '/find-local-council']),
#  ('/topic/benefits-credits/child-benefit',
#   ['/child-benefit',
#    '/child-benefit-tax-calculator',
#    '/government/organisations/hm-revenue-customs',
#    '/child-benefit-16-19',
#    '/log-in-register-hmrc-online-services',
#    '/child-benefit-move-to-uk',
#    '/how-to-have-your-benefits-paid',
#    '/child-benefit-payment-dates',
#    '/apply-national-insurance-number',
#    '/browse/births-deaths-marriages/child']),
#  ('/government/collections/helping-young-people-into-work',
#   ['/contact-jobcentre-plus',
#    '/moving-from-benefits-to-work',
#    '/moving-from-benefits-to-work/work-experience-and-volunteering',
#    '/find-a-job',
#    '/apply-apprenticeship',
#    '/guidance/apply-for-a-kickstart-scheme-grant',
#    '/become-apprentice',
#    '/guidance/plan-for-jobs-skills-and-employment-programmes-information-for-employers',
#    '/government/collections/kickstart-scheme',
#    '/moving-from-benefits-to-work/starting-your-own-business']),
#  ('/government/publications/maternity-benefits-technical-guidance',
#   ['/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance',
#    '/government/publications/maternity-allowance-claim-form',
#    '/maternity-allowance',
#    '/government/organisations/department-for-work-pensions',
#    '/browse/working',
#    '/maternity-allowance/how-to-claim',
#    '/welfare/entitlement',
#    '/maternity-allowance/what-youll-get',
#    '/sure-start-maternity-grant/what-youll-get',
#    '/maternity-pay-leave/leave']),
#  ('/apply-standard-visitor-visa',
#   ['/check-uk-visa',
#    '/standard-visitor-visa/apply',
#    '/browse/working',
#    '/standard-visitor-visa/eligibility',
#    '/visit-uk-holiday-family-friends',
#    '/contact-ukvi-inside-outside-uk',
#    '/standard-visitor-visa',
#    '/uk-family-visa',
#    '/browse/visas-immigration/tourist-short-stay-visas',
#    '/standard-visitor-visa/documents-you-will-need']),
#  ('/when-is-your-next-tax-credits-payment',
#   ['/manage-your-tax-credits',
#    '/browse/benefits/manage-your-benefit',
#    '/browse/working',
#    '/topic/benefits-credits/tax-credits',
#    '/how-to-have-your-benefits-paid',
#    '/browse/benefits/families',
#    '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries',
#    '/tax-credits-calculator',
#    '/renewing-your-tax-credits-claim',
#    '/working-tax-credit/what-youll-get']),
#  ('/apply-free-school-meals',
#   ['/browse/benefits/families',
#    '/jobseekers-allowance',
#    '/browse/working',
#    '/child-tax-credit/how-to-claim',
#    '/contact-jobcentre-plus',
#    '/sign-in-universal-credit',
#    '/right-to-reside',
#    '/cold-weather-payment',
#    '/child-benefit/eligibility',
#    '/government/organisations/hm-revenue-customs']),
#  ('/apply-for-disabled-bus-pass',
#   ['/browse/disabilities/equipment',
#    '/apply-for-elderly-person-bus-pass',
#    '/apply-needs-assessment-social-services',
#    '/driving-medical-conditions',
#    '/rights-disabled-person',
#    '/jobseekers-allowance',
#    '/looking-for-work-if-disabled',
#    '/access-to-work',
#    '/apply-blue-badge',
#    '/when-mental-health-condition-becomes-disability']),
#  ('/get-tax-free-childcare',
#   ['/sign-in-childcare-account',
#    '/tax-free-childcare',
#    '/browse/childcare-parenting/childcare',
#    '/contact-jobcentre-plus',
#    '/help-with-childcare-costs',
#    '/jobseekers-allowance',
#    '/national-minimum-wage-rates',
#    '/time-off-for-dependants',
#    '/working-tax-credit',
#    '/browse/working']),
#  ('/employment-contracts-and-conditions/collective-agreements',
#   ['/employment-contracts-and-conditions/written-statement-of-employment-particulars',
#    '/employment-contracts-and-conditions/contract-terms',
#    '/employment-contracts-and-conditions/problems-with-a-written-statement',
#    '/employment-rights-for-interns',
#    '/child-employment',
#    '/employment-contracts-and-conditions',
#    '/employ-someone',
#    '/browse/working/contract-working-hours',
#    '/browse/working']),
#  ('/carers-credit/what-youll-get',
#   ['/carers-credit/eligibility',
#    '/carers-credit',
#    '/carers-credit/how-to-claim',
#    '/attendance-allowance',
#    '/browse/benefits/help-for-carers',
#    '/carers-allowance',
#    '/pip',
#    '/contact-jobcentre-plus',
#    '/national-insurance-rates-letters']),
#  ('/browse/abroad/travel-abroad',
#   ['/foreign-travel-advice',
#    '/travel-abroad',
#    '/uk-border-control',
#    '/provide-journey-contact-details-before-travel-uk',
#    '/browse/working',
#    '/browse/abroad/living-abroad',
#    '/browse/abroad/passports',
#    '/uk-border-control/before-you-leave-for-the-uk',
#    '/claim-benefits-abroad']),
#  ('/personal-pensions-your-rights/choosing-personal-pension',
#   ['/personal-pensions-your-rights/how-you-can-take-pension',
#    '/personal-pensions-your-rights',
#    '/browse/working/workplace-personal-pensions',
#    '/browse/working',
#    '/topic/business-tax/pension-scheme-administration',
#    '/new-state-pension',
#    '/flexible-working/applying-for-flexible-working',
#    '/personal-pensions-your-rights/get-help',
#    '/pension-types']),
#  ('/claim-loss-notice',
#   ['/browse/working/redundancies-dismissals',
#    '/claim-redundancy',
#    '/jobseekers-allowance',
#    '/disciplinary-procedures-and-action-at-work',
#    '/handing-in-your-notice',
#    '/handing-in-your-notice/giving-notice',
#    '/national-minimum-wage-rates',
#    '/guidance/redundancy-help-finding-work-and-claiming-benefits',
#    '/calculate-your-redundancy-pay']),
#  ('/mandatory-reconsideration/how-to-ask-for-mandatory-reconsideration',
#   ['/mandatory-reconsideration',
#    '/sign-in-universal-credit',
#    '/benefit-overpayments',
#    '/jobseekers-allowance',
#    '/guidance/new-style-employment-and-support-allowance',
#    '/guidance/new-style-jobseekers-allowance',
#    '/pip',
#    '/government/organisations/department-for-work-pensions',
#    '/contact-jobcentre-plus/existing-benefit-claims']),
#  ('/your-employment-contract-how-it-can-be-changed/making-changes',
#   ['/your-employment-contract-how-it-can-be-changed',
#    '/browse/working/contract-working-hours',
#    '/employment-contracts-and-conditions/written-statement-of-employment-particulars',
#    '/flexible-working/applying-for-flexible-working',
#    '/maximum-weekly-working-hours/calculating-your-working-hours',
#    '/employment-contracts-and-conditions/collective-agreements',
#    '/employment-contracts-and-conditions',
#    '/maximum-weekly-working-hours',
#    '/browse/working']),
#  ('/change-circumstances-visa-brp/youre-in-the-uk-and-dont-have-a-brp',
#   ['/update-uk-visas-immigration-account-details',
#    '/change-circumstances-visa-brp',
#    '/view-prove-immigration-status',
#    '/update-uk-visas-immigration-account-details/update-your-ukvi-account',
#    '/contact-ukvi-inside-outside-uk',
#    '/browse/visas-immigration/tourist-short-stay-visas',
#    '/uk-border-control/at-border-control',
#    '/criminal-record-check-documents',
#    '/biometric-residence-permits']),
#  ('/browse/business/finance-support',
#   ['/business-finance-support',
#    '/apply-start-up-loan',
#    '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme',
#    '/business-support-helpline',
#    '/guidance/claim-for-wage-costs-through-the-coronavirus-job-retention-scheme',
#    '/business-coronavirus-support-finder',
#    '/browse/working',
#    '/browse/business/setting-up',
#    '/browse/benefits/looking-for-work']),
#  ('/disabled-facilities-grants/what-youll-get',
#   ['/disabled-facilities-grants/eligibility',
#    '/disabled-facilities-grants',
#    '/apply-home-equipment-for-disabled',
#    '/financial-help-disabled',
#    '/apply-disabled-facilities-grant',
#    '/browse/disabilities/equipment',
#    '/browse/benefits/disability',
#    '/apply-for-disabled-bus-pass',
#    '/disabled-facilities-grants/how-to-claim']),
#  ('/volunteering/when-you-can-volunteer',
#   ['/volunteering/pay-and-expenses',
#    '/volunteering',
#    '/volunteering/volunteers-rights',
#    '/browse/working/finding-job',
#    '/browse/citizenship/charities-honours',
#    '/dbs-check-applicant-criminal-record',
#    '/employment-status',
#    '/moving-from-benefits-to-work/work-experience-and-volunteering',
#    '/training-study-work-your-rights']),
#  ('/rest-breaks-work/compensatory-rest',
#   ['/rest-breaks-work/exceptions',
#    '/rest-breaks-work/taking-breaks',
#    '/rest-breaks-work',
#    '/child-employment',
#    '/rest-breaks-work/disputes',
#    '/browse/working/contract-working-hours',
#    '/taking-sick-leave',
#    '/maximum-weekly-working-hours',
#    '/browse/employing-people/contracts']),
#  ('/employers-sick-pay/entitlement',
#   ['/employers-sick-pay/eligibility-and-form-ssp1',
#    '/employers-sick-pay',
#    '/calculate-statutory-sick-pay',
#    '/employers-sick-pay/help-with-sick-pay',
#    '/statutory-sick-pay',
#    '/employers-sick-pay/notice-and-fit-notes',
#    '/parental-leave',
#    '/taking-sick-leave',
#    '/jobseekers-allowance']),
#  ('/paternity-pay-leave/how-to-claim',
#   ['/paternity-pay-leave/eligibility',
#    '/browse/working/time-off',
#    '/paternity-pay-leave',
#    '/maternity-paternity-pay-leave',
#    '/paternity-pay-leave/pay',
#    '/browse/working',
#    '/browse/benefits/families',
#    '/maternity-pay-leave',
#    '/maternity-pay-leave/how-to-claim']),
#  ('/1619-bursary-fund/eligibility',
#   ['/1619-bursary-fund/how-to-claim',
#    '/1619-bursary-fund/what-youll-get',
#    '/1619-bursary-fund',
#    '/browse/education/find-course',
#    '/apply-apprenticeship',
#    '/become-apprentice/apply-for-an-apprenticeship',
#    '/jobseekers-allowance',
#    '/student-finance/who-qualifies',
#    '/courses-qualifications']),
#  ('/tax-company-benefits',
#   ['/browse/working/tax-minimum-wage',
#    '/check-income-tax-current-year',
#    '/national-minimum-wage-accommodation',
#    '/am-i-getting-minimum-wage',
#    '/browse/tax/income-tax',
#    '/keeping-your-pay-tax-records',
#    '/national-minimum-wage',
#    '/browse/working',
#    '/tax-codes']),
#  ('/contract-types-and-employer-responsibilities',
#   ['/contract-types-and-employer-responsibilities/fulltime-and-parttime-contracts',
#    '/browse/employing-people/contracts',
#    '/employer-relocation-your-rights',
#    '/employment-status',
#    '/pension-types',
#    '/self-employment-and-universal-credit',
#    '/redundancy-your-rights/notice-periods',
#    '/au-pairs-employment-law',
#    '/employing-staff']),
#  ('/transfer-visa',
#   ['/biometric-residence-permits/replace-visa-brp',
#    '/biometric-residence-permits',
#    '/contact-ukvi-inside-outside-uk',
#    '/government/publications/personal-information-use-in-borders-immigration-and-citizenship',
#    '/criminal-record-checks-apply-role',
#    '/death-spouse-benefits-tax-pension/pensions',
#    '/uk-residence-card',
#    '/update-uk-visas-immigration-account-details',
#    '/guidance/using-your-uk-visas-and-immigration-account']),
#  ...]

# %% [markdown]
# ## Ranking the subgraph

# %% [markdown]
# We now have a subgraph of 1384 nodes. How do we rank these pages so that the most 'relevant' pages to a WUJ are at the top, while the most 'irrelevant' pages to a WUJ are at the bottom?
#
# Explored:
# - session hits
# - shortest page path lengths
# - sum of the shortest page path lengths
# - between centrality
# - degree centrality
# - closeness centrality
#
# An average (non-weighted) rank for each page path was created using:
# - shortest page path length from seed0.1: `shortest_seed0_1`
# - shortest page path length from seed0.2: `shortest_seed0_2`
# - degree centrality: `g_degree`
#
# These four metrics were chosen as the assumption is that nodes close to seed0 nodes, are more likely to be associated with the same topic, and therefore the same WUJ. In addition, nodes which are more highly connected (e.g. more outgoing/incoming relationships) should be included in the WUJ, as it is expected the majority of the pages in the subgraph are mostly relevant.
#
# The others metrics were not chosen, because:
# - session hits: pages with low session hits may be relevant to a WUJ
# - sum of the shortest page path lengths: pages may be closer to one seed0 node, but far away from the other seed0 node
# - between centrality: pages relevant to a WUJ may not neccessarily have many paths that pass through. It is likely that more 'popular' pages will (i.e. ones with higher session hits)
#
#
# Caveat: browse pages are likely to be ranked highly, as these are common pages which may be highly connected to other nodes. Therefore, irrelevant browse pages are removed.

# %% [markdown]
# ### Order by session hits

# %%
sessions = list(
    sorted(
        economic_recovery_subgraph, key=lambda x: x[1]["sessionHitsAll"], reverse=True
    )
)

# %% [markdown]
# ### Order by shortest page path lengths

# %%
# calculate the paths of the shortest page path

# for two seed pages caluclat eshortest path of all pages to the seed page
shortest_paths_seed0 = nx.shortest_path_length(g, source="/browse/working/finding-job")
shortest_paths_seed1 = nx.shortest_path_length(
    g, source="/topic/further-education-skills/apprenticeships"
)

# %%
shortest_paths_seed0
# Out:
# {'/browse/working/finding-job': 0,
#  '/government/organisations/hm-revenue-customs/about/recruitment': 1,
#  '/check-uk-visa': 1,
#  '/guidance/dbs-check-requests-guidance-for-employers': 1,
#  '/jobseekers-allowance/eligibility': 1,
#  '/topic/defence-armed-forces/military-recruitment-training-operations': 1,
#  '/guidance/immigration-rules': 1,
#  '/work-reference': 1,
#  '/find-internship': 1,
#  '/national-insurance': 1,
#  '/employee-immigration-employment-status': 1,
#  '/jobseekers-allowance/report-a-change-of-circumstances': 1,
#  '/intracompany-transfer-worker-visa': 1,
#  '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes': 1,
#  '/uk-visa-sponsorship-employers': 1,
#  '/volunteering/when-you-can-volunteer': 1,
#  '/volunteering': 1,
#  '/contact-jobcentre-plus': 1,
#  '/death-spouse-benefits-tax-pension/pensions': 1,
#  '/government/collections/sponsorship-information-for-employers-and-educators': 1,
#  '/employment-status': 1,
#  '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers': 1,
#  '/become-apprentice': 1,
#  '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme': 1,
#  '/student-finance/who-qualifies': 1,
#  '/topic/work-careers/government-graduate-schemes': 1,
#  '/moving-from-benefits-to-work/support-when-you-start-working': 1,
#  '/criminal-record-check-documents': 1,
#  '/search/services': 1,
#  '/apply-universal-credit': 1,
#  '/government/publications/register-of-licensed-sponsors-workers': 1,
#  '/national-insurance/national-insurance-classes': 1,
#  '/log-in-register-hmrc-online-services': 1,
#  '/legal-right-work-uk': 1,
#  '/what-different-qualification-levels-mean': 1,
#  '/jobseekers-allowance': 1,
#  '/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2': 1,
#  '/government/publications/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens-accessible-version': 1,
#  '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations': 1,
#  '/work-health-programme': 1,
#  '/moving-from-benefits-to-work': 1,
#  '/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work': 1,
#  '/universal-credit': 1,
#  '/exchange-foreign-driving-licence': 1,
#  '/sign-in-universal-credit': 1,
#  '/register-to-vote': 1,
#  '/browse/benefits/looking-for-work': 1,
#  '/browse/working/armed-forces': 1,
#  '/contact-jobcentre-plus/new-benefit-claims': 1,
#  '/guidance/red-amber-and-green-list-rules-for-entering-england': 1,
#  '/browse/working/redundancies-dismissals': 1,
#  '/manage-your-tax-credits': 1,
#  '/check-job-applicant-right-to-work': 1,
#  '/browse/working/time-off': 1,
#  '/browse/working/rights-trade-unions': 1,
#  '/tax-credits-calculator': 1,
#  '/advertise-job': 1,
#  '/job-offers-your-rights': 1,
#  '/become-apprentice/apply-for-an-apprenticeship': 1,
#  '/browse/working': 1,
#  '/guidance/free-courses-for-jobs': 1,
#  '/view-right-to-work': 1,
#  '/get-information-about-a-company': 1,
#  '/tell-employer-or-college-about-criminal-record/driving-convictions': 1,
#  '/government/organisations': 1,
#  '/browse/education/find-course': 1,
#  '/access-to-work': 1,
#  '/browse/working/contract-working-hours': 1,
#  '/child-employment/paying': 1,
#  '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide/universal-credit-if-you-have-a-disability-or-health-condition': 1,
#  '/apply-apprenticeship': 1,
#  '/report-problem-criminal-record-certificate': 1,
#  '/tell-employer-or-college-about-criminal-record': 1,
#  '/benefits-calculators': 1,
#  '/access-to-work/after-you-have-applied': 1,
#  '/jobcentre-plus-help-for-recruiters': 1,
#  '/seasonal-worker-visa': 1,
#  '/government/publications/skilled-worker-visa-shortage-occupations': 1,
#  '/browse/employing-people/trade-unions': 1,
#  '/topic/further-education-skills/apprenticeships': 1,
#  '/browse/working/tax-minimum-wage': 1,
#  '/pip/when-your-pip-claim-is-reviewed': 1,
#  '/government/organisations/department-for-work-pensions/about': 1,
#  '/help-with-childcare-costs': 1,
#  '/guidance/immigration-rules/immigration-rules-appendix-shortage-occupation-list': 1,
#  '/government/organisations/department-for-work-pensions/about/recruitment': 1,
#  '/dbs-check-applicant-criminal-record': 1,
#  '/get-copy-military-service-records': 1,
#  '/career-skills-and-training': 1,
#  '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers': 1,
#  '/settled-status-eu-citizens-families/apply-settled-status-for-child': 1,
#  '/skilled-worker-visa/documents-you-must-provide': 1,
#  '/browse/visas-immigration/work-visas': 1,
#  '/skilled-worker-visa/knowledge-of-english': 1,
#  '/government/publications/standard-and-enhanced-dbs-check-privacy-policy/standard-and-enhanced-dbs-check-privacy-policy': 1,
#  '/improve-english-maths-it-skills': 1,
#  '/employers-checks-job-applicants': 1,
#  '/find-a-job': 1,
#  '/dbs-update-service': 1,
#  '/government/organisations/disclosure-and-barring-service': 1,
#  '/government/get-involved/take-part/volunteer': 1,
#  '/british-citizenship': 1,
#  '/criminal-record-checks-apply-role': 1,
#  '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do': 1,
#  '/looking-for-work-if-disabled': 1,
#  '/employment-rights-for-interns': 1,
#  '/tell-employer-or-college-about-criminal-record/prison-sentences': 1,
#  '/find-traineeship': 1,
#  '/contact-ukvi-inside-outside-uk': 1,
#  '/jobsearch-rights': 1,
#  '/pip/eligibility': 1,
#  '/contact-the-dvla': 1,
#  '/browse/working/workplace-personal-pensions': 1,
#  '/government/organisations/home-office': 1,
#  '/coronavirus/worker-support': 1,
#  '/contact-jobcentre-plus/change-cancel-appointment': 1,
#  '/pension-types': 2,
#  '/browse/childcare-parenting/pregnancy-birth': 2,
#  '/budgeting-help-benefits/other-help-you-can-get': 2,
#  '/education/apprenticeships-traineeships-and-internships': 2,
#  '/government/publications/new-guidance-on-the-rehabilitation-of-offenders-act-1974': 2,
#  '/plan-retirement-income/private-pensions': 2,
#  '/workplace-pensions/what-you-your-employer-and-the-government-pay': 2,
#  '/get-a-passport-urgently': 2,
#  '/tell-hmrc-change-address': 2,
#  '/apply-online-to-replace-a-driving-licence': 2,
#  '/vehicle-exempt-from-vehicle-tax': 2,
#  '/standard-visitor-visa/documents-you-will-need': 2,
#  '/discrimination-your-rights/discrimination-at-work': 2,
#  '/calculate-statutory-sick-pay': 2,
#  '/bereavement-support-payment': 2,
#  '/browse/visas-immigration/student-visas': 2,
#  '/browse/education/universities-higher-education': 2,
#  '/dvlaforms': 2,
#  '/budgeting-help-benefits/how-to-apply': 2,
#  '/overtime-your-rights/compulsory-overtime': 2,
#  '/biometric-residence-permits/report-problem': 2,
#  '/apply-for-disabled-bus-pass': 2,
#  '/government/collections/illegal-working-penalties-codes-of-practice-for-employers': 2,
#  '/standard-visitor-visa': 2,
#  '/government/publications/the-official-hmrc-app': 2,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship/borders-immigration-and-citizenship-privacy-information-notice': 2,
#  '/after-a-death/organisations-you-need-to-contact-and-tell-us-once': 2,
#  '/guidance/new-style-jobseekers-allowance': 2,
#  '/volunteering/volunteers-rights': 2,
#  '/test-and-trace-support-payment': 2,
#  '/check-mot-history': 2,
#  '/guidance/nhs-covid-pass': 2,
#  '/coronavirus/business-support': 2,
#  '/mandatory-reconsideration': 2,
#  '/rest-breaks-work/disputes': 2,
#  '/national-minimum-wage-rates': 2,
#  '/support-visit-benefit-claim': 2,
#  '/british-passport-eligibility': 2,
#  '/check-mot-status': 2,
#  '/handing-in-your-notice/gardening-leave': 2,
#  '/education/further-and-higher-education-skills-and-vocational-training': 2,
#  '/dla-disability-living-allowance-benefit': 2,
#  '/early-retirement-pension/benefits': 2,
#  '/government/publications/basic-check-guidance-and-policies': 2,
#  '/pip/how-to-claim': 2,
#  '/child-benefit-tax-calculator': 2,
#  '/guidance/statutory-sick-pay-employee-fitness-to-work': 2,
#  '/child-benefit/how-to-claim': 2,
#  '/topic/crime-policing/criminal-record-disclosure': 2,
#  '/uk-visa-sponsorship-employers/types-of-licence': 2,
#  '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service': 2,
#  '/constant-attendance-allowance': 2,
#  '/government/publications/dbs-application-forms-guide-for-applicants/dbs-application-form-guide-for-applicants': 2,
#  '/understanding-your-pay/working-out-your-pay': 2,
#  '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens': 2,
#  '/sponsor-management-system': 2,
#  '/paternity-pay-leave/eligibility': 2,
#  '/uk-visa-sponsorship-employers/sponsorship-management-roles': 2,
#  '/employers-sick-pay': 2,
#  '/government/publications/the-basic-state-pension': 2,
#  '/government/publications/dbs-workforce-guidance': 2,
#  '/marriage-allowance': 2,
#  '/guidance/eu-settlement-scheme-how-we-use-your-personal-information': 2,
#  '/workplace-pensions/changing-jobs-and-taking-leave': 2,
#  '/state-pension-age': 2,
#  '/council-housing': 2,
#  '/bank-holidays': 2,
#  '/medical-suspensions-from-work': 2,
#  '/child-employment/local-council-rules-for-child-employment-permits': 2,
#  '/standard-visitor-visa/what-you-can-do-in-the-uk': 2,
#  '/budgeting-help-benefits/after-you-apply': 2,
#  '/government/collections/new-enterprise-allowance-campaign': 2,
#  '/employment-support-allowance/how-to-claim': 2,
#  '/employ-someone': 2,
#  '/browse/births-deaths-marriages/register-offices': 2,
#  '/tax-come-to-uk': 2,
#  '/minimum-wage-different-types-work': 2,
#  '/guidance/claim-for-wages-through-the-coronavirus-job-retention-scheme': 2,
#  '/incapacity-benefit': 2,
#  '/raise-grievance-at-work': 2,
#  '/government/publications/find-a-free-level-3-qualification': 2,
#  '/tax-right-retire-abroad-return-to-uk': 2,
#  '/new-state-pension/how-its-calculated': 2,
#  '/tell-employer-or-college-about-criminal-record/cautions': 2,
#  '/browse/benefits/families': 2,
#  '/guidance/using-your-uk-visas-and-immigration-account': 2,
#  '/passport-fees': 2,
#  '/guidance/claim-a-grant-through-the-self-employment-income-support-scheme': 2,
#  '/tax-on-your-private-pension/lifetime-allowance': 2,
#  '/skilled-worker-visa/your-partner-and-children': 2,
#  '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships': 2,
#  '/paternity-pay-leave/how-to-claim': 2,
#  '/further-education-courses/financial-help': 2,
#  '/1619-bursary-fund/how-to-claim': 2,
#  '/biometric-residence-permits/collect': 2,
#  '/welfare/jobseekers-allowance': 2,
#  '/employment-support-allowance/change-of-circumstances': 2,
#  '/short-term-benefit-advance': 2,
#  '/guidance/pensions-and-compensation-for-veterans': 2,
#  '/browse/employing-people/dismissals-redundancies': 2,
#  '/government/publications/acceptable-right-to-work-documents-an-employers-guide': 2,
#  '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant': 2,
#  '/training-study-work-your-rights': 2,
#  '/guidance/digital-and-online-services': 2,
#  '/find-pension-centre': 2,
#  '/tell-hmrc-change-of-details': 2,
#  '/holiday-entitlement-rights/calculate-leave-entitlement': 2,
#  '/employer-relocation-your-rights': 2,
#  '/uk-family-visa': 2,
#  '/government/organisations/education-and-skills-funding-agency': 2,
#  '/childcare-grant': 2,
#  '/driving-medical-conditions': 2,
#  '/intensive-personalised-employment-support': 2,
#  '/self-employed-records': 2,
#  '/advanced-learner-loan': 2,
#  '/plan-for-retirement': 2,
#  '/topic/personal-tax/self-assessment': 2,
#  '/health-care-worker-visa': 2,
#  '/government/publications/find-a-skills-bootcamp': 2,
#  '/disability-living-allowance-children': 2,
#  '/apply-blue-badge': 2,
#  '/skilled-worker-visa/if-you-work-in-healthcare-or-education': 2,
#  '/what-different-qualification-levels-mean/list-of-qualification-levels': 2,
#  '/moving-from-benefits-to-work/job-search-programmes': 2,
#  '/further-education-courses/find-a-course': 2,
#  '/business-support-helpline': 2,
#  '/lost-national-insurance-number': 2,
#  '/when-mental-health-condition-becomes-disability': 2,
#  '/check-income-tax-current-year': 2,
#  '/government/organisations/pension-service': 2,
#  '/government/publications/new-enterprise-allowance-phase-2-provider-guidance/new-enterprise-allowance-phase-2-provider-guidance': 2,
#  '/cold-weather-payment': 2,
#  '/government/publications/higher-and-degree-apprenticeships': 2,
#  '/government/publications/disclosure-application-process-for-volunteers/disclosure-application-process-for-volunteers': 2,
#  '/tax-codes': 2,
#  '/paye-forms-p45-p60-p11d': 2,
#  '/government/organisations/department-of-social-security': 2,
#  '/understanding-your-pay': 2,
#  '/check-income-tax-current-year/sign-in/prove-identity': 2,
#  '/government/organisations/skills-funding-agency': 2,
#  '/workplace-bullying-and-harassment': 2,
#  '/employment-support-allowance': 2,
#  '/check-immigration-status': 2,
#  '/types-of-british-nationality/british-citizenship': 2,
#  '/pip': 2,
#  '/government/publications/dbs-update-service-employer-guide/dbs-update-service-employer-guide': 2,
#  '/carers-allowance/effect-on-other-benefits': 2,
#  '/guidance/indefinite-leave-to-remain-in-the-uk': 2,
#  '/government/organisations/hm-revenue-customs/contact': 2,
#  '/universal-credit/what-youll-get': 2,
#  '/browse/abroad/passports': 2,
#  '/your-rights-if-your-employer-is-insolvent': 2,
#  '/holiday-entitlement-rights/booking-time-off-': 2,
#  '/prove-right-to-rent': 2,
#  '/browse/citizenship/government': 2,
#  '/contracted-out/old-state-pension': 2,
#  '/find-postgraduate-teacher-training-courses': 2,
#  '/maternity-pay-leave/pay': 2,
#  '/workplace-pensions/if-you-want-to-leave-your-workplace-pension-scheme': 2,
#  '/parental-leave': 2,
#  '/browse/benefits/disability': 2,
#  '/moving-from-benefits-to-work/help-for-parents-and-carers': 2,
#  '/browse/education/school-life': 2,
#  '/personal-tax-account/sign-in/create-account': 2,
#  '/apply-council-tax-reduction': 2,
#  '/dismissal/reasons-you-can-be-dismissed': 2,
#  '/browse/tax/income-tax': 2,
#  '/severe-disablement-allowance': 2,
#  '/report-cash-in-hand-pay': 2,
#  '/probate-estate': 2,
#  '/agency-workers-your-rights': 2,
#  '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults': 2,
#  '/employment-support-allowance/what-youll-get': 2,
#  '/entering-staying-uk/foreign-nationals-working-in-uk': 2,
#  '/financial-help-disabled/disability-and-sickness-benefits': 2,
#  '/call-charges': 2,
#  '/update-uk-visas-immigration-account-details/update-your-ukvi-account': 2,
#  '/get-copy-military-service-records/apply-for-your-own-records': 2,
#  '/how-to-have-your-benefits-paid': 2,
#  '/universal-credit/contact-universal-credit': 2,
#  '/government/collections/helping-young-people-into-work': 2,
#  '/working-tax-credit': 2,
#  '/moving-from-benefits-to-work/starting-your-own-business': 2,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-dbs-check-applications-from-3-september-2018': 2,
#  '/estimate-income-tax': 2,
#  '/health-care-worker-visa/your-job': 2,
#  '/maternity-allowance/eligibility': 2,
#  '/agency-workers-your-rights/your-rights-as-a-temporary-agency-worker': 2,
#  '/redundancy-your-rights/redundancy-pay': 2,
#  '/provide-journey-contact-details-before-travel-uk': 2,
#  '/maximum-weekly-working-hours/weekly-maximum-working-hours-and-opting-out': 2,
#  '/log-in-file-self-assessment-tax-return/sign-in/prove-identity': 2,
#  '/skilled-worker-visa': 2,
#  '/government/collections/traineeships--2': 2,
#  '/skilled-worker-visa/apply-from-outside-the-uk': 2,
#  '/carers-allowance/further-information': 2,
#  '/calculate-agricultural-holiday-entitlement': 2,
#  '/guidance/covid-19-how-dbs-is-supporting-the-fight-against-coronavirus': 2,
#  '/child-employment': 2,
#  '/contracted-out/check-if-you-were-contracted-out': 2,
#  '/guidance/visa-decision-waiting-times-applications-inside-the-uk': 2,
#  '/order-copy-birth-death-marriage-certificate': 2,
#  '/sure-start-maternity-grant/how-to-claim': 2,
#  '/guidance/criminal-record-checks-for-childminders-and-childcare-workers': 2,
#  '/income-tax': 2,
#  '/attendance-allowance': 2,
#  '/student-jobs-paying-tax': 2,
#  '/apply-standard-visitor-visa': 2,
#  '/british-national-overseas-bno-visa': 2,
#  '/overseas-domestic-worker-visa': 2,
#  '/government/topical-events/plan-for-jobs': 2,
#  '/guidance/brexit-guidance-for-individuals-and-families': 2,
#  '/government/publications/dbs-check-eligible-positions-guidance': 2,
#  '/set-up-sole-trader': 2,
#  '/state-pension/circumstances-change': 2,
#  '/housing-and-universal-credit': 2,
#  '/education': 2,
#  '/guidance/tax-professional-development-programme': 2,
#  '/government/organisations/disclosure-and-barring-service/about': 2,
#  '/uk-visa-sponsorship-employers/job-suitability': 2,
#  '/benefit-overpayments/when-repayments-have-to-be-made': 2,
#  '/pension-credit': 2,
#  '/browse/employing-people/contracts': 2,
#  '/browse/tax/dealing-with-hmrc': 2,
#  '/log-in-hmrc-excise-import-export': 2,
#  '/browse/driving/vehicle-tax-mot-insurance': 2,
#  '/book-driving-test': 2,
#  '/tips-at-work': 2,
#  '/view-prove-immigration-status': 2,
#  '/order-coronavirus-rapid-lateral-flow-tests': 2,
#  '/early-retirement-pension/personal-and-workplace-pensions': 2,
#  '/business-coronavirus-support-finder': 2,
#  '/eusettledstatus': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/guidance-on-the-application-process-for-criminal-records-checks-overseas': 2,
#  '/am-i-getting-minimum-wage': 2,
#  '/find-dbs-umbrella-body': 2,
#  '/mature-student-university-funding': 2,
#  '/government/publications/qualifications-in-new-funded-offers': 2,
#  '/child-employment/restrictions-on-child-employment': 2,
#  '/tax-on-pension/how-your-tax-is-paid': 2,
#  '/guidance/brexit-guidance-for-businesses': 2,
#  '/youth-mobility': 2,
#  '/change-driving-test': 2,
#  '/guidance/apply-for-a-kickstart-scheme-grant': 2,
#  '/employing-an-apprentice': 2,
#  '/government/organisations/hm-revenue-customs/contact/self-assessment': 2,
#  '/government/organisations/companies-house': 2,
#  '/government/organisations/department-for-work-pensions/about/complaints-procedure': 2,
#  '/government/publications/child-benefit-claim-form-ch2': 2,
#  '/jobseekers-allowance/apply-new-style-jsa': 2,
#  '/employment-support-allowance/working-while-you-claim': 2,
#  '/government/publications/employment-and-support-allowance-permitted-work-form': 2,
#  '/government/publications/disclosure-application-process-for-volunteers': 2,
#  '/national-insurance/how-much-you-pay': 2,
#  '/find-out-dbs-check': 2,
#  '/what-different-qualification-levels-mean/compare-different-qualification-levels': 2,
#  '/disabled-facilities-grants': 2,
#  '/employers-sick-pay/eligibility-and-form-ssp1': 2,
#  '/self-assessment-tax-returns': 2,
#  '/work/pensions-and-ageing-society': 2,
#  '/limited-company-formation': 2,
#  '/access-to-work/what-youll-get': 2,
#  '/topic/immigration-operational-guidance': 2,
#  '/when-someone-dies': 2,
#  '/apply-online-for-student-finance': 2,
#  '/holiday-entitlement-rights/workers-furlough-coronavirus': 2,
#  '/claim-benefits-abroad/jobseekers-allowance': 2,
#  '/dla-disability-living-allowance-benefit/dla-rates': 2,
#  '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide': 2,
#  '/working-abroad': 2,
#  '/your-employment-contract-how-it-can-be-changed/making-changes': 2,
#  '/apply-marriage-allowance': 2,
#  '/ukvcas': 2,
#  '/settled-status-eu-citizens-families/if-you-have-permanent-residence-or-indefinite-leave-to-remain': 2,
#  '/parents-learning-allowance': 2,
#  '/browse/driving/learning-to-drive': 2,
#  '/personal-pensions-your-rights': 2,
#  '/settled-status-eu-citizens-families': 2,
#  '/employment-contracts-and-conditions/contract-terms': 2,
#  '/biometric-residence-permits/lost-stolen-damaged': 2,
#  '/browse/disabilities/benefits': 2,
#  '/apply-home-equipment-for-disabled': 2,
#  '/browse/childcare-parenting/financial-help-children': 2,
#  '/guidance/universal-credit-and-students': 2,
#  '/how-tax-credits-affect-other-benefits': 2,
#  '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa': 2,
#  '/short-term-benefit-advance/how-to-apply': 2,
#  '/government/publications/apprenticeship-funding-bands': 2,
#  '/guidance/temporary-jobcentres-during-the-coronavirus-covid-19-pandemic': 2,
#  '/holiday-entitlement-rights/taking-holiday-before-leaving-a-job': 2,
#  '/topic/business-tax/paye': 2,
#  '/government/publications/access-to-work-factsheet/access-to-work-factsheet-for-customers': 2,
#  '/time-off-for-dependants/taking-time-off': 2,
#  '/get-proof-employment-history': 2,
#  '/search/news-and-communications': 2,
#  '/fixed-term-contracts': 2,
#  '/looking-for-work-if-disabled/applying-for-a-job': 2,
#  '/tell-employer-or-college-about-criminal-record/fines-and-compensation': 2,
#  '/financial-help-disabled/vat-relief': 2,
#  '/claim-national-insurance-refund': 2,
#  '/renewing-your-tax-credits-claim': 2,
#  '/overtime-your-rights': 2,
#  '/browse/business/finance-support': 2,
#  '/financial-help-disabled': 2,
#  '/income-support/income-support-rates': 2,
#  '/register-for-self-assessment': 2,
#  '/national-insurance/change-of-circumstance': 2,
#  '/sold-bought-vehicle': 2,
#  '/government/publications/apprenticeship-recruitment-employers-and-training-organisations': 2,
#  '/income-support/report-a-change-of-circumstances': 2,
#  '/find-pension-contact-details': 2,
#  '/financial-help-disabled/vehicles-and-transport': 2,
#  '/chwilio-am-swydd': 2,
#  '/start-up-visa': 2,
#  '/carers-credit/eligibility': 2,
#  '/child-tax-credit/how-to-claim': 2,
#  '/guidance/government-legal-service-gls-legal-trainee-scheme-how-to-apply': 2,
#  '/check-british-citizenship': 2,
#  '/temporary-worker-charity-worker-visa': 2,
#  '/jobcentre-plus-help-for-recruiters/work-trials': 2,
#  '/disciplinary-procedures-and-action-at-work': 2,
#  '/workplace-pensions/joining-a-workplace-pension': 2,
#  '/government/organisations/department-of-health-and-social-care': 2,
#  '/government/collections/eu-settlement-scheme-applicant-information': 2,
#  '/new-state-pension/how-to-claim': 2,
#  '/early-retirement-pension': 2,
#  '/budgeting-help-benefits/what-youll-get': 2,
#  '/tax-free-childcare': 2,
#  '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means': 2,
#  '/income-tax-rates': 2,
#  '/guidance/check-if-you-could-be-covered-by-the-coronavirus-job-retention-scheme': 2,
#  '/advanced-learner-loan/how-to-apply': 2,
#  '/tell-employer-or-college-about-criminal-record/check-your-conviction-caution': 2,
#  '/right-to-reside': 2,
#  '/claim-tax-credits': 2,
#  '/student-visa/extend-your-visa': 2,
#  '/government/collections/statutory-sick-pay-and-leave': 2,
#  '/further-education-courses/if-youre-16-or-17': 2,
#  '/topic/personal-tax/income-tax': 2,
#  '/sunday-working': 2,
#  '/find-an-immigration-adviser': 2,
#  '/carers-allowance-unit': 2,
#  '/get-coronavirus-test': 2,
#  '/change-circumstances-visa-brp': 2,
#  '/copy-of-police-records': 2,
#  '/bereavement-support-payment/how-to-claim': 2,
#  '/browse/abroad/travel-abroad': 2,
#  '/employee-rights-when-on-leave': 2,
#  '/maximum-weekly-working-hours/calculating-your-working-hours': 2,
#  '/renew-adult-passport/renew': 2,
#  '/claim-redundancy': 2,
#  '/government/publications/access-to-work-guide-for-employers/access-to-work-factsheet-for-employers': 2,
#  '/winter-fuel-payment': 2,
#  '/national-minimum-wage/who-gets-the-minimum-wage': 2,
#  '/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance': 2,
#  '/help': 2,
#  '/government/publications/right-to-work-checks-employers-guide': 2,
#  '/guidance/new-immigration-system-what-you-need-to-know': 2,
#  '/search/research-and-statistics': 2,
#  '/carers-allowance-report-change': 2,
#  '/get-a-passport-urgently/online-premium-service': 2,
#  '/employment-contracts-and-conditions': 2,
#  '/state-pension-through-partner': 2,
#  '/biometric-residence-permits/replace-expired-brp': 2,
#  '/child-trust-funds': 2,
#  '/carers-credit/how-to-claim': 2,
#  '/income-tax/taxfree-and-taxable-state-benefits': 2,
#  '/statutory-sick-pay/how-to-claim': 2,
#  '/employing-staff': 2,
#  '/working-tax-credit/what-youll-get': 2,
#  '/government/publications/paye-starter-checklist': 2,
#  '/browse/disabilities/rights': 2,
#  '/national-insurance-rates-letters/category-letters': 2,
#  '/check-state-pension': 2,
#  '/guidance/dbs-online-account-guidance': 2,
#  '/child-benefit-move-to-uk': 2,
#  '/1619-bursary-fund': 2,
#  '/view-driving-licence': 2,
#  '/tax-national-insurance-after-state-pension-age': 2,
#  '/state-pension': 2,
#  '/guidance/national-minimum-wage-work-experience-and-internships': 2,
#  '/paye-forms-p45-p60-p11d/p60': 2,
#  '/employer-preventing-discrimination': 2,
#  '/browse/citizenship/citizenship': 2,
#  '/employment-support-allowance/eligibility': 2,
#  '/browse/benefits/unable-to-work': 2,
#  '/government/publications/the-national-minimum-wage-in-2021': 2,
#  '/access-to-work/renew': 2,
#  '/carers-allowance': 2,
#  '/get-paye-forms-p45-p60': 2,
#  '/browse/visas-immigration/family-visas': 2,
#  '/vehicles-can-drive': 2,
#  '/definition-of-disability-under-equality-act-2010': 2,
#  '/government/organisations/uk-visas-and-immigration': 2,
#  '/guidance/universal-credit-advances': 2,
#  '/dual-citizenship': 2,
#  '/child-benefit/eligibility': 2,
#  '/settled-status-eu-citizens-families/switch-from-presettled-status-to-settled-status': 2,
#  '/government/publications/your-new-state-pension-explained/your-state-pension-explained': 2,
#  '/redundancy-payments-helpline': 2,
#  '/transferring-your-pension': 2,
#  '/student-visa': 2,
#  '/contact-jobcentre-plus/existing-benefit-claims': 2,
#  '/browse/visas-immigration/tourist-short-stay-visas': 2,
#  '/paternity-pay-leave': 2,
#  '/browse/citizenship/charities-honours': 2,
#  '/browse/visas-immigration/commonwealth-british-nationals-overseas': 2,
#  '/set-up-business': 2,
#  '/biometric-residence-permits/personal-data': 2,
#  '/universal-credit/eligibility': 2,
#  '/minimum-wage-different-types-work/paid-by-the-hour': 2,
#  '/government/publications/eu-settlement-scheme-application-processing-times/eu-settlement-scheme-pilot-current-expected-processing-times-for-applications': 2,
#  '/how-to-claim-new-style-jsa': 2,
#  '/government/organisations/foreign-commonwealth-development-office': 2,
#  '/child-benefit-16-19': 2,
#  '/deferring-state-pension/how-to-claim-a-deferred-state-pension': 2,
#  '/browse/benefits/bereavement': 2,
#  '/self-employment-and-universal-credit': 2,
#  '/apply-to-come-to-the-uk/prepare-your-application': 2,
#  '/contract-types-and-employer-responsibilities/fulltime-and-parttime-contracts': 2,
#  '/uk-residence-card': 2,
#  '/appeal-benefit-decision': 2,
#  '/bereavement-support-payment/what-youll-get': 2,
#  '/tax-national-insurance-after-state-pension-age/stopping-paying-national-insurance': 2,
#  '/handing-in-your-notice/payment-during-your-notice-period': 2,
#  '/guidance/traineeship-information-for-trainees': 2,
#  '/handing-in-your-notice/giving-notice': 2,
#  '/sign-in-childcare-account': 2,
#  '/apply-sponsor-licence': 2,
#  '/your-employment-contract-how-it-can-be-changed': 2,
#  '/uk-border-control/before-you-leave-for-the-uk': 2,
#  '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education': 2,
#  '/guidance/prove-your-right-to-work-eu-eea-and-swiss-citizens': 2,
#  '/reduced-national-insurance-married-women': 2,
#  '/guidance/manage-apprenticeship-funds': 2,
#  '/personal-pensions-your-rights/how-you-can-take-pension': 2,
#  '/dbs-check-applicant-criminal-record/get-a-basic-dbs-check-for-an-employee': 2,
#  '/government/publications/right-to-work-checklist': 2,
#  '/guidance/eu-settlement-scheme-uk-tax-and-benefits-records-automated-check': 2,
#  '/browse/disabilities/work': 2,
#  '/topic/benefits-credits/child-benefit': 2,
#  '/if-you-become-disabled/if-youre-in-employment-and-become-disabled': 2,
#  '/tax-relief-for-employees': 2,
#  '/check-income-tax-current-year/sign-in/create-account': 2,
#  '/additional-state-pension': 2,
#  '/advanced-learner-loan/what-youll-get': 2,
#  '/fraud-error-prevention-centres': 2,
#  '/holiday-entitlement-rights': 2,
#  '/reduced-earnings-allowance': 2,
#  '/log-in-register-hmrc-online-services/register': 2,
#  '/youth-mobility/eligibility': 2,
#  '/contact-pension-service': 2,
#  '/disability-premiums': 2,
#  '/dismissal/unfair-and-constructive-dismissal': 2,
#  '/government/publications/view-and-prove-your-immigration-status-evisa/your-immigration-status-an-introduction-for-eu-eea-and-swiss-citizens-accessible-version': 2,
#  '/state-pension-if-you-retire-abroad': 2,
#  '/apply-first-provisional-driving-licence': 2,
#  '/government/collections/statutory-pay-forms': 2,
#  '/discrimination-your-rights': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-q-z': 2,
#  '/government/collections/dbs-eligibility-guidance': 2,
#  '/voluntary-national-insurance-contributions/who-can-pay-voluntary-contributions': 2,
#  '/advanced-learner-loan/eligibility': 2,
#  '/statutory-sick-pay/eligibility': 2,
#  '/income-support': 2,
#  '/browse/visas-immigration/what-you-need-to-do': 2,
#  '/state-pension/eligibility': 2,
#  '/maternity-allowance/what-youll-get': 2,
#  '/legal-obligations-drivers-riders': 2,
#  '/government/publications/eu-settlement-scheme-application-processing-times': 2,
#  '/benefit-overpayments/how-to-make-a-repayment': 2,
#  '/guidance/incentive-payments-for-hiring-a-new-apprentice': 2,
#  '/government/publications/dbs-filtering-guidance': 2,
#  '/national-insurance/help-if-youre-not-working': 2,
#  '/biometric-residence-permits/replace-visa-brp': 2,
#  '/government/collections/desg-graduate-scheme': 2,
#  '/government/organisations/foreign-commonwealth-office': 2,
#  '/budgeting-help-benefits/eligibility': 2,
#  '/employment-status/employee': 2,
#  '/maternity-pay-leave/how-to-claim': 2,
#  '/browse/driving/driving-licences': 2,
#  '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022': 2,
#  '/guidance/working-safely-during-covid-19': 2,
#  '/guidance/redundancy-help-finding-work-and-claiming-benefits': 2,
#  '/calculate-your-redundancy-pay': 2,
#  '/national-minimum-wage/employers-and-the-minimum-wage': 2,
#  '/welfare/entitlement': 2,
#  '/new-state-pension/living-and-working-overseas': 2,
#  '/browse/benefits/low-income': 2,
#  '/income-tax/how-you-pay-income-tax': 2,
#  '/redundancy-your-rights/consultation': 2,
#  '/jobcentre-plus-help-for-recruiters/recruitment-advice-and-support': 2,
#  '/personal-pensions-your-rights/choosing-personal-pension': 2,
#  '/additional-state-pension/inheriting': 2,
#  '/keeping-your-pay-tax-records': 2,
#  '/statutory-sick-pay': 2,
#  '/government/collections/right-to-work-checks-employer-guidance': 2,
#  '/over-80-pension/how-to-claim': 2,
#  '/government/organisations/hm-revenue-customs/contact/change-your-personal-details': 2,
#  '/right-of-abode': 2,
#  '/night-working-hours': 2,
#  '/government/organisations/hm-revenue-customs/services-information': 2,
#  '/learner-support': 2,
#  '/government/publications/jobseekers-allowance-sanctions-leaflet/jobseekers-allowance-sanctions-how-to-keep-your-benefit-payment': 2,
#  '/national-insurance-rates-letters': 2,
#  '/find-coronavirus-support': 2,
#  '/government/collections/apprenticeship-vacancies': 2,
#  '/uk-family-visa/partner-spouse': 2,
#  '/higher-education-courses-find-and-apply': 2,
#  '/working-for-yourself': 2,
#  '/skilled-worker-visa/when-you-can-be-paid-less': 2,
#  '/government/organisations/hm-revenue-customs/contact/online-services-helpdesk': 2,
#  '/government/publications/find-a-skills-bootcamp/list-of-skills-bootcamps': 2,
#  '/disabled-students-allowance-dsa': 2,
#  '/government/publications/view-and-prove-your-immigration-status-evisa': 2,
#  '/guidance/check-employment-status-for-tax': 2,
#  '/housing-benefit/how-to-claim': 2,
#  '/rest-breaks-work': 2,
#  '/maternity-pay-leave/leave': 2,
#  '/guidance/claim-for-wage-costs-through-the-coronavirus-job-retention-scheme': 2,
#  '/browse/visas-immigration/arriving-in-the-uk': 2,
#  '/graduate-visa/course-you-studied': 2,
#  '/employing-an-apprentice/pay-and-conditions-for-apprentices': 2,
#  '/settled-status-eu-citizens-families/what-youll-need-to-apply': 2,
#  '/guidance/coronavirus-covid-19-advice-for-uk-visa-applicants-and-temporary-uk-residents': 2,
#  '/national-concessionary-fuel-scheme': 2,
#  '/update-uk-visas-immigration-account-details': 2,
#  '/guidance/benefits-and-pensions-for-uk-nationals-in-the-eea-or-switzerland': 2,
#  '/student-finance': 2,
#  '/government/publications/find-a-free-level-3-qualification/list-of-colleges-and-training-providers-able-to-offer-free-places-for-level-3-qualifications': 2,
#  '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries': 2,
#  '/adoption-pay-leave': 2,
#  '/employment-support-allowance/your-esa-claim': 2,
#  '/national-insurance-credits': 2,
#  '/government/collections/kickstart-scheme': 2,
#  '/plan-retirement-income/get-financial-advice': 2,
#  '/check-vehicle-tax': 2,
#  '/agricultural-sick-pay': 2,
#  '/maternity-paternity-pay-leave': 2,
#  '/government/organisations/department-for-work-pensions': 2,
#  '/workplace-pensions': 2,
#  '/standard-visitor-visa/eligibility': 2,
#  '/student-finance/new-fulltime-students': 2,
#  '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus': 2,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-standardenhanced-dbs-check-applications-from-1-july-2021': 2,
#  '/new-state-pension/your-national-insurance-record-and-your-state-pension': 2,
#  '/redundancy-your-rights/being-selected-for-redundancy': 2,
#  '/new-state-pension/youve-been-in-a-workplace-personal-or-stakeholder-pension': 2,
#  '/apply-national-insurance-number': 2,
#  '/cold-weather-payment/eligibility': 2,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-numbers': 2,
#  '/voluntary-national-insurance-contributions/deadlines': 2,
#  '/government/collections/fit-note': 2,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals': 2,
#  '/identitycards': 2,
#  '/pip/claiming-pip-if-youre-terminally-ill': 2,
#  '/government/publications/dbs-application-forms-guide-for-applicants': 2,
#  '/benefit-fraud': 2,
#  '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed': 2,
#  '/moving-from-benefits-to-work/help-for-specific-problems': 2,
#  '/check-tenant-right-to-rent-documents': 2,
#  '/income-tax/find-out-if-you-need-to-pay-income-tax': 2,
#  '/government/organisations/hm-revenue-customs/contact/child-benefit': 2,
#  '/universal-credit/your-responsibilities': 2,
#  '/get-a-passport-urgently/1-week-fast-track-service': 2,
#  '/tax-on-your-private-pension/annual-allowance': 2,
#  '/new-state-pension/what-youll-get': 2,
#  '/apply-renew-passport': 2,
#  '/guidance/booking-and-staying-in-a-quarantine-hotel-when-you-arrive-in-england': 2,
#  '/winter-fuel-payment/how-much-youll-get': 2,
#  '/penalties-for-employing-illegal-workers': 2,
#  '/disability-premiums/eligibility': 2,
#  '/career-breaks': 2,
#  '/workplace-pensions/managing-your-pension': 2,
#  '/government/publications/easy-read-get-help-at-work-if-youre-disabled-or-have-a-health-condition-access-to-work': 2,
#  '/voluntary-national-insurance-contributions/rates': 2,
#  '/come-uk-married': 2,
#  '/guidance/travel-to-england-from-another-country-during-coronavirus-covid-19': 2,
#  '/tax-on-pension': 2,
#  '/government/publications/access-to-work-guide-for-employers': 2,
#  '/learn-to-drive-a-car': 2,
#  '/voluntary-national-insurance-contributions': 2,
#  '/tell-hmrc-change-of-details/income-changes': 2,
#  '/browse/visas-immigration/settle-in-the-uk': 2,
#  '/pension-credit-calculator': 2,
#  '/redundancy-your-rights': 2,
#  '/guidance/traineeship-information-for-employers': 2,
#  '/guidance/new-style-employment-and-support-allowance': 2,
#  '/paye-forms-p45-p60-p11d/lost-paye-forms': 2,
#  '/browse/disabilities/equipment': 2,
#  '/guidance/barring-referrals': 2,
#  '/council-tax': 2,
#  '/volunteering/pay-and-expenses': 2,
#  '/national-minimum-wage-accommodation': 2,
#  '/paye-forms-p45-p60-p11d/p11d': 2,
#  '/calculate-your-holiday-entitlement': 2,
#  '/browse/visas-immigration/asylum': 2,
#  '/government/publications/maternity-allowance-claim-form': 2,
#  '/eu-eea': 2,
#  '/universal-credit/changes-of-circumstances': 2,
#  '/the-warm-home-discount-scheme/energy-suppliers': 2,
#  '/check-driving-information': 2,
#  '/jobseekers-allowance/apply-new-style-jsa/eligibility': 2,
#  '/passport-advice-line': 2,
#  '/guidance/rehabilitation-periods': 2,
#  '/benefit-cap': 2,
#  '/employing-an-apprentice/get-funding': 2,
#  '/financial-help-disabled/on-a-low-salary': 2,
#  '/student-finance-register-login': 2,
#  '/guidance/eu-settlement-scheme-evidence-of-uk-residence': 2,
#  '/government/publications/dbs-certificate-disputes-and-fingerprint-consent-forms-and-guidance-af14-af15': 2,
#  '/government/organisations/hm-revenue-customs/contact/get-help-with-the-self-employment-income-support-scheme': 2,
#  '/guidance/coronavirus-covid-19-what-to-do-if-youre-employed-and-cannot-work': 2,
#  '/graduate-visa': 2,
#  '/pay-and-work-rights': 2,
#  '/uk-benefits-abroad': 2,
#  '/government/publications/sure-start-maternity-grant-claim-form': 2,
#  '/visit-uk-holiday-family-friends': 2,
#  '/data-protection': 2,
#  '/government/publications/dbs-continuation-sheet': 2,
#  '/tell-employer-or-college-about-criminal-record/what-information-you-need-to-give': 2,
#  '/find-a-visa-application-centre': 2,
#  '/reasonable-adjustments-for-disabled-workers': 2,
#  '/government/publications/dbs-list-of-offences-that-will-never-be-filtered-from-a-criminal-record-check': 2,
#  '/get-state-pension': 2,
#  '/apply-citizenship-indefinite-leave-to-remain': 2,
#  '/dismissal/what-to-do-if-youre-dismissed': 2,
#  '/guidance/search-for-apprenticeship-standards': 2,
#  '/guidance/travel-abroad-from-england-during-coronavirus-covid-19': 2,
#  '/apply-for-student-finance': 2,
#  '/guidance/using-the-eu-exit-id-document-check-app': 2,
#  '/topic/further-education-skills/vocational-qualifications': 2,
#  '/topic/personal-tax/national-insurance': 2,
#  '/government/publications/dbs-filtering-guidance/dbs-filtering-guide': 2,
#  '/register-for-self-assessment/self-employed': 2,
#  '/care-to-learn': 2,
#  '/health-conditions-disability-universal-credit': 2,
#  '/industrial-injuries-disablement-benefit': 2,
#  '/financial-help-disabled/television-licence-discount': 2,
#  '/guidance/find-out-about-money-taken-off-your-universal-credit-payment': 2,
#  '/browse/employing-people/time-off': 2,
#  '/overtime-your-rights/parttime-workers': 2,
#  '/cold-weather-payment/how-to-claim': 2,
#  '/government/publications/register-of-licensed-sponsors-students': 2,
#  '/guidance/register-of-apprenticeship-training-providers': 2,
#  '/browse/education/student-finance': 2,
#  '/get-copy-military-service-records/apply-for-someone-elses-records': 2,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes': 2,
#  '/settled-status-eu-citizens-families/eligibility': 2,
#  '/get-help-savings-low-income': 2,
#  '/housing-benefit/other-help-with-housing-costs': 2,
#  '/government/organisations/department-for-education/services-information': 2,
#  '/plan-retirement-income': 2,
#  '/state-pension/inheritance': 2,
#  '/browse/births-deaths-marriages/child': 2,
#  '/rights-disabled-person': 2,
#  '/universal-credit/how-to-claim': 2,
#  '/part-time-worker-rights': 2,
#  '/guidance/coronavirus-covid-19-right-to-work-checks': 2,
#  '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions': 2,
#  '/government/publications/apprenticeship-technical-funding-guide': 2,
#  '/pip/change-of-circumstances': 2,
#  '/terminal-illness-benefits': 2,
#  '/benefit-cap/benefit-cap-amounts': 2,
#  '/government/publications/apprenticeship-agreement-template': 2,
#  '/tell-dvla-changed-address': 2,
#  '/what-is-the-construction-industry-scheme': 2,
#  '/skilled-worker-visa/how-much-it-costs': 2,
#  '/government/publications/dbs-update-service-applicant-guide/dbs-update-service-applicant-guide': 2,
#  '/uk-border-control': 2,
#  '/government/publications/dwp-jobcentre-register': 2,
#  '/government/publications/statutory-sick-pay-employee-not-entitled-form-for-employers': 2,
#  '/government/publications/dbs-update-service-applicant-guide': 2,
#  '/handing-in-your-notice': 2,
#  '/renew-adult-passport': 2,
#  '/tax-help': 2,
#  '/housing-and-universal-credit/renting-from-private-landlord': 2,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship': 2,
#  '/child-benefit/what-youll-get': 2,
#  '/tax-on-pension-death-benefits': 2,
#  '/disciplinary-procedures-and-action-at-work/how-disciplinary-procedures-work': 2,
#  '/topic/further-education-skills/administration': 2,
#  '/become-apprentice/pay-and-conditions': 2,
#  '/find-a-regulated-qualification': 2,
#  '/payment-exception-service': 2,
#  '/fixed-term-contracts/employees-rights': 2,
#  '/entering-staying-uk': 2,
#  '/guidance/basic-dbs-checks-guidance': 2,
#  '/deferring-state-pension/what-you-get': 2,
#  '/redundancy-your-rights/notice-periods': 2,
#  '/view-right-to-rent': 2,
#  '/windrush-prove-your-right-to-be-in-the-uk': 2,
#  '/maximum-weekly-working-hours': 2,
#  '/access-to-work/eligibility': 2,
#  '/courses-qualifications': 2,
#  '/employment-status/worker': 2,
#  '/further-education-skills/apprenticeships': 2,
#  '/national-insurance/what-national-insurance-is-for': 2,
#  '/tax-on-your-private-pension/pension-tax-relief': 2,
#  '/personal-tax-account': 2,
#  '/topic/dealing-with-hmrc/paying-hmrc': 2,
#  '/guidance/recruiting-people-from-outside-the-uk': 2,
#  '/employers-sick-pay/entitlement': 2,
#  '/pension-credit/eligibility': 2,
#  '/find-lost-utr-number': 2,
#  '/book-theory-test': 2,
#  '/settled-status-eu-citizens-families/applying-for-settled-status': 2,
#  '/disability-premiums/how-to-claim': 2,
#  '/sign-in-help-to-save': 2,
#  '/government/publications/basic-check-guidance-and-policies/basic-check-id-checking-guidelines-from-1-july-2021': 2,
#  '/government/collections/dbs-filtering-guidance': 2,
#  '/independent-livingfund': 2,
#  '/claim-benefits-abroad': 2,
#  '/over-80-pension/further-information': 2,
#  '/time-off-for-dependants/whats-an-emergency': 2,
#  '/parental-leave/entitlement': 2,
#  '/student-visa/money': 2,
#  '/check-national-insurance-record': 2,
#  '/vehicle-tax': 2,
#  '/flexible-working': 2,
#  '/topic/immigration-operational-guidance/immigration-rules': 2,
#  '/changes-affect-tax-credits': 2,
#  '/uk-visa-sponsorship-employers/eligibility': 2,
#  '/get-ready-to-employ-someone': 2,
#  '/contact-student-finance-england': 2,
#  '/frontier-worker-permit': 2,
#  '/pip/what-youll-get': 2,
#  '/jobseekers-allowance/your-jsa-claim': 2,
#  '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403': 2,
#  '/guidance/visa-decision-waiting-times-applications-outside-the-uk': 2,
#  '/new-state-pension': 2,
#  '/pension-credit/how-to-claim': 2,
#  '/claim-loss-notice': 2,
#  '/guidance/contact-the-department-for-work-and-pensions-about-its-policies': 2,
#  '/caution-warning-penalty': 2,
#  '/tell-employer-or-college-about-criminal-record/discharges': 2,
#  '/financial-help-disabled/home-and-housing': 2,
#  '/national-insurance-if-you-go-abroad': 2,
#  '/id-for-driving-licence': 2,
#  '/benefit-cap/when-youre-not-affected': 2,
#  '/child-benefit': 2,
#  '/continuous-employment-what-it-is': 2,
#  '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member': 2,
#  '/government/publications/application-for-a-state-pension-statement': 2,
#  '/foreign-travel-advice': 2,
#  '/biometric-residence-permits/not-arrived': 2,
#  '/report-benefits-change-circumstances': 2,
#  '/au-pairs-employment-law': 2,
#  '/family-permit': 2,
#  '/maternity-pay-leave': 2,
#  '/government/collections/dbs-checking-service-guidance--2': 2,
#  '/self-employed-national-insurance-rates': 2,
#  '/browse/employing-people/recruiting-hiring': 2,
#  '/the-warm-home-discount-scheme': 2,
#  '/pension-credit/what-youll-get': 2,
#  '/taking-sick-leave': 2,
#  '/carers-allowance/if-youre-working-': 2,
#  '/agency-workers-your-rights/basic-information-you-should-receive': 2,
#  '/budgeting-help-benefits/repayments': 2,
#  '/become-appointee-for-someone-claiming-benefits': 2,
#  '/government/organisations/hm-revenue-customs': 2,
#  '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments': 2,
#  '/child-employment/performance-licences-for-children': 2,
#  '/housing-benefit': 2,
#  '/understanding-your-pay/deductions-from-your-pay': 2,
#  '/government-authorised-exchange': 2,
#  '/government/organisations/home-office/about/recruitment': 2,
#  '/transfer-visa': 2,
#  '/apply-start-up-loan': 2,
#  '/government/collections/hm-revenue-and-customs-service-availability-and-issues': 2,
#  '/working-tax-credit/how-to-claim': 2,
#  '/search/policy-papers-and-consultations': 2,
#  '/claim-tax-refund': 2,
#  '/government/organisations/driver-and-vehicle-licensing-agency': 2,
#  '/apply-to-come-to-the-uk/prove-your-identity': 2,
#  '/discrimination-your-rights/how-you-can-be-discriminated-against': 2,
#  '/national-insurance-credits/eligibility': 2,
#  '/apply-to-come-to-the-uk': 2,
#  '/carers-allowance/how-to-claim': 2,
#  '/universal-credit/other-financial-support': 2,
#  '/whistleblowing': 2,
#  '/business-finance-support': 2,
#  '/apply-for-elderly-person-bus-pass': 2,
#  '/international-pension-centre': 2,
#  '/appeal-call-up-reserve-forces': 2,
#  '/bills-benefits': 2,
#  '/moving-from-benefits-to-work/work-experience-and-volunteering': 2,
#  '/further-education-courses': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants': 2,
#  '/armed-forces-pension-calculator': 2,
#  '/national-insurance/your-national-insurance-number': 2,
#  '/redundancy-your-rights/get-help-finding-a-new-job': 2,
#  '/state-pension/what-youll-get': 2,
#  '/carers-credit': 2,
#  '/biometric-residence-permits': 2,
#  '/settled-status-eu-citizens-families/after-youve-applied': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-a-to-f-applying-for-a-criminal-records-check-for-someone-from-overseas': 2,
#  '/universal-credit/how-youre-paid': 2,
#  '/travel-abroad': 2,
#  '/working-retirement-pension-age': 2,
#  '/government/publications/skilled-worker-visa-eligible-occupations': 2,
#  '/apply-housing-benefit-from-council': 2,
#  '/child-benefit-payment-dates': 2,
#  '/moving-or-retiring-abroad': 2,
#  '/parental-bereavement-pay-leave': 2,
#  '/council-tax-bands': 2,
#  '/find-travel-test-provider': 2,
#  '/criminal-record-checks-apply-role/application-process': 2,
#  '/browse/benefits/manage-your-benefit': 2,
#  '/universal-credit/how-your-earnings-affect-your-payments': 2,
#  '/flexible-working/types-of-flexible-working': 2,
#  '/benefit-cap/how-earnings-affect-when-benefit-cap-starts': 2,
#  '/housing-benefit/what-youll-get': 2,
#  '/browse/visas-immigration/immigration-appeals': 2,
#  '/flexible-working/applying-for-flexible-working': 2,
#  '/maternity-pay-leave/extra-help': 2,
#  '/get-tax-free-childcare': 2,
#  '/find-local-council': 2,
#  '/statutory-sick-pay/what-youll-get': 2,
#  '/get-help-hmrc-extra-support': 2,
#  '/international-agreement-worker-visa': 2,
#  '/guidance/coronavirus-covid-19-testing-for-people-travelling-to-england': 2,
#  '/dbs-check-applicant-criminal-record/get-a-standard-or-enhanced-dbs-check-for-an-employee': 2,
#  '/skilled-worker-visa/switch-to-this-visa': 2,
#  '/tax-company-benefits': 2,
#  '/guidance/plan-for-jobs-skills-and-employment-programmes-information-for-employers': 2,
#  '/if-you-become-disabled': 2,
#  '/change-address-driving-licence': 2,
#  '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees': 2,
#  '/access-to-work/report-a-change-of-circumstances': 2,
#  '/assisted-digital-help-online-applications': 2,
#  '/payslips': 2,
#  '/log-in-file-self-assessment-tax-return': 2,
#  '/tax-on-pension/tax-free': 2,
#  '/recruit-apprentice': 2,
#  '/new-state-pension/inheriting-or-increasing-state-pension-from-a-spouse-or-civil-partner': 2,
#  '/guidance/pay-apprenticeship-levy': 2,
#  '/benefit-overpayments': 2,
#  '/topic/business-tax/pension-scheme-administration': 2,
#  '/tax-uk-income-live-abroad': 2,
#  '/advanced-learner-loan/bursary-fund': 2,
#  '/browse/childcare-parenting/childcare': 2,
#  '/deferring-state-pension': 2,
#  '/tax-codes/tell-hmrc-about-a-change-tax-code': 2,
#  '/rest-breaks-work/compensatory-rest': 2,
#  '/solve-workplace-dispute': 2,
#  '/working-when-pregnant-your-rights': 2,
#  '/the-warm-home-discount-scheme/low-income': 2,
#  '/government/publications/dbs-identity-checking-guidelines': 2,
#  '/register-employer': 2,
#  '/national-minimum-wage': 2,
#  '/personal-tax-account/sign-in/prove-identity': 2,
#  '/guidance/return-to-your-claim-for-the-self-employment-income-support-scheme': 2,
#  '/guidance/track-a-dbs-application': 2,
#  '/time-off-for-dependants/problems-when-you-take-time-off': 2,
#  '/employers-workplace-pensions-rules': 2,
#  '/settled-status-eu-citizens-families/family-member-eligible-person-from-northern-ireland': 2,
#  '/government/publications/apprenticeships-off-the-job-training': 2,
#  '/report-problem-criminal-record-certificate/dispute-a-mistake': 2,
#  '/income-tax/check-youre-paying-the-right-amount': 2,
#  '/time-off-for-dependants': 2,
#  '/guidance/how-your-trading-conditions-affect-your-eligibility-for-the-self-employment-income-support-scheme': 2,
#  '/settle-in-the-uk': 2,
#  '/income-support/if-you-already-get-income-support': 2,
#  '/contracted-out/new-state-pension': 2,
#  '/rest-breaks-work/taking-breaks': 2,
#  '/check-state-pension/sign-in/prove-identity': 2,
#  '/government/collections/apprenticeship-changes': 2,
#  '/government/publications/introducing-govuk-verify/introducing-govuk-verify': 2,
#  '/search/guidance-and-regulation': 2,
#  '/employing-an-apprentice/apprenticeship-agreement': 2,
#  '/sure-start-maternity-grant/what-youll-get': 2,
#  '/pension-credit/change-of-circumstances': 2,
#  '/death-spouse-benefits-tax-pension/benefits': 2,
#  '/guidance/apprenticeship-funding-rules': 2,
#  '/uk-visa-sponsorship-employers/apply-for-your-licence': 2,
#  '/guidance/responsible-organisations': 2,
#  '/government/organisations/department-for-education': 2,
#  '/employment-contracts-and-conditions/written-statement-of-employment-particulars': 2,
#  '/careers-helpline-for-teenagers': 2,
#  '/paternity-pay-leave/pay': 2,
#  '/contract-types-and-employer-responsibilities': 2,
#  '/government/publications/traineeship-providers': 2,
#  '/join-trade-union': 2,
#  ...}

# %%
# seeed0.1: shortest_paths_seed0.1: '/browse/working/finding-job'
shortest_seed0_1 = {
    k: v
    for k, v in sorted(
        shortest_paths_seed0.items(), key=lambda item: item[1], reverse=False
    )
}

# %%
shortest_seed0_1
# Out:
# {'/browse/working/finding-job': 0,
#  '/government/organisations/hm-revenue-customs/about/recruitment': 1,
#  '/check-uk-visa': 1,
#  '/guidance/dbs-check-requests-guidance-for-employers': 1,
#  '/jobseekers-allowance/eligibility': 1,
#  '/topic/defence-armed-forces/military-recruitment-training-operations': 1,
#  '/guidance/immigration-rules': 1,
#  '/work-reference': 1,
#  '/find-internship': 1,
#  '/national-insurance': 1,
#  '/employee-immigration-employment-status': 1,
#  '/jobseekers-allowance/report-a-change-of-circumstances': 1,
#  '/intracompany-transfer-worker-visa': 1,
#  '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes': 1,
#  '/uk-visa-sponsorship-employers': 1,
#  '/volunteering/when-you-can-volunteer': 1,
#  '/volunteering': 1,
#  '/contact-jobcentre-plus': 1,
#  '/death-spouse-benefits-tax-pension/pensions': 1,
#  '/government/collections/sponsorship-information-for-employers-and-educators': 1,
#  '/employment-status': 1,
#  '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers': 1,
#  '/become-apprentice': 1,
#  '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme': 1,
#  '/student-finance/who-qualifies': 1,
#  '/topic/work-careers/government-graduate-schemes': 1,
#  '/moving-from-benefits-to-work/support-when-you-start-working': 1,
#  '/criminal-record-check-documents': 1,
#  '/search/services': 1,
#  '/apply-universal-credit': 1,
#  '/government/publications/register-of-licensed-sponsors-workers': 1,
#  '/national-insurance/national-insurance-classes': 1,
#  '/log-in-register-hmrc-online-services': 1,
#  '/legal-right-work-uk': 1,
#  '/what-different-qualification-levels-mean': 1,
#  '/jobseekers-allowance': 1,
#  '/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2': 1,
#  '/government/publications/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens-accessible-version': 1,
#  '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations': 1,
#  '/work-health-programme': 1,
#  '/moving-from-benefits-to-work': 1,
#  '/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work': 1,
#  '/universal-credit': 1,
#  '/exchange-foreign-driving-licence': 1,
#  '/sign-in-universal-credit': 1,
#  '/register-to-vote': 1,
#  '/browse/benefits/looking-for-work': 1,
#  '/browse/working/armed-forces': 1,
#  '/contact-jobcentre-plus/new-benefit-claims': 1,
#  '/guidance/red-amber-and-green-list-rules-for-entering-england': 1,
#  '/browse/working/redundancies-dismissals': 1,
#  '/manage-your-tax-credits': 1,
#  '/check-job-applicant-right-to-work': 1,
#  '/browse/working/time-off': 1,
#  '/browse/working/rights-trade-unions': 1,
#  '/tax-credits-calculator': 1,
#  '/advertise-job': 1,
#  '/job-offers-your-rights': 1,
#  '/become-apprentice/apply-for-an-apprenticeship': 1,
#  '/browse/working': 1,
#  '/guidance/free-courses-for-jobs': 1,
#  '/view-right-to-work': 1,
#  '/get-information-about-a-company': 1,
#  '/tell-employer-or-college-about-criminal-record/driving-convictions': 1,
#  '/government/organisations': 1,
#  '/browse/education/find-course': 1,
#  '/access-to-work': 1,
#  '/browse/working/contract-working-hours': 1,
#  '/child-employment/paying': 1,
#  '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide/universal-credit-if-you-have-a-disability-or-health-condition': 1,
#  '/apply-apprenticeship': 1,
#  '/report-problem-criminal-record-certificate': 1,
#  '/tell-employer-or-college-about-criminal-record': 1,
#  '/benefits-calculators': 1,
#  '/access-to-work/after-you-have-applied': 1,
#  '/jobcentre-plus-help-for-recruiters': 1,
#  '/seasonal-worker-visa': 1,
#  '/government/publications/skilled-worker-visa-shortage-occupations': 1,
#  '/browse/employing-people/trade-unions': 1,
#  '/topic/further-education-skills/apprenticeships': 1,
#  '/browse/working/tax-minimum-wage': 1,
#  '/pip/when-your-pip-claim-is-reviewed': 1,
#  '/government/organisations/department-for-work-pensions/about': 1,
#  '/help-with-childcare-costs': 1,
#  '/guidance/immigration-rules/immigration-rules-appendix-shortage-occupation-list': 1,
#  '/government/organisations/department-for-work-pensions/about/recruitment': 1,
#  '/dbs-check-applicant-criminal-record': 1,
#  '/get-copy-military-service-records': 1,
#  '/career-skills-and-training': 1,
#  '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers': 1,
#  '/settled-status-eu-citizens-families/apply-settled-status-for-child': 1,
#  '/skilled-worker-visa/documents-you-must-provide': 1,
#  '/browse/visas-immigration/work-visas': 1,
#  '/skilled-worker-visa/knowledge-of-english': 1,
#  '/government/publications/standard-and-enhanced-dbs-check-privacy-policy/standard-and-enhanced-dbs-check-privacy-policy': 1,
#  '/improve-english-maths-it-skills': 1,
#  '/employers-checks-job-applicants': 1,
#  '/find-a-job': 1,
#  '/dbs-update-service': 1,
#  '/government/organisations/disclosure-and-barring-service': 1,
#  '/government/get-involved/take-part/volunteer': 1,
#  '/british-citizenship': 1,
#  '/criminal-record-checks-apply-role': 1,
#  '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do': 1,
#  '/looking-for-work-if-disabled': 1,
#  '/employment-rights-for-interns': 1,
#  '/tell-employer-or-college-about-criminal-record/prison-sentences': 1,
#  '/find-traineeship': 1,
#  '/contact-ukvi-inside-outside-uk': 1,
#  '/jobsearch-rights': 1,
#  '/pip/eligibility': 1,
#  '/contact-the-dvla': 1,
#  '/browse/working/workplace-personal-pensions': 1,
#  '/government/organisations/home-office': 1,
#  '/coronavirus/worker-support': 1,
#  '/contact-jobcentre-plus/change-cancel-appointment': 1,
#  '/pension-types': 2,
#  '/browse/childcare-parenting/pregnancy-birth': 2,
#  '/budgeting-help-benefits/other-help-you-can-get': 2,
#  '/education/apprenticeships-traineeships-and-internships': 2,
#  '/government/publications/new-guidance-on-the-rehabilitation-of-offenders-act-1974': 2,
#  '/plan-retirement-income/private-pensions': 2,
#  '/workplace-pensions/what-you-your-employer-and-the-government-pay': 2,
#  '/get-a-passport-urgently': 2,
#  '/tell-hmrc-change-address': 2,
#  '/apply-online-to-replace-a-driving-licence': 2,
#  '/vehicle-exempt-from-vehicle-tax': 2,
#  '/standard-visitor-visa/documents-you-will-need': 2,
#  '/discrimination-your-rights/discrimination-at-work': 2,
#  '/calculate-statutory-sick-pay': 2,
#  '/bereavement-support-payment': 2,
#  '/browse/visas-immigration/student-visas': 2,
#  '/browse/education/universities-higher-education': 2,
#  '/dvlaforms': 2,
#  '/budgeting-help-benefits/how-to-apply': 2,
#  '/overtime-your-rights/compulsory-overtime': 2,
#  '/biometric-residence-permits/report-problem': 2,
#  '/apply-for-disabled-bus-pass': 2,
#  '/government/collections/illegal-working-penalties-codes-of-practice-for-employers': 2,
#  '/standard-visitor-visa': 2,
#  '/government/publications/the-official-hmrc-app': 2,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship/borders-immigration-and-citizenship-privacy-information-notice': 2,
#  '/after-a-death/organisations-you-need-to-contact-and-tell-us-once': 2,
#  '/guidance/new-style-jobseekers-allowance': 2,
#  '/volunteering/volunteers-rights': 2,
#  '/test-and-trace-support-payment': 2,
#  '/check-mot-history': 2,
#  '/guidance/nhs-covid-pass': 2,
#  '/coronavirus/business-support': 2,
#  '/mandatory-reconsideration': 2,
#  '/rest-breaks-work/disputes': 2,
#  '/national-minimum-wage-rates': 2,
#  '/support-visit-benefit-claim': 2,
#  '/british-passport-eligibility': 2,
#  '/check-mot-status': 2,
#  '/handing-in-your-notice/gardening-leave': 2,
#  '/education/further-and-higher-education-skills-and-vocational-training': 2,
#  '/dla-disability-living-allowance-benefit': 2,
#  '/early-retirement-pension/benefits': 2,
#  '/government/publications/basic-check-guidance-and-policies': 2,
#  '/pip/how-to-claim': 2,
#  '/child-benefit-tax-calculator': 2,
#  '/guidance/statutory-sick-pay-employee-fitness-to-work': 2,
#  '/child-benefit/how-to-claim': 2,
#  '/topic/crime-policing/criminal-record-disclosure': 2,
#  '/uk-visa-sponsorship-employers/types-of-licence': 2,
#  '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service': 2,
#  '/constant-attendance-allowance': 2,
#  '/government/publications/dbs-application-forms-guide-for-applicants/dbs-application-form-guide-for-applicants': 2,
#  '/understanding-your-pay/working-out-your-pay': 2,
#  '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens': 2,
#  '/sponsor-management-system': 2,
#  '/paternity-pay-leave/eligibility': 2,
#  '/uk-visa-sponsorship-employers/sponsorship-management-roles': 2,
#  '/employers-sick-pay': 2,
#  '/government/publications/the-basic-state-pension': 2,
#  '/government/publications/dbs-workforce-guidance': 2,
#  '/marriage-allowance': 2,
#  '/guidance/eu-settlement-scheme-how-we-use-your-personal-information': 2,
#  '/workplace-pensions/changing-jobs-and-taking-leave': 2,
#  '/state-pension-age': 2,
#  '/council-housing': 2,
#  '/bank-holidays': 2,
#  '/medical-suspensions-from-work': 2,
#  '/child-employment/local-council-rules-for-child-employment-permits': 2,
#  '/standard-visitor-visa/what-you-can-do-in-the-uk': 2,
#  '/budgeting-help-benefits/after-you-apply': 2,
#  '/government/collections/new-enterprise-allowance-campaign': 2,
#  '/employment-support-allowance/how-to-claim': 2,
#  '/employ-someone': 2,
#  '/browse/births-deaths-marriages/register-offices': 2,
#  '/tax-come-to-uk': 2,
#  '/minimum-wage-different-types-work': 2,
#  '/guidance/claim-for-wages-through-the-coronavirus-job-retention-scheme': 2,
#  '/incapacity-benefit': 2,
#  '/raise-grievance-at-work': 2,
#  '/government/publications/find-a-free-level-3-qualification': 2,
#  '/tax-right-retire-abroad-return-to-uk': 2,
#  '/new-state-pension/how-its-calculated': 2,
#  '/tell-employer-or-college-about-criminal-record/cautions': 2,
#  '/browse/benefits/families': 2,
#  '/guidance/using-your-uk-visas-and-immigration-account': 2,
#  '/passport-fees': 2,
#  '/guidance/claim-a-grant-through-the-self-employment-income-support-scheme': 2,
#  '/tax-on-your-private-pension/lifetime-allowance': 2,
#  '/skilled-worker-visa/your-partner-and-children': 2,
#  '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships': 2,
#  '/paternity-pay-leave/how-to-claim': 2,
#  '/further-education-courses/financial-help': 2,
#  '/1619-bursary-fund/how-to-claim': 2,
#  '/biometric-residence-permits/collect': 2,
#  '/welfare/jobseekers-allowance': 2,
#  '/employment-support-allowance/change-of-circumstances': 2,
#  '/short-term-benefit-advance': 2,
#  '/guidance/pensions-and-compensation-for-veterans': 2,
#  '/browse/employing-people/dismissals-redundancies': 2,
#  '/government/publications/acceptable-right-to-work-documents-an-employers-guide': 2,
#  '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant': 2,
#  '/training-study-work-your-rights': 2,
#  '/guidance/digital-and-online-services': 2,
#  '/find-pension-centre': 2,
#  '/tell-hmrc-change-of-details': 2,
#  '/holiday-entitlement-rights/calculate-leave-entitlement': 2,
#  '/employer-relocation-your-rights': 2,
#  '/uk-family-visa': 2,
#  '/government/organisations/education-and-skills-funding-agency': 2,
#  '/childcare-grant': 2,
#  '/driving-medical-conditions': 2,
#  '/intensive-personalised-employment-support': 2,
#  '/self-employed-records': 2,
#  '/advanced-learner-loan': 2,
#  '/plan-for-retirement': 2,
#  '/topic/personal-tax/self-assessment': 2,
#  '/health-care-worker-visa': 2,
#  '/government/publications/find-a-skills-bootcamp': 2,
#  '/disability-living-allowance-children': 2,
#  '/apply-blue-badge': 2,
#  '/skilled-worker-visa/if-you-work-in-healthcare-or-education': 2,
#  '/what-different-qualification-levels-mean/list-of-qualification-levels': 2,
#  '/moving-from-benefits-to-work/job-search-programmes': 2,
#  '/further-education-courses/find-a-course': 2,
#  '/business-support-helpline': 2,
#  '/lost-national-insurance-number': 2,
#  '/when-mental-health-condition-becomes-disability': 2,
#  '/check-income-tax-current-year': 2,
#  '/government/organisations/pension-service': 2,
#  '/government/publications/new-enterprise-allowance-phase-2-provider-guidance/new-enterprise-allowance-phase-2-provider-guidance': 2,
#  '/cold-weather-payment': 2,
#  '/government/publications/higher-and-degree-apprenticeships': 2,
#  '/government/publications/disclosure-application-process-for-volunteers/disclosure-application-process-for-volunteers': 2,
#  '/tax-codes': 2,
#  '/paye-forms-p45-p60-p11d': 2,
#  '/government/organisations/department-of-social-security': 2,
#  '/understanding-your-pay': 2,
#  '/check-income-tax-current-year/sign-in/prove-identity': 2,
#  '/government/organisations/skills-funding-agency': 2,
#  '/workplace-bullying-and-harassment': 2,
#  '/employment-support-allowance': 2,
#  '/check-immigration-status': 2,
#  '/types-of-british-nationality/british-citizenship': 2,
#  '/pip': 2,
#  '/government/publications/dbs-update-service-employer-guide/dbs-update-service-employer-guide': 2,
#  '/carers-allowance/effect-on-other-benefits': 2,
#  '/guidance/indefinite-leave-to-remain-in-the-uk': 2,
#  '/government/organisations/hm-revenue-customs/contact': 2,
#  '/universal-credit/what-youll-get': 2,
#  '/browse/abroad/passports': 2,
#  '/your-rights-if-your-employer-is-insolvent': 2,
#  '/holiday-entitlement-rights/booking-time-off-': 2,
#  '/prove-right-to-rent': 2,
#  '/browse/citizenship/government': 2,
#  '/contracted-out/old-state-pension': 2,
#  '/find-postgraduate-teacher-training-courses': 2,
#  '/maternity-pay-leave/pay': 2,
#  '/workplace-pensions/if-you-want-to-leave-your-workplace-pension-scheme': 2,
#  '/parental-leave': 2,
#  '/browse/benefits/disability': 2,
#  '/moving-from-benefits-to-work/help-for-parents-and-carers': 2,
#  '/browse/education/school-life': 2,
#  '/personal-tax-account/sign-in/create-account': 2,
#  '/apply-council-tax-reduction': 2,
#  '/dismissal/reasons-you-can-be-dismissed': 2,
#  '/browse/tax/income-tax': 2,
#  '/severe-disablement-allowance': 2,
#  '/report-cash-in-hand-pay': 2,
#  '/probate-estate': 2,
#  '/agency-workers-your-rights': 2,
#  '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults': 2,
#  '/employment-support-allowance/what-youll-get': 2,
#  '/entering-staying-uk/foreign-nationals-working-in-uk': 2,
#  '/financial-help-disabled/disability-and-sickness-benefits': 2,
#  '/call-charges': 2,
#  '/update-uk-visas-immigration-account-details/update-your-ukvi-account': 2,
#  '/get-copy-military-service-records/apply-for-your-own-records': 2,
#  '/how-to-have-your-benefits-paid': 2,
#  '/universal-credit/contact-universal-credit': 2,
#  '/government/collections/helping-young-people-into-work': 2,
#  '/working-tax-credit': 2,
#  '/moving-from-benefits-to-work/starting-your-own-business': 2,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-dbs-check-applications-from-3-september-2018': 2,
#  '/estimate-income-tax': 2,
#  '/health-care-worker-visa/your-job': 2,
#  '/maternity-allowance/eligibility': 2,
#  '/agency-workers-your-rights/your-rights-as-a-temporary-agency-worker': 2,
#  '/redundancy-your-rights/redundancy-pay': 2,
#  '/provide-journey-contact-details-before-travel-uk': 2,
#  '/maximum-weekly-working-hours/weekly-maximum-working-hours-and-opting-out': 2,
#  '/log-in-file-self-assessment-tax-return/sign-in/prove-identity': 2,
#  '/skilled-worker-visa': 2,
#  '/government/collections/traineeships--2': 2,
#  '/skilled-worker-visa/apply-from-outside-the-uk': 2,
#  '/carers-allowance/further-information': 2,
#  '/calculate-agricultural-holiday-entitlement': 2,
#  '/guidance/covid-19-how-dbs-is-supporting-the-fight-against-coronavirus': 2,
#  '/child-employment': 2,
#  '/contracted-out/check-if-you-were-contracted-out': 2,
#  '/guidance/visa-decision-waiting-times-applications-inside-the-uk': 2,
#  '/order-copy-birth-death-marriage-certificate': 2,
#  '/sure-start-maternity-grant/how-to-claim': 2,
#  '/guidance/criminal-record-checks-for-childminders-and-childcare-workers': 2,
#  '/income-tax': 2,
#  '/attendance-allowance': 2,
#  '/student-jobs-paying-tax': 2,
#  '/apply-standard-visitor-visa': 2,
#  '/british-national-overseas-bno-visa': 2,
#  '/overseas-domestic-worker-visa': 2,
#  '/government/topical-events/plan-for-jobs': 2,
#  '/guidance/brexit-guidance-for-individuals-and-families': 2,
#  '/government/publications/dbs-check-eligible-positions-guidance': 2,
#  '/set-up-sole-trader': 2,
#  '/state-pension/circumstances-change': 2,
#  '/housing-and-universal-credit': 2,
#  '/education': 2,
#  '/guidance/tax-professional-development-programme': 2,
#  '/government/organisations/disclosure-and-barring-service/about': 2,
#  '/uk-visa-sponsorship-employers/job-suitability': 2,
#  '/benefit-overpayments/when-repayments-have-to-be-made': 2,
#  '/pension-credit': 2,
#  '/browse/employing-people/contracts': 2,
#  '/browse/tax/dealing-with-hmrc': 2,
#  '/log-in-hmrc-excise-import-export': 2,
#  '/browse/driving/vehicle-tax-mot-insurance': 2,
#  '/book-driving-test': 2,
#  '/tips-at-work': 2,
#  '/view-prove-immigration-status': 2,
#  '/order-coronavirus-rapid-lateral-flow-tests': 2,
#  '/early-retirement-pension/personal-and-workplace-pensions': 2,
#  '/business-coronavirus-support-finder': 2,
#  '/eusettledstatus': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/guidance-on-the-application-process-for-criminal-records-checks-overseas': 2,
#  '/am-i-getting-minimum-wage': 2,
#  '/find-dbs-umbrella-body': 2,
#  '/mature-student-university-funding': 2,
#  '/government/publications/qualifications-in-new-funded-offers': 2,
#  '/child-employment/restrictions-on-child-employment': 2,
#  '/tax-on-pension/how-your-tax-is-paid': 2,
#  '/guidance/brexit-guidance-for-businesses': 2,
#  '/youth-mobility': 2,
#  '/change-driving-test': 2,
#  '/guidance/apply-for-a-kickstart-scheme-grant': 2,
#  '/employing-an-apprentice': 2,
#  '/government/organisations/hm-revenue-customs/contact/self-assessment': 2,
#  '/government/organisations/companies-house': 2,
#  '/government/organisations/department-for-work-pensions/about/complaints-procedure': 2,
#  '/government/publications/child-benefit-claim-form-ch2': 2,
#  '/jobseekers-allowance/apply-new-style-jsa': 2,
#  '/employment-support-allowance/working-while-you-claim': 2,
#  '/government/publications/employment-and-support-allowance-permitted-work-form': 2,
#  '/government/publications/disclosure-application-process-for-volunteers': 2,
#  '/national-insurance/how-much-you-pay': 2,
#  '/find-out-dbs-check': 2,
#  '/what-different-qualification-levels-mean/compare-different-qualification-levels': 2,
#  '/disabled-facilities-grants': 2,
#  '/employers-sick-pay/eligibility-and-form-ssp1': 2,
#  '/self-assessment-tax-returns': 2,
#  '/work/pensions-and-ageing-society': 2,
#  '/limited-company-formation': 2,
#  '/access-to-work/what-youll-get': 2,
#  '/topic/immigration-operational-guidance': 2,
#  '/when-someone-dies': 2,
#  '/apply-online-for-student-finance': 2,
#  '/holiday-entitlement-rights/workers-furlough-coronavirus': 2,
#  '/claim-benefits-abroad/jobseekers-allowance': 2,
#  '/dla-disability-living-allowance-benefit/dla-rates': 2,
#  '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide': 2,
#  '/working-abroad': 2,
#  '/your-employment-contract-how-it-can-be-changed/making-changes': 2,
#  '/apply-marriage-allowance': 2,
#  '/ukvcas': 2,
#  '/settled-status-eu-citizens-families/if-you-have-permanent-residence-or-indefinite-leave-to-remain': 2,
#  '/parents-learning-allowance': 2,
#  '/browse/driving/learning-to-drive': 2,
#  '/personal-pensions-your-rights': 2,
#  '/settled-status-eu-citizens-families': 2,
#  '/employment-contracts-and-conditions/contract-terms': 2,
#  '/biometric-residence-permits/lost-stolen-damaged': 2,
#  '/browse/disabilities/benefits': 2,
#  '/apply-home-equipment-for-disabled': 2,
#  '/browse/childcare-parenting/financial-help-children': 2,
#  '/guidance/universal-credit-and-students': 2,
#  '/how-tax-credits-affect-other-benefits': 2,
#  '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa': 2,
#  '/short-term-benefit-advance/how-to-apply': 2,
#  '/government/publications/apprenticeship-funding-bands': 2,
#  '/guidance/temporary-jobcentres-during-the-coronavirus-covid-19-pandemic': 2,
#  '/holiday-entitlement-rights/taking-holiday-before-leaving-a-job': 2,
#  '/topic/business-tax/paye': 2,
#  '/government/publications/access-to-work-factsheet/access-to-work-factsheet-for-customers': 2,
#  '/time-off-for-dependants/taking-time-off': 2,
#  '/get-proof-employment-history': 2,
#  '/search/news-and-communications': 2,
#  '/fixed-term-contracts': 2,
#  '/looking-for-work-if-disabled/applying-for-a-job': 2,
#  '/tell-employer-or-college-about-criminal-record/fines-and-compensation': 2,
#  '/financial-help-disabled/vat-relief': 2,
#  '/claim-national-insurance-refund': 2,
#  '/renewing-your-tax-credits-claim': 2,
#  '/overtime-your-rights': 2,
#  '/browse/business/finance-support': 2,
#  '/financial-help-disabled': 2,
#  '/income-support/income-support-rates': 2,
#  '/register-for-self-assessment': 2,
#  '/national-insurance/change-of-circumstance': 2,
#  '/sold-bought-vehicle': 2,
#  '/government/publications/apprenticeship-recruitment-employers-and-training-organisations': 2,
#  '/income-support/report-a-change-of-circumstances': 2,
#  '/find-pension-contact-details': 2,
#  '/financial-help-disabled/vehicles-and-transport': 2,
#  '/chwilio-am-swydd': 2,
#  '/start-up-visa': 2,
#  '/carers-credit/eligibility': 2,
#  '/child-tax-credit/how-to-claim': 2,
#  '/guidance/government-legal-service-gls-legal-trainee-scheme-how-to-apply': 2,
#  '/check-british-citizenship': 2,
#  '/temporary-worker-charity-worker-visa': 2,
#  '/jobcentre-plus-help-for-recruiters/work-trials': 2,
#  '/disciplinary-procedures-and-action-at-work': 2,
#  '/workplace-pensions/joining-a-workplace-pension': 2,
#  '/government/organisations/department-of-health-and-social-care': 2,
#  '/government/collections/eu-settlement-scheme-applicant-information': 2,
#  '/new-state-pension/how-to-claim': 2,
#  '/early-retirement-pension': 2,
#  '/budgeting-help-benefits/what-youll-get': 2,
#  '/tax-free-childcare': 2,
#  '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means': 2,
#  '/income-tax-rates': 2,
#  '/guidance/check-if-you-could-be-covered-by-the-coronavirus-job-retention-scheme': 2,
#  '/advanced-learner-loan/how-to-apply': 2,
#  '/tell-employer-or-college-about-criminal-record/check-your-conviction-caution': 2,
#  '/right-to-reside': 2,
#  '/claim-tax-credits': 2,
#  '/student-visa/extend-your-visa': 2,
#  '/government/collections/statutory-sick-pay-and-leave': 2,
#  '/further-education-courses/if-youre-16-or-17': 2,
#  '/topic/personal-tax/income-tax': 2,
#  '/sunday-working': 2,
#  '/find-an-immigration-adviser': 2,
#  '/carers-allowance-unit': 2,
#  '/get-coronavirus-test': 2,
#  '/change-circumstances-visa-brp': 2,
#  '/copy-of-police-records': 2,
#  '/bereavement-support-payment/how-to-claim': 2,
#  '/browse/abroad/travel-abroad': 2,
#  '/employee-rights-when-on-leave': 2,
#  '/maximum-weekly-working-hours/calculating-your-working-hours': 2,
#  '/renew-adult-passport/renew': 2,
#  '/claim-redundancy': 2,
#  '/government/publications/access-to-work-guide-for-employers/access-to-work-factsheet-for-employers': 2,
#  '/winter-fuel-payment': 2,
#  '/national-minimum-wage/who-gets-the-minimum-wage': 2,
#  '/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance': 2,
#  '/help': 2,
#  '/government/publications/right-to-work-checks-employers-guide': 2,
#  '/guidance/new-immigration-system-what-you-need-to-know': 2,
#  '/search/research-and-statistics': 2,
#  '/carers-allowance-report-change': 2,
#  '/get-a-passport-urgently/online-premium-service': 2,
#  '/employment-contracts-and-conditions': 2,
#  '/state-pension-through-partner': 2,
#  '/biometric-residence-permits/replace-expired-brp': 2,
#  '/child-trust-funds': 2,
#  '/carers-credit/how-to-claim': 2,
#  '/income-tax/taxfree-and-taxable-state-benefits': 2,
#  '/statutory-sick-pay/how-to-claim': 2,
#  '/employing-staff': 2,
#  '/working-tax-credit/what-youll-get': 2,
#  '/government/publications/paye-starter-checklist': 2,
#  '/browse/disabilities/rights': 2,
#  '/national-insurance-rates-letters/category-letters': 2,
#  '/check-state-pension': 2,
#  '/guidance/dbs-online-account-guidance': 2,
#  '/child-benefit-move-to-uk': 2,
#  '/1619-bursary-fund': 2,
#  '/view-driving-licence': 2,
#  '/tax-national-insurance-after-state-pension-age': 2,
#  '/state-pension': 2,
#  '/guidance/national-minimum-wage-work-experience-and-internships': 2,
#  '/paye-forms-p45-p60-p11d/p60': 2,
#  '/employer-preventing-discrimination': 2,
#  '/browse/citizenship/citizenship': 2,
#  '/employment-support-allowance/eligibility': 2,
#  '/browse/benefits/unable-to-work': 2,
#  '/government/publications/the-national-minimum-wage-in-2021': 2,
#  '/access-to-work/renew': 2,
#  '/carers-allowance': 2,
#  '/get-paye-forms-p45-p60': 2,
#  '/browse/visas-immigration/family-visas': 2,
#  '/vehicles-can-drive': 2,
#  '/definition-of-disability-under-equality-act-2010': 2,
#  '/government/organisations/uk-visas-and-immigration': 2,
#  '/guidance/universal-credit-advances': 2,
#  '/dual-citizenship': 2,
#  '/child-benefit/eligibility': 2,
#  '/settled-status-eu-citizens-families/switch-from-presettled-status-to-settled-status': 2,
#  '/government/publications/your-new-state-pension-explained/your-state-pension-explained': 2,
#  '/redundancy-payments-helpline': 2,
#  '/transferring-your-pension': 2,
#  '/student-visa': 2,
#  '/contact-jobcentre-plus/existing-benefit-claims': 2,
#  '/browse/visas-immigration/tourist-short-stay-visas': 2,
#  '/paternity-pay-leave': 2,
#  '/browse/citizenship/charities-honours': 2,
#  '/browse/visas-immigration/commonwealth-british-nationals-overseas': 2,
#  '/set-up-business': 2,
#  '/biometric-residence-permits/personal-data': 2,
#  '/universal-credit/eligibility': 2,
#  '/minimum-wage-different-types-work/paid-by-the-hour': 2,
#  '/government/publications/eu-settlement-scheme-application-processing-times/eu-settlement-scheme-pilot-current-expected-processing-times-for-applications': 2,
#  '/how-to-claim-new-style-jsa': 2,
#  '/government/organisations/foreign-commonwealth-development-office': 2,
#  '/child-benefit-16-19': 2,
#  '/deferring-state-pension/how-to-claim-a-deferred-state-pension': 2,
#  '/browse/benefits/bereavement': 2,
#  '/self-employment-and-universal-credit': 2,
#  '/apply-to-come-to-the-uk/prepare-your-application': 2,
#  '/contract-types-and-employer-responsibilities/fulltime-and-parttime-contracts': 2,
#  '/uk-residence-card': 2,
#  '/appeal-benefit-decision': 2,
#  '/bereavement-support-payment/what-youll-get': 2,
#  '/tax-national-insurance-after-state-pension-age/stopping-paying-national-insurance': 2,
#  '/handing-in-your-notice/payment-during-your-notice-period': 2,
#  '/guidance/traineeship-information-for-trainees': 2,
#  '/handing-in-your-notice/giving-notice': 2,
#  '/sign-in-childcare-account': 2,
#  '/apply-sponsor-licence': 2,
#  '/your-employment-contract-how-it-can-be-changed': 2,
#  '/uk-border-control/before-you-leave-for-the-uk': 2,
#  '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education': 2,
#  '/guidance/prove-your-right-to-work-eu-eea-and-swiss-citizens': 2,
#  '/reduced-national-insurance-married-women': 2,
#  '/guidance/manage-apprenticeship-funds': 2,
#  '/personal-pensions-your-rights/how-you-can-take-pension': 2,
#  '/dbs-check-applicant-criminal-record/get-a-basic-dbs-check-for-an-employee': 2,
#  '/government/publications/right-to-work-checklist': 2,
#  '/guidance/eu-settlement-scheme-uk-tax-and-benefits-records-automated-check': 2,
#  '/browse/disabilities/work': 2,
#  '/topic/benefits-credits/child-benefit': 2,
#  '/if-you-become-disabled/if-youre-in-employment-and-become-disabled': 2,
#  '/tax-relief-for-employees': 2,
#  '/check-income-tax-current-year/sign-in/create-account': 2,
#  '/additional-state-pension': 2,
#  '/advanced-learner-loan/what-youll-get': 2,
#  '/fraud-error-prevention-centres': 2,
#  '/holiday-entitlement-rights': 2,
#  '/reduced-earnings-allowance': 2,
#  '/log-in-register-hmrc-online-services/register': 2,
#  '/youth-mobility/eligibility': 2,
#  '/contact-pension-service': 2,
#  '/disability-premiums': 2,
#  '/dismissal/unfair-and-constructive-dismissal': 2,
#  '/government/publications/view-and-prove-your-immigration-status-evisa/your-immigration-status-an-introduction-for-eu-eea-and-swiss-citizens-accessible-version': 2,
#  '/state-pension-if-you-retire-abroad': 2,
#  '/apply-first-provisional-driving-licence': 2,
#  '/government/collections/statutory-pay-forms': 2,
#  '/discrimination-your-rights': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-q-z': 2,
#  '/government/collections/dbs-eligibility-guidance': 2,
#  '/voluntary-national-insurance-contributions/who-can-pay-voluntary-contributions': 2,
#  '/advanced-learner-loan/eligibility': 2,
#  '/statutory-sick-pay/eligibility': 2,
#  '/income-support': 2,
#  '/browse/visas-immigration/what-you-need-to-do': 2,
#  '/state-pension/eligibility': 2,
#  '/maternity-allowance/what-youll-get': 2,
#  '/legal-obligations-drivers-riders': 2,
#  '/government/publications/eu-settlement-scheme-application-processing-times': 2,
#  '/benefit-overpayments/how-to-make-a-repayment': 2,
#  '/guidance/incentive-payments-for-hiring-a-new-apprentice': 2,
#  '/government/publications/dbs-filtering-guidance': 2,
#  '/national-insurance/help-if-youre-not-working': 2,
#  '/biometric-residence-permits/replace-visa-brp': 2,
#  '/government/collections/desg-graduate-scheme': 2,
#  '/government/organisations/foreign-commonwealth-office': 2,
#  '/budgeting-help-benefits/eligibility': 2,
#  '/employment-status/employee': 2,
#  '/maternity-pay-leave/how-to-claim': 2,
#  '/browse/driving/driving-licences': 2,
#  '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022': 2,
#  '/guidance/working-safely-during-covid-19': 2,
#  '/guidance/redundancy-help-finding-work-and-claiming-benefits': 2,
#  '/calculate-your-redundancy-pay': 2,
#  '/national-minimum-wage/employers-and-the-minimum-wage': 2,
#  '/welfare/entitlement': 2,
#  '/new-state-pension/living-and-working-overseas': 2,
#  '/browse/benefits/low-income': 2,
#  '/income-tax/how-you-pay-income-tax': 2,
#  '/redundancy-your-rights/consultation': 2,
#  '/jobcentre-plus-help-for-recruiters/recruitment-advice-and-support': 2,
#  '/personal-pensions-your-rights/choosing-personal-pension': 2,
#  '/additional-state-pension/inheriting': 2,
#  '/keeping-your-pay-tax-records': 2,
#  '/statutory-sick-pay': 2,
#  '/government/collections/right-to-work-checks-employer-guidance': 2,
#  '/over-80-pension/how-to-claim': 2,
#  '/government/organisations/hm-revenue-customs/contact/change-your-personal-details': 2,
#  '/right-of-abode': 2,
#  '/night-working-hours': 2,
#  '/government/organisations/hm-revenue-customs/services-information': 2,
#  '/learner-support': 2,
#  '/government/publications/jobseekers-allowance-sanctions-leaflet/jobseekers-allowance-sanctions-how-to-keep-your-benefit-payment': 2,
#  '/national-insurance-rates-letters': 2,
#  '/find-coronavirus-support': 2,
#  '/government/collections/apprenticeship-vacancies': 2,
#  '/uk-family-visa/partner-spouse': 2,
#  '/higher-education-courses-find-and-apply': 2,
#  '/working-for-yourself': 2,
#  '/skilled-worker-visa/when-you-can-be-paid-less': 2,
#  '/government/organisations/hm-revenue-customs/contact/online-services-helpdesk': 2,
#  '/government/publications/find-a-skills-bootcamp/list-of-skills-bootcamps': 2,
#  '/disabled-students-allowance-dsa': 2,
#  '/government/publications/view-and-prove-your-immigration-status-evisa': 2,
#  '/guidance/check-employment-status-for-tax': 2,
#  '/housing-benefit/how-to-claim': 2,
#  '/rest-breaks-work': 2,
#  '/maternity-pay-leave/leave': 2,
#  '/guidance/claim-for-wage-costs-through-the-coronavirus-job-retention-scheme': 2,
#  '/browse/visas-immigration/arriving-in-the-uk': 2,
#  '/graduate-visa/course-you-studied': 2,
#  '/employing-an-apprentice/pay-and-conditions-for-apprentices': 2,
#  '/settled-status-eu-citizens-families/what-youll-need-to-apply': 2,
#  '/guidance/coronavirus-covid-19-advice-for-uk-visa-applicants-and-temporary-uk-residents': 2,
#  '/national-concessionary-fuel-scheme': 2,
#  '/update-uk-visas-immigration-account-details': 2,
#  '/guidance/benefits-and-pensions-for-uk-nationals-in-the-eea-or-switzerland': 2,
#  '/student-finance': 2,
#  '/government/publications/find-a-free-level-3-qualification/list-of-colleges-and-training-providers-able-to-offer-free-places-for-level-3-qualifications': 2,
#  '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries': 2,
#  '/adoption-pay-leave': 2,
#  '/employment-support-allowance/your-esa-claim': 2,
#  '/national-insurance-credits': 2,
#  '/government/collections/kickstart-scheme': 2,
#  '/plan-retirement-income/get-financial-advice': 2,
#  '/check-vehicle-tax': 2,
#  '/agricultural-sick-pay': 2,
#  '/maternity-paternity-pay-leave': 2,
#  '/government/organisations/department-for-work-pensions': 2,
#  '/workplace-pensions': 2,
#  '/standard-visitor-visa/eligibility': 2,
#  '/student-finance/new-fulltime-students': 2,
#  '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus': 2,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-standardenhanced-dbs-check-applications-from-1-july-2021': 2,
#  '/new-state-pension/your-national-insurance-record-and-your-state-pension': 2,
#  '/redundancy-your-rights/being-selected-for-redundancy': 2,
#  '/new-state-pension/youve-been-in-a-workplace-personal-or-stakeholder-pension': 2,
#  '/apply-national-insurance-number': 2,
#  '/cold-weather-payment/eligibility': 2,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-numbers': 2,
#  '/voluntary-national-insurance-contributions/deadlines': 2,
#  '/government/collections/fit-note': 2,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals': 2,
#  '/identitycards': 2,
#  '/pip/claiming-pip-if-youre-terminally-ill': 2,
#  '/government/publications/dbs-application-forms-guide-for-applicants': 2,
#  '/benefit-fraud': 2,
#  '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed': 2,
#  '/moving-from-benefits-to-work/help-for-specific-problems': 2,
#  '/check-tenant-right-to-rent-documents': 2,
#  '/income-tax/find-out-if-you-need-to-pay-income-tax': 2,
#  '/government/organisations/hm-revenue-customs/contact/child-benefit': 2,
#  '/universal-credit/your-responsibilities': 2,
#  '/get-a-passport-urgently/1-week-fast-track-service': 2,
#  '/tax-on-your-private-pension/annual-allowance': 2,
#  '/new-state-pension/what-youll-get': 2,
#  '/apply-renew-passport': 2,
#  '/guidance/booking-and-staying-in-a-quarantine-hotel-when-you-arrive-in-england': 2,
#  '/winter-fuel-payment/how-much-youll-get': 2,
#  '/penalties-for-employing-illegal-workers': 2,
#  '/disability-premiums/eligibility': 2,
#  '/career-breaks': 2,
#  '/workplace-pensions/managing-your-pension': 2,
#  '/government/publications/easy-read-get-help-at-work-if-youre-disabled-or-have-a-health-condition-access-to-work': 2,
#  '/voluntary-national-insurance-contributions/rates': 2,
#  '/come-uk-married': 2,
#  '/guidance/travel-to-england-from-another-country-during-coronavirus-covid-19': 2,
#  '/tax-on-pension': 2,
#  '/government/publications/access-to-work-guide-for-employers': 2,
#  '/learn-to-drive-a-car': 2,
#  '/voluntary-national-insurance-contributions': 2,
#  '/tell-hmrc-change-of-details/income-changes': 2,
#  '/browse/visas-immigration/settle-in-the-uk': 2,
#  '/pension-credit-calculator': 2,
#  '/redundancy-your-rights': 2,
#  '/guidance/traineeship-information-for-employers': 2,
#  '/guidance/new-style-employment-and-support-allowance': 2,
#  '/paye-forms-p45-p60-p11d/lost-paye-forms': 2,
#  '/browse/disabilities/equipment': 2,
#  '/guidance/barring-referrals': 2,
#  '/council-tax': 2,
#  '/volunteering/pay-and-expenses': 2,
#  '/national-minimum-wage-accommodation': 2,
#  '/paye-forms-p45-p60-p11d/p11d': 2,
#  '/calculate-your-holiday-entitlement': 2,
#  '/browse/visas-immigration/asylum': 2,
#  '/government/publications/maternity-allowance-claim-form': 2,
#  '/eu-eea': 2,
#  '/universal-credit/changes-of-circumstances': 2,
#  '/the-warm-home-discount-scheme/energy-suppliers': 2,
#  '/check-driving-information': 2,
#  '/jobseekers-allowance/apply-new-style-jsa/eligibility': 2,
#  '/passport-advice-line': 2,
#  '/guidance/rehabilitation-periods': 2,
#  '/benefit-cap': 2,
#  '/employing-an-apprentice/get-funding': 2,
#  '/financial-help-disabled/on-a-low-salary': 2,
#  '/student-finance-register-login': 2,
#  '/guidance/eu-settlement-scheme-evidence-of-uk-residence': 2,
#  '/government/publications/dbs-certificate-disputes-and-fingerprint-consent-forms-and-guidance-af14-af15': 2,
#  '/government/organisations/hm-revenue-customs/contact/get-help-with-the-self-employment-income-support-scheme': 2,
#  '/guidance/coronavirus-covid-19-what-to-do-if-youre-employed-and-cannot-work': 2,
#  '/graduate-visa': 2,
#  '/pay-and-work-rights': 2,
#  '/uk-benefits-abroad': 2,
#  '/government/publications/sure-start-maternity-grant-claim-form': 2,
#  '/visit-uk-holiday-family-friends': 2,
#  '/data-protection': 2,
#  '/government/publications/dbs-continuation-sheet': 2,
#  '/tell-employer-or-college-about-criminal-record/what-information-you-need-to-give': 2,
#  '/find-a-visa-application-centre': 2,
#  '/reasonable-adjustments-for-disabled-workers': 2,
#  '/government/publications/dbs-list-of-offences-that-will-never-be-filtered-from-a-criminal-record-check': 2,
#  '/get-state-pension': 2,
#  '/apply-citizenship-indefinite-leave-to-remain': 2,
#  '/dismissal/what-to-do-if-youre-dismissed': 2,
#  '/guidance/search-for-apprenticeship-standards': 2,
#  '/guidance/travel-abroad-from-england-during-coronavirus-covid-19': 2,
#  '/apply-for-student-finance': 2,
#  '/guidance/using-the-eu-exit-id-document-check-app': 2,
#  '/topic/further-education-skills/vocational-qualifications': 2,
#  '/topic/personal-tax/national-insurance': 2,
#  '/government/publications/dbs-filtering-guidance/dbs-filtering-guide': 2,
#  '/register-for-self-assessment/self-employed': 2,
#  '/care-to-learn': 2,
#  '/health-conditions-disability-universal-credit': 2,
#  '/industrial-injuries-disablement-benefit': 2,
#  '/financial-help-disabled/television-licence-discount': 2,
#  '/guidance/find-out-about-money-taken-off-your-universal-credit-payment': 2,
#  '/browse/employing-people/time-off': 2,
#  '/overtime-your-rights/parttime-workers': 2,
#  '/cold-weather-payment/how-to-claim': 2,
#  '/government/publications/register-of-licensed-sponsors-students': 2,
#  '/guidance/register-of-apprenticeship-training-providers': 2,
#  '/browse/education/student-finance': 2,
#  '/get-copy-military-service-records/apply-for-someone-elses-records': 2,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes': 2,
#  '/settled-status-eu-citizens-families/eligibility': 2,
#  '/get-help-savings-low-income': 2,
#  '/housing-benefit/other-help-with-housing-costs': 2,
#  '/government/organisations/department-for-education/services-information': 2,
#  '/plan-retirement-income': 2,
#  '/state-pension/inheritance': 2,
#  '/browse/births-deaths-marriages/child': 2,
#  '/rights-disabled-person': 2,
#  '/universal-credit/how-to-claim': 2,
#  '/part-time-worker-rights': 2,
#  '/guidance/coronavirus-covid-19-right-to-work-checks': 2,
#  '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions': 2,
#  '/government/publications/apprenticeship-technical-funding-guide': 2,
#  '/pip/change-of-circumstances': 2,
#  '/terminal-illness-benefits': 2,
#  '/benefit-cap/benefit-cap-amounts': 2,
#  '/government/publications/apprenticeship-agreement-template': 2,
#  '/tell-dvla-changed-address': 2,
#  '/what-is-the-construction-industry-scheme': 2,
#  '/skilled-worker-visa/how-much-it-costs': 2,
#  '/government/publications/dbs-update-service-applicant-guide/dbs-update-service-applicant-guide': 2,
#  '/uk-border-control': 2,
#  '/government/publications/dwp-jobcentre-register': 2,
#  '/government/publications/statutory-sick-pay-employee-not-entitled-form-for-employers': 2,
#  '/government/publications/dbs-update-service-applicant-guide': 2,
#  '/handing-in-your-notice': 2,
#  '/renew-adult-passport': 2,
#  '/tax-help': 2,
#  '/housing-and-universal-credit/renting-from-private-landlord': 2,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship': 2,
#  '/child-benefit/what-youll-get': 2,
#  '/tax-on-pension-death-benefits': 2,
#  '/disciplinary-procedures-and-action-at-work/how-disciplinary-procedures-work': 2,
#  '/topic/further-education-skills/administration': 2,
#  '/become-apprentice/pay-and-conditions': 2,
#  '/find-a-regulated-qualification': 2,
#  '/payment-exception-service': 2,
#  '/fixed-term-contracts/employees-rights': 2,
#  '/entering-staying-uk': 2,
#  '/guidance/basic-dbs-checks-guidance': 2,
#  '/deferring-state-pension/what-you-get': 2,
#  '/redundancy-your-rights/notice-periods': 2,
#  '/view-right-to-rent': 2,
#  '/windrush-prove-your-right-to-be-in-the-uk': 2,
#  '/maximum-weekly-working-hours': 2,
#  '/access-to-work/eligibility': 2,
#  '/courses-qualifications': 2,
#  '/employment-status/worker': 2,
#  '/further-education-skills/apprenticeships': 2,
#  '/national-insurance/what-national-insurance-is-for': 2,
#  '/tax-on-your-private-pension/pension-tax-relief': 2,
#  '/personal-tax-account': 2,
#  '/topic/dealing-with-hmrc/paying-hmrc': 2,
#  '/guidance/recruiting-people-from-outside-the-uk': 2,
#  '/employers-sick-pay/entitlement': 2,
#  '/pension-credit/eligibility': 2,
#  '/find-lost-utr-number': 2,
#  '/book-theory-test': 2,
#  '/settled-status-eu-citizens-families/applying-for-settled-status': 2,
#  '/disability-premiums/how-to-claim': 2,
#  '/sign-in-help-to-save': 2,
#  '/government/publications/basic-check-guidance-and-policies/basic-check-id-checking-guidelines-from-1-july-2021': 2,
#  '/government/collections/dbs-filtering-guidance': 2,
#  '/independent-livingfund': 2,
#  '/claim-benefits-abroad': 2,
#  '/over-80-pension/further-information': 2,
#  '/time-off-for-dependants/whats-an-emergency': 2,
#  '/parental-leave/entitlement': 2,
#  '/student-visa/money': 2,
#  '/check-national-insurance-record': 2,
#  '/vehicle-tax': 2,
#  '/flexible-working': 2,
#  '/topic/immigration-operational-guidance/immigration-rules': 2,
#  '/changes-affect-tax-credits': 2,
#  '/uk-visa-sponsorship-employers/eligibility': 2,
#  '/get-ready-to-employ-someone': 2,
#  '/contact-student-finance-england': 2,
#  '/frontier-worker-permit': 2,
#  '/pip/what-youll-get': 2,
#  '/jobseekers-allowance/your-jsa-claim': 2,
#  '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403': 2,
#  '/guidance/visa-decision-waiting-times-applications-outside-the-uk': 2,
#  '/new-state-pension': 2,
#  '/pension-credit/how-to-claim': 2,
#  '/claim-loss-notice': 2,
#  '/guidance/contact-the-department-for-work-and-pensions-about-its-policies': 2,
#  '/caution-warning-penalty': 2,
#  '/tell-employer-or-college-about-criminal-record/discharges': 2,
#  '/financial-help-disabled/home-and-housing': 2,
#  '/national-insurance-if-you-go-abroad': 2,
#  '/id-for-driving-licence': 2,
#  '/benefit-cap/when-youre-not-affected': 2,
#  '/child-benefit': 2,
#  '/continuous-employment-what-it-is': 2,
#  '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member': 2,
#  '/government/publications/application-for-a-state-pension-statement': 2,
#  '/foreign-travel-advice': 2,
#  '/biometric-residence-permits/not-arrived': 2,
#  '/report-benefits-change-circumstances': 2,
#  '/au-pairs-employment-law': 2,
#  '/family-permit': 2,
#  '/maternity-pay-leave': 2,
#  '/government/collections/dbs-checking-service-guidance--2': 2,
#  '/self-employed-national-insurance-rates': 2,
#  '/browse/employing-people/recruiting-hiring': 2,
#  '/the-warm-home-discount-scheme': 2,
#  '/pension-credit/what-youll-get': 2,
#  '/taking-sick-leave': 2,
#  '/carers-allowance/if-youre-working-': 2,
#  '/agency-workers-your-rights/basic-information-you-should-receive': 2,
#  '/budgeting-help-benefits/repayments': 2,
#  '/become-appointee-for-someone-claiming-benefits': 2,
#  '/government/organisations/hm-revenue-customs': 2,
#  '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments': 2,
#  '/child-employment/performance-licences-for-children': 2,
#  '/housing-benefit': 2,
#  '/understanding-your-pay/deductions-from-your-pay': 2,
#  '/government-authorised-exchange': 2,
#  '/government/organisations/home-office/about/recruitment': 2,
#  '/transfer-visa': 2,
#  '/apply-start-up-loan': 2,
#  '/government/collections/hm-revenue-and-customs-service-availability-and-issues': 2,
#  '/working-tax-credit/how-to-claim': 2,
#  '/search/policy-papers-and-consultations': 2,
#  '/claim-tax-refund': 2,
#  '/government/organisations/driver-and-vehicle-licensing-agency': 2,
#  '/apply-to-come-to-the-uk/prove-your-identity': 2,
#  '/discrimination-your-rights/how-you-can-be-discriminated-against': 2,
#  '/national-insurance-credits/eligibility': 2,
#  '/apply-to-come-to-the-uk': 2,
#  '/carers-allowance/how-to-claim': 2,
#  '/universal-credit/other-financial-support': 2,
#  '/whistleblowing': 2,
#  '/business-finance-support': 2,
#  '/apply-for-elderly-person-bus-pass': 2,
#  '/international-pension-centre': 2,
#  '/appeal-call-up-reserve-forces': 2,
#  '/bills-benefits': 2,
#  '/moving-from-benefits-to-work/work-experience-and-volunteering': 2,
#  '/further-education-courses': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants': 2,
#  '/armed-forces-pension-calculator': 2,
#  '/national-insurance/your-national-insurance-number': 2,
#  '/redundancy-your-rights/get-help-finding-a-new-job': 2,
#  '/state-pension/what-youll-get': 2,
#  '/carers-credit': 2,
#  '/biometric-residence-permits': 2,
#  '/settled-status-eu-citizens-families/after-youve-applied': 2,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-a-to-f-applying-for-a-criminal-records-check-for-someone-from-overseas': 2,
#  '/universal-credit/how-youre-paid': 2,
#  '/travel-abroad': 2,
#  '/working-retirement-pension-age': 2,
#  '/government/publications/skilled-worker-visa-eligible-occupations': 2,
#  '/apply-housing-benefit-from-council': 2,
#  '/child-benefit-payment-dates': 2,
#  '/moving-or-retiring-abroad': 2,
#  '/parental-bereavement-pay-leave': 2,
#  '/council-tax-bands': 2,
#  '/find-travel-test-provider': 2,
#  '/criminal-record-checks-apply-role/application-process': 2,
#  '/browse/benefits/manage-your-benefit': 2,
#  '/universal-credit/how-your-earnings-affect-your-payments': 2,
#  '/flexible-working/types-of-flexible-working': 2,
#  '/benefit-cap/how-earnings-affect-when-benefit-cap-starts': 2,
#  '/housing-benefit/what-youll-get': 2,
#  '/browse/visas-immigration/immigration-appeals': 2,
#  '/flexible-working/applying-for-flexible-working': 2,
#  '/maternity-pay-leave/extra-help': 2,
#  '/get-tax-free-childcare': 2,
#  '/find-local-council': 2,
#  '/statutory-sick-pay/what-youll-get': 2,
#  '/get-help-hmrc-extra-support': 2,
#  '/international-agreement-worker-visa': 2,
#  '/guidance/coronavirus-covid-19-testing-for-people-travelling-to-england': 2,
#  '/dbs-check-applicant-criminal-record/get-a-standard-or-enhanced-dbs-check-for-an-employee': 2,
#  '/skilled-worker-visa/switch-to-this-visa': 2,
#  '/tax-company-benefits': 2,
#  '/guidance/plan-for-jobs-skills-and-employment-programmes-information-for-employers': 2,
#  '/if-you-become-disabled': 2,
#  '/change-address-driving-licence': 2,
#  '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees': 2,
#  '/access-to-work/report-a-change-of-circumstances': 2,
#  '/assisted-digital-help-online-applications': 2,
#  '/payslips': 2,
#  '/log-in-file-self-assessment-tax-return': 2,
#  '/tax-on-pension/tax-free': 2,
#  '/recruit-apprentice': 2,
#  '/new-state-pension/inheriting-or-increasing-state-pension-from-a-spouse-or-civil-partner': 2,
#  '/guidance/pay-apprenticeship-levy': 2,
#  '/benefit-overpayments': 2,
#  '/topic/business-tax/pension-scheme-administration': 2,
#  '/tax-uk-income-live-abroad': 2,
#  '/advanced-learner-loan/bursary-fund': 2,
#  '/browse/childcare-parenting/childcare': 2,
#  '/deferring-state-pension': 2,
#  '/tax-codes/tell-hmrc-about-a-change-tax-code': 2,
#  '/rest-breaks-work/compensatory-rest': 2,
#  '/solve-workplace-dispute': 2,
#  '/working-when-pregnant-your-rights': 2,
#  '/the-warm-home-discount-scheme/low-income': 2,
#  '/government/publications/dbs-identity-checking-guidelines': 2,
#  '/register-employer': 2,
#  '/national-minimum-wage': 2,
#  '/personal-tax-account/sign-in/prove-identity': 2,
#  '/guidance/return-to-your-claim-for-the-self-employment-income-support-scheme': 2,
#  '/guidance/track-a-dbs-application': 2,
#  '/time-off-for-dependants/problems-when-you-take-time-off': 2,
#  '/employers-workplace-pensions-rules': 2,
#  '/settled-status-eu-citizens-families/family-member-eligible-person-from-northern-ireland': 2,
#  '/government/publications/apprenticeships-off-the-job-training': 2,
#  '/report-problem-criminal-record-certificate/dispute-a-mistake': 2,
#  '/income-tax/check-youre-paying-the-right-amount': 2,
#  '/time-off-for-dependants': 2,
#  '/guidance/how-your-trading-conditions-affect-your-eligibility-for-the-self-employment-income-support-scheme': 2,
#  '/settle-in-the-uk': 2,
#  '/income-support/if-you-already-get-income-support': 2,
#  '/contracted-out/new-state-pension': 2,
#  '/rest-breaks-work/taking-breaks': 2,
#  '/check-state-pension/sign-in/prove-identity': 2,
#  '/government/collections/apprenticeship-changes': 2,
#  '/government/publications/introducing-govuk-verify/introducing-govuk-verify': 2,
#  '/search/guidance-and-regulation': 2,
#  '/employing-an-apprentice/apprenticeship-agreement': 2,
#  '/sure-start-maternity-grant/what-youll-get': 2,
#  '/pension-credit/change-of-circumstances': 2,
#  '/death-spouse-benefits-tax-pension/benefits': 2,
#  '/guidance/apprenticeship-funding-rules': 2,
#  '/uk-visa-sponsorship-employers/apply-for-your-licence': 2,
#  '/guidance/responsible-organisations': 2,
#  '/government/organisations/department-for-education': 2,
#  '/employment-contracts-and-conditions/written-statement-of-employment-particulars': 2,
#  '/careers-helpline-for-teenagers': 2,
#  '/paternity-pay-leave/pay': 2,
#  '/contract-types-and-employer-responsibilities': 2,
#  '/government/publications/traineeship-providers': 2,
#  '/join-trade-union': 2,
#  ...}

# %%
# seed0.2: shortest_paths_seed0.2: '/topic/further-education-skills/apprenticeships'
shortest_seed0_2 = {
    k: v
    for k, v in sorted(
        shortest_paths_seed1.items(), key=lambda item: item[1], reverse=False
    )
}

# %% [markdown]
# ### Order by the sum of the shortest page path lengths

# %%
combined_paths = {
    k: finding_job[k] + apprentice[k] for k in set(finding_job) & set(apprentice)
}
combined_paths = {
    k: v
    for k, v in sorted(combined_paths.items(), key=lambda item: item[1], reverse=True)
}
combined_paths
# Out:
# {'/guidance/veterans-uk-armed-forces-pensions-forms': 7,
#  '/guidance/problems-using-government-gateway': 6,
#  '/student-visa/apply': 6,
#  '/government/publications/dbs-update-service-application-form-checklist': 6,
#  '/1619-bursary-fund/what-youll-get': 6,
#  '/government/publications/dbs-certificate-reprint-guide': 6,
#  '/personal-pensions-your-rights/get-help': 6,
#  '/parental-leave/eligibility': 6,
#  '/tax-on-pension/tax-when-you-live-abroad': 6,
#  '/dla-disability-living-allowance-benefit/your-dla-claim': 6,
#  '/apply-free-school-meals': 6,
#  '/guardians-allowance': 6,
#  '/attendance-allowance/report-change-in-circumstances': 6,
#  '/over-80-pension/what-youll-get': 6,
#  '/rights-disabled-person/employment': 6,
#  '/cold-weather-payment/what-youll-get': 6,
#  '/workplace-pensions/protection-for-your-pension': 6,
#  '/browse/housing-local-services/local-councils': 6,
#  '/housing-and-universal-credit/renting-from-local-authority-or-housing-association': 6,
#  '/register-a-death': 6,
#  '/learner-support/what-youll-get': 6,
#  '/dwp-visit': 6,
#  '/browse/housing-local-services/landlords': 6,
#  '/pay-voluntary-class-3-national-insurance/direct-debit': 6,
#  '/additional-state-pension/what-youll-get': 6,
#  '/employment-contracts-and-conditions/collective-agreements': 6,
#  '/state-pension/how-to-claim': 6,
#  '/employers-sick-pay/notice-and-fit-notes': 6,
#  '/rest-breaks-work/young-workers': 6,
#  '/discrimination-your-rights/what-you-can-do': 6,
#  '/additional-state-pension/eligibility': 6,
#  '/student-visa/documents-you-must-provide': 6,
#  '/government/collections/universal-credit-detailed-information-for-claimants': 6,
#  '/government/publications/application-for-mot-authorisation-vt01/how-to-apply-to-open-run-or-change-an-mot-testing-station': 6,
#  '/disabled-facilities-grants/eligibility': 6,
#  '/industrial-injuries-disablement-benefit/what-youll-get': 6,
#  '/free-discount-tv-licence': 6,
#  '/agency-workers-your-rights/fees': 6,
#  '/employee-tax-codes': 6,
#  '/after-a-death': 6,
#  '/employment-tribunals/if-you-win-your-case': 6,
#  '/working-tax-credit/further-information': 6,
#  '/benefit-cap/help-with-the-benefit-cap': 6,
#  '/tax-overpayments-and-underpayments/if-youre-due-a-refund': 6,
#  '/plan-retirement-income/pensions-from-the-government': 6,
#  '/disabled-students-allowance-dsa/eligibility': 6,
#  '/browse/justice/rights': 6,
#  '/employment-contracts-and-conditions/problems-with-a-written-statement': 6,
#  '/browse/tax/capital-gains': 6,
#  '/over-80-pension/eligibility': 6,
#  '/settlement-refugee-or-humanitarian-protection': 6,
#  '/child-benefit/make-a-change-to-your-claim': 6,
#  '/private-renting/document-checks': 6,
#  '/learner-support/eligibility': 6,
#  '/check-income-tax': 6,
#  '/your-rights-if-your-employer-is-insolvent/your-rights': 6,
#  '/income-tax-reliefs': 6,
#  '/permanent-residence-document-eu-eea': 6,
#  '/plan-retirement-income/working-past-state-pension-age': 6,
#  '/browse/births-deaths-marriages/death': 6,
#  '/disciplinary-procedures-and-action-at-work/disciplinary-hearings': 6,
#  '/the-warm-home-discount-scheme/guarantee-pension-credit': 6,
#  '/get-help-savings-low-income/what-youll-get': 6,
#  '/plan-retirement-income/your-pension-options': 6,
#  '/browse/justice/courts-sentencing-tribunals': 6,
#  '/government/publications/maternity-benefits-technical-guidance': 6,
#  '/tax-overpayments-and-underpayments': 6,
#  '/tax-codes/what-your-tax-code-means': 6,
#  '/vaccine-damage-payment': 6,
#  '/carers-credit/what-youll-get': 6,
#  '/tax-on-pension/higher-tax-on-unauthorised-payments': 6,
#  '/capital-gains-tax': 6,
#  '/state-pension-if-you-retire-abroad/tax-on-your-state-pension': 6,
#  '/change-circumstances-visa-brp/youre-in-the-uk-and-dont-have-a-brp': 6,
#  '/claim-benefits-abroad/where-you-can-claim-benefits': 6,
#  '/browse/tax/inheritance-tax': 6,
#  '/paternity-pay-leave/leave': 6,
#  '/help-for-disabled-child': 6,
#  '/workplace-pensions/get-help': 6,
#  '/government/collections/national-insurance-forms': 6,
#  '/applying-for-probate': 6,
#  '/benefit-overpayments/repayments-when-someone-has-died': 6,
#  '/check-if-you-need-tax-return': 6,
#  '/disabled-facilities-grants/what-youll-get': 6,
#  '/state-pension-if-you-retire-abroad/rates-of-state-pension': 6,
#  '/apply-needs-assessment-social-services': 6,
#  '/uk-border-control/layovers-and-transiting': 6,
#  '/browse/tax/court-claims-debt-bankruptcy': 6,
#  '/get-help-savings-low-income/eligibility': 6,
#  '/government/publications/equality-act-guidance': 6,
#  '/browse/births-deaths-marriages/lasting-power-attorney': 6,
#  '/inheritance-tax': 6,
#  '/uk-family-visa/adult-dependent-relative': 6,
#  '/income-tax-rates/previous-tax-years': 6,
#  '/claim-tax-credits/when-to-claim': 6,
#  '/graduate-visa/how-much-it-costs': 6,
#  '/register-for-self-assessment/not-self-employed': 6,
#  '/disabled-facilities-grants/how-to-claim': 6,
#  '/employers-sick-pay/help-with-sick-pay': 6,
#  '/government/publications/biometric-residence-permits-applicant-and-sponsor-information': 6,
#  '/marriages-civil-partnerships': 6,
#  '/browse/housing-local-services/owning-renting-property': 6,
#  '/marriage-allowance/how-to-apply': 6,
#  '/deferring-state-pension/extra-state-pension-and-lump-sum-payments': 6,
#  '/healthy-start': 6,
#  '/browse/abroad/living-abroad': 6,
#  '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service/fast-track-service-eligible-roles': 6,
#  '/browse/births-deaths-marriages/child-adoption': 6,
#  '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education/skilled-worker-visa-shortage-occupations-for-healthcare-and-education': 6,
#  '/browse/disabilities/carers': 6,
#  '/solve-workplace-dispute/formal-procedures': 6,
#  '/bringing-goods-into-uk-personal-use': 6,
#  '/additional-state-pension/you-get-divorced': 6,
#  '/budgeting-help-benefits/other-help-you-can-get': 5,
#  '/browse/employing-people/health-safety': 5,
#  '/support-visit-benefit-claim': 5,
#  '/government/publications/basic-check-guidance-and-policies': 5,
#  '/child-benefit-tax-calculator': 5,
#  '/government/publications/dbs-workforce-guidance': 5,
#  '/workplace-pensions/changing-jobs-and-taking-leave': 5,
#  '/skilled-worker-visa/your-partner-and-children': 5,
#  '/self-employed-records': 5,
#  '/maternity-allowance/eligibility': 5,
#  '/agency-workers-your-rights/your-rights-as-a-temporary-agency-worker': 5,
#  '/uk-visa-sponsorship-employers/job-suitability': 5,
#  '/benefit-overpayments/when-repayments-have-to-be-made': 5,
#  '/government/publications/child-benefit-claim-form-ch2': 5,
#  '/government/publications/employment-and-support-allowance-permitted-work-form': 5,
#  '/working-abroad': 5,
#  '/ukvcas': 5,
#  '/browse/employing-people/pensions': 5,
#  '/government/collections/citizenship-application-forms': 5,
#  '/child-tax-credit/how-to-claim': 5,
#  '/bereavement-support-payment/how-to-claim': 5,
#  '/criminal-record-check-become-driving-instructor': 5,
#  '/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance': 5,
#  '/dual-citizenship': 5,
#  '/your-employment-contract-how-it-can-be-changed': 5,
#  '/guidance/eu-settlement-scheme-uk-tax-and-benefits-records-automated-check': 5,
#  '/reduced-earnings-allowance': 5,
#  '/government/publications/dbs-filtering-guidance': 5,
#  '/browse/births-deaths-marriages/marriage-divorce': 5,
#  '/maternity-paternity-pay-leave': 5,
#  '/government/collections/fit-note': 5,
#  '/tax-on-your-private-pension/annual-allowance': 5,
#  '/the-warm-home-discount-scheme/energy-suppliers': 5,
#  '/government/publications/dbs-certificate-disputes-and-fingerprint-consent-forms-and-guidance-af14-af15': 5,
#  '/uk-benefits-abroad': 5,
#  '/government/publications/dbs-list-of-offences-that-will-never-be-filtered-from-a-criminal-record-check': 5,
#  '/apply-citizenship-indefinite-leave-to-remain': 5,
#  '/financial-help-disabled/television-licence-discount': 5,
#  '/cold-weather-payment/how-to-claim': 5,
#  '/get-copy-military-service-records/apply-for-someone-elses-records': 5,
#  '/government/publications/filtering-rules-for-criminal-record-check-certificates': 5,
#  '/government/publications/redundancy-payments-rp1-fact-sheet': 5,
#  '/disciplinary-procedures-and-action-at-work/how-disciplinary-procedures-work': 5,
#  '/tax-on-pension-death-benefits': 5,
#  '/view-right-to-rent': 5,
#  '/government/publications/handling-applications-for-permission-to-take-employment-instruction': 5,
#  '/disability-premiums/how-to-claim': 5,
#  '/parental-leave/entitlement': 5,
#  '/time-off-for-dependants/whats-an-emergency': 5,
#  '/continuous-employment-what-it-is': 5,
#  '/child-employment/performance-licences-for-children': 5,
#  '/transfer-visa': 5,
#  '/redundancy-your-rights/get-help-finding-a-new-job': 5,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-a-to-f-applying-for-a-criminal-records-check-for-someone-from-overseas': 5,
#  '/benefit-cap/how-earnings-affect-when-benefit-cap-starts': 5,
#  '/tax-uk-income-live-abroad': 5,
#  '/tax-codes/tell-hmrc-about-a-change-tax-code': 5,
#  '/time-off-for-dependants/problems-when-you-take-time-off': 5,
#  '/report-problem-criminal-record-certificate/dispute-a-mistake': 5,
#  '/guidance/responsible-organisations': 5,
#  '/state-pension-if-you-retire-abroad/report-a-change-in-your-circumstances': 5,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations': 5,
#  '/government/publications/income-tax-leaving-the-uk-getting-your-tax-right-p85': 5,
#  '/housing-benefit/report-a-change-of-circumstances': 5,
#  '/graduate-visa/apply': 5,
#  '/residence-documents-foreign-nationals-uk': 5,
#  '/workplace-temperatures': 5,
#  '/transferring-your-pension/transferring-to-a-uk-pension-scheme': 5,
#  '/government/collections/dbs-update-service-promotional-material': 5,
#  '/topic/benefits-credits/tax-credits': 5,
#  '/redundancy-your-rights/suitable-alternative-employment': 5,
#  '/tax-on-your-private-pension': 5,
#  '/skilled-worker-visa/second-job': 5,
#  '/government/publications/national-insurance-employment-history-request': 5,
#  '/access-to-work/apply': 5,
#  '/browse/childcare-parenting/pregnancy-birth': 5,
#  '/workplace-pensions/what-you-your-employer-and-the-government-pay': 5,
#  '/discrimination-your-rights/discrimination-at-work': 5,
#  '/government/collections/illegal-working-penalties-codes-of-practice-for-employers': 5,
#  '/apply-direct-payments': 5,
#  '/uk-visa-sponsorship-employers/sponsorship-management-roles': 5,
#  '/child-employment/local-council-rules-for-child-employment-permits': 5,
#  '/raise-grievance-at-work': 5,
#  '/self-employed-records/what-records-to-keep': 5,
#  '/government/publications/acceptable-right-to-work-documents-an-employers-guide': 5,
#  '/government/publications/find-a-skills-bootcamp': 5,
#  '/cold-weather-payment': 5,
#  '/seasonal-worker-visa/eligibility': 5,
#  '/maximum-weekly-working-hours/weekly-maximum-working-hours-and-opting-out': 5,
#  '/guidance/criminal-record-checks-for-childminders-and-childcare-workers': 5,
#  '/government/publications/dbs-check-eligible-positions-guidance': 5,
#  '/overseas-domestic-worker-visa': 5,
#  '/apply-marriage-allowance': 5,
#  '/biometric-residence-permits/lost-stolen-damaged': 5,
#  '/browse/disabilities/benefits': 5,
#  '/life-in-the-uk-test': 5,
#  '/government/publications/access-to-work-factsheet/access-to-work-factsheet-for-customers': 5,
#  '/time-off-for-dependants/taking-time-off': 5,
#  '/tell-employer-or-college-about-criminal-record/fines-and-compensation': 5,
#  '/disciplinary-procedures-and-action-at-work': 5,
#  '/browse/abroad/travel-abroad': 5,
#  '/guidance/dbs-online-account-guidance': 5,
#  '/access-to-work/renew': 5,
#  '/redundancy-payments-helpline': 5,
#  '/bereavement-support-payment/what-youll-get': 5,
#  '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education': 5,
#  '/reduced-national-insurance-married-women': 5,
#  '/dbs-check-applicant-criminal-record/get-a-basic-dbs-check-for-an-employee': 5,
#  '/state-pension/increase-the-amount-youll-get': 5,
#  '/dismissal/unfair-and-constructive-dismissal': 5,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/countries-q-z': 5,
#  '/student-visa/course': 5,
#  '/government/collections/dbs-eligibility-guidance': 5,
#  '/maternity-allowance/what-youll-get': 5,
#  '/personal-pensions-your-rights/choosing-personal-pension': 5,
#  '/income-tax/how-you-pay-income-tax': 5,
#  '/plan-shared-parental-leave-pay': 5,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-standardenhanced-dbs-check-applications-from-1-july-2021': 5,
#  '/get-a-passport-urgently/1-week-fast-track-service': 5,
#  '/come-uk-married': 5,
#  '/paye-forms-p45-p60-p11d/p11d': 5,
#  '/government/publications/dbs-continuation-sheet': 5,
#  '/national-insurance/what-national-insurance-is-for': 5,
#  '/caution-warning-penalty': 5,
#  '/biometric-residence-permits/not-arrived': 5,
#  '/discrimination-your-rights/how-you-can-be-discriminated-against': 5,
#  '/government/publications/criminal-records-checks-for-overseas-applicants': 5,
#  '/carers-credit': 5,
#  '/flexible-working/types-of-flexible-working': 5,
#  '/maternity-pay-leave/extra-help': 5,
#  '/skilled-worker-visa/switch-to-this-visa': 5,
#  '/the-warm-home-discount-scheme/low-income': 5,
#  '/keeping-your-pay-tax-records/how-long-to-keep-your-records': 5,
#  '/death-spouse-benefits-tax-pension/benefits': 5,
#  '/paternity-pay-leave/pay': 5,
#  '/recruitment-disabled-people/encouraging-applications': 5,
#  '/uk-border-control/at-border-control': 5,
#  '/government/publications/redundancy-payments-rp1-fact-sheet/what-to-do-when-youve-been-made-redundant': 5,
#  '/dismiss-staff': 5,
#  '/death-spouse-benefits-tax-pension': 5,
#  '/employment-tribunals/make-a-claim': 5,
#  '/handing-in-your-notice/restrictive-covenants': 5,
#  '/government/publications/dbs-update-service-employer-guide': 5,
#  '/apply-disabled-facilities-grant': 5,
#  '/guidance/using-the-uk-immigration-id-check-app': 5,
#  '/plan-retirement-income/private-pensions': 5,
#  '/standard-visitor-visa/documents-you-will-need': 5,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship/borders-immigration-and-citizenship-privacy-information-notice': 5,
#  '/rest-breaks-work/disputes': 5,
#  '/child-benefit/how-to-claim': 5,
#  '/constant-attendance-allowance': 5,
#  '/understanding-your-pay/working-out-your-pay': 5,
#  '/workplace-pensions-employers': 5,
#  '/standard-visitor-visa/what-you-can-do-in-the-uk': 5,
#  '/guidance/using-your-uk-visas-and-immigration-account': 5,
#  '/funeral-payments': 5,
#  '/paternity-pay-leave/how-to-claim': 5,
#  '/browse/driving/disability-health-condition': 5,
#  '/short-term-benefit-advance': 5,
#  '/guidance/digital-and-online-services': 5,
#  '/government/publications/disclosure-application-process-for-volunteers/disclosure-application-process-for-volunteers': 5,
#  '/tax-codes': 5,
#  '/government/publications/public-funds--2': 5,
#  '/types-of-british-nationality/british-citizenship': 5,
#  '/workplace-pensions/if-you-want-to-leave-your-workplace-pension-scheme': 5,
#  '/entering-staying-uk/foreign-nationals-working-in-uk': 5,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-dbs-check-applications-from-3-september-2018': 5,
#  '/guidance/covid-19-how-dbs-is-supporting-the-fight-against-coronavirus': 5,
#  '/carers-allowance/further-information': 5,
#  '/sure-start-maternity-grant/how-to-claim': 5,
#  '/your-employment-contract-how-it-can-be-changed/making-changes': 5,
#  '/government/publications/criminal-records-checks-for-overseas-applicants/guidance-on-the-application-process-for-criminal-records-checks-overseas': 5,
#  '/government/publications/disclosure-application-process-for-volunteers': 5,
#  '/access-to-work/what-youll-get': 5,
#  '/holiday-entitlement-rights/workers-furlough-coronavirus': 5,
#  '/dla-disability-living-allowance-benefit/dla-rates': 5,
#  '/industrial-injuries-disablement-benefit/eligibility': 5,
#  '/financial-help-disabled/vat-relief': 5,
#  '/renewing-your-tax-credits-claim': 5,
#  '/national-insurance/change-of-circumstance': 5,
#  '/jobcentre-plus-help-for-recruiters/work-trials': 5,
#  '/workplace-pensions/joining-a-workplace-pension': 5,
#  '/tell-employer-or-college-about-criminal-record/check-your-conviction-caution': 5,
#  '/carers-allowance-unit': 5,
#  '/change-circumstances-visa-brp': 5,
#  '/maximum-weekly-working-hours/calculating-your-working-hours': 5,
#  '/tax-national-insurance-after-state-pension-age': 5,
#  '/biometric-residence-permits/personal-data': 5,
#  '/deferring-state-pension/how-to-claim-a-deferred-state-pension': 5,
#  '/contract-types-and-employer-responsibilities/fulltime-and-parttime-contracts': 5,
#  '/handing-in-your-notice/payment-during-your-notice-period': 5,
#  '/handing-in-your-notice/giving-notice': 5,
#  '/tax-relief-for-employees': 5,
#  '/browse/housing-local-services/council-tax': 5,
#  '/youth-mobility/eligibility': 5,
#  '/maternity-pay-leave/leave': 5,
#  '/employer-preventing-discrimination/recruitment': 5,
#  '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed': 5,
#  '/check-tenant-right-to-rent-documents': 5,
#  '/government/publications/access-to-work-guide-for-employers': 5,
#  '/guidance/barring-referrals': 5,
#  '/check-driving-information': 5,
#  '/tell-employer-or-college-about-criminal-record/what-information-you-need-to-give': 5,
#  '/overtime-your-rights/parttime-workers': 5,
#  '/housing-and-universal-credit/property-you-own': 5,
#  '/benefit-cap/benefit-cap-amounts': 5,
#  '/fixed-term-contracts/employees-rights': 5,
#  '/government/publications/basic-check-guidance-and-policies/basic-check-id-checking-guidelines-from-1-july-2021': 5,
#  '/government/collections/dbs-filtering-guidance': 5,
#  '/claim-loss-notice': 5,
#  '/topic/benefits-credits/universal-credit': 5,
#  '/tell-employer-or-college-about-criminal-record/discharges': 5,
#  '/government/collections/dbs-checking-service-guidance--2': 5,
#  '/fixed-term-contracts/renewing-or-ending-a-fixedterm-contract': 5,
#  '/appeal-call-up-reserve-forces': 5,
#  '/government/publications/skilled-worker-visa-eligible-occupations': 5,
#  '/browse/visas-immigration/immigration-appeals': 5,
#  '/access-to-work/report-a-change-of-circumstances': 5,
#  '/income-tax/check-youre-paying-the-right-amount': 5,
#  '/rest-breaks-work/taking-breaks': 5,
#  '/sure-start-maternity-grant/what-youll-get': 5,
#  '/penalty-points-endorsements/how-to-check-your-endorsement-details': 5,
#  '/browse/housing-local-services/council-housing-association': 5,
#  '/rest-breaks-work/exceptions': 5,
#  '/join-trade-union/trade-union-membership-your-employment-rights': 5,
#  '/tax-codes/emergency-tax-codes': 5,
#  '/register-birth': 5,
#  '/government/publications/new-guidance-on-the-rehabilitation-of-offenders-act-1974': 5,
#  '/overtime-your-rights/compulsory-overtime': 5,
#  '/government/publications/find-a-free-level-3-qualification': 5,
#  '/tax-right-retire-abroad-return-to-uk': 5,
#  '/tell-employer-or-college-about-criminal-record/cautions': 5,
#  '/tax-on-your-private-pension/lifetime-allowance': 5,
#  '/biometric-residence-permits/collect': 5,
#  '/guidance/pensions-and-compensation-for-veterans': 5,
#  '/skilled-worker-visa/if-you-work-in-healthcare-or-education': 5,
#  '/government/publications/dbs-update-service-employer-guide/dbs-update-service-employer-guide': 5,
#  '/your-rights-if-your-employer-is-insolvent': 5,
#  '/prove-right-to-rent': 5,
#  '/browse/tax/income-tax': 5,
#  '/probate-estate': 5,
#  '/update-uk-visas-immigration-account-details/update-your-ukvi-account': 5,
#  '/get-copy-military-service-records/apply-for-your-own-records': 5,
#  '/check-tenant-right-to-rent-documents/how-to-check': 5,
#  '/disabled-facilities-grants': 5,
#  '/limited-company-formation': 5,
#  '/get-proof-employment-history': 5,
#  '/claim-national-insurance-refund': 5,
#  '/browse/business/finance-support': 5,
#  '/budgeting-help-benefits/what-youll-get': 5,
#  '/carers-credit/how-to-claim': 5,
#  '/lay-offs-short-timeworking': 5,
#  '/child-benefit-move-to-uk': 5,
#  '/apply-for-council-tax-discount': 5,
#  '/appeal-benefit-decision': 5,
#  '/shared-parental-leave-and-pay/eligibility-for-birth-parents': 5,
#  '/tax-national-insurance-after-state-pension-age/stopping-paying-national-insurance': 5,
#  '/maternity-pay-leave/how-to-claim': 5,
#  '/graduate-visa/course-you-studied': 5,
#  '/adoption-pay-leave': 5,
#  '/pip/claiming-pip-if-youre-terminally-ill': 5,
#  '/uk-family-visa/parent': 5,
#  '/help-with-childcare-costs/free-childcare-and-education-for-2-to-4-year-olds': 5,
#  '/browse/employing-people/payroll': 5,
#  '/financial-help-disabled/on-a-low-salary': 5,
#  '/visit-uk-holiday-family-friends': 5,
#  '/data-protection': 5,
#  '/dismissal/what-to-do-if-youre-dismissed': 5,
#  '/government/publications/dbs-filtering-guidance/dbs-filtering-guide': 5,
#  '/state-pension/inheritance': 5,
#  '/report-problem-criminal-record-certificate/appeal-against-a-new-barring-decision': 5,
#  '/government/publications/dbs-update-service-applicant-guide': 5,
#  '/over-80-pension/further-information': 5,
#  '/national-insurance-if-you-go-abroad': 5,
#  '/support-for-mortgage-interest': 5,
#  '/whistleblowing': 5,
#  '/armed-forces-pension-calculator': 5,
#  '/working-retirement-pension-age': 5,
#  '/rest-breaks-work/compensatory-rest': 5,
#  '/parental-leave/notice-period': 5,
#  '/uk-visa-sponsorship-employers/apply-for-your-licence': 5,
#  '/employment-contracts-and-conditions/written-statement-of-employment-particulars': 5,
#  '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide': 5,
#  '/uk-family-visa/proof-income': 5,
#  '/visa-documents-returned': 5,
#  '/maternity-pay-leave/eligibility': 5,
#  '/agency-workers-your-rights/pay': 5,
#  '/tell-hmrc-change-address': 4,
#  '/vehicle-exempt-from-vehicle-tax': 4,
#  '/apply-for-disabled-bus-pass': 4,
#  '/government/publications/the-official-hmrc-app': 4,
#  '/guidance/new-style-jobseekers-allowance': 4,
#  '/guidance/nhs-covid-pass': 4,
#  '/uk-visa-sponsorship-employers/types-of-licence': 4,
#  '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens': 4,
#  '/employers-sick-pay': 4,
#  '/guidance/claim-for-wages-through-the-coronavirus-job-retention-scheme': 4,
#  '/incapacity-benefit': 4,
#  '/passport-fees': 4,
#  '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant': 4,
#  '/training-study-work-your-rights': 4,
#  '/holiday-entitlement-rights/calculate-leave-entitlement': 4,
#  '/employer-relocation-your-rights': 4,
#  '/childcare-grant': 4,
#  '/business-support-helpline': 4,
#  '/further-education-courses/find-a-course': 4,
#  '/government/organisations/pension-service': 4,
#  '/government/organisations/department-of-social-security': 4,
#  '/check-income-tax-current-year/sign-in/prove-identity': 4,
#  '/employment-support-allowance': 4,
#  '/guidance/indefinite-leave-to-remain-in-the-uk': 4,
#  '/carers-allowance/effect-on-other-benefits': 4,
#  '/find-postgraduate-teacher-training-courses': 4,
#  '/maternity-pay-leave/pay': 4,
#  '/browse/benefits/disability': 4,
#  '/moving-from-benefits-to-work/help-for-parents-and-carers': 4,
#  '/government/organisations/student-loans-company': 4,
#  '/apply-council-tax-reduction': 4,
#  '/employment-support-allowance/what-youll-get': 4,
#  '/moving-from-benefits-to-work/starting-your-own-business': 4,
#  '/child-trust-funds': 4,
#  '/provide-journey-contact-details-before-travel-uk': 4,
#  '/skilled-worker-visa/apply-from-outside-the-uk': 4,
#  '/guidance/visa-decision-waiting-times-applications-inside-the-uk': 4,
#  '/order-copy-birth-death-marriage-certificate': 4,
#  '/income-tax': 4,
#  '/attendance-allowance': 4,
#  '/education': 4,
#  '/set-up-sole-trader': 4,
#  '/browse/employing-people/contracts': 4,
#  '/early-retirement-pension/personal-and-workplace-pensions': 4,
#  '/eusettledstatus': 4,
#  '/am-i-getting-minimum-wage': 4,
#  '/find-dbs-umbrella-body': 4,
#  '/child-employment/restrictions-on-child-employment': 4,
#  '/youth-mobility': 4,
#  '/jobseekers-allowance/apply-new-style-jsa': 4,
#  '/national-insurance/how-much-you-pay': 4,
#  '/what-different-qualification-levels-mean/compare-different-qualification-levels': 4,
#  '/work/pensions-and-ageing-society': 4,
#  '/visa-to-study-english': 4,
#  '/settled-status-eu-citizens-families': 4,
#  '/apply-home-equipment-for-disabled': 4,
#  '/guidance/universal-credit-and-students': 4,
#  '/fixed-term-contracts': 4,
#  '/government/collections/financial-support-for-businesses-during-coronavirus-covid-19': 4,
#  '/overtime-your-rights': 4,
#  '/tier-1-entrepreneur': 4,
#  '/financial-help-disabled': 4,
#  '/income-support/income-support-rates': 4,
#  '/register-for-self-assessment': 4,
#  '/visa-fees': 4,
#  '/guidance/government-legal-service-gls-legal-trainee-scheme-how-to-apply': 4,
#  '/check-british-citizenship': 4,
#  '/claim-tax-credits': 4,
#  '/winter-fuel-payment': 4,
#  '/carers-allowance-report-change': 4,
#  '/income-tax/taxfree-and-taxable-state-benefits': 4,
#  '/check-state-pension': 4,
#  '/1619-bursary-fund': 4,
#  '/view-driving-licence': 4,
#  '/paye-forms-p45-p60-p11d/p60': 4,
#  '/government/publications/skilled-worker-visa-eligible-healthcare-and-education-jobs': 4,
#  '/government/organisations/uk-visas-and-immigration': 4,
#  '/settled-status-eu-citizens-families/switch-from-presettled-status-to-settled-status': 4,
#  '/contact-jobcentre-plus/existing-benefit-claims': 4,
#  '/paternity-pay-leave': 4,
#  '/set-up-business': 4,
#  '/how-to-claim-new-style-jsa': 4,
#  '/government/organisations/foreign-commonwealth-development-office': 4,
#  '/self-employment-and-universal-credit': 4,
#  '/apply-to-come-to-the-uk/prepare-your-application': 4,
#  '/track-passport-application': 4,
#  '/guidance/prove-your-right-to-work-eu-eea-and-swiss-citizens': 4,
#  '/personal-pensions-your-rights/how-you-can-take-pension': 4,
#  '/additional-state-pension': 4,
#  '/contact-pension-service': 4,
#  '/state-pension-if-you-retire-abroad': 4,
#  '/government/publications/view-and-prove-your-immigration-status-evisa/your-immigration-status-an-introduction-for-eu-eea-and-swiss-citizens-accessible-version': 4,
#  '/income-support': 4,
#  '/biometric-residence-permits/replace-visa-brp': 4,
#  '/employment-status/employee': 4,
#  '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022': 4,
#  '/new-state-pension/living-and-working-overseas': 4,
#  '/browse/benefits/low-income': 4,
#  '/redundancy-your-rights/consultation': 4,
#  '/government/collections/right-to-work-checks-employer-guidance': 4,
#  '/right-of-abode': 4,
#  '/night-working-hours': 4,
#  '/higher-education-courses-find-and-apply': 4,
#  '/government/publications/find-a-skills-bootcamp/list-of-skills-bootcamps': 4,
#  '/browse/visas-immigration/arriving-in-the-uk': 4,
#  '/guidance/benefits-and-pensions-for-uk-nationals-in-the-eea-or-switzerland': 4,
#  '/update-uk-visas-immigration-account-details': 4,
#  '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries': 4,
#  '/national-insurance-credits': 4,
#  '/agricultural-sick-pay': 4,
#  '/student-finance/new-fulltime-students': 4,
#  '/government/organisations/hm-revenue-customs/contact/child-benefit': 4,
#  '/scottish-income-tax': 4,
#  '/browse/visas-immigration/settle-in-the-uk': 4,
#  '/guidance/new-style-employment-and-support-allowance': 4,
#  '/volunteering/pay-and-expenses': 4,
#  '/national-minimum-wage-accommodation': 4,
#  '/government/organisations/hm-revenue-customs/contact/get-help-with-the-self-employment-income-support-scheme': 4,
#  '/government/publications/sure-start-maternity-grant-claim-form': 4,
#  '/get-state-pension': 4,
#  '/guidance/travel-abroad-from-england-during-coronavirus-covid-19': 4,
#  '/apply-for-student-finance': 4,
#  '/guidance/using-the-eu-exit-id-document-check-app': 4,
#  '/topic/further-education-skills/vocational-qualifications': 4,
#  '/topic/personal-tax/national-insurance': 4,
#  '/care-to-learn': 4,
#  '/browse/employing-people/time-off': 4,
#  '/rights-disabled-person': 4,
#  '/part-time-worker-rights': 4,
#  '/types-of-british-nationality': 4,
#  '/renew-driving-licence-at-70': 4,
#  '/government/publications/personal-information-use-in-borders-immigration-and-citizenship': 4,
#  '/housing-and-universal-credit/renting-from-private-landlord': 4,
#  '/entering-staying-uk': 4,
#  '/employment-status/worker': 4,
#  '/tax-on-your-private-pension/pension-tax-relief': 4,
#  '/topic/dealing-with-hmrc/paying-hmrc': 4,
#  '/independent-livingfund': 4,
#  '/sign-in-help-to-save': 4,
#  '/student-visa/money': 4,
#  '/frontier-worker-permit': 4,
#  '/contact-student-finance-england': 4,
#  '/jobseekers-allowance/your-jsa-claim': 4,
#  '/pension-credit/how-to-claim': 4,
#  '/benefit-cap/when-youre-not-affected': 4,
#  '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member': 4,
#  '/report-benefits-change-circumstances': 4,
#  '/the-warm-home-discount-scheme': 4,
#  '/self-employed-national-insurance-rates': 4,
#  '/taking-sick-leave': 4,
#  '/agency-workers-your-rights/basic-information-you-should-receive': 4,
#  '/become-appointee-for-someone-claiming-benefits': 4,
#  '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments': 4,
#  '/government/collections/hm-revenue-and-customs-service-availability-and-issues': 4,
#  '/search/policy-papers-and-consultations': 4,
#  '/claim-tax-refund': 4,
#  '/bills-benefits': 4,
#  '/state-pension/what-youll-get': 4,
#  '/parental-bereavement-pay-leave': 4,
#  '/child-benefit-payment-dates': 4,
#  '/apply-housing-benefit-from-council': 4,
#  '/calculate-employee-redundancy-pay': 4,
#  '/housing-benefit/what-youll-get': 4,
#  '/get-help-hmrc-extra-support': 4,
#  '/dbs-check-applicant-criminal-record/get-a-standard-or-enhanced-dbs-check-for-an-employee': 4,
#  '/browse/driving/number-plate': 4,
#  '/assisted-digital-help-online-applications': 4,
#  '/new-state-pension/inheriting-or-increasing-state-pension-from-a-spouse-or-civil-partner': 4,
#  '/benefit-overpayments': 4,
#  '/advanced-learner-loan/bursary-fund': 4,
#  '/browse/childcare-parenting/childcare': 4,
#  '/deferring-state-pension': 4,
#  '/solve-workplace-dispute': 4,
#  '/government/publications/dbs-identity-checking-guidelines': 4,
#  '/register-employer': 4,
#  '/guidance/track-a-dbs-application': 4,
#  '/settled-status-eu-citizens-families/family-member-eligible-person-from-northern-ireland': 4,
#  '/time-off-for-dependants': 4,
#  '/careers-helpline-for-teenagers': 4,
#  '/log-in-register-hmrc-online-services/problems-signing-in': 4,
#  '/student-finance/extra-help': 4,
#  '/disability-premiums/what-youll-get': 4,
#  '/holiday-entitlement-rights/holiday-pay-the-basics': 4,
#  '/contracted-out': 4,
#  '/carers-allowance/eligibility': 4,
#  '/over-80-pension': 4,
#  '/report-unfit-work-children-vulnerable-adults': 4,
#  '/skilled-worker-visa/your-job': 4,
#  '/standard-visitor-visa/apply': 4,
#  '/maternity-allowance': 4,
#  '/government/publications/eu-settlement-scheme-introduction-for-employers/eu-settlement-scheme-introduction-for-employers': 4,
#  '/id-scan-eu-settlement-scheme': 4,
#  '/sure-start-maternity-grant': 4,
#  '/dismissal': 4,
#  '/employment-tribunals': 4,
#  '/guidance/how-to-quarantine-when-you-arrive-in-england': 4,
#  '/overtime-your-rights/time-off-and-paid-leave': 4,
#  '/child-tax-credit': 4,
#  '/foreign-travel-advice/spain': 4,
#  '/topic/business-tax/self-employed': 4,
#  '/browse/tax/self-assessment': 4,
#  '/government/publications/employing-disabled-people-and-people-with-health-conditions/employing-disabled-people-and-people-with-health-conditions': 4,
#  '/disability-living-allowance-children/rates': 4,
#  '/get-a-passport-urgently': 4,
#  '/calculate-statutory-sick-pay': 4,
#  '/browse/visas-immigration/student-visas': 4,
#  '/dvlaforms': 4,
#  '/funding-for-postgraduate-study': 4,
#  '/volunteering/volunteers-rights': 4,
#  '/check-mot-history': 4,
#  '/british-passport-eligibility': 4,
#  '/check-mot-status': 4,
#  '/pip/how-to-claim': 4,
#  '/guidance/statutory-sick-pay-employee-fitness-to-work': 4,
#  '/government/publications/dbs-application-forms-guide-for-applicants/dbs-application-form-guide-for-applicants': 4,
#  '/report-changes-child-benefit': 4,
#  '/paternity-pay-leave/eligibility': 4,
#  '/marriage-allowance': 4,
#  '/council-housing': 4,
#  '/ancestry-visa': 4,
#  '/employment-support-allowance/how-to-claim': 4,
#  '/employ-someone': 4,
#  '/browse/births-deaths-marriages/register-offices': 4,
#  '/minimum-wage-different-types-work': 4,
#  '/new-state-pension/how-its-calculated': 4,
#  '/browse/benefits/families': 4,
#  '/find-pension-centre': 4,
#  '/uk-family-visa': 4,
#  '/help/terms-conditions': 4,
#  '/lost-national-insurance-number': 4,
#  '/paye-forms-p45-p60-p11d': 4,
#  '/government/organisations/hm-revenue-customs/contact': 4,
#  '/browse/abroad/passports': 4,
#  '/browse/education/school-life': 4,
#  '/dismissal/reasons-you-can-be-dismissed': 4,
#  '/pensions-advisory-service': 4,
#  '/call-charges': 4,
#  '/how-to-have-your-benefits-paid': 4,
#  '/health-care-worker-visa/your-job': 4,
#  '/skilled-worker-visa': 4,
#  '/child-employment': 4,
#  '/welfare/jobseekers-allowance': 4,
#  '/apply-standard-visitor-visa': 4,
#  '/government/topical-events/plan-for-jobs': 4,
#  '/your-employment-contract-how-it-can-be-changed/dealing-with-problems': 4,
#  '/government/organisations/disclosure-and-barring-service/about': 4,
#  '/browse/tax/dealing-with-hmrc': 4,
#  '/order-coronavirus-rapid-lateral-flow-tests': 4,
#  '/government/publications/qualifications-in-new-funded-offers': 4,
#  '/tax-on-pension/how-your-tax-is-paid': 4,
#  '/guidance/brexit-guidance-for-businesses': 4,
#  '/find-out-dbs-check': 4,
#  '/self-assessment-tax-returns': 4,
#  '/topic/immigration-operational-guidance': 4,
#  '/parents-learning-allowance': 4,
#  '/personal-pensions-your-rights': 4,
#  '/employment-contracts-and-conditions/contract-terms': 4,
#  '/browse/education/school-admissions-transport': 4,
#  '/sold-bought-vehicle': 4,
#  '/income-support/report-a-change-of-circumstances': 4,
#  '/find-pension-contact-details': 4,
#  '/start-up-visa': 4,
#  '/temporary-worker-charity-worker-visa': 4,
#  '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means': 4,
#  '/student-visa/extend-your-visa': 4,
#  '/topic/personal-tax/income-tax': 4,
#  '/copy-of-police-records': 4,
#  '/government/publications/access-to-work-guide-for-employers/access-to-work-factsheet-for-employers': 4,
#  '/browse/disabilities/rights': 4,
#  '/guidance/national-minimum-wage-work-experience-and-internships': 4,
#  '/state-pension': 4,
#  '/right-of-abode/commonwealth-citizens': 4,
#  '/browse/citizenship/citizenship': 4,
#  '/get-paye-forms-p45-p60': 4,
#  '/get-document-legalised': 4,
#  '/browse/visas-immigration/family-visas': 4,
#  '/vehicles-can-drive': 4,
#  '/help/accessibility-statement': 4,
#  '/browse/citizenship/charities-honours': 4,
#  '/government/publications/eu-settlement-scheme-application-processing-times/eu-settlement-scheme-pilot-current-expected-processing-times-for-applications': 4,
#  '/browse/benefits/bereavement': 4,
#  '/government/publications/right-to-work-checklist': 4,
#  '/browse/disabilities/work': 4,
#  '/advanced-learner-loan/what-youll-get': 4,
#  '/new-employee/employee-information': 4,
#  '/fraud-error-prevention-centres': 4,
#  '/government/publications/capability-for-work-questionnaire': 4,
#  '/government/collections/statutory-pay-forms': 4,
#  '/discrimination-your-rights': 4,
#  '/guidance/dvla-coronavirus-covid-19-update': 4,
#  '/voluntary-national-insurance-contributions/who-can-pay-voluntary-contributions': 4,
#  '/statutory-sick-pay/eligibility': 4,
#  '/government/collections/desg-graduate-scheme': 4,
#  '/national-minimum-wage/employers-and-the-minimum-wage': 4,
#  '/welfare/entitlement': 4,
#  '/over-80-pension/how-to-claim': 4,
#  '/government/organisations/hm-revenue-customs/services-information': 4,
#  '/government/publications/jobseekers-allowance-sanctions-leaflet/jobseekers-allowance-sanctions-how-to-keep-your-benefit-payment': 4,
#  '/find-coronavirus-support': 4,
#  '/uk-family-visa/partner-spouse': 4,
#  '/housing-benefit/how-to-claim': 4,
#  '/settled-status-eu-citizens-families/what-youll-need-to-apply': 4,
#  '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus': 4,
#  '/redundancy-your-rights/being-selected-for-redundancy': 4,
#  '/apply-national-insurance-number': 4,
#  '/report-benefit-fraud': 4,
#  '/identitycards': 4,
#  '/government/publications/dbs-application-forms-guide-for-applicants': 4,
#  '/support-for-mortgage-interest/eligibility': 4,
#  '/guidance/booking-and-staying-in-a-quarantine-hotel-when-you-arrive-in-england': 4,
#  '/winter-fuel-payment/how-much-youll-get': 4,
#  '/penalties-for-employing-illegal-workers': 4,
#  '/disability-premiums/eligibility': 4,
#  '/career-breaks': 4,
#  '/government/publications/easy-read-get-help-at-work-if-youre-disabled-or-have-a-health-condition-access-to-work': 4,
#  '/voluntary-national-insurance-contributions/rates': 4,
#  '/tax-on-pension': 4,
#  '/voluntary-national-insurance-contributions': 4,
#  '/council-tax': 4,
#  '/eu-eea': 4,
#  '/universal-credit/changes-of-circumstances': 4,
#  '/passport-advice-line': 4,
#  '/student-finance-register-login': 4,
#  '/pay-and-work-rights': 4,
#  '/industrial-injuries-disablement-benefit': 4,
#  '/browse/education/student-finance': 4,
#  '/get-help-savings-low-income': 4,
#  '/browse/births-deaths-marriages/child': 4,
#  '/terminal-illness-benefits': 4,
#  '/uk-border-control': 4,
#  '/government/publications/dwp-jobcentre-register': 4,
#  '/tax-help': 4,
#  '/find-a-regulated-qualification': 4,
#  '/deferring-state-pension/what-you-get': 4,
#  '/maximum-weekly-working-hours': 4,
#  '/book-theory-test': 4,
#  '/browse/citizenship/government': 4,
#  '/apply-medal-or-veterans-badge': 4,
#  '/claim-benefits-abroad': 4,
#  '/uk-visa-sponsorship-employers/eligibility': 4,
#  '/government/publications/application-for-a-state-pension-statement': 4,
#  '/au-pairs-employment-law': 4,
#  '/tax-relief-for-employees/working-at-home': 4,
#  '/government-authorised-exchange': 4,
#  '/apply-start-up-loan': 4,
#  '/international-pension-centre': 4,
#  '/business-finance-support': 4,
#  '/further-education-courses': 4,
#  '/settled-status-eu-citizens-families/after-youve-applied': 4,
#  '/biometric-residence-permits': 4,
#  '/council-tax-bands': 4,
#  '/flexible-working/applying-for-flexible-working': 4,
#  '/pay-self-assessment-tax-bill': 4,
#  '/change-address-driving-licence': 4,
#  '/personal-tax-account/sign-in/prove-identity': 4,
#  '/guidance/claim-back-statutory-sick-pay-paid-to-employees-due-to-coronavirus-covid-19': 4,
#  '/guidance/how-your-trading-conditions-affect-your-eligibility-for-the-self-employment-income-support-scheme': 4,
#  '/income-support/if-you-already-get-income-support': 4,
#  '/contract-types-and-employer-responsibilities': 4,
#  '/join-trade-union': 4,
#  '/apply-citizenship-indefinite-leave-to-remain/how-to-apply': 4,
#  '/browse/business/setting-up': 4,
#  '/browse/tax/national-insurance': 4,
#  '/faster-decision-visa-settlement': 4,
#  '/government/publications/budgeting-loan-claim-form': 4,
#  '/mandatory-reconsideration/how-to-ask-for-mandatory-reconsideration': 4,
#  '/monitoring-work-workers-rights': 4,
#  '/maternity-allowance/how-to-claim': 4,
#  '/browse/visas-immigration/eu-eea-swiss': 4,
#  '/winter-fuel-payment/eligibility': 4,
#  '/employment/finding-job': 4,
#  '/english-language': 4,
#  '/guidance/national-skills-fund': 4,
#  '/employ-trainees': 4,
#  '/education-maintenance-allowance-ema': 4,
#  '/how-to-claim-new-style-esa': 4,
#  '/apply-online-to-replace-a-driving-licence': 4,
#  '/browse/education/universities-higher-education': 4,
#  '/biometric-residence-permits/report-problem': 4,
#  '/standard-visitor-visa': 4,
#  '/repaying-your-student-loan': 4,
#  '/topic/crime-policing/criminal-record-disclosure': 4,
#  '/sponsor-management-system': 4,
#  '/government/publications/the-basic-state-pension': 4,
#  '/guidance/eu-settlement-scheme-how-we-use-your-personal-information': 4,
#  '/bank-holidays': 4,
#  '/medical-suspensions-from-work': 4,
#  '/budgeting-help-benefits/after-you-apply': 4,
#  '/government/collections/new-enterprise-allowance-campaign': 4,
#  '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships': 4,
#  '/1619-bursary-fund/how-to-claim': 4,
#  '/employment-support-allowance/change-of-circumstances': 4,
#  '/driving-medical-conditions': 4,
#  '/intensive-personalised-employment-support': 4,
#  '/plan-for-retirement': 4,
#  '/topic/personal-tax/self-assessment': 4,
#  '/health-care-worker-visa': 4,
#  '/apply-blue-badge': 4,
#  '/browse/childcare-parenting/schools-education': 4,
#  '/universal-credit/what-youll-get': 4,
#  '/check-university-award-degree': 4,
#  '/holiday-entitlement-rights/booking-time-off-': 4,
#  '/government/publications/universal-credit-work-allowances/universal-credit-work-allowances': 4,
#  '/personal-tax-account/sign-in/create-account': 4,
#  '/severe-disablement-allowance': 4,
#  '/report-cash-in-hand-pay': 4,
#  '/government/collections/helping-young-people-into-work': 4,
#  '/universal-credit/contact-universal-credit': 4,
#  '/working-tax-credit': 4,
#  '/carers-credit/eligibility': 4,
#  '/estimate-income-tax': 4,
#  '/redundancy-your-rights/redundancy-pay': 4,
#  '/contracted-out/check-if-you-were-contracted-out': 4,
#  '/1619-bursary-fund/eligibility': 4,
#  '/reasonable-adjustments-for-disabled-workers': 4,
#  '/check-immigration-status': 4,
#  '/student-jobs-paying-tax': 4,
#  '/state-pension/circumstances-change': 4,
#  '/topic/higher-education/scholarships-for-overseas-students': 4,
#  '/guidance/brexit-guidance-for-individuals-and-families': 4,
#  '/housing-and-universal-credit': 4,
#  '/guidance/tax-professional-development-programme': 4,
#  '/tips-at-work': 4,
#  '/pension-credit': 4,
#  '/browse/driving/vehicle-tax-mot-insurance': 4,
#  '/book-driving-test': 4,
#  '/view-prove-immigration-status': 4,
#  '/employers-sick-pay/eligibility-and-form-ssp1': 4,
#  '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide': 4,
#  '/browse/driving/learning-to-drive': 4,
#  '/how-tax-credits-affect-other-benefits': 4,
#  '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa': 4,
#  '/short-term-benefit-advance/how-to-apply': 4,
#  '/topic/business-tax/paye': 4,
#  '/looking-for-work-if-disabled/applying-for-a-job': 4,
#  '/financial-help-disabled/vehicles-and-transport': 4,
#  '/government/collections/eu-settlement-scheme-applicant-information': 4,
#  '/early-retirement-pension': 4,
#  '/tax-free-childcare': 4,
#  '/government/publications/employment-and-support-allowance-permitted-work-form/permitted-work-factsheet': 4,
#  '/guidance/check-if-you-could-be-covered-by-the-coronavirus-job-retention-scheme': 4,
#  '/advanced-learner-loan/how-to-apply': 4,
#  '/right-to-reside': 4,
#  '/government/collections/statutory-sick-pay-and-leave': 4,
#  '/find-an-immigration-adviser': 4,
#  '/get-coronavirus-test': 4,
#  '/employee-rights-when-on-leave': 4,
#  '/renew-adult-passport/renew': 4,
#  '/claim-redundancy': 4,
#  '/national-minimum-wage/who-gets-the-minimum-wage': 4,
#  '/government/publications/right-to-work-checks-employers-guide': 4,
#  '/search/research-and-statistics': 4,
#  '/get-a-passport-urgently/online-premium-service': 4,
#  '/employment-contracts-and-conditions': 4,
#  '/state-pension-through-partner': 4,
#  '/government/publications/the-national-minimum-wage-in-2021': 4,
#  '/government/publications/your-new-state-pension-explained/your-state-pension-explained': 4,
#  '/browse/visas-immigration/tourist-short-stay-visas': 4,
#  '/uk-residence-card': 4,
#  '/child-trust-funds/managing-the-account': 4,
#  '/apply-sponsor-licence': 4,
#  '/uk-border-control/before-you-leave-for-the-uk': 4,
#  '/claim-tax-credits/what-counts-as-income': 4,
#  '/topic/benefits-credits/child-benefit': 4,
#  '/check-income-tax-current-year/sign-in/create-account': 4,
#  '/holiday-entitlement-rights': 4,
#  '/legal-obligations-drivers-riders': 4,
#  '/state-pension/eligibility': 4,
#  '/benefit-overpayments/how-to-make-a-repayment': 4,
#  '/government/organisations/foreign-commonwealth-office': 4,
#  '/budgeting-help-benefits/eligibility': 4,
#  '/browse/driving/driving-licences': 4,
#  '/guidance/redundancy-help-finding-work-and-claiming-benefits': 4,
#  '/guidance/working-safely-during-covid-19': 4,
#  '/additional-state-pension/inheriting': 4,
#  '/government/organisations/hm-revenue-customs/contact/change-your-personal-details': 4,
#  '/get-undergraduate-student-loan': 4,
#  '/skilled-worker-visa/when-you-can-be-paid-less': 4,
#  '/government/organisations/hm-revenue-customs/contact/online-services-helpdesk': 4,
#  '/rest-breaks-work': 4,
#  '/plan-retirement-income/get-financial-advice': 4,
#  '/healthcare-immigration-application': 4,
#  '/new-state-pension/youve-been-in-a-workplace-personal-or-stakeholder-pension': 4,
#  '/voluntary-national-insurance-contributions/deadlines': 4,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals': 4,
#  '/benefit-fraud': 4,
#  '/universal-credit/your-responsibilities': 4,
#  '/new-state-pension/what-youll-get': 4,
#  '/workplace-pensions/managing-your-pension': 4,
#  '/tell-hmrc-change-of-details/income-changes': 4,
#  '/redundancy-your-rights': 4,
#  '/paye-forms-p45-p60-p11d/lost-paye-forms': 4,
#  '/browse/disabilities/equipment': 4,
#  '/browse/visas-immigration/asylum': 4,
#  '/government/publications/maternity-allowance-claim-form': 4,
#  '/jobseekers-allowance/apply-new-style-jsa/eligibility': 4,
#  '/guidance/coronavirus-covid-19-what-to-do-if-youre-employed-and-cannot-work': 4,
#  '/graduate-visa': 4,
#  '/self-assessment-forms-and-helpsheets': 4,
#  '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes': 4,
#  '/guidance/settled-status-for-eu-citizens-and-their-families-translations': 4,
#  '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions': 4,
#  '/what-is-the-construction-industry-scheme': 4,
#  '/government/publications/statutory-sick-pay-employee-not-entitled-form-for-employers': 4,
#  '/handing-in-your-notice': 4,
#  '/renew-adult-passport': 4,
#  '/child-benefit/what-youll-get': 4,
#  '/payment-exception-service': 4,
#  '/guidance/basic-dbs-checks-guidance': 4,
#  '/windrush-prove-your-right-to-be-in-the-uk': 4,
#  '/personal-tax-account': 4,
#  '/pension-credit/eligibility': 4,
#  '/chwilio-am-swydd': 4,
#  '/vehicle-tax': 4,
#  '/get-ready-to-employ-someone': 4,
#  '/pip/what-youll-get': 4,
#  '/guidance/contact-the-department-for-work-and-pensions-about-its-policies': 4,
#  '/financial-help-disabled/home-and-housing': 4,
#  '/id-for-driving-licence': 4,
#  '/family-permit': 4,
#  '/student-visa/family-members': 4,
#  '/pension-credit/what-youll-get': 4,
#  '/carers-allowance/if-youre-working-': 4,
#  '/budgeting-help-benefits/repayments': 4,
#  '/government/organisations/hm-revenue-customs': 4,
#  '/government/organisations/home-office/about/recruitment': 4,
#  '/apply-to-come-to-the-uk/prove-your-identity': 4,
#  '/carers-allowance/how-to-claim': 4,
#  '/universal-credit/other-financial-support': 4,
#  '/national-insurance/your-national-insurance-number': 4,
#  '/universal-credit/how-youre-paid': 4,
#  '/moving-or-retiring-abroad': 4,
#  '/find-travel-test-provider': 4,
#  '/universal-credit/how-your-earnings-affect-your-payments': 4,
#  '/find-local-council': 4,
#  '/agricultural-workers-rights': 4,
#  '/tax-company-benefits': 4,
#  '/guidance/coronavirus-covid-19-testing-for-people-travelling-to-england': 4,
#  '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees': 4,
#  '/payslips': 4,
#  '/log-in-file-self-assessment-tax-return': 4,
#  '/guidance/immigration-rules/immigration-rules-part-5-working-in-the-uk': 4,
#  '/national-minimum-wage': 4,
#  '/guidance/return-to-your-claim-for-the-self-employment-income-support-scheme': 4,
#  '/employers-workplace-pensions-rules': 4,
#  '/settle-in-the-uk': 4,
#  '/government/publications/introducing-govuk-verify/introducing-govuk-verify': 4,
#  '/government/publications/united-kingdom-security-vetting-clearance-levels/national-security-vetting-clearance-levels': 4,
#  '/pension-credit/change-of-circumstances': 4,
#  '/minimum-wage-different-types-work/paid-an-annual-salary': 4,
#  '/government/publications/attendance-allowance-claim-form': 4,
#  '/guidance/get-help-with-benefits-and-pensions-if-you-have-accessibility-needs': 4,
#  '/attendance-allowance/eligibility': 4,
#  '/guidance/coronavirus-covid-19-what-to-do-if-youre-self-employed-and-getting-less-work-or-no-work': 4,
#  '/track-your-driving-licence-application': 4,
#  '/career-development-loans': 4,
#  '/government/publications/test-and-trace-support-payment-scheme-claiming-financial-support/claiming-financial-support-under-the-test-and-trace-support-payment-scheme': 4,
#  '/child-tax-credit/new-claim': 4,
#  '/government/organisations/the-pensions-advisory-service': 4,
#  '/attendance-allowance/what-youll-get': 4,
#  '/contact-hmrc': 4,
#  '/renew-driving-licence': 4,
#  '/government/publications/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19/guidance-on-shielding-and-protecting-extremely-vulnerable-persons-from-covid-19': 4,
#  '/check-state-pension/sign-in/create-account': 4,
#  '/graduate-visa/documents-youll-need-to-apply': 4,
#  '/set-up-self-employed': 4,
#  '/browse/benefits/help-for-carers': 4,
#  '/jobcentre-plus-help-for-recruiters/other-employment-schemes': 4,
#  '/grant-bursary-adult-learners': 4,
#  '/sure-start-maternity-grant/eligibility': 4,
#  '/private-renting': 4,
#  '/recruitment-disabled-people': 4,
#  '/pension-types': 4,
#  '/claim-asylum': 4,
#  '/bereavement-support-payment': 4,
#  '/budgeting-help-benefits/how-to-apply': 4,
#  '/after-a-death/organisations-you-need-to-contact-and-tell-us-once': 4,
#  '/test-and-trace-support-payment': 4,
#  '/mandatory-reconsideration': 4,
#  '/handing-in-your-notice/gardening-leave': 4,
#  '/education/further-and-higher-education-skills-and-vocational-training': 4,
#  '/dla-disability-living-allowance-benefit': 4,
#  '/early-retirement-pension/benefits': 4,
#  '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service': 4,
#  '/state-pension-age': 4,
#  '/tax-come-to-uk': 4,
#  '/guidance/claim-a-grant-through-the-self-employment-income-support-scheme': 4,
#  '/paye-for-employers': 4,
#  '/further-education-courses/financial-help': 4,
#  '/browse/employing-people/dismissals-redundancies': 4,
#  '/tell-hmrc-change-of-details': 4,
#  '/disability-living-allowance-children': 4,
#  '/moving-from-benefits-to-work/job-search-programmes': 4,
#  '/government/publications/new-enterprise-allowance-phase-2-provider-guidance/new-enterprise-allowance-phase-2-provider-guidance': 4,
#  '/check-income-tax-current-year': 4,
#  '/understanding-your-pay': 4,
#  '/marriage-visa': 4,
#  '/workplace-bullying-and-harassment': 4,
#  '/become-magistrate': 4,
#  '/pip': 4,
#  ...}

# %% [markdown]
# ### Order by centrality metrics

# %%
# degree centrality: counts the number of incoming and outgoing relationships from a node - 'most connected'
# the higher the degree, the more central the node is
g_degree = nx.degree_centrality(g)
g_degree = dict(sorted(g_degree.items(), key=itemgetter(1), reverse=True))
g_degree
# Out:
# {'/browse/working': 0.7049873203719357,
#  '/find-a-job': 0.6306001690617075,
#  '/contact-jobcentre-plus': 0.5756551141166525,
#  '/jobseekers-allowance': 0.4953508030431107,
#  '/apply-apprenticeship': 0.4074387151310228,
#  '/sign-in-universal-credit': 0.3431952662721893,
#  '/government/organisations/department-for-work-pensions': 0.32628909551986474,
#  '/view-prove-immigration-status': 0.31868131868131866,
#  '/benefits-calculators': 0.29247675401521556,
#  '/universal-credit': 0.2882502113271344,
#  '/log-in-register-hmrc-online-services': 0.2764158918005072,
#  '/state-pension-age': 0.2519019442096365,
#  '/access-to-work': 0.22738799661876583,
#  '/apply-national-insurance-number': 0.2121724429416737,
#  '/search/services': 0.2071005917159763,
#  '/contact-pension-service': 0.20456466610312762,
#  '/national-minimum-wage-rates': 0.20287404902789516,
#  '/browse/working/finding-job': 0.1978021978021978,
#  '/contact-ukvi-inside-outside-uk': 0.19103972950126796,
#  '/government/organisations': 0.18850380388841925,
#  '/check-state-pension': 0.18258664412510564,
#  '/employment-support-allowance': 0.18005071851225696,
#  '/government/organisations/hm-revenue-customs': 0.17666948436179206,
#  '/jobseekers-allowance/apply-new-style-jsa': 0.1758241758241758,
#  '/topic/further-education-skills/apprenticeships': 0.17413355874894335,
#  '/become-apprentice': 0.16821639898562973,
#  '/contact-jobcentre-plus/existing-benefit-claims': 0.16737109044801352,
#  '/jobseekers-allowance/eligibility': 0.16229923922231615,
#  '/view-right-to-work': 0.16060862214708369,
#  '/pension-credit': 0.16060862214708369,
#  '/browse/working/time-off': 0.15891800507185122,
#  '/call-charges': 0.15638207945900254,
#  '/settled-status-eu-citizens-families': 0.1555367709213863,
#  '/browse/working/tax-minimum-wage': 0.15469146238377007,
#  '/check-job-applicant-right-to-work': 0.1530008453085376,
#  '/universal-credit/eligibility': 0.1530008453085376,
#  '/government/organisations/disclosure-and-barring-service': 0.1521555367709214,
#  '/state-pension': 0.1521555367709214,
#  '/check-uk-visa': 0.15131022823330514,
#  '/check-state-pension/sign-in/prove-identity': 0.14961961115807268,
#  '/check-national-insurance-record': 0.14961961115807268,
#  '/criminal-record-checks-apply-role': 0.14370245139475907,
#  '/new-state-pension': 0.14370245139475907,
#  '/statutory-sick-pay': 0.1335587489433643,
#  '/browse/benefits/looking-for-work': 0.1327134404057481,
#  '/national-insurance': 0.1327134404057481,
#  '/dbs-update-service': 0.13102282333051563,
#  '/browse/benefits/manage-your-benefit': 0.12933220625528316,
#  '/pip': 0.12933220625528316,
#  '/career-skills-and-training': 0.12595097210481826,
#  '/browse/visas-immigration/work-visas': 0.125105663567202,
#  '/browse/working/contract-working-hours': 0.12341504649196956,
#  '/financial-help-disabled': 0.12341504649196956,
#  '/government/organisations/uk-visas-and-immigration': 0.1217244294167371,
#  '/get-state-pension': 0.12003381234150465,
#  '/browse/working/workplace-personal-pensions': 0.11834319526627218,
#  '/contact-jobcentre-plus/new-benefit-claims': 0.11749788672865595,
#  '/browse/benefits/disability': 0.11665257819103972,
#  '/legal-right-work-uk': 0.11496196111580727,
#  '/employment-contracts-and-conditions': 0.11411665257819104,
#  '/universal-credit/how-to-claim': 0.11158072696534234,
#  '/new-state-pension/what-youll-get': 0.10989010989010989,
#  '/personal-tax-account': 0.10989010989010989,
#  '/how-to-have-your-benefits-paid': 0.10989010989010989,
#  '/dbs-check-applicant-criminal-record': 0.10904480135249366,
#  '/carers-allowance': 0.10904480135249366,
#  '/housing-benefit': 0.10904480135249366,
#  '/lost-national-insurance-number': 0.10819949281487742,
#  '/employment-rights-for-interns': 0.10819949281487742,
#  '/guidance/redundancy-help-finding-work-and-claiming-benefits': 0.10735418427726119,
#  '/biometric-residence-permits': 0.10650887573964496,
#  '/national-insurance-credits': 0.10481825866441251,
#  '/guidance/red-amber-and-green-list-rules-for-entering-england': 0.10481825866441251,
#  '/employment-support-allowance/how-to-claim': 0.10397295012679628,
#  '/income-tax-rates': 0.10312764158918004,
#  '/personal-tax-account/sign-in/prove-identity': 0.10228233305156381,
#  '/skilled-worker-visa': 0.10143702451394758,
#  '/find-traineeship': 0.10059171597633136,
#  '/workplace-pensions': 0.09974640743871513,
#  '/browse/education/find-course': 0.0989010989010989,
#  '/plan-for-retirement': 0.0989010989010989,
#  '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme': 0.0989010989010989,
#  '/universal-credit/what-youll-get': 0.09805579036348266,
#  '/employment-support-allowance/eligibility': 0.09805579036348266,
#  '/contact-hmrc': 0.09805579036348266,
#  '/employers-checks-job-applicants': 0.09721048182586643,
#  '/taking-sick-leave': 0.0963651732882502,
#  '/income-support': 0.0963651732882502,
#  '/find-local-council': 0.09551986475063398,
#  '/settled-status-eu-citizens-families/applying-for-settled-status': 0.09298393913778528,
#  '/working-tax-credit': 0.09298393913778528,
#  '/guidance/new-style-jobseekers-allowance': 0.09129332206255282,
#  '/universal-credit/other-financial-support': 0.0904480135249366,
#  '/view-driving-licence': 0.08960270498732037,
#  '/universal-credit/contact-universal-credit': 0.08875739644970414,
#  '/attendance-allowance': 0.08875739644970414,
#  '/employment-status': 0.08875739644970414,
#  '/tax-on-pension': 0.08622147083685544,
#  '/government/organisations/home-office': 0.08622147083685544,
#  '/help': 0.08622147083685544,
#  '/government/organisations/hm-revenue-customs/contact': 0.08622147083685544,
#  '/government/publications/right-to-work-checklist': 0.08537616229923922,
#  '/browse/employing-people/recruiting-hiring': 0.08537616229923922,
#  '/national-insurance/your-national-insurance-number': 0.08453085376162299,
#  '/find-out-dbs-check': 0.08368554522400676,
#  '/holiday-entitlement-rights': 0.08368554522400676,
#  '/browse/employing-people/contracts': 0.0819949281487743,
#  '/guidance/universal-credit-advances': 0.08114961961115807,
#  '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees': 0.08114961961115807,
#  '/guidance/track-a-dbs-application': 0.08030431107354184,
#  '/additional-state-pension': 0.08030431107354184,
#  '/state-pension-if-you-retire-abroad': 0.07945900253592561,
#  '/employee-immigration-employment-status': 0.07945900253592561,
#  '/apply-universal-credit': 0.07945900253592561,
#  '/jobseekers-allowance/your-jsa-claim': 0.07861369399830938,
#  '/browse/benefits/families': 0.07861369399830938,
#  '/guidance/free-courses-for-jobs': 0.07776838546069315,
#  '/looking-for-work-if-disabled': 0.07776838546069315,
#  '/moving-from-benefits-to-work/starting-your-own-business': 0.07692307692307691,
#  '/browse/tax/income-tax': 0.0760777683854607,
#  '/dla-disability-living-allowance-benefit': 0.0760777683854607,
#  '/browse/working/redundancies-dismissals': 0.07523245984784446,
#  '/personal-pensions-your-rights': 0.07523245984784446,
#  '/child-benefit': 0.07523245984784446,
#  '/claim-tax-refund': 0.07523245984784446,
#  '/state-pension/eligibility': 0.07438715131022823,
#  '/browse/benefits/low-income': 0.07438715131022823,
#  '/browse/disabilities/benefits': 0.07438715131022823,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals': 0.07438715131022823,
#  '/health-conditions-disability-universal-credit': 0.073541842772612,
#  '/national-insurance/how-much-you-pay': 0.073541842772612,
#  '/criminal-record-check-documents': 0.07269653423499577,
#  '/government/collections/kickstart-scheme': 0.07269653423499577,
#  '/moving-from-benefits-to-work': 0.07269653423499577,
#  '/employment-support-allowance/what-youll-get': 0.07185122569737953,
#  '/manage-your-tax-credits': 0.07185122569737953,
#  '/calculate-your-holiday-entitlement': 0.07100591715976332,
#  '/moving-from-benefits-to-work/support-when-you-start-working': 0.07100591715976332,
#  '/pip/how-to-claim': 0.07100591715976332,
#  '/guidance/dbs-check-requests-guidance-for-employers': 0.07100591715976332,
#  '/jobseekers-allowance/report-a-change-of-circumstances': 0.07016060862214708,
#  '/government/organisations/hm-revenue-customs/contact/national-insurance
#  '/guidance/basic-dbs-checks-guidance': 0.057480980557903634,
#  '/government/organisations/education-and-skills-funding-agency': 0.057480980557903634,
#  '/employment-support-allowance/your-esa-claim': 0.057480980557903634,
#  '/tax-codes': 0.057480980557903634,
#  '/benefit-cap': 0.057480980557903634,
#  '/child-tax-credit': 0.057480980557903634,
#  '/browse/visas-immigration/settle-in-the-uk': 0.0566356720202874,
#  '/uk-visa-sponsorship-employers': 0.0566356720202874,
#  '/tax-credits-calculator': 0.0566356720202874,
#  '/browse/benefits/unable-to-work': 0.05579036348267117,
#  '/am-i-getting-minimum-wage': 0.05579036348267117,
#  '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens': 0.05579036348267117,
#  '/mandatory-reconsideration': 0.05579036348267117,
#  '/access-to-work/what-youll-get': 0.054945054945054944,
#  '/apply-for-elderly-person-bus-pass': 0.054945054945054944,
#  '/skilled-worker-visa/your-job': 0.054945054945054944,
#  '/voluntary-national-insurance-contributions': 0.054945054945054944,
#  '/browse/childcare-parenting/financial-help-children': 0.054945054945054944,
#  '/working-for-yourself': 0.054945054945054944,
#  '/apply-council-tax-reduction': 0.054945054945054944,
#  '/uk-residence-card': 0.054945054945054944,
#  '/estimate-income-tax': 0.054945054945054944,
#  '/disability-benefits-helpline': 0.054945054945054944,
#  '/contact-jobcentre-plus/change-cancel-appointment': 0.05409974640743871,
#  '/statutory-sick-pay/eligibility': 0.05409974640743871,
#  '/know-when-you-can-leave-school': 0.05409974640743871,
#  '/pip/what-youll-get': 0.05409974640743871,
#  '/carers-allowance/eligibility': 0.05409974640743871,
#  '/financial-help-disabled/disability-and-sickness-benefits': 0.05409974640743871,
#  '/pension-credit-calculator': 0.05409974640743871,
#  '/advertise-job': 0.05325443786982248,
#  '/budgeting-help-benefits': 0.05325443786982248,
#  '/bank-holidays': 0.05325443786982248,
#  '/what-different-qualification-levels-mean/list-of-qualification-levels': 0.05325443786982248,
#  '/settle-in-the-uk': 0.05325443786982248,
#  '/employment-status/employee': 0.05325443786982248,
#  '/tax-national-insurance-after-state-pension-age': 0.05325443786982248,
#  '/early-retirement-pension/personal-and-workplace-pensions': 0.052409129332206254,
#  '/work-health-programme': 0.052409129332206254,
#  '/further-education-courses': 0.052409129332206254,
#  '/how-to-claim-new-style-jsa': 0.05156382079459002,
#  '/universal-credit/how-your-earnings-affect-your-payments': 0.05156382079459002,
#  '/settled-status-eu-citizens-families/eligibility': 0.05156382079459002,
#  '/check-immigration-status': 0.05156382079459002,
#  '/redundancy-your-rights': 0.05156382079459002,
#  '/guidance/apply-for-a-kickstart-scheme-grant': 0.05156382079459002,
#  '/universal-credit/changes-of-circumstances': 0.05156382079459002,
#  '/work-reference': 0.05156382079459002,
#  '/check-income-tax-current-year': 0.05071851225697379,
#  '/early-retirement-pension': 0.05071851225697379,
#  '/state-pension/circumstances-change': 0.05071851225697379,
#  '/volunteering': 0.05071851225697379,
#  '/uk-border-control': 0.05071851225697379,
#  '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2
#  '/copy-of-police-records': 0.044801352493660185,
#  '/find-internship': 0.044801352493660185,
#  '/national-insurance/national-insurance-classes': 0.044801352493660185,
#  '/browse/benefits/help-for-carers': 0.044801352493660185,
#  '/benefit-overpayments': 0.044801352493660185,
#  '/claim-benefits-abroad': 0.044801352493660185,
#  '/search/policy-papers-and-consultations': 0.044801352493660185,
#  '/government/organisations/hm-revenue-customs/contact/child-benefit': 0.044801352493660185,
#  '/government/organisations/disclosure-and-barring-service/about': 0.04395604395604395,
#  '/working-retirement-pension-age': 0.04395604395604395,
#  '/how-tax-credits-affect-other-benefits': 0.04395604395604395,
#  '/flexible-working': 0.04395604395604395,
#  '/right-to-reside': 0.04395604395604395,
#  '/plan-retirement-income/get-financial-advice': 0.04395604395604395,
#  '/topic/immigration-operational-guidance': 0.04395604395604395,
#  '/government/organisations/department-for-education': 0.04395604395604395,
#  '/guidance/digital-and-online-services': 0.04311073541842772,
#  '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do': 0.04311073541842772,
#  '/browse/driving/driving-licences': 0.04311073541842772,
#  '/employing-an-apprentice/get-funding': 0.04311073541842772,
#  '/log-in-register-hmrc-online-services/register': 0.04311073541842772,
#  '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations': 0.04311073541842772,
#  '/employee-rights-when-on-leave': 0.04311073541842772,
#  '/paternity-pay-leave': 0.04311073541842772,
#  '/student-jobs-paying-tax': 0.04311073541842772,
#  '/carers-allowance/effect-on-other-benefits': 0.04311073541842772,
#  '/browse/employing-people/time-off': 0.04311073541842772,
#  '/renew-driving-licence': 0.04311073541842772,
#  '/incapacity-benefit': 0.04311073541842772,
#  '/self-employed-national-insurance-rates': 0.04311073541842772,
#  '/criminal-record-checks-apply-role/application-process': 0.042265426880811495,
#  '/browse/working/armed-forces': 0.042265426880811495,
#  '/1619-bursary-fund': 0.042265426880811495,
#  '/tell-hmrc-change-address': 0.042265426880811495,
#  '/advanced-learner-loan': 0.042265426880811495,
#  '/biometric-residence-permits/collect': 0.042265426880811495,
#  '/check-income-tax-last-year': 0.042265426880811495,
#  '/universal-credit/your-responsibilities': 0.042265426880811495,
#  '/graduate-visa': 0.042265426880811495,
#  '/search/news-and-communications': 0.042265426880811495,
#  '/employing-staff': 0.042265426880811495,
#  '/solve-workplace-dispute': 0.042265426880811495,
#  '/topic/crime-policing/criminal-record-disclosure': 0.042265426880811495,
#  '/statutory-sick-pay/what-youll-get': 0.04142011834319526,
#  '/government/publications/dbs-application-forms-guide-for-applicants/dbs-application-form-guide-for-applicants': 0.04142011834319526,
#  '/pay-voluntary-class-3-national-insurance': 0.04142011834319526,
#  '/calculate-your-redundancy-pay': 0.04142011834319526,
#  '/become-appointee-for-someone-claiming-benefits': 0.04142011834319526,
#  '/payslips': 0.04142011834319526,
#  '/coronavirus/business-support': 0.04142011834319526,
#  '/state-pension-through-partner': 0.04142011834319526,
#  '/family-permit': 0.04142011834319526,
#  '/guidance/new-immigration-system-what-you-need-to-know': 0.04142011834319526,
#  '/topic/business-tax/self-employed': 0.04142011834319526,
#  '/child-benefit-tax-calculator': 0.027049873203719356,
#  '/guidance/visa-decision-waiting-times-applications-outside-the-uk': 0.027049873203719356,
#  '/entering-staying-uk': 0.027049873203719356,
#  '/guidance/eu-settlement-scheme-how-we-use-your-personal-information': 0.027049873203719356,
#  '/personal-tax-account/sign-in/create-account': 0.026204564666103127,
#  '/government/organisations/department-for-work-pensions/about/recruitment': 0.026204564666103127,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-standardenhanced-dbs-check-applications-from-1-july-2021': 0.026204564666103127,
#  '/courses-qualifications': 0.026204564666103127,
#  '/your-employment-contract-how-it-can-be-changed': 0.026204564666103127,
#  '/medical-suspensions-from-work': 0.026204564666103127,
#  '/moving-from-benefits-to-work/job-search-programmes': 0.026204564666103127,
#  '/understanding-your-pay': 0.026204564666103127,
#  '/employment-contracts-and-conditions/written-statement-of-employment-particulars': 0.026204564666103127,
#  '/uk-border-control/before-you-leave-for-the-uk': 0.026204564666103127,
#  '/topic/personal-tax/self-assessment': 0.026204564666103127,
#  '/uk-family-visa/partner-spouse': 0.026204564666103127,
#  '/tell-hmrc-change-of-details/income-changes': 0.026204564666103127,
#  '/continuous-employment-what-it-is': 0.026204564666103127,
#  '/holiday-entitlement-rights/booking-time-off-': 0.026204564666103127,
#  '/browse/visas-immigration/commonwealth-british-nationals-overseas': 0.026204564666103127,
#  '/constant-attendance-allowance': 0.026204564666103127,
#  '/windrush-prove-your-right-to-be-in-the-uk': 0.026204564666103127,
#  '/government/publications/apprenticeship-agreement-template': 0.026204564666103127,
#  '/dla-disability-living-allowance-benefit/dla-rates': 0.026204564666103127,
#  '/working-abroad': 0.026204564666103127,
#  '/find-pension-centre': 0.026204564666103127,
#  '/guidance/claim-for-wage-costs-through-the-coronavirus-job-retention-scheme': 0.026204564666103127,
#  '/government/publications/qualifications-in-new-funded-offers': 0.026204564666103127,
#  '/government/publications/standard-and-enhanced-dbs-check-privacy-policy/standard-and-enhanced-dbs-check-privacy-policy': 0.026204564666103127,
#  '/government/publications/dbs-update-service-application-form-checklist': 0.026204564666103127,
#  '/travel-abroad': 0.025359256128486895,
#  '/dismissal/reasons-you-can-be-dismissed': 0.025359256128486895,
#  '/maternity-pay-leave/how-to-claim': 0.025359256128486895,
#  '/maternity-allowance/what-youll-get': 0.025359256128486895,
#  '/dismissal/unfair-and-constructive-dismissal': 0.025359256128486895,
#  '/sure-start-maternity-grant/eligibility': 0.025359256128486895,
#  '/voluntary-national-insurance-contributions/deadlines': 0.025359256128486895,
#  '/housing-and-universal-credit/renting-from-private-landlord': 0.025359256128486895,
#  '/working-tax-credit/what-youll-get': 0.025359256128486895,
#  '/government/collections/dbs-update-service-promotional-material': 0.025359256128486895,
#  '/guidance/travel-to-england-from-another-country-during-coronavirus-covid-19': 0.025359256128486895,
#  '/government/publications/your-new-state-pension-explained/your-state-pension-explained': 0.025359256128486895,
#  '/death-spouse-benefits-tax-pension': 0.025359256128486895,
#  '/national-insurance-if-you-go-abroad': 0.025359256128486895,
#  '/government/organisations/foreign-commonwealth-development-office': 0.025359256128486895,
#  '/employment/finding-job': 0.014370245139475908,
#  '/browse/citizenship/government': 0.014370245139475908,
#  '/browse/disabilities/carers': 0.014370245139475908,
#  '/paternity-pay-leave/leave': 0.014370245139475908,
#  '/carers-credit/eligibility': 0.014370245139475908,
#  '/benefit-cap/when-youre-not-affected': 0.014370245139475908,
#  '/disciplinary-procedures-and-action-at-work': 0.014370245139475908,
#  '/government/publications/find-a-skills-bootcamp': 0.014370245139475908,
#  '/uk-visa-sponsorship-employers/eligibility': 0.014370245139475908,
#  '/disabled-facilities-grants/what-youll-get': 0.014370245139475908,
#  '/register-for-self-assessment': 0.014370245139475908,
#  '/overtime-your-rights/compulsory-overtime': 0.014370245139475908,
#  '/check-income-tax-current-year/sign-in/create-account': 0.014370245139475908,
#  '/apply-to-come-to-the-uk/prove-your-identity': 0.014370245139475908,
#  '/advanced-learner-loan/what-youll-get': 0.014370245139475908,
#  '/redundancy-payments-helpline': 0.014370245139475908,
#  '/benefit-cap/how-earnings-affect-when-benefit-cap-starts': 0.014370245139475908,
#  '/contract-types-and-employer-responsibilities': 0.014370245139475908,
#  '/claim-benefits-abroad/where-you-can-claim-benefits': 0.014370245139475908,
#  '/short-term-benefit-advance/how-to-apply': 0.014370245139475908,
#  '/tax-overpayments-and-underpayments/if-youre-due-a-refund': 0.014370245139475908,
#  '/government/publications/budgeting-loan-claim-form': 0.014370245139475908,
#  '/caution-warning-penalty': 0.014370245139475908,
#  '/standard-visitor-visa/documents-you-will-need': 0.014370245139475908,
#  '/government/publications/dwp-jobcentre-register': 0.014370245139475908,
#  '/check-british-citizenship': 0.014370245139475908,
#  ...}

# %%
nx.degree_centrality(g)
# Out:
# {'/view-prove-immigration-status': 0.31868131868131866,
#  '/browse/working': 0.7049873203719357,
#  '/find-a-job': 0.6306001690617075,
#  '/check-state-pension': 0.18258664412510564,
#  '/check-state-pension/sign-in/prove-identity': 0.14961961115807268,
#  '/jobseekers-allowance': 0.4953508030431107,
#  '/jobseekers-allowance/eligibility': 0.16229923922231615,
#  '/view-right-to-work': 0.16060862214708369,
#  '/contact-jobcentre-plus': 0.5756551141166525,
#  '/government/organisations/disclosure-and-barring-service': 0.1521555367709214,
#  '/topic/further-education-skills/apprenticeships': 0.17413355874894335,
#  '/apply-apprenticeship': 0.4074387151310228,
#  '/browse/working/finding-job': 0.1978021978021978,
#  '/jobseekers-allowance/apply-new-style-jsa': 0.1758241758241758,
#  '/dbs-update-service': 0.13102282333051563,
#  '/criminal-record-checks-apply-role': 0.14370245139475907,
#  '/new-state-pension': 0.14370245139475907,
#  '/government/organisations/department-for-work-pensions': 0.32628909551986474,
#  '/apply-national-insurance-number': 0.2121724429416737,
#  '/state-pension-age': 0.2519019442096365,
#  '/contact-pension-service': 0.20456466610312762,
#  '/new-state-pension/what-youll-get': 0.10989010989010989,
#  '/check-job-applicant-right-to-work': 0.1530008453085376,
#  '/contact-jobcentre-plus/new-benefit-claims': 0.11749788672865595,
#  '/become-apprentice/apply-for-an-apprenticeship': 0.04564666103127641,
#  '/contact-jobcentre-plus/existing-benefit-claims': 0.16737109044801352,
#  '/get-state-pension': 0.12003381234150465,
#  '/sign-in-universal-credit': 0.3431952662721893,
#  '/check-state-pension/sign-in/create-account': 0.04564666103127641,
#  '/become-apprentice': 0.16821639898562973,
#  '/universal-credit': 0.2882502113271344,
#  '/find-out-dbs-check': 0.08368554522400676,
#  '/access-to-work': 0.22738799661876583,
#  '/access-to-work/eligibility': 0.06762468300929839,
#  '/browse/working/workplace-personal-pensions': 0.11834319526627218,
#  '/legal-right-work-uk': 0.11496196111580727,
#  '/browse/benefits/looking-for-work': 0.1327134404057481,
#  '/universal-credit/eligibility': 0.1530008453085376,
#  '/state-pension': 0.1521555367709214,
#  '/access-to-work/what-youll-get': 0.054945054945054944,
#  '/browse/working/tax-minimum-wage': 0.15469146238377007,
#  '/contact-ukvi-inside-outside-uk': 0.19103972950126796,
#  '/criminal-record-checks-apply-role/application-process': 0.042265426880811495,
#  '/become-apprentice/pay-and-conditions': 0.06931530008453085,
#  '/universal-credit/what-youll-get': 0.09805579036348266,
#  '/personal-tax-account': 0.10989010989010989,
#  '/personal-tax-account/sign-in/prove-identity': 0.10228233305156381,
#  '/browse/benefits/manage-your-benefit': 0.12933220625528316,
#  '/benefits-calculators': 0.29247675401521556,
#  '/advertise-job': 0.05325443786982248,
#  '/browse/education/find-course': 0.0989010989010989,
#  '/employment-support-allowance': 0.18005071851225696,
#  '/employment-support-allowance/eligibility': 0.09805579036348266,
#  '/access-to-work/apply': 0.06424344885883347,
#  '/guidance/track-a-dbs-application': 0.08030431107354184,
#  '/government/publications/higher-and-degree-apprenticeships': 0.03550295857988166,
#  '/dbs-check-applicant-criminal-record': 0.10904480135249366,
#  '/browse/working/time-off': 0.15891800507185122,
#  '/jobseekers-allowance/your-jsa-claim': 0.07861369399830938,
#  '/pension-credit': 0.16060862214708369,
#  '/pension-credit/eligibility': 0.05917159763313609,
#  '/guidance/responsible-organisations': 0.04902789518174133,
#  '/browse/working/contract-working-hours': 0.12341504649196956,
#  '/national-minimum-wage-rates': 0.20287404902789516,
#  '/state-pension/eligibility': 0.07438715131022823,
#  '/new-state-pension/your-national-insurance-record-and-your-state-pension': 0.06762468300929839,
#  '/new-state-pension/how-to-claim': 0.06086221470836855,
#  '/browse/visas-immigration/work-visas': 0.125105663567202,
#  '/how-to-claim-new-style-jsa': 0.05156382079459002,
#  '/prove-right-to-rent': 0.044801352493660185,
#  '/guidance/basic-dbs-checks-guidance': 0.057480980557903634,
#  '/contact-jobcentre-plus/change-cancel-appointment': 0.05409974640743871,
#  '/government/collections/apprenticeship-vacancies': 0.034657650042265425,
#  '/dbs-check-applicant-criminal-record/get-a-basic-dbs-check-for-an-employee': 0.03381234150464919,
#  '/statutory-sick-pay': 0.1335587489433643,
#  '/taking-sick-leave': 0.0963651732882502,
#  '/additional-state-pension': 0.08030431107354184,
#  '/universal-credit/how-your-earnings-affect-your-payments': 0.05156382079459002,
#  '/government/publications/right-to-work-checklist': 0.08537616229923922,
#  '/employing-an-apprentice': 0.06846999154691462,
#  '/employing-an-apprentice/get-funding': 0.04311073541842772,
#  '/holiday-entitlement-rights/calculate-leave-entitlement': 0.027049873203719356,
#  '/travel-abroad': 0.025359256128486895,
#  '/plan-for-retirement': 0.0989010989010989,
#  '/maximum-weekly-working-hours': 0.06931530008453085,
#  '/log-in-register-hmrc-online-services/register': 0.04311073541842772,
#  '/biometric-residence-permits': 0.10650887573964496,
#  '/budgeting-help-benefits/how-to-apply': 0.0481825866441251,
#  '/health-conditions-disability-universal-credit': 0.073541842772612,
#  '/government/collections/kickstart-scheme': 0.07269653423499577,
#  '/employment/finding-job': 0.014370245139475908,
#  '/tell-hmrc-change-of-details': 0.04057480980557904,
#  '/new-state-pension/youve-been-in-a-workplace-personal-or-stakeholder-pension': 0.032121724429416736,
#  '/browse/visas-immigration/family-visas': 0.03550295857988166,
#  '/state-pension-if-you-retire-abroad/rates-of-state-pension': 0.023668639053254437,
#  '/tell-hmrc-change-address': 0.042265426880811495,
#  '/government/publications/skilled-worker-visa-shortage-occupations': 0.04057480980557904,
#  '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations': 0.04311073541842772,
#  '/national-minimum-wage': 0.0650887573964497,
#  '/government/organisations/department-for-work-pensions/about/recruitment': 0.026204564666103127,
#  '/government/publications/dbs-identity-checking-guidelines': 0.04564666103127641,
#  '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-standardenhanced-dbs-check-applications-from-1-july-2021': 0.026204564666103127,
#  '/view-driving-licence': 0.08960270498732037,
#  '/call-charges': 0.15638207945900254,
#  '/browse/citizenship/government': 0.014370245139475908,
#  '/access-to-work/renew': 0.02028740490278952,
#  '/state-pension/how-to-claim': 0.03550295857988166,
#  '/employment-support-allowance/your-esa-claim': 0.057480980557903634,
#  '/keeping-your-pay-tax-records': 0.03296703296703297,
#  '/apply-universal-credit': 0.07945900253592561,
#  '/browse/tax/self-assessment': 0.028740490278951817,
#  '/paye-forms-p45-p60-p11d': 0.0481825866441251,
#  '/moving-from-benefits-to-work': 0.07269653423499577,
#  '/income-support': 0.0963651732882502,
#  '/attendance-allowance': 0.08875739644970414,
#  '/attendance-allowance/what-youll-get': 0.032121724429416736,
#  '/pip/how-to-claim': 0.07100591715976332,
#  '/browse/visas-immigration/tourist-short-stay-visas': 0.03803888419273035,
#  '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means': 0.062552831783601,
#  '/browse/business/setting-up': 0.022823330515638205,
#  '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens': 0.05579036348267117,
#  '/employee-rights-when-on-leave': 0.04311073541842772,
#  '/apply-start-up-loan': 0.039729501267962805,
#  '/government/collections/right-to-work-checks-employer-guidance': 0.022823330515638205,
#  '/guidance/free-courses-for-jobs': 0.07776838546069315,
#  '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults': 0.03803888419273035,
#  '/rest-breaks-work': 0.04564666103127641,
#  '/topic/personal-tax/national-insurance': 0.05832628909551986,
#  '/browse/births-deaths-marriages/death': 0.015215553677092137,
#  '/additional-state-pension/eligibility': 0.024513947590870666,
#  '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-sche
#  '/working-abroad': 0.026204564666103127,
#  '/childcare-grant': 0.021978021978021976,
#  '/start-up-visa': 0.016060862214708368,
#  '/benefit-overpayments/repayments-when-someone-has-died': 0.010989010989010988,
#  '/contact-the-dvla': 0.060016906170752324,
#  '/track-your-driving-licence-application': 0.027895181741335585,
#  '/council-housing': 0.016060862214708368,
#  '/plan-retirement-income/working-past-state-pension-age': 0.016060862214708368,
#  '/employers-sick-pay/help-with-sick-pay': 0.012679628064243447,
#  '/government/organisations/home-office/about/recruitment': 0.012679628064243447,
#  '/settled-status-eu-citizens-families/apply-settled-status-for-child': 0.027895181741335585,
#  '/what-is-the-construction-industry-scheme': 0.021132713440405747,
#  '/government/publications/dwp-jobcentre-register': 0.014370245139475908,
#  '/check-british-citizenship': 0.014370245139475908,
#  '/advanced-learner-loan/bursary-fund': 0.016906170752324597,
#  '/cold-weather-payment/how-to-claim': 0.014370245139475908,
#  '/apply-online-for-student-finance': 0.022823330515638205,
#  '/uk-residence-card': 0.054945054945054944,
#  '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022': 0.05071851225697379,
#  '/raise-grievance-at-work': 0.02028740490278952,
#  '/student-finance/new-fulltime-students': 0.011834319526627219,
#  '/calculate-agricultural-holiday-entitlement': 0.009298393913778529,
#  '/vaccine-damage-payment': 0.018596787827557058,
#  '/work-reference': 0.05156382079459002,
#  '/guidance/criminal-record-checks-for-childminders-and-childcare-workers': 0.018596787827557058,
#  ...}

# %% [markdown]
# ### Overall rank from multiple ranked items
#
# Choose a final ranking method. In this example, `shortest_seed0_1`, `shortest_seed0_2`, `g_degree` have been used.

# %%
# create lists in order
sessions_list = [(index, element[0]) for index, element in enumerate(sessions)]
shortest_seed0_1_list = [
    (index, element) for index, element in enumerate(shortest_seed0_1)
]
shortest_seed0_2_list = [
    (index, element) for index, element in enumerate(shortest_seed0_2)
]
combined_paths_list = [(index, element) for index, element in enumerate(combined_paths)]
# g_between_list = [(index, element) for index, element in enumerate(g_between)]
g_degree_list = [(index, element) for index, element in enumerate(g_degree)]
# g_closeness_list = [(index, element) for index, element in enumerate(g_closeness)]

# %%
shortest_seed0_1_list
# Out:
# [(0, '/browse/working/finding-job'),
#  (1, '/government/organisations/hm-revenue-customs/about/recruitment'),
#  (2, '/check-uk-visa'),
#  (3, '/guidance/dbs-check-requests-guidance-for-employers'),
#  (4, '/jobseekers-allowance/eligibility'),
#  (5, '/topic/defence-armed-forces/military-recruitment-training-operations'),
#  (6, '/guidance/immigration-rules'),
#  (7, '/work-reference'),
#  (8, '/find-internship'),
#  (9, '/national-insurance'),
#  (10, '/employee-immigration-employment-status'),
#  (11, '/jobseekers-allowance/report-a-change-of-circumstances'),
#  (12, '/intracompany-transfer-worker-visa'),
#  (13,
#   '/government/publications/skilled-worker-visa-eligible-occupations/skilled-worker-visa-eligible-occupations-and-codes'),
#  (14, '/uk-visa-sponsorship-employers'),
#  (15, '/volunteering/when-you-can-volunteer'),
#  (16, '/volunteering'),
#  (17, '/contact-jobcentre-plus'),
#  (18, '/death-spouse-benefits-tax-pension/pensions'),
#  (19,
#   '/government/collections/sponsorship-information-for-employers-and-educators'),
#  (20, '/employment-status'),
#  (21,
#   '/government/publications/help-and-support-for-older-workers/help-and-support-for-older-workers'),
#  (22, '/become-apprentice'),
#  (23,
#   '/guidance/claim-a-grant-through-the-coronavirus-covid-19-self-employment-income-support-scheme'),
#  (24, '/student-finance/who-qualifies'),
#  (25, '/topic/work-careers/government-graduate-schemes'),
#  (26, '/moving-from-benefits-to-work/support-when-you-start-working'),
#  (27, '/criminal-record-check-documents'),
#  (28, '/search/services'),
#  (29, '/apply-universal-credit'),
#  (30, '/government/publications/register-of-licensed-sponsors-workers'),
#  (31, '/national-insurance/national-insurance-classes'),
#  (32, '/log-in-register-hmrc-online-services'),
#  (33, '/legal-right-work-uk'),
#  (34, '/what-different-qualification-levels-mean'),
#  (35, '/jobseekers-allowance'),
#  (36,
#   '/government/publications/statutory-sick-pay-employees-statement-of-sickness-sc2'),
#  (37,
#   '/government/publications/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens/understanding-your-right-to-work-in-the-uk-eu-eea-and-swiss-citizens-accessible-version'),
#  (38,
#   '/government/publications/skilled-worker-visa-shortage-occupations/skilled-worker-visa-shortage-occupations'),
#  (39, '/work-health-programme'),
#  (40, '/moving-from-benefits-to-work'),
#  (41,
#   '/guidance/apply-for-communication-support-at-a-job-interview-if-you-have-a-disability-or-health-condition-access-to-work'),
#  (42, '/universal-credit'),
#  (43, '/exchange-foreign-driving-licence'),
#  (44, '/sign-in-universal-credit'),
#  (45, '/register-to-vote'),
#  (46, '/browse/benefits/looking-for-work'),
#  (47, '/browse/working/armed-forces'),
#  (48, '/contact-jobcentre-plus/new-benefit-claims'),
#  (49, '/guidance/red-amber-and-green-list-rules-for-entering-england'),
#  (50, '/browse/working/redundancies-dismissals'),
#  (51, '/manage-your-tax-credits'),
#  (52, '/check-job-applicant-right-to-work'),
#  (53, '/browse/working/time-off'),
#  (54, '/browse/working/rights-trade-unions'),
#  (55, '/tax-credits-calculator'),
#  (56, '/advertise-job'),
#  (57, '/job-offers-your-rights'),
#  (58, '/become-apprentice/apply-for-an-apprenticeship'),
#  (59, '/browse/working'),
#  (60, '/guidance/free-courses-for-jobs'),
#  (61, '/view-right-to-work'),
#  (62, '/get-information-about-a-company'),
#  (63, '/tell-employer-or-college-about-criminal-record/driving-convictions'),
#  (64, '/government/organisations'),
#  (65, '/browse/education/find-course'),
#  (66, '/access-to-work'),
#  (67, '/browse/working/contract-working-hours'),
#  (68, '/child-employment/paying'),
#  (69,
#   '/government/publications/universal-credit-if-you-have-a-disability-or-health-condition-quick-guide/universal-credit-if-you-have-a-disability-or-health-condition'),
#  (70, '/apply-apprenticeship'),
#  (71, '/report-problem-criminal-record-certificate'),
#  (72, '/tell-employer-or-college-about-criminal-record'),
#  (73, '/benefits-calculators'),
#  (74, '/access-to-work/after-you-have-applied'),
#  (75, '/jobcentre-plus-help-for-recruiters'),
#  (76, '/seasonal-worker-visa'),
#  (77, '/government/publications/skilled-worker-visa-shortage-occupations'),
#  (78, '/browse/employing-people/trade-unions'),
#  (79, '/topic/further-education-skills/apprenticeships'),
#  (80, '/browse/working/tax-minimum-wage'),
#  (81, '/pip/when-your-pip-claim-is-reviewed'),
#  (82, '/government/organisations/department-for-work-pensions/about'),
#  (83, '/help-with-childcare-costs'),
#  (84,
#   '/guidance/immigration-rules/immigration-rules-appendix-shortage-occupation-list'),
#  (85,
#   '/government/organisations/department-for-work-pensions/about/recruitment'),
#  (86, '/dbs-check-applicant-criminal-record'),
#  (87, '/get-copy-military-service-records'),
#  (88, '/career-skills-and-training'),
#  (89,
#   '/government/collections/plan-for-jobs-skills-employment-and-support-programmes-for-jobseekers'),
#  (90, '/settled-status-eu-citizens-families/apply-settled-status-for-child'),
#  (91, '/skilled-worker-visa/documents-you-must-provide'),
#  (92, '/browse/visas-immigration/work-visas'),
#  (93, '/skilled-worker-visa/knowledge-of-english'),
#  (94,
#   '/government/publications/standard-and-enhanced-dbs-check-privacy-policy/standard-and-enhanced-dbs-check-privacy-policy'),
#  (95, '/improve-english-maths-it-skills'),
#  (96, '/employers-checks-job-applicants'),
#  (97, '/find-a-job'),
#  (98, '/dbs-update-service'),
#  (99, '/government/organisations/disclosure-and-barring-service'),
#  (100, '/government/get-involved/take-part/volunteer'),
#  (101, '/british-citizenship'),
#  (102, '/criminal-record-checks-apply-role'),
#  (103,
#   '/guidance/covid-19-coronavirus-restrictions-what-you-can-and-cannot-do'),
#  (104, '/looking-for-work-if-disabled'),
#  (105, '/employment-rights-for-interns'),
#  (106, '/tell-employer-or-college-about-criminal-record/prison-sentences'),
#  (107, '/find-traineeship'),
#  (108, '/contact-ukvi-inside-outside-uk'),
#  (109, '/jobsearch-rights'),
#  (110, '/pip/eligibility'),
#  (111, '/contact-the-dvla'),
#  (112, '/browse/working/workplace-personal-pensions'),
#  (113, '/government/organisations/home-office'),
#  (114, '/coronavirus/worker-support'),
#  (115, '/contact-jobcentre-plus/change-cancel-appointment'),
#  (116, '/pension-types'),
#  (117, '/browse/childcare-parenting/pregnancy-birth'),
#  (118, '/budgeting-help-benefits/other-help-you-can-get'),
#  (119, '/education/apprenticeships-traineeships-and-internships'),
#  (120,
#   '/government/publications/new-guidance-on-the-rehabilitation-of-offenders-act-1974'),
#  (121, '/plan-retirement-income/private-pensions'),
#  (122, '/workplace-pensions/what-you-your-employer-and-the-government-pay'),
#  (123, '/get-a-passport-urgently'),
#  (124, '/tell-hmrc-change-address'),
#  (125, '/apply-online-to-replace-a-driving-licence'),
#  (126, '/vehicle-exempt-from-vehicle-tax'),
#  (127, '/standard-visitor-visa/documents-you-will-need'),
#  (128, '/discrimination-your-rights/discrimination-at-work'),
#  (129, '/calculate-statutory-sick-pay'),
#  (130, '/bereavement-support-payment'),
#  (131, '/browse/visas-immigration/student-visas'),
#  (132, '/browse/education/universities-higher-education'),
#  (133, '/dvlaforms'),
#  (134, '/budgeting-help-benefits/how-to-apply'),
#  (135, '/overtime-your-rights/compulsory-overtime'),
#  (136, '/biometric-residence-permits/report-problem'),
#  (137, '/apply-for-disabled-bus-pass'),
#  (138,
#   '/government/collections/illegal-working-penalties-codes-of-practice-for-employers'),
#  (139, '/standard-visitor-visa'),
#  (140, '/government/publications/the-official-hmrc-app'),
#  (141,
#   '/government/publications/personal-information-use-in-borders-immigration-and-citizenship/borders-immigration-and-citizenship-privacy-information-notice'),
#  (142, '/after-a-death/organisations-you-need-to-contact-and-tell-us-once'),
#  (143, '/guidance/new-style-jobseekers-allowance'),
#  (144, '/volunteering/volunteers-rights'),
#  (145, '/test-and-trace-support-payment'),
#  (146, '/check-mot-history'),
#  (147, '/guidance/nhs-covid-pass'),
#  (148, '/coronavirus/business-support'),
#  (149, '/mandatory-reconsideration'),
#  (150, '/rest-breaks-work/disputes'),
#  (151, '/national-minimum-wage-rates'),
#  (152, '/support-visit-benefit-claim'),
#  (153, '/british-passport-eligibility'),
#  (154, '/check-mot-status'),
#  (155, '/handing-in-your-notice/gardening-leave'),
#  (156,
#   '/education/further-and-higher-education-skills-and-vocational-training'),
#  (157, '/dla-disability-living-allowance-benefit'),
#  (158, '/early-retirement-pension/benefits'),
#  (159, '/government/publications/basic-check-guidance-and-policies'),
#  (160, '/pip/how-to-claim'),
#  (161, '/child-benefit-tax-calculator'),
#  (162, '/guidance/statutory-sick-pay-employee-fitness-to-work'),
#  (163, '/child-benefit/how-to-claim'),
#  (164, '/topic/crime-policing/criminal-record-disclosure'),
#  (165, '/uk-visa-sponsorship-employers/types-of-licence'),
#  (166,
#   '/government/publications/covid-19-free-of-charge-dbs-applications-and-fast-track-barred-list-check-service'),
#  (167, '/constant-attendance-allowance'),
#  (168,
#   '/government/publications/dbs-application-forms-guide-for-applicants/dbs-application-form-guide-for-applicants'),
#  (169, '/understanding-your-pay/working-out-your-pay'),
#  (170, '/guidance/right-to-work-checks-employing-eu-eea-and-swiss-citizens'),
#  (171, '/sponsor-management-system'),
#  (172, '/paternity-pay-leave/eligibility'),
#  (173, '/uk-visa-sponsorship-employers/sponsorship-management-roles'),
#  (174, '/employers-sick-pay'),
#  (175, '/government/publications/the-basic-state-pension'),
#  (176, '/government/publications/dbs-workforce-guidance'),
#  (177, '/marriage-allowance'),
#  (178, '/guidance/eu-settlement-scheme-how-we-use-your-personal-information'),
#  (179, '/workplace-pensions/changing-jobs-and-taking-leave'),
#  (180, '/state-pension-age'),
#  (181, '/council-housing'),
#  (182, '/bank-holidays'),
#  (183, '/medical-suspensions-from-work'),
#  (184, '/child-employment/local-council-rules-for-child-employment-permits'),
#  (185, '/standard-visitor-visa/what-you-can-do-in-the-uk'),
#  (186, '/budgeting-help-benefits/after-you-apply'),
#  (187, '/government/collections/new-enterprise-allowance-campaign'),
#  (188, '/employment-support-allowance/how-to-claim'),
#  (189, '/employ-someone'),
#  (190, '/browse/births-deaths-marriages/register-offices'),
#  (191, '/tax-come-to-uk'),
#  (192, '/minimum-wage-different-types-work'),
#  (193,
#   '/guidance/claim-for-wages-through-the-coronavirus-job-retention-scheme'),
#  (194, '/incapacity-benefit'),
#  (195, '/raise-grievance-at-work'),
#  (196, '/government/publications/find-a-free-level-3-qualification'),
#  (197, '/tax-right-retire-abroad-return-to-uk'),
#  (198, '/new-state-pension/how-its-calculated'),
#  (199, '/tell-employer-or-college-about-criminal-record/cautions'),
#  (200, '/browse/benefits/families'),
#  (201, '/guidance/using-your-uk-visas-and-immigration-account'),
#  (202, '/passport-fees'),
#  (203,
#   '/guidance/claim-a-grant-through-the-self-employment-income-support-scheme'),
#  (204, '/tax-on-your-private-pension/lifetime-allowance'),
#  (205, '/skilled-worker-visa/your-partner-and-children'),
#  (206, '/jobcentre-plus-help-for-recruiters/work-experience-apprenticeships'),
#  (207, '/paternity-pay-leave/how-to-claim'),
#  (208, '/further-education-courses/financial-help'),
#  (209, '/1619-bursary-fund/how-to-claim'),
#  (210, '/biometric-residence-permits/collect'),
#  (211, '/welfare/jobseekers-allowance'),
#  (212, '/employment-support-allowance/change-of-circumstances'),
#  (213, '/short-term-benefit-advance'),
#  (214, '/guidance/pensions-and-compensation-for-veterans'),
#  (215, '/browse/employing-people/dismissals-redundancies'),
#  (216,
#   '/government/publications/acceptable-right-to-work-documents-an-employers-guide'),
#  (217,
#   '/guidance/work-out-your-turnover-so-you-can-claim-the-fifth-seiss-grant'),
#  (218, '/training-study-work-your-rights'),
#  (219, '/guidance/digital-and-online-services'),
#  (220, '/find-pension-centre'),
#  (221, '/tell-hmrc-change-of-details'),
#  (222, '/holiday-entitlement-rights/calculate-leave-entitlement'),
#  (223, '/employer-relocation-your-rights'),
#  (224, '/uk-family-visa'),
#  (225, '/government/organisations/education-and-skills-funding-agency'),
#  (226, '/childcare-grant'),
#  (227, '/driving-medical-conditions'),
#  (228, '/intensive-personalised-employment-support'),
#  (229, '/self-employed-records'),
#  (230, '/advanced-learner-loan'),
#  (231, '/plan-for-retirement'),
#  (232, '/topic/personal-tax/self-assessment'),
#  (233, '/health-care-worker-visa'),
#  (234, '/government/publications/find-a-skills-bootcamp'),
#  (235, '/disability-living-allowance-children'),
#  (236, '/apply-blue-badge'),
#  (237, '/skilled-worker-visa/if-you-work-in-healthcare-or-education'),
#  (238,
#   '/what-different-qualification-levels-mean/list-of-qualification-levels'),
#  (239, '/moving-from-benefits-to-work/job-search-programmes'),
#  (240, '/further-education-courses/find-a-course'),
#  (241, '/business-support-helpline'),
#  (242, '/lost-national-insurance-number'),
#  (243, '/when-mental-health-condition-becomes-disability'),
#  (244, '/check-income-tax-current-year'),
#  (245, '/government/organisations/pension-service'),
#  (246,
#   '/government/publications/new-enterprise-allowance-phase-2-provider-guidance/new-enterprise-allowance-phase-2-provider-guidance'),
#  (247, '/cold-weather-payment'),
#  (248, '/government/publications/higher-and-degree-apprenticeships'),
#  (249,
#   '/government/publications/disclosure-application-process-for-volunteers/disclosure-application-process-for-volunteers'),
#  (250, '/tax-codes'),
#  (251, '/paye-forms-p45-p60-p11d'),
#  (252, '/government/organisations/department-of-social-security'),
#  (253, '/understanding-your-pay'),
#  (254, '/check-income-tax-current-year/sign-in/prove-identity'),
#  (255, '/government/organisations/skills-funding-agency'),
#  (256, '/workplace-bullying-and-harassment'),
#  (257, '/employment-support-allowance'),
#  (258, '/check-immigration-status'),
#  (259, '/types-of-british-nationality/british-citizenship'),
#  (260, '/pip'),
#  (261,
#   '/government/publications/dbs-update-service-employer-guide/dbs-update-service-employer-guide'),
#  (262, '/carers-allowance/effect-on-other-benefits'),
#  (263, '/guidance/indefinite-leave-to-remain-in-the-uk'),
#  (264, '/government/organisations/hm-revenue-customs/contact'),
#  (265, '/universal-credit/what-youll-get'),
#  (266, '/browse/abroad/passports'),
#  (267, '/your-rights-if-your-employer-is-insolvent'),
#  (268, '/holiday-entitlement-rights/booking-time-off-'),
#  (269, '/prove-right-to-rent'),
#  (270, '/browse/citizenship/government'),
#  (271, '/contracted-out/old-state-pension'),
#  (272, '/find-postgraduate-teacher-training-courses'),
#  (273, '/maternity-pay-leave/pay'),
#  (274,
#   '/workplace-pensions/if-you-want-to-leave-your-workplace-pension-scheme'),
#  (275, '/parental-leave'),
#  (276, '/browse/benefits/disability'),
#  (277, '/moving-from-benefits-to-work/help-for-parents-and-carers'),
#  (278, '/browse/education/school-life'),
#  (279, '/personal-tax-account/sign-in/create-account'),
#  (280, '/apply-council-tax-reduction'),
#  (281, '/dismissal/reasons-you-can-be-dismissed'),
#  (282, '/browse/tax/income-tax'),
#  (283, '/severe-disablement-allowance'),
#  (284, '/report-cash-in-hand-pay'),
#  (285, '/probate-estate'),
#  (286, '/agency-workers-your-rights'),
#  (287,
#   '/government/publications/find-a-free-level-3-qualification/list-of-free-level-3-qualifications-available-to-eligible-adults'),
#  (288, '/employment-support-allowance/what-youll-get'),
#  (289, '/entering-staying-uk/foreign-nationals-working-in-uk'),
#  (290, '/financial-help-disabled/disability-and-sickness-benefits'),
#  (291, '/call-charges'),
#  (292,
#   '/update-uk-visas-immigration-account-details/update-your-ukvi-account'),
#  (293, '/get-copy-military-service-records/apply-for-your-own-records'),
#  (294, '/how-to-have-your-benefits-paid'),
#  (295, '/universal-credit/contact-universal-credit'),
#  (296, '/government/collections/helping-young-people-into-work'),
#  (297, '/working-tax-credit'),
#  (298, '/moving-from-benefits-to-work/starting-your-own-business'),
#  (299,
#   '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-dbs-check-applications-from-3-september-2018'),
#  (300, '/estimate-income-tax'),
#  (301, '/health-care-worker-visa/your-job'),
#  (302, '/maternity-allowance/eligibility'),
#  (303, '/agency-workers-your-rights/your-rights-as-a-temporary-agency-worker'),
#  (304, '/redundancy-your-rights/redundancy-pay'),
#  (305, '/provide-journey-contact-details-before-travel-uk'),
#  (306,
#   '/maximum-weekly-working-hours/weekly-maximum-working-hours-and-opting-out'),
#  (307, '/log-in-file-self-assessment-tax-return/sign-in/prove-identity'),
#  (308, '/skilled-worker-visa'),
#  (309, '/government/collections/traineeships--2'),
#  (310, '/skilled-worker-visa/apply-from-outside-the-uk'),
#  (311, '/carers-allowance/further-information'),
#  (312, '/calculate-agricultural-holiday-entitlement'),
#  (313,
#   '/guidance/covid-19-how-dbs-is-supporting-the-fight-against-coronavirus'),
#  (314, '/child-employment'),
#  (315, '/contracted-out/check-if-you-were-contracted-out'),
#  (316, '/guidance/visa-decision-waiting-times-applications-inside-the-uk'),
#  (317, '/order-copy-birth-death-marriage-certificate'),
#  (318, '/sure-start-maternity-grant/how-to-claim'),
#  (319,
#   '/guidance/criminal-record-checks-for-childminders-and-childcare-workers'),
#  (320, '/income-tax'),
#  (321, '/attendance-allowance'),
#  (322, '/student-jobs-paying-tax'),
#  (323, '/apply-standard-visitor-visa'),
#  (324, '/british-national-overseas-bno-visa'),
#  (325, '/overseas-domestic-worker-visa'),
#  (326, '/government/topical-events/plan-for-jobs'),
#  (327, '/guidance/brexit-guidance-for-individuals-and-families'),
#  (328, '/government/publications/dbs-check-eligible-positions-guidance'),
#  (329, '/set-up-sole-trader'),
#  (330, '/state-pension/circumstances-change'),
#  (331, '/housing-and-universal-credit'),
#  (332, '/education'),
#  (333, '/guidance/tax-professional-development-programme'),
#  (334, '/government/organisations/disclosure-and-barring-service/about'),
#  (335, '/uk-visa-sponsorship-employers/job-suitability'),
#  (336, '/benefit-overpayments/when-repayments-have-to-be-made'),
#  (337, '/pension-credit'),
#  (338, '/browse/employing-people/contracts'),
#  (339, '/browse/tax/dealing-with-hmrc'),
#  (340, '/log-in-hmrc-excise-import-export'),
#  (341, '/browse/driving/vehicle-tax-mot-insurance'),
#  (342, '/book-driving-test'),
#  (343, '/tips-at-work'),
#  (344, '/view-prove-immigration-status'),
#  (345, '/order-coronavirus-rapid-lateral-flow-tests'),
#  (346, '/early-retirement-pension/personal-and-workplace-pensions'),
#  (347, '/business-coronavirus-support-finder'),
#  (348, '/eusettledstatus'),
#  (349,
#   '/government/publications/criminal-records-checks-for-overseas-applicants/guidance-on-the-application-process-for-criminal-records-checks-overseas'),
#  (350, '/am-i-getting-minimum-wage'),
#  (351, '/find-dbs-umbrella-body'),
#  (352, '/mature-student-university-funding'),
#  (353, '/government/publications/qualifications-in-new-funded-offers'),
#  (354, '/child-employment/restrictions-on-child-employment'),
#  (355, '/tax-on-pension/how-your-tax-is-paid'),
#  (356, '/guidance/brexit-guidance-for-businesses'),
#  (357, '/youth-mobility'),
#  (358, '/change-driving-test'),
#  (359, '/guidance/apply-for-a-kickstart-scheme-grant'),
#  (360, '/employing-an-apprentice'),
#  (361, '/government/organisations/hm-revenue-customs/contact/self-assessment'),
#  (362, '/government/organisations/companies-house'),
#  (363,
#   '/government/organisations/department-for-work-pensions/about/complaints-procedure'),
#  (364, '/government/publications/child-benefit-claim-form-ch2'),
#  (365, '/jobseekers-allowance/apply-new-style-jsa'),
#  (366, '/employment-support-allowance/working-while-you-claim'),
#  (367,
#   '/government/publications/employment-and-support-allowance-permitted-work-form'),
#  (368,
#   '/government/publications/disclosure-application-process-for-volunteers'),
#  (369, '/national-insurance/how-much-you-pay'),
#  (370, '/find-out-dbs-check'),
#  (371,
#   '/what-different-qualification-levels-mean/compare-different-qualification-levels'),
#  (372, '/disabled-facilities-grants'),
#  (373, '/employers-sick-pay/eligibility-and-form-ssp1'),
#  (374, '/self-assessment-tax-returns'),
#  (375, '/work/pensions-and-ageing-society'),
#  (376, '/limited-company-formation'),
#  (377, '/access-to-work/what-youll-get'),
#  (378, '/topic/immigration-operational-guidance'),
#  (379, '/when-someone-dies'),
#  (380, '/apply-online-for-student-finance'),
#  (381, '/holiday-entitlement-rights/workers-furlough-coronavirus'),
#  (382, '/claim-benefits-abroad/jobseekers-allowance'),
#  (383, '/dla-disability-living-allowance-benefit/dla-rates'),
#  (384,
#   '/government/publications/dbs-certificate-reprint-guide/dbs-certificate-reprint-guide'),
#  (385, '/working-abroad'),
#  (386, '/your-employment-contract-how-it-can-be-changed/making-changes'),
#  (387, '/apply-marriage-allowance'),
#  (388, '/ukvcas'),
#  (389,
#   '/settled-status-eu-citizens-families/if-you-have-permanent-residence-or-indefinite-leave-to-remain'),
#  (390, '/parents-learning-allowance'),
#  (391, '/browse/driving/learning-to-drive'),
#  (392, '/personal-pensions-your-rights'),
#  (393, '/settled-status-eu-citizens-families'),
#  (394, '/employment-contracts-and-conditions/contract-terms'),
#  (395, '/biometric-residence-permits/lost-stolen-damaged'),
#  (396, '/browse/disabilities/benefits'),
#  (397, '/apply-home-equipment-for-disabled'),
#  (398, '/browse/childcare-parenting/financial-help-children'),
#  (399, '/guidance/universal-credit-and-students'),
#  (400, '/how-tax-credits-affect-other-benefits'),
#  (401,
#   '/jobseekers-allowance/if-youre-getting-contribution-or-income-based-jsa'),
#  (402, '/short-term-benefit-advance/how-to-apply'),
#  (403, '/government/publications/apprenticeship-funding-bands'),
#  (404,
#   '/guidance/temporary-jobcentres-during-the-coronavirus-covid-19-pandemic'),
#  (405, '/holiday-entitlement-rights/taking-holiday-before-leaving-a-job'),
#  (406, '/topic/business-tax/paye'),
#  (407,
#   '/government/publications/access-to-work-factsheet/access-to-work-factsheet-for-customers'),
#  (408, '/time-off-for-dependants/taking-time-off'),
#  (409, '/get-proof-employment-history'),
#  (410, '/search/news-and-communications'),
#  (411, '/fixed-term-contracts'),
#  (412, '/looking-for-work-if-disabled/applying-for-a-job'),
#  (413,
#   '/tell-employer-or-college-about-criminal-record/fines-and-compensation'),
#  (414, '/financial-help-disabled/vat-relief'),
#  (415, '/claim-national-insurance-refund'),
#  (416, '/renewing-your-tax-credits-claim'),
#  (417, '/overtime-your-rights'),
#  (418, '/browse/business/finance-support'),
#  (419, '/financial-help-disabled'),
#  (420, '/income-support/income-support-rates'),
#  (421, '/register-for-self-assessment'),
#  (422, '/national-insurance/change-of-circumstance'),
#  (423, '/sold-bought-vehicle'),
#  (424,
#   '/government/publications/apprenticeship-recruitment-employers-and-training-organisations'),
#  (425, '/income-support/report-a-change-of-circumstances'),
#  (426, '/find-pension-contact-details'),
#  (427, '/financial-help-disabled/vehicles-and-transport'),
#  (428, '/chwilio-am-swydd'),
#  (429, '/start-up-visa'),
#  (430, '/carers-credit/eligibility'),
#  (431, '/child-tax-credit/how-to-claim'),
#  (432,
#   '/guidance/government-legal-service-gls-legal-trainee-scheme-how-to-apply'),
#  (433, '/check-british-citizenship'),
#  (434, '/temporary-worker-charity-worker-visa'),
#  (435, '/jobcentre-plus-help-for-recruiters/work-trials'),
#  (436, '/disciplinary-procedures-and-action-at-work'),
#  (437, '/workplace-pensions/joining-a-workplace-pension'),
#  (438, '/government/organisations/department-of-health-and-social-care'),
#  (439, '/government/collections/eu-settlement-scheme-applicant-information'),
#  (440, '/new-state-pension/how-to-claim'),
#  (441, '/early-retirement-pension'),
#  (442, '/budgeting-help-benefits/what-youll-get'),
#  (443, '/tax-free-childcare'),
#  (444,
#   '/settled-status-eu-citizens-families/what-settled-and-presettled-status-means'),
#  (445, '/income-tax-rates'),
#  (446,
#   '/guidance/check-if-you-could-be-covered-by-the-coronavirus-job-retention-scheme'),
#  (447, '/advanced-learner-loan/how-to-apply'),
#  (448,
#   '/tell-employer-or-college-about-criminal-record/check-your-conviction-caution'),
#  (449, '/right-to-reside'),
#  (450, '/claim-tax-credits'),
#  (451, '/student-visa/extend-your-visa'),
#  (452, '/government/collections/statutory-sick-pay-and-leave'),
#  (453, '/further-education-courses/if-youre-16-or-17'),
#  (454, '/topic/personal-tax/income-tax'),
#  (455, '/sunday-working'),
#  (456, '/find-an-immigration-adviser'),
#  (457, '/carers-allowance-unit'),
#  (458, '/get-coronavirus-test'),
#  (459, '/change-circumstances-visa-brp'),
#  (460, '/copy-of-police-records'),
#  (461, '/bereavement-support-payment/how-to-claim'),
#  (462, '/browse/abroad/travel-abroad'),
#  (463, '/employee-rights-when-on-leave'),
#  (464, '/maximum-weekly-working-hours/calculating-your-working-hours'),
#  (465, '/renew-adult-passport/renew'),
#  (466, '/claim-redundancy'),
#  (467,
#   '/government/publications/access-to-work-guide-for-employers/access-to-work-factsheet-for-employers'),
#  (468, '/winter-fuel-payment'),
#  (469, '/national-minimum-wage/who-gets-the-minimum-wage'),
#  (470,
#   '/government/publications/maternity-benefits-technical-guidance/maternity-benefits-technical-guidance'),
#  (471, '/help'),
#  (472, '/government/publications/right-to-work-checks-employers-guide'),
#  (473, '/guidance/new-immigration-system-what-you-need-to-know'),
#  (474, '/search/research-and-statistics'),
#  (475, '/carers-allowance-report-change'),
#  (476, '/get-a-passport-urgently/online-premium-service'),
#  (477, '/employment-contracts-and-conditions'),
#  (478, '/state-pension-through-partner'),
#  (479, '/biometric-residence-permits/replace-expired-brp'),
#  (480, '/child-trust-funds'),
#  (481, '/carers-credit/how-to-claim'),
#  (482, '/income-tax/taxfree-and-taxable-state-benefits'),
#  (483, '/statutory-sick-pay/how-to-claim'),
#  (484, '/employing-staff'),
#  (485, '/working-tax-credit/what-youll-get'),
#  (486, '/government/publications/paye-starter-checklist'),
#  (487, '/browse/disabilities/rights'),
#  (488, '/national-insurance-rates-letters/category-letters'),
#  (489, '/check-state-pension'),
#  (490, '/guidance/dbs-online-account-guidance'),
#  (491, '/child-benefit-move-to-uk'),
#  (492, '/1619-bursary-fund'),
#  (493, '/view-driving-licence'),
#  (494, '/tax-national-insurance-after-state-pension-age'),
#  (495, '/state-pension'),
#  (496, '/guidance/national-minimum-wage-work-experience-and-internships'),
#  (497, '/paye-forms-p45-p60-p11d/p60'),
#  (498, '/employer-preventing-discrimination'),
#  (499, '/browse/citizenship/citizenship'),
#  (500, '/employment-support-allowance/eligibility'),
#  (501, '/browse/benefits/unable-to-work'),
#  (502, '/government/publications/the-national-minimum-wage-in-2021'),
#  (503, '/access-to-work/renew'),
#  (504, '/carers-allowance'),
#  (505, '/get-paye-forms-p45-p60'),
#  (506, '/browse/visas-immigration/family-visas'),
#  (507, '/vehicles-can-drive'),
#  (508, '/definition-of-disability-under-equality-act-2010'),
#  (509, '/government/organisations/uk-visas-and-immigration'),
#  (510, '/guidance/universal-credit-advances'),
#  (511, '/dual-citizenship'),
#  (512, '/child-benefit/eligibility'),
#  (513,
#   '/settled-status-eu-citizens-families/switch-from-presettled-status-to-settled-status'),
#  (514,
#   '/government/publications/your-new-state-pension-explained/your-state-pension-explained'),
#  (515, '/redundancy-payments-helpline'),
#  (516, '/transferring-your-pension'),
#  (517, '/student-visa'),
#  (518, '/contact-jobcentre-plus/existing-benefit-claims'),
#  (519, '/browse/visas-immigration/tourist-short-stay-visas'),
#  (520, '/paternity-pay-leave'),
#  (521, '/browse/citizenship/charities-honours'),
#  (522, '/browse/visas-immigration/commonwealth-british-nationals-overseas'),
#  (523, '/set-up-business'),
#  (524, '/biometric-residence-permits/personal-data'),
#  (525, '/universal-credit/eligibility'),
#  (526, '/minimum-wage-different-types-work/paid-by-the-hour'),
#  (527,
#   '/government/publications/eu-settlement-scheme-application-processing-times/eu-settlement-scheme-pilot-current-expected-processing-times-for-applications'),
#  (528, '/how-to-claim-new-style-jsa'),
#  (529, '/government/organisations/foreign-commonwealth-development-office'),
#  (530, '/child-benefit-16-19'),
#  (531, '/deferring-state-pension/how-to-claim-a-deferred-state-pension'),
#  (532, '/browse/benefits/bereavement'),
#  (533, '/self-employment-and-universal-credit'),
#  (534, '/apply-to-come-to-the-uk/prepare-your-application'),
#  (535,
#   '/contract-types-and-employer-responsibilities/fulltime-and-parttime-contracts'),
#  (536, '/uk-residence-card'),
#  (537, '/appeal-benefit-decision'),
#  (538, '/bereavement-support-payment/what-youll-get'),
#  (539,
#   '/tax-national-insurance-after-state-pension-age/stopping-paying-national-insurance'),
#  (540, '/handing-in-your-notice/payment-during-your-notice-period'),
#  (541, '/guidance/traineeship-information-for-trainees'),
#  (542, '/handing-in-your-notice/giving-notice'),
#  (543, '/sign-in-childcare-account'),
#  (544, '/apply-sponsor-licence'),
#  (545, '/your-employment-contract-how-it-can-be-changed'),
#  (546, '/uk-border-control/before-you-leave-for-the-uk'),
#  (547,
#   '/government/publications/skilled-worker-visa-shortage-occupations-for-health-and-education'),
#  (548, '/guidance/prove-your-right-to-work-eu-eea-and-swiss-citizens'),
#  (549, '/reduced-national-insurance-married-women'),
#  (550, '/guidance/manage-apprenticeship-funds'),
#  (551, '/personal-pensions-your-rights/how-you-can-take-pension'),
#  (552,
#   '/dbs-check-applicant-criminal-record/get-a-basic-dbs-check-for-an-employee'),
#  (553, '/government/publications/right-to-work-checklist'),
#  (554,
#   '/guidance/eu-settlement-scheme-uk-tax-and-benefits-records-automated-check'),
#  (555, '/browse/disabilities/work'),
#  (556, '/topic/benefits-credits/child-benefit'),
#  (557, '/if-you-become-disabled/if-youre-in-employment-and-become-disabled'),
#  (558, '/tax-relief-for-employees'),
#  (559, '/check-income-tax-current-year/sign-in/create-account'),
#  (560, '/additional-state-pension'),
#  (561, '/advanced-learner-loan/what-youll-get'),
#  (562, '/fraud-error-prevention-centres'),
#  (563, '/holiday-entitlement-rights'),
#  (564, '/reduced-earnings-allowance'),
#  (565, '/log-in-register-hmrc-online-services/register'),
#  (566, '/youth-mobility/eligibility'),
#  (567, '/contact-pension-service'),
#  (568, '/disability-premiums'),
#  (569, '/dismissal/unfair-and-constructive-dismissal'),
#  (570,
#   '/government/publications/view-and-prove-your-immigration-status-evisa/your-immigration-status-an-introduction-for-eu-eea-and-swiss-citizens-accessible-version'),
#  (571, '/state-pension-if-you-retire-abroad'),
#  (572, '/apply-first-provisional-driving-licence'),
#  (573, '/government/collections/statutory-pay-forms'),
#  (574, '/discrimination-your-rights'),
#  (575,
#   '/government/publications/criminal-records-checks-for-overseas-applicants/countries-q-z'),
#  (576, '/government/collections/dbs-eligibility-guidance'),
#  (577,
#   '/voluntary-national-insurance-contributions/who-can-pay-voluntary-contributions'),
#  (578, '/advanced-learner-loan/eligibility'),
#  (579, '/statutory-sick-pay/eligibility'),
#  (580, '/income-support'),
#  (581, '/browse/visas-immigration/what-you-need-to-do'),
#  (582, '/state-pension/eligibility'),
#  (583, '/maternity-allowance/what-youll-get'),
#  (584, '/legal-obligations-drivers-riders'),
#  (585,
#   '/government/publications/eu-settlement-scheme-application-processing-times'),
#  (586, '/benefit-overpayments/how-to-make-a-repayment'),
#  (587, '/guidance/incentive-payments-for-hiring-a-new-apprentice'),
#  (588, '/government/publications/dbs-filtering-guidance'),
#  (589, '/national-insurance/help-if-youre-not-working'),
#  (590, '/biometric-residence-permits/replace-visa-brp'),
#  (591, '/government/collections/desg-graduate-scheme'),
#  (592, '/government/organisations/foreign-commonwealth-office'),
#  (593, '/budgeting-help-benefits/eligibility'),
#  (594, '/employment-status/employee'),
#  (595, '/maternity-pay-leave/how-to-claim'),
#  (596, '/browse/driving/driving-licences'),
#  (597,
#   '/government/publications/benefit-and-pension-rates-2021-to-2022/benefit-and-pension-rates-2021-to-2022'),
#  (598, '/guidance/working-safely-during-covid-19'),
#  (599, '/guidance/redundancy-help-finding-work-and-claiming-benefits'),
#  (600, '/calculate-your-redundancy-pay'),
#  (601, '/national-minimum-wage/employers-and-the-minimum-wage'),
#  (602, '/welfare/entitlement'),
#  (603, '/new-state-pension/living-and-working-overseas'),
#  (604, '/browse/benefits/low-income'),
#  (605, '/income-tax/how-you-pay-income-tax'),
#  (606, '/redundancy-your-rights/consultation'),
#  (607, '/jobcentre-plus-help-for-recruiters/recruitment-advice-and-support'),
#  (608, '/personal-pensions-your-rights/choosing-personal-pension'),
#  (609, '/additional-state-pension/inheriting'),
#  (610, '/keeping-your-pay-tax-records'),
#  (611, '/statutory-sick-pay'),
#  (612, '/government/collections/right-to-work-checks-employer-guidance'),
#  (613, '/over-80-pension/how-to-claim'),
#  (614,
#   '/government/organisations/hm-revenue-customs/contact/change-your-personal-details'),
#  (615, '/right-of-abode'),
#  (616, '/night-working-hours'),
#  (617, '/government/organisations/hm-revenue-customs/services-information'),
#  (618, '/learner-support'),
#  (619,
#   '/government/publications/jobseekers-allowance-sanctions-leaflet/jobseekers-allowance-sanctions-how-to-keep-your-benefit-payment'),
#  (620, '/national-insurance-rates-letters'),
#  (621, '/find-coronavirus-support'),
#  (622, '/government/collections/apprenticeship-vacancies'),
#  (623, '/uk-family-visa/partner-spouse'),
#  (624, '/higher-education-courses-find-and-apply'),
#  (625, '/working-for-yourself'),
#  (626, '/skilled-worker-visa/when-you-can-be-paid-less'),
#  (627,
#   '/government/organisations/hm-revenue-customs/contact/online-services-helpdesk'),
#  (628,
#   '/government/publications/find-a-skills-bootcamp/list-of-skills-bootcamps'),
#  (629, '/disabled-students-allowance-dsa'),
#  (630,
#   '/government/publications/view-and-prove-your-immigration-status-evisa'),
#  (631, '/guidance/check-employment-status-for-tax'),
#  (632, '/housing-benefit/how-to-claim'),
#  (633, '/rest-breaks-work'),
#  (634, '/maternity-pay-leave/leave'),
#  (635,
#   '/guidance/claim-for-wage-costs-through-the-coronavirus-job-retention-scheme'),
#  (636, '/browse/visas-immigration/arriving-in-the-uk'),
#  (637, '/graduate-visa/course-you-studied'),
#  (638, '/employing-an-apprentice/pay-and-conditions-for-apprentices'),
#  (639, '/settled-status-eu-citizens-families/what-youll-need-to-apply'),
#  (640,
#   '/guidance/coronavirus-covid-19-advice-for-uk-visa-applicants-and-temporary-uk-residents'),
#  (641, '/national-concessionary-fuel-scheme'),
#  (642, '/update-uk-visas-immigration-account-details'),
#  (643,
#   '/guidance/benefits-and-pensions-for-uk-nationals-in-the-eea-or-switzerland'),
#  (644, '/student-finance'),
#  (645,
#   '/government/publications/find-a-free-level-3-qualification/list-of-colleges-and-training-providers-able-to-offer-free-places-for-level-3-qualifications'),
#  (646,
#   '/government/organisations/hm-revenue-customs/contact/tax-credits-enquiries'),
#  (647, '/adoption-pay-leave'),
#  (648, '/employment-support-allowance/your-esa-claim'),
#  (649, '/national-insurance-credits'),
#  (650, '/government/collections/kickstart-scheme'),
#  (651, '/plan-retirement-income/get-financial-advice'),
#  (652, '/check-vehicle-tax'),
#  (653, '/agricultural-sick-pay'),
#  (654, '/maternity-paternity-pay-leave'),
#  (655, '/government/organisations/department-for-work-pensions'),
#  (656, '/workplace-pensions'),
#  (657, '/standard-visitor-visa/eligibility'),
#  (658, '/student-finance/new-fulltime-students'),
#  (659,
#   '/guidance/if-you-need-to-self-isolate-or-cannot-attend-work-due-to-coronavirus'),
#  (660,
#   '/government/publications/dbs-identity-checking-guidelines/id-checking-guidelines-for-standardenhanced-dbs-check-applications-from-1-july-2021'),
#  (661,
#   '/new-state-pension/your-national-insurance-record-and-your-state-pension'),
#  (662, '/redundancy-your-rights/being-selected-for-redundancy'),
#  (663,
#   '/new-state-pension/youve-been-in-a-workplace-personal-or-stakeholder-pension'),
#  (664, '/apply-national-insurance-number'),
#  (665, '/cold-weather-payment/eligibility'),
#  (666,
#   '/government/organisations/hm-revenue-customs/contact/national-insurance-numbers'),
#  (667, '/voluntary-national-insurance-contributions/deadlines'),
#  (668, '/government/collections/fit-note'),
#  (669,
#   '/government/organisations/hm-revenue-customs/contact/national-insurance-enquiries-for-employees-and-individuals'),
#  (670, '/identitycards'),
#  (671, '/pip/claiming-pip-if-youre-terminally-ill'),
#  (672, '/government/publications/dbs-application-forms-guide-for-applicants'),
#  (673, '/benefit-fraud'),
#  (674,
#   '/log-in-file-self-assessment-tax-return/register-if-youre-self-employed'),
#  (675, '/moving-from-benefits-to-work/help-for-specific-problems'),
#  (676, '/check-tenant-right-to-rent-documents'),
#  (677, '/income-tax/find-out-if-you-need-to-pay-income-tax'),
#  (678, '/government/organisations/hm-revenue-customs/contact/child-benefit'),
#  (679, '/universal-credit/your-responsibilities'),
#  (680, '/get-a-passport-urgently/1-week-fast-track-service'),
#  (681, '/tax-on-your-private-pension/annual-allowance'),
#  (682, '/new-state-pension/what-youll-get'),
#  (683, '/apply-renew-passport'),
#  (684,
#   '/guidance/booking-and-staying-in-a-quarantine-hotel-when-you-arrive-in-england'),
#  (685, '/winter-fuel-payment/how-much-youll-get'),
#  (686, '/penalties-for-employing-illegal-workers'),
#  (687, '/disability-premiums/eligibility'),
#  (688, '/career-breaks'),
#  (689, '/workplace-pensions/managing-your-pension'),
#  (690,
#   '/government/publications/easy-read-get-help-at-work-if-youre-disabled-or-have-a-health-condition-access-to-work'),
#  (691, '/voluntary-national-insurance-contributions/rates'),
#  (692, '/come-uk-married'),
#  (693,
#   '/guidance/travel-to-england-from-another-country-during-coronavirus-covid-19'),
#  (694, '/tax-on-pension'),
#  (695, '/government/publications/access-to-work-guide-for-employers'),
#  (696, '/learn-to-drive-a-car'),
#  (697, '/voluntary-national-insurance-contributions'),
#  (698, '/tell-hmrc-change-of-details/income-changes'),
#  (699, '/browse/visas-immigration/settle-in-the-uk'),
#  (700, '/pension-credit-calculator'),
#  (701, '/redundancy-your-rights'),
#  (702, '/guidance/traineeship-information-for-employers'),
#  (703, '/guidance/new-style-employment-and-support-allowance'),
#  (704, '/paye-forms-p45-p60-p11d/lost-paye-forms'),
#  (705, '/browse/disabilities/equipment'),
#  (706, '/guidance/barring-referrals'),
#  (707, '/council-tax'),
#  (708, '/volunteering/pay-and-expenses'),
#  (709, '/national-minimum-wage-accommodation'),
#  (710, '/paye-forms-p45-p60-p11d/p11d'),
#  (711, '/calculate-your-holiday-entitlement'),
#  (712, '/browse/visas-immigration/asylum'),
#  (713, '/government/publications/maternity-allowance-claim-form'),
#  (714, '/eu-eea'),
#  (715, '/universal-credit/changes-of-circumstances'),
#  (716, '/the-warm-home-discount-scheme/energy-suppliers'),
#  (717, '/check-driving-information'),
#  (718, '/jobseekers-allowance/apply-new-style-jsa/eligibility'),
#  (719, '/passport-advice-line'),
#  (720, '/guidance/rehabilitation-periods'),
#  (721, '/benefit-cap'),
#  (722, '/employing-an-apprentice/get-funding'),
#  (723, '/financial-help-disabled/on-a-low-salary'),
#  (724, '/student-finance-register-login'),
#  (725, '/guidance/eu-settlement-scheme-evidence-of-uk-residence'),
#  (726,
#   '/government/publications/dbs-certificate-disputes-and-fingerprint-consent-forms-and-guidance-af14-af15'),
#  (727,
#   '/government/organisations/hm-revenue-customs/contact/get-help-with-the-self-employment-income-support-scheme'),
#  (728,
#   '/guidance/coronavirus-covid-19-what-to-do-if-youre-employed-and-cannot-work'),
#  (729, '/graduate-visa'),
#  (730, '/pay-and-work-rights'),
#  (731, '/uk-benefits-abroad'),
#  (732, '/government/publications/sure-start-maternity-grant-claim-form'),
#  (733, '/visit-uk-holiday-family-friends'),
#  (734, '/data-protection'),
#  (735, '/government/publications/dbs-continuation-sheet'),
#  (736,
#   '/tell-employer-or-college-about-criminal-record/what-information-you-need-to-give'),
#  (737, '/find-a-visa-application-centre'),
#  (738, '/reasonable-adjustments-for-disabled-workers'),
#  (739,
#   '/government/publications/dbs-list-of-offences-that-will-never-be-filtered-from-a-criminal-record-check'),
#  (740, '/get-state-pension'),
#  (741, '/apply-citizenship-indefinite-leave-to-remain'),
#  (742, '/dismissal/what-to-do-if-youre-dismissed'),
#  (743, '/guidance/search-for-apprenticeship-standards'),
#  (744, '/guidance/travel-abroad-from-england-during-coronavirus-covid-19'),
#  (745, '/apply-for-student-finance'),
#  (746, '/guidance/using-the-eu-exit-id-document-check-app'),
#  (747, '/topic/further-education-skills/vocational-qualifications'),
#  (748, '/topic/personal-tax/national-insurance'),
#  (749, '/government/publications/dbs-filtering-guidance/dbs-filtering-guide'),
#  (750, '/register-for-self-assessment/self-employed'),
#  (751, '/care-to-learn'),
#  (752, '/health-conditions-disability-universal-credit'),
#  (753, '/industrial-injuries-disablement-benefit'),
#  (754, '/financial-help-disabled/television-licence-discount'),
#  (755,
#   '/guidance/find-out-about-money-taken-off-your-universal-credit-payment'),
#  (756, '/browse/employing-people/time-off'),
#  (757, '/overtime-your-rights/parttime-workers'),
#  (758, '/cold-weather-payment/how-to-claim'),
#  (759, '/government/publications/register-of-licensed-sponsors-students'),
#  (760, '/guidance/register-of-apprenticeship-training-providers'),
#  (761, '/browse/education/student-finance'),
#  (762, '/get-copy-military-service-records/apply-for-someone-elses-records'),
#  (763,
#   '/government/publications/skilled-worker-visa-going-rates-for-eligible-occupations/skilled-worker-visa-going-rates-for-eligible-occupation-codes'),
#  (764, '/settled-status-eu-citizens-families/eligibility'),
#  (765, '/get-help-savings-low-income'),
#  (766, '/housing-benefit/other-help-with-housing-costs'),
#  (767,
#   '/government/organisations/department-for-education/services-information'),
#  (768, '/plan-retirement-income'),
#  (769, '/state-pension/inheritance'),
#  (770, '/browse/births-deaths-marriages/child'),
#  (771, '/rights-disabled-person'),
#  (772, '/universal-credit/how-to-claim'),
#  (773, '/part-time-worker-rights'),
#  (774, '/guidance/coronavirus-covid-19-right-to-work-checks'),
#  (775,
#   '/guidance/request-your-personal-information-from-the-department-for-work-and-pensions'),
#  (776, '/government/publications/apprenticeship-technical-funding-guide'),
#  (777, '/pip/change-of-circumstances'),
#  (778, '/terminal-illness-benefits'),
#  (779, '/benefit-cap/benefit-cap-amounts'),
#  (780, '/government/publications/apprenticeship-agreement-template'),
#  (781, '/tell-dvla-changed-address'),
#  (782, '/what-is-the-construction-industry-scheme'),
#  (783, '/skilled-worker-visa/how-much-it-costs'),
#  (784,
#   '/government/publications/dbs-update-service-applicant-guide/dbs-update-service-applicant-guide'),
#  (785, '/uk-border-control'),
#  (786, '/government/publications/dwp-jobcentre-register'),
#  (787,
#   '/government/publications/statutory-sick-pay-employee-not-entitled-form-for-employers'),
#  (788, '/government/publications/dbs-update-service-applicant-guide'),
#  (789, '/handing-in-your-notice'),
#  (790, '/renew-adult-passport'),
#  (791, '/tax-help'),
#  (792, '/housing-and-universal-credit/renting-from-private-landlord'),
#  (793,
#   '/government/publications/personal-information-use-in-borders-immigration-and-citizenship'),
#  (794, '/child-benefit/what-youll-get'),
#  (795, '/tax-on-pension-death-benefits'),
#  (796,
#   '/disciplinary-procedures-and-action-at-work/how-disciplinary-procedures-work'),
#  (797, '/topic/further-education-skills/administration'),
#  (798, '/become-apprentice/pay-and-conditions'),
#  (799, '/find-a-regulated-qualification'),
#  (800, '/payment-exception-service'),
#  (801, '/fixed-term-contracts/employees-rights'),
#  (802, '/entering-staying-uk'),
#  (803, '/guidance/basic-dbs-checks-guidance'),
#  (804, '/deferring-state-pension/what-you-get'),
#  (805, '/redundancy-your-rights/notice-periods'),
#  (806, '/view-right-to-rent'),
#  (807, '/windrush-prove-your-right-to-be-in-the-uk'),
#  (808, '/maximum-weekly-working-hours'),
#  (809, '/access-to-work/eligibility'),
#  (810, '/courses-qualifications'),
#  (811, '/employment-status/worker'),
#  (812, '/further-education-skills/apprenticeships'),
#  (813, '/national-insurance/what-national-insurance-is-for'),
#  (814, '/tax-on-your-private-pension/pension-tax-relief'),
#  (815, '/personal-tax-account'),
#  (816, '/topic/dealing-with-hmrc/paying-hmrc'),
#  (817, '/guidance/recruiting-people-from-outside-the-uk'),
#  (818, '/employers-sick-pay/entitlement'),
#  (819, '/pension-credit/eligibility'),
#  (820, '/find-lost-utr-number'),
#  (821, '/book-theory-test'),
#  (822, '/settled-status-eu-citizens-families/applying-for-settled-status'),
#  (823, '/disability-premiums/how-to-claim'),
#  (824, '/sign-in-help-to-save'),
#  (825,
#   '/government/publications/basic-check-guidance-and-policies/basic-check-id-checking-guidelines-from-1-july-2021'),
#  (826, '/government/collections/dbs-filtering-guidance'),
#  (827, '/independent-livingfund'),
#  (828, '/claim-benefits-abroad'),
#  (829, '/over-80-pension/further-information'),
#  (830, '/time-off-for-dependants/whats-an-emergency'),
#  (831, '/parental-leave/entitlement'),
#  (832, '/student-visa/money'),
#  (833, '/check-national-insurance-record'),
#  (834, '/vehicle-tax'),
#  (835, '/flexible-working'),
#  (836, '/topic/immigration-operational-guidance/immigration-rules'),
#  (837, '/changes-affect-tax-credits'),
#  (838, '/uk-visa-sponsorship-employers/eligibility'),
#  (839, '/get-ready-to-employ-someone'),
#  (840, '/contact-student-finance-england'),
#  (841, '/frontier-worker-permit'),
#  (842, '/pip/what-youll-get'),
#  (843, '/jobseekers-allowance/your-jsa-claim'),
#  (844,
#   '/government/publications/national-insurance-get-your-national-insurance-number-in-writing-ca5403'),
#  (845, '/guidance/visa-decision-waiting-times-applications-outside-the-uk'),
#  (846, '/new-state-pension'),
#  (847, '/pension-credit/how-to-claim'),
#  (848, '/claim-loss-notice'),
#  (849,
#   '/guidance/contact-the-department-for-work-and-pensions-about-its-policies'),
#  (850, '/caution-warning-penalty'),
#  (851, '/tell-employer-or-college-about-criminal-record/discharges'),
#  (852, '/financial-help-disabled/home-and-housing'),
#  (853, '/national-insurance-if-you-go-abroad'),
#  (854, '/id-for-driving-licence'),
#  (855, '/benefit-cap/when-youre-not-affected'),
#  (856, '/child-benefit'),
#  (857, '/continuous-employment-what-it-is'),
#  (858, '/settled-status-eu-citizens-families/join-eu-eea-swiss-family-member'),
#  (859, '/government/publications/application-for-a-state-pension-statement'),
#  (860, '/foreign-travel-advice'),
#  (861, '/biometric-residence-permits/not-arrived'),
#  (862, '/report-benefits-change-circumstances'),
#  (863, '/au-pairs-employment-law'),
#  (864, '/family-permit'),
#  (865, '/maternity-pay-leave'),
#  (866, '/government/collections/dbs-checking-service-guidance--2'),
#  (867, '/self-employed-national-insurance-rates'),
#  (868, '/browse/employing-people/recruiting-hiring'),
#  (869, '/the-warm-home-discount-scheme'),
#  (870, '/pension-credit/what-youll-get'),
#  (871, '/taking-sick-leave'),
#  (872, '/carers-allowance/if-youre-working-'),
#  (873, '/agency-workers-your-rights/basic-information-you-should-receive'),
#  (874, '/budgeting-help-benefits/repayments'),
#  (875, '/become-appointee-for-someone-claiming-benefits'),
#  (876, '/government/organisations/hm-revenue-customs'),
#  (877,
#   '/government/publications/claiming-discretionary-housing-payments/claiming-discretionary-housing-payments'),
#  (878, '/child-employment/performance-licences-for-children'),
#  (879, '/housing-benefit'),
#  (880, '/understanding-your-pay/deductions-from-your-pay'),
#  (881, '/government-authorised-exchange'),
#  (882, '/government/organisations/home-office/about/recruitment'),
#  (883, '/transfer-visa'),
#  (884, '/apply-start-up-loan'),
#  (885,
#   '/government/collections/hm-revenue-and-customs-service-availability-and-issues'),
#  (886, '/working-tax-credit/how-to-claim'),
#  (887, '/search/policy-papers-and-consultations'),
#  (888, '/claim-tax-refund'),
#  (889, '/government/organisations/driver-and-vehicle-licensing-agency'),
#  (890, '/apply-to-come-to-the-uk/prove-your-identity'),
#  (891, '/discrimination-your-rights/how-you-can-be-discriminated-against'),
#  (892, '/national-insurance-credits/eligibility'),
#  (893, '/apply-to-come-to-the-uk'),
#  (894, '/carers-allowance/how-to-claim'),
#  (895, '/universal-credit/other-financial-support'),
#  (896, '/whistleblowing'),
#  (897, '/business-finance-support'),
#  (898, '/apply-for-elderly-person-bus-pass'),
#  (899, '/international-pension-centre'),
#  (900, '/appeal-call-up-reserve-forces'),
#  (901, '/bills-benefits'),
#  (902, '/moving-from-benefits-to-work/work-experience-and-volunteering'),
#  (903, '/further-education-courses'),
#  (904,
#   '/government/publications/criminal-records-checks-for-overseas-applicants'),
#  (905, '/armed-forces-pension-calculator'),
#  (906, '/national-insurance/your-national-insurance-number'),
#  (907, '/redundancy-your-rights/get-help-finding-a-new-job'),
#  (908, '/state-pension/what-youll-get'),
#  (909, '/carers-credit'),
#  (910, '/biometric-residence-permits'),
#  (911, '/settled-status-eu-citizens-families/after-youve-applied'),
#  (912,
#   '/government/publications/criminal-records-checks-for-overseas-applicants/countries-a-to-f-applying-for-a-criminal-records-check-for-someone-from-overseas'),
#  (913, '/universal-credit/how-youre-paid'),
#  (914, '/travel-abroad'),
#  (915, '/working-retirement-pension-age'),
#  (916, '/government/publications/skilled-worker-visa-eligible-occupations'),
#  (917, '/apply-housing-benefit-from-council'),
#  (918, '/child-benefit-payment-dates'),
#  (919, '/moving-or-retiring-abroad'),
#  (920, '/parental-bereavement-pay-leave'),
#  (921, '/council-tax-bands'),
#  (922, '/find-travel-test-provider'),
#  (923, '/criminal-record-checks-apply-role/application-process'),
#  (924, '/browse/benefits/manage-your-benefit'),
#  (925, '/universal-credit/how-your-earnings-affect-your-payments'),
#  (926, '/flexible-working/types-of-flexible-working'),
#  (927, '/benefit-cap/how-earnings-affect-when-benefit-cap-starts'),
#  (928, '/housing-benefit/what-youll-get'),
#  (929, '/browse/visas-immigration/immigration-appeals'),
#  (930, '/flexible-working/applying-for-flexible-working'),
#  (931, '/maternity-pay-leave/extra-help'),
#  (932, '/get-tax-free-childcare'),
#  (933, '/find-local-council'),
#  (934, '/statutory-sick-pay/what-youll-get'),
#  (935, '/get-help-hmrc-extra-support'),
#  (936, '/international-agreement-worker-visa'),
#  (937,
#   '/guidance/coronavirus-covid-19-testing-for-people-travelling-to-england'),
#  (938,
#   '/dbs-check-applicant-criminal-record/get-a-standard-or-enhanced-dbs-check-for-an-employee'),
#  (939, '/skilled-worker-visa/switch-to-this-visa'),
#  (940, '/tax-company-benefits'),
#  (941,
#   '/guidance/plan-for-jobs-skills-and-employment-programmes-information-for-employers'),
#  (942, '/if-you-become-disabled'),
#  (943, '/change-address-driving-licence'),
#  (944,
#   '/government/organisations/hm-revenue-customs/contact/income-tax-enquiries-for-individuals-pensioners-and-employees'),
#  (945, '/access-to-work/report-a-change-of-circumstances'),
#  (946, '/assisted-digital-help-online-applications'),
#  (947, '/payslips'),
#  (948, '/log-in-file-self-assessment-tax-return'),
#  (949, '/tax-on-pension/tax-free'),
#  (950, '/recruit-apprentice'),
#  (951,
#   '/new-state-pension/inheriting-or-increasing-state-pension-from-a-spouse-or-civil-partner'),
#  (952, '/guidance/pay-apprenticeship-levy'),
#  (953, '/benefit-overpayments'),
#  (954, '/topic/business-tax/pension-scheme-administration'),
#  (955, '/tax-uk-income-live-abroad'),
#  (956, '/advanced-learner-loan/bursary-fund'),
#  (957, '/browse/childcare-parenting/childcare'),
#  (958, '/deferring-state-pension'),
#  (959, '/tax-codes/tell-hmrc-about-a-change-tax-code'),
#  (960, '/rest-breaks-work/compensatory-rest'),
#  (961, '/solve-workplace-dispute'),
#  (962, '/working-when-pregnant-your-rights'),
#  (963, '/the-warm-home-discount-scheme/low-income'),
#  (964, '/government/publications/dbs-identity-checking-guidelines'),
#  (965, '/register-employer'),
#  (966, '/national-minimum-wage'),
#  (967, '/personal-tax-account/sign-in/prove-identity'),
#  (968,
#   '/guidance/return-to-your-claim-for-the-self-employment-income-support-scheme'),
#  (969, '/guidance/track-a-dbs-application'),
#  (970, '/time-off-for-dependants/problems-when-you-take-time-off'),
#  (971, '/employers-workplace-pensions-rules'),
#  (972,
#   '/settled-status-eu-citizens-families/family-member-eligible-person-from-northern-ireland'),
#  (973, '/government/publications/apprenticeships-off-the-job-training'),
#  (974, '/report-problem-criminal-record-certificate/dispute-a-mistake'),
#  (975, '/income-tax/check-youre-paying-the-right-amount'),
#  (976, '/time-off-for-dependants'),
#  (977,
#   '/guidance/how-your-trading-conditions-affect-your-eligibility-for-the-self-employment-income-support-scheme'),
#  (978, '/settle-in-the-uk'),
#  (979, '/income-support/if-you-already-get-income-support'),
#  (980, '/contracted-out/new-state-pension'),
#  (981, '/rest-breaks-work/taking-breaks'),
#  (982, '/check-state-pension/sign-in/prove-identity'),
#  (983, '/government/collections/apprenticeship-changes'),
#  (984,
#   '/government/publications/introducing-govuk-verify/introducing-govuk-verify'),
#  (985, '/search/guidance-and-regulation'),
#  (986, '/employing-an-apprentice/apprenticeship-agreement'),
#  (987, '/sure-start-maternity-grant/what-youll-get'),
#  (988, '/pension-credit/change-of-circumstances'),
#  (989, '/death-spouse-benefits-tax-pension/benefits'),
#  (990, '/guidance/apprenticeship-funding-rules'),
#  (991, '/uk-visa-sponsorship-employers/apply-for-your-licence'),
#  (992, '/guidance/responsible-organisations'),
#  (993, '/government/organisations/department-for-education'),
#  (994,
#   '/employment-contracts-and-conditions/written-statement-of-employment-particulars'),
#  (995, '/careers-helpline-for-teenagers'),
#  (996, '/paternity-pay-leave/pay'),
#  (997, '/contract-types-and-employer-responsibilities'),
#  (998, '/government/publications/traineeship-providers'),
#  (999, '/join-trade-union'),
#  ...]

# %%
len(shortest_seed0_1_list + shortest_seed0_2_list + g_degree_list)
# Out:
# 3552

# %%
pd.DataFrame.from_records(
        shortest_seed0_1_list + shortest_seed0_2_list + g_degree_list
    )
# Out:
#          0                                                  1
# 0        0                        /browse/working/finding-job
# 1        1  /government/organisations/hm-revenue-customs/a...
# 2        2                                     /check-uk-visa
# 3        3  /guidance/dbs-check-requests-guidance-for-empl...
# 4        4                  /jobseekers-allowance/eligibility
# ...    ...                                                ...
# 3547  1179                   /agency-workers-your-rights/fees
# 3548  1180                                  /chwilio-am-swydd
# 3549  1181                    /learner-support/what-youll-get
# 3550  1182  /industrial-injuries-disablement-benefit/what-...
# 3551  1183  /government/publications/application-for-mot-a...
#
# [3552 rows x 2 columns]

# %%
# take average of rank for each page path (non-weighted)
ranked_items = (
    pd.DataFrame.from_records(
        shortest_seed0_1_list + shortest_seed0_2_list + g_degree_list # this combines 3 lists into one long list
    )
    .groupby(1) # group by column named "1": i.e. by page path
    .mean()
    .round()
    .reset_index()
)
ranked_items = ranked_items.rename(columns={1: "page", 0: "rank"})
ranked_items = ranked_items.sort_values(by=["rank"])

# %%
ranked_items
# Out:
#                                                    page    rank
# 761               /log-in-register-hmrc-online-services    21.0
# 68                                   /become-apprentice    22.0
# 159                         /browse/working/finding-job    23.0
# 1113                                  /universal-credit    26.0
# 967                           /sign-in-universal-credit    26.0
# ...                                                 ...     ...
# 574   /government/publications/skilled-worker-visa-s...  1131.0
# 79    /benefit-overpayments/repayments-when-someone-...  1144.0
# 140                           /browse/tax/capital-gains  1159.0
# 892                    /private-renting/document-checks  1170.0
# 673   /guidance/veterans-uk-armed-forces-pensions-forms  1174.0
#
# [1184 rows x 2 columns]

# %%
# download as csv file
# ranked_items.to_csv("../../data/processed/ranked_items.csv", index=False)

# %% [markdown]
# ## Create final output

# %% [markdown]
# ### Add document type and session hit data to final csv file
#
# Document supertypes as per: https://docs.publishing.service.gov.uk/document-types/content_purpose_supergroup.html

# %%
# extract: documentType, sessionHitsAll, entranceHit, exitHit, entranceAndExitHit
df_page = pd.DataFrame([i[0] for i in economic_recovery_subgraph], columns=["page"])
df_info = pd.DataFrame([i[1] for i in economic_recovery_subgraph])
df_all = df_page.join(df_info)

# define a set for news and communication doc types
news_and_comms_doctypes = {
    "medical_safety_alert",
    "drug_safety_update",
    "news_article",
    "news_story",
    "press_release",
    "world_location_news_article",
    "world_news_story",
    "fatality_notice",
    "fatality_notice",
    "tax_tribunal_decision",
    "utaac_decision",
    "asylum_support_decision",
    "employment_appeal_tribunal_decision",
    "employment_tribunal_decision",
    "employment_tribunal_decision",
    "service_standard_report",
    "cma_case",
    "decision",
    "oral_statement",
    "written_statement",
    "authored_article",
    "correspondence",
    "speech",
    "government_response",
    "case_study",
}

# define a set for service doc types
service_doctypes = {
    "completed_transaction",
    "local_transaction",
    "form",
    "calculator",
    "smart_answer",
    "simple_smart_answer",
    "place",
    "licence",
    "step_by_step_nav",
    "transaction",
    "answer",
    "guide",
}

# define a set for guidance and regulation doc types
guidance_and_reg_doctypes = {
    "regulation",
    "detailed_guide",
    "manual",
    "manual_section",
    "guidance",
    "map",
    "calendar",
    "statutory_guidance",
    "notice",
    "international_treaty",
    "travel_advice",
    "promotional",
    "international_development_fund",
    "countryside_stewardship_grant",
    "esi_fund",
    "business_finance_support_scheme",
    "statutory_instrument",
    "hmrc_manual",
    "standard",
}

# define a set for policy and engagement doc types
policy_and_engage_doctypes = {
    "impact_assessment",
    "policy_paper",
    "open_consultation",
    "policy_paper",
    "closed_consultation",
    "consultation_outcome",
    "policy_and_engagement",
}

# define a set for research and statistics doc types
research_and_stats_doctypes = {
    "dfid_research_output",
    "independent_report",
    "research",
    "statistics",
    "national_statistics",
    "statistics_announcement",
    "national_statistics_announcement",
    "official_statistics_announcement",
    "statistical_data_set",
    "official_statistics",
}

# define a set for transparency doc types
transparency_doctypes = {
    "transparency",
    "corporate_report",
    "foi_release",
    "aaib_report",
    "raib_report",
    "maib_report",
}

# loop through document types and create document supertype column
document_type_dict = dict.fromkeys(list(set(df_info["documentType"])))

for docType, docSupertype in document_type_dict.items():
    if docType in news_and_comms_doctypes:
        document_type_dict[docType] = "news and communication"

    elif docType in service_doctypes:
        document_type_dict[docType] = "services"

    elif docType in guidance_and_reg_doctypes:
        document_type_dict[docType] = "guidance and regulation"

    elif docType in policy_and_engage_doctypes:
        document_type_dict[docType] = "policy and engagement"

    elif docType in research_and_stats_doctypes:
        document_type_dict[docType] = "research and statistics"

    elif docType in transparency_doctypes:
        document_type_dict[docType] = "transparency"

    else:
        document_type_dict[docType] = "other"

df_docSuper = pd.DataFrame(
    document_type_dict.items(), columns=["documentType", "documentSupertype"]
)

df_all = pd.merge(df_all, df_docSuper, how="left")

# reoder and rename columns
df_all = df_all[
    [
        "page",
        "documentType",
        "documentSupertype",
        "sessionHitsAll",
        "entranceHit",
        "exitHit",
        "entranceAndExitHit",
    ]
]
df_all = df_all.rename(
    columns={
        "documentType": "document type",
        "documentSupertype": "document supertype",
        "sessionHitsAll": "number of sessions that visit this page",
        "entranceHit": "number of sessions where this page is an entrance hit",
        "exitHit": "number of sessions where this page is an exit hit",
        "entranceAndExitHit": "number of sessions where this page is both an entrance and exit hit",
    }
)

# %% [markdown]
# ### Add ranking to final csv file

# %%
# shortest_seed0_1
df_shortest_seed_0_1 = pd.DataFrame(
    shortest_seed0_1.items(),
    columns=[
        "page",
        "distance from `/browse/working/finding-job` (e.g. the higher the value is, the further away the page is from /browse/working/finding-job)",
    ],
)
df_all = pd.merge(df_all, df_shortest_seed_0_1, how="left")

# shortest_seed0_2
df_shortest_seed_0_2 = pd.DataFrame(
    shortest_seed0_2.items(),
    columns=[
        "page",
        "distance from `/topic/further-education-skills/apprenticeships (e.g. the higher the value is, the further away the page is from /topic/further-education-skills/apprenticeships)",
    ],
)
df_all = pd.merge(df_all, df_shortest_seed_0_2, how="left")

# where NaN, add 'no path' (NaN = no path is present between the source and target nodes)
df_all.fillna("no path", inplace=True)

# g_degree
df_g_degree = pd.DataFrame(
    g_degree.items(),
    columns=[
        "page",
        "the number of pages a user moves to/from between this page and another page in the list (e.g. the higher the value, the more users have moved to/from this page and another page in the list)",
    ],
)
df_all = pd.merge(df_all, df_g_degree, how="left")

# %% [markdown]
# ### Order final csv by rank

# %%
# page path becomes an index:
df_all = df_all.set_index("page")
# order webpages by the ranking (the highe rth better), which is stored in ranked_items dataframe
df_all = df_all.reindex(index=ranked_items["page"]).reset_index()

# %%
df_all
# Out:
#                                                    page  \
# 0                 /log-in-register-hmrc-online-services
# 1                                    /become-apprentice
# 2                           /browse/working/finding-job
# 3                                     /universal-credit
# 4                             /sign-in-universal-credit
# ...                                                 ...
# 1179  /government/publications/skilled-worker-visa-s...
# 1180  /benefit-overpayments/repayments-when-someone-...
# 1181                          /browse/tax/capital-gains
# 1182                   /private-renting/document-checks
# 1183  /guidance/veterans-uk-armed-forces-pensions-forms
#
#                document type       document supertype  \
# 0                      guide                 services
# 1                      guide                 services
# 2     mainstream_browse_page                    other
# 3                      guide                 services
# 4                transaction                 services
# ...                      ...                      ...
# 1179        html_publication                    other
# 1180                   guide                 services
# 1181  mainstream_browse_page                    other
# 1182                   guide                 services
# 1183          detailed_guide  guidance and regulation
#
#       number of sessions that visit this page  \
# 0                                        1765
# 1                                        5377
# 2                                        6709
# 3                                        4140
# 4                                        7527
# ...                                       ...
# 1179                                       35
# 1180                                       28
# 1181                                       52
# 1182                                      111
# 1183                                       45
#
#       number of sessions where this page is an entrance hit  \
# 0                                                   652
# 1                                                   585
# 2                                                   410
# 3                                                   217
# 4                                                  3403
# ...                                                 ...
# 1179                                                  3
# 1180                                                  5
# 1181                                                  1
# 1182                                                 10
# 1183                                                 18
#
#       number of sessions where this page is an exit hit  \
# 0                                                   447
# 1                                                  1403
# 2                                                   753
# 3                                                  1076
# 4                                                  2042
# ...                                                 ...
# 1179                                                  3
# 1180                                                  2
# 1181                                                  0
# 1182                                                  4
# 1183                                                  0
#
#       number of sessions where this page is both an entrance and exit hit  \
# 0                                                    32
# 1                                                  1107
# 2                                                   304
# 3                                                    24
# 4                                                   349
# ...                                                 ...
# 1179                                                  0
# 1180                                                  0
# 1181                                                  0
# 1182                                                  0
# 1183                                                  0
#
#       distance from `/browse/working/finding-job` (e.g. the higher the value is, the further away the page is from /browse/working/finding-job)  \
# 0                                                     1
# 1                                                     1
# 2                                                     0
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 1179                                                  3
# 1180                                                  3
# 1181                                                  3
# 1182                                                  3
# 1183                                                  3
#
#       distance from `/topic/further-education-skills/apprenticeships (e.g. the higher the value is, the further away the page is from /topic/further-education-skills/apprenticeships)  \
# 0                                                     1
# 1                                                     1
# 2                                                     1
# 3                                                     1
# 4                                                     1
# ...                                                 ...
# 1179                                                  3
# 1180                                                  3
# 1181                                                  3
# 1182                                                  3
# 1183                                                  4
#
#       the number of pages a user moves to/from between this page and another page in the list (e.g. the higher the value, the more users have moved to/from this page and another page in the list)
# 0                                              0.276416
# 1                                              0.168216
# 2                                              0.197802
# 3                                              0.288250
# 4                                              0.343195
# ...                                                 ...
# 1179                                           0.008453
# 1180                                           0.010989
# 1181                                           0.007608
# 1182                                           0.008453
# 1183                                           0.006762
#
# [1184 rows x 10 columns]

# %%
df_all.to_csv("../data/outputs/original_method/original_method_ranking.csv", index=False)

# %%
ranked_items
# Out:
#                                                    page    rank
# 761               /log-in-register-hmrc-online-services    21.0
# 68                                   /become-apprentice    22.0
# 159                         /browse/working/finding-job    23.0
# 1113                                  /universal-credit    26.0
# 967                           /sign-in-universal-credit    26.0
# ...                                                 ...     ...
# 574   /government/publications/skilled-worker-visa-s...  1131.0
# 79    /benefit-overpayments/repayments-when-someone-...  1144.0
# 140                           /browse/tax/capital-gains  1159.0
# 892                    /private-renting/document-checks  1170.0
# 673   /guidance/veterans-uk-armed-forces-pensions-forms  1174.0
#
# [1184 rows x 2 columns]
